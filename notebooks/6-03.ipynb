# %%
# ●リスト6.3.1：高レベルのインタフェースのインポート例
from bokeh.charts import Line, output_notebook, show

# %%
# ●リスト6.3.3：output_notebook関数の実行
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5a245ee7-ca1d-4c03-8abd-9b34af57e1c9">Loading BokehJS ...</span>
#     </div>

# %%
# ●リスト6.3.5：インスタンス作成
p = Line([1, 2])

# %%
# ●リスト6.3.7：グラフの調整
p.plot_height = 200
p.plot_width = 200

# %%
# ●リスト6.3.9：グラフ出力
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b82071a9-2514-4b9d-8672-a721cbab6745"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b82071a9-2514-4b9d-8672-a721cbab6745");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b82071a9-2514-4b9d-8672-a721cbab6745");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b82071a9-2514-4b9d-8672-a721cbab6745' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"968c8834-e6b3-4763-bb45-7e4be1df1a2d":{"roots":{"references":[{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"25d2036e-e0e1-4ea7-b722-68cfae63eb5c","type":"WheelZoomTool"},{"attributes":{},"id":"255a5d52-9de1-4c41-864a-473ee1268a11","type":"BasicTicker"},{"attributes":{"callback":null,"end":2.1,"start":0.9},"id":"782a6169-1d6f-453c-8276-bcf27f204bd1","type":"Range1d"},{"attributes":{"overlay":{"id":"8715ee90-3477-43fd-98d8-90de5ea5126d","type":"BoxAnnotation"},"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"dff7afb1-6fd9-4062-9760-aa507065fbbd","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"bd289e19-aff4-405a-bc8c-53813bbc9c0d","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"},"ticker":{"id":"c6d0fe6d-8b01-48c9-b10b-d08281a342a4","type":"BasicTicker"}},"id":"11ad0607-0f66-4cb2-a04c-a9b973792d7f","type":"Grid"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"7a31e5a6-5099-48db-97ce-f385495bb514","type":"ResetTool"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"347c5ba6-0f26-4cf4-b37a-f1dfbbf0370d","type":"Line"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"c4e30fcb-df04-49cd-8fc8-fec53fc2a7b4","type":"HelpTool"},{"attributes":{"data_source":{"id":"8fe803f1-22ec-4a95-8071-2ae4dcfed6ad","type":"ColumnDataSource"},"glyph":{"id":"347c5ba6-0f26-4cf4-b37a-f1dfbbf0370d","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"1223c39a-cb65-4294-9507-afd6747152b9","type":"GlyphRenderer"},{"attributes":{"axis_label":"index","formatter":{"id":"92023e68-acec-4387-a798-55cfd54fba05","type":"BasicTickFormatter"},"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"},"ticker":{"id":"255a5d52-9de1-4c41-864a-473ee1268a11","type":"BasicTicker"}},"id":"d4b3903b-b3ab-4165-91d5-9ecea1afd31c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"a"},{"series":"a"}],"series":["a","a"],"x_values":[0,1],"y_values":[1,2]}},"id":"8fe803f1-22ec-4a95-8071-2ae4dcfed6ad","type":"ColumnDataSource"},{"attributes":{},"id":"c6d0fe6d-8b01-48c9-b10b-d08281a342a4","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"598cdefd-df19-4292-9305-5c61b41d3a9a","type":"PanTool"},{"id":"25d2036e-e0e1-4ea7-b722-68cfae63eb5c","type":"WheelZoomTool"},{"id":"dff7afb1-6fd9-4062-9760-aa507065fbbd","type":"BoxZoomTool"},{"id":"bd289e19-aff4-405a-bc8c-53813bbc9c0d","type":"SaveTool"},{"id":"7a31e5a6-5099-48db-97ce-f385495bb514","type":"ResetTool"},{"id":"c4e30fcb-df04-49cd-8fc8-fec53fc2a7b4","type":"HelpTool"}]},"id":"271e1f43-3f36-47d6-a60c-67e8fde21c33","type":"Toolbar"},{"attributes":{"callback":null,"end":1.1,"start":-0.1},"id":"c24f5508-7f34-425b-a7ef-a220c18ae0f3","type":"Range1d"},{"attributes":{"items":[{"id":"cb63353c-55c6-4070-a65b-d1a4bba75877","type":"LegendItem"}],"location":"top_left","plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"3d83b0b3-89bb-4ca6-93e5-9c90beced8d2","type":"Legend"},{"attributes":{},"id":"bc4c51b3-83fb-484e-8af6-54550f70a960","type":"ToolEvents"},{"attributes":{},"id":"1df5d9e2-bdf4-4f13-9e21-fbdcbdc6c501","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"a"},"renderers":[{"id":"1223c39a-cb65-4294-9507-afd6747152b9","type":"GlyphRenderer"}]},"id":"cb63353c-55c6-4070-a65b-d1a4bba75877","type":"LegendItem"},{"attributes":{"below":[{"id":"d4b3903b-b3ab-4165-91d5-9ecea1afd31c","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"e929a3 ...

# %%
# ●リスト6.3.11：HTMLファイルにグラフを出力する
from bokeh.charts import output_file
output_file('out.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dcc35f13-93b1-4259-a6ec-6257c0b6308b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dcc35f13-93b1-4259-a6ec-6257c0b6308b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dcc35f13-93b1-4259-a6ec-6257c0b6308b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dcc35f13-93b1-4259-a6ec-6257c0b6308b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"38d21731-8812-4444-a7ac-5d179851a6ba":{"roots":{"references":[{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"25d2036e-e0e1-4ea7-b722-68cfae63eb5c","type":"WheelZoomTool"},{"attributes":{},"id":"255a5d52-9de1-4c41-864a-473ee1268a11","type":"BasicTicker"},{"attributes":{"callback":null,"end":2.1,"start":0.9},"id":"782a6169-1d6f-453c-8276-bcf27f204bd1","type":"Range1d"},{"attributes":{"overlay":{"id":"8715ee90-3477-43fd-98d8-90de5ea5126d","type":"BoxAnnotation"},"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"dff7afb1-6fd9-4062-9760-aa507065fbbd","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"bd289e19-aff4-405a-bc8c-53813bbc9c0d","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"},"ticker":{"id":"c6d0fe6d-8b01-48c9-b10b-d08281a342a4","type":"BasicTicker"}},"id":"11ad0607-0f66-4cb2-a04c-a9b973792d7f","type":"Grid"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"7a31e5a6-5099-48db-97ce-f385495bb514","type":"ResetTool"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"347c5ba6-0f26-4cf4-b37a-f1dfbbf0370d","type":"Line"},{"attributes":{"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"c4e30fcb-df04-49cd-8fc8-fec53fc2a7b4","type":"HelpTool"},{"attributes":{"data_source":{"id":"8fe803f1-22ec-4a95-8071-2ae4dcfed6ad","type":"ColumnDataSource"},"glyph":{"id":"347c5ba6-0f26-4cf4-b37a-f1dfbbf0370d","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"1223c39a-cb65-4294-9507-afd6747152b9","type":"GlyphRenderer"},{"attributes":{"axis_label":"index","formatter":{"id":"92023e68-acec-4387-a798-55cfd54fba05","type":"BasicTickFormatter"},"plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"},"ticker":{"id":"255a5d52-9de1-4c41-864a-473ee1268a11","type":"BasicTicker"}},"id":"d4b3903b-b3ab-4165-91d5-9ecea1afd31c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"a"},{"series":"a"}],"series":["a","a"],"x_values":[0,1],"y_values":[1,2]}},"id":"8fe803f1-22ec-4a95-8071-2ae4dcfed6ad","type":"ColumnDataSource"},{"attributes":{},"id":"c6d0fe6d-8b01-48c9-b10b-d08281a342a4","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"598cdefd-df19-4292-9305-5c61b41d3a9a","type":"PanTool"},{"id":"25d2036e-e0e1-4ea7-b722-68cfae63eb5c","type":"WheelZoomTool"},{"id":"dff7afb1-6fd9-4062-9760-aa507065fbbd","type":"BoxZoomTool"},{"id":"bd289e19-aff4-405a-bc8c-53813bbc9c0d","type":"SaveTool"},{"id":"7a31e5a6-5099-48db-97ce-f385495bb514","type":"ResetTool"},{"id":"c4e30fcb-df04-49cd-8fc8-fec53fc2a7b4","type":"HelpTool"}]},"id":"271e1f43-3f36-47d6-a60c-67e8fde21c33","type":"Toolbar"},{"attributes":{"callback":null,"end":1.1,"start":-0.1},"id":"c24f5508-7f34-425b-a7ef-a220c18ae0f3","type":"Range1d"},{"attributes":{"items":[{"id":"cb63353c-55c6-4070-a65b-d1a4bba75877","type":"LegendItem"}],"location":"top_left","plot":{"id":"8740bb1d-1bac-4132-9f16-4224a3d4ed7a","subtype":"Chart","type":"Plot"}},"id":"3d83b0b3-89bb-4ca6-93e5-9c90beced8d2","type":"Legend"},{"attributes":{},"id":"bc4c51b3-83fb-484e-8af6-54550f70a960","type":"ToolEvents"},{"attributes":{},"id":"1df5d9e2-bdf4-4f13-9e21-fbdcbdc6c501","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"a"},"renderers":[{"id":"1223c39a-cb65-4294-9507-afd6747152b9","type":"GlyphRenderer"}]},"id":"cb63353c-55c6-4070-a65b-d1a4bba75877","type":"LegendItem"},{"attributes":{"below":[{"id":"d4b3903b-b3ab-4165-91d5-9ecea1afd31c","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"e929a3 ...

# %%
# ●リスト6.3.12：出力先を元に戻す
from bokeh.io import reset_output
reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="39d757e5-150c-4b0b-96ee-2b089da1bc12">Loading BokehJS ...</span>
#     </div>
