# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-4: さまざまな線の調整

# %%
# リスト7.4.1：線の太さの設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([0, 1, 2], [1, 2, 3], line_width=4)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e0bb1451-791f-49df-ba32-fc4e17c44426">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5e5f464-6de2-491d-8d78-3b8f290d4774"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f5e5f464-6de2-491d-8d78-3b8f290d4774");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5e5f464-6de2-491d-8d78-3b8f290d4774");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5e5f464-6de2-491d-8d78-3b8f290d4774' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9a7113f8-3409-4a31-be83-3c91c6796ba7":{"roots":{"references":[{"attributes":{},"id":"7bfa851b-7018-4a6f-9621-3f791d199837","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"52ca6590-1cd0-4cea-b56b-353c5815ecbc","type":"BoxAnnotation"},"plot":{"id":"e8eb9ff0-0191-4662-83f2-523c9df11c84","subtype":"Figure","type":"Plot"}},"id":"8217929c-0fac-43d9-8d04-c467c16c2a91","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"79b38756-dfe5-4872-8bbf-4fa7fcb92484","type":"ColumnDataSource"},"glyph":{"id":"0bbcf2c2-0313-4915-af75-a0f91581e21c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"11d4b198-a45a-4e09-ac01-7d2c46aa1bfe","type":"Line"},"selection_glyph":null},"id":"bd998df3-c322-4af4-8734-86072d73e468","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e8eb9ff0-0191-4662-83f2-523c9df11c84","subtype":"Figure","type":"Plot"}},"id":"0566b65b-dbff-47d4-8aa3-e1dc2a009cc7","type":"SaveTool"},{"attributes":{},"id":"ff445c53-0317-49f4-be3e-b67fb479cfa6","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6ab39505-a805-4b26-8448-f1bd28f0dc50","type":"PanTool"},{"id":"9342659a-a09e-4598-8d40-520040a0397f","type":"WheelZoomTool"},{"id":"8217929c-0fac-43d9-8d04-c467c16c2a91","type":"BoxZoomTool"},{"id":"0566b65b-dbff-47d4-8aa3-e1dc2a009cc7","type":"SaveTool"},{"id":"c11d3a0e-5dcd-4751-986a-e03460a7e7ec","type":"ResetTool"},{"id":"e1bdf90f-39be-4aae-b20f-93a4df0ed43d","type":"HelpTool"}]},"id":"163809de-1bb0-4718-99b3-51993fc309e6","type":"Toolbar"},{"attributes":{},"id":"5a0e551c-ec76-4c9c-b293-ddd7a81d67e3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"e8eb9ff0-0191-4662-83f2-523c9df11c84","subtype":"Figure","type":"Plot"}},"id":"c11d3a0e-5dcd-4751-986a-e03460a7e7ec","type":"ResetTool"},{"attributes":{"plot":{"id":"e8eb9ff0-0191-4662-83f2-523c9df11c84","subtype":"Figure","type":"Plot"}},"id":"e1bdf90f-39be-4aae-b20f-93a4df0ed43d","type":"HelpTool"},{"attributes":{"callback":null},"id":"0bc8699f-5abf-4baf-866a-d37c78a02efb","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2],"y":[1,2,3]}},"id":"79b38756-dfe5-4872-8bbf-4fa7fcb92484","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"52ca6590-1cd0-4cea-b56b-353c5815ecbc","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d72341ce-1e98-4270-8696-af8660f244e5","type":"LinearAxis"}],"left":[{"id":"5098c1e7-34ba-4b84-9042-9f7a2a91711a","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"d72341ce-1e98-4270-8696-af8660f244e5","type":"LinearAxis"},{"id":"0bfdd547-99a4-4be4-a4b3-ed3d57215933","type":"Grid"},{"id":"5098c1e7-34ba-4b84-9042-9f7a2a91711a","type":"LinearAxis"},{"id":"c4ccc0b7-5193-4400-b1a0-cb1bf094f440","type":"Grid"},{"id":"52ca6590-1cd0-4cea-b56b-353c5815ecbc","type":"BoxAnnotation"},{"id":"bd998df3-c322-4af4-8734-86072d73e468","type":"GlyphRenderer"}],"title":{"id":"db4762b3-f26e-4f8f-8f2b-c7bf69feb553","type":"Title"},"tool_events":{"id":"ff445c53-0317-49f4-be3e-b67fb479cfa6","type":"ToolEvents"},"toolbar":{"id":"163809de-1bb0-4718-99b3-51993fc309e6","type":"Toolbar"},"x_range":{"id":"5a13030a-c37a-4880-9f57-06971e18a358","type":"DataRange1d"},"y_range":{"id":"0bc8699f-5abf-4baf-866a-d37c78a02efb","type":"DataRange1d"}},"id":"e8eb9ff0-0191-4662-83f2-523c9df11c84","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"0bbcf2c2-0313-4915-af75-a0f91581e21c","type":"Line"},{"attributes":{},"id":"c3905b16-11fe-4da0-bef7-e47767daba6d","type":"BasicTicker"},{"attributes":{"plot" ...

# %%
# リスト7.4.2：線の色の設定
p = figure(plot_width=200, plot_height=200)
p.line([0, 1, 2], [1, 2, 3], line_color="red")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0df02c64-5a0e-4380-8f4b-f86971851553"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0df02c64-5a0e-4380-8f4b-f86971851553");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0df02c64-5a0e-4380-8f4b-f86971851553");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0df02c64-5a0e-4380-8f4b-f86971851553' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"14ae529b-a95a-4803-accc-1ba98ecbfea1":{"roots":{"references":[{"attributes":{"formatter":{"id":"51fdb520-2bcc-41eb-9228-4545b49a1296","type":"BasicTickFormatter"},"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"},"ticker":{"id":"09ac40af-bc06-4719-a3d5-a97840688035","type":"BasicTicker"}},"id":"e9e9814a-40b3-4c28-9d81-d7a6f2b304dd","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"99396504-066b-40b4-a29a-101545e90da4","type":"PanTool"},{"id":"4f5f3660-d83b-460d-b827-e7fe64e34f85","type":"WheelZoomTool"},{"id":"d089b227-7023-4f34-818a-26dedbb8e840","type":"BoxZoomTool"},{"id":"d86b26a1-a2eb-442c-9412-001d446de04a","type":"SaveTool"},{"id":"145952b5-639e-4025-a4ed-f249f87c7683","type":"ResetTool"},{"id":"86a57947-137f-4fd2-a65e-1ee5dd883935","type":"HelpTool"}]},"id":"93b138a4-b72c-444b-a718-e4ffb40d0b1f","type":"Toolbar"},{"attributes":{},"id":"09ac40af-bc06-4719-a3d5-a97840688035","type":"BasicTicker"},{"attributes":{"callback":null},"id":"de1b1d03-6188-470d-a9c6-3202a16fd203","type":"DataRange1d"},{"attributes":{"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"}},"id":"99396504-066b-40b4-a29a-101545e90da4","type":"PanTool"},{"attributes":{"callback":null},"id":"226f5176-7355-4216-92e1-011f95c73dc0","type":"DataRange1d"},{"attributes":{},"id":"45c808d1-1e44-4c30-922d-4b1a81a4ae19","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"bb85712b-c887-484d-b252-63a1e6121ccd","type":"LinearAxis"}],"left":[{"id":"e9e9814a-40b3-4c28-9d81-d7a6f2b304dd","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"bb85712b-c887-484d-b252-63a1e6121ccd","type":"LinearAxis"},{"id":"8298d369-8cd7-4605-8401-e7f7d4d79d9c","type":"Grid"},{"id":"e9e9814a-40b3-4c28-9d81-d7a6f2b304dd","type":"LinearAxis"},{"id":"a38bbe9f-9d42-417e-a86f-dbd2217845e0","type":"Grid"},{"id":"295912ba-92f0-4a7e-b73b-fa6eec192ca0","type":"BoxAnnotation"},{"id":"66fd0607-1d00-4de7-b05f-56ecaa1f7d2f","type":"GlyphRenderer"}],"title":{"id":"9d53ebd1-8064-466a-b5f9-972db729fddc","type":"Title"},"tool_events":{"id":"9abf493a-d92e-4911-b99d-fe73062c2d65","type":"ToolEvents"},"toolbar":{"id":"93b138a4-b72c-444b-a718-e4ffb40d0b1f","type":"Toolbar"},"x_range":{"id":"de1b1d03-6188-470d-a9c6-3202a16fd203","type":"DataRange1d"},"y_range":{"id":"226f5176-7355-4216-92e1-011f95c73dc0","type":"DataRange1d"}},"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2],"y":[1,2,3]}},"id":"b178118a-09ed-48ec-b212-5bbf0014f18e","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"}},"id":"145952b5-639e-4025-a4ed-f249f87c7683","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68e66703-2b9a-4622-a5fb-ceeacb3e0acb","type":"Line"},{"attributes":{"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"}},"id":"86a57947-137f-4fd2-a65e-1ee5dd883935","type":"HelpTool"},{"attributes":{"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"}},"id":"d86b26a1-a2eb-442c-9412-001d446de04a","type":"SaveTool"},{"attributes":{},"id":"9abf493a-d92e-4911-b99d-fe73062c2d65","type":"ToolEvents"},{"attributes":{"overlay":{"id":"295912ba-92f0-4a7e-b73b-fa6eec192ca0","type":"BoxAnnotation"},"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"}},"id":"d089b227-7023-4f34-818a-26dedbb8e840","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"57f9080a-0f85-42f3-84a5-b67ebd2b05cc","subtype":"Figure","type":"Plot"},"ticker":{"id":"b080ec63-d292-418c-a0f8-defeebf8bf84","type":"BasicTicker"}},"id":"8298d369-8cd7-4605-8401-e7f7d4d79d9c","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"9d53 ...

# %%
# リスト7.4.3：線の不透明度設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 3.5))
p.line([0, 1], [3, 3], line_color="green", line_width=30)
p.line([0, 1], [2, 2], line_alpha=0.6, line_color="green", line_width=30)
p.line([0, 1], [1, 1], line_color=(0, 255, 0, 0.4), line_width=30)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="298ecb5e-2927-46e8-b437-ef8f40e71746"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("298ecb5e-2927-46e8-b437-ef8f40e71746");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("298ecb5e-2927-46e8-b437-ef8f40e71746");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '298ecb5e-2927-46e8-b437-ef8f40e71746' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1e0de4c1-0d54-4464-bd97-5ac238898a6a":{"roots":{"references":[{"attributes":{"data_source":{"id":"51a7acf6-016c-47b2-8561-0f2be3b7b212","type":"ColumnDataSource"},"glyph":{"id":"a9bd1bdb-597d-4f14-a42d-0e657cf6bfc2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"05cfa62f-5f0c-46d8-a7f2-83024c7a7331","type":"Line"},"selection_glyph":null},"id":"987a0636-8283-4b6b-af75-1309bd5e618f","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":3.5,"start":0.5},"id":"d59dade0-a692-48c7-ac21-5066309f4a40","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f102655-79b3-4048-9dce-0a48c7e52c6f","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[2,2]}},"id":"51a7acf6-016c-47b2-8561-0f2be3b7b212","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"rgba(0, 255, 0, 0.4)"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"299b621d-898a-4c77-9bf7-a225a6e84f9d","type":"Line"},{"attributes":{"data_source":{"id":"d26558d2-7fe7-4eea-9e4e-a5ea1cb85ff6","type":"ColumnDataSource"},"glyph":{"id":"299b621d-898a-4c77-9bf7-a225a6e84f9d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0f102655-79b3-4048-9dce-0a48c7e52c6f","type":"Line"},"selection_glyph":null},"id":"616130a3-becd-4113-9e28-af4efbe960b1","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c727e6ac-66df-4480-b66d-1bc4972850c1","subtype":"Figure","type":"Plot"}},"id":"977bdc9d-2204-43ba-a14c-13d664034b79","type":"HelpTool"},{"attributes":{},"id":"342bdaed-8e06-4abb-8043-b76368ac293b","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"05cfa62f-5f0c-46d8-a7f2-83024c7a7331","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"c727e6ac-66df-4480-b66d-1bc4972850c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"efdfd4fa-1ab8-4e36-aaf4-abbe60b339a5","type":"BasicTicker"}},"id":"82c73c5f-f144-4dee-bb49-803e64f2c13b","type":"Grid"},{"attributes":{},"id":"efdfd4fa-1ab8-4e36-aaf4-abbe60b339a5","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dd1b7e29-4d05-4253-95d2-8c3ef27122e2","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"bf0a5a99-f316-44b4-9d05-b8769f622b92","type":"LinearAxis"}],"left":[{"id":"6c92b100-e095-407e-93d8-88c7903ef56d","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"bf0a5a99-f316-44b4-9d05-b8769f622b92","type":"LinearAxis"},{"id":"a5ee8f47-2261-4f53-a695-687605736a28","type":"Grid"},{"id":"6c92b100-e095-407e-93d8-88c7903ef56d","type":"LinearAxis"},{"id":"82c73c5f-f144-4dee-bb49-803e64f2c13b","type":"Grid"},{"id":"dd1b7e29-4d05-4253-95d2-8c3ef27122e2","type":"BoxAnnotation"},{"id":"096186d3-4b79-460d-8886-289b8aa09e59","type":"GlyphRenderer"},{"id":"987a0636-8283-4b6b-af75-1309bd5e618f","type":"GlyphRenderer"},{"id":"616130a3-becd-4113-9e28-af4efbe960b1","type":"GlyphRenderer"}],"title":{"id":"edd638fd-5585-40d4-a3bc-5d12f0cffef2","type":"Title"},"tool_events":{"id":"7b34e9ee-2a0a-4664-b542-e0b56684a7e5","type":"ToolEvents"},"toolbar":{"id":"c6961cf7-5603-497c-a094-3bc5bbde7b46","type":"Toolbar"},"x_range":{"id":"727f3e04-7dff-4d38-952e-3a31ecd25304","type":"DataRange1d"},"y_range":{"id":"d59dade0-a692-48c7-ac21-5066309f4a40","type":"Range1d"}},"id":"c727e6ac-66df-4480-b66d-1bc4972850c1","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"585456e9-7b5a-4f6c-a03b-e0838df5cdf6","type":"ColumnDataSource"},"glyph":{"id":"a98524a1-72d ...

# %%
# リスト7.4.4：線の結合点の設定
p = figure(plot_width=200, plot_height=200, x_range=(0, 2))
for y, line in enumerate(["bevel", "round", "miter"]):
    p.line([0, 1, 0], [y, y + 0.5, y + 1], line_width=10, line_join=line)
    p.text(1.5, y + 0.5, text=[line], text_align="center")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e1111af-fc0f-493e-8f66-a2910df6b674"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8e1111af-fc0f-493e-8f66-a2910df6b674");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8e1111af-fc0f-493e-8f66-a2910df6b674");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8e1111af-fc0f-493e-8f66-a2910df6b674' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e645fe18-86e3-4ee5-832d-3a77ea9d3e30":{"roots":{"references":[{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":1.5}},"id":"d3629b99-bfac-421b-8993-dabc68feb32e","type":"Text"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0380b79-ff84-47da-85cc-66875b530dfa","type":"Line"},{"attributes":{"plot":{"id":"b7fd11e9-fd70-4847-92a1-c76f75e26ffc","subtype":"Figure","type":"Plot"}},"id":"ee67b317-bb1f-4cf2-80ca-4fcfdfb906d0","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":2},"id":"008d7e0a-333b-4309-b5f7-6ac56fb2099e","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"b7fd11e9-fd70-4847-92a1-c76f75e26ffc","subtype":"Figure","type":"Plot"},"ticker":{"id":"930c5e23-fe4c-4fdd-b706-da4bf313cec5","type":"BasicTicker"}},"id":"474d739e-b3c2-43bb-8470-86236558ca36","type":"Grid"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":2.5}},"id":"99eb8c86-0a63-41e4-8269-dca0eb02c6a7","type":"Text"},{"attributes":{},"id":"930c5e23-fe4c-4fdd-b706-da4bf313cec5","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"634ad6c3-9256-425b-b556-115c78e6f1aa","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"634ad6c3-9256-425b-b556-115c78e6f1aa","type":"BoxAnnotation"},"plot":{"id":"b7fd11e9-fd70-4847-92a1-c76f75e26ffc","subtype":"Figure","type":"Plot"}},"id":"dd18c122-895c-4303-b173-694dca6fe797","type":"BoxZoomTool"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":0.5}},"id":"764b9e76-67d9-4044-8519-da6808656dc1","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":1.5}},"id":"cdfee4b6-ac44-446e-870b-b76b6d0b33dd","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["miter"]}},"id":"15ec1959-3af1-4c8b-a2ab-626d03fcd7fc","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b7fd11e9-fd70-4847-92a1-c76f75e26ffc","subtype":"Figure","type":"Plot"}},"id":"295fcc6c-08c5-4198-8ba9-f567db4798dd","type":"PanTool"},{"attributes":{"data_source":{"id":"80b37199-17fb-41e1-abc1-f17c870b2f7f","type":"ColumnDataSource"},"glyph":{"id":"d3629b99-bfac-421b-8993-dabc68feb32e","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"cdfee4b6-ac44-446e-870b-b76b6d0b33dd","type":"Text"},"selection_glyph":null},"id":"9cb77eb5-a3e4-4b4b-bae0-46727c296bb6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["bevel"]}},"id":"c9a794ab-77ea-4500-b992-c4804260de58","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"928d2f21-6a97-48a2-b2a9-9aa9dc6e1645","type":"ColumnDataSource"},"glyph":{"id":"e0380b79-ff84-47da-85cc-66875b530dfa","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"46acf0c4-6299-4c4f-89f3-3c656e27eac1","type":"Line"},"selection_glyph":null},"id":"708886ef-0aed-4845-ae1b-1206562c6562","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":2.5}},"id":"34f82ea1-7651-42d9-a391-8f6a52d2964f","type":"Text"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"46acf0c4-6299-4c4f-89f3-3c656e27eac1","type":"Line"},{"attributes":{},"id":"16e96b42-1dac-43da-8272-a3443bb36296","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,0],"y": ...

# %%
# リスト7.4.5：線の先端の設定
p = figure(plot_width=200, plot_height=200, x_range=[-0.5, 2.5], y_range=[-0.5, 2.5])
for y, line in enumerate(["square", "round", "butt"]):
    p.line([0, 1], [y, y], line_width=20, line_cap=line)
    p.text(2, y, text=[line], text_align="center")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eaa79650-5f9b-4679-9379-a66acc82edd0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eaa79650-5f9b-4679-9379-a66acc82edd0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eaa79650-5f9b-4679-9379-a66acc82edd0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eaa79650-5f9b-4679-9379-a66acc82edd0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"08260c88-c275-4055-98b7-74c075d0fc4f":{"roots":{"references":[{"attributes":{},"id":"91c99956-84a5-43d3-96f4-fe03b9e5e0bc","type":"BasicTicker"},{"attributes":{"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"}},"id":"f3ad950e-4f85-4e17-8726-013e83cf7a4f","type":"WheelZoomTool"},{"attributes":{"line_cap":"square","line_color":{"value":"#1f77b4"},"line_width":{"value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"002cd4de-80a0-4022-a104-be640abdd3c2","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"square","line_color":{"value":"#1f77b4"},"line_width":{"value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"5777c78b-5341-4f86-9a68-fc4c1eedb821","type":"Line"},{"attributes":{"data_source":{"id":"3532d04e-3cca-4945-941c-85784412833a","type":"ColumnDataSource"},"glyph":{"id":"002cd4de-80a0-4022-a104-be640abdd3c2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5777c78b-5341-4f86-9a68-fc4c1eedb821","type":"Line"},"selection_glyph":null},"id":"d921669b-9193-45a0-b115-07e2fd4d353c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"}},"id":"fc5cbbcf-9469-4696-bc88-f6f5f4fdbc07","type":"PanTool"},{"attributes":{"formatter":{"id":"3103b384-6efc-421e-9617-c86ccdb3ae26","type":"BasicTickFormatter"},"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"},"ticker":{"id":"4e3a0ab6-107f-44fe-be82-49e198e26f75","type":"BasicTicker"}},"id":"5591058d-67f9-4fdb-b261-bb813d28d6c3","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1f8ac63f-e8a8-41f0-8a2e-81d3080b27ce","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"82e9c676-87fc-4a67-914b-718c629c215f","type":"ColumnDataSource"},"glyph":{"id":"1bd3c0eb-db8c-416a-a9d4-c2d18ef36b36","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"89101606-bc92-4ab9-b76e-bc37261a4667","type":"Text"},"selection_glyph":null},"id":"6be304f2-fc77-45d7-8613-271bf076ca35","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[0,0]}},"id":"3532d04e-3cca-4945-941c-85784412833a","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":2},"y":{"value":1}},"id":"9ea2aa01-4bf8-497d-a4da-1dd56110fece","type":"Text"},{"attributes":{"formatter":{"id":"6c474a06-5b47-4a75-b474-9b66e14f63f1","type":"BasicTickFormatter"},"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"},"ticker":{"id":"91c99956-84a5-43d3-96f4-fe03b9e5e0bc","type":"BasicTicker"}},"id":"908d6d39-7288-4756-9315-caed89437e5c","type":"LinearAxis"},{"attributes":{"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"},"ticker":{"id":"4e3a0ab6-107f-44fe-be82-49e198e26f75","type":"BasicTicker"}},"id":"ea05011f-9504-45b3-994a-c51d11d71685","type":"Grid"},{"attributes":{"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"}},"id":"7f883a37-1e07-4a96-b2bc-f7816186fbf3","type":"ResetTool"},{"attributes":{"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"}},"id":"e66f4028-46eb-4c24-a3ab-8d887ebde344","type":"SaveTool"},{"attributes":{"overlay":{"id":"1f8ac63f-e8a8-41f0-8a2e-81d3080b27ce","type":"BoxAnnotation"},"plot":{"id":"e351de7a-a631-486e-bfb3-3e1e79e9f916","subtype":"Figure","type":"Plot"}},"id":"4b031af5-38d5-4b40-98f2-71cd74a3347d","type":"BoxZoomTool"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":2},"y":{"value":1}},"id":"3f0b785a-d1d5 ...

# %%
# リスト7.4.6：線の種類設定①
p = figure(plot_width=200, plot_height=200, y_range=(-0.5, 5))
line_styles = ["solid", "dashed", "dotted", "dotdash", "dashdot"]
for y, line_style in enumerate(line_styles):
    p.line([0, 1], [y, y], line_dash=line_style)
    p.text(0, y, text=[line_style])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="85083240-97f3-4d3e-b70c-0762d2f93a1d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("85083240-97f3-4d3e-b70c-0762d2f93a1d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85083240-97f3-4d3e-b70c-0762d2f93a1d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85083240-97f3-4d3e-b70c-0762d2f93a1d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a7e13bb1-f605-4e39-9166-6af5873047fe":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"19d7ccb9-6ae7-4e30-b0a2-e84f2d65e854","type":"Line"},{"attributes":{},"id":"1537602a-ab8c-4b9f-b05f-eea80b89f298","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"e7579839-c13c-448d-8b14-d3b861489cbb","type":"Line"},{"attributes":{"plot":{"id":"cb4d85fc-2862-4d70-991e-b46bdafb464a","subtype":"Figure","type":"Plot"}},"id":"242be177-6b92-45d3-8329-98127deab053","type":"SaveTool"},{"attributes":{"data_source":{"id":"9832f439-13a4-4e8e-ad11-6ed7329a4dd4","type":"ColumnDataSource"},"glyph":{"id":"19d7ccb9-6ae7-4e30-b0a2-e84f2d65e854","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e7579839-c13c-448d-8b14-d3b861489cbb","type":"Line"},"selection_glyph":null},"id":"ae2a0098-9a68-4fc2-a898-0f06a23e63df","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"cb4d85fc-2862-4d70-991e-b46bdafb464a","subtype":"Figure","type":"Plot"}},"id":"f415ebf1-309e-4801-a4e0-38dbe476414e","type":"PanTool"},{"attributes":{"formatter":{"id":"a79ff418-ee07-4b5a-829c-019b924bbd3e","type":"BasicTickFormatter"},"plot":{"id":"cb4d85fc-2862-4d70-991e-b46bdafb464a","subtype":"Figure","type":"Plot"},"ticker":{"id":"005aaa4c-8d74-4fd6-af36-0af01dac7447","type":"BasicTicker"}},"id":"094e3235-cdb4-4257-9b3d-369fe990b621","type":"LinearAxis"},{"attributes":{"text_color":{"value":"black"},"x":{"value":0},"y":{"value":0}},"id":"2268384e-d09d-409d-a672-ba0037b455d9","type":"Text"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":2}},"id":"f5b5de85-2b55-413b-89de-7cb35377b2eb","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["solid"]}},"id":"64cb8004-5d94-44e7-8efc-fb05574e7365","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["dotted"]}},"id":"69c021d2-ae8d-4733-89ea-4cde2dccd009","type":"ColumnDataSource"},{"attributes":{},"id":"9a680243-da2c-4c7f-985c-c56482b5cae0","type":"ToolEvents"},{"attributes":{"text_color":{"value":"black"},"x":{"value":0},"y":{"value":2}},"id":"a9c433cb-9ee0-4123-be29-a8dd1d75ece9","type":"Text"},{"attributes":{"data_source":{"id":"69c021d2-ae8d-4733-89ea-4cde2dccd009","type":"ColumnDataSource"},"glyph":{"id":"a9c433cb-9ee0-4123-be29-a8dd1d75ece9","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f5b5de85-2b55-413b-89de-7cb35377b2eb","type":"Text"},"selection_glyph":null},"id":"a76cf094-b4e3-49d9-a791-4cfa1846924c","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4,6,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"67f2a047-5e39-4749-b518-a5e99e2a38a1","type":"Line"},{"attributes":{"callback":null},"id":"c430be87-6618-4524-b652-de7fbca18115","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[3,3]}},"id":"b215eece-420a-4d10-90cd-b296c6ad3aaa","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[2,4,6,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"4a3d2778-7ab2-4e73-8aa6-78261cd379e6","type":"Line"},{"attributes":{"data_source":{"id":"b215eece-420a-4d10-90cd-b296c6ad3aaa","type":"ColumnDataSource"},"glyph":{"id":"4a3d2778-7ab2-4e73-8aa6-78261cd379e6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"67f2a047-5e39-4749-b518-a5e99e2a38a1","type":"Line"},"selection_glyph":null},"id":"ae460fe7-bf2d-4402-bc69-decb1fbae5f8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"64cb8004-5d94-44e7-8efc-fb05574e7365","type":"ColumnDataSource"},"glyph":{"id":"2268384e-d09d-409d-a672-ba0037b455d9","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyp ...

# %%
# リスト7.4.7：線の種類設定②
p = figure(plot_width=200, plot_height=200)
p.line([0, 1], [1, 1], line_dash=(10, 2), line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0854cfbd-f97c-4650-b879-5e324a727588"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0854cfbd-f97c-4650-b879-5e324a727588");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0854cfbd-f97c-4650-b879-5e324a727588");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0854cfbd-f97c-4650-b879-5e324a727588' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"365826a0-b056-4bc0-a94a-f34ca25aebfb":{"roots":{"references":[{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"}},"id":"e9d8db57-92c7-4c7e-9d3e-9a53d8105367","type":"WheelZoomTool"},{"attributes":{},"id":"2a85a959-1cb6-43fa-8ce0-4cecf06518bb","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a85a959-1cb6-43fa-8ce0-4cecf06518bb","type":"BasicTicker"}},"id":"c073f8cd-de03-4df0-9510-1b001b76f1f5","type":"Grid"},{"attributes":{},"id":"8f8ea4b5-2f92-4814-8aec-a56cadd46964","type":"ToolEvents"},{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"}},"id":"7b827459-d3e0-4277-b3e1-1681918c9d6c","type":"HelpTool"},{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"}},"id":"5f07ff00-1ac7-4ed6-bfd5-0d579be83ba1","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"57c2f57f-f644-42be-9e77-4c7d758a00ad","type":"Title"},{"attributes":{},"id":"da1ea605-ba7b-4c7f-a4ad-516c005aed00","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"deaa0441-4926-453b-aaa0-78163c9a4049","type":"PanTool"},{"id":"e9d8db57-92c7-4c7e-9d3e-9a53d8105367","type":"WheelZoomTool"},{"id":"903a0cf5-3b8f-4ca9-bf14-7f515aa4b2fa","type":"BoxZoomTool"},{"id":"ae19efed-926b-44dc-8cc7-805f01fabfea","type":"SaveTool"},{"id":"5f07ff00-1ac7-4ed6-bfd5-0d579be83ba1","type":"ResetTool"},{"id":"7b827459-d3e0-4277-b3e1-1681918c9d6c","type":"HelpTool"}]},"id":"d59b0427-7b2e-4b40-bcb4-4aa73fcd8fd3","type":"Toolbar"},{"attributes":{"formatter":{"id":"053c6d71-f648-4519-9d17-f21dda867e1a","type":"BasicTickFormatter"},"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a85a959-1cb6-43fa-8ce0-4cecf06518bb","type":"BasicTicker"}},"id":"88fe0279-4305-4fcb-90b0-d126a9d6b0ad","type":"LinearAxis"},{"attributes":{"data_source":{"id":"ff4194c6-08a1-4d5c-848e-d0720acecd3c","type":"ColumnDataSource"},"glyph":{"id":"fc834068-435c-41bf-914b-6e5c99edea33","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"33c098da-37f8-43d7-8160-363994188d65","type":"Line"},"selection_glyph":null},"id":"fe9f6b24-cfd2-4645-86d4-fd84c1998e18","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"}},"id":"ae19efed-926b-44dc-8cc7-805f01fabfea","type":"SaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[10,2],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"33c098da-37f8-43d7-8160-363994188d65","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cead523b-b1cd-44f6-91f7-578f6cc1c449","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"},"ticker":{"id":"da1ea605-ba7b-4c7f-a4ad-516c005aed00","type":"BasicTicker"}},"id":"0ab0e518-0ada-4c81-a186-1f45d1f92d0f","type":"Grid"},{"attributes":{},"id":"b67c72d3-6fcb-4fa8-9680-a7e21fae4e0a","type":"BasicTickFormatter"},{"attributes":{},"id":"053c6d71-f648-4519-9d17-f21dda867e1a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"}},"id":"deaa0441-4926-453b-aaa0-78163c9a4049","type":"PanTool"},{"attributes":{"formatter":{"id":"b67c72d3-6fcb-4fa8-9680-a7e21fae4e0a","type":"BasicTickFormatter"},"plot":{"id":"c2d6eb4a-960a-48b6-b4a4-56bb84776896","subtype":"Figure","type":"Plot"},"ticker":{"id":"da1ea6 ...

# %%
# リスト7.4.8：線の種類設定③
p = figure(plot_width=200, plot_height=200, x_range=(-0.5, 1.5))
p.line([0, 1], [3, 3], line_dash=(20, 5), line_width=5)
p.line([0, 1], [2, 2], line_dash=(20, 5), line_dash_offset=(-5), line_width=5)
p.line([0, 1], [1, 1], line_dash=(20, 5), line_dash_offset=(5), line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="284731ec-7897-4b06-9d91-24fe635bdfce"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("284731ec-7897-4b06-9d91-24fe635bdfce");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("284731ec-7897-4b06-9d91-24fe635bdfce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '284731ec-7897-4b06-9d91-24fe635bdfce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d1bcb70-fbfb-4667-825a-b2927a8a55be":{"roots":{"references":[{"attributes":{"overlay":{"id":"bc3ed2fb-372f-4622-b2d9-825ecc8c5b05","type":"BoxAnnotation"},"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"1c179132-997b-4bc2-aa34-14d3a0f3c1b9","type":"BoxZoomTool"},{"attributes":{},"id":"904c45c6-1fd8-4ebb-886b-e18509731b93","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"40bc8797-c4ba-4252-91d2-47ad04d83fa3","type":"Line"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"2d7c1659-2ffe-42d3-af49-0a7dd91c1fe1","type":"SaveTool"},{"attributes":{},"id":"88af8899-8e44-4b5b-b759-e0f8621d8556","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"ddcbd138-1e19-494f-8583-91bc64923fa6","type":"Title"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"8d08433c-716e-4ce6-8fbf-5d2f33acf9ee","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[2,2]}},"id":"c5560e3d-af7c-4316-8b9a-1401d0e5c834","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3db71513-1d11-4d0d-913d-eb624bb1745f","type":"PanTool"},{"id":"8d08433c-716e-4ce6-8fbf-5d2f33acf9ee","type":"WheelZoomTool"},{"id":"1c179132-997b-4bc2-aa34-14d3a0f3c1b9","type":"BoxZoomTool"},{"id":"2d7c1659-2ffe-42d3-af49-0a7dd91c1fe1","type":"SaveTool"},{"id":"a67770f3-a1dd-4f07-960c-a70e2be31caf","type":"ResetTool"},{"id":"863ef3bf-7314-4524-af0b-8c8aa846a25c","type":"HelpTool"}]},"id":"3be14497-efb0-44b6-b72f-1202707b38a2","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bc3ed2fb-372f-4622-b2d9-825ecc8c5b05","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"},"ticker":{"id":"cb9c8941-440e-48b5-997f-91a34afb50b0","type":"BasicTicker"}},"id":"d42f986e-cff4-4749-98b5-e837e4467273","type":"Grid"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"3db71513-1d11-4d0d-913d-eb624bb1745f","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_dash_offset":-5,"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"961ede0b-ada9-4282-9a61-4335fa0ce4be","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[3,3]}},"id":"7acb5869-9af8-4f8c-8dbe-489567937c1c","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"88af8899-8e44-4b5b-b759-e0f8621d8556","type":"BasicTickFormatter"},"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"},"ticker":{"id":"126132a7-e528-4b15-9fe4-d68ddd729ce0","type":"BasicTicker"}},"id":"51f64e25-ab52-4542-89d2-9581fe60c10e","type":"LinearAxis"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"a67770f3-a1dd-4f07-960c-a70e2be31caf","type":"ResetTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"d681b14d-710e-4a48-bf72-8d80102cbe4e","type":"Line"},{"attributes":{"plot":{"id":"b6164118-237a-4caa-b9b9-cd0fc025769c","subtype":"Figure","type":"Plot"}},"id":"863ef3bf-7314-4524-af0b-8c8aa846a25c","type":"HelpTool"},{"attributes":{"below":[{"id":"0eb87503-688d-4a63-add5-40659aadd2cc","type":"LinearAxis"}],"left":[{"i ...
