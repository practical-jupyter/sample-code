# %%
# リスト7.4.1：線の太さの設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([0, 1, 2], [1, 2, 3], line_width=4)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d5c0aecc-ee91-4125-add7-07f2e728fab2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1944ab76-cf97-4a59-a8ab-285d35d9c94c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1944ab76-cf97-4a59-a8ab-285d35d9c94c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1944ab76-cf97-4a59-a8ab-285d35d9c94c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1944ab76-cf97-4a59-a8ab-285d35d9c94c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e59b5893-a09a-430e-bf28-80913e70be73":{"roots":{"references":[{"attributes":{"overlay":{"id":"0c097cea-4936-4ade-b1ed-fef222dc35f3","type":"BoxAnnotation"},"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"}},"id":"4846f92b-83c4-4c52-9c83-b47876e9c245","type":"BoxZoomTool"},{"attributes":{},"id":"1ba96e59-b5de-4535-babd-cc3d299c1e7e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"}},"id":"e4757031-5dcc-4b4c-a348-b5bd7c3894c5","type":"SaveTool"},{"attributes":{"below":[{"id":"98a8e9d2-bce3-4ef7-ae97-1ef6fe53d5aa","type":"LinearAxis"}],"left":[{"id":"064d05e9-4fbe-43a2-b0ed-e4bd5984c49b","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"98a8e9d2-bce3-4ef7-ae97-1ef6fe53d5aa","type":"LinearAxis"},{"id":"0814b035-ef65-44be-b06e-fc7a2c01b642","type":"Grid"},{"id":"064d05e9-4fbe-43a2-b0ed-e4bd5984c49b","type":"LinearAxis"},{"id":"138326be-d97d-427b-9e10-0827791c198f","type":"Grid"},{"id":"0c097cea-4936-4ade-b1ed-fef222dc35f3","type":"BoxAnnotation"},{"id":"ebbb4242-a123-46ce-8238-cd41bff3a1bf","type":"GlyphRenderer"}],"title":{"id":"4a27e485-69ca-49d4-9f97-0e17fb42fe34","type":"Title"},"tool_events":{"id":"4eee3fce-9013-4228-8a93-4ee442255ccf","type":"ToolEvents"},"toolbar":{"id":"2f2c84c2-be08-4828-8c2e-47b52206fa9f","type":"Toolbar"},"x_range":{"id":"ec0eece8-ce99-4f14-b726-96db05be0671","type":"DataRange1d"},"y_range":{"id":"0339554c-8557-4c60-b12f-21e4b96a1481","type":"DataRange1d"}},"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"}},"id":"bd2bedbf-416c-4716-ac1d-01c7f79199df","type":"ResetTool"},{"attributes":{"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"}},"id":"909dee7f-0e83-457b-a8a8-e54fb4f875a3","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7fd29fd4-d4bf-4adf-874e-4776e982e1bd","type":"PanTool"},{"id":"5bcc5e00-541f-4f12-a605-316ea415c0de","type":"WheelZoomTool"},{"id":"4846f92b-83c4-4c52-9c83-b47876e9c245","type":"BoxZoomTool"},{"id":"e4757031-5dcc-4b4c-a348-b5bd7c3894c5","type":"SaveTool"},{"id":"bd2bedbf-416c-4716-ac1d-01c7f79199df","type":"ResetTool"},{"id":"909dee7f-0e83-457b-a8a8-e54fb4f875a3","type":"HelpTool"}]},"id":"2f2c84c2-be08-4828-8c2e-47b52206fa9f","type":"Toolbar"},{"attributes":{"callback":null},"id":"0339554c-8557-4c60-b12f-21e4b96a1481","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"4a27e485-69ca-49d4-9f97-0e17fb42fe34","type":"Title"},{"attributes":{"formatter":{"id":"91a9dfcf-d7a5-4e00-bca4-2a0316a47f42","type":"BasicTickFormatter"},"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"},"ticker":{"id":"f304f697-12d8-4685-9e81-6c3536223d2a","type":"BasicTicker"}},"id":"98a8e9d2-bce3-4ef7-ae97-1ef6fe53d5aa","type":"LinearAxis"},{"attributes":{},"id":"f304f697-12d8-4685-9e81-6c3536223d2a","type":"BasicTicker"},{"attributes":{},"id":"36b91727-a6ef-4e1a-9ffc-63eef6cdf9dc","type":"BasicTicker"},{"attributes":{"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"},"ticker":{"id":"f304f697-12d8-4685-9e81-6c3536223d2a","type":"BasicTicker"}},"id":"0814b035-ef65-44be-b06e-fc7a2c01b642","type":"Grid"},{"attributes":{},"id":"4eee3fce-9013-4228-8a93-4ee442255ccf","type":"ToolEvents"},{"attributes":{"formatter":{"id":"1ba96e59-b5de-4535-babd-cc3d299c1e7e","type":"BasicTickFormatter"},"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"},"ticker":{"id":"36b91727-a6ef-4e1a-9ffc-63eef6cdf9dc","type":"BasicTicker"}},"id":"064d05e9-4fbe-43a2-b0ed-e4bd5984c49b","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"82eb54cd-e710-4531-837c-102e480ede81","subtype":"Figure","type":"Plot"},"ticker":{"id":"3 ...

# %%
# リスト7.4.2：線の色の設定
p = figure(plot_width=200, plot_height=200)
p.line([0, 1, 2], [1, 2, 3], line_color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9e4ec695-1694-43dc-a3da-42fffef1dcd3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9e4ec695-1694-43dc-a3da-42fffef1dcd3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9e4ec695-1694-43dc-a3da-42fffef1dcd3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9e4ec695-1694-43dc-a3da-42fffef1dcd3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1f7a619f-77ea-4f05-80f3-b8f6c7289f04":{"roots":{"references":[{"attributes":{"callback":null},"id":"83c7a660-80f6-4201-93fe-9931d4fd4504","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2],"y":[1,2,3]}},"id":"6be02f73-9877-4ed7-ac35-37bb3aceb98f","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"},"ticker":{"id":"791e36d4-7972-4e22-af4d-6d11b3129003","type":"BasicTicker"}},"id":"27be21aa-d50f-46f8-9404-70c432b40f36","type":"Grid"},{"attributes":{"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"},"ticker":{"id":"209fe3ad-7140-42cc-a054-4ef58d713f0a","type":"BasicTicker"}},"id":"8d10120a-1c40-4ba9-88a1-9c39b9f53bb1","type":"Grid"},{"attributes":{},"id":"209fe3ad-7140-42cc-a054-4ef58d713f0a","type":"BasicTicker"},{"attributes":{},"id":"791e36d4-7972-4e22-af4d-6d11b3129003","type":"BasicTicker"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b2673e0f-dcb0-4fbf-9937-8568e2f77f87","type":"Line"},{"attributes":{"formatter":{"id":"7b01c508-70b3-42c4-9201-62f1d8f20bda","type":"BasicTickFormatter"},"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"},"ticker":{"id":"791e36d4-7972-4e22-af4d-6d11b3129003","type":"BasicTicker"}},"id":"0efd899c-f01a-4209-899c-46e822b9f0a2","type":"LinearAxis"},{"attributes":{},"id":"7b01c508-70b3-42c4-9201-62f1d8f20bda","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"}},"id":"9bacf4f2-1de4-4685-8a36-ef0488806037","type":"HelpTool"},{"attributes":{"callback":null},"id":"833bd3d6-db07-4530-8e2a-4a7a21d0d890","type":"DataRange1d"},{"attributes":{"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"}},"id":"60cafca5-df7d-4878-be8d-dfc3574a3a0c","type":"SaveTool"},{"attributes":{"formatter":{"id":"22e99787-3822-4349-a0e5-2693496c46a3","type":"BasicTickFormatter"},"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"},"ticker":{"id":"209fe3ad-7140-42cc-a054-4ef58d713f0a","type":"BasicTicker"}},"id":"6631243b-7866-4e23-8107-bdee3ff2c41d","type":"LinearAxis"},{"attributes":{"overlay":{"id":"f1e4da20-e803-4c0b-8a09-c0da4ac5c6a4","type":"BoxAnnotation"},"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"}},"id":"87b8db14-318c-4c5f-92ff-c4d7837bbb92","type":"BoxZoomTool"},{"attributes":{},"id":"c082c0c5-bbd2-4829-8924-d1d68da3f0a3","type":"ToolEvents"},{"attributes":{"plot":{"id":"9d86e35c-e81c-46b4-a8d7-529e8d0bbad1","subtype":"Figure","type":"Plot"}},"id":"17495e59-70c4-4151-9eee-5957a506a9e8","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bd70a080-25db-4cdf-a050-bf779310acd6","type":"PanTool"},{"id":"fd2cb155-0be3-47ad-aa9d-4057caddaa3d","type":"WheelZoomTool"},{"id":"87b8db14-318c-4c5f-92ff-c4d7837bbb92","type":"BoxZoomTool"},{"id":"60cafca5-df7d-4878-be8d-dfc3574a3a0c","type":"SaveTool"},{"id":"17495e59-70c4-4151-9eee-5957a506a9e8","type":"ResetTool"},{"id":"9bacf4f2-1de4-4685-8a36-ef0488806037","type":"HelpTool"}]},"id":"5481675b-2c8a-400b-9c29-902028d8e45f","type":"Toolbar"},{"attributes":{"below":[{"id":"6631243b-7866-4e23-8107-bdee3ff2c41d","type":"LinearAxis"}],"left":[{"id":"0efd899c-f01a-4209-899c-46e822b9f0a2","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6631243b-7866-4e23-8107-bdee3ff2c41d","type":"LinearAxis"},{"id":"8d10120a-1c40-4ba9-88a1-9c39b9f53bb1","type":"Grid"},{"id":"0efd899c-f01a-4209-899c-46e822b9f0a2","type":"LinearAxis"},{"id":"27be21aa-d50f-46f8-9404-70c432b40f36","type":"Grid"},{"id":"f1e4da20-e803-4c0b-8a09-c0da4ac5c6a4","type":"BoxAnnotation"},{"id":"6d7ab8e2-f982-4d13-9f21-0db93ff885d0","type":"GlyphRenderer"}],"tit ...

# %%
# リスト7.4.3：線の不透明度設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 3.5))
p.line([0, 1], [3, 3], line_color='green', line_width=30)
p.line([0, 1], [2, 2], line_alpha=0.6, line_color='green', line_width=30)
p.line([0, 1], [1, 1], line_color=(0, 255, 0, 0.4), line_width=30)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7f5a82d-336b-4923-81b2-ec87023d515f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f7f5a82d-336b-4923-81b2-ec87023d515f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7f5a82d-336b-4923-81b2-ec87023d515f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7f5a82d-336b-4923-81b2-ec87023d515f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cbe0d7df-0076-413c-a052-3c44d55f2c85":{"roots":{"references":[{"attributes":{"callback":null},"id":"dc12ed34-1a04-46d3-b170-c7d1a2e38124","type":"DataRange1d"},{"attributes":{},"id":"28531131-f011-4a35-80cd-2eab4d81430b","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[3,3]}},"id":"84062821-ae1b-4b17-9bc8-837e63f6f800","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"6243022d-24a0-4b31-a22b-92d30ab64508","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e9cb38a-1e7c-4eef-b183-0bb6442f9bc1","type":"Line"},{"attributes":{},"id":"e64fc5a8-bbe4-443c-9ee7-810fb8a2d401","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"42b05376-937b-4997-bdd0-a3b94531d8db","type":"LinearAxis"}],"left":[{"id":"7061122b-7af1-46ef-b249-29bd941efce7","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"42b05376-937b-4997-bdd0-a3b94531d8db","type":"LinearAxis"},{"id":"82cbe0b2-3885-4243-8e13-1dd53488a220","type":"Grid"},{"id":"7061122b-7af1-46ef-b249-29bd941efce7","type":"LinearAxis"},{"id":"9972f6b5-f1db-4d7f-9604-08e0b7622d33","type":"Grid"},{"id":"0d50670f-a1cb-44bc-a4eb-e0e92a40f9d6","type":"BoxAnnotation"},{"id":"f0ed3f85-ccc3-4db9-a83b-eafb8e050381","type":"GlyphRenderer"},{"id":"8ae9a4c8-d5e0-4c95-bb31-a30b569ce7f5","type":"GlyphRenderer"},{"id":"331427b5-540d-4f30-80d1-577317704438","type":"GlyphRenderer"}],"title":{"id":"6243022d-24a0-4b31-a22b-92d30ab64508","type":"Title"},"tool_events":{"id":"28531131-f011-4a35-80cd-2eab4d81430b","type":"ToolEvents"},"toolbar":{"id":"0304494f-ced7-44b5-a1eb-85948e4b1399","type":"Toolbar"},"x_range":{"id":"dc12ed34-1a04-46d3-b170-c7d1a2e38124","type":"DataRange1d"},"y_range":{"id":"21a1dfb4-da6b-4df3-96ec-a94fd7aedc8d","type":"Range1d"}},"id":"d0547989-dc6c-4329-adaf-1dcf3078b7b6","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f3bf2893-5499-4e9e-b4da-5959f5f31db3","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"rgba(0, 255, 0, 0.4)"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"734de0e5-b1cd-4705-9b05-2500549fda30","type":"Line"},{"attributes":{"data_source":{"id":"1d23df97-be17-45ef-b6dd-ee2329880b82","type":"ColumnDataSource"},"glyph":{"id":"a8061b3f-a79c-4066-94bb-a076048e060e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ab64dadc-b27c-488b-9bc2-fe0cffb42ec9","type":"Line"},"selection_glyph":null},"id":"8ae9a4c8-d5e0-4c95-bb31-a30b569ce7f5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[2,2]}},"id":"1d23df97-be17-45ef-b6dd-ee2329880b82","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8b4e4f9-2e9c-4eb0-bc6f-741cdad55feb","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab64dadc-b27c-488b-9bc2-fe0cffb42ec9","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7d2b717f-b13f-4c04-bc1a-d69ffd8bd6fb","type":"PanTool"},{"id":"ff0b5d37-7e64-4749-8fc7-f8ea41c7301a","type":"WheelZoomTool"},{"id":"98fb13e3-2570-4e73-a080-bd07cbd6adc3","type":"BoxZoomTool"},{"id":"f8856fc6-3bc6-4bc5-bfdc-bf7f3b36db4e","type":"SaveTool"},{"id":"085e2a0b-7b54-4b2c-9e0f-ff9b4af3f33b","type":"ResetTool"},{"id":"564bd493-4c93-48c3-b753-76143a5d3d42","type":"HelpTool"}]},"id":"0304494f-ced7-44b5-a1eb-85948e4b1399","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"84295b41-942e-4206-b42a-6c78c9d2f978","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"e64fc5a8-bbe4-443c-9ee7-810fb8a2d401","type":"BasicTi ...

# %%
# リスト7.4.4：線の結合点の設定
p = figure(plot_width=200, plot_height=200, x_range=(0, 2))
for y, line in enumerate(['bevel', 'round', 'miter']):
    p.line([0, 1, 0], [y, y + 0.5, y + 1], line_width=10, line_join=line)
    p.text(1.5, y + 0.5, text=[line], text_align='center')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bb1f299f-76b5-447d-9772-18270d5c2587"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bb1f299f-76b5-447d-9772-18270d5c2587");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bb1f299f-76b5-447d-9772-18270d5c2587");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bb1f299f-76b5-447d-9772-18270d5c2587' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f896268c-1504-4d13-a2ee-a2ea85cb1640":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["miter"]}},"id":"a5d6030a-1c86-49ab-a209-8ea3cc63e8f9","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"54a7f089-a27d-465b-9e56-3e9f6b302659","type":"PanTool"},{"id":"039227ab-2321-4981-a6db-86b1e3a4865d","type":"WheelZoomTool"},{"id":"d75bc74d-c8e4-4fc2-91dd-d2622f77031f","type":"BoxZoomTool"},{"id":"cf584ca8-847d-4aab-9360-91c2634de0ff","type":"SaveTool"},{"id":"fda0596c-2084-42e1-a713-4df914064458","type":"ResetTool"},{"id":"4a40e020-d7aa-4c52-b31c-7656f0ce0d38","type":"HelpTool"}]},"id":"712894a3-fcbc-40e3-9a3c-a0af6d5f9b70","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["bevel"]}},"id":"2b9c0913-5426-4b4c-a289-4b0640889b8a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b0c66ca7-962d-401a-a71e-6552d2ab0c7e","subtype":"Figure","type":"Plot"}},"id":"54a7f089-a27d-465b-9e56-3e9f6b302659","type":"PanTool"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":0.5}},"id":"3c83ff8e-9e35-414e-bb04-55bda507eefb","type":"Text"},{"attributes":{"callback":null},"id":"6508d84c-4ab7-478a-9af5-a134a4bcf5d9","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["round"]}},"id":"009ca75c-a531-48ce-921f-a3a7660b3fa4","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_join":"bevel","line_width":{"value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fb2c9ae-39df-44b3-8638-10e12e4cb5ee","type":"Line"},{"attributes":{"data_source":{"id":"009ca75c-a531-48ce-921f-a3a7660b3fa4","type":"ColumnDataSource"},"glyph":{"id":"473ed0f6-4a47-458d-809d-8eb25853d59f","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"586fd0c9-528d-4692-ae29-816a0e03f440","type":"Text"},"selection_glyph":null},"id":"acbb76a4-eaa6-4fbd-a911-85cbda080343","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":2.5}},"id":"c9efee66-41a5-48a6-ac11-dfdcb5c16c31","type":"Text"},{"attributes":{"data_source":{"id":"2b9c0913-5426-4b4c-a289-4b0640889b8a","type":"ColumnDataSource"},"glyph":{"id":"3c83ff8e-9e35-414e-bb04-55bda507eefb","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0f583e57-9c33-4a3d-a97b-e9688883e3b0","type":"Text"},"selection_glyph":null},"id":"45bf401f-43db-4c75-877d-220bfcd24960","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":0.5}},"id":"0f583e57-9c33-4a3d-a97b-e9688883e3b0","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.5},"y":{"value":1.5}},"id":"586fd0c9-528d-4692-ae29-816a0e03f440","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,0],"y":[1,1.5,2]}},"id":"80db0b5f-c0e9-4893-b822-bc8e05445f64","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"02479adf-924b-4b85-bae6-924071a13c43","type":"ColumnDataSource"},"glyph":{"id":"5870f226-5c39-40cb-aa9e-ac972cfbe703","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9a8f44b4-8b8d-441a-8365-fb60384b469f","type":"Line"},"selection_glyph":null},"id":"258163a6-8a68-4c37-9496-989af390dcda","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b0c66ca7-962d-401a-a71e-6552d2ab0c7e","subtype":"Figure","type":"Plot"}},"id":"039227ab-2321-4981-a6db-86b1e3a4865d","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a8f44b4-8b8d-441a-8365-fb60384b469f","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4" ...

# %%
# リスト7.4.5：線の先端の設定
p = figure(plot_width=200, plot_height=200,
           x_range=[-0.5, 2.5], y_range=[-0.5, 2.5])
for y, line in enumerate(['square', 'round', 'butt']):
    p.line([0, 1], [y, y], line_width=20, line_cap=line)
    p.text(2, y, text=[line], text_align='center')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eb789091-7df6-4bfc-ad3f-c26b6f506c82"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eb789091-7df6-4bfc-ad3f-c26b6f506c82");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eb789091-7df6-4bfc-ad3f-c26b6f506c82");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eb789091-7df6-4bfc-ad3f-c26b6f506c82' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32b0d8d3-aafe-4dfb-85b5-a8d5976ccedd":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[0,0]}},"id":"8100ba2d-e147-4d13-a8b2-be8aa53d4641","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":2},"y":{"value":1}},"id":"987cccd7-6c4a-45c0-9967-a84430b45b3c","type":"Text"},{"attributes":{"data_source":{"id":"e16c2e87-f99d-4014-91eb-91eded0413b1","type":"ColumnDataSource"},"glyph":{"id":"2274fb03-d084-46f8-a3e6-c995f0ef1ff8","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"92625084-2fbc-485f-8860-8bacc544f596","type":"Text"},"selection_glyph":null},"id":"9e155a2e-abe7-44d7-be91-026b2148d169","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5a70d7f7-e30f-4452-ac6b-ee62ce74a8b5","subtype":"Figure","type":"Plot"},"ticker":{"id":"0e89c259-cd26-4241-8435-9608fc3cc6e9","type":"BasicTicker"}},"id":"3c99722a-4719-4b15-b50e-8cd216e5c44d","type":"Grid"},{"attributes":{"formatter":{"id":"1d5874a1-e618-4e72-9ba8-79d9f25195fc","type":"BasicTickFormatter"},"plot":{"id":"5a70d7f7-e30f-4452-ac6b-ee62ce74a8b5","subtype":"Figure","type":"Plot"},"ticker":{"id":"f02b91d7-b9e7-4586-b068-d04146239799","type":"BasicTicker"}},"id":"833a3a37-79a9-4825-a40a-9b89bf15c551","type":"LinearAxis"},{"attributes":{"callback":null,"end":2.5,"start":-0.5},"id":"942f5cdc-c85f-4553-84a0-2fbed5168a6f","type":"Range1d"},{"attributes":{"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"006cc9c3-76dc-4494-b765-9fb47b83685f","type":"Line"},{"attributes":{"plot":{"id":"5a70d7f7-e30f-4452-ac6b-ee62ce74a8b5","subtype":"Figure","type":"Plot"}},"id":"a43697a9-6a09-4d4e-8eaa-8aac18e75bee","type":"PanTool"},{"attributes":{"data_source":{"id":"aa34d600-9b6f-4925-a99e-f9b10329841a","type":"ColumnDataSource"},"glyph":{"id":"987cccd7-6c4a-45c0-9967-a84430b45b3c","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b4294aba-773b-4865-b2b4-fee1f6e42904","type":"Text"},"selection_glyph":null},"id":"d6859bd3-8bdf-4f98-b2ac-fb92f0c3b3dc","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5a70d7f7-e30f-4452-ac6b-ee62ce74a8b5","subtype":"Figure","type":"Plot"}},"id":"409f0132-91a5-47fa-a361-d14aa569cea9","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"12f3fc5c-3fea-4daa-ae61-2c62daf98cba","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["butt"]}},"id":"e16c2e87-f99d-4014-91eb-91eded0413b1","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"square","line_color":{"value":"#1f77b4"},"line_width":{"value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e58c029-3b98-4835-be70-2734d8739e2d","type":"Line"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":2},"y":{"value":0}},"id":"ac089aea-84b6-4c7e-8fe9-21a88112e0ff","type":"Text"},{"attributes":{"data_source":{"id":"1cd11d3b-34e1-459d-a8b9-5e1da532739d","type":"ColumnDataSource"},"glyph":{"id":"006cc9c3-76dc-4494-b765-9fb47b83685f","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f1b37f36-df96-481b-a20f-8aa7081013e6","type":"Line"},"selection_glyph":null},"id":"8633bab4-d4f7-4392-a49b-9f162f4b3c4c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5a70d7f7-e30f-4452-ac6b-ee62ce74a8b5","subtype":"Figure","type":"Plot"}},"id":"30e94fdf-a45b-442a-afac-311f68c5bbae","type":"HelpTool"},{"attributes":{},"id":"1d5874a1-e618-4e72-9ba8-79d9f25195fc","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color": ...

# %%
# リスト7.4.6：線の種類設定①
p = figure(plot_width=200, plot_height=200, y_range=(-0.5, 5))
line_styles = ['solid', 'dashed', 'dotted', 'dotdash', 'dashdot']
for y, line_style in enumerate(line_styles):
    p.line([0, 1], [y, y], line_dash=line_style)
    p.text(0, y, text=[line_style])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="baf37fb3-fcdd-4e96-bf0c-f746e32cfe33"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("baf37fb3-fcdd-4e96-bf0c-f746e32cfe33");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("baf37fb3-fcdd-4e96-bf0c-f746e32cfe33");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'baf37fb3-fcdd-4e96-bf0c-f746e32cfe33' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"616a5459-2155-40ee-9938-c88c461b4389":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"159b8a20-4c10-4474-93a0-f22f4a5ebb40","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[2,4,6,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"91188571-9642-4299-9e47-5f46275e4c22","type":"Line"},{"attributes":{"formatter":{"id":"01d21620-66e0-4c01-bcdc-af0516a6bcba","type":"BasicTickFormatter"},"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"},"ticker":{"id":"2231c3e7-39be-4d67-9a65-1616b1b37dea","type":"BasicTicker"}},"id":"d9e8ef0f-1e31-4078-b9fd-e86908f210f2","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"55a70d8a-04d6-4488-9d7f-bb89ac61c492","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":5,"start":-0.5},"id":"41df33e9-15cb-4867-8e3a-de13806214cf","type":"Range1d"},{"attributes":{"overlay":{"id":"55a70d8a-04d6-4488-9d7f-bb89ac61c492","type":"BoxAnnotation"},"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"}},"id":"b3473be4-c8d5-4932-9b8d-4b0e1310b6ec","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[6,4,2,4],"x":{"field":"x"},"y":{"field":"y"}},"id":"4251d9f7-be09-40db-8541-3481294180ba","type":"Line"},{"attributes":{"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"},"ticker":{"id":"2231c3e7-39be-4d67-9a65-1616b1b37dea","type":"BasicTicker"}},"id":"d88eac02-3f8f-4ceb-a92f-1224a3a00dca","type":"Grid"},{"attributes":{"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"}},"id":"8e53aa52-8d6b-48a5-bcc1-a7e3a201fd9a","type":"PanTool"},{"attributes":{"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"0452cf4c-a044-4768-a258-6132276bf427","type":"Text"},{"attributes":{"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"}},"id":"16a07113-e842-467c-a28b-ad0e554c8a61","type":"ResetTool"},{"attributes":{"data_source":{"id":"b8c7f253-e676-47d6-aee5-96630cfe6367","type":"ColumnDataSource"},"glyph":{"id":"91188571-9642-4299-9e47-5f46275e4c22","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a664162d-620e-4537-b9c6-37b06842909a","type":"Line"},"selection_glyph":null},"id":"5f83e7c3-dd79-4b8c-afd7-289badc135d8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"}},"id":"3a0b178e-fe0d-459f-8ba1-71c976fea7a5","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"e255e476-bb41-4a4d-b3a4-3f25df524322","type":"Title"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":3}},"id":"ab57bf4c-55b1-4b38-93b5-0bc1710ae518","type":"Text"},{"attributes":{"plot":{"id":"6eb4620d-0b67-4e22-bfd7-fbfb921dec27","subtype":"Figure","type":"Plot"}},"id":"2b309914-1549-402f-a1e7-70e05159c3cc","type":"SaveTool"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":4}},"id":"745e8e31-56fd-46d5-8b9e-e69aeec6aa94","type":"Text"},{"attributes":{},"id":"2231c3e7-39be-4d67-9a65-1616b1b37dea","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6c15fd20-0b5d-4aea-98fb-cdb386354fea","type":"ColumnDataSource"},"glyph":{"id":"5c0dfefb-d675-40e2-b190-312451211e6a","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ab57bf4c-55b1-4b38-93b5-0bc1710ae518","type":"Text"},"selection_glyph":null},"id":"d0a944de-e561-4025-9402-45bfd83c1a5d","type":"GlyphRenderer"},{"attributes":{" ...

# %%
# リスト7.4.7：線の種類設定②
p = figure(plot_width=200, plot_height=200)
p.line([0, 1], [1, 1], line_dash=(10, 2), line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d55f494c-7b1b-4e16-a6f8-0fc3ed0690a1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d55f494c-7b1b-4e16-a6f8-0fc3ed0690a1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d55f494c-7b1b-4e16-a6f8-0fc3ed0690a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd55f494c-7b1b-4e16-a6f8-0fc3ed0690a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"270a318f-7716-4a64-8ca7-6d98333ba0ce":{"roots":{"references":[{"attributes":{},"id":"1ce0398a-4ae1-4dd2-b7f3-ed649b1f7a1f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b82e965a-4a0a-4e7f-93de-c151a4677ce7","subtype":"Figure","type":"Plot"}},"id":"2de83fd9-8a7c-4e92-8d7f-76e822d0ae73","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[10,2],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"57a88683-8aba-407e-ae66-a924886e916a","type":"Line"},{"attributes":{"formatter":{"id":"82ab795c-ae63-4a6c-8282-d0bce25caeb9","type":"BasicTickFormatter"},"plot":{"id":"b82e965a-4a0a-4e7f-93de-c151a4677ce7","subtype":"Figure","type":"Plot"},"ticker":{"id":"d604c2ea-9ab1-466e-b793-2ffa3f2134a3","type":"BasicTicker"}},"id":"dae54279-1d8b-4dfc-abf5-521a2217aa91","type":"LinearAxis"},{"attributes":{"data_source":{"id":"6165c740-d9e9-459f-a7fa-680b42a26e96","type":"ColumnDataSource"},"glyph":{"id":"66c24392-7aec-4ba6-8879-735ed5533017","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"57a88683-8aba-407e-ae66-a924886e916a","type":"Line"},"selection_glyph":null},"id":"12add8a1-0d50-4fa6-8284-111d33d6ee4b","type":"GlyphRenderer"},{"attributes":{},"id":"c6568533-d9fe-4fae-9e49-1953b8bdae95","type":"BasicTicker"},{"attributes":{"plot":{"id":"b82e965a-4a0a-4e7f-93de-c151a4677ce7","subtype":"Figure","type":"Plot"}},"id":"091cd401-44b3-4d11-a779-de0db29ab39a","type":"HelpTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[10,2],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"66c24392-7aec-4ba6-8879-735ed5533017","type":"Line"},{"attributes":{"callback":null},"id":"2c9b8611-c746-43b8-986b-a6f5a0d4e5db","type":"DataRange1d"},{"attributes":{},"id":"6c403ba1-3096-4415-b364-5611aa92b1e3","type":"ToolEvents"},{"attributes":{"callback":null},"id":"cbf6f6f9-51e2-460d-b320-88a87416e246","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"53316f54-3833-4e55-b0e4-03e3cb546901","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2de83fd9-8a7c-4e92-8d7f-76e822d0ae73","type":"PanTool"},{"id":"95e12b11-ccac-42c9-b4e7-a4891ed8bf06","type":"WheelZoomTool"},{"id":"b48fba81-79ba-4c00-a6ef-66b38d2ab957","type":"BoxZoomTool"},{"id":"ef28b7a0-5760-490d-a2f7-179932c2382c","type":"SaveTool"},{"id":"ad6637e3-11b1-446f-b0eb-45dfe17a3cda","type":"ResetTool"},{"id":"091cd401-44b3-4d11-a779-de0db29ab39a","type":"HelpTool"}]},"id":"4c70151d-83e6-4762-80d3-b2644a8e3962","type":"Toolbar"},{"attributes":{"plot":{"id":"b82e965a-4a0a-4e7f-93de-c151a4677ce7","subtype":"Figure","type":"Plot"}},"id":"ef28b7a0-5760-490d-a2f7-179932c2382c","type":"SaveTool"},{"attributes":{"plot":{"id":"b82e965a-4a0a-4e7f-93de-c151a4677ce7","subtype":"Figure","type":"Plot"}},"id":"ad6637e3-11b1-446f-b0eb-45dfe17a3cda","type":"ResetTool"},{"attributes":{},"id":"d604c2ea-9ab1-466e-b793-2ffa3f2134a3","type":"BasicTicker"},{"attributes":{"below":[{"id":"dae54279-1d8b-4dfc-abf5-521a2217aa91","type":"LinearAxis"}],"left":[{"id":"bc044db2-ef31-4473-a8ed-4826ca63428e","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"dae54279-1d8b-4dfc-abf5-521a2217aa91","type":"LinearAxis"},{"id":"b7b8da66-8b3a-4062-aa83-d075576c5e68","type":"Grid"},{"id":"bc044db2-ef31-4473-a8ed-4826ca63428e","type":"LinearAxis"},{"id":"712b76bc-1028-460f-9f59-2fb86493ccbf","type":"Grid"},{"id":"53316f54-3833-4e55-b0e4-03e3cb546901","type":"BoxAnnotation"},{"id":"12add8a1-0d50-4fa6-8284-111d33d6ee4b","type":"GlyphRenderer"}],"title":{"id":"027ddbbf-732e-42d5-930e-5342bf6181ff","type":"Title ...

# %%
# リスト7.4.8：線の種類設定③
p = figure(plot_width=200, plot_height=200, x_range=(-0.5, 1.5))
p.line([0, 1], [3, 3], line_dash=(20, 5), line_width=5)
p.line([0, 1], [2, 2], line_dash=(20, 5), line_dash_offset=(-5), line_width=5)
p.line([0, 1], [1, 1], line_dash=(20, 5), line_dash_offset=(5), line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="135e50e9-7a1c-416d-8ef5-36098cc772c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("135e50e9-7a1c-416d-8ef5-36098cc772c1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("135e50e9-7a1c-416d-8ef5-36098cc772c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '135e50e9-7a1c-416d-8ef5-36098cc772c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"895ef1c2-6521-4e89-b2a8-3ceaf9031c6d":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"},"ticker":{"id":"91c673b8-5608-4595-9588-a2e503638b48","type":"BasicTicker"}},"id":"1f40f16b-18e6-4816-91a5-4379f3bf94ae","type":"Grid"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"69bb00a7-223d-45c4-a4ff-7028875e2b73","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c4edf7d5-6069-4e57-8808-199bbc8c900d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"4d58feb1-ea98-49bf-a37c-c7876e135589","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"cc5bbda1-4aef-4e12-8979-33479cdc787d","type":"SaveTool"},{"attributes":{"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"e75e60f8-c435-45c3-aacb-5159a39af9bf","type":"PanTool"},{"attributes":{"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"46c63724-dfff-45f3-9e21-0cc1577b9ecf","type":"ResetTool"},{"attributes":{"data_source":{"id":"c41f6afe-c01c-4dd4-aef5-db02adda43b3","type":"ColumnDataSource"},"glyph":{"id":"5def3d20-dfdc-4c23-8bf5-b85c715b49f5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0c4139c9-a141-46fa-9487-5e5ee1ab516c","type":"Line"},"selection_glyph":null},"id":"8f67c8ef-ecaa-4fc9-bf6c-c509a51992ff","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"edb1df36-2f9c-4cd2-a2d5-8a7c1a062a2a","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"c4edf7d5-6069-4e57-8808-199bbc8c900d","type":"BoxAnnotation"},"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"f0ce719e-50d2-4652-b89f-e4c5e68c2e35","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[3,3]}},"id":"3bd8a392-2248-4c73-a0a8-ce786a8912ed","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"206ce203-87fa-4d8b-a08a-12706b592347","subtype":"Figure","type":"Plot"}},"id":"b237e435-0a69-4d6c-a693-0fe1b5220d4b","type":"HelpTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2239165-55a9-4c74-b5b8-37ec63a42f8b","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_dash_offset":-5,"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c4139c9-a141-46fa-9487-5e5ee1ab516c","type":"Line"},{"attributes":{"callback":null},"id":"b1f73b86-4e69-4a59-acef-f9e572645fab","type":"DataRange1d"},{"attributes":{},"id":"4b3f71f5-7abf-4b98-9a14-8ce58f658dd8","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_dash":[20,5],"line_dash_offset":-5,"line_width":{"value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5def3d20-dfdc-4c23-8bf5-b85c715b49f5","type":"Line"},{"attributes":{"callback":null,"end":1.5,"start":-0.5},"id":"19a94424-231e-4789-a301-3068cf2b588a","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e75e60f8-c435-45c3-aacb-5159a39af9bf","type":"PanTool"},{"id":"4d58feb1-ea98-49bf-a37c-c7876e135589","type":"WheelZoomTool"},{"id":"f0ce719e-50d2-4652-b89f-e4c5e68c2e35","type":"BoxZoomTool"},{"id":"cc5bbda1-4aef-4e12-8979-33479cdc787d","type":"Save ...
