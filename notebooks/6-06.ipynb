# %%
# ●リスト6.6.1：リスト-ライク・オブジェクトのデータを渡したグラフ
from bokeh.charts import output_notebook, Bar, show
output_notebook()
p = Bar([1, 2, 3], plot_width=300, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a3b8cddf-9666-4a66-9c2e-5fb568853f16">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8dbfa9a5-654a-4218-bcc2-4efa596fde3d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8dbfa9a5-654a-4218-bcc2-4efa596fde3d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8dbfa9a5-654a-4218-bcc2-4efa596fde3d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8dbfa9a5-654a-4218-bcc2-4efa596fde3d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bbe7a37e-0d61-462b-9d90-4ccc70e34956":{"roots":{"references":[{"attributes":{"callback":null,"factors":["0","1","2"]},"id":"01951c57-3471-457c-bd49-57a9700aadf8","type":"FactorRange"},{"attributes":{"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"}},"id":"87cba536-18b5-40f8-a520-9fa6147cd818","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"8c9fed97-d8bb-432b-afd4-b0dcbd158fd4","type":"BoxAnnotation"},"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"}},"id":"9781e893-f399-4cc5-96f3-5b914a036b7e","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"}},"id":"3f7286cc-c3fd-4303-801c-995a6ae6f283","type":"SaveTool"},{"attributes":{"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"}},"id":"fe76b0e9-4629-40d2-bc14-eedecdbb3d12","type":"ResetTool"},{"attributes":{"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"}},"id":"70b84812-3c26-4b2c-9c83-f8b02fc22081","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8c9fed97-d8bb-432b-afd4-b0dcbd158fd4","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c3ad955e-ab1d-4b7e-a84f-e2d647ddb280","type":"ColumnDataSource"},"glyph":{"id":"c9aeef90-aa39-45f1-9191-ecc37364bf83","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"3b79007c-8de6-47f2-aff3-dddd42b90d54","type":"GlyphRenderer"},{"attributes":{},"id":"21e7f7f7-00a7-422d-a5fe-8a78b62556fe","type":"CategoricalTicker"},{"attributes":{"callback":null,"end":3.15},"id":"8bf2c483-d54e-4b22-87ee-9bdbf7e3f7be","type":"Range1d"},{"attributes":{"data_source":{"id":"8fa3af9b-ea80-4ded-9311-9c219b9b5f49","type":"ColumnDataSource"},"glyph":{"id":"7136fd17-de9f-49cc-99be-609b9e1691be","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1645d6bc-5dde-42a2-b0f1-ce4023b76c85","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":0}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"index":[0],"label":[{"index":0}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["0"],"y":[0.5]}},"id":"c3ad955e-ab1d-4b7e-a84f-e2d647ddb280","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"473b7948-9140-4ede-ad8b-804805284328","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"69248aa3-63c5-48b1-8bad-78831765a78d","subtype":"Chart","type":"Plot"},"ticker":{"id":"21e7f7f7-00a7-422d-a5fe-8a78b62556fe","type":"CategoricalTicker"}},"id":"46acefeb-64d6-40cf-9d1f-bd7ef7bc9f77","type":"CategoricalAxis"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"3b79007c-8de6-47f2-aff3-dddd42b90d54","type":"GlyphRenderer"}]},"id":"6be4c154-5f90-4df2-9c1d-9e2b005afe70","type":"LegendItem"},{"attributes":{"label":{"value":"2"},"renderers":[{"id":"95397cdd-ed7a-414f-9890-25fab8be1bc4","type":"GlyphRenderer"}]},"id":"35bd1f13-8238-4ea9-b07c-9645e98ce37d","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":1}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"index":[1],"label":[{"index":1}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1"],"y":[1.0]}},"id":"8fa3af9b-ea80-4ded-9311-9c219b9b5f49","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":2}],"color":["#f22c40 ...

# %%
# ●リスト6.6.2：辞書型のデータを渡したグラフ
data = {'data': [1, 2, 3], 'x_label': ['a', 'b', 'c']}
p = Bar(data, values='data', label='x_label', plot_width=300, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fade38c0-d67b-4d88-a773-86888ae81244"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fade38c0-d67b-4d88-a773-86888ae81244");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fade38c0-d67b-4d88-a773-86888ae81244");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fade38c0-d67b-4d88-a773-86888ae81244' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d91ff33d-d911-403a-a5a8-72c23498476c":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"x_label":"c"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":[{"x_label":"c"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["c"],"x_label":["c"],"y":[1.5]}},"id":"a83f87c8-f63e-4fdb-80c3-568ec908b488","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"36e0155f-b391-48eb-80bc-3fb4c9f28219","type":"PanTool"},{"id":"e7c79771-14ef-430a-9d79-a1d782ee409e","type":"WheelZoomTool"},{"id":"a57e8dd2-5915-4726-b0d2-eff66715be3b","type":"BoxZoomTool"},{"id":"5c627528-d92b-44c1-8e73-ea4615bd555c","type":"SaveTool"},{"id":"a4b626fa-5ed1-4278-a970-4ac79100327a","type":"ResetTool"},{"id":"73ecb11a-16d7-4d03-8ae4-acec55bd6875","type":"HelpTool"}]},"id":"4f5338cc-891e-4449-b32f-6b48e43b1764","type":"Toolbar"},{"attributes":{"plot":null,"text":null},"id":"4b9863e2-846f-404e-bb00-f8c0b2ff5187","type":"Title"},{"attributes":{"callback":null,"end":3.15},"id":"388bc8b9-d04a-46f2-8228-2c9011ca7c29","type":"Range1d"},{"attributes":{"axis_label":"X_Label","formatter":{"id":"ba57dc09-fc2e-4fa7-8a2d-e24a391d9ace","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"},"ticker":{"id":"36e5a465-58ff-4d56-b299-7e041fc95035","type":"CategoricalTicker"}},"id":"196d723b-5ac3-4bed-9277-193274cbc686","type":"CategoricalAxis"},{"attributes":{"items":[{"id":"50f19825-fb56-4165-979b-1806bfcf4706","type":"LegendItem"},{"id":"fc3a1168-84f9-4ce5-9b85-f5525309ebd3","type":"LegendItem"},{"id":"57d3b218-89fc-4bc0-ad33-d76e8a435bf2","type":"LegendItem"}],"location":"top_left","plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"}},"id":"a39c654b-3667-4497-9c59-9101fdaada89","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44b497d4-8b64-45bf-b9ba-43897e28374a","type":"Rect"},{"attributes":{"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"}},"id":"e7c79771-14ef-430a-9d79-a1d782ee409e","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"}},"id":"73ecb11a-16d7-4d03-8ae4-acec55bd6875","type":"HelpTool"},{"attributes":{"data_source":{"id":"cf6fa038-df06-4b9b-9d6e-c6d6a1ec1e22","type":"ColumnDataSource"},"glyph":{"id":"44b497d4-8b64-45bf-b9ba-43897e28374a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"19c841f1-981a-4080-8eb6-e4985a78c27d","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"},"ticker":{"id":"c8f791a3-4198-40ff-9f6f-c76aaac34a5d","type":"BasicTicker"}},"id":"39cbd239-035e-4f1e-bfab-ec1f7dd15c30","type":"Grid"},{"attributes":{"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"}},"id":"a4b626fa-5ed1-4278-a970-4ac79100327a","type":"ResetTool"},{"attributes":{},"id":"c8f791a3-4198-40ff-9f6f-c76aaac34a5d","type":"BasicTicker"},{"attributes":{},"id":"ba57dc09-fc2e-4fa7-8a2d-e24a391d9ace","type":"CategoricalTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebc8f81c-6520-4f35-bd07-27beb04f201a","type":"Rect"},{"attributes":{"plot":{"id":"989ae267-c06e-4de7-9b5d-a79d09ea17dd","subtype":"Chart","type":"Plot"}},"id":"5c627528-d92b-44c1-8e73-ea4615bd555 ...

# %%
# ●リスト6.6.3：DataFrameを渡したグラフ
import os
import pandas as pd
base_url = 'https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
anime_master_csv = os.path.join(base_url, 'anime_master.csv')
df = pd.read_csv(anime_master_csv)
sum_df = df.groupby('type').sum()
p = Bar(
    sum_df, values='members', ylabel='メンバ数の合計',
    plot_width=400, plot_height=400,
    legend=False)  # 凡例を非表示
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ba69e7d2-53cc-41fa-981f-c8da62ed6595"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ba69e7d2-53cc-41fa-981f-c8da62ed6595");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ba69e7d2-53cc-41fa-981f-c8da62ed6595");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ba69e7d2-53cc-41fa-981f-c8da62ed6595' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"98e16a8b-baf3-4ef8-8531-e690ac70497f":{"roots":{"references":[{"attributes":{"below":[{"id":"ab0da8aa-2f36-4e31-9b78-f1911885d6d5","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"8b6d3ea9-7487-45b7-8375-a6e20e5aac3f","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"8d106a2f-c7fe-4b07-8b16-7dd91d3b8bcb","type":"BoxAnnotation"},{"id":"f728bcb3-3c60-4177-a303-8c01c054302e","type":"GlyphRenderer"},{"id":"f5cf8997-8c50-4f98-8595-6e833c5b160b","type":"GlyphRenderer"},{"id":"cec61bf5-a0d3-4989-b2dd-534a9fb7c57d","type":"GlyphRenderer"},{"id":"7ea6c51e-9712-4d9d-bd8b-72c8a23d2acc","type":"GlyphRenderer"},{"id":"e76eb32c-eda7-427f-8839-d1b995bb7a38","type":"GlyphRenderer"},{"id":"99e2f08a-d5c6-4b72-ab4f-e921fe8f11a7","type":"GlyphRenderer"},{"id":"ab0da8aa-2f36-4e31-9b78-f1911885d6d5","type":"CategoricalAxis"},{"id":"8b6d3ea9-7487-45b7-8375-a6e20e5aac3f","type":"LinearAxis"},{"id":"10e552b9-0bd8-4063-8824-1e3a25487883","type":"Grid"}],"title":{"id":"57a61def-de74-4e56-9cd5-e4bbcda90a3b","type":"Title"},"tool_events":{"id":"0eb2a321-8138-43a8-a033-c5e9b436fba1","type":"ToolEvents"},"toolbar":{"id":"32eb320f-8682-4304-bce8-bf9e26ff8d8f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"a7d7dea3-2c60-42e8-a911-b0b974452f1e","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"b00f6d48-ed3f-4c4d-b941-f4c9dca2e962","type":"Range1d"}},"id":"1bc82619-21a2-471c-8654-2158e669c26a","subtype":"Chart","type":"Plot"},{"attributes":{"data_source":{"id":"22023062-5d2c-4997-b034-22a7ffcfe52f","type":"ColumnDataSource"},"glyph":{"id":"10dde3f0-662f-4265-8870-e04b8633b73d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"cec61bf5-a0d3-4989-b2dd-534a9fb7c57d","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"57a61def-de74-4e56-9cd5-e4bbcda90a3b","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"de46a7b5-2acd-4b82-99e5-247b9d883fa6","type":"PanTool"},{"id":"34d97dc7-0e30-446f-8d7b-7423806fddf3","type":"WheelZoomTool"},{"id":"9e039edb-0096-485d-82f9-94c1faf60d14","type":"BoxZoomTool"},{"id":"1ab2a396-e0c7-4e2d-9a3c-40a20cfc439e","type":"SaveTool"},{"id":"b39f3945-d39d-456d-bc2a-3c0e52753416","type":"ResetTool"},{"id":"e38cb093-bb63-4400-a5d6-69c753613910","type":"HelpTool"}]},"id":"32eb320f-8682-4304-bce8-bf9e26ff8d8f","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Special"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11263162.0],"index":["Special"],"label":[{"index":"Special"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Special"],"y":[5631581.0]}},"id":"fc242452-8848-472b-a492-fd89754cf432","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"TV"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[139301607.0],"index":["TV"],"label":[{"index":"TV"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["TV"],"y":[69650803.5]}},"id":"4660031b-12d2-4141-b4fa-1e290b68e18c","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["Movie","Music","ONA","OVA","Special","TV"]},"id":"a7d7dea3-2c60-42e8-a911-b0b974452f1e","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"10dde3f0-662f-4265-8870-e04b8633b73d","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":nul ...

# %%
# ●リスト6.6.4：indexをX軸としたグラフ
p = Bar(sum_df.reset_index(), label='type', values='members', ylabel='メンバ数の合計',
        plot_width=400, plot_height=400, legend=False)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="811f8a67-c560-4c2f-bccb-eb8db47cf94d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("811f8a67-c560-4c2f-bccb-eb8db47cf94d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("811f8a67-c560-4c2f-bccb-eb8db47cf94d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '811f8a67-c560-4c2f-bccb-eb8db47cf94d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a7c60ecf-e207-4c94-a17d-5c6ef178de3b":{"roots":{"references":[{"attributes":{"data_source":{"id":"89664f25-409c-4534-86b0-c8e33f086d2b","type":"ColumnDataSource"},"glyph":{"id":"9c438f2a-c5a5-4021-9b10-f5c4a4dc0b5c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"dac033a9-0e45-416b-bb2e-441ed4e9998c","type":"GlyphRenderer"},{"attributes":{},"id":"0581738a-b933-48ec-9b0d-e47b33176347","type":"CategoricalTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6d63ec11-29cd-4f56-9a91-4bf4fd5c57ff","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c23487c0-39fe-4b3a-8ea3-c1ccc6637557","type":"ColumnDataSource"},"glyph":{"id":"0fd39466-ede3-446f-bb3d-23023da576ba","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"126b4494-e193-4b98-93ef-228215012cad","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"77aa01ef-c9f2-4a46-98d3-ebd3a318b0dd","subtype":"Chart","type":"Plot"},"ticker":{"id":"de5d95b7-fbc2-4821-b71e-ec6178ad5725","type":"BasicTicker"}},"id":"b79cc78e-d522-4121-bafb-b3fc985f5acb","type":"Grid"},{"attributes":{"plot":{"id":"77aa01ef-c9f2-4a46-98d3-ebd3a318b0dd","subtype":"Chart","type":"Plot"}},"id":"cf39dc43-c26b-4b3b-869d-f1276b8b8b12","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1a81f083-87ec-4197-91cc-096ea252597a","type":"PanTool"},{"id":"e4cc11ba-b47a-44ab-802e-ca5d132c4a4b","type":"WheelZoomTool"},{"id":"9cbf3645-e63f-4287-907c-9c93842637a2","type":"BoxZoomTool"},{"id":"f4afd3f6-23e7-44de-aded-bf6424a7b912","type":"SaveTool"},{"id":"a65c7e09-814d-4f23-af04-7f1180821db9","type":"ResetTool"},{"id":"cf39dc43-c26b-4b3b-869d-f1276b8b8b12","type":"HelpTool"}]},"id":"dbcf1c70-a59c-44f0-b5ba-b8f9c3b844d7","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c438f2a-c5a5-4021-9b10-f5c4a4dc0b5c","type":"Rect"},{"attributes":{},"id":"3ba03bdc-f58f-48f4-8967-d31e78cacd3e","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"77aa01ef-c9f2-4a46-98d3-ebd3a318b0dd","subtype":"Chart","type":"Plot"}},"id":"f4afd3f6-23e7-44de-aded-bf6424a7b912","type":"SaveTool"},{"attributes":{"data_source":{"id":"8626fd2a-565d-4ea7-8109-01fe8d3ad8c8","type":"ColumnDataSource"},"glyph":{"id":"a4aa3165-9523-45a2-ae7a-f7ee60341ace","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0ed0d8dc-4850-4e0b-b69d-27abbd8eb100","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a4aa3165-9523-45a2-ae7a-f7ee60341ace","type":"Rect"},{"attributes":{"plot":{"id":"77aa01ef-c9f2-4a46-98d3-ebd3a318b0dd","subtype":"Chart","type":"Plot"}},"id":"a65c7e09-814d-4f23-af04-7f1180821db9","type":"ResetTool"},{"attributes":{"below":[{"id":"08eb261d-f9f2-4429-98f6-f4be4fd36959","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"f531f6a8-9aad-4e7b-a53f-7e0e93480195","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"6d63ec11-29cd-4f56-9a91-4bf4fd5c57ff","type":"BoxAnnotation"},{"id":"0ed0d8dc-4850-4e0b-b69d-27abbd8eb100","type":"GlyphRenderer"},{"id":"a7f60d46-7be8-4484-ab09-cb43c6e3c38f","type":"GlyphRenderer"},{"id":"b9e5c6bb-922d-4b30-87f1-1b6002d7f42e","type":"GlyphRenderer"},{"id":"e8036ec2-e891-4095-88b3-e6384fe3c143","type":"GlyphRenderer"},{"id":"dac033a9-0e45-416b-bb2e-441ed4e9998 ...

# %%
# ●リスト6.6.5：Bokehの集約機能を使用したグラフ
p = Bar(
    df, label='type', values='members', agg='sum', ylabel='メンバ数の合計',
    plot_width=400, plot_height=400, legend=False)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0c00aac8-f701-4293-a934-9c1fe803a7a1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0c00aac8-f701-4293-a934-9c1fe803a7a1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0c00aac8-f701-4293-a934-9c1fe803a7a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0c00aac8-f701-4293-a934-9c1fe803a7a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"103fce54-a037-4d0f-8acf-312b655bcf7f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Movie"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[23651929.0],"label":[{"type":"Movie"}],"line_alpha":[1.0],"line_color":["white"],"type":["Movie"],"width":[0.8],"x":["Movie"],"y":[11825964.5]}},"id":"15482a6a-d0d6-462d-9716-8293cb3e2470","type":"ColumnDataSource"},{"attributes":{},"id":"7397fc76-9e6f-4442-95c6-5d0e6813cf9d","type":"ToolEvents"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4bc12ba8-3773-4a4a-b558-eb55a4e1f0d0","type":"Rect"},{"attributes":{"data_source":{"id":"1675fb89-b56d-4827-b043-fda76aa6a21a","type":"ColumnDataSource"},"glyph":{"id":"4bc12ba8-3773-4a4a-b558-eb55a4e1f0d0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"e813acd4-1ab7-4688-8c0e-4b884491e121","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"15482a6a-d0d6-462d-9716-8293cb3e2470","type":"ColumnDataSource"},"glyph":{"id":"5dd9dd4c-6cff-4c06-a756-797265ee63af","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"cea5ca97-d967-4acd-beb7-66b4e3080a11","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2dec04fa-b2d4-4951-8b2f-0e6e7c3627c3","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"TV"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[139301607.0],"label":[{"type":"TV"}],"line_alpha":[1.0],"line_color":["white"],"type":["TV"],"width":[0.8],"x":["TV"],"y":[69650803.5]}},"id":"1ea25160-cd00-4482-a12e-72aff6a81248","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"3d047b14-5429-4a29-b972-5dd94f98b441","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e7a157a-5b32-4cba-9ef6-9152051d8f49","type":"BasicTicker"}},"id":"8c7a6025-2c02-465a-b6e9-310ca9a3fef7","type":"Grid"},{"attributes":{"plot":null,"text":null},"id":"7020a33b-3ce0-46e4-b45d-98c6c2a652c5","type":"Title"},{"attributes":{"axis_label":"\u30e1\u30f3\u30d0\u6570\u306e\u5408\u8a08","formatter":{"id":"e9148451-6792-443b-a947-51214e533de6","type":"BasicTickFormatter"},"plot":{"id":"3d047b14-5429-4a29-b972-5dd94f98b441","subtype":"Chart","type":"Plot"},"ticker":{"id":"1e7a157a-5b32-4cba-9ef6-9152051d8f49","type":"BasicTicker"}},"id":"be51bcf1-5ec9-4eea-82c1-fa752e561318","type":"LinearAxis"},{"attributes":{},"id":"2b2212ff-5c53-4bdf-91b5-8500d0fd9cae","type":"CategoricalTicker"},{"attributes":{},"id":"ff19b156-3cb9-409d-8782-ac5e8380f140","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"1ea25160-cd00-4482-a12e-72aff6a81248","type":"ColumnDataSource"},"glyph":{"id":"2dec04fa-b2d4-4951-8b2f-0e6e7c3627c3","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4fa1ae52-ea71-4462-b2a3-ed1da43ebd13","type":"GlyphRenderer"},{"attributes":{},"id":"1e7a157a-5b32-4cba-9ef6-9152051d8f49","type":"BasicTicker"},{"attributes":{"callback":null,"end":146266687.35},"id":"861d4476-3c09-4115-b1dd-584bd6d7fe75","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5dd9dd4c-6cff-4c06-a756-797265ee63af","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"d ...

# %%
# ●リスト6.6.6：グループ化したグラフ
top10_df = pd.read_csv(os.path.join(base_url, 'anime_genre_top10.csv'))
p = Bar(
    top10_df, label='genre', values='members', group='type', agg='sum',
    ylabel='メンバ数の合計', plot_width=600, plot_height=400,
    legend='top_right')  # 凡例の位置
p.legend.background_fill_alpha = 0  # 凡例の背景を透過 （次章参照）
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="64bf44ec-1a9e-4461-9977-3083fabb4ebe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("64bf44ec-1a9e-4461-9977-3083fabb4ebe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64bf44ec-1a9e-4461-9977-3083fabb4ebe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64bf44ec-1a9e-4461-9977-3083fabb4ebe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d4fa263c-bd90-43e4-9de7-2f2849d76c9f":{"roots":{"references":[{"attributes":{"data_source":{"id":"58a62324-42c4-4822-a954-b3f2a6be4034","type":"ColumnDataSource"},"glyph":{"id":"e7af91f4-556e-46e4-bbbf-93a9ec21d28f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"6007cee5-50ed-4ed2-9e0d-2690e08883e8","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"456b3fd3-11f5-40c1-8f22-c2c53f0f3d0d","type":"PanTool"},{"id":"eb9fc411-c574-4cfc-9a97-97e47f5a9b1c","type":"WheelZoomTool"},{"id":"84cbf4f3-c222-480d-ad2f-92f02bf2598f","type":"BoxZoomTool"},{"id":"1950a4c6-02fd-4b54-a02a-7e90b7130a1e","type":"SaveTool"},{"id":"97bf32c8-e901-4bdb-9416-e618c7290a22","type":"ResetTool"},{"id":"db85d49b-4495-479a-a376-18ac2d497de9","type":"HelpTool"}]},"id":"ce221f6f-d468-4f10-b5ef-178e520381a1","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Supernatural","type":"OVA"}],"color":["#df5320"],"fill_alpha":[0.8],"genre":["Supernatural"],"height":[2696715.0],"label":[{"genre":"Supernatural","type":"OVA"}],"line_alpha":[1.0],"line_color":["white"],"type":["OVA"],"width":[0.13932646701298945],"x":["Supernatural:0.142857142857"],"y":[1348357.5]}},"id":"68ce698c-557f-403c-ae6e-a9bb8417c2c3","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Shounen","type":"ONA"}],"color":["#407ee7"],"fill_alpha":[0.8],"genre":["Shounen"],"height":[97833.0],"label":[{"genre":"Shounen","type":"ONA"}],"line_alpha":[1.0],"line_color":["white"],"type":["ONA"],"width":[0.13932646701298945],"x":["Shounen:0.714285714286"],"y":[48916.5]}},"id":"c0d19812-3c7a-437a-93a8-003204fe0bf4","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1c6b9e0e-ffaa-410f-93fe-bb16275257f8","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Adventure","type":"ONA"}],"color":["#407ee7"],"fill_alpha":[0.8],"genre":["Adventure"],"height":[70431.0],"label":[{"genre":"Adventure","type":"ONA"}],"line_alpha":[1.0],"line_color":["white"],"type":["ONA"],"width":[0.13932646701298945],"x":["Adventure:0.714285714286"],"y":[35215.5]}},"id":"8c9bb37a-4f6f-4fb4-9b99-c9ea7bbb5b45","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Fantasy","type":"ONA"}],"color":["#407ee7"],"fill_alpha":[0.8],"genre":["Fantasy"],"height":[188937.0],"label":[{"genre":"Fantasy","type":"ONA"}],"line_alpha":[1.0],"line_color":["white"],"type":["ONA"],"width":[0.13932646701298945],"x":["Fantasy:0.714285714286"],"y":[94468.5]}},"id":"0af75849-233a-4ab1-ab13-ddb1dd12a295","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"bbc6fb1c-4131-4e9f-8362-1580f4c4e5c7","type":"ColumnDataSource"},"glyph":{"id":"f2de208d-06c3-4bcc-af21-6f8c66c341a7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4f69ba5d-8bec-4dad-bdb0-4514319cc76f","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":null},"id":"4646969c-e349-407e-8a7f-2e12ade4df6c","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Drama","type":"Music"}],"color":["#5ab738"],"fill_alpha":[0.8],"genre":["Drama"],"height":[100734.0],"label":[{"genre":"Drama","type":"Music"}],"line_alpha":[1.0],"line_color": ...

# %%
# ●リスト6.6.7：積み上げ棒グラフ
p = Bar(
    top10_df.sort_values('type'), label='genre', values='members', stack='type', agg='sum',
    ylabel='メンバ数の合計', plot_width=600, plot_height=400, legend='top_right')
p.legend.padding = 0  # 凡例の中の余白を設定 （次章参照）
p.legend.background_fill_alpha = 0  # 凡例の背景を透過 （次章参照）
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e62d95f1-cde7-4d0c-9d95-dbe35ba0f07e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e62d95f1-cde7-4d0c-9d95-dbe35ba0f07e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e62d95f1-cde7-4d0c-9d95-dbe35ba0f07e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e62d95f1-cde7-4d0c-9d95-dbe35ba0f07e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d0e4c5f-70b3-44ad-8e09-ea16b7d893fe":{"roots":{"references":[{"attributes":{"data_source":{"id":"820e380b-6867-4f44-8eec-e39d57b9b30f","type":"ColumnDataSource"},"glyph":{"id":"1c784379-f389-4be2-bbd9-b6a71a47a79a","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4e98e5bb-3d5b-4b0e-bba6-e0fba831ace0","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"fb4ed184-00af-417d-b7d1-d9448481fc0d","subtype":"Chart","type":"Plot"},"ticker":{"id":"09512a47-627d-46d1-b550-d63f54c4b0ab","type":"BasicTicker"}},"id":"687bb251-32dd-45a6-980a-4368e0c0e102","type":"Grid"},{"attributes":{"data_source":{"id":"4664df8e-8e03-4ec1-b62a-fc948a91fa8d","type":"ColumnDataSource"},"glyph":{"id":"49e477ca-9a7c-437a-bbc9-bcad2fb84db6","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"40f16839-2442-4867-94fe-f9451a54ee11","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Fantasy","type":"Music"}],"color":["#5ab738"],"fill_alpha":[0.8],"genre":["Fantasy"],"height":[43962.0],"label":[{"genre":"Fantasy","type":"Music"}],"line_alpha":[1.0],"line_color":["white"],"type":["Music"],"width":[0.8],"x":["Fantasy"],"y":[8041387.0]}},"id":"726310e7-69b4-416d-99e7-41d8e7edae3e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd485da9-cbcb-49cc-aa9c-c583011287cb","type":"Rect"},{"attributes":{"data_source":{"id":"867b2738-ef96-4c8d-b1a9-62753966723e","type":"ColumnDataSource"},"glyph":{"id":"855ecd43-623e-4eb5-8084-6ab5744b115e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"d3654d3e-83d8-4c43-94bc-bf02ce136666","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c9d0a0c0-a5e2-4c62-a9f5-f3000f18b1d2","type":"ColumnDataSource"},"glyph":{"id":"998ed78d-411d-4648-97ed-1b2b9428796d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"60670773-3846-4a27-98c8-dbff7b2e1cd1","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural"]},"id":"de57fdb1-47b8-4ae1-8020-24d175d73337","type":"FactorRange"},{"attributes":{"data_source":{"id":"55dcfbf7-6078-4534-ae79-cb553cd6aa88","type":"ColumnDataSource"},"glyph":{"id":"d534beb7-150f-47e6-bceb-9f7e11377e11","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"c74dd8dd-3a00-4ad0-9d58-6ddb1a9cc6be","type":"GlyphRenderer"},{"attributes":{"background_fill_alpha":{"value":0},"items":[{"id":"26598470-95cf-4db9-a29e-511fc8bb3652","type":"LegendItem"},{"id":"f2fa291c-be96-44c5-8666-ae9965fbd43b","type":"LegendItem"},{"id":"b90d5469-01ac-48a2-9d49-345c07398967","type":"LegendItem"},{"id":"f50df048-6136-4e59-92cb-3c9ba34bf60b","type":"LegendItem"},{"id":"acc5a446-40cf-466c-b6e9-c325cbd6e7c5","type":"LegendItem"},{"id":"fe39e9e0-9fe1-40e2-a0b9-f33630b31d38","type":"LegendItem"}],"padding":0,"plot":{"id":"fb4ed184-00af-417d-b7d1-d9448481fc0d","subtype":"Chart","type":"Plot"}},"id":"c5c5be99-ae24-4062-8746-6a01d17dfa0a","type":"Legend"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bd08f3d5-bb97-4b1a-aa75-9f02382aa7f0","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"School","type":"TV"}],"color":["#c33ff3"],"fill_alpha":[0.8],"genre":["School"],"height":[35489099.0],"label":[{"genre":"School","type":"TV"}],"line_alpha":[1.0],"line_color":["white"],"type":["TV"],"width" ...

# %%
# ●リスト6.6.8：vbar()メソッドを使用した棒グラフ
from bokeh.plotting import figure
p = figure(plot_width=200, plot_height=200)
p.vbar(x=[1, 2, 3], top=[1, 2, 3], width=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f7e89d9d-2907-488f-a42d-868061b82f95"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f7e89d9d-2907-488f-a42d-868061b82f95");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f7e89d9d-2907-488f-a42d-868061b82f95");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f7e89d9d-2907-488f-a42d-868061b82f95' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"73072f3d-4b7f-4aa0-85f2-77f23ab23216":{"roots":{"references":[{"attributes":{},"id":"20a4d67d-2b49-4b24-b1e9-3e5a67721ea1","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"482ec540-9cc3-4846-b939-99e464bf3407","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"482ec540-9cc3-4846-b939-99e464bf3407","type":"BoxAnnotation"},"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"}},"id":"a94f4be8-120b-4dbb-94d9-575cb6893742","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"},"ticker":{"id":"1787e826-0197-45e1-8972-b99f9887f852","type":"BasicTicker"}},"id":"082e9d44-4969-4e74-b695-c36d6e6cea29","type":"Grid"},{"attributes":{"callback":null},"id":"465b7d6a-39bb-45f7-9105-13a9dafdef2c","type":"DataRange1d"},{"attributes":{},"id":"1787e826-0197-45e1-8972-b99f9887f852","type":"BasicTicker"},{"attributes":{"callback":null},"id":"b407e91f-b6a5-471a-b6a3-4caf8bbd9d4f","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c2fc909-96c9-4480-9a5d-e59382e303a7","type":"BasicTicker"}},"id":"d14be59d-a86b-45b9-8132-e142c12e57ce","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"2b5fceed-4f47-4c12-bdba-2134ab190030","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"60e0df45-694c-4159-bbc2-41700b236d0a","type":"PanTool"},{"id":"cb887b92-f978-494f-abe7-768fb828ca2d","type":"WheelZoomTool"},{"id":"a94f4be8-120b-4dbb-94d9-575cb6893742","type":"BoxZoomTool"},{"id":"9ee1d118-0b7f-45b1-bd51-9c95a566660d","type":"SaveTool"},{"id":"3426d018-9982-4af9-9f71-2d3fa23e3cd4","type":"ResetTool"},{"id":"7f81b6e8-1d2f-4b15-8296-08b06fe5f1c0","type":"HelpTool"}]},"id":"6427e5ff-d42f-49a8-b97b-8a6029a7c6d6","type":"Toolbar"},{"attributes":{},"id":"c9384e61-32a4-42b8-aa98-627a6c0c2030","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"}},"id":"60e0df45-694c-4159-bbc2-41700b236d0a","type":"PanTool"},{"attributes":{"formatter":{"id":"c9384e61-32a4-42b8-aa98-627a6c0c2030","type":"BasicTickFormatter"},"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"},"ticker":{"id":"1787e826-0197-45e1-8972-b99f9887f852","type":"BasicTicker"}},"id":"10afc11a-f45e-4d7a-ba38-e0a6c33ba02f","type":"LinearAxis"},{"attributes":{"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"}},"id":"3426d018-9982-4af9-9f71-2d3fa23e3cd4","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"41f3fa7d-6b10-4f09-88ed-326e72b8f5ce","type":"VBar"},{"attributes":{"plot":{"id":"29b10c57-c6e8-479b-b90c-1fa659d60bc7","subtype":"Figure","type":"Plot"}},"id":"cb887b92-f978-494f-abe7-768fb828ca2d","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"10afc11a-f45e-4d7a-ba38-e0a6c33ba02f","type":"LinearAxis"}],"left":[{"id":"649bd312-6dbd-429c-8451-7ac59796a182","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"10afc11a-f45e-4d7a-ba38-e0a6c33ba02f","type":"LinearAxis"},{"id":"082e9d44-4969-4e74-b695-c36d6e6cea29","type":"Grid"},{"id":"649bd312-6dbd-429c-8451-7ac59796a182","type":"LinearAxis"},{"id":"d14be59d-a86b-45b9-8132-e142c12e57ce","type":"Grid"},{"id":"482ec540-9cc3-4846-b939-99e464bf3407","type":"BoxAnnotation"},{"id":"20069db3-1bd6-454d-b2a6-fb7c9679ab7c","type":"GlyphRender ...

# %%
# ●リスト6.6.9：hbar()メソッドを使用した棒グラフ
p = figure(plot_width=200, plot_height=200)
p.hbar(y=[1, 2, 3], right=[1, 2, 3], height=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5942f13e-19ec-4ea5-9e63-c50aa12659b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5942f13e-19ec-4ea5-9e63-c50aa12659b5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5942f13e-19ec-4ea5-9e63-c50aa12659b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5942f13e-19ec-4ea5-9e63-c50aa12659b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd26dcb3-3ad4-4708-b5cb-b71da93045bf":{"roots":{"references":[{"attributes":{"overlay":{"id":"1b520dd0-6d09-4ff6-97bd-4f8bcd3d4ed2","type":"BoxAnnotation"},"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"}},"id":"ad3c28bb-15c1-4852-9ca9-959e9b3019b3","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.5},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"6aa11dad-fb11-4703-a4d4-f4fb4b95e2e1","type":"HBar"},{"attributes":{},"id":"95f7d906-2aed-4ec4-a52d-1c2e757565d8","type":"BasicTicker"},{"attributes":{"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"}},"id":"c32a2dd8-59a5-4e48-be3d-7291f3f3d67f","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[1,2,3],"y":[1,2,3]}},"id":"efc2e6ed-1266-43f6-a66a-164b990ebfb0","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"0a60d4ae-74bb-4f2f-8f9b-b850c143e98c","type":"Title"},{"attributes":{"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"}},"id":"82755938-eb4a-44ea-8d60-61860b7a43b9","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"height":{"value":0.5},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"e782798f-85d7-4042-a10e-d4b3b4fbd532","type":"HBar"},{"attributes":{"below":[{"id":"e5d94259-6ade-41d7-b0b5-3e8769b8a099","type":"LinearAxis"}],"left":[{"id":"c6ae4468-70e4-420b-b49c-02be329b689c","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"e5d94259-6ade-41d7-b0b5-3e8769b8a099","type":"LinearAxis"},{"id":"39e6a88f-8034-44aa-970d-1a95418dbb1b","type":"Grid"},{"id":"c6ae4468-70e4-420b-b49c-02be329b689c","type":"LinearAxis"},{"id":"878ed91c-d67c-490d-8707-4328668435eb","type":"Grid"},{"id":"1b520dd0-6d09-4ff6-97bd-4f8bcd3d4ed2","type":"BoxAnnotation"},{"id":"aec78249-eb4c-4b64-9304-347ae8a1f055","type":"GlyphRenderer"}],"title":{"id":"0a60d4ae-74bb-4f2f-8f9b-b850c143e98c","type":"Title"},"tool_events":{"id":"886fa49d-f34d-419e-bfa2-5c574cea0db7","type":"ToolEvents"},"toolbar":{"id":"c5434b58-5f69-43f3-b937-b648a1659f6a","type":"Toolbar"},"x_range":{"id":"53e7914c-9985-4894-bfbe-60852a2cb025","type":"DataRange1d"},"y_range":{"id":"05ee2c6d-cb9c-48c0-a943-7d11abbf5fab","type":"DataRange1d"}},"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"05ee2c6d-cb9c-48c0-a943-7d11abbf5fab","type":"DataRange1d"},{"attributes":{},"id":"886fa49d-f34d-419e-bfa2-5c574cea0db7","type":"ToolEvents"},{"attributes":{},"id":"687bf61f-6cfe-40de-be4f-f366f12cc73b","type":"BasicTicker"},{"attributes":{"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"}},"id":"2d65ca06-8963-4605-b597-821b23f7735b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"}},"id":"9a765736-e145-4a4e-94da-e1b1d0c892c4","type":"ResetTool"},{"attributes":{"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"95f7d906-2aed-4ec4-a52d-1c2e757565d8","type":"BasicTicker"}},"id":"39e6a88f-8034-44aa-970d-1a95418dbb1b","type":"Grid"},{"attributes":{},"id":"81254bce-dc72-49e3-9539-e2ca69cd4d3d","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"687bf61f-6cfe-40de-be4f-f366f12cc73b","type":"BasicTicker"}},"id":"878ed91c-d67c-490d-8707-4328668435eb","type":"Grid"},{"attributes":{},"id":"6f3bd9b1-25a4-4cc8-b0e8-e68223f64d81","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"6f3bd9b1-25a4-4cc8-b0e8-e68223f64d81","type":"BasicTickFormatter"},"plot":{"id":"4134db51-98aa-4c12-8386-bb15be1ed2c0","subtype":"Figure","type":"Plot" ...

# %%
# ●リスト6.6.10：書式を設定した棒グラフ
from bokeh.palettes import d3
# ジャンルをメンバ数で集計
genre = top10_df.groupby('genre')['members'].sum().sort_values()
p = figure(
    title='メンバ数が多いジャンルトップ10',
    plot_width=400, plot_height=400,
    x_range=(0, genre.max()),
    y_range=(-0.5, len(genre) - 0.5))
text_x = genre.min() * 0.1  # 注釈のX座標
colors = d3['Category20b'][10][::-1]  # カラーパレット(7章で解説)
# 枠、 罫線、 軸をすべて非表示
p.outline_line_color = None
p.grid.visible = False
p.axis.visible = False
for i, g in enumerate(genre):
    text = ': '.join((genre.index[i], '{:,}'.format(g)))
    p.hbar(y=i, left=0, right=g, height=1, color=colors[i])
    p.text(
        x=text_x,
        y=i,
        text=[text],
        text_color='#ffffff',
        text_font_size='10pt',
        text_font_style='bold',
        text_baseline='middle')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7baffe01-2e0f-43b3-b460-6f937b51b4f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7baffe01-2e0f-43b3-b460-6f937b51b4f5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7baffe01-2e0f-43b3-b460-6f937b51b4f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7baffe01-2e0f-43b3-b460-6f937b51b4f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0b1e92f5-78ea-403a-b7e7-031dbcf9ae40":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"37270ac0-2119-4db9-91b0-0ff86df5c214","type":"BoxAnnotation"},{"attributes":{"callback":null,"data":{}},"id":"b99b0205-99cf-4dfb-95e7-8e24c05cbf8b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"90869dea-da08-45a5-b388-4e1b95b9f66b","type":"ColumnDataSource"},"glyph":{"id":"3fd3c601-91b3-49e4-9bd6-7463a73515b4","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"07239efd-a822-42ca-8e92-45d4ee480430","type":"Text"},"selection_glyph":null},"id":"6c4faf9b-ab59-4d71-b375-392cee5f45fa","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"1697c128-1a8c-4149-bd20-5a12bbf8e3af","type":"PanTool"},{"attributes":{},"id":"8f5de121-be07-4c6d-8fd8-b141f990a85a","type":"BasicTickFormatter"},{"attributes":{"text_baseline":"middle","text_color":{"value":"#ffffff"},"text_font_size":{"value":"10pt"},"text_font_style":"bold","x":{"value":4058455.5},"y":{"value":9}},"id":"97bbdb44-3192-4e06-8388-bcf2f3729d93","type":"Text"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":83397322},"y":{"value":8}},"id":"726652a5-927e-479f-bb14-92f4f8da5dca","type":"HBar"},{"attributes":{"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"d74755ad-3c06-4bba-bce5-9934ccea48ca","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["Action: 83,397,322"]}},"id":"3901c063-1bd8-4e67-b5df-b6a35f68a6e2","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"37270ac0-2119-4db9-91b0-0ff86df5c214","type":"BoxAnnotation"},"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"403ffccb-e42d-4c5d-8e40-cffc82409d1a","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#5254a3"},"height":{"value":1},"line_color":{"value":"#5254a3"},"right":{"value":83397322},"y":{"value":8}},"id":"b2ada2ba-b9ee-40b1-b24a-3b5e7bc403a7","type":"HBar"},{"attributes":{"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"ff0ccf73-c5a3-42a5-9d55-02f37b09e864","type":"SaveTool"},{"attributes":{"data_source":{"id":"b99b0205-99cf-4dfb-95e7-8e24c05cbf8b","type":"ColumnDataSource"},"glyph":{"id":"b2ada2ba-b9ee-40b1-b24a-3b5e7bc403a7","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"726652a5-927e-479f-bb14-92f4f8da5dca","type":"HBar"},"selection_glyph":null},"id":"95324598-fc2e-4009-8a9a-4e854ec10d5f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"85ceef66-5f2e-4daa-8146-5d241a03d926","type":"ResetTool"},{"attributes":{"plot":{"id":"2c807ef6-e037-42ce-860e-93921b3ce9ff","subtype":"Figure","type":"Plot"}},"id":"985d76a3-aa18-47f6-9078-0b7fc3262334","type":"HelpTool"},{"attributes":{},"id":"6739cacb-1cf2-4583-a9f5-cfec38c93b86","type":"BasicTickFormatter"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"10pt"},"text_font_style":"bold","x":{"value":4058455.5},"y":{"value":8}},"id":"3c584183-f48d-4f7e-a19e-a986e14d5b62","type":"Text"},{"attributes":{"data_source":{"id":"e4ccdaac-9e1f-482e-9eea-0ca69532d429","type":"ColumnDataSource"},"glyph":{"id":"97bbdb44-3192-4e06-8388-bcf2f3729d93","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"da0115ca-aa50-4df8-b59e-92693f3e5308" ...
