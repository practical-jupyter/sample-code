# %% [markdown]
# ## 第6章 Bokehでグラフを描画しよう
#
# ### 6-6: 棒グラフ

# %%
# リスト6.6.1：リスト-ライク・オブジェクトのデータを渡したグラフ
from bokeh.charts import output_notebook, Bar, show

output_notebook()
p = Bar([1, 2, 3], plot_width=300, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="340952e7-e22c-4dde-b862-adb4c4071cb1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c4c91798-7054-4126-af93-311b176e495f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c4c91798-7054-4126-af93-311b176e495f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c4c91798-7054-4126-af93-311b176e495f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c4c91798-7054-4126-af93-311b176e495f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e28be337-3af5-460e-95d2-229b95234c48":{"roots":{"references":[{"attributes":{},"id":"e5b18443-d25b-4ca6-be1c-3fb00be644ac","type":"CategoricalTicker"},{"attributes":{"items":[{"id":"46f7a5f6-0532-4039-8728-130f3fce83bb","type":"LegendItem"},{"id":"50c6491b-0295-4ba4-a618-acbb6e793567","type":"LegendItem"},{"id":"a04a349b-6e83-47c7-8f81-a5938f338c93","type":"LegendItem"}],"location":"top_left","plot":{"id":"61cd8b6c-57cc-4ba9-bd40-e37d1da7d198","subtype":"Chart","type":"Plot"}},"id":"762ce360-9700-4514-8621-ae6d2955f242","type":"Legend"},{"attributes":{"data_source":{"id":"e819a87d-f666-4303-aad4-909422b873e3","type":"ColumnDataSource"},"glyph":{"id":"af5b0f84-af72-47fc-946d-c05b71a898d2","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"db40f177-f26c-4607-a994-3a43168087bf","type":"GlyphRenderer"},{"attributes":{"label":{"value":"1"},"renderers":[{"id":"db40f177-f26c-4607-a994-3a43168087bf","type":"GlyphRenderer"}]},"id":"50c6491b-0295-4ba4-a618-acbb6e793567","type":"LegendItem"},{"attributes":{"formatter":{"id":"b0ba6827-538c-4e84-8b52-18b212e19107","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"61cd8b6c-57cc-4ba9-bd40-e37d1da7d198","subtype":"Chart","type":"Plot"},"ticker":{"id":"e5b18443-d25b-4ca6-be1c-3fb00be644ac","type":"CategoricalTicker"}},"id":"27c59674-d87d-44ba-b6c6-8dd7fb55aa04","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":2}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"index":[2],"label":[{"index":2}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["2"],"y":[1.5]}},"id":"caad5d4c-4833-4ab2-88ea-4b697f7e1ada","type":"ColumnDataSource"},{"attributes":{"label":{"value":"0"},"renderers":[{"id":"a76d7637-ef18-454e-bef1-5e9b207f0218","type":"GlyphRenderer"}]},"id":"46f7a5f6-0532-4039-8728-130f3fce83bb","type":"LegendItem"},{"attributes":{},"id":"3f99875b-d09a-458d-a378-7048b1f196dd","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":3.15},"id":"2d13c53d-e3b7-4330-8806-02d522743c02","type":"Range1d"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8414b88a-948b-44c0-97a6-314f827f41e7","type":"Rect"},{"attributes":{"axis_label":"Sum( A )","formatter":{"id":"3f99875b-d09a-458d-a378-7048b1f196dd","type":"BasicTickFormatter"},"plot":{"id":"61cd8b6c-57cc-4ba9-bd40-e37d1da7d198","subtype":"Chart","type":"Plot"},"ticker":{"id":"1fb5576b-6446-4c33-90b0-b830d244be5d","type":"BasicTicker"}},"id":"668b00bc-46ac-4665-8367-3d84d76db9a4","type":"LinearAxis"},{"attributes":{"label":{"value":"2"},"renderers":[{"id":"8dfb8721-9524-434c-8b9a-141d6afae798","type":"GlyphRenderer"}]},"id":"a04a349b-6e83-47c7-8f81-a5938f338c93","type":"LegendItem"},{"attributes":{},"id":"3c5d7a48-bcf8-4793-8736-f0262493cfcb","type":"ToolEvents"},{"attributes":{"data_source":{"id":"caad5d4c-4833-4ab2-88ea-4b697f7e1ada","type":"ColumnDataSource"},"glyph":{"id":"8414b88a-948b-44c0-97a6-314f827f41e7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8dfb8721-9524-434c-8b9a-141d6afae798","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["0","1","2"]},"id":"1917ee2b-b4cf-4c37-8fdd-47fefe5d064a","type":"FactorRange"},{"attributes":{"plot":null,"text":null},"id":"772d70dc-d58b-485f-b5fc-49e6ab964cbf","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"68b3de94-a91c-4780-a3a6-870e767cc04b","type":"PanTool"},{"id":"1cf61c20-c4a6-417a-815b-8db7fc060dab","type":"WheelZoomTool"},{"id":"6c6065ca-640d-4b8d-bb34-b493f699e65c","type":"BoxZoomTool"},{"id":"779b2c9e-d1bf-460f-ba67-f8880e61bf9f","type":"SaveTool"},{"id":"6293ea50-aba0-4027- ...

# %%
# リスト6.6.2：辞書型のデータを渡したグラフ
data = {"data": [1, 2, 3], "x_label": ["a", "b", "c"]}
p = Bar(data, values="data", label="x_label", plot_width=300, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc439ed1-bf24-40fb-9851-90c339659197"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fc439ed1-bf24-40fb-9851-90c339659197");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc439ed1-bf24-40fb-9851-90c339659197");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc439ed1-bf24-40fb-9851-90c339659197' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fab7cf62-a766-4f6a-8769-ce8e252956e7":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"5fa18fbd-c6bc-4abd-826d-a6c8747a557a","type":"Title"},{"attributes":{"overlay":{"id":"6178e145-094a-4574-a836-35fddfde3089","type":"BoxAnnotation"},"plot":{"id":"bd02f3d0-4ecf-478b-85b2-07008a37f3c6","subtype":"Chart","type":"Plot"}},"id":"d10af90c-f3e7-4224-8242-7dc5cf15e68a","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"x_label":"b"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":[{"x_label":"b"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["b"],"x_label":["b"],"y":[1.0]}},"id":"4d17cf4c-669b-4022-8297-a06fa6acb744","type":"ColumnDataSource"},{"attributes":{"label":{"value":"a"},"renderers":[{"id":"5681774a-051c-46a7-baa5-f7af151f81ce","type":"GlyphRenderer"}]},"id":"6b871566-1e54-4455-bef9-8cbf06c93c66","type":"LegendItem"},{"attributes":{"axis_label":"Sum( Data )","formatter":{"id":"d7ed4a7a-2265-4418-8592-f08f23550a16","type":"BasicTickFormatter"},"plot":{"id":"bd02f3d0-4ecf-478b-85b2-07008a37f3c6","subtype":"Chart","type":"Plot"},"ticker":{"id":"1f40b6b4-da8d-43ff-a8f2-9d6c2fdca2ca","type":"BasicTicker"}},"id":"bc921d23-9f23-42db-9981-822deec3e7d1","type":"LinearAxis"},{"attributes":{"below":[{"id":"54eb845e-6cf2-4083-bf84-25c9cd5297bf","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"bc921d23-9f23-42db-9981-822deec3e7d1","type":"LinearAxis"}],"plot_height":200,"plot_width":300,"renderers":[{"id":"6178e145-094a-4574-a836-35fddfde3089","type":"BoxAnnotation"},{"id":"5681774a-051c-46a7-baa5-f7af151f81ce","type":"GlyphRenderer"},{"id":"67cfddc6-4acf-499c-bd3e-ad319d61107c","type":"GlyphRenderer"},{"id":"e27c733c-9c0d-43cf-80c4-890940a293b0","type":"GlyphRenderer"},{"id":"104fd313-b31b-411d-974e-133002031d8f","type":"Legend"},{"id":"54eb845e-6cf2-4083-bf84-25c9cd5297bf","type":"CategoricalAxis"},{"id":"bc921d23-9f23-42db-9981-822deec3e7d1","type":"LinearAxis"},{"id":"be1e6da0-da13-4254-beb1-e7726795523c","type":"Grid"}],"title":{"id":"5fa18fbd-c6bc-4abd-826d-a6c8747a557a","type":"Title"},"tool_events":{"id":"b06fdbd2-0234-4df6-8cb4-6690e63d52f8","type":"ToolEvents"},"toolbar":{"id":"f9ccace3-3765-4cd2-b5be-1c7af0b717ec","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"aeb90efd-0765-46de-9591-ef5734203651","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"b0938db3-cbd4-46c4-b155-0d834201450d","type":"Range1d"}},"id":"bd02f3d0-4ecf-478b-85b2-07008a37f3c6","subtype":"Chart","type":"Plot"},{"attributes":{"items":[{"id":"6b871566-1e54-4455-bef9-8cbf06c93c66","type":"LegendItem"},{"id":"6d052a11-72b1-4eb6-86f5-8352095604d1","type":"LegendItem"},{"id":"d1b29607-ea0f-48f1-b920-cd3d278fdbaf","type":"LegendItem"}],"location":"top_left","plot":{"id":"bd02f3d0-4ecf-478b-85b2-07008a37f3c6","subtype":"Chart","type":"Plot"}},"id":"104fd313-b31b-411d-974e-133002031d8f","type":"Legend"},{"attributes":{"callback":null,"factors":["a","b","c"]},"id":"aeb90efd-0765-46de-9591-ef5734203651","type":"FactorRange"},{"attributes":{"data_source":{"id":"4d17cf4c-669b-4022-8297-a06fa6acb744","type":"ColumnDataSource"},"glyph":{"id":"fef3fcb6-b2b1-4392-9bff-2382dcf0d784","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"67cfddc6-4acf-499c-bd3e-ad319d61107c","type":"GlyphRenderer"},{"attributes":{},"id":"ce16d437-b9b2-44f5-a581-63722e0d008d","type":"CategoricalTickFormatter"},{"attributes":{},"id":"d7ed4a7a-2265-4418-8592-f08f23550a16","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fef3fcb6-b2b1-4392-9bff-2382dcf0d784","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5 ...

# %%
# リスト6.6.3：DataFrameを渡したグラフ
import os
import pandas as pd

base_url = (
    "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
)
anime_master_csv = os.path.join(base_url, "anime_master.csv")
df = pd.read_csv(anime_master_csv)
sum_df = df.groupby("type").sum()
p = Bar(
    sum_df,
    values="members",
    ylabel="メンバ数の合計",
    plot_width=400,
    plot_height=400,
    legend=False,
)  # 凡例を非表示
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="223e7f27-7945-4fbc-bd55-b10efb341670"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("223e7f27-7945-4fbc-bd55-b10efb341670");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("223e7f27-7945-4fbc-bd55-b10efb341670");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '223e7f27-7945-4fbc-bd55-b10efb341670' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fe7bd158-b3d8-4403-aad9-b85c494c4d52":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5604969e-dd49-4045-a5df-bd94e5e87e91","type":"Rect"},{"attributes":{},"id":"ee8991b0-7c81-455b-be6b-b51d39e496f0","type":"BasicTicker"},{"attributes":{},"id":"afc3c985-d33d-44a4-bcac-0e76718b6470","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5d1d0194-2b8a-486d-99fd-77359a61755f","type":"Rect"},{"attributes":{"data_source":{"id":"2b5b90da-6ada-4d62-bd3d-1457fe3c3117","type":"ColumnDataSource"},"glyph":{"id":"5604969e-dd49-4045-a5df-bd94e5e87e91","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f0d163a6-ba36-44fa-917e-d433555af8cd","type":"GlyphRenderer"},{"attributes":{},"id":"9e656af0-2ec9-471c-ae66-9cb1a97697ad","type":"CategoricalTicker"},{"attributes":{"callback":null,"end":146266687.35},"id":"5de9d592-34e7-463a-b2bc-15499062a85c","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"OVA"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[13233285.0],"index":["OVA"],"label":[{"index":"OVA"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OVA"],"y":[6616642.5]}},"id":"64eee72c-9c5f-4ac2-853e-e18359c2c5f3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d1115b47-fa9c-48be-be5e-66d05066150b","type":"ColumnDataSource"},"glyph":{"id":"207a01d2-58e9-4822-ad3a-dee69d4b3227","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f7978077-5245-4e49-8c1d-a2d092816a27","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"Special"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11263162.0],"index":["Special"],"label":[{"index":"Special"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Special"],"y":[5631581.0]}},"id":"702c818b-709e-4032-87ef-7b293a2f6dae","type":"ColumnDataSource"},{"attributes":{},"id":"d500af82-024a-4acf-9cfa-72b55d48f0ce","type":"ToolEvents"},{"attributes":{"below":[{"id":"04f011fb-7b73-47d7-b64a-0ea032cceae4","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"50c56897-ad36-47df-8ebd-ee4f62e3d141","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a83e765e-ea1c-46fa-b5f0-0ef6044177de","type":"BoxAnnotation"},{"id":"8c552ef3-0968-4034-bcde-5c5e14bc02fb","type":"GlyphRenderer"},{"id":"951b36d3-6712-4161-acf9-f1c9f91dd04b","type":"GlyphRenderer"},{"id":"f7978077-5245-4e49-8c1d-a2d092816a27","type":"GlyphRenderer"},{"id":"c06f265f-1e6b-4d61-be26-b8434b9c9e30","type":"GlyphRenderer"},{"id":"f1c807a4-4012-48e0-93bd-29b9533e8d42","type":"GlyphRenderer"},{"id":"f0d163a6-ba36-44fa-917e-d433555af8cd","type":"GlyphRenderer"},{"id":"04f011fb-7b73-47d7-b64a-0ea032cceae4","type":"CategoricalAxis"},{"id":"50c56897-ad36-47df-8ebd-ee4f62e3d141","type":"LinearAxis"},{"id":"2dc66507-a27a-436e-a0fc-939b334f1c95","type":"Grid"}],"title":{"id":"54b67df1-322d-4f17-aa14-84a1fbd4b7a1","type":"Title"},"tool_events":{"id":"d500af82-024a-4acf-9cfa-72b55d48f0ce","type":"ToolEvents"},"toolbar":{"id":"16eb93a4-b66c-41f9-a02e-7047c380608a","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"dd1daceb-7748-4495-92af-750f4d16d1d3","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"5de9d592-34e7-463a-b2bc-15499062a85c","type":"Range1d"}},"id":"9b85fc76-13f0-41c9-a754-01bb27f4f32a","subtype":"Chart","type":"Plot"},{"attributes":{" ...

# %%
# リスト6.6.4：indexをX軸としたグラフ
p = Bar(
    sum_df.reset_index(),
    label="type",
    values="members",
    ylabel="メンバ数の合計",
    plot_width=400,
    plot_height=400,
    legend=False,
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4568954-56bb-4b38-884c-56cf76e21d1f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f4568954-56bb-4b38-884c-56cf76e21d1f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4568954-56bb-4b38-884c-56cf76e21d1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4568954-56bb-4b38-884c-56cf76e21d1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fb90faf1-e4dc-4b12-a2d5-1ab33b88fe14":{"roots":{"references":[{"attributes":{"data_source":{"id":"b26cdfed-64f3-4aa2-a026-c72787d1663a","type":"ColumnDataSource"},"glyph":{"id":"c6b6764c-b48f-4734-9054-fba2a829e6e9","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"58e3ef74-ed10-474b-a40c-7d5379d37012","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Special"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11263162.0],"label":[{"type":"Special"}],"line_alpha":[1.0],"line_color":["white"],"type":["Special"],"width":[0.8],"x":["Special"],"y":[5631581.0]}},"id":"905f7729-3a43-460f-b6c3-52eca6def7ad","type":"ColumnDataSource"},{"attributes":{"axis_label":"\u30e1\u30f3\u30d0\u6570\u306e\u5408\u8a08","formatter":{"id":"3de93da5-0717-4621-b85c-bbb144be1dc6","type":"BasicTickFormatter"},"plot":{"id":"c0803010-0974-4e17-ac7d-c521f967a728","subtype":"Chart","type":"Plot"},"ticker":{"id":"073bbb5f-2df9-4378-af31-8dd2c3d8d0cf","type":"BasicTicker"}},"id":"e7068a55-eace-4470-8df9-ac10cdb839b0","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Movie"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[23651929.0],"label":[{"type":"Movie"}],"line_alpha":[1.0],"line_color":["white"],"type":["Movie"],"width":[0.8],"x":["Movie"],"y":[11825964.5]}},"id":"e04550cc-060c-4943-9828-60d8d9145622","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e12a7c0-c45a-4f23-975f-f3f44a728011","type":"Rect"},{"attributes":{},"id":"3de93da5-0717-4621-b85c-bbb144be1dc6","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c918a4d6-4fa0-45ca-acc2-6cdd63167815","type":"Rect"},{"attributes":{},"id":"a0d21e00-af4a-45de-97c9-df67dce1ae32","type":"CategoricalTickFormatter"},{"attributes":{"data_source":{"id":"e04550cc-060c-4943-9828-60d8d9145622","type":"ColumnDataSource"},"glyph":{"id":"86e78dc2-2513-481b-8b7d-0d9dfd3ba7cb","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4ec16046-65ce-45ed-9925-8a298b46ab19","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"06ceb62e-f6be-4201-b5a8-a189b1998507","type":"ColumnDataSource"},"glyph":{"id":"c918a4d6-4fa0-45ca-acc2-6cdd63167815","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"24d3ab33-49a6-430a-9408-5fd999469909","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"TV"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[139301607.0],"label":[{"type":"TV"}],"line_alpha":[1.0],"line_color":["white"],"type":["TV"],"width":[0.8],"x":["TV"],"y":[69650803.5]}},"id":"ced69b74-2d41-46d5-abd6-f55ea98460af","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"ONA"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2601477.0],"label":[{"type":"ONA"}],"line_alpha":[1.0],"line_color":["white"],"type":["ONA"],"width":[0.8],"x":["ONA"],"y":[1300738.5]}},"id":"74258ab2-60c3-4e8b-a4c4-d02606ffe58a","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value": ...

# %%
# リスト6.6.5：Bokehの集約機能を使用したグラフ
p = Bar(
    df,
    label="type",
    values="members",
    agg="sum",
    ylabel="メンバ数の合計",
    plot_width=400,
    plot_height=400,
    legend=False,
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d3512caf-d10a-4679-8b59-2435911f5100"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d3512caf-d10a-4679-8b59-2435911f5100");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d3512caf-d10a-4679-8b59-2435911f5100");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd3512caf-d10a-4679-8b59-2435911f5100' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5347909-a47f-4824-9857-dd8e51206140":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"536e6343-d0c0-48c9-91ac-aeaf19588532","subtype":"Chart","type":"Plot"},"ticker":{"id":"4ef723ad-7b40-4f50-8aad-499fb85908e6","type":"BasicTicker"}},"id":"963821c6-d5e4-4a9c-9879-f364e7911878","type":"Grid"},{"attributes":{"axis_label":"\u30e1\u30f3\u30d0\u6570\u306e\u5408\u8a08","formatter":{"id":"7a0ac26f-761f-423f-a414-1e023a5c90fc","type":"BasicTickFormatter"},"plot":{"id":"536e6343-d0c0-48c9-91ac-aeaf19588532","subtype":"Chart","type":"Plot"},"ticker":{"id":"4ef723ad-7b40-4f50-8aad-499fb85908e6","type":"BasicTicker"}},"id":"f9800551-9a7f-4ee7-b7f2-ff99797103c5","type":"LinearAxis"},{"attributes":{},"id":"4ef723ad-7b40-4f50-8aad-499fb85908e6","type":"BasicTicker"},{"attributes":{"data_source":{"id":"d8b9d3f8-39d1-44d4-85f3-aeb55374b1f1","type":"ColumnDataSource"},"glyph":{"id":"97bdb655-c648-40a9-910f-c316c1cf1278","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"09f0b3f9-c00b-4f9d-b3a2-9a73cd0b7ecf","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"2e94c2fe-85bb-4e1c-86e0-1684d7c54e70","type":"BoxAnnotation"},"plot":{"id":"536e6343-d0c0-48c9-91ac-aeaf19588532","subtype":"Chart","type":"Plot"}},"id":"36dbdefd-3e34-4a7e-bd8b-85b22b60a987","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"1bd02e26-9a7a-4de0-883f-7834773222fd","type":"ColumnDataSource"},"glyph":{"id":"87fbc186-e466-445a-b157-b31b82352d24","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ad6955eb-1a4a-477b-97b7-c2bd91a7f703","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"TV"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[139301607.0],"label":[{"type":"TV"}],"line_alpha":[1.0],"line_color":["white"],"type":["TV"],"width":[0.8],"x":["TV"],"y":[69650803.5]}},"id":"cba7cd72-25bc-47e5-a983-2e91c16f5bbc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"482ec95f-1e0c-471e-833e-a611e7bfa8ab","type":"ColumnDataSource"},"glyph":{"id":"13fad99f-1855-4c1f-bcb3-1684e039d748","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f5e7d198-93d5-4770-9a0d-3de63e728911","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"ONA"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2601477.0],"label":[{"type":"ONA"}],"line_alpha":[1.0],"line_color":["white"],"type":["ONA"],"width":[0.8],"x":["ONA"],"y":[1300738.5]}},"id":"1bd02e26-9a7a-4de0-883f-7834773222fd","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"536e6343-d0c0-48c9-91ac-aeaf19588532","subtype":"Chart","type":"Plot"}},"id":"0cecac84-219d-428e-89f4-d631d473c4ea","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Music"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[617419.0],"label":[{"type":"Music"}],"line_alpha":[1.0],"line_color":["white"],"type":["Music"],"width":[0.8],"x":["Music"],"y":[308709.5]}},"id":"482ec95f-1e0c-471e-833e-a611e7bfa8ab","type":"ColumnDataSource"},{"attributes":{},"id":"7a0ac26f-761f-423f-a414-1e023a5c90fc","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"536e6343-d0c0-48c9-91ac-aeaf19588532","subtype":"Chart","type":"Plot"}},"id":"99f86e21-e542-47e6-85d4-fb4858453608","type":"WheelZoomTool"},{"attributes":{"callback":null,"factors":["Movie","Music","ONA","OVA","Special","TV"]},"id":"5badb8ac-4825-4e53-8805-68176b2b8255","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"type":"Movie"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[23651929.0],"label":[{"type":"Movie"}],"line_ ...

# %%
# リスト6.6.6：グループ化したグラフ
top10_df = pd.read_csv(os.path.join(base_url, "anime_genre_top10.csv"))
p = Bar(
    top10_df,
    label="genre",
    values="members",
    group="type",
    agg="sum",
    ylabel="メンバ数の合計",
    plot_width=600,
    plot_height=400,
    legend="top_right",
)  # 凡例の位置
p.legend.background_fill_alpha = 0  # 凡例の背景を透過 （次章参照）
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="29a07b2c-7ac7-42c2-8e06-c0151da4adc7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("29a07b2c-7ac7-42c2-8e06-c0151da4adc7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("29a07b2c-7ac7-42c2-8e06-c0151da4adc7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '29a07b2c-7ac7-42c2-8e06-c0151da4adc7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d93fe9c0-88c9-4d23-a52b-16ebe6c438f5":{"roots":{"references":[{"attributes":{"data_source":{"id":"f8f2a0b2-4dcf-41c8-b6c3-ffebaf0cce11","type":"ColumnDataSource"},"glyph":{"id":"895f13fc-2d9b-477a-b20a-1f5d863800d9","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"b7322399-ac5b-43a5-ba84-55031c24849a","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"School","type":"Special"}],"color":["#00ad9c"],"fill_alpha":[0.8],"genre":["School"],"height":[2661425.0],"label":[{"genre":"School","type":"Special"}],"line_alpha":[1.0],"line_color":["white"],"type":["Special"],"width":[0.13932646701298945],"x":["School:0.428571428571"],"y":[1330712.5]}},"id":"15f1fcf3-102a-4a89-b4e0-ecdf2d563a0f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f919250e-ac9f-4ecd-8ac4-d03a9b3a3d99","type":"ColumnDataSource"},"glyph":{"id":"a8c5bf46-e5a9-422b-8269-699cddab38d7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"603860ae-b81b-47d1-9143-8572f1317638","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Romance","type":"Movie"}],"color":["#f22c40"],"fill_alpha":[0.8],"genre":["Romance"],"height":[5245386.0],"label":[{"genre":"Romance","type":"Movie"}],"line_alpha":[1.0],"line_color":["white"],"type":["Movie"],"width":[0.13932646701298945],"x":["Romance:0.285714285714"],"y":[2622693.0]}},"id":"a2030639-6f9d-4d23-baca-c0cf8a2604df","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Romance","type":"Special"}],"color":["#00ad9c"],"fill_alpha":[0.8],"genre":["Romance"],"height":[2015820.0],"label":[{"genre":"Romance","type":"Special"}],"line_alpha":[1.0],"line_color":["white"],"type":["Special"],"width":[0.13932646701298945],"x":["Romance:0.428571428571"],"y":[1007910.0]}},"id":"f518042b-2215-4aec-95dd-16cdedea9131","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"08f12b3a-b4fa-4012-9aee-4c5cd19d797d","type":"ColumnDataSource"},"glyph":{"id":"2d37f1bb-0d1c-422c-8bd2-11bbd54e1d1e","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"ff9aec08-d5a0-49f2-9112-b580aa68d2a7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Adventure","type":"Special"}],"color":["#00ad9c"],"fill_alpha":[0.8],"genre":["Adventure"],"height":[2052024.0],"label":[{"genre":"Adventure","type":"Special"}],"line_alpha":[1.0],"line_color":["white"],"type":["Special"],"width":[0.13932646701298945],"x":["Adventure:0.428571428571"],"y":[1026012.0]}},"id":"fea30746-9baa-41f0-8d79-78bdd2ca4e24","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"763bb18f-8a29-415b-bfed-8e73b2f2ec94","type":"Rect"},{"attributes":{"data_source":{"id":"d62010c2-4a0d-4bda-9fa4-fe5a792ef3ab","type":"ColumnDataSource"},"glyph":{"id":"5a06eff3-1869-4314-acdc-de4f1043d09f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a0847a9b-e861-435c-858a-8312c9ae9927","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fea30746-9baa-41f0-8d79-78bdd2ca4e24","type":"ColumnDataSource"},"glyph":{"id":"1449664b-53b6-4648-8259-a01fd9e65ccd","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"cd84724c-0ccf-49c3-9456-02da2bf0a800","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"69197d70-08c4-44b1-8874-7463a3ce8a4a","type":"ColumnDataSource"},"glyph":{"id":"ba053236 ...

# %%
# リスト6.6.7：積み上げ棒グラフ
p = Bar(
    top10_df.sort_values("type"),
    label="genre",
    values="members",
    stack="type",
    agg="sum",
    ylabel="メンバ数の合計",
    plot_width=600,
    plot_height=400,
    legend="top_right",
)
p.legend.padding = 0  # 凡例の中の余白を設定 （次章参照）
p.legend.background_fill_alpha = 0  # 凡例の背景を透過 （次章参照）
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="990f7daf-e381-4a50-bae2-e146beb31200"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("990f7daf-e381-4a50-bae2-e146beb31200");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("990f7daf-e381-4a50-bae2-e146beb31200");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '990f7daf-e381-4a50-bae2-e146beb31200' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5eaf38ba-b6b2-4b80-bf3f-0035cbd0383d":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"74485003-52f6-43e6-8e12-6b6990b1592a","type":"BoxAnnotation"},{"attributes":{"axis_label":"\u30e1\u30f3\u30d0\u6570\u306e\u5408\u8a08","formatter":{"id":"2a453919-0bd6-4900-a023-9f9212919de2","type":"BasicTickFormatter"},"plot":{"id":"e2ffa8da-8174-466c-9d3c-7aca03592e8a","subtype":"Chart","type":"Plot"},"ticker":{"id":"5a0d3c62-b84d-4f0b-ac39-b3e8e908ec87","type":"BasicTicker"}},"id":"0c23fd89-048f-40f9-affa-2eb1c13ec3fe","type":"LinearAxis"},{"attributes":{"data_source":{"id":"eedcbe5b-158f-4fad-8f62-bf281e807654","type":"ColumnDataSource"},"glyph":{"id":"3fa8ef69-28f2-4ace-ba8d-bfb7c3e89ca6","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"2c793b14-e98f-4066-bc7e-5caae4d349f4","type":"GlyphRenderer"},{"attributes":{},"id":"5a0d3c62-b84d-4f0b-ac39-b3e8e908ec87","type":"BasicTicker"},{"attributes":{"data_source":{"id":"2b9f83aa-abbf-4620-9989-7f76f532b4f7","type":"ColumnDataSource"},"glyph":{"id":"7bf00bb2-2c90-41bb-ba6c-98b3eaa4b579","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"1c966a38-760c-47d9-a68c-7a462d8544ad","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"84439d48-ec22-4f74-8a32-c5b15fe66f89","type":"ColumnDataSource"},"glyph":{"id":"03a43a73-a6a6-4ab8-9bd7-77039e4c724b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"dd46278f-c7d6-4c8c-a798-4ca4952bf820","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"e2ffa8da-8174-466c-9d3c-7aca03592e8a","subtype":"Chart","type":"Plot"},"ticker":{"id":"5a0d3c62-b84d-4f0b-ac39-b3e8e908ec87","type":"BasicTicker"}},"id":"52b6252f-9366-417b-bcb2-762f963efdea","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e17791ea-2df2-45ad-bef7-52e78a023d7c","type":"Rect"},{"attributes":{"background_fill_alpha":{"value":0},"items":[{"id":"7b4fd355-4d44-4310-8837-380a014046a0","type":"LegendItem"},{"id":"c8deea3b-a02d-4bd0-b20f-17fe6fa2d233","type":"LegendItem"},{"id":"2c27fed3-7fbe-4982-8c61-88c3fac30d1a","type":"LegendItem"},{"id":"6a2e85ab-7b49-4182-90d0-cc00a1a21df6","type":"LegendItem"},{"id":"cf902d39-b1d8-43d4-9b3b-b3a95ca065a5","type":"LegendItem"},{"id":"d1950124-d6aa-4efb-905e-3ab53cfb294a","type":"LegendItem"}],"padding":0,"plot":{"id":"e2ffa8da-8174-466c-9d3c-7aca03592e8a","subtype":"Chart","type":"Plot"}},"id":"3aa2bd48-0fd5-47a4-adaa-b315994affe5","type":"Legend"},{"attributes":{"data_source":{"id":"dec59aed-825d-4deb-978d-48543e32bf5a","type":"ColumnDataSource"},"glyph":{"id":"753862c3-0fc9-41de-ae4f-6b159b3dd40c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"5bc2ca71-89b7-4538-96d6-f768d522f166","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"bd7c940b-c519-439d-b74d-1c22df016b11","type":"ColumnDataSource"},"glyph":{"id":"d103b14b-47da-4e36-a053-751ff50b6c6f","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a3c80f30-c852-49bd-864f-e85f69cc1bed","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"genre":"Adventure","type":"OVA"}],"color":["#df5320"],"fill_alpha":[0.8],"genre":["Adventure"],"height":[2373765.0],"label":[{"genre":"Adventure","type":"OVA"}],"line_alpha":[1.0],"line_color":["white"],"type":["OVA"],"width":[0.8],"x":["Adventure"],"y":[10785365.5]}},"id":"7bc8413a-6220-43ab-9075-664df770822e","type":"ColumnDataSource"},{"attributes":{ ...

# %%
# リスト6.6.8：vbar()メソッドを使用した棒グラフ
from bokeh.plotting import figure

p = figure(plot_width=200, plot_height=200)
p.vbar(x=[1, 2, 3], top=[1, 2, 3], width=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d33377d6-a477-4eed-acc8-deca2aeac949"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d33377d6-a477-4eed-acc8-deca2aeac949");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d33377d6-a477-4eed-acc8-deca2aeac949");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd33377d6-a477-4eed-acc8-deca2aeac949' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"347d8b46-0986-49de-93e6-b4322baa6852":{"roots":{"references":[{"attributes":{},"id":"5cf2a2e2-b1e5-4eaf-82b4-70e2da4bd44f","type":"ToolEvents"},{"attributes":{"overlay":{"id":"606c68ea-bdf2-496c-b684-c8fb2aadeb8c","type":"BoxAnnotation"},"plot":{"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"}},"id":"ca248900-71df-4fba-a701-62c559d56410","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"}},"id":"fa6a58c3-809b-4180-8dd8-f51c10054f3e","type":"HelpTool"},{"attributes":{"below":[{"id":"8d594eaa-7309-496a-89ad-3da6ce707c49","type":"LinearAxis"}],"left":[{"id":"f30c0cc1-8b84-4623-91ff-53ba1e2477a5","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"8d594eaa-7309-496a-89ad-3da6ce707c49","type":"LinearAxis"},{"id":"081a106b-e82d-4503-ae02-5c2cfd181236","type":"Grid"},{"id":"f30c0cc1-8b84-4623-91ff-53ba1e2477a5","type":"LinearAxis"},{"id":"f301fbf3-c4c1-4e5d-89c4-28c2a8691a98","type":"Grid"},{"id":"606c68ea-bdf2-496c-b684-c8fb2aadeb8c","type":"BoxAnnotation"},{"id":"d9682321-5bd1-454c-af58-aba6e5f2913a","type":"GlyphRenderer"}],"title":{"id":"4d0e13f1-158c-4170-b211-beaf5403f106","type":"Title"},"tool_events":{"id":"5cf2a2e2-b1e5-4eaf-82b4-70e2da4bd44f","type":"ToolEvents"},"toolbar":{"id":"2082dd75-66d2-4228-b25f-525aeef5a040","type":"Toolbar"},"x_range":{"id":"9b6fb4ef-d02d-4243-b36d-ff273d4870f9","type":"DataRange1d"},"y_range":{"id":"194f9f1f-269c-4bb7-84a0-c40aa7816229","type":"DataRange1d"}},"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"},"ticker":{"id":"6ea1f9d3-24cc-4074-a3e2-15c89fea0e6d","type":"BasicTicker"}},"id":"f301fbf3-c4c1-4e5d-89c4-28c2a8691a98","type":"Grid"},{"attributes":{"plot":{"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"}},"id":"70105422-c5ea-4990-9469-fed4454d6bfb","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"194f9f1f-269c-4bb7-84a0-c40aa7816229","type":"DataRange1d"},{"attributes":{},"id":"51200d48-e9af-4d7e-8e63-f30f3a26971a","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"4d0e13f1-158c-4170-b211-beaf5403f106","type":"Title"},{"attributes":{},"id":"c7bc89b7-6ad8-4384-a3dc-8a7968812382","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":[1,2,3],"x":[1,2,3]}},"id":"83e20c86-b481-4b87-a177-ebe15c602f54","type":"ColumnDataSource"},{"attributes":{},"id":"aeebab65-ce2a-4c60-ae6b-799f432dac48","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"94aa4104-1710-4007-896b-59fe154d1d2a","type":"VBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.5},"x":{"field":"x"}},"id":"878e0022-9d12-40f0-b4c0-b5d9eed1e683","type":"VBar"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cd373f7a-2c2b-4901-8489-fab28b9f9b7e","type":"PanTool"},{"id":"70105422-c5ea-4990-9469-fed4454d6bfb","type":"WheelZoomTool"},{"id":"ca248900-71df-4fba-a701-62c559d56410","type":"BoxZoomTool"},{"id":"57a9e6e9-255e-4b4a-98cd-1b268e507b48","type":"SaveTool"},{"id":"eb0448f8-f4ee-4f40-88cf-56ee3cc7be12","type":"ResetTool"},{"id":"fa6a58c3-809b-4180-8dd8-f51c10054f3e","type":"HelpTool"}]},"id":"2082dd75-66d2-4228-b25f-525aeef5a040","type":"Toolbar"},{"attributes":{"plot":{"id":"e96ca052-cd0d-4014-8c17-1e848d2a4872","subtype":"Figure","type":"Plot"}},"id":"eb0448f8-f4ee-4f40-88cf-56ee3cc7be12","type":"ResetTool"},{"attributes":{"formatter":{"id":"aeebab65-ce2a-4c60-ae6b-799f432dac48","type":"BasicTickFormatter"},"plot":{"id":"e96ca052-cd0d-4014-8c17- ...

# %%
# リスト6.6.9：hbar()メソッドを使用した棒グラフ
p = figure(plot_width=200, plot_height=200)
p.hbar(y=[1, 2, 3], right=[1, 2, 3], height=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8f63ca6f-83f4-46e0-b579-acba832bc350"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8f63ca6f-83f4-46e0-b579-acba832bc350");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8f63ca6f-83f4-46e0-b579-acba832bc350");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8f63ca6f-83f4-46e0-b579-acba832bc350' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c8403d3f-a08a-4869-b375-31547aea5ff4":{"roots":{"references":[{"attributes":{"formatter":{"id":"eff10ae4-7766-4045-bcf9-d35c53a32ada","type":"BasicTickFormatter"},"plot":{"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"},"ticker":{"id":"d53d5878-7454-449f-9b8c-1e6c33cf3dbf","type":"BasicTicker"}},"id":"24e561bc-dbb2-4c82-9b81-7bbfde4dfafe","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"height":{"value":0.5},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"a2440414-d08d-4a7f-b0d5-ca72022f142d","type":"HBar"},{"attributes":{"formatter":{"id":"44a11b73-31b0-4761-9f38-643fae9496d0","type":"BasicTickFormatter"},"plot":{"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"},"ticker":{"id":"f1958ce0-25f0-4e81-aa63-37b48fab2433","type":"BasicTicker"}},"id":"46480f5d-6def-45e3-b5f3-10237c6f2ddf","type":"LinearAxis"},{"attributes":{"callback":null},"id":"9928ec5a-0bd1-4b28-ab45-474b5095a1a7","type":"DataRange1d"},{"attributes":{},"id":"eff10ae4-7766-4045-bcf9-d35c53a32ada","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"2c5a21fb-dad8-48f8-9c52-7a84f9d7a4a8","type":"ColumnDataSource"},"glyph":{"id":"a2440414-d08d-4a7f-b0d5-ca72022f142d","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4d424771-c7a5-461d-bf86-e0e6206e977a","type":"HBar"},"selection_glyph":null},"id":"b8e24286-151c-4706-aaf6-51f2032ebf0a","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"},"ticker":{"id":"d53d5878-7454-449f-9b8c-1e6c33cf3dbf","type":"BasicTicker"}},"id":"7c47e1ac-1c57-4ebc-bce2-9b1b734d7fc0","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e9cd75d4-716b-40e0-a920-ef5b4cf7efa0","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"}},"id":"49bab62f-3f39-410d-82d1-0271da83260e","type":"PanTool"},{"attributes":{},"id":"f1958ce0-25f0-4e81-aa63-37b48fab2433","type":"BasicTicker"},{"attributes":{"below":[{"id":"46480f5d-6def-45e3-b5f3-10237c6f2ddf","type":"LinearAxis"}],"left":[{"id":"24e561bc-dbb2-4c82-9b81-7bbfde4dfafe","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"46480f5d-6def-45e3-b5f3-10237c6f2ddf","type":"LinearAxis"},{"id":"976c31e6-e3a1-41c8-bd80-1ab0352a63a1","type":"Grid"},{"id":"24e561bc-dbb2-4c82-9b81-7bbfde4dfafe","type":"LinearAxis"},{"id":"7c47e1ac-1c57-4ebc-bce2-9b1b734d7fc0","type":"Grid"},{"id":"e9cd75d4-716b-40e0-a920-ef5b4cf7efa0","type":"BoxAnnotation"},{"id":"b8e24286-151c-4706-aaf6-51f2032ebf0a","type":"GlyphRenderer"}],"title":{"id":"b7e152b0-5a13-4fa1-ba65-5cd32f7baa31","type":"Title"},"tool_events":{"id":"7b18e561-89ae-472a-9005-66065f30ff6f","type":"ToolEvents"},"toolbar":{"id":"f6c5551b-a3f8-4f02-848d-012766b6a393","type":"Toolbar"},"x_range":{"id":"9928ec5a-0bd1-4b28-ab45-474b5095a1a7","type":"DataRange1d"},"y_range":{"id":"cdac9e08-05a8-41b6-a419-6b792bc2b23d","type":"DataRange1d"}},"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"f947d60e-e879-4209-b90e-57e750c4c429","subtype":"Figure","type":"Plot"}},"id":"737cd509-0630-4ca0-9350-d6eda6c275a1","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.5},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"4d424771-c7a5-461d-bf86-e0e6206e977a","type":"HBar"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[1,2,3],"y":[1,2,3]}},"id ...

# %%
# リスト6.6.10：書式を設定した棒グラフ
from bokeh.palettes import d3

# ジャンルをメンバ数で集計
genre = top10_df.groupby("genre")["members"].sum().sort_values()
p = figure(
    title="メンバ数が多いジャンルトップ10",
    plot_width=400,
    plot_height=400,
    x_range=(0, genre.max()),
    y_range=(-0.5, len(genre) - 0.5),
)
text_x = genre.min() * 0.1  # 注釈のX座標
colors = d3["Category20b"][10][::-1]  # カラーパレット(7章で解説)
# 枠、 罫線、 軸をすべて非表示
p.outline_line_color = None
p.grid.visible = False
p.axis.visible = False
for i, g in enumerate(genre):
    text = ": ".join((genre.index[i], "{:,}".format(g)))
    p.hbar(y=i, left=0, right=g, height=1, color=colors[i])
    p.text(
        x=text_x,
        y=i,
        text=[text],
        text_color="#ffffff",
        text_font_size="10pt",
        text_font_style="bold",
        text_baseline="middle",
    )
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="098be806-9e97-4475-a5bc-7dafcde752fc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("098be806-9e97-4475-a5bc-7dafcde752fc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("098be806-9e97-4475-a5bc-7dafcde752fc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '098be806-9e97-4475-a5bc-7dafcde752fc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7fa7a58d-1972-4cad-9d2b-03ae63afda59":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["Shounen: 47,782,772"]}},"id":"4e176c32-f93d-4763-9aab-042e97c78cfb","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#b5cf6b"},"height":{"value":1},"line_color":{"value":"#b5cf6b"},"right":{"value":47782772},"y":{"value":3}},"id":"bee022dc-da12-4bad-b9ea-422a6bdd12ff","type":"HBar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":47782772},"y":{"value":3}},"id":"8c3a4adc-785b-4a8a-a709-c99b0dbe3c1d","type":"HBar"},{"attributes":{"data_source":{"id":"d3ed733e-a18b-406a-b020-0ba4a7dcb76d","type":"ColumnDataSource"},"glyph":{"id":"bee022dc-da12-4bad-b9ea-422a6bdd12ff","type":"HBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8c3a4adc-785b-4a8a-a709-c99b0dbe3c1d","type":"HBar"},"selection_glyph":null},"id":"afa97a43-3516-4854-87af-bb463646767c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":49644915},"y":{"value":5}},"id":"b5789663-2c7d-4fe4-858e-45f357c299f2","type":"HBar"},{"attributes":{"plot":null,"text":"\u30e1\u30f3\u30d0\u6570\u304c\u591a\u3044\u30b8\u30e3\u30f3\u30eb\u30c8\u30c3\u30d710"},"id":"5f4ed5d3-f97f-4ba9-b137-96e537dc9e63","type":"Title"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"text_font_size":{"value":"10pt"},"text_font_style":"bold","x":{"value":4058455.5},"y":{"value":3}},"id":"8d3cf558-d25a-4c66-980a-8ba07a962a91","type":"Text"},{"attributes":{"callback":null,"data":{}},"id":"20b792f9-d138-4e9e-b0cf-66a920982b4c","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0807cabe-6ba7-411f-be18-7e4186474083","type":"PanTool"},{"id":"d7bb4f68-b8e4-4be1-930c-5367be5dfea1","type":"WheelZoomTool"},{"id":"6e10f06f-f1fd-40a7-afd7-36469aa04b59","type":"BoxZoomTool"},{"id":"cfe3b8d0-5d8d-4bc3-8228-2be2d99ee544","type":"SaveTool"},{"id":"ef04c542-fb6f-4fb6-9fa5-b217c2169eee","type":"ResetTool"},{"id":"f9ddfb0c-84a7-4577-9e60-2d8fcdacf054","type":"HelpTool"}]},"id":"f2f29da0-730b-4e82-8e44-f1faa1dedf04","type":"Toolbar"},{"attributes":{"text_baseline":"middle","text_color":{"value":"#ffffff"},"text_font_size":{"value":"10pt"},"text_font_style":"bold","x":{"value":4058455.5},"y":{"value":3}},"id":"3c7aa499-3673-4c6f-a00e-1e1c9e477401","type":"Text"},{"attributes":{"data_source":{"id":"4e176c32-f93d-4763-9aab-042e97c78cfb","type":"ColumnDataSource"},"glyph":{"id":"3c7aa499-3673-4c6f-a00e-1e1c9e477401","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8d3cf558-d25a-4c66-980a-8ba07a962a91","type":"Text"},"selection_glyph":null},"id":"89f0da44-9b30-449a-97ac-035960b086fb","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3fc60d16-678f-44e4-b954-cbcc7ce37d91","type":"ColumnDataSource"},"glyph":{"id":"abf10d04-4472-4266-aa63-c5781a0fd75b","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3d6adcf9-1186-4888-ab0b-ae90169789bb","type":"Text"},"selection_glyph":null},"id":"89bfeae7-bdd9-4699-aa97-58df89aac0a2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"value":48443223},"y":{"value":4}},"id":"31085cfe-4a51-497e-aaf3-350a6651db56","type":"HBar"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["Supernatural: 49,644,915"]}},"id":"0deb2e0d-0400-4358-9243-1623ad389a43","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#8ca252"},"height":{"value":1},"line_color":{"value":"#8ca252"},"right":{"value ...
