# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-3: 色の調整

# %%
# リスト7.3.1：カラーネームによる色の設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color="red")
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6a5122f4-3eec-4b89-a7e3-bf1e5c9ebc2a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d373f44a-97ea-4507-bb6b-e0eb66e80cf3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d373f44a-97ea-4507-bb6b-e0eb66e80cf3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d373f44a-97ea-4507-bb6b-e0eb66e80cf3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd373f44a-97ea-4507-bb6b-e0eb66e80cf3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cd527e0a-8b0d-4d3c-a97d-e655f8f98946":{"roots":{"references":[{"attributes":{"plot":{"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"}},"id":"d8daf05e-8774-43ec-8d54-afc2facf8bcc","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c5b3a881-1041-4260-82e6-368cb37f836e","type":"PanTool"},{"id":"56b86591-f4b5-47bc-899d-683689018ba9","type":"WheelZoomTool"},{"id":"d16b6b10-37c2-445e-8f4f-890856bed176","type":"BoxZoomTool"},{"id":"d8daf05e-8774-43ec-8d54-afc2facf8bcc","type":"SaveTool"},{"id":"f29e4efa-28d1-435d-ac64-1e4e8971662b","type":"ResetTool"},{"id":"d6cb60ae-081b-4436-b1a3-d7bc1be48945","type":"HelpTool"}]},"id":"46b12b5e-f010-447a-ab91-640d6c7a6b4e","type":"Toolbar"},{"attributes":{"data_source":{"id":"fa3e8b9a-6df3-410e-b020-3d82b2248a0a","type":"ColumnDataSource"},"glyph":{"id":"dc5035c1-4fa0-4c13-a76d-4930f8d4005f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5e3d9916-9f0d-4484-965c-4f908c3a758a","type":"Circle"},"selection_glyph":null},"id":"2e678f86-be2a-4e95-8d72-cbf916424483","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"1bd0bc13-6179-4d16-ad44-eb1083f43bbf","type":"DataRange1d"},{"attributes":{"plot":{"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"}},"id":"f29e4efa-28d1-435d-ac64-1e4e8971662b","type":"ResetTool"},{"attributes":{"below":[{"id":"506b11f3-0bc8-454e-a29b-1d23a05d6111","type":"LinearAxis"}],"left":[{"id":"13463539-c23c-4942-9445-a31e4bd2815a","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"506b11f3-0bc8-454e-a29b-1d23a05d6111","type":"LinearAxis"},{"id":"7c403a82-ae0d-4fc9-bc18-f193a045e257","type":"Grid"},{"id":"13463539-c23c-4942-9445-a31e4bd2815a","type":"LinearAxis"},{"id":"edea6e1d-8051-4cf8-8af5-5b1bb00f2dcf","type":"Grid"},{"id":"b9a2d53a-f671-4e45-a4b9-9744b778d1be","type":"BoxAnnotation"},{"id":"2e678f86-be2a-4e95-8d72-cbf916424483","type":"GlyphRenderer"}],"title":{"id":"4b3f9168-c374-47d8-9617-4a16079c8654","type":"Title"},"tool_events":{"id":"07532858-b155-4231-b32e-cba10eb37fd2","type":"ToolEvents"},"toolbar":{"id":"46b12b5e-f010-447a-ab91-640d6c7a6b4e","type":"Toolbar"},"x_range":{"id":"3b752de8-13d2-4560-875f-e0118938ad50","type":"DataRange1d"},"y_range":{"id":"1bd0bc13-6179-4d16-ad44-eb1083f43bbf","type":"DataRange1d"}},"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"0aac1365-3604-4639-9567-7d8df87c9d43","type":"BasicTickFormatter"},"plot":{"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"b898c801-3009-4b83-8787-8679cbc17a31","type":"BasicTicker"}},"id":"506b11f3-0bc8-454e-a29b-1d23a05d6111","type":"LinearAxis"},{"attributes":{},"id":"07532858-b155-4231-b32e-cba10eb37fd2","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc5035c1-4fa0-4c13-a76d-4930f8d4005f","type":"Circle"},{"attributes":{},"id":"b898c801-3009-4b83-8787-8679cbc17a31","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"fa3e8b9a-6df3-410e-b020-3d82b2248a0a","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"4b3f9168-c374-47d8-9617-4a16079c8654","type":"Title"},{"attributes":{"plot":{"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"b898c801-3009-4b83-8787-8679cbc17a31","type":"BasicTicker"}},"id":"7c403a82-ae0d-4fc9-bc18-f193a045e257","type":"Grid"},{"attributes":{"formatter":{"id":"6f7054af-16c4-4a15-9d06-c42d933c78ff","type":"BasicTickFormatter"},"plot":{"id":"71ed8b72-fa53-49d6-94da-f0d7b19e77ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"c1eab7c4-7ab2-4576-90bf-222427e73944","type":"BasicTicker"}},"id":"13463539-c23c-4942-9445-a31e4bd ...

# %%
# リスト7.3.2：16進数カラーコードによる色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color="#FF0000")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="62bff8c4-09b3-443b-8c8a-c42c18d9601f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("62bff8c4-09b3-443b-8c8a-c42c18d9601f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("62bff8c4-09b3-443b-8c8a-c42c18d9601f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '62bff8c4-09b3-443b-8c8a-c42c18d9601f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"65017fa5-9e98-4256-9fe7-07db9e75bb0a":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"70a13ee8-f2de-4019-b7b7-d6e171bfa165","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"63154289-2551-421d-8523-f5d491a4c274","type":"Circle"},{"attributes":{"formatter":{"id":"4c672097-752c-428c-8aca-63180c54751a","type":"BasicTickFormatter"},"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"},"ticker":{"id":"71de00ed-90a6-4b94-9f67-c9e5f71d8b4d","type":"BasicTicker"}},"id":"15fb9e52-3341-406b-ba4c-bd40978a2544","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"393f9b21-d3e5-40f6-9e2c-510e6f6ad875","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"e4d37bb5-f37e-4170-8ca1-62300468a485","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"c01db026-9b92-4d44-8f24-8d49b77c46dd","type":"HelpTool"},{"attributes":{"below":[{"id":"15fb9e52-3341-406b-ba4c-bd40978a2544","type":"LinearAxis"}],"left":[{"id":"4b674a10-40e3-4346-b5f9-8ee55e5b61c4","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"15fb9e52-3341-406b-ba4c-bd40978a2544","type":"LinearAxis"},{"id":"6df90598-d730-447e-956a-d3dfbfba3851","type":"Grid"},{"id":"4b674a10-40e3-4346-b5f9-8ee55e5b61c4","type":"LinearAxis"},{"id":"93d19bd5-7f77-4827-8d1b-31c92ff15913","type":"Grid"},{"id":"393f9b21-d3e5-40f6-9e2c-510e6f6ad875","type":"BoxAnnotation"},{"id":"104ebbe2-ee83-45eb-9da9-50efb0ad9477","type":"GlyphRenderer"}],"title":{"id":"70a13ee8-f2de-4019-b7b7-d6e171bfa165","type":"Title"},"tool_events":{"id":"23cd403b-f4b7-4132-86f9-40bf7a6e3ffc","type":"ToolEvents"},"toolbar":{"id":"da9db192-bced-494b-8a8b-97619c58420a","type":"Toolbar"},"x_range":{"id":"d7afad22-a6f3-4d81-b2aa-aad9c2a07a02","type":"DataRange1d"},"y_range":{"id":"b4b03999-ee63-4fc3-83bb-d4935fe75a45","type":"DataRange1d"}},"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"6ecf8809-7d95-4fae-98b4-db84fd703117","type":"ResetTool"},{"attributes":{"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"552e8e88-5b52-4520-9d93-4adb8054efce","type":"SaveTool"},{"attributes":{"overlay":{"id":"393f9b21-d3e5-40f6-9e2c-510e6f6ad875","type":"BoxAnnotation"},"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"7f0a40d1-906b-48b9-94e8-f4dbe6419c1a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"0f5ae556-4253-441b-89d0-b61b345f1636","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"e4d37bb5-f37e-4170-8ca1-62300468a485","type":"ColumnDataSource"},"glyph":{"id":"5e562edc-bbbb-45a7-b5ff-b6b085499fa0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"63154289-2551-421d-8523-f5d491a4c274","type":"Circle"},"selection_glyph":null},"id":"104ebbe2-ee83-45eb-9da9-50efb0ad9477","type":"GlyphRenderer"},{"attributes":{},"id":"d3e05697-8c31-41b1-86d1-5daf580aa9fb","type":"BasicTickFormatter"},{"attributes":{},"id":"ed2b37f4-434d-44d1-bbd0-0edc6b08bb00","type":"BasicTicker"},{"attributes":{"plot":{"id":"4ac229c9-1986-4375-801e-7ecc8c3b7ec8","subtype":"Figure","type":"Plot"}},"id":"07df98cf-938e-4069-bae5-92158f5e6 ...

# %%
# リスト7.3.3：RGBカラーコードによる色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color=(255, 0, 0))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4bb2739b-cea3-4add-91cc-732101edb685"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4bb2739b-cea3-4add-91cc-732101edb685");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4bb2739b-cea3-4add-91cc-732101edb685");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4bb2739b-cea3-4add-91cc-732101edb685' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f59ca993-d607-4e8d-a041-74804185cc46":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"805f263a-8837-4477-b41d-aa5c2ec94994","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca6cbfe7-f650-48ac-9217-9a537512d4af","type":"BasicTicker"}},"id":"18ea0542-671d-4d21-9d67-591a21509f6f","type":"Grid"},{"attributes":{"formatter":{"id":"f3da58f0-88f5-4f71-b20a-7d9ca9386098","type":"BasicTickFormatter"},"plot":{"id":"805f263a-8837-4477-b41d-aa5c2ec94994","subtype":"Figure","type":"Plot"},"ticker":{"id":"e4921b93-6b4b-4b85-896b-7470fb5daaf8","type":"BasicTicker"}},"id":"9f09110a-89c0-4dba-8ad2-3b95ca6b2ea4","type":"LinearAxis"},{"attributes":{"callback":null},"id":"26140895-5003-4620-b547-5da638d0d3a2","type":"DataRange1d"},{"attributes":{},"id":"f3da58f0-88f5-4f71-b20a-7d9ca9386098","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"4075def0-de53-4e68-a823-40f8a583e345","type":"ColumnDataSource"},"glyph":{"id":"e7bdb695-151d-4565-af42-bf543edb547c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bea10abe-1798-47be-84c8-e70686637fdb","type":"Circle"},"selection_glyph":null},"id":"a7266db7-c1f6-4955-ac80-12ed2874173f","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"7eaeadd7-0d28-4b98-adc1-b6685649e0fa","type":"BasicTickFormatter"},"plot":{"id":"805f263a-8837-4477-b41d-aa5c2ec94994","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca6cbfe7-f650-48ac-9217-9a537512d4af","type":"BasicTicker"}},"id":"5fc0fff0-ccbb-4b5e-9995-5860ae4c9a06","type":"LinearAxis"},{"attributes":{},"id":"ca6cbfe7-f650-48ac-9217-9a537512d4af","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"bea10abe-1798-47be-84c8-e70686637fdb","type":"Circle"},{"attributes":{"overlay":{"id":"06f27c6e-e706-4c93-858d-506b4139bf20","type":"BoxAnnotation"},"plot":{"id":"805f263a-8837-4477-b41d-aa5c2ec94994","subtype":"Figure","type":"Plot"}},"id":"81267dc6-8b02-4894-9e5b-110676675756","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"06f27c6e-e706-4c93-858d-506b4139bf20","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"4075def0-de53-4e68-a823-40f8a583e345","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"805f263a-8837-4477-b41d-aa5c2ec94994","subtype":"Figure","type":"Plot"}},"id":"8f97eedb-63cc-4455-b1b7-261571621c87","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"a509e43a-2278-4c8a-b2a4-63f64e94d3c0","type":"DataRange1d"},{"attributes":{},"id":"7eaeadd7-0d28-4b98-adc1-b6685649e0fa","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"9f09110a-89c0-4dba-8ad2-3b95ca6b2ea4","type":"LinearAxis"}],"left":[{"id":"5fc0fff0-ccbb-4b5e-9995-5860ae4c9a06","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"9f09110a-89c0-4dba-8ad2-3b95ca6b2ea4","type":"LinearAxis"},{"id":"8248726c-690b-4759-9988-d9d47722594c","type":"Grid"},{"id":"5fc0fff0-ccbb-4b5e-9995-5860ae4c9a06","type":"LinearAxis"},{"id":"18ea0542-671d-4d21-9d67-591a21509f6f","type":"Grid"},{"id":"06f27c6e-e706-4c93-858d-506b4139bf20","type":"BoxAnnotation"},{"id":"a7266db7-c1f6-4955-ac80-12ed2874173f","type":"GlyphRenderer"}],"title":{"id":"b9690958-8674-4e06-bb35-326f74011c30","type":"Title"},"tool_events":{"id":"7939787b-ece0-4e0b-8270-7290643e764f","type":"ToolEvents"},"toolbar":{"id":"5fbad27c-32c5-40d1-afd3-3f662497eb54","type":"Toolbar"},"x_range":{"id":"26140895-5003-4620-b547-5da638d0d3a2","type":"DataRange1d"},"y_range":{"id":"a509e43a ...

# %%
# リスト7.3.4：オブジェクトの不透明度を設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 0.5, 1], [0, 0, 0], size=30, color=(0, 0, 255))
p.circle([0.25, 0.75], [0, 0], size=50, color=(255, 0, 0, 0.5))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d2e401a9-8d50-4a7a-b0ef-5d0c32481cd7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d2e401a9-8d50-4a7a-b0ef-5d0c32481cd7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d2e401a9-8d50-4a7a-b0ef-5d0c32481cd7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd2e401a9-8d50-4a7a-b0ef-5d0c32481cd7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6684b59a-eca1-4dcf-b013-6abe0d757f81":{"roots":{"references":[{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"14886410-6d70-4a59-8a30-278178c3ea42","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"3502d365-f601-4454-82fa-67bdb7c867cf","type":"SaveTool"},{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"},"ticker":{"id":"732ce591-c018-4a4b-8d69-54698a28febe","type":"BasicTicker"}},"id":"ea4bb7ca-615e-48e0-a180-803830b5fbd1","type":"Grid"},{"attributes":{"overlay":{"id":"c06a8564-2481-4159-a981-830ebc3ccc23","type":"BoxAnnotation"},"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"a9852726-f616-4eb8-b27a-873a0fc4fdca","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"268eec4e-38fd-4eb3-a0cd-478d9e413aab","type":"ColumnDataSource"},"glyph":{"id":"ee1188a1-2188-40de-972c-104aea4e851e","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8cd36cc3-5e29-4e7d-9530-e5d50e9d5558","type":"Circle"},"selection_glyph":null},"id":"b33e50b7-6393-4d13-8b65-de922cd9670f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"823d7c5e-d4be-42d4-ae77-dd762f90e4f9","type":"HelpTool"},{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"058c7279-1d88-4c84-ab15-b29c1c42a85e","type":"PanTool"},{"attributes":{"fill_color":{"value":"rgb(0, 0, 255)"},"line_color":{"value":"rgb(0, 0, 255)"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd66a811-8724-49f3-b099-1192b0cd71ad","type":"Circle"},{"attributes":{"fill_color":{"value":"rgba(255, 0, 0, 0.5)"},"line_color":{"value":"rgba(255, 0, 0, 0.5)"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee1188a1-2188-40de-972c-104aea4e851e","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,0.5,1],"y":[0,0,0]}},"id":"22395749-3390-49af-b5a5-1e5f8a8e1d38","type":"ColumnDataSource"},{"attributes":{},"id":"732ce591-c018-4a4b-8d69-54698a28febe","type":"BasicTicker"},{"attributes":{},"id":"22d8ddf4-4662-49b9-9a69-39ce0fa94ac0","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"8a64e1a4-4acf-4c5c-8563-5346e13e1577","type":"BasicTickFormatter"},"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"},"ticker":{"id":"732ce591-c018-4a4b-8d69-54698a28febe","type":"BasicTicker"}},"id":"a4263e05-4656-4316-a516-7178a1398cb7","type":"LinearAxis"},{"attributes":{"data_source":{"id":"22395749-3390-49af-b5a5-1e5f8a8e1d38","type":"ColumnDataSource"},"glyph":{"id":"dd66a811-8724-49f3-b099-1192b0cd71ad","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5d2e6b66-519a-44dc-9872-e3c3da48b683","type":"Circle"},"selection_glyph":null},"id":"7962d40b-1072-4bcd-adb9-a37f7b3bc3a4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.25,0.75],"y":[0,0]}},"id":"268eec4e-38fd-4eb3-a0cd-478d9e413aab","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"8cd36cc3-5e29-4e7d-9530-e5d50e9d5558","type":"Circle"},{"attributes":{"callback":null},"id":"65392f1a-6906-4847-8a43-7217f520d1e0","type":"DataRange1d"},{"attributes":{"plot":{"id":"0e4e2dfc-76bd-4597-86fe-cb7c5578f7df","subtype":"Figure","type":"Plot"}},"id":"6ba6ac0a-723c-4888-85c7-b80d66577491","type":"ResetTool"},{"attributes":{},"id":"ca81d648-fa90-40bc-b67f-ed5d03beefb8","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"}," ...

# %%
# リスト7.3.5：alphaによる透過設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 0.5, 1], [0, 0, 0], size=30, color="blue")
p.circle([0.25, 0.75], [0, 0], size=50, color="red", alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f1f061be-7dd6-4dcf-8626-ac45ba8026ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f1f061be-7dd6-4dcf-8626-ac45ba8026ed");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1f061be-7dd6-4dcf-8626-ac45ba8026ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1f061be-7dd6-4dcf-8626-ac45ba8026ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ad54620-58f8-4b7b-89f5-07ed828480a6":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"0895c6ce-21df-475d-be31-70e78e60fc6e","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"26f7b4a9-4d02-49f9-9c2e-01a6517eb6a2","type":"Circle"},{"attributes":{},"id":"949f5c05-1755-4bc9-89de-a0367a658858","type":"ToolEvents"},{"attributes":{"callback":null},"id":"2cfe843c-b697-4a19-afe3-1cae5457cf2c","type":"DataRange1d"},{"attributes":{},"id":"8043a580-2e69-450b-acec-4ae4d3b07c88","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"9e7573b9-4d4e-494e-b998-e344554a6e24","type":"BoxAnnotation"},"plot":{"id":"63d20942-b6ce-40a3-abc7-1757bf2a5c5b","subtype":"Figure","type":"Plot"}},"id":"9685a9b2-41b4-4f9e-9759-c62f54de7dfd","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,0.5,1],"y":[0,0,0]}},"id":"cdabe63c-ea74-407a-a609-df29af336324","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"63d20942-b6ce-40a3-abc7-1757bf2a5c5b","subtype":"Figure","type":"Plot"}},"id":"84b72ca7-c437-4768-86cc-39902a1d51dc","type":"SaveTool"},{"attributes":{"below":[{"id":"ea9b479d-4f13-4d02-a108-f9199f66a78b","type":"LinearAxis"}],"left":[{"id":"43562fc3-e016-461f-af60-c8f10ffff161","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"ea9b479d-4f13-4d02-a108-f9199f66a78b","type":"LinearAxis"},{"id":"30e693de-8dab-459b-9305-21861e9900b4","type":"Grid"},{"id":"43562fc3-e016-461f-af60-c8f10ffff161","type":"LinearAxis"},{"id":"d48ef412-26b2-4ef5-8f3c-08b1929acdc8","type":"Grid"},{"id":"9e7573b9-4d4e-494e-b998-e344554a6e24","type":"BoxAnnotation"},{"id":"1451227e-8eae-4267-8b43-c1c9e46a668e","type":"GlyphRenderer"},{"id":"8e86c74e-0585-4e2f-8981-c891aae510be","type":"GlyphRenderer"}],"title":{"id":"70a5bc36-e276-4a0d-a235-259051e90a3b","type":"Title"},"tool_events":{"id":"949f5c05-1755-4bc9-89de-a0367a658858","type":"ToolEvents"},"toolbar":{"id":"649216bc-23b8-4a59-8773-aaa4f8337d24","type":"Toolbar"},"x_range":{"id":"571b3fc5-df24-426d-922a-1c684733e462","type":"DataRange1d"},"y_range":{"id":"2cfe843c-b697-4a19-afe3-1cae5457cf2c","type":"DataRange1d"}},"id":"63d20942-b6ce-40a3-abc7-1757bf2a5c5b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"63d20942-b6ce-40a3-abc7-1757bf2a5c5b","subtype":"Figure","type":"Plot"}},"id":"b6453658-8283-45f3-8575-22e03e546974","type":"ResetTool"},{"attributes":{"data_source":{"id":"f44f3fb1-aad8-4a8b-9fd1-08060254fa88","type":"ColumnDataSource"},"glyph":{"id":"0895c6ce-21df-475d-be31-70e78e60fc6e","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"26f7b4a9-4d02-49f9-9c2e-01a6517eb6a2","type":"Circle"},"selection_glyph":null},"id":"8e86c74e-0585-4e2f-8981-c891aae510be","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"63d20942-b6ce-40a3-abc7-1757bf2a5c5b","subtype":"Figure","type":"Plot"},"ticker":{"id":"e09a97b7-1c8d-47c4-920c-c714307404ae","type":"BasicTicker"}},"id":"d48ef412-26b2-4ef5-8f3c-08b1929acdc8","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e81505a8-1827-4a7c-b2e0-47866784f414","type":"PanTool"},{"id":"5407fd8f-7142-4bd6-b8c6-cd7a12bd151e","type":"WheelZoomTool"},{"id":"9685a9b2-41b4-4f9e-9759-c62f54de7dfd","type":"BoxZoomTool"},{"id":"84b72ca7-c437-4768-86cc-39902a1d51dc","type":"SaveTool"},{"id":"b6453658-8283-45f3-8575-22e03e546974","type":"ResetTool"},{"id":"c9105d79-583b-4d54-9d97-bebf2ad4d787","type":"HelpTool"}]},"id":"649216bc-23b8-4a59-8773-aaa4f8337d24","type":"Toolbar"},{"attributes":{"plot":{"id":"63d20942-b6ce-40a3-abc7-1757 ...

# %%
# リスト7.3.6：fill_colorを設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, fill_color="red", line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="60b11120-4fc5-4499-8a29-f4ba1736db79"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("60b11120-4fc5-4499-8a29-f4ba1736db79");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("60b11120-4fc5-4499-8a29-f4ba1736db79");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '60b11120-4fc5-4499-8a29-f4ba1736db79' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9348a229-5d24-4d63-a13c-df474f082af5":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"65846ac1-9941-4f86-bf74-9274dc33e150","type":"PanTool"},{"id":"ba955fc5-9ace-4872-b4d6-ad7d87c19ef6","type":"WheelZoomTool"},{"id":"2d0bc7b3-568b-488d-a85b-a5c396dd7543","type":"BoxZoomTool"},{"id":"ada4807d-e1e2-4459-b978-13a4785edfc6","type":"SaveTool"},{"id":"4613cf1b-b395-4367-9334-1c5a5edd9e67","type":"ResetTool"},{"id":"aaf286e4-7d40-4335-96bb-660d9719efa3","type":"HelpTool"}]},"id":"940fb38c-a4c7-4b04-8738-bd03087347bb","type":"Toolbar"},{"attributes":{"overlay":{"id":"09cf25a0-b91a-41a2-80c2-20bc7d055e51","type":"BoxAnnotation"},"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"}},"id":"2d0bc7b3-568b-488d-a85b-a5c396dd7543","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"ccb7fd21-87ad-4ebf-86ab-896fa4eeea52","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"78bdeda7-2fc3-401f-870b-61a43c0c2037","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ae22306-4a14-429b-aff1-f81ca381f459","type":"BasicTicker"}},"id":"a8a665b4-a057-449e-9bad-a462e2126483","type":"Grid"},{"attributes":{"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"},"ticker":{"id":"5d2a01d0-6151-4457-8e13-de2567a084b5","type":"BasicTicker"}},"id":"bd71c0a8-02cb-4e2d-8dd8-c99dd6d26e90","type":"Grid"},{"attributes":{"formatter":{"id":"24b489ce-2edf-49a4-82aa-3ea74560e2a4","type":"BasicTickFormatter"},"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"},"ticker":{"id":"4ae22306-4a14-429b-aff1-f81ca381f459","type":"BasicTicker"}},"id":"504aa694-b867-4df6-82d8-65324865b2bf","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"2d931d61-62d5-472f-87ff-b7831d236f98","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"09cf25a0-b91a-41a2-80c2-20bc7d055e51","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"d5c9a741-e5e2-4e5f-b29f-9d44a8989d8c","type":"LinearAxis"}],"left":[{"id":"504aa694-b867-4df6-82d8-65324865b2bf","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"d5c9a741-e5e2-4e5f-b29f-9d44a8989d8c","type":"LinearAxis"},{"id":"bd71c0a8-02cb-4e2d-8dd8-c99dd6d26e90","type":"Grid"},{"id":"504aa694-b867-4df6-82d8-65324865b2bf","type":"LinearAxis"},{"id":"a8a665b4-a057-449e-9bad-a462e2126483","type":"Grid"},{"id":"09cf25a0-b91a-41a2-80c2-20bc7d055e51","type":"BoxAnnotation"},{"id":"020cfb46-b6b2-4952-92bd-b909b59147ba","type":"GlyphRenderer"}],"title":{"id":"ccb7fd21-87ad-4ebf-86ab-896fa4eeea52","type":"Title"},"tool_events":{"id":"8ef0ccf1-cfa5-461a-b48a-0f5a902e7913","type":"ToolEvents"},"toolbar":{"id":"940fb38c-a4c7-4b04-8738-bd03087347bb","type":"Toolbar"},"x_range":{"id":"1fa772ef-c45a-4f0d-b458-b08681cab3b1","type":"DataRange1d"},"y_range":{"id":"ce157fdc-a4ab-4fe5-a364-0d4f47c51e14","type":"DataRange1d"}},"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3358791e30","subtype":"Figure","type":"Plot"}},"id":"ada4807d-e1e2-4459-b978-13a4785edfc6","type":"SaveTool"},{"attributes":{"formatter":{"id":"49c8a07c-c49e-43ca-8864-87c73205c3d9","type":"BasicTickFormatter"},"plot":{"id":"433adc68-b8f5-4a6c-b469-3c3 ...

# %%
# リスト7.3.7：line_colorを設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, fill_color="red", line_color="black", line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d22ded77-9b5a-41ba-af5f-3613ddaef16f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d22ded77-9b5a-41ba-af5f-3613ddaef16f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d22ded77-9b5a-41ba-af5f-3613ddaef16f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd22ded77-9b5a-41ba-af5f-3613ddaef16f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e855d281-69a9-4552-9e7e-6b1acd731821":{"roots":{"references":[{"attributes":{"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"}},"id":"4eec3973-8c6d-4da6-8e0c-4c311d3797b1","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"7b9a808b-e43c-4894-a0ed-b45b1fcbb090","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"a1b006e0-5de2-4e9e-a13f-3cd18a630de6","type":"LinearAxis"}],"left":[{"id":"a0bc2ee3-a9b2-44a3-90d8-87a7e5d3d135","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"a1b006e0-5de2-4e9e-a13f-3cd18a630de6","type":"LinearAxis"},{"id":"ec44feae-ad7a-4b09-a0f7-d41cf23a76a7","type":"Grid"},{"id":"a0bc2ee3-a9b2-44a3-90d8-87a7e5d3d135","type":"LinearAxis"},{"id":"84158e5f-e5d2-453b-9c2c-b171766d0c85","type":"Grid"},{"id":"4d005a4a-ba5a-4ff5-b12b-30e6c35ea1a3","type":"BoxAnnotation"},{"id":"48381934-16b3-499f-aea5-8313afded44a","type":"GlyphRenderer"}],"title":{"id":"0edb15b8-04c9-4800-a5af-eb8022911567","type":"Title"},"tool_events":{"id":"c7e4d058-bc57-4fb1-88bd-a5e5115a47b8","type":"ToolEvents"},"toolbar":{"id":"3b60309d-8a62-4c5d-a443-4570e73f82f7","type":"Toolbar"},"x_range":{"id":"c1ddc6d8-8415-4e1a-bf23-e11d16046d13","type":"DataRange1d"},"y_range":{"id":"4fca589c-0619-4bc0-9bc7-3e5aba6f0018","type":"DataRange1d"}},"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"0edb15b8-04c9-4800-a5af-eb8022911567","type":"Title"},{"attributes":{"overlay":{"id":"4d005a4a-ba5a-4ff5-b12b-30e6c35ea1a3","type":"BoxAnnotation"},"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"}},"id":"8fc4cee5-ac82-4f95-b8a0-c63333f64bd2","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"4fca589c-0619-4bc0-9bc7-3e5aba6f0018","type":"DataRange1d"},{"attributes":{"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"}},"id":"6284da3e-26b6-4efb-b3af-b5b4e7cfdd4d","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"0055cba9-20c5-417e-a3d8-63a3bff576e7","type":"BasicTicker"}},"id":"84158e5f-e5d2-453b-9c2c-b171766d0c85","type":"Grid"},{"attributes":{"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"}},"id":"8f03ea78-746f-45f6-8cc0-b25d049d80e6","type":"ResetTool"},{"attributes":{"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"}},"id":"9f9089d7-49c6-4afa-b0d3-e026d25386a6","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"08836a23-715a-4413-a8af-001f2978617d","type":"Circle"},{"attributes":{"formatter":{"id":"c0a5f12b-e8f8-4e43-a598-0d6278e3ef50","type":"BasicTickFormatter"},"plot":{"id":"76a2728a-d19e-4a7b-b849-5d7d228db7c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"94a6fcc7-b8a8-491e-bf7c-16534d136be7","type":"BasicTicker"}},"id":"a1b006e0-5de2-4e9e-a13f-3cd18a630de6","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"950e91c8-6dfc-4855-b4a6-372bb33819b6","type":"PanTool"},{"id":"4eec3973-8c6d-4da6-8e0c-4c311d3797b1","type":"WheelZoomTool"},{"id":"8fc4cee5-ac82-4f95-b8a0-c63333f64bd2","type":"BoxZoomTool"},{"id":"6284da3e-26b6-4efb-b3af-b5b4e7cfdd4d","type":"SaveTool"},{"id":"8f03ea78-746f-45f6-8cc0-b25d049d80e6","type":"ResetTool"},{"id":"9f9089d7-49c6-4afa-b0d3-e026d25386a6","type":"HelpTool"}]},"id":"3b60309d-8a62-4c5d-a443-4570e73f82f7","type":"Toolbar"},{"attributes":{},"id":"c0a5f12b-e8f8-4e43-a598-0d6278e3ef50","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"97f5296e-5750-4ce8-8520-d406b59ed25e","type ...

# %%
# リスト7.3.8：Blues6を指定してインポート
from bokeh.palettes import Blues6

Blues6
# Out:
# ['#08519c', '#3182bd', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff']

# %%
# リスト7.3.10：Bluesを指定してインポート
from bokeh.palettes import Blues

Blues
# Out:
# {3: ['#3182bd', '#9ecae1', '#deebf7'],
#  4: ['#2171b5', '#6baed6', '#bdd7e7', '#eff3ff'],
#  5: ['#08519c', '#3182bd', '#6baed6', '#bdd7e7', '#eff3ff'],
#  6: ['#08519c', '#3182bd', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff'],
#  7: ['#084594',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#eff3ff'],
#  8: ['#084594',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#deebf7',
#   '#f7fbff'],
#  9: ['#08306b',
#   '#08519c',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#deebf7',
#   '#f7fbff']}

# %%
# リスト7.3.12：Blues6による着色
p = figure(plot_width=200, plot_height=200, x_range=(0, 2), y_range=(-0.5, 5.5))
for i, color in enumerate(Blues6):
    p.square(0.5, i, color=color, size=20)
    p.text(1, i, text=[color], text_baseline="middle")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8bafa609-6691-4d3a-8a4b-9dc3726c4b4e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8bafa609-6691-4d3a-8a4b-9dc3726c4b4e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8bafa609-6691-4d3a-8a4b-9dc3726c4b4e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8bafa609-6691-4d3a-8a4b-9dc3726c4b4e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ddda74a8-63f7-430e-b556-4a116d1dc201":{"roots":{"references":[{"attributes":{"text_baseline":"middle","text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"d9af6041-cae4-4ae3-bd15-29e4dfe90536","type":"Text"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"b78375f5-b8bf-4be7-8316-6d4c8ca60a1e","type":"Text"},{"attributes":{"data_source":{"id":"134667be-a5fa-4d4d-a418-5c5868e67639","type":"ColumnDataSource"},"glyph":{"id":"d9af6041-cae4-4ae3-bd15-29e4dfe90536","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b78375f5-b8bf-4be7-8316-6d4c8ca60a1e","type":"Text"},"selection_glyph":null},"id":"3d379506-4124-4d03-a8c7-631d865656e6","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3c6538e0-54df-4aa0-bc72-8473bfdea193","type":"ColumnDataSource"},"glyph":{"id":"87d00440-f1a1-4081-b1b0-320a045b9a3d","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"32d76fdd-e7e0-4e46-ba5f-fd498b968339","type":"Text"},"selection_glyph":null},"id":"d22b9470-1a1e-419d-97c4-b722a8ee14b3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":3}},"id":"c0a8ed3b-f28c-4a83-8aa3-9cd3dc097727","type":"Square"},{"attributes":{"callback":null,"data":{}},"id":"555d8774-bc14-400c-a967-004f8c95c309","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#9ecae1"},"line_color":{"value":"#9ecae1"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":3}},"id":"5cc42292-4073-4da4-8b5a-f33416238d78","type":"Square"},{"attributes":{"data_source":{"id":"555d8774-bc14-400c-a967-004f8c95c309","type":"ColumnDataSource"},"glyph":{"id":"5cc42292-4073-4da4-8b5a-f33416238d78","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c0a8ed3b-f28c-4a83-8aa3-9cd3dc097727","type":"Square"},"selection_glyph":null},"id":"06b2fbb6-58b3-486f-9b7a-03c73595f4bc","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"value":1},"y":{"value":3}},"id":"2dc1f73e-a2c3-4694-8a89-a02e512690bb","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["#9ecae1"]}},"id":"bf47350a-4be2-4250-b192-090d46036a52","type":"ColumnDataSource"},{"attributes":{"text_baseline":"middle","text_color":{"value":"black"},"x":{"value":1},"y":{"value":3}},"id":"6c77d1ee-f3a5-4d58-bebc-dc0e337198ad","type":"Text"},{"attributes":{"data_source":{"id":"bf47350a-4be2-4250-b192-090d46036a52","type":"ColumnDataSource"},"glyph":{"id":"6c77d1ee-f3a5-4d58-bebc-dc0e337198ad","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2dc1f73e-a2c3-4694-8a89-a02e512690bb","type":"Text"},"selection_glyph":null},"id":"3ddb9944-84be-479b-b701-442701887851","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{}},"id":"0d2ca24d-b635-46a9-98fb-626b4b3cc528","type":"ColumnDataSource"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"value":1},"y":{"value":4}},"id":"32d76fdd-e7e0-4e46-ba5f-fd498b968339","type":"Text"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":5}},"id":"cba83d7a-9b5e-4371-8af6-b8870ccd2a4f","type":"Square"},{"attributes":{"fill_color":{"value":"#eff3ff"},"line_color":{"value":"#eff3ff"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":5}},"id":"dc3df47d-2f31-495c-be9b-0f350a393857","type":"Square"},{"attributes":{"data_source":{"id":"0d2ca24d-b635-46a9-98fb-626b4b3cc528","type":"ColumnDataSource"},"glyph":{"id":"dc3df47d-2f31-495c-be9b-0f3 ...
