# %%
# リスト7.3.1：カラーネームによる色の設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color='red')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37a678d9-71e0-463a-9521-45603975710d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dc9d5a1f-9a66-4558-adb1-a7c8b71f8372"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dc9d5a1f-9a66-4558-adb1-a7c8b71f8372");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dc9d5a1f-9a66-4558-adb1-a7c8b71f8372");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dc9d5a1f-9a66-4558-adb1-a7c8b71f8372' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"754e9d51-6e3d-43d7-adbc-c3e17f588773":{"roots":{"references":[{"attributes":{"overlay":{"id":"673e0ae1-b5df-4667-a397-39d8fe5aec88","type":"BoxAnnotation"},"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"}},"id":"4e303592-0e27-46a1-ad8b-c431622abf97","type":"BoxZoomTool"},{"attributes":{},"id":"dc335c4e-ff72-44bb-82be-f22a04626bca","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"}},"id":"c398d3eb-1a0c-49b7-aa85-d44909634f16","type":"SaveTool"},{"attributes":{"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"}},"id":"2e6d0836-2ac3-4f20-9e8d-cea622b81739","type":"ResetTool"},{"attributes":{"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"}},"id":"719e93f8-d530-4fd7-992c-3560773359ef","type":"HelpTool"},{"attributes":{"callback":null},"id":"d2675ff5-1388-4715-8907-c3d5eef66da0","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"676aaefd-a220-4906-8e19-c2793c35d2ed","type":"PanTool"},{"id":"205b0132-f756-4f4e-8559-91cb6c6d303f","type":"WheelZoomTool"},{"id":"4e303592-0e27-46a1-ad8b-c431622abf97","type":"BoxZoomTool"},{"id":"c398d3eb-1a0c-49b7-aa85-d44909634f16","type":"SaveTool"},{"id":"2e6d0836-2ac3-4f20-9e8d-cea622b81739","type":"ResetTool"},{"id":"719e93f8-d530-4fd7-992c-3560773359ef","type":"HelpTool"}]},"id":"c18ce893-e3b7-47dd-8783-286c5d246ad7","type":"Toolbar"},{"attributes":{"formatter":{"id":"a427a325-eba3-4ef6-9627-22a0b7744240","type":"BasicTickFormatter"},"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"},"ticker":{"id":"02a5ff3f-0bdd-407c-82a1-3428c49164ac","type":"BasicTicker"}},"id":"1ff1a4f1-8ce8-4fe0-a8dd-fd84761c446d","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"ecc16072-2c67-4798-b730-1e89fc7f38af","type":"Title"},{"attributes":{},"id":"02a5ff3f-0bdd-407c-82a1-3428c49164ac","type":"BasicTicker"},{"attributes":{"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"},"ticker":{"id":"02a5ff3f-0bdd-407c-82a1-3428c49164ac","type":"BasicTicker"}},"id":"0e6aca35-74e3-4d27-86f7-15c91646acfa","type":"Grid"},{"attributes":{},"id":"ddf86f05-615a-427c-b5a3-8c1d153688c9","type":"ToolEvents"},{"attributes":{"formatter":{"id":"dc335c4e-ff72-44bb-82be-f22a04626bca","type":"BasicTickFormatter"},"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e431f14-9284-446a-b168-dee2876fdc64","type":"BasicTicker"}},"id":"9911792a-eed8-4f04-b54d-7c0a3fe59d68","type":"LinearAxis"},{"attributes":{},"id":"5e431f14-9284-446a-b168-dee2876fdc64","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"b43de5d5-b700-482c-a503-e67394754130","subtype":"Figure","type":"Plot"},"ticker":{"id":"5e431f14-9284-446a-b168-dee2876fdc64","type":"BasicTicker"}},"id":"673e11cd-e448-4a1b-ac85-0bdba8e34994","type":"Grid"},{"attributes":{"data_source":{"id":"c9b7af6e-10bc-4006-b28b-8a179a9ea162","type":"ColumnDataSource"},"glyph":{"id":"6655032d-44b2-466a-9582-4b96ac1ba5ad","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a827f5a8-fe24-4bec-a193-9619d7bd0dfb","type":"Circle"},"selection_glyph":null},"id":"d5ca1f41-ee21-479a-8e5e-4c1459422d01","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"673e0ae1-b5df-4667-a397-39d8fe5aec88","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30 ...

# %%
# リスト7.3.2：16進数カラーコードによる色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color='#FF0000')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e0c7eae9-cdec-4b8f-82f6-542c7e283e54"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e0c7eae9-cdec-4b8f-82f6-542c7e283e54");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e0c7eae9-cdec-4b8f-82f6-542c7e283e54");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e0c7eae9-cdec-4b8f-82f6-542c7e283e54' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c8b9c2d2-9e90-4faf-b2aa-e0109e5024b3":{"roots":{"references":[{"attributes":{"plot":{"id":"09fcedfd-aef8-4097-96a7-ee7309e78496","subtype":"Figure","type":"Plot"}},"id":"22d0f09d-1936-4620-8fb9-9c83fb26b63c","type":"PanTool"},{"attributes":{},"id":"0a21c0c6-2d8f-4882-ba3c-a812550ac6a7","type":"BasicTickFormatter"},{"attributes":{},"id":"9439fe45-4750-40e9-b9a0-2c09cf7a9b38","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"abb90969-b41c-4086-992c-43206aebd354","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"4e78f42b-625b-414b-ab18-75a69553b77f","type":"ColumnDataSource"},"glyph":{"id":"367fc6b7-144b-4867-b344-4822aa792774","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b269a5e8-acce-4206-bb82-9b756b01f9cc","type":"Circle"},"selection_glyph":null},"id":"30b7946d-500f-4c6a-aef4-e23b005065de","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"22d0f09d-1936-4620-8fb9-9c83fb26b63c","type":"PanTool"},{"id":"6ae54beb-c5cc-4ebf-8960-e004bb4baee8","type":"WheelZoomTool"},{"id":"c960b29d-056a-49f8-98ad-90d82d0716dc","type":"BoxZoomTool"},{"id":"d62e057f-47ea-4837-873e-335732cfd4ca","type":"SaveTool"},{"id":"e8ba29f5-f564-4970-ab2c-19dd22cbe15f","type":"ResetTool"},{"id":"58f41c7c-dc3b-4676-8e13-3a41fa442867","type":"HelpTool"}]},"id":"a35a78ac-218a-412b-9262-0697f3884fd3","type":"Toolbar"},{"attributes":{"plot":{"id":"09fcedfd-aef8-4097-96a7-ee7309e78496","subtype":"Figure","type":"Plot"}},"id":"58f41c7c-dc3b-4676-8e13-3a41fa442867","type":"HelpTool"},{"attributes":{"formatter":{"id":"0a21c0c6-2d8f-4882-ba3c-a812550ac6a7","type":"BasicTickFormatter"},"plot":{"id":"09fcedfd-aef8-4097-96a7-ee7309e78496","subtype":"Figure","type":"Plot"},"ticker":{"id":"9dcf376c-32e9-4db6-bf3f-c5a7a3b12e63","type":"BasicTicker"}},"id":"6b1f8d97-2a9b-4084-9062-1239ce1aeba1","type":"LinearAxis"},{"attributes":{"formatter":{"id":"743357a1-f5d0-474c-bec5-fceb3bc47b84","type":"BasicTickFormatter"},"plot":{"id":"09fcedfd-aef8-4097-96a7-ee7309e78496","subtype":"Figure","type":"Plot"},"ticker":{"id":"9439fe45-4750-40e9-b9a0-2c09cf7a9b38","type":"BasicTicker"}},"id":"40308e43-30de-43b2-a69e-dd70b5d65c5d","type":"LinearAxis"},{"attributes":{"callback":null},"id":"15d2e842-2639-41c3-b5c0-f7dd02f89935","type":"DataRange1d"},{"attributes":{},"id":"9dcf376c-32e9-4db6-bf3f-c5a7a3b12e63","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#FF0000"},"line_color":{"value":"#FF0000"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"367fc6b7-144b-4867-b344-4822aa792774","type":"Circle"},{"attributes":{"callback":null},"id":"2c5d7335-4d71-41d0-8c1a-73c5f5fa9e47","type":"DataRange1d"},{"attributes":{"below":[{"id":"6b1f8d97-2a9b-4084-9062-1239ce1aeba1","type":"LinearAxis"}],"left":[{"id":"40308e43-30de-43b2-a69e-dd70b5d65c5d","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6b1f8d97-2a9b-4084-9062-1239ce1aeba1","type":"LinearAxis"},{"id":"db5ea238-7944-4a45-b4b5-17dee5b067cc","type":"Grid"},{"id":"40308e43-30de-43b2-a69e-dd70b5d65c5d","type":"LinearAxis"},{"id":"427354f8-224c-4607-8ade-880b0160d3b1","type":"Grid"},{"id":"abb90969-b41c-4086-992c-43206aebd354","type":"BoxAnnotation"},{"id":"30b7946d-500f-4c6a-aef4-e23b005065de","type":"GlyphRenderer"}],"title":{"id":"c2d4eb0f-39b5-42fa-9f7c-229a74b5e43d","type":"Title"},"tool_events":{"id":"36eca99a-0c23-4cdc-8d22-d479e3900e5f","type":"ToolEvents"},"toolbar":{"id":"a35a78ac-218a-412b-9262-0697f3884fd3","type":"Toolbar"},"x_range":{"id":"2c5d7335-4d71-41d0-8c1a-73c5f5fa9e47","type":"DataRange1d"},"y_range":{"id":"15d2e842-2639-41c ...

# %%
# リスト7.3.3：RGBカラーコードによる色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, color=(255, 0, 0))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="95c93b45-75cb-41cb-ae4a-b322c5f93be3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("95c93b45-75cb-41cb-ae4a-b322c5f93be3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("95c93b45-75cb-41cb-ae4a-b322c5f93be3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '95c93b45-75cb-41cb-ae4a-b322c5f93be3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf61fab1-06dc-4d5b-9c80-e3c298124fdc":{"roots":{"references":[{"attributes":{"plot":{"id":"b1af6f02-f04c-4759-9aff-c8a3b73d5e60","subtype":"Figure","type":"Plot"}},"id":"445409fd-7b1e-4613-b1ed-44a0ba9fbb95","type":"SaveTool"},{"attributes":{"plot":{"id":"b1af6f02-f04c-4759-9aff-c8a3b73d5e60","subtype":"Figure","type":"Plot"}},"id":"dd5206cd-7623-4a4b-a01b-873cf381f8e2","type":"PanTool"},{"attributes":{"overlay":{"id":"668db101-68da-47d0-8acc-45b49024d103","type":"BoxAnnotation"},"plot":{"id":"b1af6f02-f04c-4759-9aff-c8a3b73d5e60","subtype":"Figure","type":"Plot"}},"id":"28ce699e-618e-438c-8076-22ec20498054","type":"BoxZoomTool"},{"attributes":{},"id":"80062878-d503-4ea3-94fb-2c17b51a8118","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"807c3313-3e02-4558-a8d0-b9dfa23f7e4c","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"668db101-68da-47d0-8acc-45b49024d103","type":"BoxAnnotation"},{"attributes":{},"id":"21ea3dac-8513-4226-a0d3-0b6500794712","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"f97d0091-3999-4ace-a833-711e62d67bc1","type":"Title"},{"attributes":{},"id":"9615bd69-b808-4122-946e-e6fb35782c08","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"dd5206cd-7623-4a4b-a01b-873cf381f8e2","type":"PanTool"},{"id":"31f6d67d-8b3c-4fd1-b451-d3fe4e212fe3","type":"WheelZoomTool"},{"id":"28ce699e-618e-438c-8076-22ec20498054","type":"BoxZoomTool"},{"id":"445409fd-7b1e-4613-b1ed-44a0ba9fbb95","type":"SaveTool"},{"id":"a4bf7bef-9293-4ffd-b171-8bbe354bafe5","type":"ResetTool"},{"id":"56dccf8e-57ae-46f3-b463-f9e305c11b35","type":"HelpTool"}]},"id":"d2903b61-efb7-4d35-af59-c0c9d103a9ca","type":"Toolbar"},{"attributes":{},"id":"f85d6897-e4fe-40d7-b1f5-01601885e2c7","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"9cca40e8-27bc-42e1-830d-c2dc11ec36a9","type":"Circle"},{"attributes":{"callback":null},"id":"3649590f-7b11-4427-8fcb-ec1141619c5f","type":"DataRange1d"},{"attributes":{"data_source":{"id":"807c3313-3e02-4558-a8d0-b9dfa23f7e4c","type":"ColumnDataSource"},"glyph":{"id":"46ded399-d8fb-4a5b-bc6f-8ec7ff1cb30a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9cca40e8-27bc-42e1-830d-c2dc11ec36a9","type":"Circle"},"selection_glyph":null},"id":"ab6c1977-992c-465f-ae72-7c69bd423843","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"rgb(255, 0, 0)"},"line_color":{"value":"rgb(255, 0, 0)"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"46ded399-d8fb-4a5b-bc6f-8ec7ff1cb30a","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"b1af6f02-f04c-4759-9aff-c8a3b73d5e60","subtype":"Figure","type":"Plot"},"ticker":{"id":"80062878-d503-4ea3-94fb-2c17b51a8118","type":"BasicTicker"}},"id":"5e3119ba-1cc2-40ae-af13-5b3f0852d3d9","type":"Grid"},{"attributes":{"below":[{"id":"07356996-f95b-41ae-8702-7c950b6b8465","type":"LinearAxis"}],"left":[{"id":"ec648ea9-7236-439c-9b23-03e9a74e4fad","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"07356996-f95b-41ae-8702-7c950b6b8465","type":"LinearAxis"},{"id":"72867d57-18f3-4a2c-a425-2797f187a8c8","type":"Grid"},{"id":"ec648ea9-7236-439c-9b23-03e9a74e4fad","type":"LinearAxis"},{"id":"5e3119ba-1cc2-40ae-af13-5b3f0852d3d9","type":"Grid"},{"id":"668db101-68da-47d0-8acc-45b49024d103","type":"BoxAnnotation"},{"id":"ab6c1977-992c-465f-ae72-7c69bd ...

# %%
# リスト7.3.4：オブジェクトの不透明度を設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 0.5, 1], [0, 0, 0], size=30, color=(0, 0, 255))
p.circle([0.25, 0.75], [0, 0], size=50, color=(255, 0, 0, 0.5))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e0259c80-6ffd-4c9d-9eb1-d9e1cdacc936"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e0259c80-6ffd-4c9d-9eb1-d9e1cdacc936");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e0259c80-6ffd-4c9d-9eb1-d9e1cdacc936");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e0259c80-6ffd-4c9d-9eb1-d9e1cdacc936' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b0075653-af65-4bde-a0f5-092f2def555f":{"roots":{"references":[{"attributes":{"below":[{"id":"894424be-c38f-41f3-b5dc-a74633c9beca","type":"LinearAxis"}],"left":[{"id":"dc94a9f0-36a6-4af4-91e7-83e8c887ec11","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"894424be-c38f-41f3-b5dc-a74633c9beca","type":"LinearAxis"},{"id":"4a75f4e2-e5ea-4d12-af2b-aaf4ccdfd89f","type":"Grid"},{"id":"dc94a9f0-36a6-4af4-91e7-83e8c887ec11","type":"LinearAxis"},{"id":"325ed1b7-1e28-4eb9-b23b-0b36af46f4d3","type":"Grid"},{"id":"6d00f904-7c0f-44e6-b5cf-5bee37c54e58","type":"BoxAnnotation"},{"id":"bad7b5a1-6a8a-4f62-be6f-76c11fca26e5","type":"GlyphRenderer"},{"id":"4d34a91d-9c45-46a1-9157-e2d2dd4d0e7b","type":"GlyphRenderer"}],"title":{"id":"510134a9-9a01-4634-ab70-549f1704e2df","type":"Title"},"tool_events":{"id":"654122aa-4e48-46e2-bdef-3757d75056a3","type":"ToolEvents"},"toolbar":{"id":"f83e33a0-094f-4c79-8d91-a02b207efe39","type":"Toolbar"},"x_range":{"id":"27b85b0c-9d57-4167-a0eb-1273aa1961d8","type":"DataRange1d"},"y_range":{"id":"1e256efc-88ed-4a8b-815d-4e4dea5ec038","type":"DataRange1d"}},"id":"a1e13341-afdb-4012-b9c7-163704d434d4","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"9fb0c926-59b9-4df1-b4ed-cc97b656c5c3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a1e13341-afdb-4012-b9c7-163704d434d4","subtype":"Figure","type":"Plot"}},"id":"921bc98f-fbe3-4ae2-8710-40cf5743d073","type":"HelpTool"},{"attributes":{"fill_color":{"value":"rgba(255, 0, 0, 0.5)"},"line_color":{"value":"rgba(255, 0, 0, 0.5)"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"2ae01cf4-5126-4666-8a98-804fe1e096dc","type":"Circle"},{"attributes":{},"id":"b0c64876-efaf-40ab-8d8c-0cfe96b7c164","type":"BasicTicker"},{"attributes":{"callback":null},"id":"27b85b0c-9d57-4167-a0eb-1273aa1961d8","type":"DataRange1d"},{"attributes":{"callback":null},"id":"1e256efc-88ed-4a8b-815d-4e4dea5ec038","type":"DataRange1d"},{"attributes":{"data_source":{"id":"1f4535ea-7939-4c60-beb2-9bb0f8f9efc1","type":"ColumnDataSource"},"glyph":{"id":"2ae01cf4-5126-4666-8a98-804fe1e096dc","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c4bcdadb-2fdb-4550-9e1e-99353404a5b3","type":"Circle"},"selection_glyph":null},"id":"4d34a91d-9c45-46a1-9157-e2d2dd4d0e7b","type":"GlyphRenderer"},{"attributes":{},"id":"654122aa-4e48-46e2-bdef-3757d75056a3","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,0.5,1],"y":[0,0,0]}},"id":"c0125e2e-da0c-4a1f-a64e-9c67f9e29567","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"9fb0c926-59b9-4df1-b4ed-cc97b656c5c3","type":"BasicTickFormatter"},"plot":{"id":"a1e13341-afdb-4012-b9c7-163704d434d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"b0c64876-efaf-40ab-8d8c-0cfe96b7c164","type":"BasicTicker"}},"id":"894424be-c38f-41f3-b5dc-a74633c9beca","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f7747990-2bc6-4756-9fb4-70581aa78f67","type":"PanTool"},{"id":"af3294c5-2098-4ebf-9f5f-c43a923e6d61","type":"WheelZoomTool"},{"id":"20ddafea-b66f-45e3-b16b-fc74cda8daf6","type":"BoxZoomTool"},{"id":"547f784d-3b2d-4cb7-8c9e-a93d51ca71ca","type":"SaveTool"},{"id":"e7f3afc2-cb2c-4e53-b406-fa118c363e4d","type":"ResetTool"},{"id":"921bc98f-fbe3-4ae2-8710-40cf5743d073","type":"HelpTool"}]},"id":"f83e33a0-094f-4c79-8d91-a02b207efe39","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"510134a9-9a01-4634-ab70-549f1704e2df","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"f864fcfa-8c4e-4905-9489-2fc33bf1a1aa","type":"Circle"},{"attributes":{"plot":{"id":"a1e13341-afdb-4012-b9c7-163704d434d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"b0c64876-efaf-40 ...

# %%
# リスト7.3.5：alphaによる透過設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 0.5, 1], [0, 0, 0], size=30, color='blue')
p.circle([0.25, 0.75], [0, 0], size=50, color='red', alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="21b431db-ed0b-40f0-a503-461f21c5d842"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("21b431db-ed0b-40f0-a503-461f21c5d842");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("21b431db-ed0b-40f0-a503-461f21c5d842");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '21b431db-ed0b-40f0-a503-461f21c5d842' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b4d199a4-c3ee-4615-83e5-9dbba5a1d7de":{"roots":{"references":[{"attributes":{"plot":{"id":"57e88485-f43c-45b3-b74c-5a348fe798a5","subtype":"Figure","type":"Plot"}},"id":"e3fde3f8-cc2a-4c06-92e8-852ad8712103","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"eb694e50-f403-47a2-8e6c-6c899dd7ce6f","type":"Circle"},{"attributes":{"plot":{"id":"57e88485-f43c-45b3-b74c-5a348fe798a5","subtype":"Figure","type":"Plot"}},"id":"de123ede-e47d-456a-aa04-7b4dedd76d79","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,0.5,1],"y":[0,0,0]}},"id":"cdd52a19-60db-42e7-af89-c790389b575c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"57e88485-f43c-45b3-b74c-5a348fe798a5","subtype":"Figure","type":"Plot"}},"id":"45ca3708-1626-4833-97b7-6dc70e2a313f","type":"ResetTool"},{"attributes":{"below":[{"id":"5fe8a8ab-6608-41d8-a9f8-8e4266684bfe","type":"LinearAxis"}],"left":[{"id":"9f3c320a-53a3-43f9-8756-cb37613ef51c","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"5fe8a8ab-6608-41d8-a9f8-8e4266684bfe","type":"LinearAxis"},{"id":"5c98a820-7df8-43fc-966c-d68ed452958f","type":"Grid"},{"id":"9f3c320a-53a3-43f9-8756-cb37613ef51c","type":"LinearAxis"},{"id":"9dd0ae21-1d10-43e3-b10c-cbdb015c2f8a","type":"Grid"},{"id":"a7cff080-458d-4ac1-b84c-92b32de7d5e8","type":"BoxAnnotation"},{"id":"bc1217a4-3eb9-49d7-bb48-0ba42456611a","type":"GlyphRenderer"},{"id":"342441c1-9bcd-41e3-861e-d7b0a883e5f8","type":"GlyphRenderer"}],"title":{"id":"5f36e538-90cd-469d-b5b5-4834be4765d3","type":"Title"},"tool_events":{"id":"194d3c90-87f2-4213-892b-ca786efcd306","type":"ToolEvents"},"toolbar":{"id":"5a7d4974-cd0c-4b0a-bfbd-20d981ef6938","type":"Toolbar"},"x_range":{"id":"e1e0203e-846c-4bcc-94f4-a9935e44b401","type":"DataRange1d"},"y_range":{"id":"4667b88e-3e26-4e72-94f3-d3d4ca9ade00","type":"DataRange1d"}},"id":"57e88485-f43c-45b3-b74c-5a348fe798a5","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a7cff080-458d-4ac1-b84c-92b32de7d5e8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"57e88485-f43c-45b3-b74c-5a348fe798a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d2d511f-5794-4e95-8174-5c5d4a8c61d5","type":"BasicTicker"}},"id":"5c98a820-7df8-43fc-966c-d68ed452958f","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d411d33-9371-4d5c-bba4-39c2ad7f55b7","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3403434a-4d25-432f-885f-6149e0a56e5f","type":"PanTool"},{"id":"e61fe3d5-f6f4-419e-84a0-9b45861e80ab","type":"WheelZoomTool"},{"id":"d214a516-b6f2-4daf-bb83-8e8aa2f3af70","type":"BoxZoomTool"},{"id":"e3fde3f8-cc2a-4c06-92e8-852ad8712103","type":"SaveTool"},{"id":"45ca3708-1626-4833-97b7-6dc70e2a313f","type":"ResetTool"},{"id":"de123ede-e47d-456a-aa04-7b4dedd76d79","type":"HelpTool"}]},"id":"5a7d4974-cd0c-4b0a-bfbd-20d981ef6938","type":"Toolbar"},{"attributes":{},"id":"4d2d511f-5794-4e95-8174-5c5d4a8c61d5","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"red"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"deb758d8-3881-4c99-869d-81b86de2108b","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"5f36e538-90cd-469d-b5b5 ...

# %%
# リスト7.3.6：fill_colorを設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, fill_color='red', line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9f6c15a4-b110-46ec-bf61-f310bd5f7742"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9f6c15a4-b110-46ec-bf61-f310bd5f7742");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9f6c15a4-b110-46ec-bf61-f310bd5f7742");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9f6c15a4-b110-46ec-bf61-f310bd5f7742' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9e9d8f42-7e85-4e80-aee1-572b6ee69233":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"eb3e9e94-fe2f-4ca4-b9b7-393233ba6a6c","type":"ColumnDataSource"},{"attributes":{},"id":"089929f1-e45a-4d00-8b04-c93fa2695cde","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"eb3e9e94-fe2f-4ca4-b9b7-393233ba6a6c","type":"ColumnDataSource"},"glyph":{"id":"c36853e7-5ee3-444e-8c71-6ef081ce69b9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"64937c00-ed0c-4705-9fc9-9d2412bf7f01","type":"Circle"},"selection_glyph":null},"id":"79ba6d85-326b-470f-b26f-bff732cefd24","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"}},"id":"37b142be-1a1a-4ffe-aad6-253cab3ed138","type":"HelpTool"},{"attributes":{},"id":"f2d6b250-18d5-4141-a2c9-7ee61505a4d0","type":"ToolEvents"},{"attributes":{"plot":{"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"}},"id":"f4b55a73-132e-40b6-8c34-4dd5530d252d","type":"ResetTool"},{"attributes":{"callback":null},"id":"dc116c5e-0000-4951-b967-cdd0b9b28e03","type":"DataRange1d"},{"attributes":{"plot":{"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"}},"id":"58b52e62-21a0-4804-b054-261c38ea3ed1","type":"PanTool"},{"attributes":{"below":[{"id":"6eaf4b4b-361e-4e96-99a1-1e5b49a63146","type":"LinearAxis"}],"left":[{"id":"fe350c09-a1e5-4eb4-8a42-15c45e6c4128","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6eaf4b4b-361e-4e96-99a1-1e5b49a63146","type":"LinearAxis"},{"id":"39676fb6-7238-4ef8-a7da-6eb22b6a16bc","type":"Grid"},{"id":"fe350c09-a1e5-4eb4-8a42-15c45e6c4128","type":"LinearAxis"},{"id":"7755021f-32e3-4625-a101-971dc2a00157","type":"Grid"},{"id":"2b226f8a-a7a1-4c98-a410-332f1c9290c4","type":"BoxAnnotation"},{"id":"79ba6d85-326b-470f-b26f-bff732cefd24","type":"GlyphRenderer"}],"title":{"id":"0fbbc7ac-2587-4bdc-a5d0-defd2511c2dd","type":"Title"},"tool_events":{"id":"f2d6b250-18d5-4141-a2c9-7ee61505a4d0","type":"ToolEvents"},"toolbar":{"id":"d86e1c13-c781-4306-85ac-fa78667e3bbf","type":"Toolbar"},"x_range":{"id":"dc116c5e-0000-4951-b967-cdd0b9b28e03","type":"DataRange1d"},"y_range":{"id":"b9788ff4-8697-4c2a-995d-cc3a57b1ae86","type":"DataRange1d"}},"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"c36853e7-5ee3-444e-8c71-6ef081ce69b9","type":"Circle"},{"attributes":{"formatter":{"id":"38fb0456-d28a-448c-9f8b-f71871428eaf","type":"BasicTickFormatter"},"plot":{"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"},"ticker":{"id":"49ffead6-486c-4f77-a0bc-1c7327df7d73","type":"BasicTicker"}},"id":"6eaf4b4b-361e-4e96-99a1-1e5b49a63146","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"58b52e62-21a0-4804-b054-261c38ea3ed1","type":"PanTool"},{"id":"180078ec-5332-4bd9-8e60-0f607e3caa1a","type":"WheelZoomTool"},{"id":"179027b7-b547-4d26-b8fa-d6aca80256c0","type":"BoxZoomTool"},{"id":"ace3852b-5b37-4d2d-b751-1c492793eab6","type":"SaveTool"},{"id":"f4b55a73-132e-40b6-8c34-4dd5530d252d","type":"ResetTool"},{"id":"37b142be-1a1a-4ffe-aad6-253cab3ed138","type":"HelpTool"}]},"id":"d86e1c13-c781-4306-85ac-fa78667e3bbf","type":"Toolbar"},{"attributes":{"plot":{"id":"0fe9b7ea-670d-40a0-affb-9b84c33baca8","subtype":"Figure","type":"Plot"}},"id":"180078ec-5332-4bd9-8e60-0f607e3caa1a","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"64937c00-ed0c-4705-9fc9-9d ...

# %%
# リスト7.3.7：line_colorを設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], size=30, fill_color='red', line_color='black', line_width=5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57f19bdb-6945-4581-b6f8-3524b0c5a5fe"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("57f19bdb-6945-4581-b6f8-3524b0c5a5fe");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57f19bdb-6945-4581-b6f8-3524b0c5a5fe");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57f19bdb-6945-4581-b6f8-3524b0c5a5fe' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"584321b9-dca1-44b6-a532-5573fbb5cdee":{"roots":{"references":[{"attributes":{},"id":"d9ff40cd-8e9e-4344-966c-922049046253","type":"ToolEvents"},{"attributes":{"callback":null},"id":"caef7b6d-4094-4133-9b74-e11356e70ba6","type":"DataRange1d"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"}},"id":"265352d7-ac23-485b-bbb2-02ff7be4ef12","type":"PanTool"},{"attributes":{},"id":"b96924cc-5303-4b17-a870-bc79f601a837","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"}},"id":"6a88832a-f166-416b-ba1a-2e3eca5a979c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"}},"id":"f99b8a67-fa8d-40a9-bc91-c9924513788c","type":"SaveTool"},{"attributes":{},"id":"396e7db2-951e-45fb-a921-9af217051b9b","type":"BasicTicker"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"}},"id":"a70ea8df-c60d-4f42-b643-7d4317eb88c0","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"265352d7-ac23-485b-bbb2-02ff7be4ef12","type":"PanTool"},{"id":"6a88832a-f166-416b-ba1a-2e3eca5a979c","type":"WheelZoomTool"},{"id":"36221c81-b90d-4c91-aefa-b71c05f8af17","type":"BoxZoomTool"},{"id":"f99b8a67-fa8d-40a9-bc91-c9924513788c","type":"SaveTool"},{"id":"a70ea8df-c60d-4f42-b643-7d4317eb88c0","type":"ResetTool"},{"id":"2bbbfd29-f398-4339-b336-462cc4c86327","type":"HelpTool"}]},"id":"3ed8448d-ec30-42bc-b7fb-99db5a57134d","type":"Toolbar"},{"attributes":{"callback":null},"id":"34000896-7746-4a2e-8222-2f555c97864d","type":"DataRange1d"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"}},"id":"2bbbfd29-f398-4339-b336-462cc4c86327","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b14f6b97-b0e0-4c95-90e3-30a2907e9945","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c4774af0-c2b2-4b6e-afe2-62e69bffcf76","type":"ColumnDataSource"},"glyph":{"id":"72799ee6-1d4f-4f59-becc-6b75901d50b4","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"24c9cb44-af0f-4d3c-be0c-eacac362941e","type":"Circle"},"selection_glyph":null},"id":"ae7ac393-550c-4171-a76f-67303ec66df2","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"},"ticker":{"id":"206bb641-6cd5-45d5-89f4-cd8538147f59","type":"BasicTicker"}},"id":"f6fd4d8d-e372-48c9-b224-f1f4b7865aaf","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"c4774af0-c2b2-4b6e-afe2-62e69bffcf76","type":"ColumnDataSource"},{"attributes":{},"id":"206bb641-6cd5-45d5-89f4-cd8538147f59","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":5},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"24c9cb44-af0f-4d3c-be0c-eacac362941e","type":"Circle"},{"attributes":{"plot":{"id":"5dca7cba-5875-4a24-bc9d-fb72af5f1081","subtype":"Figure","type":"Plot"},"ticker":{"id":"396e7db2-951e-45fb-a921-9af217051b9b","type":"BasicTicker"}},"id":"4b0f6eae-c376-47e7-a513-f9ad943a00e8","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"09360fdf-38ed-4d79-8c5c-f9a863751002","type":"Title"},{"attributes":{"below":[{"id":"a050a482-15ab-48e9-850c-edc5bd517f0c","type":"LinearAxis"}],"left":[{"id":"85e8ceeb-794d-4112-baeb-5fa19eeb6771","type":"LinearAxis"}],"plot_height":200,"plot_width ...

# %%
# リスト7.3.8：Blues6を指定してインポート
from bokeh.palettes import Blues6
Blues6
# Out:
# ['#08519c', '#3182bd', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff']

# %%
# リスト7.3.10：Bluesを指定してインポート
from bokeh.palettes import Blues
Blues
# Out:
# {3: ['#3182bd', '#9ecae1', '#deebf7'],
#  4: ['#2171b5', '#6baed6', '#bdd7e7', '#eff3ff'],
#  5: ['#08519c', '#3182bd', '#6baed6', '#bdd7e7', '#eff3ff'],
#  6: ['#08519c', '#3182bd', '#6baed6', '#9ecae1', '#c6dbef', '#eff3ff'],
#  7: ['#084594',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#eff3ff'],
#  8: ['#084594',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#deebf7',
#   '#f7fbff'],
#  9: ['#08306b',
#   '#08519c',
#   '#2171b5',
#   '#4292c6',
#   '#6baed6',
#   '#9ecae1',
#   '#c6dbef',
#   '#deebf7',
#   '#f7fbff']}

# %%
# リスト7.3.12：Blues6による着色
p = figure(
    plot_width=200, plot_height=200, x_range=(0, 2), y_range=(-0.5, 5.5))
for i, color in enumerate(Blues6):
    p.square(0.5, i, color=color, size=20)
    p.text(1, i, text=[color], text_baseline='middle')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4098135b-f0b6-4b00-8a56-4d1edb06ee4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4098135b-f0b6-4b00-8a56-4d1edb06ee4f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4098135b-f0b6-4b00-8a56-4d1edb06ee4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4098135b-f0b6-4b00-8a56-4d1edb06ee4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"60a6eea4-bf52-4bc3-8a20-e6ba2956cf8e":{"roots":{"references":[{"attributes":{"below":[{"id":"97819e52-c8c8-4523-abdd-2efb669cb51a","type":"LinearAxis"}],"left":[{"id":"5c6289ce-de07-4cbd-97af-ed3a5256d718","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"97819e52-c8c8-4523-abdd-2efb669cb51a","type":"LinearAxis"},{"id":"72d5d55d-5fe7-4d3d-a70d-d9210a86ef86","type":"Grid"},{"id":"5c6289ce-de07-4cbd-97af-ed3a5256d718","type":"LinearAxis"},{"id":"c6e3739f-13e2-4d9e-b17e-be7a92d9f505","type":"Grid"},{"id":"d4a9529a-356f-401f-b8e0-ab030affc157","type":"BoxAnnotation"},{"id":"008cebe3-46b5-42fc-bcc8-d002c59e3174","type":"GlyphRenderer"},{"id":"31606668-5fca-455e-975a-49a2c39ff117","type":"GlyphRenderer"},{"id":"3b1eb946-ce3d-4d86-94bb-480163e9ca35","type":"GlyphRenderer"},{"id":"2fcf3fdc-4777-48ec-bf76-219622d448a8","type":"GlyphRenderer"},{"id":"02860ae2-fed6-42f1-90ee-20d7cbf7457a","type":"GlyphRenderer"},{"id":"77faf574-2de3-415a-a36a-66a53ad4b10c","type":"GlyphRenderer"},{"id":"21720dea-4ea2-4f4f-9925-544a089e421f","type":"GlyphRenderer"},{"id":"cc9fc469-1dcf-421c-8f8d-a3c79343d0c9","type":"GlyphRenderer"},{"id":"16836558-3c00-4621-a66e-cbe55fe2512c","type":"GlyphRenderer"},{"id":"5db65021-d181-4204-a37a-6d3d61ff8ce7","type":"GlyphRenderer"},{"id":"c25f04f3-178c-4714-838a-c030022ede0b","type":"GlyphRenderer"},{"id":"417f8a71-7a8e-48a5-a2da-558ed018bacf","type":"GlyphRenderer"}],"title":{"id":"f9b739de-ed89-433f-b051-c52e668e7c19","type":"Title"},"tool_events":{"id":"a60cd1ec-df64-4b8b-ae38-cf291727b99e","type":"ToolEvents"},"toolbar":{"id":"ef4f639f-7403-4868-a510-1e498721aaba","type":"Toolbar"},"x_range":{"id":"87eafb24-5b98-4131-ba5a-9c208abbd79e","type":"Range1d"},"y_range":{"id":"2f46baab-aa4d-4aed-bf08-942e65275a62","type":"Range1d"}},"id":"bffd0073-905d-489f-a651-0a4b0a7de135","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"691a57b2-a2a7-40b9-8841-1f46510a1e1e","type":"ColumnDataSource"},"glyph":{"id":"2b19a9a5-f070-494c-8e21-3ccc74400fe3","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5640eab8-720e-4077-8b70-a98119eaeaf9","type":"Square"},"selection_glyph":null},"id":"008cebe3-46b5-42fc-bcc8-d002c59e3174","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5ca09724-b17f-49fe-be02-bff06d799f44","type":"ColumnDataSource"},"glyph":{"id":"752a2a9a-b750-436b-ad4d-032fe76cbe68","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a1080473-993d-434b-a20d-1dd0be33733b","type":"Text"},"selection_glyph":null},"id":"417f8a71-7a8e-48a5-a2da-558ed018bacf","type":"GlyphRenderer"},{"attributes":{},"id":"a60cd1ec-df64-4b8b-ae38-cf291727b99e","type":"ToolEvents"},{"attributes":{"callback":null,"end":2},"id":"87eafb24-5b98-4131-ba5a-9c208abbd79e","type":"Range1d"},{"attributes":{"fill_color":{"value":"#9ecae1"},"line_color":{"value":"#9ecae1"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":3}},"id":"a2359f0d-16ce-48a3-9272-7b5eb6c260f8","type":"Square"},{"attributes":{"fill_color":{"value":"#6baed6"},"line_color":{"value":"#6baed6"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":2}},"id":"eabd9b9e-6349-439a-a900-528c7909fca8","type":"Square"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c8f0915c-9714-4e44-a9ce-d7ec6ab3e3b0","type":"PanTool"},{"id":"22090fc8-3638-45b8-b67a-50c4fe90e9d6","type":"WheelZoomTool"},{"id":"e686abcd-c28b-4de9-a043-37b8f3045d2e","type":"BoxZoomTool"},{"id":"185bc239-25af-4388-ab95-f44cf643ac5d","type":"SaveTool"},{"id":"4ed22b4e-fff1-4d51-b56b-b537423c3ab4","type":"ResetTool"},{"id":"63078756-3a8d-4871-961a-87753ea332ab","type":"HelpTool"}]},"id":"ef4f639f-7403-4868-a510-1e498721aaba","type":"Toolbar"},{"attributes":{"fill_color":{"value":"#08519c"},"line_color":{"value":"#08519c"},"size":{"units":"screen","value":20},"x":{"value":0.5},"y":{"value":0}},"id":"2b19a9a5-f070-494c ...
