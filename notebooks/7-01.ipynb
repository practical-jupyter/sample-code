# %%
# リスト7.1.1：テキストの描画
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.text([1, 2], [1, 1], text=['text1', 'text2'])
p.x([1, 2], [1, 1], size=10)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="db6d4bbd-7567-445b-a5e6-d21497e3b70e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="97d87b12-4d01-4dd3-8970-3355e12ecc3e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("97d87b12-4d01-4dd3-8970-3355e12ecc3e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97d87b12-4d01-4dd3-8970-3355e12ecc3e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97d87b12-4d01-4dd3-8970-3355e12ecc3e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9f336663-2c05-4dbc-8189-856807260902":{"roots":{"references":[{"attributes":{"overlay":{"id":"8a31c3fb-ac36-4d22-9481-b28c36335709","type":"BoxAnnotation"},"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"}},"id":"02684e6c-7c93-44f3-ae66-0b6e226d80b1","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"436fa583-7bce-4be9-a2de-a720d8fd6df4","type":"Range1d"},{"attributes":{"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"}},"id":"fceee129-7088-4166-9901-456d4cac2b15","type":"SaveTool"},{"attributes":{},"id":"497a5444-ca99-4eeb-90c2-b9b7befe4307","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["text1","text2"],"x":[1,2],"y":[1,1]}},"id":"20d9a6ca-f5fd-40e8-9802-c247c37948f5","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"}},"id":"adba3557-55ee-40a9-ae23-361eaaa92508","type":"ResetTool"},{"attributes":{"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"}},"id":"8581c080-5ed8-471d-b43a-3ba71b281954","type":"HelpTool"},{"attributes":{"callback":null},"id":"1ff75001-0f37-4e9e-94d7-452d7d35f01d","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"386431fa-63f2-48aa-9ba8-801c9eebf439","type":"Title"},{"attributes":{"formatter":{"id":"c869f4e6-e3ff-475f-a035-182eb030f05b","type":"BasicTickFormatter"},"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"},"ticker":{"id":"275ea6e8-d5ed-4044-bcd8-9ed3e1bec6e9","type":"BasicTicker"}},"id":"333cc9b0-251e-4739-95ac-b079a644c7d2","type":"LinearAxis"},{"attributes":{},"id":"275ea6e8-d5ed-4044-bcd8-9ed3e1bec6e9","type":"BasicTicker"},{"attributes":{"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a921a57-8eec-4140-8ebf-49afd24a9874","type":"Text"},{"attributes":{"below":[{"id":"333cc9b0-251e-4739-95ac-b079a644c7d2","type":"LinearAxis"}],"left":[{"id":"14d9002e-c1ab-44d6-9167-3b68be46e015","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"333cc9b0-251e-4739-95ac-b079a644c7d2","type":"LinearAxis"},{"id":"5761a955-6773-494c-bfc6-6153d0456547","type":"Grid"},{"id":"14d9002e-c1ab-44d6-9167-3b68be46e015","type":"LinearAxis"},{"id":"ad70ff08-06b9-4e96-9faf-912d0a143be0","type":"Grid"},{"id":"8a31c3fb-ac36-4d22-9481-b28c36335709","type":"BoxAnnotation"},{"id":"a4cdde6b-8784-4fe0-934f-f9f32f3ed923","type":"GlyphRenderer"},{"id":"3b26682a-f9fe-4f9d-83a9-fdabb8fb8bc8","type":"GlyphRenderer"}],"title":{"id":"386431fa-63f2-48aa-9ba8-801c9eebf439","type":"Title"},"tool_events":{"id":"1a0a584e-21bf-4dd5-875b-d47a89bba2f6","type":"ToolEvents"},"toolbar":{"id":"e5155471-6eb9-463f-a074-6f136df8a299","type":"Toolbar"},"x_range":{"id":"436fa583-7bce-4be9-a2de-a720d8fd6df4","type":"Range1d"},"y_range":{"id":"1ff75001-0f37-4e9e-94d7-452d7d35f01d","type":"DataRange1d"}},"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"},"ticker":{"id":"275ea6e8-d5ed-4044-bcd8-9ed3e1bec6e9","type":"BasicTicker"}},"id":"5761a955-6773-494c-bfc6-6153d0456547","type":"Grid"},{"attributes":{},"id":"c869f4e6-e3ff-475f-a035-182eb030f05b","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2],"y":[1,1]}},"id":"459a5615-7b00-4459-bc8b-1fe8d483ce45","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"497a5444-ca99-4eeb-90c2-b9b7befe4307","type":"BasicTickFormatter"},"plot":{"id":"8ff3e8d8-36f1-47ee-a2db-5f5de7fc4d42","subtype":"Figure","type":"Plot"},"ticker":{"id":"638bb150-c7ac-4137-928f-c9fa4bb45cd9","type":"BasicTicker"}},"id":"14d9002e-c1ab-44d6-9167-3b68be46e015","type":"LinearAxis"},{"attributes":{},"id":"1a0a584e-21bf-4dd5-875b-d47a89bba2f6","type":"ToolEvents"}, ...

# %%
# リスト7.1.2：circle()メソッドによる円形の描画
p = figure(plot_width=200, plot_height=200)
p.circle([1, 2], [1, 2])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6dd886ca-dd82-48af-8734-3b67cd1f0219"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6dd886ca-dd82-48af-8734-3b67cd1f0219");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6dd886ca-dd82-48af-8734-3b67cd1f0219");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6dd886ca-dd82-48af-8734-3b67cd1f0219' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"39c8db04-e1e4-4eeb-ae15-aa29553b6eff":{"roots":{"references":[{"attributes":{"callback":null},"id":"c6355060-41fe-4371-9ceb-987a50747730","type":"DataRange1d"},{"attributes":{},"id":"ff91c7ee-0c0a-43a4-833b-0e6b8c9f54c9","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"85b331cf-257d-44c5-8c6b-f7a6a671e1f8","type":"LinearAxis"}],"left":[{"id":"294ec8be-b16d-4f87-abb7-1a222cd58eef","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"85b331cf-257d-44c5-8c6b-f7a6a671e1f8","type":"LinearAxis"},{"id":"731d04b1-febd-4468-8fc4-dfff0efbd0bf","type":"Grid"},{"id":"294ec8be-b16d-4f87-abb7-1a222cd58eef","type":"LinearAxis"},{"id":"bd8f6838-4f41-499f-b400-87332c30046a","type":"Grid"},{"id":"e3cd4d12-c1e9-436c-b0e3-45f67972745c","type":"BoxAnnotation"},{"id":"be0f36e7-5da0-40e1-bca9-af2c4d8247ac","type":"GlyphRenderer"}],"title":{"id":"a12fb32d-1214-40e7-ad21-d46599e8a125","type":"Title"},"tool_events":{"id":"23b14a9f-40ed-4c8a-b92b-90da3f7492cd","type":"ToolEvents"},"toolbar":{"id":"d6a298ca-f60d-403e-99d0-c0787b59c81c","type":"Toolbar"},"x_range":{"id":"c5742b39-3529-4fc5-9005-48f447ec0bc6","type":"DataRange1d"},"y_range":{"id":"c6355060-41fe-4371-9ceb-987a50747730","type":"DataRange1d"}},"id":"b8a2c95c-267a-4572-8c2d-ecae42a7217e","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1dedbf62-ebeb-414b-9d4f-fdf99f8c54be","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2],"y":[1,2]}},"id":"5a36cf31-681d-47d4-855f-f4eef2dec85a","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"e3cd4d12-c1e9-436c-b0e3-45f67972745c","type":"BoxAnnotation"},"plot":{"id":"b8a2c95c-267a-4572-8c2d-ecae42a7217e","subtype":"Figure","type":"Plot"}},"id":"9920a074-7f9b-409b-b932-26942edffa81","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"b8a2c95c-267a-4572-8c2d-ecae42a7217e","subtype":"Figure","type":"Plot"}},"id":"8a1e7b48-3cbc-4ed7-b1e8-8399f88d580d","type":"PanTool"},{"attributes":{"plot":{"id":"b8a2c95c-267a-4572-8c2d-ecae42a7217e","subtype":"Figure","type":"Plot"}},"id":"930c9807-794b-4942-be73-5366bad5b2d3","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"c5742b39-3529-4fc5-9005-48f447ec0bc6","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8a1e7b48-3cbc-4ed7-b1e8-8399f88d580d","type":"PanTool"},{"id":"930c9807-794b-4942-be73-5366bad5b2d3","type":"WheelZoomTool"},{"id":"9920a074-7f9b-409b-b932-26942edffa81","type":"BoxZoomTool"},{"id":"48ae5810-f4e2-4727-b8ab-3fc79dbc3632","type":"SaveTool"},{"id":"90a3d319-0d05-4143-906f-c06172eb94c0","type":"ResetTool"},{"id":"3c1dab0c-fb2d-4763-9fbd-d828fd4c8a38","type":"HelpTool"}]},"id":"d6a298ca-f60d-403e-99d0-c0787b59c81c","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e3cd4d12-c1e9-436c-b0e3-45f67972745c","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"5a36cf31-681d-47d4-855f-f4eef2dec85a","type":"ColumnDataSource"},"glyph":{"id":"b364f927-8e8c-4b04-9ccb-aabc48437548","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ea6b988a-79c2-456b-ae61-ac7437530489","type":"Circle"},"selection_glyph":null},"id":"be0f36e7-5da0-40e1-bca9-af2c4d8247ac","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b364f927-8e8c-4b04-9ccb-aabc48437548","type":"Circle"},{"attributes":{"plot":{"id":"b8a2c95c-267a-4572-8c2d-ecae42a7217e","subtype":"Figure","type":"Plot"}},"id":"90a3d319-0d05-4143-906f-c06172eb94c0","type":"ResetTool"},{"attributes":{"formatter":{"id":"1dedbf62-ebeb-414b-9d4f-fdf99f8c54be","t ...

# %%
# リスト7.1.4：長方形の描画
from numpy import pi
p = figure(plot_width=400, plot_height=400, x_range=(-6, 6))
# quad
p.quad(top=[12], bottom=[10], left=[-1], right=[1], alpha=0.5)
# rect
p.rect(x=[0], y=[8], width=2, height=2, angle=pi * 0.25, alpha=0.5)
# vbar
p.vbar(x=[0], bottom=[4], top=[6], width=2, alpha=0.5)
# hbar
p.hbar(y=[2], left=[-1], right=[1], height=2, alpha=0.5)
# 注釈
# quad
p.text([-4], [11], text=['quad'], text_baseline='middle')
p.text(
    [0, 0, -1, 1], [12, 10, 11, 11],
    text=['top=12', 'bottom=10', 'left=-1', 'right=1'],
    text_align='center',
    text_baseline='middle')
# rect
p.text([-4], [8], text=['rect'], text_baseline='middle')
p.text(
    [0], [8], text=['x=0, y=8'], text_align='center', text_baseline='middle')
p.text(
    [-1], [8.5], text=['width=2'], angle=pi * 0.25,
    text_align='center', text_baseline='middle')
p.text(
    [1], [8.5], text=['height=2'], angle=pi * -0.25,
    text_align='center', text_baseline='middle')
p.text(
    [0], [7], text=['angle=pi*0.25'],
    text_align='center', text_baseline='middle')
# vbar
p.text([-4], [5], text=['vbar'], text_baseline='middle')
p.text(
    [0], [5], text=['x=0, width=2'],
    text_align='center', text_baseline='middle')
p.text(
    [0, 0], [6, 4], text=['top=6', 'bottom=4'],
    text_align='center', text_baseline='middle')
# hbar
p.text([-4], [2], text=['hbar'], text_baseline='middle')
p.text(
    [0, 0], [2.2, 1.8], text=['y=2,', 'height=2'],
    text_align='center', text_baseline='middle')
p.text(
    [-1.5, 1.5], [2, 2], text=['left=-1', 'right=1'],
    angle=pi * 0.5,
    text_align='center', text_baseline='middle')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="499dfa56-25df-41a3-9738-c186a12cfb7b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("499dfa56-25df-41a3-9738-c186a12cfb7b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("499dfa56-25df-41a3-9738-c186a12cfb7b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '499dfa56-25df-41a3-9738-c186a12cfb7b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bfa39e58-795a-4089-bc1a-6c45a1663bd1":{"roots":{"references":[{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"531d7574-b8d5-415e-80bd-ec914b4f7cf8","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["angle=pi*0.25"],"x":[0],"y":[7]}},"id":"921d4ddb-3934-4506-8787-a2aa1a01183b","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":-0.7853981633974483},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f22485a7-f423-4118-a0b2-4f97b58bb794","type":"Text"},{"attributes":{"angle":{"units":"rad","value":-0.7853981633974483},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"33ce25aa-bfca-4aa1-8122-5a6e3621b3a1","type":"Text"},{"attributes":{"data_source":{"id":"fdf4dacb-6662-44c7-9061-f05393e2e126","type":"ColumnDataSource"},"glyph":{"id":"33ce25aa-bfca-4aa1-8122-5a6e3621b3a1","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f22485a7-f423-4118-a0b2-4f97b58bb794","type":"Text"},"selection_glyph":null},"id":"eee6176b-2fdc-4f06-bc2e-903c9bca01cb","type":"GlyphRenderer"},{"attributes":{"angle":{"units":"rad","value":1.5707963267948966},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"45216b3b-640a-4fb7-a5ab-4324a36fcb97","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"389e9eee-4548-43e0-913f-335e82e1763d","type":"Text"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"fef5a724-042a-4402-be73-07338619b5cc","type":"Quad"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9e6020c8-f5e9-4721-bae1-ab086814eda0","type":"Text"},{"attributes":{"data_source":{"id":"1f6e25be-64a2-4f4c-9c67-b66af35eace7","type":"ColumnDataSource"},"glyph":{"id":"37fd4a52-f341-49f3-a4d4-08896aeefe70","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a6cfdb8f-8271-4920-9ab0-c4ee8f151b28","type":"Text"},"selection_glyph":null},"id":"b976feb1-ffb7-4989-897f-5e65acdf79ef","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"921d4ddb-3934-4506-8787-a2aa1a01183b","type":"ColumnDataSource"},"glyph":{"id":"9e6020c8-f5e9-4721-bae1-ab086814eda0","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"389e9eee-4548-43e0-913f-335e82e1763d","type":"Text"},"selection_glyph":null},"id":"7b48e05d-5448-4de9-a1de-09d45ba4478f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c5090f54-6d17-48ba-9c7f-b701f01ecf57","type":"ColumnDataSource"},"glyph":{"id":"5f517e8d-05d3-433f-a346-6042fe8f3a53","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"fef5a724-042a-4402-be73-07338619b5cc","type":"Quad"},"selection_glyph":null},"id":"56ffca13-c4f9-4492-9293-cf58bddcd05b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"56aaf077-393b-450f-810e-103d9ee3eaf6","type":"LinearAxis"}],"left":[{"id":"b7634942-4e80-44c7-b710-f08024647784","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"56aaf077-393b-450f-810e-103d9ee3eaf6","type":"LinearAxis"},{"id":"be78c8ad-f0c3-4adf-94ee-256da95f2636","type":"Grid"},{"id":"b7634942-4e80-44c7-b710-f08024647784","type":"LinearAxis"},{"id":"60b537ac-603e-4fcc-97ef-b37ca6f44556","type":"Grid"},{"id":"5c84a184-b71a-4172-b8b9-5ca2a389854e","type":"BoxAnnotation" ...

# %%
# リスト7.1.5：多角形の描画
p = figure(plot_width=400, plot_height=400, x_range=(-0.5, 5.5))
# patch
p.patch([0, 2, 1], [0, 0, 1], alpha=0.5)
# patches
p.patches([[3, 4, 3], [4, 5, 5]], [[0, 0, 1], [1, 1, 0]], alpha=0.5)
# 注釈
# patch
p.text(
    [1, 1, 1], [0.6, 0.5, 0.4],
    text=['patch', 'x=[0, 2, 1]', 'y=[0, 0, 1]'],
    text_align='center', text_baseline='middle')
p.text(
    [0, 2, 1], [0, 0, 1],
    text=['(0, 0)', '(2, 0)', '(1, 1)'],
    text_align='center', text_baseline='middle')
# patches
p.text(
    [4, 4, 4], [0.6, 0.5, 0.4],
    text=['patches', 'xs=[[3, 4, 3], [4, 5, 5]]', 'ys=[[0, 0, 1], [1, 1, 0]]'],
    text_align='center', text_baseline='middle')
p.text(
    [3, 4, 3], [0, 0, 1],
    text=['(3, 0)', '(4, 0)', '(3, 1)'],
    text_align='center', text_baseline='middle')
p.text(
    [4, 5, 5], [1, 1, 0],
    text=['(4, 1)', '(5, 1)', '(5, 0)'],
    text_align='center', text_baseline='middle')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4b804af5-9428-44fc-9479-4077a81ae34d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4b804af5-9428-44fc-9479-4077a81ae34d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b804af5-9428-44fc-9479-4077a81ae34d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b804af5-9428-44fc-9479-4077a81ae34d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8a071fd7-9a33-46e3-9cd7-0e7daab9c71c":{"roots":{"references":[{"attributes":{"overlay":{"id":"b63f85e1-b697-4fb4-ad8b-9a7d0d073b77","type":"BoxAnnotation"},"plot":{"id":"9e5de105-71a4-4141-9132-076c21940a85","subtype":"Figure","type":"Plot"}},"id":"594cd32e-4a91-4079-91b4-efd4a778a694","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"9e5de105-71a4-4141-9132-076c21940a85","subtype":"Figure","type":"Plot"}},"id":"adc20a7f-1f1a-4fd9-a44e-f1e772415f5a","type":"SaveTool"},{"attributes":{"plot":{"id":"9e5de105-71a4-4141-9132-076c21940a85","subtype":"Figure","type":"Plot"}},"id":"f37f3277-5260-4849-8e96-ab8a9587ecd5","type":"ResetTool"},{"attributes":{"plot":{"id":"9e5de105-71a4-4141-9132-076c21940a85","subtype":"Figure","type":"Plot"}},"id":"4195b7e0-867e-4dd8-846d-01bee602d78f","type":"HelpTool"},{"attributes":{"data_source":{"id":"d95caafe-9daa-4181-b9bf-d78959c2aca7","type":"ColumnDataSource"},"glyph":{"id":"f574ac24-df9b-449d-997a-b8c0a339a139","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"01638c7b-663b-440a-b05d-7f0b288f94e3","type":"Text"},"selection_glyph":null},"id":"5d365fba-49dc-48db-ac60-f413eb1b6b06","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"311643f2-fc7b-4f50-96ff-21fb98a9e126","type":"ColumnDataSource"},"glyph":{"id":"817dcec0-f765-41d5-a32d-61483951ed01","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2317abe4-1210-44f0-adcf-c70c29a2330f","type":"Patches"},"selection_glyph":null},"id":"c339461b-6767-4a29-b903-08c2baf625ff","type":"GlyphRenderer"},{"attributes":{},"id":"22915207-82a3-4ca6-9738-39859141856e","type":"BasicTickFormatter"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f574ac24-df9b-449d-997a-b8c0a339a139","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["patch","x=[0, 2, 1]","y=[0, 0, 1]"],"x":[1,1,1],"y":[0.6,0.5,0.4]}},"id":"9923f5b3-9f2d-4d84-8afe-b69770463e25","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"604923bb-0870-4d76-afc3-efd5d67186d0","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["(0, 0)","(2, 0)","(1, 1)"],"x":[0,2,1],"y":[0,0,1]}},"id":"d95caafe-9daa-4181-b9bf-d78959c2aca7","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4924daa9-ac76-49cf-a6c2-5a117eaf5a03","type":"Text"},{"attributes":{"data_source":{"id":"9923f5b3-9f2d-4d84-8afe-b69770463e25","type":"ColumnDataSource"},"glyph":{"id":"4924daa9-ac76-49cf-a6c2-5a117eaf5a03","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"604923bb-0870-4d76-afc3-efd5d67186d0","type":"Text"},"selection_glyph":null},"id":"9e1fbed4-7c84-4edd-bcff-e5438bbd99ed","type":"GlyphRenderer"},{"attributes":{},"id":"bd803f09-9052-41cc-a757-9b8e120540e9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,2,1],"y":[0,0,1]}},"id":"ab8744c8-b9f9-42da-86c3-4fa9e4263fc1","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"07239c36-2031-483c-a6ac-b43ff0442326","type":"Text"},{"attributes":{"below":[{"id":"c6126797-b8d4-4606-993e-bd48035a2b14","type":"LinearAxis"}],"left":[{"id":"df741e16-f14e-48f4-b721-bc378bc01cce","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"c6126797-b8d4-4606-993e-bd48035a2b14","type":"LinearAxis"},{"id":"e74411cd-47ba-41a0-81f8-26590384978d","type":"Grid"},{"id":"df741e16-f14e-48f4-b721-bc378bc01cce","type":"LinearAxis"},{"id":"f3a0d332-543a-47dc-959d-16753aad2294","type":"Grid"},{"id": ...

# %%
# リスト7.1.6：楕円の描画
p = figure(
    plot_width=400, plot_height=200, x_range=(-0.5, 1.5), y_range=(-0.5, 0.5))
# oval
p.oval(x=[0], y=[0], width=1, height=1, alpha=0.5)
# ellipse
p.ellipse(x=[1], y=[0], width=1, height=1, alpha=0.5)
# 注釈
# oval
p.text(
    x=[0], y=[0], text=['oval'], text_align='center', text_baseline='middle')
# ellipse
p.text(
    x=[1], y=[0], text=['ellipse'],
    text_align='center', text_baseline='middle')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d5dbab37-8fba-4135-9389-76a7140389c5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d5dbab37-8fba-4135-9389-76a7140389c5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d5dbab37-8fba-4135-9389-76a7140389c5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd5dbab37-8fba-4135-9389-76a7140389c5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80b78cf1-81f0-4025-acc0-0eac8bc4929e":{"roots":{"references":[{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc815d50-9e0d-4a4e-9d62-0dfa9668b281","type":"Text"},{"attributes":{"data_source":{"id":"66ca431f-ccab-4eef-a44e-fa0342455494","type":"ColumnDataSource"},"glyph":{"id":"e56c67dc-b49d-4313-9c2f-35034c2a018c","type":"Oval"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3bf232da-609b-4d76-a082-2f3033cad63c","type":"Oval"},"selection_glyph":null},"id":"46a112f9-4670-4eb5-a26e-9eadf60c7044","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"bee2e21e-dbde-4bfa-bc97-736ce7dc85f7","type":"BasicTickFormatter"},"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc05237f-d67a-48d8-ba30-b8e87d52cfe8","type":"BasicTicker"}},"id":"638d0af3-fbb7-47dd-8f4d-10aafcb3beea","type":"LinearAxis"},{"attributes":{},"id":"dc05237f-d67a-48d8-ba30-b8e87d52cfe8","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc05237f-d67a-48d8-ba30-b8e87d52cfe8","type":"BasicTicker"}},"id":"34c62b28-f6f8-4965-ab9f-840dbbf50658","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"707adb88-4931-4384-b573-5c11d768f605","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"3bf232da-609b-4d76-a082-2f3033cad63c","type":"Oval"},{"attributes":{},"id":"bee2e21e-dbde-4bfa-bc97-736ce7dc85f7","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"ab12063d-2550-48a5-ba12-29f046b28f4f","type":"ColumnDataSource"},"glyph":{"id":"fc815d50-9e0d-4a4e-9d62-0dfa9668b281","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a4945d31-1852-48be-9e2c-730b2e0f6943","type":"Text"},"selection_glyph":null},"id":"fd0aa709-7aed-4ac7-8cf5-848d681203d3","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3de4d1ef-22ca-45b4-9c9b-6172fffcaf6e","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"}},"id":"0a03b919-8477-46dd-9335-c3f377d03f7a","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["oval"],"x":[0],"y":[0]}},"id":"ab12063d-2550-48a5-ba12-29f046b28f4f","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e86fb29a-6eef-4082-9992-e0e8bca4f5cd","type":"Text"},{"attributes":{"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"}},"id":"83bc4721-f7c2-447e-be7d-373b5e68fb21","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"}},"id":"c59268ca-2791-44c0-b859-0d3686505dd2","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.5},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"e56c67dc-b49d-4313-9c2f-35034c2a018c","type":"Oval"},{"attributes":{"overlay":{"id":"3de4d1ef-22ca-45b4-9c9b-6172fffcaf6e","type":"BoxAnnotation"},"plot":{"id":"25b06930-5f3c-4b0c-8cbb-4f3dd69acda8","subtype":"Figure","type":"Plot"}},"id":"b58fa58a-b121-461f-80a2-d45e74bbb1ae","type":"BoxZoomTool"},{"attr ...

# %%
# リスト7.1.7：円形の描画
p = figure(plot_width=400, plot_height=400, x_range=(-0.5, 1.5), y_range=(0.5, 2.5))
p.arc(x=[0], y=[2], radius=0.5, start_angle=0, end_angle=pi * 1.5)
p.wedge(x=[0], y=[1], radius=0.5, start_angle=pi * 1.5, end_angle=0)
p.annulus(x=[1], y=[2], inner_radius=0.3, outer_radius=0.5)
p.annular_wedge(x=[1], y=[1], inner_radius=0.3, outer_radius=0.5,
                start_angle=0, end_angle=pi * 1)
# 注釈
# arc
p.text(x=[0], y=[2], text=['arc'],
       text_align='center', text_baseline='middle')
# wedge
p.text(x=[0], y=[1], text=['wedge'],
       text_align='center', text_baseline='bottom')
# annulus
p.text(x=[1], y=[2], text=['annulus'],
       text_align='center', text_baseline='middle')
# annular_wedge
p.text(x=[1], y=[1], text=['annular_wedge'],
       text_align='center', text_baseline='top')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="25936306-477a-4d0d-a6a9-b8c5aaee2579"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("25936306-477a-4d0d-a6a9-b8c5aaee2579");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25936306-477a-4d0d-a6a9-b8c5aaee2579");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25936306-477a-4d0d-a6a9-b8c5aaee2579' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bc2ebabf-8ff5-4c8d-a3d4-561c35801266":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["wedge"],"x":[0],"y":[1]}},"id":"f26df994-8a6c-42e2-9d53-0727b501d64f","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"745b8014-ec60-4edb-a952-8349a68f54fc","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"544c8020-4717-44c1-af85-051efca0fb52","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["arc"],"x":[0],"y":[2]}},"id":"ff622b4f-ba42-4475-8a09-de38b11094aa","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ff622b4f-ba42-4475-8a09-de38b11094aa","type":"ColumnDataSource"},"glyph":{"id":"745b8014-ec60-4edb-a952-8349a68f54fc","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"544c8020-4717-44c1-af85-051efca0fb52","type":"Text"},"selection_glyph":null},"id":"3447ebea-d010-4f47-ab03-a98386a978dd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"b531b468-ed7a-42a0-b481-050b82be00d2","type":"ColumnDataSource"},"glyph":{"id":"674e6307-247f-4d3f-8883-6e03f35a415f","type":"Wedge"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"86379937-e4fa-4b1f-a79a-eb0396a40005","type":"Wedge"},"selection_glyph":null},"id":"f5bdb72e-837f-4e5e-a71a-ce903b53f674","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e5fee91-71bf-400e-b14d-5bee9ad8bfb0","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[2]}},"id":"2013b6a6-e811-48e8-b2f3-eb8ebe6b876d","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":3.141592653589793},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"inner_radius":{"units":"data","value":0.3},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"outer_radius":{"units":"data","value":0.5},"start_angle":{"units":"rad","value":0},"x":{"field":"x"},"y":{"field":"y"}},"id":"203ded1b-53d3-4268-9378-c1f8c41418ab","type":"AnnularWedge"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["annulus"],"x":[1],"y":[2]}},"id":"43eb2590-82c9-48bc-91eb-464fba540c16","type":"ColumnDataSource"},{"attributes":{"end_angle":{"units":"rad","value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"start_angle":{"units":"rad","value":4.71238898038469},"x":{"field":"x"},"y":{"field":"y"}},"id":"86379937-e4fa-4b1f-a79a-eb0396a40005","type":"Wedge"},{"attributes":{"overlay":{"id":"747e506b-52f8-4637-be18-4daab9315fa2","type":"BoxAnnotation"},"plot":{"id":"875e3d80-12c3-4674-921b-052cb76eb5da","subtype":"Figure","type":"Plot"}},"id":"52bf2f56-5324-480c-bfcd-85586a30fddc","type":"BoxZoomTool"},{"attributes":{"end_angle":{"units":"rad","value":4.71238898038469},"line_color":{"value":"#1f77b4"},"radius":{"units":"data","value":0.5},"start_angle":{"units":"rad","value":0},"x":{"field":"x"},"y":{"field":"y"}},"id":"3655e801-c0a3-455c-86ad-ff10ded04f2b","type":"Arc"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"inner_radius":{"units":"data","value":0.3},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"outer_radius":{"units":"data","value":0.5},"x":{"field":"x"},"y":{"field":"y"}},"id":"9bc064d6-7175-4941-8458-3ff1bd1375dd","type":"Annulus"},{"attributes":{"data_source":{"id":"f26df994-8a6c-42e2-9d53-0727b501d64f","type":"ColumnDataSource"},"glyph":{"id":"afdb09e6-59c7-418d-b3ce-48c9cdfaa321","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5e5f ...

# %%
# リスト7.1.8：line()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.line([0, 1], [0, 1])
p.line([1, 2], [0, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e318aed7-5aed-491a-babb-af8214548688"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e318aed7-5aed-491a-babb-af8214548688");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e318aed7-5aed-491a-babb-af8214548688");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e318aed7-5aed-491a-babb-af8214548688' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f8898eeb-51ab-4672-938a-46c29165b1f1":{"roots":{"references":[{"attributes":{"plot":{"id":"eb53d6ea-e1ca-4c19-abdc-1b770882e914","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad4bd9fd-0c50-4093-a5e2-dc8626137046","type":"BasicTicker"}},"id":"b3385695-7c6e-472b-a4a1-7c75c657e91e","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"6b52ee42-ae76-439d-80d4-8ba9e8b932ae","type":"Title"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d1c88ef7-f079-4301-ae82-990f6216e742","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"eb53d6ea-e1ca-4c19-abdc-1b770882e914","subtype":"Figure","type":"Plot"},"ticker":{"id":"a6be6a6d-8f3a-4239-b497-2537d8d6978b","type":"BasicTicker"}},"id":"a538ca73-907a-46da-9a77-ecba84156e57","type":"Grid"},{"attributes":{"formatter":{"id":"4c450785-d8f4-4a18-9c2b-ad879591e7d5","type":"BasicTickFormatter"},"plot":{"id":"eb53d6ea-e1ca-4c19-abdc-1b770882e914","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad4bd9fd-0c50-4093-a5e2-dc8626137046","type":"BasicTicker"}},"id":"5b2236ee-b167-41cc-a656-94b0a16832f5","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2f46bd4f-2e07-4588-9d5c-d3ad8bc6cc11","type":"Line"},{"attributes":{"plot":{"id":"eb53d6ea-e1ca-4c19-abdc-1b770882e914","subtype":"Figure","type":"Plot"}},"id":"52f4f63d-3ea6-40e3-b1dc-228986f435f3","type":"SaveTool"},{"attributes":{},"id":"62b31b42-a42f-47da-8fb9-f463708dcf7f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"eb53d6ea-e1ca-4c19-abdc-1b770882e914","subtype":"Figure","type":"Plot"}},"id":"ed0b3000-59e8-43e8-9f3f-325afd7f13dc","type":"ResetTool"},{"attributes":{"callback":null},"id":"85d4511e-6d69-457e-9c6d-ee11c0c0f711","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"47e99713-2b5c-430c-b157-2dc002038b28","type":"PanTool"},{"id":"b2204e62-5601-492e-8feb-793c19e7acb6","type":"WheelZoomTool"},{"id":"de32237a-b7ef-4343-860d-fd3b3dcdf084","type":"BoxZoomTool"},{"id":"52f4f63d-3ea6-40e3-b1dc-228986f435f3","type":"SaveTool"},{"id":"ed0b3000-59e8-43e8-9f3f-325afd7f13dc","type":"ResetTool"},{"id":"95014d7b-e943-489b-82f1-f6d6b8268731","type":"HelpTool"}]},"id":"9572c6d7-7cc2-4b0f-be62-2b7cfd60ce53","type":"Toolbar"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3a008fda-148b-49e4-972d-378934d08592","type":"Line"},{"attributes":{},"id":"a6be6a6d-8f3a-4239-b497-2537d8d6978b","type":"BasicTicker"},{"attributes":{},"id":"ad4bd9fd-0c50-4093-a5e2-dc8626137046","type":"BasicTicker"},{"attributes":{},"id":"624a1640-c44c-42bf-ad82-498cf0eb183c","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e828c20-0669-457a-999b-29b2b767cee7","type":"Line"},{"attributes":{"below":[{"id":"5b2236ee-b167-41cc-a656-94b0a16832f5","type":"LinearAxis"}],"left":[{"id":"5314af32-f99d-4560-adde-50b4683ec831","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"5b2236ee-b167-41cc-a656-94b0a16832f5","type":"LinearAxis"},{"id":"b3385695-7c6e-472b-a4a1-7c75c657e91e","type":"Grid"},{"id":"5314af32-f99d-4560-adde-50b4683ec831","type":"LinearAxis"},{"id":"a538ca73-907a-46da-9a77-ecba84156e57","type":"Grid"},{"id":"490265d8-9ccc-45ed-b678-3e3840d74aaf","type":"BoxAnnotation"},{"id":"3c0942de-9a09-4ac2-8fec-89cc5c6a4cd6","type":"GlyphRenderer"},{"id":"cc6d5fbb-1ad6-4e3f-8fd0-b66be39aeb1a","type":"GlyphRenderer"}],"title":{"id":"6b52ee42-ae76-439d-80d4-8ba9e8b932ae","type":"Title"},"tool_events":{"id":"624a1640-c44c-42bf-ad82-498cf0eb183c","type":"ToolEvents"},"toolbar":{"id":"9572c6d7-7cc2-4b0f-be62-2b7cfd60ce53","type":"Toolbar"},"x_range":{"id":"25ca978c-daad-4184-832b-2948938ddb3d","type":"DataRange1d"},"y_range":{"id":"85d4511e-6d69-457e-9c6d-ee11c0c0f711","type":"DataRange1d"}}," ...

# %%
# リスト7.1.9：multi_line()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.multi_line([[0, 1], [1, 2]], [[0, 1], [0, 1]])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a25bc7a8-7206-459e-ba99-d468e5f7f194"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a25bc7a8-7206-459e-ba99-d468e5f7f194");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a25bc7a8-7206-459e-ba99-d468e5f7f194");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a25bc7a8-7206-459e-ba99-d468e5f7f194' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"382fe769-e780-403b-9410-10fb429d2fe5":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"00be48dc-124c-4e57-8e2a-4c10dcb0c3a8","type":"BoxAnnotation"},{"attributes":{},"id":"5a67dc8a-e2c6-4af2-9dfa-4d61bc306b1a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a67dc8a-e2c6-4af2-9dfa-4d61bc306b1a","type":"BasicTicker"}},"id":"21a3d248-90f4-49ea-8100-193bcb27c3ab","type":"Grid"},{"attributes":{"callback":null},"id":"4a140346-9119-4725-8279-6a409a27c214","type":"DataRange1d"},{"attributes":{},"id":"f5f8f95e-eac1-44c9-81c2-9ce10f762068","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"}},"id":"465d944e-e4d9-4915-92e6-55851fa37791","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"e077e669-705a-48d7-b834-9aa22207d6b3","type":"MultiLine"},{"attributes":{"below":[{"id":"5bd72fc8-4565-4c96-a8d8-21f3406816ea","type":"LinearAxis"}],"left":[{"id":"7b8583fa-8f0b-40e5-8246-32fe81380e98","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"5bd72fc8-4565-4c96-a8d8-21f3406816ea","type":"LinearAxis"},{"id":"77d3f93f-6425-4526-8a67-b43e47b53f29","type":"Grid"},{"id":"7b8583fa-8f0b-40e5-8246-32fe81380e98","type":"LinearAxis"},{"id":"21a3d248-90f4-49ea-8100-193bcb27c3ab","type":"Grid"},{"id":"00be48dc-124c-4e57-8e2a-4c10dcb0c3a8","type":"BoxAnnotation"},{"id":"8dfd20f5-3f5e-49e1-b099-12d28523f6e5","type":"GlyphRenderer"}],"title":{"id":"64481ec8-1874-43bd-b657-06ed39351e1f","type":"Title"},"tool_events":{"id":"2409452f-66e6-4694-ad5c-3c890d4c865a","type":"ToolEvents"},"toolbar":{"id":"e1ba51be-5f9b-46e5-90ca-b638748a6fc5","type":"Toolbar"},"x_range":{"id":"4a140346-9119-4725-8279-6a409a27c214","type":"DataRange1d"},"y_range":{"id":"e994822a-c275-4c52-8f65-b54f328efc8b","type":"DataRange1d"}},"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"f5f8f95e-eac1-44c9-81c2-9ce10f762068","type":"BasicTickFormatter"},"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"},"ticker":{"id":"5a67dc8a-e2c6-4af2-9dfa-4d61bc306b1a","type":"BasicTicker"}},"id":"7b8583fa-8f0b-40e5-8246-32fe81380e98","type":"LinearAxis"},{"attributes":{"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"}},"id":"c8692428-b3d7-4bb3-b641-e11a47112703","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"df976a88-a127-4668-8f01-0f8ffe143057","type":"PanTool"},{"id":"465d944e-e4d9-4915-92e6-55851fa37791","type":"WheelZoomTool"},{"id":"e042dab1-cd38-44b6-a103-5dd294e92e93","type":"BoxZoomTool"},{"id":"6d8240f0-d3f0-46b3-9348-4a98644eb7eb","type":"SaveTool"},{"id":"c8692428-b3d7-4bb3-b641-e11a47112703","type":"ResetTool"},{"id":"a59bf72e-94c0-47e3-8a41-f696d5bc9850","type":"HelpTool"}]},"id":"e1ba51be-5f9b-46e5-90ca-b638748a6fc5","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"64481ec8-1874-43bd-b657-06ed39351e1f","type":"Title"},{"attributes":{"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"}},"id":"6d8240f0-d3f0-46b3-9348-4a98644eb7eb","type":"SaveTool"},{"attributes":{"plot":{"id":"53b1f667-6b95-4b2c-a1d3-67e9fbbace57","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e9ef81c-9d96-426b-88da-58e537ec965d","type":"BasicTicker"}},"id":"77d3f93f-6425-4526-8a67-b43e47b53f29","type":"Grid"},{"attributes":{"plot":{"id":"53b1f667-6b95-4b2c-a1 ...

# %%
# リスト7.1.10：segment()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.segment(x0=[0, 1], y0=[0, 0], x1=[1, 2], y1=[1, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ea0997b3-dbf8-4748-a2d0-09b8d23132e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ea0997b3-dbf8-4748-a2d0-09b8d23132e7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ea0997b3-dbf8-4748-a2d0-09b8d23132e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ea0997b3-dbf8-4748-a2d0-09b8d23132e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c4ed355e-00d0-40d9-be28-7254ad5ee61e":{"roots":{"references":[{"attributes":{"callback":null},"id":"6ef2eaf7-7c20-43c6-8806-8d582c735eb5","type":"DataRange1d"},{"attributes":{"plot":{"id":"17bf2e70-9422-4302-b552-c0da07572510","subtype":"Figure","type":"Plot"}},"id":"67dfa14d-6cc9-4052-9211-eaa408a28de4","type":"PanTool"},{"attributes":{"plot":{"id":"17bf2e70-9422-4302-b552-c0da07572510","subtype":"Figure","type":"Plot"},"ticker":{"id":"f03847e1-4d4b-4c8a-b127-97e1875c210d","type":"BasicTicker"}},"id":"35feb0f0-583d-4598-86b9-ed35a7e7ecb1","type":"Grid"},{"attributes":{},"id":"a6d7a3d0-e08f-432d-9612-27d32a779fe6","type":"BasicTickFormatter"},{"attributes":{},"id":"8c5c6fd9-00e3-4c1f-97ca-7350a9b6695b","type":"ToolEvents"},{"attributes":{"data_source":{"id":"612c0338-229c-4233-8e3b-6e129268d4fe","type":"ColumnDataSource"},"glyph":{"id":"6668a3e5-a98f-4298-a9c8-ed24fe5d0f95","type":"Segment"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"732b1e5e-a526-446d-aa7b-5136ca7759d3","type":"Segment"},"selection_glyph":null},"id":"757b83c5-bc72-46c0-aa76-cd628c36abc9","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"a06966c6-2b21-42bf-a103-d66d9dafa220","type":"LinearAxis"}],"left":[{"id":"41153e31-1c87-4ed7-9d85-9008bb9076e9","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"a06966c6-2b21-42bf-a103-d66d9dafa220","type":"LinearAxis"},{"id":"35feb0f0-583d-4598-86b9-ed35a7e7ecb1","type":"Grid"},{"id":"41153e31-1c87-4ed7-9d85-9008bb9076e9","type":"LinearAxis"},{"id":"ea912d23-c608-45bf-b771-ab99b0c9859a","type":"Grid"},{"id":"547ca1c2-6949-46eb-a0b6-f9c2d649c9c4","type":"BoxAnnotation"},{"id":"757b83c5-bc72-46c0-aa76-cd628c36abc9","type":"GlyphRenderer"}],"title":{"id":"7507f1e0-2e57-45b0-b3c6-37fa453b34ab","type":"Title"},"tool_events":{"id":"8c5c6fd9-00e3-4c1f-97ca-7350a9b6695b","type":"ToolEvents"},"toolbar":{"id":"57948345-a778-48be-b5a7-4d808370a88a","type":"Toolbar"},"x_range":{"id":"6ef2eaf7-7c20-43c6-8806-8d582c735eb5","type":"DataRange1d"},"y_range":{"id":"8125f6ae-a118-412e-bda6-fbe0a87f7eb4","type":"DataRange1d"}},"id":"17bf2e70-9422-4302-b552-c0da07572510","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"7507f1e0-2e57-45b0-b3c6-37fa453b34ab","type":"Title"},{"attributes":{"formatter":{"id":"0c3461db-a1d7-45c2-9b40-41b749f0b5cc","type":"BasicTickFormatter"},"plot":{"id":"17bf2e70-9422-4302-b552-c0da07572510","subtype":"Figure","type":"Plot"},"ticker":{"id":"f03847e1-4d4b-4c8a-b127-97e1875c210d","type":"BasicTicker"}},"id":"a06966c6-2b21-42bf-a103-d66d9dafa220","type":"LinearAxis"},{"attributes":{},"id":"0c3461db-a1d7-45c2-9b40-41b749f0b5cc","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"732b1e5e-a526-446d-aa7b-5136ca7759d3","type":"Segment"},{"attributes":{"plot":{"id":"17bf2e70-9422-4302-b552-c0da07572510","subtype":"Figure","type":"Plot"}},"id":"4297a29e-f30d-4fbf-b4db-9cc6ac596153","type":"ResetTool"},{"attributes":{"callback":null},"id":"8125f6ae-a118-412e-bda6-fbe0a87f7eb4","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"547ca1c2-6949-46eb-a0b6-f9c2d649c9c4","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"67dfa14d-6cc9-4052-9211-eaa408a28de4","type":"PanTool"},{"id":"97e1a053-93af-4e05-8fa4-cd431b8440a8","type":"WheelZoomTool"},{"id":"a3f620f8-6b5d-4fb3-906e-9d1f15636ba8","type":"BoxZoomTool"},{"id":"4a2e36c5-a09c-4d1d-b5b3-74710e33ce5b","type":"SaveTool"},{"id":"4297a29e-f30d-4fbf-b4db-9cc6ac596153","type":"R ...

# %%
# リスト7.1.12：辞書を利用
data_dict = {'x': [1, 2], 'y': [1, 1], 'text': ['a', 'b']}
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.circle(x='x', y='y', source=data_dict)
p.line(x='x', y='y', source=data_dict)
p.text(x='x', y='y', text='text', source=data_dict)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dbb1c8eb-7364-4985-8dcb-ecbf3023c057"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dbb1c8eb-7364-4985-8dcb-ecbf3023c057");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dbb1c8eb-7364-4985-8dcb-ecbf3023c057");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dbb1c8eb-7364-4985-8dcb-ecbf3023c057' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1e768646-be03-4fc5-b2bc-e7ade80601af":{"roots":{"references":[{"attributes":{},"id":"5fab4d2d-ddee-4704-a1a4-8130fdba2a23","type":"ToolEvents"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ffaf8d40-a86d-4e09-9362-052f17b7c0e6","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"560b63dc-011e-463c-a35c-1be922976364","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"e6b3a3cc-6f23-43f1-8179-20bce65fd5ef","type":"LinearAxis"}],"left":[{"id":"970f3f63-e01a-4dc3-8abb-2989cb906ab8","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"e6b3a3cc-6f23-43f1-8179-20bce65fd5ef","type":"LinearAxis"},{"id":"76274de1-9680-4131-87db-277caa1b4cb8","type":"Grid"},{"id":"970f3f63-e01a-4dc3-8abb-2989cb906ab8","type":"LinearAxis"},{"id":"e2ddc46b-758d-4cbb-adba-8aeabaef138a","type":"Grid"},{"id":"2b502778-d24b-41e0-80db-8df713d93849","type":"BoxAnnotation"},{"id":"a31f95ac-e6f2-49d7-b58e-3a43cc93e357","type":"GlyphRenderer"},{"id":"852f415a-9903-42ac-98ad-fe005b250fa5","type":"GlyphRenderer"},{"id":"f017b2dd-c049-42ab-a733-83ee170533df","type":"GlyphRenderer"}],"title":{"id":"cfc42090-79a2-4ad0-bf28-ebfed5e9dc10","type":"Title"},"tool_events":{"id":"5fab4d2d-ddee-4704-a1a4-8130fdba2a23","type":"ToolEvents"},"toolbar":{"id":"6bf55544-d15d-4f42-981f-e0502afa6e5b","type":"Toolbar"},"x_range":{"id":"42f3aea8-2a7c-4f53-b1b8-4421e600dfe8","type":"Range1d"},"y_range":{"id":"2e829edf-0dec-4039-af57-eb357b8ac5fb","type":"DataRange1d"}},"id":"713ae68c-8781-4441-922c-5343409b93f1","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"713ae68c-8781-4441-922c-5343409b93f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc47d2c7-26e2-4456-b9df-cc6c1367a4d3","type":"BasicTicker"}},"id":"76274de1-9680-4131-87db-277caa1b4cb8","type":"Grid"},{"attributes":{"formatter":{"id":"f68f488d-0208-4f6c-abd2-4f1c5ca689e4","type":"BasicTickFormatter"},"plot":{"id":"713ae68c-8781-4441-922c-5343409b93f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"ffad9885-8de2-4135-82c8-222a133e8b90","type":"BasicTicker"}},"id":"970f3f63-e01a-4dc3-8abb-2989cb906ab8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"b3d93f04-3227-4a3d-95cc-f14c80c49c3b","type":"ColumnDataSource"},"glyph":{"id":"0bf4cbe7-4c03-4d00-91e8-5d28106e1687","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2dfa6c50-c735-4d13-9857-62206be4349a","type":"Line"},"selection_glyph":null},"id":"852f415a-9903-42ac-98ad-fe005b250fa5","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"713ae68c-8781-4441-922c-5343409b93f1","subtype":"Figure","type":"Plot"}},"id":"40a73eba-ca70-41ae-a47c-9a5b2f14efc1","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e815545d-08fe-4e09-8f3c-1e3484c5c12d","type":"PanTool"},{"id":"40a73eba-ca70-41ae-a47c-9a5b2f14efc1","type":"WheelZoomTool"},{"id":"f5c17fea-0295-4c8a-a871-40e12979a477","type":"BoxZoomTool"},{"id":"cbaba3c1-0ae8-492e-9f82-f3a12f6d728a","type":"SaveTool"},{"id":"2202b2ff-0f6f-49cb-b758-a5ae1cab764e","type":"ResetTool"},{"id":"6478684f-7e59-4bfb-a2ae-0c179138c78f","type":"HelpTool"}]},"id":"6bf55544-d15d-4f42-981f-e0502afa6e5b","type":"Toolbar"},{"attributes":{"overlay":{"id":"2b502778-d24b-41e0-80db-8df713d93849","type":"BoxAnnotation"},"plot":{"id":"713ae68c-8781-4441-922c-5343409b93f1","subtype":"Figure","type":"Plot"}},"id":"f5c17fea-0295-4c8a-a871-40e12979a477","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"ee9f59db-13e4-4728-9133-85f4ded9ee1c","type":"ColumnDataSource"},"glyph":{"id":"57256576-9048-4b2b-90cf-b2cea61dc630","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ffaf8d40-a86d-4e09-9362-052f17b7c0e6","type":"Text"},"selection_glyph":null},"id":"f017b2dd-c049-42ab-a733-83ee170533df","type":"GlyphRender ...

# %%
# リスト7.1.13：DataFrameを利用
import pandas as pd
df = pd.DataFrame(data_dict)
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.circle(x='x', y='y', source=df)
p.line(x='x', y='y', source=df)
p.text(x='x', y='y', text='text', source=df)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a504db9a-820e-461e-aa47-cb1c8965a92d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a504db9a-820e-461e-aa47-cb1c8965a92d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a504db9a-820e-461e-aa47-cb1c8965a92d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a504db9a-820e-461e-aa47-cb1c8965a92d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25508676-9863-4782-9d59-50575d237087":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"a302b28d-b13e-4744-bda3-fb36fb1cc41d","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4744c62f-927d-4007-ab6f-20dde8b53201","type":"Circle"},{"attributes":{"formatter":{"id":"39668c5e-0337-4152-a8ea-5818948187c8","type":"BasicTickFormatter"},"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9ffcf89-a74e-4937-945d-8ed6d7527e54","type":"BasicTicker"}},"id":"683616c2-9226-45a9-9337-d3fa8f0b316d","type":"LinearAxis"},{"attributes":{"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"abdeadcc-6d20-4542-97b7-50d563da0e86","type":"Text"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9724e54d-6efc-4ea8-b398-def0ba7f0cc8","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["text","x","y","index"],"data":{"index":[0,1],"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"a327d0a6-46e2-4d1f-a89d-e9bc990e6f72","type":"ColumnDataSource"},{"attributes":{},"id":"d9ffcf89-a74e-4937-945d-8ed6d7527e54","type":"BasicTicker"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c41bfa4c-ea71-4bbd-bab4-da4ecae574fd","type":"Text"},{"attributes":{},"id":"4a84f268-c6c2-4ab5-8433-325c181f1f15","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"}},"id":"a4ef5932-eab3-4e5c-a899-59ada9b8d9bb","type":"PanTool"},{"attributes":{"callback":null,"column_names":["text","x","y","index"],"data":{"index":[0,1],"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"cff55852-14b6-4af1-907e-636ce4715e3d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["text","x","y","index"],"data":{"index":[0,1],"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"5e75834e-b6e5-4738-9bfd-d86f209c9652","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cff55852-14b6-4af1-907e-636ce4715e3d","type":"ColumnDataSource"},"glyph":{"id":"abdeadcc-6d20-4542-97b7-50d563da0e86","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c41bfa4c-ea71-4bbd-bab4-da4ecae574fd","type":"Text"},"selection_glyph":null},"id":"cad47173-b8fb-483a-8597-48a2049cccab","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"}},"id":"1b96c854-f7d8-4cc0-a943-a49d423774ba","type":"HelpTool"},{"attributes":{"callback":null},"id":"14eacaff-3531-4ea3-b749-3f1862b3101e","type":"DataRange1d"},{"attributes":{},"id":"bbe8bfe7-4e81-4bf9-9a35-4788cac1ba38","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9ffcf89-a74e-4937-945d-8ed6d7527e54","type":"BasicTicker"}},"id":"90a2ef65-660d-4d57-b4b1-d489bac5bbfa","type":"Grid"},{"attributes":{},"id":"39668c5e-0337-4152-a8ea-5818948187c8","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"}},"id":"f0c402ef-da1c-4d03-afcb-d9394e8cfdb1","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"c48edaea-6dd3-42e5-81a0-42d80c1c9753","subtype":"Figure","type":"Plot"},"ticker":{"id":"fe01571f-9226-4393-a20d-b566b3ce390e","type":"BasicTicker"}},"id":"c1cb650a-8a8f-4788-8f93-885aec06f138","type":"Grid"},{"attributes":{"data_source":{"id":"5e75834e-b6e5-4738-9bfd-d86f209c9652","type":"ColumnDataSource"},"glyph":{"id":"09b39101-0f96-4 ...
