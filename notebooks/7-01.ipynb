# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-1: さまざまな図形の描画

# %%
# リスト7.1.1：テキストの描画
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.text([1, 2], [1, 1], text=["text1", "text2"])
p.x([1, 2], [1, 1], size=10)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5f266e9f-5d8d-47cd-849b-6e12196f1ee4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="771510b3-a940-4281-a95c-77cdcf4ce208"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("771510b3-a940-4281-a95c-77cdcf4ce208");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("771510b3-a940-4281-a95c-77cdcf4ce208");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '771510b3-a940-4281-a95c-77cdcf4ce208' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ea06d10a-8384-48c4-a3e7-5d70586fa325":{"roots":{"references":[{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"7d1a1b33-a483-4ead-8bdc-258266e00a09","type":"Range1d"},{"attributes":{},"id":"4f422e4c-4ae7-482a-ac1c-b3abc2851111","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"7e59f714-011a-49ab-886c-2b7bf85170ab","type":"BoxAnnotation"},"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"}},"id":"3f5702d7-59ae-41ff-af4b-97f1e4c5d113","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7e59f714-011a-49ab-886c-2b7bf85170ab","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4b69d69a-6c97-4fd7-a771-e8f20f990d8d","type":"PanTool"},{"id":"85379589-0018-4904-9ef0-5f496469e9ed","type":"WheelZoomTool"},{"id":"3f5702d7-59ae-41ff-af4b-97f1e4c5d113","type":"BoxZoomTool"},{"id":"e7c3f887-7509-4240-ac6b-87812dd60802","type":"SaveTool"},{"id":"d96b092f-2493-40b7-8388-cfcc6f2cc702","type":"ResetTool"},{"id":"82b2209e-10d7-468f-9d85-a55eff72b73d","type":"HelpTool"}]},"id":"21cf3642-92e2-4e2d-b7f5-71b551d9fe42","type":"Toolbar"},{"attributes":{"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"}},"id":"e7c3f887-7509-4240-ac6b-87812dd60802","type":"SaveTool"},{"attributes":{"callback":null},"id":"f3a78f31-cf3f-4f95-a014-a639d2583345","type":"DataRange1d"},{"attributes":{"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"}},"id":"d96b092f-2493-40b7-8388-cfcc6f2cc702","type":"ResetTool"},{"attributes":{"formatter":{"id":"4f422e4c-4ae7-482a-ac1c-b3abc2851111","type":"BasicTickFormatter"},"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3810a5f-c116-4db7-8b95-c53aee6bbb4e","type":"BasicTicker"}},"id":"271321b1-d77f-42ee-ac60-000803b1f60b","type":"LinearAxis"},{"attributes":{"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"}},"id":"82b2209e-10d7-468f-9d85-a55eff72b73d","type":"HelpTool"},{"attributes":{},"id":"b3810a5f-c116-4db7-8b95-c53aee6bbb4e","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"68d8b8bc-c198-47f5-a506-eacd5f370bdd","type":"Title"},{"attributes":{},"id":"8f44de9b-8819-4314-ba9f-7302ebd67718","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"},"ticker":{"id":"b3810a5f-c116-4db7-8b95-c53aee6bbb4e","type":"BasicTicker"}},"id":"66307352-951b-41c0-b4e0-629e528fbbc7","type":"Grid"},{"attributes":{"formatter":{"id":"8f44de9b-8819-4314-ba9f-7302ebd67718","type":"BasicTickFormatter"},"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4398f456-eee9-4f75-abf3-0eca457c2a4c","type":"BasicTicker"}},"id":"398ee1e9-56f2-472c-8815-21c1779f7c1c","type":"LinearAxis"},{"attributes":{"data_source":{"id":"4878053c-bfdf-47cf-96cc-aeb50c20f220","type":"ColumnDataSource"},"glyph":{"id":"d36b0664-7a13-4aee-ab0f-6c960804f06b","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"33eda6de-790b-4e72-94c8-3fd820754d67","type":"Text"},"selection_glyph":null},"id":"cb9b6461-b999-4b68-929c-8ad6eb60f3c1","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e458e6c-a249-4110-8e9a-66bc5a7bd0fd","type":"X"},{"attributes":{},"id":"4398f456-eee9-4f75-abf3-0eca457c2a4c","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"eaae16d8-ca06-496d-8233-f85a0f7f198f","subtype" ...

# %%
# リスト7.1.2：circle()メソッドによる円形の描画
p = figure(plot_width=200, plot_height=200)
p.circle([1, 2], [1, 2])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6453b49-1edd-4d17-9a25-d0a292f965bd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e6453b49-1edd-4d17-9a25-d0a292f965bd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6453b49-1edd-4d17-9a25-d0a292f965bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6453b49-1edd-4d17-9a25-d0a292f965bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"28a2d3f3-46ab-4312-b1ed-d1d75954b228":{"roots":{"references":[{"attributes":{},"id":"91742715-48c9-421b-b8aa-e38e4a20c2df","type":"BasicTicker"},{"attributes":{"callback":null},"id":"b2356a17-f46b-4379-8967-ac75086c575d","type":"DataRange1d"},{"attributes":{"plot":{"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"}},"id":"f92ed91b-af8f-4da1-8ee6-edc5fc9a823b","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"d3df6331-12b7-4745-9305-21e3d7d950ee","type":"ColumnDataSource"},"glyph":{"id":"62f7e16a-d9c0-4ded-86fd-1129f8e14b89","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f4341ad7-1681-484a-b4c9-ddeca90514bc","type":"Circle"},"selection_glyph":null},"id":"2e270c4d-d68a-43ed-91ee-1c6e5bf1cf6b","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"38001462-63c2-4ef7-98a2-9233d64fcc09","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f4341ad7-1681-484a-b4c9-ddeca90514bc","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2],"y":[1,2]}},"id":"d3df6331-12b7-4745-9305-21e3d7d950ee","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"}},"id":"b17dc70e-9b98-40fc-96ad-049432e5c352","type":"SaveTool"},{"attributes":{"below":[{"id":"b161ee21-44d6-42d2-9ed7-dcb67b3db8aa","type":"LinearAxis"}],"left":[{"id":"3a9c4b2d-8c5d-44fe-9a41-71e69664f989","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"b161ee21-44d6-42d2-9ed7-dcb67b3db8aa","type":"LinearAxis"},{"id":"8da2c57e-1e14-469b-814a-8707833d090c","type":"Grid"},{"id":"3a9c4b2d-8c5d-44fe-9a41-71e69664f989","type":"LinearAxis"},{"id":"8c0f8b33-560c-4f99-9449-fde95025d910","type":"Grid"},{"id":"2e0559e9-89cf-4452-980e-33197a5d52ac","type":"BoxAnnotation"},{"id":"2e270c4d-d68a-43ed-91ee-1c6e5bf1cf6b","type":"GlyphRenderer"}],"title":{"id":"69c37ff3-7b66-417a-a7ff-472ae50c7545","type":"Title"},"tool_events":{"id":"4b2fc589-403a-4bc3-9e6f-18d200b2beeb","type":"ToolEvents"},"toolbar":{"id":"d3ea07e4-28f1-4fba-bc29-2ec9eac7cf07","type":"Toolbar"},"x_range":{"id":"38001462-63c2-4ef7-98a2-9233d64fcc09","type":"DataRange1d"},"y_range":{"id":"b2356a17-f46b-4379-8967-ac75086c575d","type":"DataRange1d"}},"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"2e0559e9-89cf-4452-980e-33197a5d52ac","type":"BoxAnnotation"},"plot":{"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"}},"id":"3ddd734f-acca-453d-8321-72d817c12b03","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"85a6da28-4bed-49d4-af0b-8968d98eb7d4","type":"BasicTicker"}},"id":"8da2c57e-1e14-469b-814a-8707833d090c","type":"Grid"},{"attributes":{},"id":"7d7d60cf-f0d1-489e-a169-b611dab14236","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"32cbd457-27ab-427d-96f5-3e40c9d96e07","type":"PanTool"},{"id":"f92ed91b-af8f-4da1-8ee6-edc5fc9a823b","type":"WheelZoomTool"},{"id":"3ddd734f-acca-453d-8321-72d817c12b03","type":"BoxZoomTool"},{"id":"b17dc70e-9b98-40fc-96ad-049432e5c352","type":"SaveTool"},{"id":"f9d337ce-3e67-42b6-9961-4c223f2a1501","type":"ResetTool"},{"id":"288dadbf-df84-4484-8151-64aba7fdea44","type":"HelpTool"}]},"id":"d3ea07e4-28f1-4fba-bc29-2ec9eac7cf07","type":"Toolbar"},{"attributes":{"formatter":{"id":"232e6754-74e9-4b73-860e-19ca244488c7","type":"BasicTickFormatter"},"plot":{"id":"7cafc007-31a2-49d4-a139-17541b740a29","subtype":"Figure","type":"Plot"},"ticker":{"id":"85a6da28-4bed-49d4-af0b-8968d98eb7d4","type":"BasicTicker"}},"id":"b161ee21-44d6-42d2-9ed7-dcb67b3db8aa","type":"LinearAxis"},{"attributes" ...

# %%
# リスト7.1.4：長方形の描画
from numpy import pi

p = figure(plot_width=400, plot_height=400, x_range=(-6, 6))
# quad
p.quad(top=[12], bottom=[10], left=[-1], right=[1], alpha=0.5)
# rect
p.rect(x=[0], y=[8], width=2, height=2, angle=pi * 0.25, alpha=0.5)
# vbar
p.vbar(x=[0], bottom=[4], top=[6], width=2, alpha=0.5)
# hbar
p.hbar(y=[2], left=[-1], right=[1], height=2, alpha=0.5)
# 注釈
# quad
p.text([-4], [11], text=["quad"], text_baseline="middle")
p.text(
    [0, 0, -1, 1],
    [12, 10, 11, 11],
    text=["top=12", "bottom=10", "left=-1", "right=1"],
    text_align="center",
    text_baseline="middle",
)
# rect
p.text([-4], [8], text=["rect"], text_baseline="middle")
p.text([0], [8], text=["x=0, y=8"], text_align="center", text_baseline="middle")
p.text(
    [-1],
    [8.5],
    text=["width=2"],
    angle=pi * 0.25,
    text_align="center",
    text_baseline="middle",
)
p.text(
    [1],
    [8.5],
    text=["height=2"],
    angle=pi * -0.25,
    text_align="center",
    text_baseline="middle",
)
p.text([0], [7], text=["angle=pi*0.25"], text_align="center", text_baseline="middle")
# vbar
p.text([-4], [5], text=["vbar"], text_baseline="middle")
p.text([0], [5], text=["x=0, width=2"], text_align="center", text_baseline="middle")
p.text(
    [0, 0],
    [6, 4],
    text=["top=6", "bottom=4"],
    text_align="center",
    text_baseline="middle",
)
# hbar
p.text([-4], [2], text=["hbar"], text_baseline="middle")
p.text(
    [0, 0],
    [2.2, 1.8],
    text=["y=2,", "height=2"],
    text_align="center",
    text_baseline="middle",
)
p.text(
    [-1.5, 1.5],
    [2, 2],
    text=["left=-1", "right=1"],
    angle=pi * 0.5,
    text_align="center",
    text_baseline="middle",
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="88191af3-c15d-4b2f-9e66-66896332cc51"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("88191af3-c15d-4b2f-9e66-66896332cc51");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("88191af3-c15d-4b2f-9e66-66896332cc51");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '88191af3-c15d-4b2f-9e66-66896332cc51' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dfacaf13-1adb-4fba-9d1b-746d8e5389b1":{"roots":{"references":[{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"765db60e-9b0d-4da2-8964-266c7715e46a","type":"Quad"},{"attributes":{"angle":{"units":"rad","value":1.5707963267948966},"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"10ce634a-5572-489f-9a03-66fadcaaa6c8","type":"Text"},{"attributes":{"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"963df900-8d5c-4a1e-825e-343cfb33ee18","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["top=6","bottom=4"],"x":[0,0],"y":[6,4]}},"id":"6dad12ca-353b-43eb-817d-cb9d5fb21b40","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b5c446b5-f589-4a3c-a50e-f15c7fd02dc3","type":"ColumnDataSource"},"glyph":{"id":"a34f0765-438d-46d1-9f54-b818092a5d60","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"765db60e-9b0d-4da2-8964-266c7715e46a","type":"Quad"},"selection_glyph":null},"id":"cfdadaeb-62db-4158-a5f6-0cf0ac45fbd2","type":"GlyphRenderer"},{"attributes":{},"id":"7a6a11e1-0102-4454-bd90-0c4747204f03","type":"BasicTicker"},{"attributes":{"callback":null},"id":"64f11ba2-8940-4601-9561-5007407aa706","type":"DataRange1d"},{"attributes":{"data_source":{"id":"aaaf881e-0d50-4df8-85f0-b6004ac63f43","type":"ColumnDataSource"},"glyph":{"id":"d472f937-993d-4d24-9b51-7a8ef7347714","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b3f61f43-5448-498a-9c05-56c8106c1364","type":"Text"},"selection_glyph":null},"id":"63f233e1-46f0-4d44-80c6-727379ec08bd","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"6ad1196d-5a62-4734-94ca-b400ad90ed51","type":"BasicTickFormatter"},"plot":{"id":"a79604dc-d7bd-428f-a8e1-5cb042516477","subtype":"Figure","type":"Plot"},"ticker":{"id":"579a7735-3649-42bb-8f06-5670272cc8da","type":"BasicTicker"}},"id":"ee31250d-c487-4955-bb1b-3c576b44dcaf","type":"LinearAxis"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e4be6ebd-7a10-4289-ae2e-d1f47079e8f7","type":"Text"},{"attributes":{},"id":"579a7735-3649-42bb-8f06-5670272cc8da","type":"BasicTicker"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f7e02515-f9a2-4ba8-8600-96c275206e6b","type":"Text"},{"attributes":{"plot":{"id":"a79604dc-d7bd-428f-a8e1-5cb042516477","subtype":"Figure","type":"Plot"},"ticker":{"id":"579a7735-3649-42bb-8f06-5670272cc8da","type":"BasicTicker"}},"id":"cce0371c-3e34-4a50-963d-593b75669635","type":"Grid"},{"attributes":{"data_source":{"id":"6dad12ca-353b-43eb-817d-cb9d5fb21b40","type":"ColumnDataSource"},"glyph":{"id":"e4be6ebd-7a10-4289-ae2e-d1f47079e8f7","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f7e02515-f9a2-4ba8-8600-96c275206e6b","type":"Text"},"selection_glyph":null},"id":"faa44ec6-0a8e-4988-a3ce-6aa4252fa4d1","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"06d438c4-2031-404e-b24f-8b8d2aef50f6","type":"BasicTickFormatter"},"plot":{"id":"a79604dc-d7bd-428f-a8e1-5cb042516477","subtype":"Figure","type":"Plot"},"ticker":{"id":"7a6a11e1-0102-4454-bd90-0c4747204f03","type":"BasicTicker"}},"id":"ab3b655f-6fb8-45a3-83b0-321d369df207","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"6d8f22cc-40b6-44e5-90df-6145f3a60458","type":"Title"},{"attributes":{"angle":{"units":"rad","value":1.5707963267948966},"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id" ...

# %%
# リスト7.1.5：多角形の描画
p = figure(plot_width=400, plot_height=400, x_range=(-0.5, 5.5))
# patch
p.patch([0, 2, 1], [0, 0, 1], alpha=0.5)
# patches
p.patches([[3, 4, 3], [4, 5, 5]], [[0, 0, 1], [1, 1, 0]], alpha=0.5)
# 注釈
# patch
p.text(
    [1, 1, 1],
    [0.6, 0.5, 0.4],
    text=["patch", "x=[0, 2, 1]", "y=[0, 0, 1]"],
    text_align="center",
    text_baseline="middle",
)
p.text(
    [0, 2, 1],
    [0, 0, 1],
    text=["(0, 0)", "(2, 0)", "(1, 1)"],
    text_align="center",
    text_baseline="middle",
)
# patches
p.text(
    [4, 4, 4],
    [0.6, 0.5, 0.4],
    text=["patches", "xs=[[3, 4, 3], [4, 5, 5]]", "ys=[[0, 0, 1], [1, 1, 0]]"],
    text_align="center",
    text_baseline="middle",
)
p.text(
    [3, 4, 3],
    [0, 0, 1],
    text=["(3, 0)", "(4, 0)", "(3, 1)"],
    text_align="center",
    text_baseline="middle",
)
p.text(
    [4, 5, 5],
    [1, 1, 0],
    text=["(4, 1)", "(5, 1)", "(5, 0)"],
    text_align="center",
    text_baseline="middle",
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="328dd25c-b502-4483-80e1-b2a24fc32dd1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("328dd25c-b502-4483-80e1-b2a24fc32dd1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("328dd25c-b502-4483-80e1-b2a24fc32dd1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '328dd25c-b502-4483-80e1-b2a24fc32dd1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bc6d4c94-86fd-4541-a03a-fb1e1aaac236":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"681f2fcf-2617-4e96-92b4-846574f06e05","type":"PanTool"},{"id":"b446eabe-0023-44f1-923e-d74a2185d6ac","type":"WheelZoomTool"},{"id":"a0d43d5a-08e3-4f26-b99a-9c78c240cf04","type":"BoxZoomTool"},{"id":"71eacf7a-998b-40eb-9623-72587de96d41","type":"SaveTool"},{"id":"40ccbf8b-0ac5-41ae-9bdf-b48783b1b127","type":"ResetTool"},{"id":"ff1fe8ff-d6cc-496a-9aa6-dd657a7576d8","type":"HelpTool"}]},"id":"55742dda-9df6-445e-b850-1301fb24368f","type":"Toolbar"},{"attributes":{"data_source":{"id":"ada849ce-e92b-4fdd-b695-c4e397da1f74","type":"ColumnDataSource"},"glyph":{"id":"5fca8070-e750-4f6e-b70b-e7bf4a27b64c","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"79c245a9-2e2b-4148-87a3-f66253620892","type":"Text"},"selection_glyph":null},"id":"1b037572-efed-4286-8612-e7c82f9fad9c","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"865c7d00-2e9e-42f0-a4ad-df6afc4bff33","type":"DataRange1d"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f61c784c-9969-4323-8e57-49efa9d1009a","type":"Text"},{"attributes":{"formatter":{"id":"1654170a-62b8-46f6-a638-4b2f0c533d40","type":"BasicTickFormatter"},"plot":{"id":"14554833-ced1-42c8-b9bc-bceb4f76286c","subtype":"Figure","type":"Plot"},"ticker":{"id":"fff54739-6471-499a-9fb6-f845bda077f8","type":"BasicTicker"}},"id":"de23085c-0e98-4419-82a8-f11c31b147eb","type":"LinearAxis"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9a154fea-99f6-418f-91b9-32dc4ad88dfa","type":"Text"},{"attributes":{"data_source":{"id":"926498e3-281e-4263-a62a-f3e3c699909a","type":"ColumnDataSource"},"glyph":{"id":"28b19ad7-d977-4030-8a8e-dc5da0b08f6a","type":"Patch"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ffed3b12-6110-466b-8088-542cc150212f","type":"Patch"},"selection_glyph":null},"id":"db2d4c2f-68e9-4754-9ffb-07dade86f6e4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e1cfac75-525b-475c-9b87-b6cecf4d7d04","type":"ColumnDataSource"},"glyph":{"id":"c3a226dc-2600-4e62-af4a-15a3b4e079dd","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"65d77744-bcb4-4dcd-9a56-0dd76debd021","type":"Text"},"selection_glyph":null},"id":"9195dbb3-89c1-4699-9c42-92d438bff96c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"14554833-ced1-42c8-b9bc-bceb4f76286c","subtype":"Figure","type":"Plot"},"ticker":{"id":"fff54739-6471-499a-9fb6-f845bda077f8","type":"BasicTicker"}},"id":"ba52d46b-4335-48b7-8fd2-1491159400ea","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["(3, 0)","(4, 0)","(3, 1)"],"x":[3,4,3],"y":[0,0,1]}},"id":"ada849ce-e92b-4fdd-b695-c4e397da1f74","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"105f97fd-4e67-4bba-8d86-389ba77b5048","type":"Title"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"46094392-3339-4ad2-8abc-9e44b65633cd","type":"Text"},{"attributes":{"dimension":1,"plot":{"id":"14554833-ced1-42c8-b9bc-bceb4f76286c","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae3ff682-2a40-446c-8736-3c4d60b70c57","type":"BasicTicker"}},"id":"2a96ee04-e1f2-4c94-b93b-e5671211c834","type":"Grid"},{"attributes":{"data_source":{"id":"b0133189-da5d-4552-ba96-79275d409e26","type":"ColumnDataSource"},"glyph":{"id":"46094392-3339-4ad2-8abc-9e44b65633cd","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f61c784c-9969-4323-8e57-49efa9d1009a","type":"Text"},"selection_glyph":null},"id":"cf603ce9-1f45-4c2c-bc85-b8e0e9989fb6","type":"GlyphRenderer"},{"attributes":{},"id":"ae3ff682 ...

# %%
# リスト7.1.6：楕円の描画
p = figure(plot_width=400, plot_height=200, x_range=(-0.5, 1.5), y_range=(-0.5, 0.5))
# oval
p.oval(x=[0], y=[0], width=1, height=1, alpha=0.5)
# ellipse
p.ellipse(x=[1], y=[0], width=1, height=1, alpha=0.5)
# 注釈
# oval
p.text(x=[0], y=[0], text=["oval"], text_align="center", text_baseline="middle")
# ellipse
p.text(x=[1], y=[0], text=["ellipse"], text_align="center", text_baseline="middle")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="64226e07-496e-4614-b949-dc8ca08f7edc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("64226e07-496e-4614-b949-dc8ca08f7edc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64226e07-496e-4614-b949-dc8ca08f7edc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64226e07-496e-4614-b949-dc8ca08f7edc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8eec2f0a-cf54-4305-ae08-7a5e9423b0dd":{"roots":{"references":[{"attributes":{"plot":{"id":"9a97bf27-5434-4874-bae2-69760c8f97a4","subtype":"Figure","type":"Plot"}},"id":"01b939e3-be66-44e1-a466-6826338066a9","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"918ed61f-0604-40b6-a71f-6eafc59707a1","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"6d795e71-35f1-4a43-91c1-1b54d6e1810a","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"9a97bf27-5434-4874-bae2-69760c8f97a4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c01d312e-c868-47cc-93f8-6bb769e87320","type":"BasicTicker"}},"id":"a0600aa6-5790-4850-91f7-66389a16c1b8","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"68479198-51ea-4774-a771-803a141a3cce","type":"Title"},{"attributes":{},"id":"ce44ec5c-e050-4634-9cf0-7acc192e77ed","type":"ToolEvents"},{"attributes":{"data_source":{"id":"6d795e71-35f1-4a43-91c1-1b54d6e1810a","type":"ColumnDataSource"},"glyph":{"id":"88523779-27cc-4f59-9757-56bff6114a36","type":"Oval"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7ffc18b8-981c-4bb5-bc4c-e25658baaee4","type":"Oval"},"selection_glyph":null},"id":"cbc45aff-423a-44ff-9ade-6f5de9d6fe3d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9a97bf27-5434-4874-bae2-69760c8f97a4","subtype":"Figure","type":"Plot"},"ticker":{"id":"d29cbf65-2ee4-47b1-b2c8-1db6024478b4","type":"BasicTicker"}},"id":"111b01e4-63be-493e-bded-f9ed04c75f5d","type":"Grid"},{"attributes":{"overlay":{"id":"918ed61f-0604-40b6-a71f-6eafc59707a1","type":"BoxAnnotation"},"plot":{"id":"9a97bf27-5434-4874-bae2-69760c8f97a4","subtype":"Figure","type":"Plot"}},"id":"8c3dfea2-aab1-4bbb-939a-6e069fbe3c12","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["oval"],"x":[0],"y":[0]}},"id":"f40602b9-047e-4bf1-891c-4ecfa5ebb9f5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1],"y":[0]}},"id":"b9da8428-36fa-4228-bd5e-5c832b4437ad","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":1},"line_alpha":{"value":0.5},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd735be8-1cc3-4f46-ba41-395a4360224f","type":"Ellipse"},{"attributes":{"data_source":{"id":"f40602b9-047e-4bf1-891c-4ecfa5ebb9f5","type":"ColumnDataSource"},"glyph":{"id":"2ba9f464-27cb-4527-a776-65067d04341a","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"dba1f68b-4166-495b-be2b-dd9400fba58a","type":"Text"},"selection_glyph":null},"id":"b9cdb34b-92b9-4535-92a5-885f84f1a554","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0dc51418-d652-4620-a83b-73ddc54ec6d8","type":"ColumnDataSource"},"glyph":{"id":"b4dd5b7e-036d-4d2d-8178-ff1516b68d95","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e7384cd6-e4f7-454b-98f2-cd14f79c6d01","type":"Text"},"selection_glyph":null},"id":"e61ed27d-2912-48a4-aa27-cb69c84113a3","type":"GlyphRenderer"},{"attributes":{},"id":"e047c7ce-e558-4426-89d2-73d9dece7693","type":"BasicTickFormatter"},{"attributes":{},"id":"4a4cc7bd-98d3-40aa-989a-08b2e78a7ce0","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"e047c7ce-e558-4426-89d2-73d9dece7693","type":"BasicTickFormatter"},"plot":{"id":"9a97bf27-5434-4874-bae2-69760c8f97a4","subtype":"Figure","type":"Plot"},"ticker":{"id":"d29cbf65-2ee4-47b1-b2c8-1db6024478b4","type":"BasicTicker"}},"id":"b6cbe30f-4ce6-4b25-a49f-9503093aabe8","type":"LinearAxis"},{"attr ...

# %%
# リスト7.1.7：円形の描画
p = figure(plot_width=400, plot_height=400, x_range=(-0.5, 1.5), y_range=(0.5, 2.5))
p.arc(x=[0], y=[2], radius=0.5, start_angle=0, end_angle=pi * 1.5)
p.wedge(x=[0], y=[1], radius=0.5, start_angle=pi * 1.5, end_angle=0)
p.annulus(x=[1], y=[2], inner_radius=0.3, outer_radius=0.5)
p.annular_wedge(
    x=[1], y=[1], inner_radius=0.3, outer_radius=0.5, start_angle=0, end_angle=pi * 1
)
# 注釈
# arc
p.text(x=[0], y=[2], text=["arc"], text_align="center", text_baseline="middle")
# wedge
p.text(x=[0], y=[1], text=["wedge"], text_align="center", text_baseline="bottom")
# annulus
p.text(x=[1], y=[2], text=["annulus"], text_align="center", text_baseline="middle")
# annular_wedge
p.text(x=[1], y=[1], text=["annular_wedge"], text_align="center", text_baseline="top")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6dd9ef3-7962-469f-b97b-242d53ba776b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d6dd9ef3-7962-469f-b97b-242d53ba776b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6dd9ef3-7962-469f-b97b-242d53ba776b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6dd9ef3-7962-469f-b97b-242d53ba776b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"899da896-a923-483b-a0b1-dedc067a412b":{"roots":{"references":[{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2691bf84-6861-465f-a32a-0d7d1797de78","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"33326c51-cad4-4bb6-ba12-d0d535572cdd","type":"Text"},{"attributes":{"data_source":{"id":"62907aea-6c85-4d86-a4b7-ee2fe2bee94e","type":"ColumnDataSource"},"glyph":{"id":"2691bf84-6861-465f-a32a-0d7d1797de78","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"33326c51-cad4-4bb6-ba12-d0d535572cdd","type":"Text"},"selection_glyph":null},"id":"347a27b4-d31d-438a-a8db-9b601bc1b7b9","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"aa08c354-3d77-4d05-ae0c-f74b05dc87a6","type":"LinearAxis"}],"left":[{"id":"66e444f9-edfc-4e14-8d5d-e40f51433c48","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"aa08c354-3d77-4d05-ae0c-f74b05dc87a6","type":"LinearAxis"},{"id":"57d79d7c-70a0-40ad-9b1f-314df7f98731","type":"Grid"},{"id":"66e444f9-edfc-4e14-8d5d-e40f51433c48","type":"LinearAxis"},{"id":"3e573f0c-7a77-46c9-85c6-de803cfb6c76","type":"Grid"},{"id":"5c772fc6-1a2b-4151-9279-64ae58c9c570","type":"BoxAnnotation"},{"id":"4244d612-9bd0-4f56-85be-a99f646f1cdd","type":"GlyphRenderer"},{"id":"861ea83b-d5c3-459b-9c18-9f367d4eda67","type":"GlyphRenderer"},{"id":"49ea8286-f8aa-4383-aa48-57cfb61a5a4f","type":"GlyphRenderer"},{"id":"ed73519e-d0d9-4039-88a5-28308fefd551","type":"GlyphRenderer"},{"id":"294f8948-0f06-444a-b0e4-63d2de773a09","type":"GlyphRenderer"},{"id":"347a27b4-d31d-438a-a8db-9b601bc1b7b9","type":"GlyphRenderer"},{"id":"bc21135e-f400-49de-bbcd-3531fd68b878","type":"GlyphRenderer"},{"id":"2ed8cc07-dc2b-4758-b39b-34b112864070","type":"GlyphRenderer"}],"title":{"id":"2e8988ef-657b-4071-9470-606442877208","type":"Title"},"tool_events":{"id":"e4ec2fe4-4482-4cdb-9b66-0d315b75194f","type":"ToolEvents"},"toolbar":{"id":"7999f3b7-9338-4804-b7c6-de40e74767cb","type":"Toolbar"},"x_range":{"id":"789cff51-a7b0-4742-b578-9a0daeee6d06","type":"Range1d"},"y_range":{"id":"0b632649-e4aa-40d9-8eff-ceca08ab67f3","type":"Range1d"}},"id":"9e3cb3b8-bf87-4d72-b45a-5a3aa8ee4b96","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"8f92ba26-d34e-49fb-8a5f-7936483e8685","type":"ColumnDataSource"},"glyph":{"id":"9d37ee3c-0784-4bd7-96f5-f3a779a1b771","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"34deca87-075a-4f88-b47f-808622bf1144","type":"Text"},"selection_glyph":null},"id":"294f8948-0f06-444a-b0e4-63d2de773a09","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f93d0a7-4802-44a5-9251-96668dbf469c","type":"Text"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9d37ee3c-0784-4bd7-96f5-f3a779a1b771","type":"Text"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["annular_wedge"],"x":[1],"y":[1]}},"id":"1c3dd783-875a-4f88-bb65-ec50d5299eaa","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["wedge"],"x":[0],"y":[1]}},"id":"62907aea-6c85-4d86-a4b7-ee2fe2bee94e","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"2e8988ef-657b-4071-9470-606442877208","type":"Title"},{"attributes":{"text_align":"center","text_baseline":"middle","text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67514e14-42c6-43f6-88b2-7faa6253d620","type":"Text"},{"attributes":{"data_source":{"id":"65154d40-a0dc-476b-869d-eca76cc5eef4","type":"ColumnDataSource"},"glyph":{"id":"67514e14-42c6-43f6-88b2-7faa6253d620","type":"Text"},"hover_glyph":null,"muted_glyph":nu ...

# %%
# リスト7.1.8：line()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.line([0, 1], [0, 1])
p.line([1, 2], [0, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="71b09e6b-56d3-4286-bceb-0ff297738014"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("71b09e6b-56d3-4286-bceb-0ff297738014");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("71b09e6b-56d3-4286-bceb-0ff297738014");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '71b09e6b-56d3-4286-bceb-0ff297738014' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ad6a2fe-d7a2-4aca-86fd-ea81161eae3d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2],"y":[0,1]}},"id":"8fd38f26-4f21-4401-acbe-c0278f4c0999","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"}},"id":"8ef01d1a-7072-47bc-85eb-71581d687b3a","type":"ResetTool"},{"attributes":{"overlay":{"id":"391dd9a7-b540-48af-a83c-1a2dd25a44b7","type":"BoxAnnotation"},"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"}},"id":"b15b4870-06eb-4e5b-8aff-0d77e4f8eb83","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"391dd9a7-b540-48af-a83c-1a2dd25a44b7","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"}},"id":"191895e2-0f93-40dc-a840-24ad06eaf0ce","type":"SaveTool"},{"attributes":{"data_source":{"id":"8fd38f26-4f21-4401-acbe-c0278f4c0999","type":"ColumnDataSource"},"glyph":{"id":"a5980e8a-5abc-4d87-a7f6-b9d84ef81aa6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e9dff1a7-a5b9-45f5-a489-b4e5d8e6ceea","type":"Line"},"selection_glyph":null},"id":"62a5f6ca-8efe-4375-9a1a-ce0622182880","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"0b1c1a40-ac46-42c8-9a54-3ddb39a532ba","type":"DataRange1d"},{"attributes":{"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"}},"id":"22f54775-a7bd-448c-b44e-2640857dd9a5","type":"HelpTool"},{"attributes":{},"id":"431fbc30-6b71-4042-ace2-7390742b6442","type":"BasicTicker"},{"attributes":{"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"},"ticker":{"id":"a3385571-338a-46e6-83d8-5c172ab1447f","type":"BasicTicker"}},"id":"a2c11d07-35ac-432f-8cca-545482ff4031","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"},"ticker":{"id":"431fbc30-6b71-4042-ace2-7390742b6442","type":"BasicTicker"}},"id":"ed725eaf-4761-4f10-89ac-228e4f895618","type":"Grid"},{"attributes":{},"id":"7d7f5ee2-e497-4084-ae26-efac29f63396","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5980e8a-5abc-4d87-a7f6-b9d84ef81aa6","type":"Line"},{"attributes":{"below":[{"id":"46631494-2bfb-429e-bed0-c015d6f5c1fe","type":"LinearAxis"}],"left":[{"id":"6ebc818f-99a3-4812-9810-139b559428a2","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"46631494-2bfb-429e-bed0-c015d6f5c1fe","type":"LinearAxis"},{"id":"a2c11d07-35ac-432f-8cca-545482ff4031","type":"Grid"},{"id":"6ebc818f-99a3-4812-9810-139b559428a2","type":"LinearAxis"},{"id":"ed725eaf-4761-4f10-89ac-228e4f895618","type":"Grid"},{"id":"391dd9a7-b540-48af-a83c-1a2dd25a44b7","type":"BoxAnnotation"},{"id":"9ad8f962-a8ce-48e6-9666-1ce97e0e39f8","type":"GlyphRenderer"},{"id":"62a5f6ca-8efe-4375-9a1a-ce0622182880","type":"GlyphRenderer"}],"title":{"id":"6a6fd3b0-2380-43ea-b720-c02f99af4795","type":"Title"},"tool_events":{"id":"7d7f5ee2-e497-4084-ae26-efac29f63396","type":"ToolEvents"},"toolbar":{"id":"034d5e29-3b08-4a02-a8fa-41d1ce8de491","type":"Toolbar"},"x_range":{"id":"0b1c1a40-ac46-42c8-9a54-3ddb39a532ba","type":"DataRange1d"},"y_range":{"id":"1c99d4f5-44db-445a-b8c6-4e084d090418","type":"DataRange1d"}},"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5bd48d3f-2793-406b-a617-f97777725459","subtype":"Figure","type":"Plot"}},"id":"d7452559-0bfd-434b-9d7f-94aac2909c6e","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":[ ...

# %%
# リスト7.1.9：multi_line()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.multi_line([[0, 1], [1, 2]], [[0, 1], [0, 1]])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b9864f85-ae68-489b-a5c6-8ad0326ee538"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b9864f85-ae68-489b-a5c6-8ad0326ee538");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b9864f85-ae68-489b-a5c6-8ad0326ee538");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b9864f85-ae68-489b-a5c6-8ad0326ee538' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"628fdefe-e857-4b7d-a4e4-b7f9773d6935":{"roots":{"references":[{"attributes":{"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"}},"id":"7db746bf-3f6d-41e5-9578-6fcb7b7c7486","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"}},"id":"62199662-7d3c-4601-a109-314f7225d744","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"0f7f513c-59d5-410e-9585-befb9dca5f5d","type":"Title"},{"attributes":{"callback":null,"column_names":["xs","ys"],"data":{"xs":[[0,1],[1,2]],"ys":[[0,1],[0,1]]}},"id":"de0e68f7-9e5b-492c-9e6d-c810e20d754e","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"4ae4f01d-ec2a-4a7d-81e5-68a46ebcd2a5","type":"LinearAxis"}],"left":[{"id":"79cbf247-5c72-4f58-a4f7-53d2d6bdc18a","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"4ae4f01d-ec2a-4a7d-81e5-68a46ebcd2a5","type":"LinearAxis"},{"id":"47fe25a9-feaa-43ed-b759-676aba498c92","type":"Grid"},{"id":"79cbf247-5c72-4f58-a4f7-53d2d6bdc18a","type":"LinearAxis"},{"id":"42f09fb9-0fc5-423e-b284-5d8e2862491b","type":"Grid"},{"id":"a98ae7f3-e6c7-4db1-a563-a260d323d60d","type":"BoxAnnotation"},{"id":"b4c4f191-2130-4187-895e-69f13c16c270","type":"GlyphRenderer"}],"title":{"id":"0f7f513c-59d5-410e-9585-befb9dca5f5d","type":"Title"},"tool_events":{"id":"dd7f4a11-8764-4625-ace9-ba3a31ee3335","type":"ToolEvents"},"toolbar":{"id":"b4c32786-b708-4281-a49d-ebbf07fc8ead","type":"Toolbar"},"x_range":{"id":"d482b537-aacd-487a-83f9-1ee61a2d0d7a","type":"DataRange1d"},"y_range":{"id":"8130ec19-1abc-4cf6-891d-0da8f7097c14","type":"DataRange1d"}},"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"3e07495c-0b67-4dc9-a754-28981b5d5157","type":"BasicTickFormatter"},{"attributes":{},"id":"dd7f4a11-8764-4625-ace9-ba3a31ee3335","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"595f773b-facc-490a-b290-5ad4cfe81471","type":"MultiLine"},{"attributes":{"formatter":{"id":"3e07495c-0b67-4dc9-a754-28981b5d5157","type":"BasicTickFormatter"},"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"},"ticker":{"id":"91615851-f253-4989-89ba-0300d6acdf2f","type":"BasicTicker"}},"id":"4ae4f01d-ec2a-4a7d-81e5-68a46ebcd2a5","type":"LinearAxis"},{"attributes":{},"id":"6ed6afc8-b6f1-46f0-8ceb-a262cff39878","type":"BasicTickFormatter"},{"attributes":{},"id":"91615851-f253-4989-89ba-0300d6acdf2f","type":"BasicTicker"},{"attributes":{"formatter":{"id":"6ed6afc8-b6f1-46f0-8ceb-a262cff39878","type":"BasicTickFormatter"},"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f115182-0029-46a5-9cf2-4e512df6f371","type":"BasicTicker"}},"id":"79cbf247-5c72-4f58-a4f7-53d2d6bdc18a","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a98ae7f3-e6c7-4db1-a563-a260d323d60d","type":"BoxAnnotation"},{"attributes":{},"id":"0f115182-0029-46a5-9cf2-4e512df6f371","type":"BasicTicker"},{"attributes":{"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"}},"id":"57bd617c-978c-41c0-b55f-34489319a9c2","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"789061ea-dced-4c4f-9337-2cc6adef0101","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f115182-0029-46a5-9cf2-4e512df6f371","type":"BasicTicker"}},"id":"42f09fb9-0fc5-423e-b284-5d8e2862491b","type":"Grid"},{"attributes":{"data_source":{"id":"de0e68f7-9e5b-492c-9e6d-c810e20d754e","type":"ColumnDataSource"},"glyph":{"id":"32dea9c5-ab7c-46c7-88a1-03ebb51f53b1","type":"MultiLi ...

# %%
# リスト7.1.10：segment()メソッドの利用
p = figure(plot_width=200, plot_height=200)
p.segment(x0=[0, 1], y0=[0, 0], x1=[1, 2], y1=[1, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a819d2c5-e10e-4539-a34e-3877e2a72838"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a819d2c5-e10e-4539-a34e-3877e2a72838");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a819d2c5-e10e-4539-a34e-3877e2a72838");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a819d2c5-e10e-4539-a34e-3877e2a72838' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ae5dcaa4-7772-4ddd-94c6-a14ea26a20ad":{"roots":{"references":[{"attributes":{"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"}},"id":"6962b1fd-e295-4d58-9405-9a02d75763b9","type":"ResetTool"},{"attributes":{"overlay":{"id":"ad520d77-8b29-4387-ae53-224af7aedd0a","type":"BoxAnnotation"},"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"}},"id":"842dcbcb-b7fd-45bc-813d-055af4dc7770","type":"BoxZoomTool"},{"attributes":{},"id":"9a05a30c-a3af-4f42-b71c-12996bfb4312","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#1f77b4"},"x0":{"field":"x0"},"x1":{"field":"x1"},"y0":{"field":"y0"},"y1":{"field":"y1"}},"id":"cb62fce1-269c-452f-90cd-0e200046a63c","type":"Segment"},{"attributes":{"data_source":{"id":"8aae8fa8-ea50-4e4d-ae0f-7e18f4dfed9b","type":"ColumnDataSource"},"glyph":{"id":"cb62fce1-269c-452f-90cd-0e200046a63c","type":"Segment"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"01977e90-96cd-4011-af9f-33e48067dc31","type":"Segment"},"selection_glyph":null},"id":"ec688d83-9127-4ead-b4ea-da2ecd65d05c","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"dda3e200-8026-4a83-91b3-fefd0684b32f","type":"BasicTickFormatter"},"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"6c45384c-1d1d-4a98-b05a-be3408d1211b","type":"BasicTicker"}},"id":"9692eef5-e287-4a4f-83e4-c3ec709b92ef","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"6c45384c-1d1d-4a98-b05a-be3408d1211b","type":"BasicTicker"}},"id":"cc764364-0e31-45e9-b3b3-1e69fc9b8dae","type":"Grid"},{"attributes":{"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a05a30c-a3af-4f42-b71c-12996bfb4312","type":"BasicTicker"}},"id":"46949861-e058-4915-82bb-fd166982351b","type":"Grid"},{"attributes":{},"id":"dda3e200-8026-4a83-91b3-fefd0684b32f","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"68835d2c-1332-41e2-adb6-d10f58250489","type":"Title"},{"attributes":{},"id":"286efea4-47b9-49bc-8e82-624e069305e5","type":"ToolEvents"},{"attributes":{"callback":null},"id":"6343de17-b559-4a4a-9f93-a7cfb6126de6","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c491b1aa-75f1-46ef-86b6-88dd2d2dd26d","type":"PanTool"},{"id":"778df69a-c836-4a5e-b9da-9de5df926b38","type":"WheelZoomTool"},{"id":"842dcbcb-b7fd-45bc-813d-055af4dc7770","type":"BoxZoomTool"},{"id":"baceba75-92f3-4d36-ad10-472d939e6d2a","type":"SaveTool"},{"id":"6962b1fd-e295-4d58-9405-9a02d75763b9","type":"ResetTool"},{"id":"6a5dd9ee-f9ab-43b6-9dc1-0725bf6abd36","type":"HelpTool"}]},"id":"fdf5ffcd-7c1a-411a-9460-70e85810126c","type":"Toolbar"},{"attributes":{"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"}},"id":"778df69a-c836-4a5e-b9da-9de5df926b38","type":"WheelZoomTool"},{"attributes":{},"id":"283a788c-42ae-46df-a643-09637d7175c9","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"283a788c-42ae-46df-a643-09637d7175c9","type":"BasicTickFormatter"},"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a05a30c-a3af-4f42-b71c-12996bfb4312","type":"BasicTicker"}},"id":"75315a88-2d7c-46f0-9f65-2ef644968028","type":"LinearAxis"},{"attributes":{"plot":{"id":"87cc0f07-38a3-4c12-b575-e0a72bb5c3a3","subtype":"Figure","type":"Plot"}},"id":"baceba75-92f3-4d36-ad10-472d939e6d2a","type":"SaveTool"},{"attributes":{"callback":null},"id":"545cc1cd-bec0-42fd-bde4-c25bd813d8ea","type":"DataRange1d"},{"attributes":{},"id":"6c45384c-1d1d-4a98-b05a-be3408d1211b","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"li ...

# %%
# リスト7.1.12：辞書を利用
data_dict = {"x": [1, 2], "y": [1, 1], "text": ["a", "b"]}
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.circle(x="x", y="y", source=data_dict)
p.line(x="x", y="y", source=data_dict)
p.text(x="x", y="y", text="text", source=data_dict)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d4c97fd7-bf62-4c95-9076-3f4a0b68b05e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d4c97fd7-bf62-4c95-9076-3f4a0b68b05e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d4c97fd7-bf62-4c95-9076-3f4a0b68b05e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd4c97fd7-bf62-4c95-9076-3f4a0b68b05e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1ccef53c-bd4a-4743-9264-2c89404b8e73":{"roots":{"references":[{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5191bfb8-0cfd-4ec6-9174-6c466dd767cf","type":"Line"},{"attributes":{"data_source":{"id":"a0eee4ae-de90-4fd8-9f29-4f69d43ebb98","type":"ColumnDataSource"},"glyph":{"id":"5191bfb8-0cfd-4ec6-9174-6c466dd767cf","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e7aa03b1-30ef-4aeb-a55c-26482085d034","type":"Line"},"selection_glyph":null},"id":"6b6fd6db-1297-46a9-9fa8-e59b375bb523","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7aa03b1-30ef-4aeb-a55c-26482085d034","type":"Line"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4276f813-d3c4-4999-bb4d-336fb9ff8af9","type":"Text"},{"attributes":{"text_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"60bf7a77-6ef8-47dc-8a72-637e363098e0","type":"Text"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7f47dd1c-d764-4717-958c-f54b0efbeca2","type":"PanTool"},{"id":"8489e1d6-2c24-4b9c-9a5f-067298490a65","type":"WheelZoomTool"},{"id":"cfbfbfe2-b2e0-46fb-aaf6-65ec44f58d3a","type":"BoxZoomTool"},{"id":"82cd8deb-a449-4d8c-bcfc-b08c2d1e237e","type":"SaveTool"},{"id":"f3964ae1-cec4-43a8-8ced-c75f857d4335","type":"ResetTool"},{"id":"54566744-79fc-4a29-9d85-221c15a51134","type":"HelpTool"}]},"id":"1d0b0845-8aca-4bc9-8820-895f5a2ba590","type":"Toolbar"},{"attributes":{"overlay":{"id":"65f2dcf5-d696-4ca1-b0ca-aac4bad1a3cd","type":"BoxAnnotation"},"plot":{"id":"e119f172-c857-407a-8074-18790c7d3e1e","subtype":"Figure","type":"Plot"}},"id":"cfbfbfe2-b2e0-46fb-aaf6-65ec44f58d3a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"1a13bc0b-c606-420b-9cb0-dca0508932a0","type":"LinearAxis"}],"left":[{"id":"614310ed-96a0-42a2-be1a-3c12e68b6838","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"1a13bc0b-c606-420b-9cb0-dca0508932a0","type":"LinearAxis"},{"id":"63e89b6d-70bf-48ca-8968-b7e5a788fb93","type":"Grid"},{"id":"614310ed-96a0-42a2-be1a-3c12e68b6838","type":"LinearAxis"},{"id":"a3da04ba-9d14-4531-9370-6dd51176a309","type":"Grid"},{"id":"65f2dcf5-d696-4ca1-b0ca-aac4bad1a3cd","type":"BoxAnnotation"},{"id":"88822d9d-e6e8-4641-bbd0-1a5d6ab580c2","type":"GlyphRenderer"},{"id":"6b6fd6db-1297-46a9-9fa8-e59b375bb523","type":"GlyphRenderer"},{"id":"1d4bcdf1-6df9-4482-aee0-06e94dbbe596","type":"GlyphRenderer"}],"title":{"id":"795d4fe2-dc67-49bf-8a38-19d18b50efb0","type":"Title"},"tool_events":{"id":"e494c839-2044-4bde-88cc-d4f1ac164f2c","type":"ToolEvents"},"toolbar":{"id":"1d0b0845-8aca-4bc9-8820-895f5a2ba590","type":"Toolbar"},"x_range":{"id":"c70ae390-a81f-4513-8413-64316ae0194c","type":"Range1d"},"y_range":{"id":"08e758ee-e95d-48bf-b84f-14ed05d3bbb8","type":"DataRange1d"}},"id":"e119f172-c857-407a-8074-18790c7d3e1e","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"3ed18568-5a50-4c84-8ca2-bf700711fc56","type":"ColumnDataSource"},"glyph":{"id":"60bf7a77-6ef8-47dc-8a72-637e363098e0","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4276f813-d3c4-4999-bb4d-336fb9ff8af9","type":"Text"},"selection_glyph":null},"id":"1d4bcdf1-6df9-4482-aee0-06e94dbbe596","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e119f172-c857-407a-8074-18790c7d3e1e","subtype":"Figure","type":"Plot"}},"id":"54566744-79fc-4a29-9d85-221c15a51134","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"3ed18568-5a50-4c84-8ca2-bf700711fc56","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"13e17424-d80a ...

# %%
# リスト7.1.13：DataFrameを利用
import pandas as pd

df = pd.DataFrame(data_dict)
p = figure(plot_width=200, plot_height=200, x_range=(0.5, 2.5))
p.circle(x="x", y="y", source=df)
p.line(x="x", y="y", source=df)
p.text(x="x", y="y", text="text", source=df)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8199104c-939f-4e99-8195-14ac130efa0e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8199104c-939f-4e99-8195-14ac130efa0e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8199104c-939f-4e99-8195-14ac130efa0e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8199104c-939f-4e99-8195-14ac130efa0e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"81bb46b6-9a49-414b-a22f-105c86389db1":{"roots":{"references":[{"attributes":{"plot":{"id":"57349699-0611-462f-bd93-626171ee2dd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"9ac75337-3c4b-4499-8d6b-64ac1ddbf87e","type":"BasicTicker"}},"id":"87ed2fca-0653-4c93-b249-012c25e3eb16","type":"Grid"},{"attributes":{},"id":"5978bf67-319c-469d-9dee-ec47dc00b222","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"57349699-0611-462f-bd93-626171ee2dd1","subtype":"Figure","type":"Plot"}},"id":"64ea9417-6f96-43df-9861-b778167c1048","type":"HelpTool"},{"attributes":{"data_source":{"id":"238194dc-fbe9-458f-b539-2bddd7b60037","type":"ColumnDataSource"},"glyph":{"id":"5afbb076-3e28-4e71-86fc-b3cb97bfd46f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2f5d021c-f5c6-438a-bb17-957f80b3818e","type":"Circle"},"selection_glyph":null},"id":"ea19089f-22f8-440f-9808-917c2658fc4b","type":"GlyphRenderer"},{"attributes":{},"id":"8cc623c7-c739-47ef-a8cc-0755c5cf6f49","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["text","x","y","index"],"data":{"index":[0,1],"text":["a","b"],"x":[1,2],"y":[1,1]}},"id":"64c3ecdb-24b0-42f1-a024-51473f395630","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"c00d0cb3-1246-43e9-981f-3e65c557d040","type":"Title"},{"attributes":{"below":[{"id":"8c258243-7141-4962-a48c-5b88e06dd74f","type":"LinearAxis"}],"left":[{"id":"b8ed459b-67e2-485c-9ce6-1c61f1293c71","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"8c258243-7141-4962-a48c-5b88e06dd74f","type":"LinearAxis"},{"id":"87ed2fca-0653-4c93-b249-012c25e3eb16","type":"Grid"},{"id":"b8ed459b-67e2-485c-9ce6-1c61f1293c71","type":"LinearAxis"},{"id":"9f0b6bda-e9ff-45f0-a55c-31967e736744","type":"Grid"},{"id":"bbc52045-0cc6-423c-9370-baa786cac2e5","type":"BoxAnnotation"},{"id":"ea19089f-22f8-440f-9808-917c2658fc4b","type":"GlyphRenderer"},{"id":"231a90c4-f803-4151-8e45-15cc4fe70984","type":"GlyphRenderer"},{"id":"d8fb9440-162b-4858-8fc5-a0c7c22d0579","type":"GlyphRenderer"}],"title":{"id":"c00d0cb3-1246-43e9-981f-3e65c557d040","type":"Title"},"tool_events":{"id":"eed3bbca-12e9-4d16-b193-cafc030fc429","type":"ToolEvents"},"toolbar":{"id":"42f43c1b-a1a6-45cd-8e9e-64fb7fdfa429","type":"Toolbar"},"x_range":{"id":"3aca104f-b1e1-48a7-b317-73266d0c92ad","type":"Range1d"},"y_range":{"id":"ef917228-50ad-4c15-a660-f6aa7795bb67","type":"DataRange1d"}},"id":"57349699-0611-462f-bd93-626171ee2dd1","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"cbe00e14-976b-4156-8605-23fdb6728a13","type":"ColumnDataSource"},"glyph":{"id":"611aead8-78bd-4276-bf41-e68990f01385","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b2d47747-c3df-4cc8-9bdf-951913122e7c","type":"Line"},"selection_glyph":null},"id":"231a90c4-f803-4151-8e45-15cc4fe70984","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"64c3ecdb-24b0-42f1-a024-51473f395630","type":"ColumnDataSource"},"glyph":{"id":"49fe4df2-968c-48ff-aa8d-a087d24d5c59","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5db59cd4-478f-4af0-84e4-aabce571b47d","type":"Text"},"selection_glyph":null},"id":"d8fb9440-162b-4858-8fc5-a0c7c22d0579","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"57349699-0611-462f-bd93-626171ee2dd1","subtype":"Figure","type":"Plot"},"ticker":{"id":"8cc623c7-c739-47ef-a8cc-0755c5cf6f49","type":"BasicTicker"}},"id":"9f0b6bda-e9ff-45f0-a55c-31967e736744","type":"Grid"},{"attributes":{"plot":{"id":"57349699-0611-462f-bd93-626171ee2dd1","subtype":"Figure","type":"Plot"}},"id":"d0b25204-d4b3-4f0c-9e32-b9dc09acd22b","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"02a8a76b-4cb5-44bd-ac43-ff55a72e96e5","type":"PanTool"},{"id":"d0b25204-d4b3-4f0c-9e32-b9dc09acd22b","type":"WheelZoomTool"},{"id":"667c3a9a-c821-462d-b0c2-b9c6eb081970","type":" ...
