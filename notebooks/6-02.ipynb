# %%
# ●リスト6.2.1：高レベルのインタフェースを使用したグラフの例
from bokeh.charts import output_notebook, Line, show
output_notebook()
p = Line([1, 2], plot_width=200, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fd92d54b-b0c2-48c3-a2fd-ee8ceeb31de2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="79eec183-c2ef-427e-8569-af2ddfb20f0c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("79eec183-c2ef-427e-8569-af2ddfb20f0c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79eec183-c2ef-427e-8569-af2ddfb20f0c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79eec183-c2ef-427e-8569-af2ddfb20f0c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d8af828-3bca-494a-8a70-f7a0e37148c5":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"7bab32d8-9509-4d06-b834-9a3dc39f1b61","type":"Title"},{"attributes":{"label":{"value":"a"},"renderers":[{"id":"e61f6c04-f5e7-4597-9f99-d3253911a816","type":"GlyphRenderer"}]},"id":"06256dde-fe17-41ea-84dc-c443eb9508f2","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4618c4e0-6bf8-4105-ab83-112705c6fe5c","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"32e0929a-9b33-490e-8fd6-14162debda71","type":"ColumnDataSource"},"glyph":{"id":"9aa1c74a-c02c-4468-8440-848b01ec29a5","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"e61f6c04-f5e7-4597-9f99-d3253911a816","type":"GlyphRenderer"},{"attributes":{},"id":"657e4b2e-c83d-4609-8b93-c4adfb10d8d8","type":"BasicTickFormatter"},{"attributes":{"axis_label":"value","formatter":{"id":"657e4b2e-c83d-4609-8b93-c4adfb10d8d8","type":"BasicTickFormatter"},"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"},"ticker":{"id":"3ab4a638-db35-4d0f-ab29-410650e83c49","type":"BasicTicker"}},"id":"72f1f313-4ea4-44e3-a42c-652997779c05","type":"LinearAxis"},{"attributes":{"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"}},"id":"21bd6286-b774-4771-8e6c-804fd4d93ea1","type":"PanTool"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9aa1c74a-c02c-4468-8440-848b01ec29a5","type":"Line"},{"attributes":{"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"}},"id":"943d71ac-1de4-4bdc-a022-c48625e4be30","type":"WheelZoomTool"},{"attributes":{"callback":null,"end":2.1,"start":0.9},"id":"3a2d7b7f-a0d6-4536-8989-4e81155bcdf1","type":"Range1d"},{"attributes":{},"id":"38d849d2-b82e-43ab-a244-d71ec8a673fe","type":"ToolEvents"},{"attributes":{"overlay":{"id":"4618c4e0-6bf8-4105-ab83-112705c6fe5c","type":"BoxAnnotation"},"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"}},"id":"c35c3216-3205-4332-b079-a4d21ddb8ad0","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"}},"id":"bc4c2cd4-9cb6-43c2-889b-63928610502d","type":"SaveTool"},{"attributes":{"below":[{"id":"a0c4f78e-e241-4660-b8c0-ffd579598cef","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"72f1f313-4ea4-44e3-a42c-652997779c05","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"4618c4e0-6bf8-4105-ab83-112705c6fe5c","type":"BoxAnnotation"},{"id":"e61f6c04-f5e7-4597-9f99-d3253911a816","type":"GlyphRenderer"},{"id":"4714025c-2475-47cb-b358-76dee54d7fe8","type":"Legend"},{"id":"a0c4f78e-e241-4660-b8c0-ffd579598cef","type":"LinearAxis"},{"id":"72f1f313-4ea4-44e3-a42c-652997779c05","type":"LinearAxis"},{"id":"0c9741fa-747d-4d58-940f-7b7e04796381","type":"Grid"},{"id":"9d538847-5a71-470c-97a9-3748d7cf7f07","type":"Grid"}],"title":{"id":"7bab32d8-9509-4d06-b834-9a3dc39f1b61","type":"Title"},"tool_events":{"id":"38d849d2-b82e-43ab-a244-d71ec8a673fe","type":"ToolEvents"},"toolbar":{"id":"aaa0f276-66d6-417e-8581-53676243951a","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"9631f340-5e7d-40c5-b4fa-beac186f02be","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"3a2d7b7f-a0d6-4536-8989-4e81155bcdf1","type":"Range1d"}},"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"33b78c06-097d-4979-b38e-18350029abbb","subtype":"Chart","type":"Plot"}},"id":"074cbfca-8f3a-4f26-98fa-53cb575e790e","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"a ...

# %%
# ●リスト6.2.2：中レベルのインタフェースを使用したグラフの例
from bokeh.plotting import output_notebook, figure, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.line([1, 2], [1, 2])
p.circle([1.5], [1.5])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="83ad9572-ca02-4080-9a71-f5aded6e6fd2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68319b59-88e3-41a2-bcb7-9da7e766e957"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("68319b59-88e3-41a2-bcb7-9da7e766e957");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68319b59-88e3-41a2-bcb7-9da7e766e957");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68319b59-88e3-41a2-bcb7-9da7e766e957' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1081e7c8-c2c3-4db4-915a-95263ad8b0ca":{"roots":{"references":[{"attributes":{},"id":"e7a65c42-4839-4b60-8590-045a9c2e4594","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"5259cb11-b229-44f0-8b11-be155b936efc","type":"BoxAnnotation"},"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"}},"id":"c0f0b867-2213-4e8d-acb5-85831fcea68a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"b6bf1bcf-6469-4520-b481-e244911b6c17","type":"LinearAxis"}],"left":[{"id":"1b92d611-ef07-4504-a608-10a1e30c5e0c","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"b6bf1bcf-6469-4520-b481-e244911b6c17","type":"LinearAxis"},{"id":"9e423b2a-c2a1-4223-aecc-60c4aa152e28","type":"Grid"},{"id":"1b92d611-ef07-4504-a608-10a1e30c5e0c","type":"LinearAxis"},{"id":"3edea043-93a2-4709-aa5b-c88430b9cc6f","type":"Grid"},{"id":"5259cb11-b229-44f0-8b11-be155b936efc","type":"BoxAnnotation"},{"id":"c75de143-47e2-4555-9d00-44d804e89f21","type":"GlyphRenderer"},{"id":"62e5cedb-2127-4fb7-af71-2deb69b58fc6","type":"GlyphRenderer"}],"title":{"id":"4a698be2-1645-42dc-a209-7582d7673677","type":"Title"},"tool_events":{"id":"2ab4d0f6-6cc1-466e-98a5-ef62de687693","type":"ToolEvents"},"toolbar":{"id":"70486bd1-1930-40d6-a00f-4dcc30094945","type":"Toolbar"},"x_range":{"id":"a8e964e9-eb2a-4f61-b394-f0ae66f10f1a","type":"DataRange1d"},"y_range":{"id":"ef60dbbd-ac02-4a57-bbef-e8c8edb59664","type":"DataRange1d"}},"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e3d265a-55b6-49a3-9fee-28aacfbd8041","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5259cb11-b229-44f0-8b11-be155b936efc","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"}},"id":"ee766dd2-d5e1-4319-8443-fc3229738a6b","type":"SaveTool"},{"attributes":{"formatter":{"id":"60485525-8b9b-4159-a5ce-3785dd99b41b","type":"BasicTickFormatter"},"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3078dc48-7729-407f-9500-38b7690e7ef5","type":"BasicTicker"}},"id":"b6bf1bcf-6469-4520-b481-e244911b6c17","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2],"y":[1,2]}},"id":"e3414b58-ddf4-4b8d-b2a1-b7e7a8f90de8","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a8e964e9-eb2a-4f61-b394-f0ae66f10f1a","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"4a698be2-1645-42dc-a209-7582d7673677","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4c313a4c-3871-42a9-8323-89e043844808","type":"PanTool"},{"id":"ba17f704-fb0c-4862-8775-c3eb654dff1a","type":"WheelZoomTool"},{"id":"c0f0b867-2213-4e8d-acb5-85831fcea68a","type":"BoxZoomTool"},{"id":"ee766dd2-d5e1-4319-8443-fc3229738a6b","type":"SaveTool"},{"id":"c3805a23-c86a-4da1-a8b7-f0a554b43339","type":"ResetTool"},{"id":"96771a21-c6f6-4343-bbc7-7731220dbc69","type":"HelpTool"}]},"id":"70486bd1-1930-40d6-a00f-4dcc30094945","type":"Toolbar"},{"attributes":{"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"}},"id":"ba17f704-fb0c-4862-8775-c3eb654dff1a","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"}},"id":"96771a21-c6f6-4343-bbc7-7731220dbc69","type":"HelpTool"},{"attributes":{"plot":{"id":"48cec58c-e825-4b4e-830b-73c94c7c5c0c","subtype":"Figure","type":"Plot"}},"id":"c3805a23-c86a-4da1-a8b7-f0a554b43339","typ ...

# %%
# ●リスト6.2.3：低レベルのインタフェースを利用したグラフの例
from bokeh.plotting import output_notebook, figure, show
from bokeh.models import LinearAxis, Range1d
output_notebook()
p = figure(width=300, height=300, toolbar_location='above')
p.extra_y_ranges = {"small_data": Range1d(start=0, end=5)}
p.line([1, 2, 3], [1, 2, 3], y_range_name="small_data")
p.circle([1, 2, 3], [2000, 3000, 1000])
p.add_layout(LinearAxis(y_range_name="small_data"), 'right')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="adf537d1-e037-45d0-a444-139d8eb5a41a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3972cbf-ca39-4467-ac8e-9b513d605aca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a3972cbf-ca39-4467-ac8e-9b513d605aca");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3972cbf-ca39-4467-ac8e-9b513d605aca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3972cbf-ca39-4467-ac8e-9b513d605aca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c36122c4-c44a-43dd-a5b8-0a91644c6693":{"roots":{"references":[{"attributes":{},"id":"0e33b3d8-9a9b-44d8-a9dd-07959fd73ffd","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fb92f751-715d-4147-b887-cd4037ebf9f3","type":"PanTool"},{"id":"a3a4a03d-9f4d-49e3-8499-ba792dd47911","type":"WheelZoomTool"},{"id":"d2e33e04-2dfe-4e20-8daf-e45fd3cae484","type":"BoxZoomTool"},{"id":"122afe2a-61dc-439a-8854-3758bd58daa5","type":"SaveTool"},{"id":"8e880af4-2ad7-4083-84e1-6307ffee5354","type":"ResetTool"},{"id":"aa768383-80fe-42d6-a390-1a4daa11d3b8","type":"HelpTool"}]},"id":"c1843472-e919-4028-bff8-da6596d466d7","type":"Toolbar"},{"attributes":{},"id":"9ce9e893-6707-4de8-8f85-4409d90b277e","type":"ToolEvents"},{"attributes":{"formatter":{"id":"5b4d4632-e7d6-43fd-806f-9f3262dd68de","type":"BasicTickFormatter"},"plot":{"id":"d4332030-16c9-495b-a999-b8c3f1eac333","subtype":"Figure","type":"Plot"},"ticker":{"id":"a2046d10-a816-420e-b286-3b3b8397c208","type":"BasicTicker"}},"id":"93839bce-70b8-45a1-b521-82031d5ff904","type":"LinearAxis"},{"attributes":{"callback":null},"id":"e5e3d98b-a3e2-42b5-bb56-bbe907b1dc9b","type":"DataRange1d"},{"attributes":{},"id":"063e5f89-f5f2-4c18-a468-439dc6f97139","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"d4332030-16c9-495b-a999-b8c3f1eac333","subtype":"Figure","type":"Plot"},"ticker":{"id":"a2046d10-a816-420e-b286-3b3b8397c208","type":"BasicTicker"}},"id":"70064ed5-44b9-4104-9b17-d8bf1934c106","type":"Grid"},{"attributes":{},"id":"a2046d10-a816-420e-b286-3b3b8397c208","type":"BasicTicker"},{"attributes":{"data_source":{"id":"e62e0b7e-34f8-427d-9227-4fea3558a471","type":"ColumnDataSource"},"glyph":{"id":"0ffb1fe6-c45f-434c-8e9f-a2d2bb38ddd9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"abfb571c-13f0-4211-ae1c-41b52c190a06","type":"Circle"},"selection_glyph":null},"id":"9dd4b153-6d8d-4fe4-b148-c3fbf3f5690b","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a448bed8-bd17-45fb-b7be-9f25e2f46984","type":"Line"},{"attributes":{"plot":{"id":"d4332030-16c9-495b-a999-b8c3f1eac333","subtype":"Figure","type":"Plot"},"ticker":{"id":"063e5f89-f5f2-4c18-a468-439dc6f97139","type":"BasicTicker"}},"id":"1a2fd7a8-1887-43b9-806f-2dd23e3269fe","type":"Grid"},{"attributes":{"callback":null},"id":"24cf196c-2228-416a-8aba-165d74ee17de","type":"DataRange1d"},{"attributes":{"formatter":{"id":"e13ff067-9ba0-4f03-b3c6-0456e12de6ec","type":"BasicTickFormatter"},"plot":{"id":"d4332030-16c9-495b-a999-b8c3f1eac333","subtype":"Figure","type":"Plot"},"ticker":{"id":"063e5f89-f5f2-4c18-a468-439dc6f97139","type":"BasicTicker"}},"id":"c51c89bc-7130-4c43-a26f-a29fa11371da","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"13544bc1-325b-45a9-9fa1-5efaaec613e9","type":"Line"},{"attributes":{"data_source":{"id":"c59283af-86c4-4f99-a889-e410e68611df","type":"ColumnDataSource"},"glyph":{"id":"13544bc1-325b-45a9-9fa1-5efaaec613e9","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a448bed8-bd17-45fb-b7be-9f25e2f46984","type":"Line"},"selection_glyph":null,"y_range_name":"small_data"},"id":"c5f97d3f-1bfd-4b84-8a7f-864140bb5840","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9f23dc97-1f71-4c1a-afea-2bebf1179e58","type":"BoxAnnotation"},{"attributes":{},"id":"e13ff067-9ba0-4f03-b3c6-0456e12de6ec","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"17c64669-09c8-4a60-9235-ccffe2bfbc93","type":"Title"},{" ...
