# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-10: 目盛り線の調整

# %%
# リスト7.10.1：主目盛り線の書式設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.grid.grid_line_width = 3
p.xgrid.grid_line_color = "red"
p.xgrid.grid_line_alpha = 0.5
p.ygrid.grid_line_dash = "dashed"
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2a74ef61-be27-4ea8-af5c-e82c7d568974">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="79289870-a565-477e-959e-14642dfa94f6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("79289870-a565-477e-959e-14642dfa94f6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("79289870-a565-477e-959e-14642dfa94f6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '79289870-a565-477e-959e-14642dfa94f6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ebb6e467-ea05-4d4d-a73d-935d67b132b6":{"roots":{"references":[{"attributes":{"callback":null},"id":"5c57aa59-74cc-4162-bcdf-44d205869006","type":"DataRange1d"},{"attributes":{"callback":null},"id":"52796da1-aadd-4185-9614-62a69d391981","type":"DataRange1d"},{"attributes":{"grid_line_alpha":{"value":0.5},"grid_line_color":{"value":"red"},"grid_line_width":{"value":3},"plot":{"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"468116e3-d1bc-44ba-9c07-95951c254628","type":"BasicTicker"}},"id":"ae92459a-6723-487f-983d-712dd1ead0f0","type":"Grid"},{"attributes":{"formatter":{"id":"654a3ae2-d9d9-4234-88e5-9d14de25dd36","type":"BasicTickFormatter"},"plot":{"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"c9582fc3-7926-4dfa-90d1-6551d995a6e1","type":"BasicTicker"}},"id":"421e65b7-c8e7-421e-bfc9-40d252f69ce2","type":"LinearAxis"},{"attributes":{},"id":"c9582fc3-7926-4dfa-90d1-6551d995a6e1","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"8fc3b163-b2fe-4570-8df8-232b374748ce","type":"Title"},{"attributes":{"dimension":1,"grid_line_dash":[6],"grid_line_width":{"value":3},"plot":{"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"c9582fc3-7926-4dfa-90d1-6551d995a6e1","type":"BasicTicker"}},"id":"fe3275f3-4f39-49b7-90dc-29db3be66572","type":"Grid"},{"attributes":{},"id":"b4d999c2-9ba3-48f8-90e5-32ae591088be","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0ac8ceab-e212-4754-a89b-12e2c4bdc221","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"}},"id":"598c6180-e57f-4250-85bd-9ebe046ccac9","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a4550bf-8963-4331-88c6-40f654b3eb94","type":"Circle"},{"attributes":{"below":[{"id":"11d62464-5bb0-4934-b3b7-2c0acd56436f","type":"LinearAxis"}],"left":[{"id":"421e65b7-c8e7-421e-bfc9-40d252f69ce2","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"11d62464-5bb0-4934-b3b7-2c0acd56436f","type":"LinearAxis"},{"id":"ae92459a-6723-487f-983d-712dd1ead0f0","type":"Grid"},{"id":"421e65b7-c8e7-421e-bfc9-40d252f69ce2","type":"LinearAxis"},{"id":"fe3275f3-4f39-49b7-90dc-29db3be66572","type":"Grid"},{"id":"0ac8ceab-e212-4754-a89b-12e2c4bdc221","type":"BoxAnnotation"},{"id":"bffa6fb5-e3fb-44b9-8259-bb5afcf6700f","type":"GlyphRenderer"}],"title":{"id":"8fc3b163-b2fe-4570-8df8-232b374748ce","type":"Title"},"tool_events":{"id":"b366f7ec-24b3-4e3f-aa21-c52254b9833b","type":"ToolEvents"},"toolbar":{"id":"5296bd66-b42f-44cc-9fdb-31736923e4fa","type":"Toolbar"},"x_range":{"id":"5c57aa59-74cc-4162-bcdf-44d205869006","type":"DataRange1d"},"y_range":{"id":"52796da1-aadd-4185-9614-62a69d391981","type":"DataRange1d"}},"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a65c9ba3-0703-48cc-b29f-2f75a3b32f98","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"5898bbf5-6a73-4427-90db-c6fbdb4dabf6","type":"ColumnDataSource"},{"attributes":{},"id":"468116e3-d1bc-44ba-9c07-95951c254628","type":"BasicTicker"},{"attributes":{"plot":{"id":"da0c3a0c-9275-43db-9e52-0133336c71ef","subtype":"Figure","type":"Plot"}},"id":"c6084206-141e-4f87-be4d-951275a82ee7","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"0ac8ceab-e212-47 ...

# %%
# リスト7.10.2：補助目盛り線の書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.ygrid.minor_grid_line_color = "black"
p.ygrid.minor_grid_line_alpha = 0.2
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="418cc90c-c891-4995-b9f4-9834f274d507"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("418cc90c-c891-4995-b9f4-9834f274d507");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("418cc90c-c891-4995-b9f4-9834f274d507");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '418cc90c-c891-4995-b9f4-9834f274d507' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ceae1aab-3175-41d7-860a-732a97f16ef4":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"677f3498-a193-4fd1-9ffa-cd2aab8e7280","type":"Title"},{"attributes":{"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"d4f062be-de88-4239-8c11-f3b9061147ca","type":"PanTool"},{"attributes":{},"id":"4efed30d-e84f-4c06-b718-39bc2133f65c","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3c53a07d-ed96-4bac-a84c-75fa73e98c5a","type":"BoxAnnotation"},{"attributes":{},"id":"029d0746-64cc-456d-b80c-e4801b3f5801","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"7dd83027-3a37-47fe-86e6-3ac6ba48347b","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d4f062be-de88-4239-8c11-f3b9061147ca","type":"PanTool"},{"id":"0db3d943-1ba5-4152-80db-41a611fd4063","type":"WheelZoomTool"},{"id":"ebdddc2b-bec4-4c05-8c50-f95d3e985bcb","type":"BoxZoomTool"},{"id":"c38f2cd7-324e-4165-9ddb-962bc62d50d4","type":"SaveTool"},{"id":"e9c7a9a7-389b-4988-a584-ed5799cbc604","type":"ResetTool"},{"id":"920a82be-ab82-451f-a931-cfa64821f266","type":"HelpTool"}]},"id":"7f0cd8ba-f37b-48a8-ad8a-e2c5dde2dee0","type":"Toolbar"},{"attributes":{"overlay":{"id":"3c53a07d-ed96-4bac-a84c-75fa73e98c5a","type":"BoxAnnotation"},"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"ebdddc2b-bec4-4c05-8c50-f95d3e985bcb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"0db3d943-1ba5-4152-80db-41a611fd4063","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"816959a5-e652-4ebf-ae2b-a90795589b0d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"e9c7a9a7-389b-4988-a584-ed5799cbc604","type":"ResetTool"},{"attributes":{"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"c38f2cd7-324e-4165-9ddb-962bc62d50d4","type":"SaveTool"},{"attributes":{"dimension":1,"minor_grid_line_alpha":{"value":0.2},"minor_grid_line_color":{"value":"black"},"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"},"ticker":{"id":"427d9471-0bdd-44ae-b0b4-0f166278f780","type":"BasicTicker"}},"id":"05e3acba-7045-467f-99ad-14085479d774","type":"Grid"},{"attributes":{"callback":null},"id":"f611e64e-38cd-47d2-b6e8-81a18abe4722","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0220713-ae62-4af8-b47f-0d3cc9827d6b","type":"Circle"},{"attributes":{},"id":"fb54b5d6-234e-4c4f-b796-07d37e864f5d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"029d0746-64cc-456d-b80c-e4801b3f5801","type":"BasicTickFormatter"},"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"},"ticker":{"id":"427d9471-0bdd-44ae-b0b4-0f166278f780","type":"BasicTicker"}},"id":"79af08b2-8fe7-405a-844f-e54b891966ce","type":"LinearAxis"},{"attributes":{"plot":{"id":"0c75c9cf-bd7d-4526-b355-65f38a943524","subtype":"Figure","type":"Plot"}},"id":"920a82be-ab82-451f-a931-cfa64821f266","type":"HelpTool"},{"attributes":{"below":[{"id":"46d1eeca-af8e-4592-90d8-0d8127d57def","type":"LinearAxis"}],"left":[{"id":"79af08b2-8fe7-405a-844f-e54b891966ce","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"46d1eeca-af8e-4592-90d8-0d8127d57def","type":"LinearAxis"},{"id":"257a57c7-1 ...

# %%
# リスト7.10.3：網掛けの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1, 2], [0, 1, 2])
p.ygrid.band_fill_color = "red"
p.ygrid.band_fill_alpha = 0.1
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3fe82196-31cb-48ca-b65c-1b55fce564b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3fe82196-31cb-48ca-b65c-1b55fce564b5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3fe82196-31cb-48ca-b65c-1b55fce564b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3fe82196-31cb-48ca-b65c-1b55fce564b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"63eb4991-89d3-414e-be5b-e4182235af60":{"roots":{"references":[{"attributes":{"band_fill_alpha":{"value":0.1},"band_fill_color":{"value":"red"},"dimension":1,"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"},"ticker":{"id":"119f746f-4267-493f-bd7c-80cd20aa9cd1","type":"BasicTicker"}},"id":"6f757916-3f2a-4011-a361-445d84ac699e","type":"Grid"},{"attributes":{},"id":"119f746f-4267-493f-bd7c-80cd20aa9cd1","type":"BasicTicker"},{"attributes":{"overlay":{"id":"aeb0c418-1132-45ae-ae12-ac8508cd8de7","type":"BoxAnnotation"},"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"}},"id":"e7b74eb8-8f4f-4d45-898b-718bd456ff9b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"}},"id":"887e6a40-d16c-4529-a1df-65b679e4a85d","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"599befb5-0ea8-4178-8390-e28125dec0d3","type":"BasicTickFormatter"},"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"},"ticker":{"id":"119f746f-4267-493f-bd7c-80cd20aa9cd1","type":"BasicTicker"}},"id":"cdcb170f-ea88-4799-bc8e-7dce723e63e8","type":"LinearAxis"},{"attributes":{},"id":"599befb5-0ea8-4178-8390-e28125dec0d3","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aeb0c418-1132-45ae-ae12-ac8508cd8de7","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c5674557-7fee-49ac-b403-a6b3c1a8a0af","type":"PanTool"},{"id":"887e6a40-d16c-4529-a1df-65b679e4a85d","type":"WheelZoomTool"},{"id":"e7b74eb8-8f4f-4d45-898b-718bd456ff9b","type":"BoxZoomTool"},{"id":"d8e015df-a18f-4341-9e61-7d9f50038447","type":"SaveTool"},{"id":"c1c8fb5b-f33d-46b0-97c3-8b098758c518","type":"ResetTool"},{"id":"0aed3822-d3fb-4cfc-b7e8-6d1f878ce077","type":"HelpTool"}]},"id":"bbeca3c3-c61d-4e28-943b-ee5428aa32b9","type":"Toolbar"},{"attributes":{"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"}},"id":"0aed3822-d3fb-4cfc-b7e8-6d1f878ce077","type":"HelpTool"},{"attributes":{"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"}},"id":"d8e015df-a18f-4341-9e61-7d9f50038447","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"e8723faa-cbd1-44c3-895c-46b365d3482a","type":"Title"},{"attributes":{"data_source":{"id":"7bf6d1b8-d668-413e-aa9e-8951407e595e","type":"ColumnDataSource"},"glyph":{"id":"a913f641-2b10-44f1-a04b-b04d57e8beef","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d732367f-3d50-438c-82f3-4346fd47bfea","type":"Circle"},"selection_glyph":null},"id":"dee8b03b-ef11-4dd1-83a0-a4529a22adc2","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"},"ticker":{"id":"8029cef8-b9ae-424d-b61e-eb84c3e25241","type":"BasicTicker"}},"id":"237b385e-2a3e-4529-b77f-f48972a186ba","type":"Grid"},{"attributes":{"plot":{"id":"fc7402b9-d775-45ce-9009-9adff6842a4f","subtype":"Figure","type":"Plot"}},"id":"c1c8fb5b-f33d-46b0-97c3-8b098758c518","type":"ResetTool"},{"attributes":{"callback":null},"id":"2c2a90d0-9241-431a-be9c-eb12af3ddf9b","type":"DataRange1d"},{"attributes":{},"id":"8ff75575-06f9-4bb1-93bf-be11283d4425","type":"ToolEvents"},{"attributes":{"callback":null},"id":"f21c2fe4-5081-41e9-8084-1de762c11386","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d732367f-3d50-438c-82f3-4346fd47bfea","type":"Circle"},{"attributes":{ ...

# %%
# リスト7.10.4：目盛り線の範囲設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.grid.bounds = (-0.25, 0.25)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="363d15e9-377f-44b6-a559-eefcd93ab370"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("363d15e9-377f-44b6-a559-eefcd93ab370");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("363d15e9-377f-44b6-a559-eefcd93ab370");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '363d15e9-377f-44b6-a559-eefcd93ab370' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"57982f4c-42d1-407d-ab7b-85506be3ff28":{"roots":{"references":[{"attributes":{"below":[{"id":"602cf467-f4d1-4825-9eac-e8763aa74308","type":"LinearAxis"}],"left":[{"id":"5e66f59e-123a-4c28-badb-50908df9a0bc","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"602cf467-f4d1-4825-9eac-e8763aa74308","type":"LinearAxis"},{"id":"49998f1c-e00b-4ef4-aaf4-63e875bebdbc","type":"Grid"},{"id":"5e66f59e-123a-4c28-badb-50908df9a0bc","type":"LinearAxis"},{"id":"a8dd63e9-edbc-45f4-83da-a53f4231c9d6","type":"Grid"},{"id":"1156feb5-97ec-42e3-86f6-40ac8965724a","type":"BoxAnnotation"},{"id":"6f3c1818-672f-4620-a950-a0a514d1c0c2","type":"GlyphRenderer"}],"title":{"id":"d2890d91-88e0-45cb-b8b9-cfee76226628","type":"Title"},"tool_events":{"id":"1c750808-39eb-412b-a1df-2eed84041408","type":"ToolEvents"},"toolbar":{"id":"f41bf740-4dcf-495c-b244-f36043869165","type":"Toolbar"},"x_range":{"id":"af955bbd-2456-43dd-903d-e4a34a821b66","type":"DataRange1d"},"y_range":{"id":"d99d4c44-4d71-418a-bf53-77ee6648da1f","type":"DataRange1d"}},"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"d2890d91-88e0-45cb-b8b9-cfee76226628","type":"Title"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76073359-ed62-4534-9ca2-fd1ca9d9f772","type":"Circle"},{"attributes":{"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"}},"id":"0c53dc8b-5981-47c7-9eb9-f5417e70133e","type":"HelpTool"},{"attributes":{"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"}},"id":"63ebf643-307c-4819-a056-33deff715577","type":"PanTool"},{"attributes":{},"id":"1c750808-39eb-412b-a1df-2eed84041408","type":"ToolEvents"},{"attributes":{},"id":"e7986901-0553-48d5-869a-5914cb101bd6","type":"BasicTicker"},{"attributes":{"bounds":[-0.25,0.25],"dimension":1,"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"},"ticker":{"id":"0a51a402-c746-4abb-bcbf-0d77da9fe426","type":"BasicTicker"}},"id":"a8dd63e9-edbc-45f4-83da-a53f4231c9d6","type":"Grid"},{"attributes":{},"id":"0a51a402-c746-4abb-bcbf-0d77da9fe426","type":"BasicTicker"},{"attributes":{},"id":"ac1af268-c18e-40cc-b7d2-e62f1f0a33bc","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"}},"id":"5f57f8fb-4769-49cd-9388-e8542a3d72a8","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"}},"id":"661e8f90-ceff-4607-8e23-2f0e433acb45","type":"SaveTool"},{"attributes":{"data_source":{"id":"d0ab0b2c-61b6-4ff0-9457-07da545d3870","type":"ColumnDataSource"},"glyph":{"id":"76073359-ed62-4534-9ca2-fd1ca9d9f772","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2e1c56c5-beea-4870-a4ef-b8db7f2f2f32","type":"Circle"},"selection_glyph":null},"id":"6f3c1818-672f-4620-a950-a0a514d1c0c2","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"d99d4c44-4d71-418a-bf53-77ee6648da1f","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1156feb5-97ec-42e3-86f6-40ac8965724a","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"ac1af268-c18e-40cc-b7d2-e62f1f0a33bc","type":"BasicTickFormatter"},"plot":{"id":"a601d6fa-dcb4-4bea-9a1f-91116d237a8b","subtype":"Figure","type":"Plot"},"ticker":{"id":"e7986901-0553-48d5-869a-5914cb101bd6","type":"BasicTicker"}},"id":"602cf467-f4d1-4825-9eac-e8763aa74308","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"d0ab0b2c-6 ...
