# %%
# リスト7.10.1：主目盛り線の書式設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.grid.grid_line_width = 3
p.xgrid.grid_line_color = 'red'
p.xgrid.grid_line_alpha = 0.5
p.ygrid.grid_line_dash = 'dashed'
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3d7ebef3-8cd7-475b-87fd-dd2221f0573c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5a224ebd-0615-49fb-8583-091cab647d0d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5a224ebd-0615-49fb-8583-091cab647d0d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5a224ebd-0615-49fb-8583-091cab647d0d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5a224ebd-0615-49fb-8583-091cab647d0d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2641f3ae-9317-4192-980e-1415d5d11ad1":{"roots":{"references":[{"attributes":{"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"}},"id":"b830132f-b330-46e2-92b3-5006e96fa391","type":"ResetTool"},{"attributes":{},"id":"e2bc9084-4259-4ed8-a2c6-59139a29dd80","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"}},"id":"62b008b8-9ee2-4656-bc9b-7a0f870fe33f","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"6917ab88-9cbd-4fe2-be8e-6766c86f09c0","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"92c3f985-f0e6-4007-b8a4-3675d6d1fda5","type":"DataRange1d"},{"attributes":{"below":[{"id":"b4013eac-b9c3-4b16-8b55-dbdf5036c1f0","type":"LinearAxis"}],"left":[{"id":"37b92ac6-6569-46f8-bc0b-b7bfd7beb0c0","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"b4013eac-b9c3-4b16-8b55-dbdf5036c1f0","type":"LinearAxis"},{"id":"6fa758f4-01ee-4a23-820f-5faed2ab78c7","type":"Grid"},{"id":"37b92ac6-6569-46f8-bc0b-b7bfd7beb0c0","type":"LinearAxis"},{"id":"b6d71c00-d12a-4a5d-899b-c6e18cbfbc75","type":"Grid"},{"id":"ac54cc81-3161-48a8-932f-1b1b5ff005a4","type":"BoxAnnotation"},{"id":"a596b375-a557-492e-a0c8-b3cb66a43a47","type":"GlyphRenderer"}],"title":{"id":"ace39ed8-48e2-420e-b21e-28bedd6be9ba","type":"Title"},"tool_events":{"id":"ba8a4280-ed3e-41db-8b43-d048d289d200","type":"ToolEvents"},"toolbar":{"id":"b4389fa5-bb8a-4908-b91f-bcd0fecd8201","type":"Toolbar"},"x_range":{"id":"d3e5ac6e-011b-47d6-af43-34c64f1f872f","type":"DataRange1d"},"y_range":{"id":"92c3f985-f0e6-4007-b8a4-3675d6d1fda5","type":"DataRange1d"}},"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5dfb350d-40d4-4575-a2e9-44b6349666cc","type":"PanTool"},{"id":"1e1fe19d-157e-4809-a07f-394f70ba53ef","type":"WheelZoomTool"},{"id":"f536e3fc-7ea8-4917-a5fe-f467915f5019","type":"BoxZoomTool"},{"id":"0de4c98a-8adf-4af5-9f9e-c6c39314f47d","type":"SaveTool"},{"id":"b830132f-b330-46e2-92b3-5006e96fa391","type":"ResetTool"},{"id":"62b008b8-9ee2-4656-bc9b-7a0f870fe33f","type":"HelpTool"}]},"id":"b4389fa5-bb8a-4908-b91f-bcd0fecd8201","type":"Toolbar"},{"attributes":{"formatter":{"id":"e2bc9084-4259-4ed8-a2c6-59139a29dd80","type":"BasicTickFormatter"},"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ab18be64-9bb6-4a26-b010-4007bdb5393a","type":"BasicTicker"}},"id":"b4013eac-b9c3-4b16-8b55-dbdf5036c1f0","type":"LinearAxis"},{"attributes":{},"id":"ab18be64-9bb6-4a26-b010-4007bdb5393a","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"ace39ed8-48e2-420e-b21e-28bedd6be9ba","type":"Title"},{"attributes":{"grid_line_alpha":{"value":0.5},"grid_line_color":{"value":"red"},"grid_line_width":{"value":3},"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"ab18be64-9bb6-4a26-b010-4007bdb5393a","type":"BasicTicker"}},"id":"6fa758f4-01ee-4a23-820f-5faed2ab78c7","type":"Grid"},{"attributes":{"formatter":{"id":"59ff1988-e8fa-4e24-a2f3-0ef90114d453","type":"BasicTickFormatter"},"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"},"ticker":{"id":"4fe97995-d015-4712-8a88-7c3a4c284464","type":"BasicTicker"}},"id":"37b92ac6-6569-46f8-bc0b-b7bfd7beb0c0","type":"LinearAxis"},{"attributes":{"overlay":{"id":"ac54cc81-3161-48a8-932f-1b1b5ff005a4","type":"BoxAnnotation"},"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f","subtype":"Figure","type":"Plot"}},"id":"f536e3fc-7ea8-4917-a5fe-f467915f5019","type":"BoxZoomTool"},{"attributes":{},"id":"4fe97995-d015-4712-8a88-7c3a4c284464","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_dash":[6],"grid_line_width":{"value":3},"plot":{"id":"bdb98220-79cd-4792-9893-981545828f5f ...

# %%
# リスト7.10.2：補助目盛り線の書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.ygrid.minor_grid_line_color = 'black'
p.ygrid.minor_grid_line_alpha = 0.2
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="267a894b-88c6-43ec-99ec-ec19b33feeff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("267a894b-88c6-43ec-99ec-ec19b33feeff");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("267a894b-88c6-43ec-99ec-ec19b33feeff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '267a894b-88c6-43ec-99ec-ec19b33feeff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01df2603-8688-4fae-89f8-71eeae4c4d28":{"roots":{"references":[{"attributes":{},"id":"54a1807a-5db5-4ea4-adb8-054cdd962971","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"54a1807a-5db5-4ea4-adb8-054cdd962971","type":"BasicTickFormatter"},"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"10cd8c5e-8f18-4720-ab13-5a4e14f7c6b4","type":"BasicTicker"}},"id":"80863a5e-317a-4a99-b77b-4213584ae6ce","type":"LinearAxis"},{"attributes":{},"id":"9e39f005-01b1-4a1b-9d6c-3eacdaf36b13","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"}},"id":"3bce0a12-78fd-425d-a227-7f7db472abea","type":"PanTool"},{"attributes":{"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"}},"id":"bb38bdbe-cdb6-4ae9-b439-bb72d7b4fdb0","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"fe61c8e5-11b6-4887-b73e-06997a3e80c8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"}},"id":"0f189064-4111-403a-b316-5f6ee2b98f87","type":"ResetTool"},{"attributes":{"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"}},"id":"772a6a63-d9da-4867-9fcd-1201c6eb9a6d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"}},"id":"8db1b004-b789-4460-98a7-bd39413362a3","type":"SaveTool"},{"attributes":{"data_source":{"id":"bbee288a-96c3-4008-a5c0-0ccc667baf55","type":"ColumnDataSource"},"glyph":{"id":"b120220b-6a2b-46d5-91d4-bb89e6901e2d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0fd36e09-4462-4bf6-baee-1d8794985da4","type":"Circle"},"selection_glyph":null},"id":"82e35223-6068-4386-867e-a8ee7c62c2f2","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fd36e09-4462-4bf6-baee-1d8794985da4","type":"Circle"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b120220b-6a2b-46d5-91d4-bb89e6901e2d","type":"Circle"},{"attributes":{"dimension":1,"minor_grid_line_alpha":{"value":0.2},"minor_grid_line_color":{"value":"black"},"plot":{"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"10cd8c5e-8f18-4720-ab13-5a4e14f7c6b4","type":"BasicTicker"}},"id":"c749ad25-dff0-413b-881b-47179d630471","type":"Grid"},{"attributes":{"below":[{"id":"7f80ebe2-ee74-425d-9732-1d6719d96464","type":"LinearAxis"}],"left":[{"id":"80863a5e-317a-4a99-b77b-4213584ae6ce","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"7f80ebe2-ee74-425d-9732-1d6719d96464","type":"LinearAxis"},{"id":"490c458a-b660-4af4-8a78-7476d7e88803","type":"Grid"},{"id":"80863a5e-317a-4a99-b77b-4213584ae6ce","type":"LinearAxis"},{"id":"c749ad25-dff0-413b-881b-47179d630471","type":"Grid"},{"id":"fe61c8e5-11b6-4887-b73e-06997a3e80c8","type":"BoxAnnotation"},{"id":"82e35223-6068-4386-867e-a8ee7c62c2f2","type":"GlyphRenderer"}],"title":{"id":"f5b94f79-2ffc-4de5-9b86-05420109fe53","type":"Title"},"tool_events":{"id":"8f548606-d510-4804-b562-1527e568526b","type":"ToolEvents"},"toolbar":{"id":"e8c91c22-0b31-47f2-8c6c-0ea2ee24c860","type":"Toolbar"},"x_range":{"id":"f9e9c31f-7718-49ff-9e79-edfec12894f1","type":"DataRange1d"},"y_range":{"id":"701245de-ceaf-449d-a61b-18e3f49660cc","type":"DataRange1d"}},"id":"a11a1297-83fe-4718-b8ad-892feea615ff","subtype":"Figure","type":"Pl ...

# %%
# リスト7.10.3：網掛けの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1, 2], [0, 1, 2])
p.ygrid.band_fill_color = 'red'
p.ygrid.band_fill_alpha = 0.1
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a0ac8af4-d675-4ef0-92af-3212bf2fe173"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a0ac8af4-d675-4ef0-92af-3212bf2fe173");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a0ac8af4-d675-4ef0-92af-3212bf2fe173");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a0ac8af4-d675-4ef0-92af-3212bf2fe173' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dbce71da-e2d8-4cfc-84f8-3544a53ff7fc":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1e05d46e-bace-43b9-9f95-d3d1fe4dad19","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"ba5c2f9e-8509-45cb-8adc-43e4b72e71a7","type":"Title"},{"attributes":{"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"},"ticker":{"id":"488e4804-838a-4db5-8c38-737f9c3eca27","type":"BasicTicker"}},"id":"26dca1df-73a9-444e-928b-a6dd8686d333","type":"Grid"},{"attributes":{},"id":"700b0a39-2a31-4040-8d10-a8f34eaa85df","type":"ToolEvents"},{"attributes":{"callback":null},"id":"8fb12aed-a94f-4664-8bea-b2061b5a5555","type":"DataRange1d"},{"attributes":{"below":[{"id":"3be4932a-ea58-40af-931f-0369a8102507","type":"LinearAxis"}],"left":[{"id":"ab15333a-2171-4f2f-967a-b4454f4852d3","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"3be4932a-ea58-40af-931f-0369a8102507","type":"LinearAxis"},{"id":"26dca1df-73a9-444e-928b-a6dd8686d333","type":"Grid"},{"id":"ab15333a-2171-4f2f-967a-b4454f4852d3","type":"LinearAxis"},{"id":"e0804f57-e28b-4ca5-a35f-d2479e312488","type":"Grid"},{"id":"c8e50de9-cb00-4b48-9668-5ce6a371e966","type":"BoxAnnotation"},{"id":"7864f6a0-be1a-4ee0-9a02-05f98d378836","type":"GlyphRenderer"}],"title":{"id":"ba5c2f9e-8509-45cb-8adc-43e4b72e71a7","type":"Title"},"tool_events":{"id":"700b0a39-2a31-4040-8d10-a8f34eaa85df","type":"ToolEvents"},"toolbar":{"id":"cd473e9f-4957-48eb-bb4c-c170486d90c4","type":"Toolbar"},"x_range":{"id":"23e95210-39de-45b8-a91a-b5d6cde6e7d2","type":"DataRange1d"},"y_range":{"id":"8fb12aed-a94f-4664-8bea-b2061b5a5555","type":"DataRange1d"}},"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null},"id":"23e95210-39de-45b8-a91a-b5d6cde6e7d2","type":"DataRange1d"},{"attributes":{},"id":"cd17e262-bef8-45f1-a200-206c58eea533","type":"BasicTickFormatter"},{"attributes":{},"id":"488e4804-838a-4db5-8c38-737f9c3eca27","type":"BasicTicker"},{"attributes":{"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"}},"id":"e621766b-8370-4768-b633-369254a1674a","type":"SaveTool"},{"attributes":{"formatter":{"id":"91717350-625a-4f1b-9d46-5872c7286019","type":"BasicTickFormatter"},"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"},"ticker":{"id":"7de7a1c9-a89d-4ee5-9fcb-b4664eca6c38","type":"BasicTicker"}},"id":"ab15333a-2171-4f2f-967a-b4454f4852d3","type":"LinearAxis"},{"attributes":{"formatter":{"id":"cd17e262-bef8-45f1-a200-206c58eea533","type":"BasicTickFormatter"},"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"},"ticker":{"id":"488e4804-838a-4db5-8c38-737f9c3eca27","type":"BasicTicker"}},"id":"3be4932a-ea58-40af-931f-0369a8102507","type":"LinearAxis"},{"attributes":{"data_source":{"id":"bb3211bf-3768-4c5b-b177-5d87d0f18c3a","type":"ColumnDataSource"},"glyph":{"id":"1e05d46e-bace-43b9-9f95-d3d1fe4dad19","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f5a24d14-7a57-476f-aaac-d21bec85edba","type":"Circle"},"selection_glyph":null},"id":"7864f6a0-be1a-4ee0-9a02-05f98d378836","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c8e50de9-cb00-4b48-9668-5ce6a371e966","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"}},"id":"90b19511-339c-4ec6-831b-12006be7fe69","type":"ResetTool"},{"attributes":{"plot":{"id":"44cd67d2-7ef5-4955-badc-b5529ffae6f3","subtype":"Figure","type":"Plot"}},"id":"fc945329-f0fc-4 ...

# %%
# リスト7.10.4：目盛り線の範囲設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.grid.bounds = (-0.25, 0.25)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3134d143-dd7d-47f5-997f-116ada310c77"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3134d143-dd7d-47f5-997f-116ada310c77");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3134d143-dd7d-47f5-997f-116ada310c77");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3134d143-dd7d-47f5-997f-116ada310c77' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d28416e1-e396-4980-9119-cd2b92bf8cfe":{"roots":{"references":[{"attributes":{"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"}},"id":"593a8972-7df1-49f9-ad7f-3e885876c7d7","type":"PanTool"},{"attributes":{},"id":"59459998-caf3-4377-b992-ebe3939041bb","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"e180d7b3-ebf4-44e5-a8c5-f116ad5ad3ea","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"3932cf49-8fc4-436d-a001-c0b4a5427a4b","type":"DataRange1d"},{"attributes":{"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"}},"id":"c9d44931-879c-43ff-9b5c-1411d2379e25","type":"ResetTool"},{"attributes":{"formatter":{"id":"51e381a1-f69e-4151-a02e-f3da67d041a3","type":"BasicTickFormatter"},"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"},"ticker":{"id":"d5d752ce-ac51-4703-ad47-b810b6b66cad","type":"BasicTicker"}},"id":"76c838e9-28ca-4ff4-80b8-6e2251b435eb","type":"LinearAxis"},{"attributes":{"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"}},"id":"1a15af68-cfc7-4fc1-a56d-5782064671b8","type":"HelpTool"},{"attributes":{},"id":"d5d752ce-ac51-4703-ad47-b810b6b66cad","type":"BasicTicker"},{"attributes":{},"id":"51e381a1-f69e-4151-a02e-f3da67d041a3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"}},"id":"7ca14511-7f6d-4995-b597-e371fe82f90f","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"76c838e9-28ca-4ff4-80b8-6e2251b435eb","type":"LinearAxis"}],"left":[{"id":"5c411fb1-0500-4fae-ab32-841669165ef1","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"76c838e9-28ca-4ff4-80b8-6e2251b435eb","type":"LinearAxis"},{"id":"97008438-920d-4241-8b9b-0c289b8ee003","type":"Grid"},{"id":"5c411fb1-0500-4fae-ab32-841669165ef1","type":"LinearAxis"},{"id":"0ffb0d82-a5d4-4e81-b6cc-28598073d00e","type":"Grid"},{"id":"ea5f8bd2-dea5-4f0b-8823-7f1c1902e2c3","type":"BoxAnnotation"},{"id":"30342468-ac51-4b6d-99f0-59d13a2e5920","type":"GlyphRenderer"}],"title":{"id":"b3ef26cc-cd55-4807-ad3f-b72f9a384dcc","type":"Title"},"tool_events":{"id":"591dccf6-9c7a-4db9-95b0-8a5a2dda10a7","type":"ToolEvents"},"toolbar":{"id":"3689aaa6-7437-40bd-976f-049f2e2141c7","type":"Toolbar"},"x_range":{"id":"3f0ca81b-1bed-4f89-a5cd-dae546ac7c18","type":"DataRange1d"},"y_range":{"id":"3932cf49-8fc4-436d-a001-c0b4a5427a4b","type":"DataRange1d"}},"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"59459998-caf3-4377-b992-ebe3939041bb","type":"BasicTickFormatter"},"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"},"ticker":{"id":"89f109b4-c7e2-453d-9b78-786e4515be33","type":"BasicTicker"}},"id":"5c411fb1-0500-4fae-ab32-841669165ef1","type":"LinearAxis"},{"attributes":{"bounds":[-0.25,0.25],"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"},"ticker":{"id":"d5d752ce-ac51-4703-ad47-b810b6b66cad","type":"BasicTicker"}},"id":"97008438-920d-4241-8b9b-0c289b8ee003","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c72d244-c1ca-4de3-a40e-8fe358780f0e","type":"Circle"},{"attributes":{"overlay":{"id":"ea5f8bd2-dea5-4f0b-8823-7f1c1902e2c3","type":"BoxAnnotation"},"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"}},"id":"3ae8577d-c748-4530-a857-b2dbdd365a86","type":"BoxZoomTool"},{"attributes":{"bounds":[-0.25,0.25],"dimension":1,"plot":{"id":"4c557604-fae4-416e-b5c5-0856c81add28","subtype":"Figure","type":"Plot"},"ticker":{"id":"89f109b4-c7e2-453d-9b78-786e4515be33","type":"BasicTicker"}},"id":"0ffb0d82-a5d4-4e81-b6cc-28598073d00e","type":"Grid"},{"attributes":{},"id":"591dccf6-9c7a-4db9-95b0-8a5a2d ...
