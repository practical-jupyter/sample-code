# %%
# ●リスト6.7.1：リスト-ライク・オブジェクトのデータを渡したヒストグラム
from bokeh.charts import Histogram, output_notebook, show
import numpy as np
np.random.seed(0)
data = np.random.normal(100, 10, 10000)  # データセットの作成
output_notebook()
p = Histogram(data, plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="780b25c6-bdb0-4486-8946-5634d4a48569">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cf48dbef-1b29-4c8b-b8ed-438b2b1348d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cf48dbef-1b29-4c8b-b8ed-438b2b1348d5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cf48dbef-1b29-4c8b-b8ed-438b2b1348d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cf48dbef-1b29-4c8b-b8ed-438b2b1348d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b0ac8084-dc0d-46e9-a459-9454ef07bc20":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dc445c88-f0fb-4646-9868-a722f2c8ec9b","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(129.362122, 130.598477]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"label":["(129.362122, 130.598477]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["129.9802995"],"y":[3.5]}},"id":"8f4f0673-ebb0-4489-a3a3-5750e56e840d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a32bdc0f-5a60-4402-bfd3-5bd21a726159","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(99.689621, 100.925975]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[473.0],"label":["(99.689621, 100.925975]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["100.30779799999999"],"y":[236.5]}},"id":"a93e2c16-8fd7-4fb7-957b-4ff0dfa92532","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(133.071185, 134.307539]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(133.071185, 134.307539]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["133.68936200000002"],"y":[0.5]}},"id":"4de3b22e-641b-4b42-b62a-0d41c5e25d20","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e7ea8a6b-4dc6-41b3-82e9-9a225c49e781","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(100.925975, 102.162329]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[539.0],"label":["(100.925975, 102.162329]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["101.544152"],"y":[269.5]}},"id":"399f0c35-39dd-46ee-bc09-fa41296802de","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6d63bcf-43c5-4494-920c-37c83cc66f2a","type":"Rect"},{"attributes":{"data_source":{"id":"a93e2c16-8fd7-4fb7-957b-4ff0dfa92532","type":"ColumnDataSource"},"glyph":{"id":"dc445c88-f0fb-4646-9868-a722f2c8ec9b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"42aa9872-cbb4-4ad7-ad28-313f77bc7bd8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a0149e62-2942-48e5-9698-4c30e8fa2fb8","type":"ColumnDataSource"},"glyph":{"id":"60c825f5-2a5d-4785-8e07-7ec8088708b4","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a821e99c-3c2e-4fe5-9f23-6d55beb27df7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8f4f0673-ebb0-4489-a3a3-5750e56e840d","type":"ColumnDataSource"},"glyph":{"id":"a32bdc0f-5a60-4402-bfd3-5bd21a726159","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0a613145-01b6-4e8a-9c4d-080fb7ffa33f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{" ...

# %%
# ●リスト6.7.2：DataFrameを渡したヒストグラム
import os
import pandas as pd
base_url = 'https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
anime_master_csv = os.path.join(base_url, 'anime_master.csv')
df = pd.read_csv(anime_master_csv)
p = Histogram(df, values='rating', plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="99ec2b98-7dc1-4993-8101-89bf2ccd6c3b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("99ec2b98-7dc1-4993-8101-89bf2ccd6c3b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("99ec2b98-7dc1-4993-8101-89bf2ccd6c3b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '99ec2b98-7dc1-4993-8101-89bf2ccd6c3b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2f2ed728-6f7e-4404-9ff3-9b1ee0af24c7":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e74ddbb1-ba3c-4754-9b7d-13fdcb01cf0b","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a703411-844b-453a-a025-86d75fe41d91","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cf933c47-53d6-405e-8538-e9d93daccb8e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4aaa693b-3319-414a-bb7a-a36cd52d32b0","type":"Rect"},{"attributes":{"plot":{"id":"27040756-57ca-4b60-9f02-c1bd2d860de2","subtype":"Chart","type":"Plot"}},"id":"ad734725-3247-4cb7-aebc-36fcfb4c604f","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.427273, 2.553485]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(2.427273, 2.553485]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.12621212121212144],"x":["2.490379"],"y":[1.0]}},"id":"7857ed5d-8ded-4767-83f0-516b1ebea60c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(3.941818, 4.068030]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[49.0],"label":["(3.941818, 4.068030]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.12621212121212144],"x":["4.004924"],"y":[24.5]}},"id":"d9593e35-100d-42a2-a330-69efe2cfb9ec","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(9.747576, 9.873788]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(9.747576, 9.873788]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.12621212121212189],"x":["9.810682"],"y":[0.0]}},"id":"2a20e7d5-4707-44ee-a72b-ff1745dc1d3f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1175bf89-aac4-4b1f-b570-e2df370b8a97","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0896ce87-fb3d-4cc1-961e-a877d6b21cbe","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"387d5b02-efb5-4610-a00d-df45b8b74569","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"be9de445-f98d-4cb5-b ...

# %%
# ●リスト6.7.3：ビン数を設定したヒストグラム
p = Histogram(df, values='rating', plot_width=300, plot_height=200, bins=10)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6294c2ee-32cf-40fb-bf34-854030f8ddd7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6294c2ee-32cf-40fb-bf34-854030f8ddd7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6294c2ee-32cf-40fb-bf34-854030f8ddd7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6294c2ee-32cf-40fb-bf34-854030f8ddd7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"76804171-701d-47c2-98a9-77ab53fc9d2c":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.334000, 9.167000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[217.0],"label":["(8.334000, 9.167000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8330000000000002],"x":["8.750499999999999"],"y":[108.5]}},"id":"65839e19-f1dd-4d36-99f0-71521683c6aa","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e49f57f-6274-4424-85ca-b937d4448777","type":"Rect"},{"attributes":{"data_source":{"id":"9a404039-15f2-4a0c-bfb4-0724be9b3263","type":"ColumnDataSource"},"glyph":{"id":"95604db1-0d9e-4a1c-88c2-6a89472332b0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"233bb923-d6ac-4ab1-a250-13bda994d4f3","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"5d1758dd-3e30-4df7-8471-7f4d65c81291","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"032af25e-235d-4375-8c5c-a4ab8099f708","type":"LinearAxis"}],"plot_height":200,"plot_width":300,"renderers":[{"id":"546b5cf8-188d-4744-802f-214a79e61393","type":"BoxAnnotation"},{"id":"4b7fb79b-6e32-429d-af46-eed1e9297a21","type":"GlyphRenderer"},{"id":"f5705d41-8594-49bf-9c7f-dd4b266e1a1f","type":"GlyphRenderer"},{"id":"233bb923-d6ac-4ab1-a250-13bda994d4f3","type":"GlyphRenderer"},{"id":"bd7c1e06-9b79-4444-b664-83df84c0e16d","type":"GlyphRenderer"},{"id":"8ebc466d-fc1f-46c5-a149-961e6728581d","type":"GlyphRenderer"},{"id":"26b60eda-07dd-452d-8e33-6f0893ef5e81","type":"GlyphRenderer"},{"id":"69f460e5-7ed2-4991-9faa-3b1a8be9f473","type":"GlyphRenderer"},{"id":"26da5403-be46-4aaa-9a9c-60b582ae25a6","type":"GlyphRenderer"},{"id":"80797b11-8a54-4dc9-bdd5-0d9676f02289","type":"GlyphRenderer"},{"id":"301f65b3-6d17-4d99-ace7-e0997a8ebb00","type":"GlyphRenderer"},{"id":"6ead7aaf-b134-4342-9aa8-1d419917c469","type":"Legend"},{"id":"5d1758dd-3e30-4df7-8471-7f4d65c81291","type":"LinearAxis"},{"id":"032af25e-235d-4375-8c5c-a4ab8099f708","type":"LinearAxis"},{"id":"307c626d-752b-48b0-9ab1-48fce3643ec2","type":"Grid"}],"title":{"id":"72bb4d10-492e-4739-a745-9314d17f460b","type":"Title"},"tool_events":{"id":"a7efe98d-66c5-4793-bc9d-4e82086a65a8","type":"ToolEvents"},"toolbar":{"id":"0cbe0fa0-39ec-4893-9e9a-c1322f3cd6c1","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"43114b20-f94f-48f5-b977-1f3535a89aa5","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"71628269-da0e-485b-9ad7-4355f3d43cae","type":"Range1d"}},"id":"f248bb97-4ad9-448c-923f-6161efc508d1","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":10.29175,"start":1.37825},"id":"43114b20-f94f-48f5-b977-1f3535a89aa5","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.169000, 5.002000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[653.0],"label":["(4.169000, 5.002000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8330000000000002],"x":["4.5855"],"y":[326.5]}},"id":"12ade024-14d2-4ef8-864d-d835a34bfbe8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(7.501000, 8.334000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1385.0],"label":["(7.501000, 8.334000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8330000000000002],"x":["7.9175"],"y":[692.5]}},"id":"759b121e-cea7-4a14-b5f9-64b4800f7600","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_ ...

# %%
# ●リスト6.7.4：色分けしたヒストグラム
p = Histogram(df, values='rating', color='type',
              plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e1b0e49-ca3c-4b6c-a51c-38397c3310f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8e1b0e49-ca3c-4b6c-a51c-38397c3310f0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8e1b0e49-ca3c-4b6c-a51c-38397c3310f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8e1b0e49-ca3c-4b6c-a51c-38397c3310f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3ed54cad-04f4-4800-aadc-833971700a48":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.307391, 8.443478]"],"color":["#c33ff3"],"fill_alpha":[0.6],"height":[46.0],"label":["(8.307391, 8.443478]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.13608695652173886],"x":["8.3754345"],"y":[23.0]}},"id":"089a8f1a-d44c-4699-aa25-d56f9c3ba2ee","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d72ac8e3-e118-43cb-802c-c2939bebcaff","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"df7db2de-d47c-4c86-936e-795a36016b52","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bfab06e1-634d-4782-8535-c15dc18249d3","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(3.526316, 3.717105]"],"color":["#df5320"],"fill_alpha":[0.6],"height":[1.0],"label":["(3.526316, 3.717105]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.19078947368421062],"x":["3.6217105"],"y":[0.5]}},"id":"dc1490d9-6251-4941-a8d2-841f0311be85","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(5.165000, 5.348947]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[26.0],"label":["(5.165000, 5.348947]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["5.2569735"],"y":[13.0]}},"id":"b34d4763-31c7-4b53-85ba-bffc99857a1d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"75d1d232-6989-45de-9329-1ee6331c9f9d","type":"ColumnDataSource"},"glyph":{"id":"d3119691-dd3c-4399-a485-5b17e26d58f7","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"21004ec3-9d98-442e-a03a-ad4bff22dae8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.443478, 8.579565]"],"color":["#c33ff3"],"fill_alpha":[0.6],"height":[40.0],"label":["(8.443478, 8.579565]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.13608695652174063],"x":["8.5115215"],"y":[20.0]}},"id":"ec0d5ca2-cad7-4fab-a857-96825091e49d","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"59ff8b9d-c3ef-4c8b-9384-44fada89df80","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4312736c-6732-48e5-9641-93d0b0ef17b4","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(5.348947, 5.532895]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[53.0],"label":["(5.348947, 5.532895]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["5.4409209999999995"],"y":[26.5]}},"id":"b8731305-5963-4 ...

# %%
# ●リスト6.7.6：近似曲線を加えたヒストグラム
import numpy as np
from bokeh.plotting import figure
bins = 100  # binの数
# 平均と標準偏差
mu, sigma = df['rating'].mean(), df['rating'].std()
# 正規化したヒストグラムのデータを集計
hist = np.histogram(df['rating'], normed=True, bins=bins)[0]
# X値のデータを作成
x = np.linspace(np.min(df['rating']), np.max(df['rating']), bins)
# 近似的な確率密度関数を使用してY値を生成
y = 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(- (x - mu)**2 / (2 * sigma**2))
p = figure(plot_width=600, plot_height=400)
# ヒストグラム
p.vbar(x, top=hist, width=0.05)
# 近似曲線
p.line(x, y, color='red', line_width=4, alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cab8a6f2-5442-482c-80b6-c9dc2c2f05c2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cab8a6f2-5442-482c-80b6-c9dc2c2f05c2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cab8a6f2-5442-482c-80b6-c9dc2c2f05c2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cab8a6f2-5442-482c-80b6-c9dc2c2f05c2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d5fd119e-ea42-4852-ba98-284768db54a6":{"roots":{"references":[{"attributes":{"data_source":{"id":"e53f9c51-a3f8-4117-b9a7-3d4ba0b4a095","type":"ColumnDataSource"},"glyph":{"id":"3d205514-22ea-421e-8e1d-1d6352e90584","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c5b4ee6d-89ff-426f-bcc2-c6cf53194b56","type":"VBar"},"selection_glyph":null},"id":"dc59ce3a-bb55-4621-a26e-0884b8714544","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"05a611a1-ad16-45db-9d28-12cf1be583ab","type":"LinearAxis"}],"left":[{"id":"25c120e2-41c0-4895-8591-245a4be675ea","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"05a611a1-ad16-45db-9d28-12cf1be583ab","type":"LinearAxis"},{"id":"85d030fc-b096-413b-87e7-8c252f171466","type":"Grid"},{"id":"25c120e2-41c0-4895-8591-245a4be675ea","type":"LinearAxis"},{"id":"f0651dd7-3bdb-4c83-b850-17956f753525","type":"Grid"},{"id":"ec1e76d9-3658-4011-abbc-8ad1581812d8","type":"BoxAnnotation"},{"id":"dc59ce3a-bb55-4621-a26e-0884b8714544","type":"GlyphRenderer"},{"id":"e1c276ed-891d-495c-ae1c-7afc2f6db872","type":"GlyphRenderer"}],"title":{"id":"58fb214d-b954-44d7-a0f2-6b2bdb83a828","type":"Title"},"tool_events":{"id":"e30bc827-3e15-4e09-9584-5fde2517a715","type":"ToolEvents"},"toolbar":{"id":"34c58d84-dca7-4448-8ec2-7e38a9090653","type":"Toolbar"},"x_range":{"id":"5073fe73-e126-4103-9e5f-dc8b985f87fe","type":"DataRange1d"},"y_range":{"id":"89a6eaff-df10-4c1e-bd22-57913e3faba7","type":"DataRange1d"}},"id":"f55f1d84-f199-4e5f-8ffc-aed59494481d","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"...","dtype":"float64","shape":[100]},"x":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"e53f9c51-a3f8-4117-b9a7-3d4ba0b4a095","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.5},"line_color":{"value":"red"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"d482ba0e-8ef3-419d-849e-2ae8d69e44bb","type":"Line"},{"attributes":{"plot":{"id":"f55f1d84-f199-4e5f-8ffc-aed59494481d","subtype":"Figure","type":"Plot"},"ticker":{"id":"0eaab429-6ccd-43ac-b9e0-0779deb843b8","type":"BasicTicker"}},"id":"85d030fc-b096-413b-87e7-8c252f171466","type":"Grid"},{"attributes":{"callback":null},"id":"5073fe73-e126-4103-9e5f-dc8b985f87fe","type":"DataRange1d"},{"attributes":{"data_source":{"id":"371dbf2b-e98e-43fd-9634-d98b13005e18","type":"ColumnDataSource"},"glyph":{"id":"d482ba0e-8ef3-419d-849e-2ae8d69e44bb","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a125d4d7-2d6e-46c7-b2e2-819a3ba762af","type":"Line"},"selection_glyph":null},"id":"e1c276ed-891d-495c-ae1c-7afc2f6db872","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f55f1d84-f199-4e5f-8ffc-aed59494481d","subtype":"Figure","type":"Plot"}},"id":"e1e5f539-f3d0-4cb6-a27c-11b02272d9ee","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.05},"x":{"field":"x"}},"id":"c5b4ee6d-89ff-426f-bcc2-c6cf53194b56","type":"VBar"},{"attributes":{"formatter":{"id":"c3fc4093-2fc0-4835-90ee-80f68bc2d774","type":"BasicTickFormatter"},"plot":{"id":"f55f1d84-f199-4e5f-8ffc-aed59494481d","subtype":"Figure","type":"Plot"},"ticker":{"id":"a339c0cd-dfd1-4495-aa84-6b8aa28b3fa5","type":"BasicTicker"}},"id":"25c120e2-41c0-4895-8591-245a4be675ea","type":"LinearAxis"},{"attributes":{},"id":"c3fc4093-2fc0-4835-90ee-80f68bc2d774","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.05},"x":{"field":"x"}},"id":"3d205514-22ea-421e-8e1d-1d6352e90584","type":"VBar"},{"attributes":{"dimension":1,"plot":{"id":"f55f1d84-f199-4e5f-8ffc-aed59494481d","subtype":"Figure","type":"Plot"},"ticker":{"id":"a339c0cd-dfd1-4495-aa84-6b8aa28b3fa5","type":"BasicTicker"}},"id":"f0651dd7- ...
