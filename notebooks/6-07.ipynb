# %% [markdown]
# ## 第6章 Bokehでグラフを描画しよう
#
# ### 6-7: ヒストグラム

# %%
# リスト6.7.1：リスト-ライク・オブジェクトのデータを渡したヒストグラム
from bokeh.charts import Histogram, output_notebook, show
import numpy as np

np.random.seed(0)
data = np.random.normal(100, 10, 10000)  # データセットの作成
output_notebook()
p = Histogram(data, plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cd106c8f-6786-41d7-abec-ef111bc3cbc4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8305616a-073c-4c0a-b75f-12f871883c9e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8305616a-073c-4c0a-b75f-12f871883c9e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8305616a-073c-4c0a-b75f-12f871883c9e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8305616a-073c-4c0a-b75f-12f871883c9e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"62adc934-3c79-4b48-bb62-9b88d0af3fa8":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(68.780765, 70.017119]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[6.0],"label":["(68.780765, 70.017119]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["69.398942"],"y":[3.0]}},"id":"3acab3f4-1480-49fc-833d-6a843cc9de8d","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(79.907953, 81.144307]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[61.0],"label":["(79.907953, 81.144307]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["80.52613"],"y":[30.5]}},"id":"5388fbe5-9aba-4bef-b1da-03c7926c9ce8","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(94.744204, 95.980558]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[439.0],"label":["(94.744204, 95.980558]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["95.362381"],"y":[219.5]}},"id":"206d50ee-8ebb-4687-876c-9e8ba44fb3eb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e0d6cb59-ef3f-4051-84bf-b44c02a23474","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9c3a96d-d47a-44a0-b9d5-36a084650ed5","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(65.071702, 66.308056]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(65.071702, 66.308056]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["65.68987899999999"],"y":[0.5]}},"id":"955f1d8d-4d59-4ff4-9117-9d0b0e67512e","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"67251ff9-ea9c-4d0d-932a-c83a56487768","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(66.308056, 67.544411]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(66.308056, 67.544411]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["66.9262335"],"y":[0.0]}},"id":"f3039ec6-fa86-4769-a053-1394782046b4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(81.144307, 82.380661]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[94.0],"label":["(81.144307, 82.380661]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.2363542381834236],"x":["81.762484"],"y":[47.0]}},"id":"a65a1b3a-0b07-48c2-b260-48a506c7f332","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f13f41e-ea3c-4eb4-bd90-826a3f899dc8","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height", ...

# %%
# リスト6.7.2：DataFrameを渡したヒストグラム
import os
import pandas as pd

base_url = (
    "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
)
anime_master_csv = os.path.join(base_url, "anime_master.csv")
df = pd.read_csv(anime_master_csv)
p = Histogram(df, values="rating", plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="be1f7d0e-fe56-476a-9f4e-55393687928d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("be1f7d0e-fe56-476a-9f4e-55393687928d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("be1f7d0e-fe56-476a-9f4e-55393687928d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'be1f7d0e-fe56-476a-9f4e-55393687928d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"90347740-c65f-4f97-a69d-bf10962e1d0b":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(3.184545, 3.310758]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[10.0],"label":["(3.184545, 3.310758]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.126212121212121],"x":["3.2476515"],"y":[5.0]}},"id":"4e8756c0-e3e8-4d94-836a-a1d86ba9ecc9","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"72325798-24a7-41de-92b9-ee72b6d8502e","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.320455, 4.446667]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[69.0],"label":["(4.320455, 4.446667]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.12621212121212189],"x":["4.383561"],"y":[34.5]}},"id":"1ad16637-8b7c-4153-a42d-6231390e3c00","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86070089-85e2-4077-bdd6-af1ca95f5741","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6396fa88-7086-4321-9310-036253bde055","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.446667, 4.572879]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[89.0],"label":["(4.446667, 4.572879]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.126212121212121],"x":["4.509773"],"y":[44.5]}},"id":"88f83266-c9a4-4d0a-bb58-8385123e4fb2","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1ad16637-8b7c-4153-a42d-6231390e3c00","type":"ColumnDataSource"},"glyph":{"id":"a57ac3d1-9969-40c7-abbf-7ccb3ebafcf0","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f715c390-2107-4cb1-8d7b-0eaf06294c9c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(3.058333, 3.184545]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(3.058333, 3.184545]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.126212121212121],"x":["3.121439"],"y":[1.5]}},"id":"4ae45f46-dcba-4265-80b8-79ae8865d64f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"34c669ec-c1a3-48ff-a211-f16ce12d979c","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"186a3070-cc77-40a9-93fe-25f5de05655b","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.572879, 4.699091]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[73.0],"label":["(4.572879, 4.699091]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.126212121212121],"x":["4.635985"],"y":[36.5]}},"id":"a6b79038-3d6a-436e-8dff-70fe3f40bba1" ...

# %%
# リスト6.7.3：ビン数を設定したヒストグラム
p = Histogram(df, values="rating", plot_width=300, plot_height=200, bins=10)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d5df3bf4-84ca-4612-af0d-f62745427953"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d5df3bf4-84ca-4612-af0d-f62745427953");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d5df3bf4-84ca-4612-af0d-f62745427953");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd5df3bf4-84ca-4612-af0d-f62745427953' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"86063d59-b1c4-4991-af3f-4f37edf98e25":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4c87064-8811-41f2-beb8-b3e37ae34141","type":"Rect"},{"attributes":{"data_source":{"id":"0144e777-f572-4349-bbad-9fb9a7b8787f","type":"ColumnDataSource"},"glyph":{"id":"c4c87064-8811-41f2-beb8-b3e37ae34141","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f039a060-6246-4887-9b81-d57c95b6bebd","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"43f41ef9-e088-454a-82bf-358846eb1a32","subtype":"Chart","type":"Plot"}},"id":"0a2e4146-8e5b-49c1-8189-8306791d3a39","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"48254e9a-991f-44ab-92ec-1908e2c2b68f","type":"Rect"},{"attributes":{"plot":{"id":"43f41ef9-e088-454a-82bf-358846eb1a32","subtype":"Chart","type":"Plot"}},"id":"8172feb9-9d86-4d81-b02c-6e884497668b","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(6.668000, 7.501000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3222.0],"label":["(6.668000, 7.501000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8330000000000002],"x":["7.0845"],"y":[1611.0]}},"id":"2fd53e48-bc86-4f83-a5eb-e7ea2590b7b1","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(3.336000, 4.169000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[247.0],"label":["(3.336000, 4.169000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8329999999999997],"x":["3.7524999999999995"],"y":[123.5]}},"id":"7452c16e-70ee-45b2-9d29-1c5045a62ca1","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d667e38b-d645-4268-bf65-1628bc6c7f36","type":"ColumnDataSource"},"glyph":{"id":"4df4ee0d-a9c6-47f6-b322-b6ce921fddde","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"86c50a11-e623-41a8-a861-0fc9bb2ea29b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.503000, 3.336000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[36.0],"label":["(2.503000, 3.336000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8329999999999997],"x":["2.9195"],"y":[18.0]}},"id":"709c0ea7-838d-43d6-8a29-ffa1398270cc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"709c0ea7-838d-43d6-8a29-ffa1398270cc","type":"ColumnDataSource"},"glyph":{"id":"765f9613-15ed-4e35-8e4c-9af8e3c66d05","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"0d0ba108-19a9-4383-b1c0-f8f33bf8e160","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":3544.2000000000003},"id":"54ff56d4-2278-4390-b650-27203ed1fd3e","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.334000, 9.167000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[217.0],"label":["(8.334000, 9.167000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.8330000000000002],"x":["8.750499999999999"],"y":[108.5]}},"id":"10a23473-42c1-4d5a-aa0e-153c4f890cdb","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2f878533-a4d6-4a57-9953-12ac4bc4bce6","type":"PanTool"},{"id":"8172feb9-9d86-4d81-b02c-6e884497668b","type":"WheelZoomTool"},{"id":"6314c511-8d73-43da-9f93-3edbd25b9c57","typ ...

# %%
# リスト6.7.4：色分けしたヒストグラム
p = Histogram(df, values="rating", color="type", plot_width=600, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4c7e8ce4-05ae-4eac-a587-390c17921214"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4c7e8ce4-05ae-4eac-a587-390c17921214");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c7e8ce4-05ae-4eac-a587-390c17921214");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c7e8ce4-05ae-4eac-a587-390c17921214' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"624c22fa-a642-4afa-80ca-16cb0d59c015":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.773684, 2.957632]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[1.0],"label":["(2.773684, 2.957632]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["2.865658"],"y":[0.5]}},"id":"3b5c70c8-d6bd-44ad-a1ae-c652e40fc3ea","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9813a228-789b-4c17-b707-a05d07a83a0b","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2eba24c3-b3e0-4ee3-998a-405b51658c5c","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.613158, 4.797105]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[19.0],"label":["(4.613158, 4.797105]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["4.7051315"],"y":[9.5]}},"id":"18093729-b52e-49a5-92e8-be76d4bbdfa0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.957632, 3.141579]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[2.0],"label":["(2.957632, 3.141579]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["3.0496055"],"y":[1.0]}},"id":"56553a5d-e8bd-4bd2-b544-bc9ff2b3ffe7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f4cf6ab1-1356-43b0-ae86-eabd9566c933","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.797105, 4.981053]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[9.0],"label":["(4.797105, 4.981053]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["4.889079000000001"],"y":[4.5]}},"id":"071575dc-af4b-45eb-9a22-29773ffd02cd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"18093729-b52e-49a5-92e8-be76d4bbdfa0","type":"ColumnDataSource"},"glyph":{"id":"bf9fc555-48d7-4c69-9a42-8695bfb54c1d","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"7abe29e8-225d-4d5c-ad35-c11d5eaa84eb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"52a0c9fe-d613-4940-a897-1fa7952009ee","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.981053, 5.165000]"],"color":["#00ad9c"],"fill_alpha":[0.6],"height":[30.0],"label":["(4.981053, 5.165000]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.18394736842105264],"x":["5.0730265"],"y":[15.0]}},"id":"fec41ab4-70ea-414c-9dea-5cc076c67b5a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3b5c70c8-d6bd-44ad-a1ae-c652e40fc3ea","type":"ColumnDataSource"},"glyph":{"id":"9813a228-789b-4c17-b707-a05d07a83a0b","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"4a51eb58-01ce-41ca-b327-e8c26feb8bd9","ty ...

# %%
# リスト6.7.6：近似曲線を加えたヒストグラム
import numpy as np
from bokeh.plotting import figure

bins = 100  # binの数
# 平均と標準偏差
mu, sigma = df["rating"].mean(), df["rating"].std()
# 正規化したヒストグラムのデータを集計
hist = np.histogram(df["rating"], normed=True, bins=bins)[0]
# X値のデータを作成
x = np.linspace(np.min(df["rating"]), np.max(df["rating"]), bins)
# 近似的な確率密度関数を使用してY値を生成
y = 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-(x - mu) ** 2 / (2 * sigma ** 2))
p = figure(plot_width=600, plot_height=400)
# ヒストグラム
p.vbar(x, top=hist, width=0.05)
# 近似曲線
p.line(x, y, color="red", line_width=4, alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6351a556-2412-4f07-b3e2-fd93f5a3491c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6351a556-2412-4f07-b3e2-fd93f5a3491c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6351a556-2412-4f07-b3e2-fd93f5a3491c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6351a556-2412-4f07-b3e2-fd93f5a3491c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1987caba-bc25-4774-b6cb-dba4739a94af":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd1262cb-8e4d-43f4-b5a2-197b867dd690","type":"Line"},{"attributes":{"formatter":{"id":"bbfc2ae3-c49c-4c90-b8ee-f8355ded7e76","type":"BasicTickFormatter"},"plot":{"id":"03ba255a-1621-4b57-a57e-d8f5106147ad","subtype":"Figure","type":"Plot"},"ticker":{"id":"d9a05cf5-1a96-4ce6-8d79-1a5fbd4510f2","type":"BasicTicker"}},"id":"891c6a72-8473-4c3d-97d1-b4b95d5577bf","type":"LinearAxis"},{"attributes":{"data_source":{"id":"e1d82e43-5fe2-4410-bdce-67fb08f6afeb","type":"ColumnDataSource"},"glyph":{"id":"2cf91171-6f31-4d35-b6b3-25b299ca25c7","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4a8e1405-3a25-4bb3-936f-672a204a2e7c","type":"VBar"},"selection_glyph":null},"id":"80650b08-2732-4457-910f-867edb22dc77","type":"GlyphRenderer"},{"attributes":{},"id":"d9a05cf5-1a96-4ce6-8d79-1a5fbd4510f2","type":"BasicTicker"},{"attributes":{},"id":"bbfc2ae3-c49c-4c90-b8ee-f8355ded7e76","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"03ba255a-1621-4b57-a57e-d8f5106147ad","subtype":"Figure","type":"Plot"}},"id":"6c8ae2c2-a92d-4cc1-9b86-d8b230489805","type":"ResetTool"},{"attributes":{"plot":{"id":"03ba255a-1621-4b57-a57e-d8f5106147ad","subtype":"Figure","type":"Plot"},"ticker":{"id":"1962447a-12d1-48ac-9c11-5e347b460912","type":"BasicTicker"}},"id":"2c8c329a-741a-49bb-8d0e-4f1db028bda0","type":"Grid"},{"attributes":{"callback":null},"id":"53fcc1c4-e161-40e6-ab95-86d5ec2dfc51","type":"DataRange1d"},{"attributes":{},"id":"07e9d866-0984-4a9b-ac2e-88f87fc1d6d5","type":"ToolEvents"},{"attributes":{},"id":"f166192f-63b1-40c7-9d0e-71714b120779","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"1f4103c9-3c16-4e84-a1b2-f5ce38e8b9a7","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"1cf69bd4-91d2-4a71-86d9-f49dc9e12321","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1c4044f3-3a86-4654-9561-da511ab13fc7","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.05},"x":{"field":"x"}},"id":"2cf91171-6f31-4d35-b6b3-25b299ca25c7","type":"VBar"},{"attributes":{"below":[{"id":"f89e3e35-7cc5-4bd2-930c-6dc311e6cbda","type":"LinearAxis"}],"left":[{"id":"891c6a72-8473-4c3d-97d1-b4b95d5577bf","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"f89e3e35-7cc5-4bd2-930c-6dc311e6cbda","type":"LinearAxis"},{"id":"2c8c329a-741a-49bb-8d0e-4f1db028bda0","type":"Grid"},{"id":"891c6a72-8473-4c3d-97d1-b4b95d5577bf","type":"LinearAxis"},{"id":"8803ecdf-99bc-4690-97a8-6c1ffccdd3f0","type":"Grid"},{"id":"1c4044f3-3a86-4654-9561-da511ab13fc7","type":"BoxAnnotation"},{"id":"80650b08-2732-4457-910f-867edb22dc77","type":"GlyphRenderer"},{"id":"8b23933f-3dc3-4907-8011-d1de0e7c1334","type":"GlyphRenderer"}],"title":{"id":"1f4103c9-3c16-4e84-a1b2-f5ce38e8b9a7","type":"Title"},"tool_events":{"id":"07e9d866-0984-4a9b-ac2e-88f87fc1d6d5","type":"ToolEvents"},"toolbar":{"id":"2e8fd9ae-7308-4347-bcd4-8372aba4e0b7","type":"Toolbar"},"x_range":{"id":"723f796b-7ac7-41c5-9a74-e7cacb9936ce","type":"DataRange1d"},"y_range":{"id":"53fcc1c4-e161-40e6-ab95-86d5ec2dfc51","type":"DataRange1d"}},"id":"03ba255a-1621-4b57-a57e-d8f5106147ad","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"1c4044f3-3a86-4654-9561-da511ab13fc7","type":"BoxAnnotation"},"plot":{" ...
