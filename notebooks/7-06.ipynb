# %%
# リスト7.6.1：図のサイズの設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=400, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a245d919-b3c7-4e96-8285-0c0c70a4821f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="11f936e5-e183-4be2-875b-39f0e38483b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("11f936e5-e183-4be2-875b-39f0e38483b6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("11f936e5-e183-4be2-875b-39f0e38483b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '11f936e5-e183-4be2-875b-39f0e38483b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"205166b0-51f2-43b3-82fc-93d58948f834":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c2ed408f-63b3-4fdf-9611-c172e0bb9cd9","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"}},"id":"22da5962-eb4d-4423-a38c-0eacdd38ea46","type":"ResetTool"},{"attributes":{"callback":null},"id":"9a08d17f-8927-4b5c-b7f8-3d7cd63e6560","type":"DataRange1d"},{"attributes":{},"id":"96adbf0d-db68-4fad-bce7-3b421ba6a55a","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"}},"id":"b09757a7-ffa3-44a0-b485-433964937d9c","type":"HelpTool"},{"attributes":{"formatter":{"id":"4f9d0432-b141-44ce-93cd-18e100792e8c","type":"BasicTickFormatter"},"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"},"ticker":{"id":"d1082dc7-c12b-4d88-8369-fe50a0c2b089","type":"BasicTicker"}},"id":"5b5b790c-4a54-4331-994a-32ebe18287b0","type":"LinearAxis"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"}},"id":"724fc2a9-bd70-4a9e-ac36-5d0594d3f05f","type":"WheelZoomTool"},{"attributes":{},"id":"d1082dc7-c12b-4d88-8369-fe50a0c2b089","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"344431d2-09be-43a5-969f-b1a260bcdda1","type":"Title"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"},"ticker":{"id":"d1082dc7-c12b-4d88-8369-fe50a0c2b089","type":"BasicTicker"}},"id":"0b869f5b-7801-4bfb-a803-cab062b22450","type":"Grid"},{"attributes":{"formatter":{"id":"96adbf0d-db68-4fad-bce7-3b421ba6a55a","type":"BasicTickFormatter"},"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b4793c2-27af-4a2e-be6d-2462459deb9f","type":"BasicTicker"}},"id":"8da8bff1-de4e-4206-94bb-b7daa47a909b","type":"LinearAxis"},{"attributes":{},"id":"6b4793c2-27af-4a2e-be6d-2462459deb9f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b4793c2-27af-4a2e-be6d-2462459deb9f","type":"BasicTicker"}},"id":"0ec03bd7-94c2-41fc-9c7a-a64dd861cac3","type":"Grid"},{"attributes":{},"id":"4f9d0432-b141-44ce-93cd-18e100792e8c","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"5b5b790c-4a54-4331-994a-32ebe18287b0","type":"LinearAxis"}],"left":[{"id":"8da8bff1-de4e-4206-94bb-b7daa47a909b","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"5b5b790c-4a54-4331-994a-32ebe18287b0","type":"LinearAxis"},{"id":"0b869f5b-7801-4bfb-a803-cab062b22450","type":"Grid"},{"id":"8da8bff1-de4e-4206-94bb-b7daa47a909b","type":"LinearAxis"},{"id":"0ec03bd7-94c2-41fc-9c7a-a64dd861cac3","type":"Grid"},{"id":"c2ed408f-63b3-4fdf-9611-c172e0bb9cd9","type":"BoxAnnotation"}],"title":{"id":"344431d2-09be-43a5-969f-b1a260bcdda1","type":"Title"},"tool_events":{"id":"a0fb0f7a-8523-4a4c-a36e-f3e2d310e8fd","type":"ToolEvents"},"toolbar":{"id":"766e4f21-42b0-4532-992e-57878d09b799","type":"Toolbar"},"x_range":{"id":"aaf04b64-9ec5-4c99-9073-7f961da28a5b","type":"DataRange1d"},"y_range":{"id":"9a08d17f-8927-4b5c-b7f8-3d7cd63e6560","type":"DataRange1d"}},"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"}},"id":"b66893f6-4580-4380-bf97-cbd3f15c81ea","type":"PanTool"},{"attributes":{"plot":{"id":"8e8b0998-3cef-456c-9b9d-3e5c829dff07","subtype":"Figure","type":"Plot"}},"id":"ed00b4c3-74d2-4e58-bc72-3805a3b5fdfe","type":"SaveTool"},{"attributes ...

# %%
# リスト7.6.2：図の背景色の設定
p = figure(
    plot_width=200,
    plot_height=200,
    background_fill_color='red',
    background_fill_alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="382dc2f8-a691-4603-890b-bc4d1a55fdbf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("382dc2f8-a691-4603-890b-bc4d1a55fdbf");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("382dc2f8-a691-4603-890b-bc4d1a55fdbf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '382dc2f8-a691-4603-890b-bc4d1a55fdbf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2d40a37-dc8f-4814-9f9b-d49112d8e2af":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"5f3fd8df-ac24-496d-8415-5692e3c765c3","type":"Title"},{"attributes":{},"id":"a8cf7611-185f-4af3-b345-1cb0d5a290fe","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"}},"id":"fda6aaae-8224-4095-932c-3f6cd1ca9c87","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"05d8ca91-ec38-44bc-b544-361e07bddeea","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fda6aaae-8224-4095-932c-3f6cd1ca9c87","type":"PanTool"},{"id":"d930f81e-7bcd-4a74-a90f-2ab2ef606acb","type":"WheelZoomTool"},{"id":"d55e35a7-98b0-48ed-8df3-b6aa2feb2cb8","type":"BoxZoomTool"},{"id":"9674a187-48ed-4571-95bb-1f35f01b07ff","type":"SaveTool"},{"id":"e1e14e74-6e06-4a90-8c67-f38af16c21e6","type":"ResetTool"},{"id":"974e9691-a8f3-4d1e-aca1-d0dd2f03d178","type":"HelpTool"}]},"id":"9d0667c2-f1b5-45b1-ac2f-019cc13f98bb","type":"Toolbar"},{"attributes":{"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"}},"id":"e1e14e74-6e06-4a90-8c67-f38af16c21e6","type":"ResetTool"},{"attributes":{"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"}},"id":"d930f81e-7bcd-4a74-a90f-2ab2ef606acb","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"},"ticker":{"id":"19d45dfe-8570-4861-b5b1-4e6fa0ebb727","type":"BasicTicker"}},"id":"b8ff1268-7fd9-49d9-af01-a79f41f6145e","type":"Grid"},{"attributes":{},"id":"19d45dfe-8570-4861-b5b1-4e6fa0ebb727","type":"BasicTicker"},{"attributes":{"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"}},"id":"9674a187-48ed-4571-95bb-1f35f01b07ff","type":"SaveTool"},{"attributes":{"overlay":{"id":"05d8ca91-ec38-44bc-b544-361e07bddeea","type":"BoxAnnotation"},"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"}},"id":"d55e35a7-98b0-48ed-8df3-b6aa2feb2cb8","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"a8cf7611-185f-4af3-b345-1cb0d5a290fe","type":"BasicTickFormatter"},"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"},"ticker":{"id":"19d45dfe-8570-4861-b5b1-4e6fa0ebb727","type":"BasicTicker"}},"id":"3660826f-b343-41a4-a450-120633ea5aef","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"fcac7a23-9323-423b-9b41-ffde0b57f537","subtype":"Figure","type":"Plot"},"ticker":{"id":"03ff6d11-76cd-416a-a802-1a085a93b700","type":"BasicTicker"}},"id":"727d546d-bfcc-4733-baa5-cfcb0be0934c","type":"Grid"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"red"},"below":[{"id":"3660826f-b343-41a4-a450-120633ea5aef","type":"LinearAxis"}],"left":[{"id":"11b78f55-e213-45a5-ae38-dd62f07458b4","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"3660826f-b343-41a4-a450-120633ea5aef","type":"LinearAxis"},{"id":"b8ff1268-7fd9-49d9-af01-a79f41f6145e","type":"Grid"},{"id":"11b78f55-e213-45a5-ae38-dd62f07458b4","type":"LinearAxis"},{"id":"727d546d-bfcc-4733-baa5-cfcb0be0934c","type":"Grid"},{"id":"05d8ca91-ec38-44bc-b544-361e07bddeea","type":"BoxAnnotation"}],"title":{"id":"5f3fd8df-ac24-496d-8415-5692e3c765c3","type":"Title"},"tool_events":{"id":"1e326a67-4a22-4503-af2f-71add8268df2","type":"ToolEvents"},"toolbar":{"id":"9d0667c2-f1b5-45b1-ac2f-019cc13f98bb","type":"Toolbar"},"x_range":{"id":"792ccc57-5f18-44d0-8730-49178956034b","type":"DataRange1d"},"y_range":{"id":"76df376a-6d7b-49a7-a031-c909c7c85833","type":"D ...

# %%
# リスト7.6.3：余白の設定
p = figure(plot_width=200, plot_height=200,
           border_fill_color='red', border_fill_alpha=0.5)
p.min_border = 10
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ef643131-1e70-4137-bea8-910c04446a30"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ef643131-1e70-4137-bea8-910c04446a30");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ef643131-1e70-4137-bea8-910c04446a30");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ef643131-1e70-4137-bea8-910c04446a30' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"867d420f-a4dc-408f-a90f-5d1cf4278743":{"roots":{"references":[{"attributes":{"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"}},"id":"8427667f-5084-4194-81b8-b65623891670","type":"HelpTool"},{"attributes":{},"id":"640d1e5e-9344-4225-a1f6-d57b9bad6e47","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d6245223-29ca-4020-8ed5-c3f3c6bee801","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"4a6af39d-24ba-4bf6-87d1-c9c4bc8de184","type":"BasicTickFormatter"},"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"},"ticker":{"id":"640d1e5e-9344-4225-a1f6-d57b9bad6e47","type":"BasicTicker"}},"id":"3957a930-6cbb-4543-8086-8a2e11940d85","type":"LinearAxis"},{"attributes":{"formatter":{"id":"8e6ffbf1-5821-421b-a170-a5ec731c4ab8","type":"BasicTickFormatter"},"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"},"ticker":{"id":"3a0c2cee-c7ba-4b43-baef-eb9d10dfd517","type":"BasicTicker"}},"id":"82af59fd-76ef-4989-a944-1f60440e09df","type":"LinearAxis"},{"attributes":{},"id":"4a6af39d-24ba-4bf6-87d1-c9c4bc8de184","type":"BasicTickFormatter"},{"attributes":{},"id":"8e6ffbf1-5821-421b-a170-a5ec731c4ab8","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"}},"id":"31c597c6-482a-4f0a-a08b-2461a6713760","type":"ResetTool"},{"attributes":{"overlay":{"id":"d6245223-29ca-4020-8ed5-c3f3c6bee801","type":"BoxAnnotation"},"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"}},"id":"b4c42132-9911-40c7-88fa-4d04535cd558","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"},"ticker":{"id":"640d1e5e-9344-4225-a1f6-d57b9bad6e47","type":"BasicTicker"}},"id":"f04f0471-6686-4bd3-af0f-f6b46db67173","type":"Grid"},{"attributes":{},"id":"3a0c2cee-c7ba-4b43-baef-eb9d10dfd517","type":"BasicTicker"},{"attributes":{"callback":null},"id":"775695dc-5dd9-410c-b69b-984b1e9cb1c1","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"a25f7482-2ac3-4d12-9ab5-ab468efc05ee","type":"Title"},{"attributes":{},"id":"5e0958e2-fdc4-4dca-b43e-d4896ef0b673","type":"ToolEvents"},{"attributes":{"below":[{"id":"3957a930-6cbb-4543-8086-8a2e11940d85","type":"LinearAxis"}],"border_fill_alpha":{"value":0.5},"border_fill_color":{"value":"red"},"left":[{"id":"82af59fd-76ef-4989-a944-1f60440e09df","type":"LinearAxis"}],"min_border":10,"plot_height":200,"plot_width":200,"renderers":[{"id":"3957a930-6cbb-4543-8086-8a2e11940d85","type":"LinearAxis"},{"id":"f04f0471-6686-4bd3-af0f-f6b46db67173","type":"Grid"},{"id":"82af59fd-76ef-4989-a944-1f60440e09df","type":"LinearAxis"},{"id":"9ddbe5ef-7355-4ae6-812a-eb909e23e604","type":"Grid"},{"id":"d6245223-29ca-4020-8ed5-c3f3c6bee801","type":"BoxAnnotation"}],"title":{"id":"a25f7482-2ac3-4d12-9ab5-ab468efc05ee","type":"Title"},"tool_events":{"id":"5e0958e2-fdc4-4dca-b43e-d4896ef0b673","type":"ToolEvents"},"toolbar":{"id":"9fd87a40-9b00-4242-840c-f624b16c5b53","type":"Toolbar"},"x_range":{"id":"775695dc-5dd9-410c-b69b-984b1e9cb1c1","type":"DataRange1d"},"y_range":{"id":"95c376f1-9389-4b1a-8d82-04f852612cda","type":"DataRange1d"}},"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d069de22-e8bc-469c-816d-e7f09907be6a","subtype":"Figure","type":"Plot"}},"id":"5e3e034c-cfbf-4140-a0dd-d2236cbedf06","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c007d3c7-85b3-45f3-9ef0-d73c8147be4d","type":"PanTool"},{"id":"5e3e034c-cfbf-4140- ...

# %%
# リスト7.6.4：個別に余白を変更
p = figure(plot_width=200, plot_height=200)
p.border_fill_color = 'red'
p.min_border_left = 20
p.min_border_right = 60
p.min_border_top = 30
p.min_border_bottom = 50
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dbdc255b-05bc-421a-afef-6e1b7e35ffcc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dbdc255b-05bc-421a-afef-6e1b7e35ffcc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dbdc255b-05bc-421a-afef-6e1b7e35ffcc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dbdc255b-05bc-421a-afef-6e1b7e35ffcc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ab4a5c4b-3c81-4c2c-a880-34090848f40d":{"roots":{"references":[{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad2f5ada-a43a-49a9-8cac-8ff8ee410486","type":"BasicTicker"}},"id":"3ee5bff5-2f6c-4418-a5cf-3edaf478a946","type":"Grid"},{"attributes":{"callback":null},"id":"9ef6c2f2-856b-45e9-92e7-b6b4e8aa21ac","type":"DataRange1d"},{"attributes":{},"id":"329a89f6-e402-4aed-9cc7-b70bf46ac6af","type":"ToolEvents"},{"attributes":{},"id":"c697b9dc-19ed-467a-950b-0295c76d9d49","type":"BasicTicker"},{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"83567677-e270-4080-a36e-5051d92a6340","type":"SaveTool"},{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"09e8bb45-5ab5-4aa8-9f75-da226ed08b60","type":"PanTool"},{"attributes":{"formatter":{"id":"9e82362c-ae00-4f98-8f5a-adaf81effbc8","type":"BasicTickFormatter"},"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c697b9dc-19ed-467a-950b-0295c76d9d49","type":"BasicTicker"}},"id":"2b1543dd-bb69-47ca-9608-5580c663c96c","type":"LinearAxis"},{"attributes":{"formatter":{"id":"beeb7797-2ee6-4b7d-82d1-f0648f6ce84f","type":"BasicTickFormatter"},"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad2f5ada-a43a-49a9-8cac-8ff8ee410486","type":"BasicTicker"}},"id":"cbd48230-3dd0-4877-83f8-23b04db33dc3","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"09e8bb45-5ab5-4aa8-9f75-da226ed08b60","type":"PanTool"},{"id":"8665c1c6-a9e6-4dc9-b55e-ef703710c741","type":"WheelZoomTool"},{"id":"bcec0b2e-de32-4490-883f-9e40c2a72406","type":"BoxZoomTool"},{"id":"83567677-e270-4080-a36e-5051d92a6340","type":"SaveTool"},{"id":"61abcebe-4449-43c0-966f-fb83d8d08c99","type":"ResetTool"},{"id":"2d641313-4c5d-419f-b3e0-5f5359af3beb","type":"HelpTool"}]},"id":"fc2ff477-823d-4dbf-b036-bd3b2cf2e39d","type":"Toolbar"},{"attributes":{},"id":"beeb7797-2ee6-4b7d-82d1-f0648f6ce84f","type":"BasicTickFormatter"},{"attributes":{},"id":"ad2f5ada-a43a-49a9-8cac-8ff8ee410486","type":"BasicTicker"},{"attributes":{},"id":"9e82362c-ae00-4f98-8f5a-adaf81effbc8","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7d376bcf-bf5e-4b45-a1c8-c2b4a510a5f7","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"c697b9dc-19ed-467a-950b-0295c76d9d49","type":"BasicTicker"}},"id":"abff518b-cd1a-4f31-99bb-6c2eafd07140","type":"Grid"},{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"8665c1c6-a9e6-4dc9-b55e-ef703710c741","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"d2999372-2a21-49dc-859d-9fe36b5531ee","type":"Title"},{"attributes":{"overlay":{"id":"7d376bcf-bf5e-4b45-a1c8-c2b4a510a5f7","type":"BoxAnnotation"},"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"bcec0b2e-de32-4490-883f-9e40c2a72406","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"2d641313-4c5d-419f-b3e0-5f5359af3beb","type":"HelpTool"},{"attributes":{"plot":{"id":"6f5be1e3-e359-45f0-bd7c-3e335fe88cd4","subtype":"Figure","type":"Plot"}},"id":"61abcebe-4449-43c0-966f-fb83d8d08c99","type":"ResetTool"},{"attributes":{"below":[{"id":"cbd48230-3dd0-4877-83f8-23b04db33dc3","type":"LinearAxis"}],"border_fill_color":{"value":"red"},"le ...

# %%
# リスト7.6.5：図の外枠の設定
p = figure(plot_width=200, plot_height=200)
p.outline_line_width = 10
p.outline_line_color = 'red'
p.outline_line_alpha = 0.5
p.outline_line_dash = (5, 20)
p.outline_line_cap = 'round'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bf24fd3-ba75-4394-b4d0-d6395be3bd49"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bf24fd3-ba75-4394-b4d0-d6395be3bd49");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bf24fd3-ba75-4394-b4d0-d6395be3bd49");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bf24fd3-ba75-4394-b4d0-d6395be3bd49' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8167cfa9-a3c2-4225-8299-d1da9f3c30cd":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"31709522-b99c-4e01-ab68-32c288545818","type":"Title"},{"attributes":{"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"4af2d834-29f3-453b-bf16-4dc96c36a7c3","type":"ResetTool"},{"attributes":{"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"854f3ea7-fb85-4b59-9344-df5f80cf62bc","type":"HelpTool"},{"attributes":{"callback":null},"id":"8dd6a366-da06-4dc6-a23e-f2faef52a56c","type":"DataRange1d"},{"attributes":{"formatter":{"id":"498c83ca-6fe4-47c8-a347-31ce34de407c","type":"BasicTickFormatter"},"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"},"ticker":{"id":"dcd0d516-781b-4886-9f6c-8c5eded6ba5f","type":"BasicTicker"}},"id":"691fe2b6-3152-4bb8-bd6e-4a8f44a3ade0","type":"LinearAxis"},{"attributes":{"below":[{"id":"53f53829-2332-469a-a6c8-2c10abe972cb","type":"LinearAxis"}],"left":[{"id":"691fe2b6-3152-4bb8-bd6e-4a8f44a3ade0","type":"LinearAxis"}],"outline_line_alpha":{"value":0.5},"outline_line_cap":"round","outline_line_color":{"value":"red"},"outline_line_dash":[5,20],"outline_line_width":{"value":10},"plot_height":200,"plot_width":200,"renderers":[{"id":"53f53829-2332-469a-a6c8-2c10abe972cb","type":"LinearAxis"},{"id":"7c2c52b6-1346-4560-81c4-69141bfe0488","type":"Grid"},{"id":"691fe2b6-3152-4bb8-bd6e-4a8f44a3ade0","type":"LinearAxis"},{"id":"4055ecaa-80f9-4ff5-99c3-8c6c5ba1dd14","type":"Grid"},{"id":"71483c22-b627-405e-bfa1-7697c687bbed","type":"BoxAnnotation"}],"title":{"id":"31709522-b99c-4e01-ab68-32c288545818","type":"Title"},"tool_events":{"id":"72c8b16d-c383-492c-b202-406afae8ce8b","type":"ToolEvents"},"toolbar":{"id":"74a7e040-65fc-4f4d-9b5e-7efdb70a95f0","type":"Toolbar"},"x_range":{"id":"d8422124-6c98-497e-af5d-c99cc20d186c","type":"DataRange1d"},"y_range":{"id":"8dd6a366-da06-4dc6-a23e-f2faef52a56c","type":"DataRange1d"}},"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"71483c22-b627-405e-bfa1-7697c687bbed","type":"BoxAnnotation"},"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"9cda5713-f3fb-4b9d-8ab1-32fc6cf6f0e0","type":"BoxZoomTool"},{"attributes":{},"id":"dcd0d516-781b-4886-9f6c-8c5eded6ba5f","type":"BasicTicker"},{"attributes":{"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"014e69e3-31f2-490c-aead-2a9839f1cc26","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8d3f79ce-ef65-4064-8c42-c83d7358feea","type":"PanTool"},{"id":"fa256444-a626-45ec-b15c-39f404bbcfeb","type":"WheelZoomTool"},{"id":"9cda5713-f3fb-4b9d-8ab1-32fc6cf6f0e0","type":"BoxZoomTool"},{"id":"014e69e3-31f2-490c-aead-2a9839f1cc26","type":"SaveTool"},{"id":"4af2d834-29f3-453b-bf16-4dc96c36a7c3","type":"ResetTool"},{"id":"854f3ea7-fb85-4b59-9344-df5f80cf62bc","type":"HelpTool"}]},"id":"74a7e040-65fc-4f4d-9b5e-7efdb70a95f0","type":"Toolbar"},{"attributes":{},"id":"35d8030a-2974-46b0-af69-ac58e5a4e229","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"35d8030a-2974-46b0-af69-ac58e5a4e229","type":"BasicTickFormatter"},"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"},"ticker":{"id":"7544dbd1-6b59-4c8d-a293-cb91dfe570d7","type":"BasicTicker"}},"id":"53f53829-2332-469a-a6c8-2c10abe972cb","type":"LinearAxis"},{"attributes":{"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"8d3f79ce-ef65-4064-8c42-c83d7358feea","type":"PanTool"},{"attributes":{},"id":"72c8b16d-c383-492c-b202-406afae8ce8b","type":"ToolEvents"},{"attributes":{"plot":{"id":"4265e00a-f40e-458b-b0f6-5fdb486cd932","subtype":"Figure","type":"Plot"}},"id":"fa256444-a626-45ec-b15c-39f404bbcfeb","type":"WheelZoomTool"},{"attributes":{"plot":{"id" ...

# %%
# リスト7.6.6：タイトルの設定 （その1）
p = figure(plot_width=200, plot_height=200, title='Title')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c6a505d8-a2ac-4ab5-b322-83450ec330bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c6a505d8-a2ac-4ab5-b322-83450ec330bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c6a505d8-a2ac-4ab5-b322-83450ec330bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c6a505d8-a2ac-4ab5-b322-83450ec330bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5a8b538f-2f3d-4cb4-a8eb-fc6eb9d3aa1e":{"roots":{"references":[{"attributes":{"overlay":{"id":"4e5c031b-7787-46e5-a973-ef26709372b7","type":"BoxAnnotation"},"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"}},"id":"623e3138-abb4-4109-90ed-55e33cb61606","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"970ef5f3-2571-43bf-b16e-ecfc186d4b5d","type":"BasicTickFormatter"},"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"},"ticker":{"id":"74ff7fab-e5f4-490e-8194-1e84c05621eb","type":"BasicTicker"}},"id":"4f345468-3d3e-4ac4-85a0-8dedf119f1e9","type":"LinearAxis"},{"attributes":{},"id":"7f4539d7-e9af-4078-a58c-35d0437a1e49","type":"BasicTicker"},{"attributes":{"callback":null},"id":"e19999fe-4d43-45f5-9f05-27e5a92de5c3","type":"DataRange1d"},{"attributes":{},"id":"1b995a34-793f-4d6a-9642-80d506142ea8","type":"BasicTickFormatter"},{"attributes":{},"id":"74ff7fab-e5f4-490e-8194-1e84c05621eb","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4e5c031b-7787-46e5-a973-ef26709372b7","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"},"ticker":{"id":"74ff7fab-e5f4-490e-8194-1e84c05621eb","type":"BasicTicker"}},"id":"3144af81-364c-4c01-b6e8-a0028a1828d3","type":"Grid"},{"attributes":{"plot":null,"text":"Title"},"id":"fd2ed829-0c1e-498e-9533-249e55a572d5","type":"Title"},{"attributes":{"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"}},"id":"48673d8a-be28-41a3-904e-f8a04324bcde","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"}},"id":"1916cf66-8a6c-4209-b80a-ced13e0e24db","type":"SaveTool"},{"attributes":{"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"}},"id":"e187340b-f7bb-4e3b-a611-bdb81fefe056","type":"ResetTool"},{"attributes":{"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"}},"id":"4cb14bc3-0451-4a8d-a136-356f67bf6335","type":"HelpTool"},{"attributes":{"formatter":{"id":"1b995a34-793f-4d6a-9642-80d506142ea8","type":"BasicTickFormatter"},"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f4539d7-e9af-4078-a58c-35d0437a1e49","type":"BasicTicker"}},"id":"e9550e03-e23d-4b0b-aac0-6c59db1e4cd4","type":"LinearAxis"},{"attributes":{"callback":null},"id":"5468411e-0b5a-4b48-b851-aa473c2beecb","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b9a1c768-5188-4eea-b57c-857b0ad3653d","type":"PanTool"},{"id":"48673d8a-be28-41a3-904e-f8a04324bcde","type":"WheelZoomTool"},{"id":"623e3138-abb4-4109-90ed-55e33cb61606","type":"BoxZoomTool"},{"id":"1916cf66-8a6c-4209-b80a-ced13e0e24db","type":"SaveTool"},{"id":"e187340b-f7bb-4e3b-a611-bdb81fefe056","type":"ResetTool"},{"id":"4cb14bc3-0451-4a8d-a136-356f67bf6335","type":"HelpTool"}]},"id":"143fc8cb-2921-4aeb-9bfb-ca10f35e897a","type":"Toolbar"},{"attributes":{"plot":{"id":"5ba1e75c-3d40-464e-867d-608aea855ca4","subtype":"Figure","type":"Plot"},"ticker":{"id":"7f4539d7-e9af-4078-a58c-35d0437a1e49","type":"BasicTicker"}},"id":"7f68aaf8-fa2b-417f-9ccf-5fc525b1b131","type":"Grid"},{"attributes":{},"id":"970ef5f3-2571-43bf-b16e-ecfc186d4b5d","type":"BasicTickFormatter"},{"attributes":{},"id":"9a26030f-e644-4608-935a-064d3ba9c27e","type":"ToolEvents"},{"attributes":{"below":[{"id":"e9550e03-e23d-4b0b-aac0-6c59db1e4cd4","type":"LinearAxis"}],"left":[{"id":"4f345468-3d3e-4ac4-85a0-8dedf119f1e9","type":"LinearAxis"}],"plot_height":200,"plot_w ...

# %%
# リスト7.6.7：タイトルの設定 （その2）
p = figure(plot_width=200, plot_height=200)
p.title.text = 'Title'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c3048312-d51c-433d-aca9-b1b1dec0d080"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c3048312-d51c-433d-aca9-b1b1dec0d080");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c3048312-d51c-433d-aca9-b1b1dec0d080");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c3048312-d51c-433d-aca9-b1b1dec0d080' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"39c36d7a-5c77-42ae-9427-01131e8d2a12":{"roots":{"references":[{"attributes":{"formatter":{"id":"d66cffaf-b75c-4525-8374-0539cde83845","type":"BasicTickFormatter"},"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a521eca0-4b84-4f22-9b20-b80617366c71","type":"BasicTicker"}},"id":"58d25dbe-5a69-4dff-aa3e-3d5765220b15","type":"LinearAxis"},{"attributes":{},"id":"d66cffaf-b75c-4525-8374-0539cde83845","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"0021ab99-f013-4da5-b2dc-2b86f0407414","type":"ResetTool"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"862743f2-abe2-42be-a8ad-6ce6e6111b19","type":"SaveTool"},{"attributes":{},"id":"394b8880-1cff-4dc4-952c-8bdea24b1354","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"eb272e0c-311c-4c80-8f7f-5488b3671535","type":"LinearAxis"}],"left":[{"id":"58d25dbe-5a69-4dff-aa3e-3d5765220b15","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"eb272e0c-311c-4c80-8f7f-5488b3671535","type":"LinearAxis"},{"id":"7b90efe6-3db2-4d7b-80b6-4f7d2dc7f710","type":"Grid"},{"id":"58d25dbe-5a69-4dff-aa3e-3d5765220b15","type":"LinearAxis"},{"id":"0a7f508f-151b-4c2d-a4e1-fc411c6197e8","type":"Grid"},{"id":"4d3eba46-1fb0-4baf-85e5-d3fe8565e33a","type":"BoxAnnotation"}],"title":{"id":"331910dd-1325-4dda-9714-f00b4c4da7c0","type":"Title"},"tool_events":{"id":"4b95f32c-03d0-44b8-9559-3e41d5a35bb4","type":"ToolEvents"},"toolbar":{"id":"160aa59a-ff43-4b83-9b59-9167f47ea7b8","type":"Toolbar"},"x_range":{"id":"51e6e909-a6f5-42a5-9961-bb112ab8fb66","type":"DataRange1d"},"y_range":{"id":"dbf3043b-b268-49b2-bfd3-58ee8c19f401","type":"DataRange1d"}},"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"Title"},"id":"331910dd-1325-4dda-9714-f00b4c4da7c0","type":"Title"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"f28504a4-d88a-456a-84b8-29ecb619169f","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a521eca0-4b84-4f22-9b20-b80617366c71","type":"BasicTicker"}},"id":"0a7f508f-151b-4c2d-a4e1-fc411c6197e8","type":"Grid"},{"attributes":{},"id":"4b95f32c-03d0-44b8-9559-3e41d5a35bb4","type":"ToolEvents"},{"attributes":{},"id":"a521eca0-4b84-4f22-9b20-b80617366c71","type":"BasicTicker"},{"attributes":{"callback":null},"id":"51e6e909-a6f5-42a5-9961-bb112ab8fb66","type":"DataRange1d"},{"attributes":{"callback":null},"id":"dbf3043b-b268-49b2-bfd3-58ee8c19f401","type":"DataRange1d"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"2c72fff9-dd61-4b1e-aa42-bec06af874e4","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2c72fff9-dd61-4b1e-aa42-bec06af874e4","type":"PanTool"},{"id":"f28504a4-d88a-456a-84b8-29ecb619169f","type":"WheelZoomTool"},{"id":"2ec662c9-2c00-497e-9f96-0573ba341419","type":"BoxZoomTool"},{"id":"862743f2-abe2-42be-a8ad-6ce6e6111b19","type":"SaveTool"},{"id":"0021ab99-f013-4da5-b2dc-2b86f0407414","type":"ResetTool"},{"id":"f448eb0c-ead9-49fa-832a-b65e1a0fa998","type":"HelpTool"}]},"id":"160aa59a-ff43-4b83-9b59-9167f47ea7b8","type":"Toolbar"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"f448eb0c-ead9-49fa-832a-b65e1a0fa998","type":"HelpTool"},{"attributes":{"overlay":{"id":"4d3eba46-1fb0-4baf-85e5-d3fe8565e33a","type":"BoxAnnotation"},"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subtype":"Figure","type":"Plot"}},"id":"2ec662c9-2c00-497e-9f96-0573ba341419","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"f10a868e-158b-46f3-b956-b06d471d6cc8","subt ...

# %%
# リスト7.6.8：タイトルの水平位置の設定
p = figure(plot_width=200, plot_height=200, title='Title')
p.title.align = 'center'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ec24d2f6-5011-4445-8fa8-f61e434c7a44"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ec24d2f6-5011-4445-8fa8-f61e434c7a44");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ec24d2f6-5011-4445-8fa8-f61e434c7a44");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ec24d2f6-5011-4445-8fa8-f61e434c7a44' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"43bd7e16-dd25-44bb-996c-709036f3fbd9":{"roots":{"references":[{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"},"ticker":{"id":"03879204-f487-4873-b571-a2fa6704dc5a","type":"BasicTicker"}},"id":"29ae0f42-8945-48a2-bb00-033780bf9945","type":"Grid"},{"attributes":{"formatter":{"id":"046b4028-95b8-472b-aa0c-a7cb71fda25c","type":"BasicTickFormatter"},"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"},"ticker":{"id":"35e55bde-f638-40d9-868a-543e7b3a9b3a","type":"BasicTicker"}},"id":"6c95091c-719b-4751-8ed2-ad8cb1712bce","type":"LinearAxis"},{"attributes":{"overlay":{"id":"84bf1fa1-74b4-40a6-acfa-8216bc358498","type":"BoxAnnotation"},"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"82392347-98b5-4ca0-b8aa-7719c841d44d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"35a69d48-1ee8-4ae8-b1d3-0e5ca5a20674","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"7b440737-056c-4226-8f9b-f9f97d5da498","type":"LinearAxis"}],"left":[{"id":"6c95091c-719b-4751-8ed2-ad8cb1712bce","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"7b440737-056c-4226-8f9b-f9f97d5da498","type":"LinearAxis"},{"id":"29ae0f42-8945-48a2-bb00-033780bf9945","type":"Grid"},{"id":"6c95091c-719b-4751-8ed2-ad8cb1712bce","type":"LinearAxis"},{"id":"a76abccb-7d42-4ee4-aa05-c19e2e118661","type":"Grid"},{"id":"84bf1fa1-74b4-40a6-acfa-8216bc358498","type":"BoxAnnotation"}],"title":{"id":"fdc9475c-44eb-466d-994b-64eb893066a0","type":"Title"},"tool_events":{"id":"6877ad9a-03f4-4167-bd5b-209218df0c3c","type":"ToolEvents"},"toolbar":{"id":"56facb2d-f308-4184-a92a-ad50aada6dc3","type":"Toolbar"},"x_range":{"id":"e4df0eb3-482a-490b-8121-3023fe51b8cb","type":"DataRange1d"},"y_range":{"id":"9e24bd5a-3a83-4548-966d-f6ffca1ff570","type":"DataRange1d"}},"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"},"ticker":{"id":"35e55bde-f638-40d9-868a-543e7b3a9b3a","type":"BasicTicker"}},"id":"a76abccb-7d42-4ee4-aa05-c19e2e118661","type":"Grid"},{"attributes":{},"id":"f006efb9-9347-4f6b-bb11-aca7e01b08d5","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"3ca9b0b1-da24-4d98-bdb6-b8d0c5de3591","type":"PanTool"},{"attributes":{},"id":"6877ad9a-03f4-4167-bd5b-209218df0c3c","type":"ToolEvents"},{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"e5d876df-8041-4fb1-9e0e-e47aec609780","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"84bf1fa1-74b4-40a6-acfa-8216bc358498","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"3b08b7b2-8314-4a5d-9477-375f0a784b6f","type":"ResetTool"},{"attributes":{"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type":"Plot"}},"id":"48891866-e4dc-40fa-ad85-b176b3d209c6","type":"SaveTool"},{"attributes":{"callback":null},"id":"9e24bd5a-3a83-4548-966d-f6ffca1ff570","type":"DataRange1d"},{"attributes":{},"id":"046b4028-95b8-472b-aa0c-a7cb71fda25c","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"e4df0eb3-482a-490b-8121-3023fe51b8cb","type":"DataRange1d"},{"attributes":{"formatter":{"id":"f006efb9-9347-4f6b-bb11-aca7e01b08d5","type":"BasicTickFormatter"},"plot":{"id":"d4178411-4a32-4582-8750-f9e2d451dfac","subtype":"Figure","type" ...

# %%
# リスト7.6.9：タイトルの書式
p = figure(plot_width=200, plot_height=200, title='Title')
p.title.text_font = 'times'
p.title.text_font_size = '20pt'
p.title.text_font_style = 'bold'
p.title.text_color = 'red'
p.title.text_alpha = 0.5
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a0b6b7af-9eb8-4177-a6f3-065bfe73e167"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a0b6b7af-9eb8-4177-a6f3-065bfe73e167");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a0b6b7af-9eb8-4177-a6f3-065bfe73e167");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a0b6b7af-9eb8-4177-a6f3-065bfe73e167' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4dbf9fdd-7dc9-4ffa-88a6-f674704108bd":{"roots":{"references":[{"attributes":{"below":[{"id":"d451d8ad-1361-48b9-af84-9864ecb67c54","type":"LinearAxis"}],"left":[{"id":"541ed703-9c0f-49b4-910c-3a9a7c7dd1bc","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"d451d8ad-1361-48b9-af84-9864ecb67c54","type":"LinearAxis"},{"id":"888e9092-8075-425f-81f3-5e3d87bca772","type":"Grid"},{"id":"541ed703-9c0f-49b4-910c-3a9a7c7dd1bc","type":"LinearAxis"},{"id":"94d7dfa0-94b8-41ce-8109-4871d16d0671","type":"Grid"},{"id":"a3ca6205-bd2b-4406-8b44-207e6766e732","type":"BoxAnnotation"}],"title":{"id":"47dc63bd-d38f-4eb7-86e6-417063eb5c00","type":"Title"},"tool_events":{"id":"904e2222-918e-41e0-b004-a99fddd32963","type":"ToolEvents"},"toolbar":{"id":"d9a20f3a-f1fc-472a-ace5-de869375ff4d","type":"Toolbar"},"x_range":{"id":"8876e837-94d6-463a-8a46-af2a4aa14b0a","type":"DataRange1d"},"y_range":{"id":"1a5daa43-2509-45d7-9b1b-a3e26c011e92","type":"DataRange1d"}},"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"}},"id":"fff279ff-5da0-4835-930f-8a3301328f4c","type":"PanTool"},{"attributes":{"plot":null,"text":"Title","text_alpha":{"value":0.5},"text_color":{"value":"red"},"text_font":"times","text_font_size":{"value":"20pt"}},"id":"47dc63bd-d38f-4eb7-86e6-417063eb5c00","type":"Title"},{"attributes":{"callback":null},"id":"1a5daa43-2509-45d7-9b1b-a3e26c011e92","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"fdd7704d-346e-40c7-9541-adabd6f68d38","type":"BasicTicker"}},"id":"94d7dfa0-94b8-41ce-8109-4871d16d0671","type":"Grid"},{"attributes":{"formatter":{"id":"5bf2b680-1d65-45ff-b296-871d8736b967","type":"BasicTickFormatter"},"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef1a77c8-8e6c-4455-a7e5-5ef45274537d","type":"BasicTicker"}},"id":"d451d8ad-1361-48b9-af84-9864ecb67c54","type":"LinearAxis"},{"attributes":{},"id":"fdd7704d-346e-40c7-9541-adabd6f68d38","type":"BasicTicker"},{"attributes":{"overlay":{"id":"a3ca6205-bd2b-4406-8b44-207e6766e732","type":"BoxAnnotation"},"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"}},"id":"512ad9a9-dfcf-4104-9f3b-bb5de1d886a4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"}},"id":"7d6d2179-9d2e-4caa-99cc-9e974401135f","type":"WheelZoomTool"},{"attributes":{},"id":"5bf2b680-1d65-45ff-b296-871d8736b967","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef1a77c8-8e6c-4455-a7e5-5ef45274537d","type":"BasicTicker"}},"id":"888e9092-8075-425f-81f3-5e3d87bca772","type":"Grid"},{"attributes":{},"id":"ef1a77c8-8e6c-4455-a7e5-5ef45274537d","type":"BasicTicker"},{"attributes":{"plot":{"id":"7bbe1371-9c24-42ac-ba71-75b9015fd4eb","subtype":"Figure","type":"Plot"}},"id":"60e8e4f7-908a-48dc-90f1-fa858a19b97f","type":"SaveTool"},{"attributes":{},"id":"17c56db9-12f2-4414-bc66-b0de999f0034","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a3ca6205-bd2b-4406-8b44-207e6766e732","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fff279ff-5da0-4835-930f-8a3301328f4c","type":"PanTool"},{"id":"7d6d2179-9d2e-4caa-99cc-9e974401135f","type":"WheelZoomTool"},{"id":"512ad9a9-dfcf-4104-9f3b-bb5de1d886a4","type":"BoxZoomTool"},{"id":"60e8e4f7-908a-48 ...
