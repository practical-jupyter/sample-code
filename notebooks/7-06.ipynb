# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-6: 図の調整

# %%
# リスト7.6.1：図のサイズの設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=400, plot_height=200)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9bced2ab-9c7b-477c-9b11-543beaf27915">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="730a405a-43ef-4919-9e26-32aa35f626f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("730a405a-43ef-4919-9e26-32aa35f626f7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("730a405a-43ef-4919-9e26-32aa35f626f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '730a405a-43ef-4919-9e26-32aa35f626f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b3c91ec5-09ca-49fd-8620-3e270aae334c":{"roots":{"references":[{"attributes":{"below":[{"id":"80d30e86-2ec9-4c29-b708-8c971d0942e1","type":"LinearAxis"}],"left":[{"id":"97a52075-acf1-492f-93ea-6e4d0ba596ae","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"80d30e86-2ec9-4c29-b708-8c971d0942e1","type":"LinearAxis"},{"id":"e8868004-56b2-43a3-a52d-e30b1282adfe","type":"Grid"},{"id":"97a52075-acf1-492f-93ea-6e4d0ba596ae","type":"LinearAxis"},{"id":"c512ae09-d245-4ac0-bd92-9f1061d1b7d6","type":"Grid"},{"id":"d849f04e-2703-4c08-bf0d-043acab8851d","type":"BoxAnnotation"}],"title":{"id":"59a5aaf0-3ce9-4c43-9c0d-c9487887ed52","type":"Title"},"tool_events":{"id":"5cdfd0a2-8c3c-427d-a20d-cb4660e5c13a","type":"ToolEvents"},"toolbar":{"id":"8b1d0d62-e16b-4410-83d1-5d907b2f152a","type":"Toolbar"},"x_range":{"id":"ead10502-3484-40b7-ba0b-b08aeaa1f299","type":"DataRange1d"},"y_range":{"id":"0754a3be-e869-46b1-861a-42e9bb5a4e8e","type":"DataRange1d"}},"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"77b7a2b5-471a-4664-baf1-8ab38ff46b6d","type":"PanTool"},{"attributes":{},"id":"7cefd56e-5dec-4f3f-af88-4e5cf22f81c3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"41333873-109d-42d9-990a-f9c6c98fa1cf","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"d849f04e-2703-4c08-bf0d-043acab8851d","type":"BoxAnnotation"},"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"28452070-1f9d-4fa6-b407-faa57e52979b","type":"BoxZoomTool"},{"attributes":{},"id":"3bfb3462-7c00-4782-9eeb-e70b3ff3f074","type":"BasicTicker"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"3c839da0-becb-493c-84ee-af4296f7c1a8","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d849f04e-2703-4c08-bf0d-043acab8851d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"2edcf9ae-42f8-496a-b9cc-10890b2630d3","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"77b7a2b5-471a-4664-baf1-8ab38ff46b6d","type":"PanTool"},{"id":"41333873-109d-42d9-990a-f9c6c98fa1cf","type":"WheelZoomTool"},{"id":"28452070-1f9d-4fa6-b407-faa57e52979b","type":"BoxZoomTool"},{"id":"3c839da0-becb-493c-84ee-af4296f7c1a8","type":"SaveTool"},{"id":"2edcf9ae-42f8-496a-b9cc-10890b2630d3","type":"ResetTool"},{"id":"9bc2f78a-301f-43b5-a6bc-de839e5f7811","type":"HelpTool"}]},"id":"8b1d0d62-e16b-4410-83d1-5d907b2f152a","type":"Toolbar"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"}},"id":"9bc2f78a-301f-43b5-a6bc-de839e5f7811","type":"HelpTool"},{"attributes":{"callback":null},"id":"ead10502-3484-40b7-ba0b-b08aeaa1f299","type":"DataRange1d"},{"attributes":{"callback":null},"id":"0754a3be-e869-46b1-861a-42e9bb5a4e8e","type":"DataRange1d"},{"attributes":{"formatter":{"id":"7cefd56e-5dec-4f3f-af88-4e5cf22f81c3","type":"BasicTickFormatter"},"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"},"ticker":{"id":"3bfb3462-7c00-4782-9eeb-e70b3ff3f074","type":"BasicTicker"}},"id":"80d30e86-2ec9-4c29-b708-8c971d0942e1","type":"LinearAxis"},{"attributes":{},"id":"5cdfd0a2-8c3c-427d-a20d-cb4660e5c13a","type":"ToolEvents"},{"attributes":{"plot":{"id":"5f6a9bec-f874-489d-9e47-2ddbd38ad053","subtype":"Figure","type":"Plot"},"ticker":{"id":"3bfb3462-7c0 ...

# %%
# リスト7.6.2：図の背景色の設定
p = figure(
    plot_width=200,
    plot_height=200,
    background_fill_color="red",
    background_fill_alpha=0.5,
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c14e792-7d2d-4125-a9e2-e619547ed7e2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8c14e792-7d2d-4125-a9e2-e619547ed7e2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c14e792-7d2d-4125-a9e2-e619547ed7e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c14e792-7d2d-4125-a9e2-e619547ed7e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"75fc28c6-5210-461d-8b33-88c53670538c":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"},"ticker":{"id":"a61b187a-040a-4c7d-8d18-6005ab180aab","type":"BasicTicker"}},"id":"ddf8b250-17b1-4a2a-ba92-ac5a6f08c887","type":"Grid"},{"attributes":{},"id":"fc468577-6d0b-407f-82d9-13687eb08034","type":"ToolEvents"},{"attributes":{"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7251cdb-3e0d-4d2c-a153-912d89591a1a","type":"BasicTicker"}},"id":"377e9744-b19c-4905-a771-ffeb6aad7785","type":"Grid"},{"attributes":{"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"}},"id":"3905e067-6dad-4b73-906c-3a86de5821ee","type":"ResetTool"},{"attributes":{"callback":null},"id":"8e44221a-f067-4be9-a119-bf3b9dc55965","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"cbfb34a7-5c7e-46fd-8a74-983bf842f236","type":"PanTool"},{"id":"de08bed8-b4fc-4d36-b0a4-3e06f74101a6","type":"WheelZoomTool"},{"id":"98f48b41-087d-4c66-bdf3-5a99967dff2d","type":"BoxZoomTool"},{"id":"e5622ba7-4b9a-4edb-b240-08be2b749fd5","type":"SaveTool"},{"id":"3905e067-6dad-4b73-906c-3a86de5821ee","type":"ResetTool"},{"id":"c7207ce4-336e-4479-a854-c59e555c58ce","type":"HelpTool"}]},"id":"c5568f10-2f46-414f-8321-48ed9bcb7bf2","type":"Toolbar"},{"attributes":{"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"}},"id":"e5622ba7-4b9a-4edb-b240-08be2b749fd5","type":"SaveTool"},{"attributes":{},"id":"6e73dd8f-34f3-4f67-a964-c425eff3f2cc","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"}},"id":"cbfb34a7-5c7e-46fd-8a74-983bf842f236","type":"PanTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"red"},"below":[{"id":"1c88c75c-cd81-4c1c-9d58-1f6be2f450bc","type":"LinearAxis"}],"left":[{"id":"da255834-ad26-4c5c-a2b2-92832b01ebce","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"1c88c75c-cd81-4c1c-9d58-1f6be2f450bc","type":"LinearAxis"},{"id":"377e9744-b19c-4905-a771-ffeb6aad7785","type":"Grid"},{"id":"da255834-ad26-4c5c-a2b2-92832b01ebce","type":"LinearAxis"},{"id":"ddf8b250-17b1-4a2a-ba92-ac5a6f08c887","type":"Grid"},{"id":"ca256f0c-f885-4739-9eac-2176afa0d409","type":"BoxAnnotation"}],"title":{"id":"8cf5269e-0e70-482a-a916-c3890a878bc2","type":"Title"},"tool_events":{"id":"fc468577-6d0b-407f-82d9-13687eb08034","type":"ToolEvents"},"toolbar":{"id":"c5568f10-2f46-414f-8321-48ed9bcb7bf2","type":"Toolbar"},"x_range":{"id":"8e44221a-f067-4be9-a119-bf3b9dc55965","type":"DataRange1d"},"y_range":{"id":"4043d080-3d86-4f2b-8b41-b1608b1442fd","type":"DataRange1d"}},"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"e1d11607-3522-416b-90d8-3502231e9ee5","type":"BasicTickFormatter"},"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7251cdb-3e0d-4d2c-a153-912d89591a1a","type":"BasicTicker"}},"id":"1c88c75c-cd81-4c1c-9d58-1f6be2f450bc","type":"LinearAxis"},{"attributes":{"overlay":{"id":"ca256f0c-f885-4739-9eac-2176afa0d409","type":"BoxAnnotation"},"plot":{"id":"24c8ed37-83f3-4758-ba8f-9195f24a9a75","subtype":"Figure","type":"Plot"}},"id":"98f48b41-087d-4c66-bdf3-5a99967dff2d","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"4043d080-3d86-4f2b-8b41-b1608b1442fd","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca256f0c-f885-4739-9eac-2176afa0d409","type ...

# %%
# リスト7.6.3：余白の設定
p = figure(
    plot_width=200, plot_height=200, border_fill_color="red", border_fill_alpha=0.5
)
p.min_border = 10
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ccf11176-6971-42de-b89e-c89a54f32193"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ccf11176-6971-42de-b89e-c89a54f32193");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ccf11176-6971-42de-b89e-c89a54f32193");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ccf11176-6971-42de-b89e-c89a54f32193' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"107dab5f-9699-4e84-92c2-6cc4bb20f70b":{"roots":{"references":[{"attributes":{"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"}},"id":"8a78f451-9adc-49ab-a0dc-7ba06ebb82aa","type":"SaveTool"},{"attributes":{"overlay":{"id":"102c1c5a-bef3-40a5-95cb-8ff80b9088ef","type":"BoxAnnotation"},"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"}},"id":"7a5a6c72-0680-438b-8e38-aa443094d3c6","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"c05656fd-2cad-442a-860c-ce5e0363b281","type":"Title"},{"attributes":{"callback":null},"id":"74b8b797-8168-4ebb-abe1-ebf40671d03f","type":"DataRange1d"},{"attributes":{"callback":null},"id":"069fcb3f-0455-4170-bb2f-8fb1d44343a7","type":"DataRange1d"},{"attributes":{"formatter":{"id":"18057887-eece-44bf-a7bc-318ad12f9679","type":"BasicTickFormatter"},"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"},"ticker":{"id":"637a5723-090f-4866-a760-adb3eaee50da","type":"BasicTicker"}},"id":"0af04949-50d1-4392-8b39-a9d65a1c689a","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"},"ticker":{"id":"637a5723-090f-4866-a760-adb3eaee50da","type":"BasicTicker"}},"id":"8f1aecc1-4209-4ddc-b666-6ec0fc39c9e4","type":"Grid"},{"attributes":{},"id":"4f81f89c-bdcc-401e-84b8-ba12b933eea7","type":"ToolEvents"},{"attributes":{"formatter":{"id":"0e6043d1-347b-4c94-b462-775f3b8dbac9","type":"BasicTickFormatter"},"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9e63314-470a-4a98-a2eb-ce9c4c6c99af","type":"BasicTicker"}},"id":"2f92d37d-a9e4-4278-b3a3-e6d6d7a8e2e3","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"80ba6514-ec99-4483-9963-eb13c66b0148","type":"PanTool"},{"id":"728a1c66-7cf8-4eac-a04a-f46a104730f3","type":"WheelZoomTool"},{"id":"7a5a6c72-0680-438b-8e38-aa443094d3c6","type":"BoxZoomTool"},{"id":"8a78f451-9adc-49ab-a0dc-7ba06ebb82aa","type":"SaveTool"},{"id":"8e1866e1-1547-4523-b1f0-7eb8d52971af","type":"ResetTool"},{"id":"320dd22d-7c74-4c5a-88a7-d97c40e5d4af","type":"HelpTool"}]},"id":"d55e0549-b3b2-4956-a185-c4d03eb374b8","type":"Toolbar"},{"attributes":{},"id":"a9e63314-470a-4a98-a2eb-ce9c4c6c99af","type":"BasicTicker"},{"attributes":{"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9e63314-470a-4a98-a2eb-ce9c4c6c99af","type":"BasicTicker"}},"id":"bcd8f9a9-de40-4f24-ac7c-9bd563f14142","type":"Grid"},{"attributes":{},"id":"637a5723-090f-4866-a760-adb3eaee50da","type":"BasicTicker"},{"attributes":{"plot":{"id":"e8e99a4d-739a-474b-8029-b7d138874af2","subtype":"Figure","type":"Plot"}},"id":"728a1c66-7cf8-4eac-a04a-f46a104730f3","type":"WheelZoomTool"},{"attributes":{},"id":"18057887-eece-44bf-a7bc-318ad12f9679","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"2f92d37d-a9e4-4278-b3a3-e6d6d7a8e2e3","type":"LinearAxis"}],"border_fill_alpha":{"value":0.5},"border_fill_color":{"value":"red"},"left":[{"id":"0af04949-50d1-4392-8b39-a9d65a1c689a","type":"LinearAxis"}],"min_border":10,"plot_height":200,"plot_width":200,"renderers":[{"id":"2f92d37d-a9e4-4278-b3a3-e6d6d7a8e2e3","type":"LinearAxis"},{"id":"bcd8f9a9-de40-4f24-ac7c-9bd563f14142","type":"Grid"},{"id":"0af04949-50d1-4392-8b39-a9d65a1c689a","type":"LinearAxis"},{"id":"8f1aecc1-4209-4ddc-b666-6ec0fc39c9e4","type":"Grid"},{"id":"102c1c5a-bef3-40a5-95cb-8ff80b9088ef","type":"BoxAnnotation"}],"title":{"id":"c05656fd-2cad-442a-860c-ce5e0363b281","type":"Title"},"tool_events":{"id":"4f81f89c-bdcc-401e-84b8-ba12b933eea7","type":"ToolEvents"},"toolbar":{"id":"d55e0549-b3b2-4956-a185-c4d03eb374b8","type":"Toolbar"},"x_range":{"id":"069fcb3f-0455-4170-bb2f-8fb1d44343a7","type":"DataRange1d"},"y_range":{"id":"74b8b797-8168-4ebb-abe1-ebf40671d03f","type":"DataRange1d"}},"id": ...

# %%
# リスト7.6.4：個別に余白を変更
p = figure(plot_width=200, plot_height=200)
p.border_fill_color = "red"
p.min_border_left = 20
p.min_border_right = 60
p.min_border_top = 30
p.min_border_bottom = 50
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eee3436f-4260-45e7-a365-28e9f0b2ccc9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eee3436f-4260-45e7-a365-28e9f0b2ccc9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eee3436f-4260-45e7-a365-28e9f0b2ccc9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eee3436f-4260-45e7-a365-28e9f0b2ccc9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b8669e9d-778e-4ae7-9759-c188f334244b":{"roots":{"references":[{"attributes":{"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"}},"id":"feab38eb-4cdb-43f6-ad3c-ba211e39dc15","type":"SaveTool"},{"attributes":{"overlay":{"id":"133436c5-55e6-4f04-914c-1082e9b26291","type":"BoxAnnotation"},"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"}},"id":"75e2521d-8a66-4923-ad59-ba295456d33d","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"c2528a91-3270-4db5-8f62-efe1f0be494b","type":"DataRange1d"},{"attributes":{},"id":"65fdff8a-3c9e-451a-b113-a152455f2937","type":"BasicTicker"},{"attributes":{},"id":"67a20236-85eb-4f87-a177-a9ec8ca245b0","type":"BasicTickFormatter"},{"attributes":{},"id":"2f1bcecd-d69d-459f-8a5b-72400be1835e","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"4cfbe071-fe54-41d2-8ea4-6bf6f742d6da","type":"DataRange1d"},{"attributes":{"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"}},"id":"37708d67-704d-425b-8aa0-da971071e913","type":"ResetTool"},{"attributes":{"below":[{"id":"66fe2120-0221-4d1d-b1dd-1c61efaa09e5","type":"LinearAxis"}],"border_fill_color":{"value":"red"},"left":[{"id":"9e8874a4-16c5-494e-b55b-9f3e393652bd","type":"LinearAxis"}],"min_border_bottom":50,"min_border_left":20,"min_border_right":60,"min_border_top":30,"plot_height":200,"plot_width":200,"renderers":[{"id":"66fe2120-0221-4d1d-b1dd-1c61efaa09e5","type":"LinearAxis"},{"id":"3cf52822-10fc-475c-8830-de0c9307025f","type":"Grid"},{"id":"9e8874a4-16c5-494e-b55b-9f3e393652bd","type":"LinearAxis"},{"id":"367ed2b3-2906-4c0e-9941-6c0c2dbf144b","type":"Grid"},{"id":"133436c5-55e6-4f04-914c-1082e9b26291","type":"BoxAnnotation"}],"title":{"id":"c3a4d48d-f7e6-4caa-84f6-e65b29082c00","type":"Title"},"tool_events":{"id":"7ddcd033-ede9-424f-9f48-b397908d02ab","type":"ToolEvents"},"toolbar":{"id":"8973aa49-18b6-484f-a9c1-c7d945854567","type":"Toolbar"},"x_range":{"id":"c2528a91-3270-4db5-8f62-efe1f0be494b","type":"DataRange1d"},"y_range":{"id":"4cfbe071-fe54-41d2-8ea4-6bf6f742d6da","type":"DataRange1d"}},"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"65fdff8a-3c9e-451a-b113-a152455f2937","type":"BasicTicker"}},"id":"3cf52822-10fc-475c-8830-de0c9307025f","type":"Grid"},{"attributes":{"formatter":{"id":"2f1bcecd-d69d-459f-8a5b-72400be1835e","type":"BasicTickFormatter"},"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"65fdff8a-3c9e-451a-b113-a152455f2937","type":"BasicTicker"}},"id":"66fe2120-0221-4d1d-b1dd-1c61efaa09e5","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"c3a4d48d-f7e6-4caa-84f6-e65b29082c00","type":"Title"},{"attributes":{"formatter":{"id":"67a20236-85eb-4f87-a177-a9ec8ca245b0","type":"BasicTickFormatter"},"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b80c553-d7fa-401d-962e-664672f5dfd8","type":"BasicTicker"}},"id":"9e8874a4-16c5-494e-b55b-9f3e393652bd","type":"LinearAxis"},{"attributes":{"plot":{"id":"ebb712fa-ddd3-4d63-9e22-071e316d23e0","subtype":"Figure","type":"Plot"}},"id":"07413be2-91f0-4175-846b-3b574890a46c","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"07413be2-91f0-4175-846b-3b574890a46c","type":"PanTool"},{"id":"c26cd336-d7b4-443e-840d-430114409f42","type":"WheelZoomTool"},{"id":"75e2521d-8a66-4923-ad59-ba295456d33d","type":"BoxZoomTool"},{"id":"feab38eb-4cdb-43f6-ad3c-ba211e39dc15","type":"SaveTool"},{"id":"37708d67-704d-425b-8aa0-da971071e913","type":"ResetTool"},{"id":"07c8706f-d063-4d55-965e-3c2008c7c21a","type":"HelpTool"}]},"id":"8973aa49-18b6-484f-a9c1-c7d945854567","type":"Toolbar"},{"attributes":{},"id":"7ddcd033-ede9-424f-9f48-b397908d02 ...

# %%
# リスト7.6.5：図の外枠の設定
p = figure(plot_width=200, plot_height=200)
p.outline_line_width = 10
p.outline_line_color = "red"
p.outline_line_alpha = 0.5
p.outline_line_dash = (5, 20)
p.outline_line_cap = "round"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="12940997-0972-4cea-9d9d-2c06c6450554"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("12940997-0972-4cea-9d9d-2c06c6450554");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("12940997-0972-4cea-9d9d-2c06c6450554");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '12940997-0972-4cea-9d9d-2c06c6450554' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b65a21b4-6943-4c46-af8d-14265ff4abf1":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7cfc86f9-2825-411e-a4a1-5b2941e77180","type":"PanTool"},{"id":"e829b7c8-1b6e-4b76-852e-093283bdd8b9","type":"WheelZoomTool"},{"id":"3d40b6b3-69ee-45e9-83aa-948f34b8882f","type":"BoxZoomTool"},{"id":"b17e60d3-94bb-4cbb-8f7d-ff67e352ffe2","type":"SaveTool"},{"id":"89b81e88-7a45-4956-b890-634bffa58174","type":"ResetTool"},{"id":"d1efad73-8079-4efe-a2ea-36d3aca76194","type":"HelpTool"}]},"id":"497311bc-83b8-4c24-92b0-43a25eed02f3","type":"Toolbar"},{"attributes":{"callback":null},"id":"9b88bc40-5290-49b1-b0e8-b6e900e1492e","type":"DataRange1d"},{"attributes":{},"id":"f1cd79f6-17ab-4b49-a7ee-33af2d4ab14e","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"131b6a72-c603-4ce6-8abb-37b248304826","type":"DataRange1d"},{"attributes":{"below":[{"id":"67c464b4-b10c-4b22-a8ca-b7e10cf68eda","type":"LinearAxis"}],"left":[{"id":"a0aa607a-d74c-4469-b7ea-8662b66f4168","type":"LinearAxis"}],"outline_line_alpha":{"value":0.5},"outline_line_cap":"round","outline_line_color":{"value":"red"},"outline_line_dash":[5,20],"outline_line_width":{"value":10},"plot_height":200,"plot_width":200,"renderers":[{"id":"67c464b4-b10c-4b22-a8ca-b7e10cf68eda","type":"LinearAxis"},{"id":"e403f24e-9de3-44fb-87ca-d13e6a62b521","type":"Grid"},{"id":"a0aa607a-d74c-4469-b7ea-8662b66f4168","type":"LinearAxis"},{"id":"c941e4ec-bb2c-4426-85c3-7b0f3557f9c3","type":"Grid"},{"id":"65902a38-acc7-4a40-8df7-94ebadab2303","type":"BoxAnnotation"}],"title":{"id":"819de2ec-29e1-4f9f-a4b0-d9f6f36d1eae","type":"Title"},"tool_events":{"id":"69c9c701-719e-4ec5-9553-d49aeedd140f","type":"ToolEvents"},"toolbar":{"id":"497311bc-83b8-4c24-92b0-43a25eed02f3","type":"Toolbar"},"x_range":{"id":"131b6a72-c603-4ce6-8abb-37b248304826","type":"DataRange1d"},"y_range":{"id":"9b88bc40-5290-49b1-b0e8-b6e900e1492e","type":"DataRange1d"}},"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"}},"id":"89b81e88-7a45-4956-b890-634bffa58174","type":"ResetTool"},{"attributes":{"formatter":{"id":"f1cd79f6-17ab-4b49-a7ee-33af2d4ab14e","type":"BasicTickFormatter"},"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"},"ticker":{"id":"40086d25-18e9-44a1-aadd-f567a8e695b4","type":"BasicTicker"}},"id":"a0aa607a-d74c-4469-b7ea-8662b66f4168","type":"LinearAxis"},{"attributes":{"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"},"ticker":{"id":"3ac6e272-2100-472c-ad31-4cc87579c5fd","type":"BasicTicker"}},"id":"e403f24e-9de3-44fb-87ca-d13e6a62b521","type":"Grid"},{"attributes":{"formatter":{"id":"8a2fff7e-c430-4fc6-9ecc-317032868c9e","type":"BasicTickFormatter"},"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"},"ticker":{"id":"3ac6e272-2100-472c-ad31-4cc87579c5fd","type":"BasicTicker"}},"id":"67c464b4-b10c-4b22-a8ca-b7e10cf68eda","type":"LinearAxis"},{"attributes":{},"id":"69c9c701-719e-4ec5-9553-d49aeedd140f","type":"ToolEvents"},{"attributes":{},"id":"8a2fff7e-c430-4fc6-9ecc-317032868c9e","type":"BasicTickFormatter"},{"attributes":{},"id":"3ac6e272-2100-472c-ad31-4cc87579c5fd","type":"BasicTicker"},{"attributes":{"overlay":{"id":"65902a38-acc7-4a40-8df7-94ebadab2303","type":"BoxAnnotation"},"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"}},"id":"3d40b6b3-69ee-45e9-83aa-948f34b8882f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"}},"id":"d1efad73-8079-4efe-a2ea-36d3aca76194","type":"HelpTool"},{"attributes":{},"id":"40086d25-18e9-44a1-aadd-f567a8e695b4","type":"BasicTicker"},{"attributes":{"plot":{"id":"5fab91c4-fe39-41fc-9f05-6f0c3f897d37","subtype":"Figure","type":"Plot"}},"id":"e829b7c8 ...

# %%
# リスト7.6.6：タイトルの設定 （その1）
p = figure(plot_width=200, plot_height=200, title="Title")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7366706b-46b3-4ed4-ace4-e6cc67fecdf4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7366706b-46b3-4ed4-ace4-e6cc67fecdf4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7366706b-46b3-4ed4-ace4-e6cc67fecdf4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7366706b-46b3-4ed4-ace4-e6cc67fecdf4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e8372075-3542-4b91-945d-d31bf5ca68aa":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"30b322db-0d6c-47cf-8213-1cb93bda7b9d","type":"PanTool"},{"id":"fc5b2497-0b81-4ad6-a84c-f2cdb0dce4ce","type":"WheelZoomTool"},{"id":"c6a3e3dd-ddce-4b29-84fa-346c24ecb623","type":"BoxZoomTool"},{"id":"95df04dd-c88f-42c3-9421-017c67b8194a","type":"SaveTool"},{"id":"bd58883d-5bd2-47c4-bbe9-6c78c5947a8d","type":"ResetTool"},{"id":"6b70e4e7-dc22-4872-aa27-ac11deaf34e2","type":"HelpTool"}]},"id":"196397bf-3f48-4b72-bc8a-b6dbe256e4fb","type":"Toolbar"},{"attributes":{},"id":"72ac7d5b-b255-458d-b06e-03f85d398ac7","type":"BasicTicker"},{"attributes":{"formatter":{"id":"0521107c-1bf6-4037-95fd-1d3515ca5e19","type":"BasicTickFormatter"},"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"},"ticker":{"id":"72ac7d5b-b255-458d-b06e-03f85d398ac7","type":"BasicTicker"}},"id":"ddff37fc-9060-4bf5-a6e1-a3a2344557a5","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6b26dc9b-f245-470e-8389-874154f75acd","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"23b3eee9-7ff0-44eb-9184-349269e73a02","type":"DataRange1d"},{"attributes":{},"id":"0521107c-1bf6-4037-95fd-1d3515ca5e19","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"ddff37fc-9060-4bf5-a6e1-a3a2344557a5","type":"LinearAxis"}],"left":[{"id":"9f17681a-634a-487f-b11e-aef445a491bf","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"ddff37fc-9060-4bf5-a6e1-a3a2344557a5","type":"LinearAxis"},{"id":"0a031f45-30b2-4450-89c1-a0406e438b26","type":"Grid"},{"id":"9f17681a-634a-487f-b11e-aef445a491bf","type":"LinearAxis"},{"id":"73072aa6-606e-4178-af0f-bdbe55769873","type":"Grid"},{"id":"6b26dc9b-f245-470e-8389-874154f75acd","type":"BoxAnnotation"}],"title":{"id":"fc39b775-3325-4509-92ca-0877b95e045c","type":"Title"},"tool_events":{"id":"b795b8fd-dc0a-4cdf-9e7a-29653cf17f92","type":"ToolEvents"},"toolbar":{"id":"196397bf-3f48-4b72-bc8a-b6dbe256e4fb","type":"Toolbar"},"x_range":{"id":"3b8ae616-fd95-4a15-96ad-5519c1334cd5","type":"DataRange1d"},"y_range":{"id":"23b3eee9-7ff0-44eb-9184-349269e73a02","type":"DataRange1d"}},"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"},"ticker":{"id":"53164cdb-22f5-409d-80f4-ac80d2d99725","type":"BasicTicker"}},"id":"73072aa6-606e-4178-af0f-bdbe55769873","type":"Grid"},{"attributes":{"callback":null},"id":"3b8ae616-fd95-4a15-96ad-5519c1334cd5","type":"DataRange1d"},{"attributes":{"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"}},"id":"6b70e4e7-dc22-4872-aa27-ac11deaf34e2","type":"HelpTool"},{"attributes":{},"id":"53164cdb-22f5-409d-80f4-ac80d2d99725","type":"BasicTicker"},{"attributes":{"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"}},"id":"95df04dd-c88f-42c3-9421-017c67b8194a","type":"SaveTool"},{"attributes":{"overlay":{"id":"6b26dc9b-f245-470e-8389-874154f75acd","type":"BoxAnnotation"},"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"}},"id":"c6a3e3dd-ddce-4b29-84fa-346c24ecb623","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"}},"id":"fc5b2497-0b81-4ad6-a84c-f2cdb0dce4ce","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f8f5ee67-cd3e-4246-b5c9-ead29ae4083f","subtype":"Figure","type":"Plot"}},"id":"30b322db-0d6c-47cf-8213-1cb93bda7b9d","type":"PanTool"},{"attributes":{},"id":"65ae6b45-14ea-48f7-8 ...

# %%
# リスト7.6.7：タイトルの設定 （その2）
p = figure(plot_width=200, plot_height=200)
p.title.text = "Title"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="87c155a5-50a1-4217-880a-9f9c777ba6e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("87c155a5-50a1-4217-880a-9f9c777ba6e6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("87c155a5-50a1-4217-880a-9f9c777ba6e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '87c155a5-50a1-4217-880a-9f9c777ba6e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6e01c718-0522-41f6-ab00-92b9e37a9834":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"df2bd229-af15-4313-baef-0569129d610c","type":"BoxAnnotation"},{"attributes":{},"id":"8dfee1d0-cb36-49f1-ae80-e1ae4d0f0e43","type":"BasicTicker"},{"attributes":{"callback":null},"id":"8127fac5-bea5-45c0-80d1-be32c66087c2","type":"DataRange1d"},{"attributes":{"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"}},"id":"d0350f5e-37a9-43b8-804d-528b1cb81449","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"},"ticker":{"id":"8dfee1d0-cb36-49f1-ae80-e1ae4d0f0e43","type":"BasicTicker"}},"id":"c893257d-c012-4bd1-ba58-0d7112fbf53f","type":"Grid"},{"attributes":{"overlay":{"id":"df2bd229-af15-4313-baef-0569129d610c","type":"BoxAnnotation"},"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"}},"id":"0ba55839-306f-473f-aa1d-1abd44f3a36a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"}},"id":"e91290bf-3b87-4e6a-9303-0cbeee0f0fc2","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"}},"id":"e21f1e26-0232-4efd-8647-0d720ba62e2a","type":"HelpTool"},{"attributes":{"callback":null},"id":"447c42ec-e010-47f9-9821-f4d3aac1225c","type":"DataRange1d"},{"attributes":{},"id":"507af0d5-9885-4734-8c87-e04af980dea2","type":"BasicTicker"},{"attributes":{"below":[{"id":"6a95e04f-cab0-44d1-9a4e-ba5ac7eec5c3","type":"LinearAxis"}],"left":[{"id":"2c9fa5f9-da23-46a3-becc-d8104e5f62fc","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6a95e04f-cab0-44d1-9a4e-ba5ac7eec5c3","type":"LinearAxis"},{"id":"eef7a793-55c9-4abe-89fa-18e3b4f1897d","type":"Grid"},{"id":"2c9fa5f9-da23-46a3-becc-d8104e5f62fc","type":"LinearAxis"},{"id":"c893257d-c012-4bd1-ba58-0d7112fbf53f","type":"Grid"},{"id":"df2bd229-af15-4313-baef-0569129d610c","type":"BoxAnnotation"}],"title":{"id":"c624d133-35ae-458a-98fb-cf8aec897f4f","type":"Title"},"tool_events":{"id":"451ff789-268c-4ad7-baea-1cd278f55bc3","type":"ToolEvents"},"toolbar":{"id":"2db45fc7-d257-4d54-982d-3770b8a74132","type":"Toolbar"},"x_range":{"id":"8127fac5-bea5-45c0-80d1-be32c66087c2","type":"DataRange1d"},"y_range":{"id":"447c42ec-e010-47f9-9821-f4d3aac1225c","type":"DataRange1d"}},"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5ef14850-a36f-4bb4-aada-30c1accc3e2e","type":"PanTool"},{"id":"e91290bf-3b87-4e6a-9303-0cbeee0f0fc2","type":"WheelZoomTool"},{"id":"0ba55839-306f-473f-aa1d-1abd44f3a36a","type":"BoxZoomTool"},{"id":"d0350f5e-37a9-43b8-804d-528b1cb81449","type":"SaveTool"},{"id":"5c2b6d62-6f0d-4809-a1a3-d7990fb7cd9b","type":"ResetTool"},{"id":"e21f1e26-0232-4efd-8647-0d720ba62e2a","type":"HelpTool"}]},"id":"2db45fc7-d257-4d54-982d-3770b8a74132","type":"Toolbar"},{"attributes":{"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"}},"id":"5c2b6d62-6f0d-4809-a1a3-d7990fb7cd9b","type":"ResetTool"},{"attributes":{},"id":"451ff789-268c-4ad7-baea-1cd278f55bc3","type":"ToolEvents"},{"attributes":{},"id":"e4676e18-4c5a-4107-9a86-cbf81a385a21","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"e4676e18-4c5a-4107-9a86-cbf81a385a21","type":"BasicTickFormatter"},"plot":{"id":"aa09b60e-7377-4559-a758-bdd9c827c338","subtype":"Figure","type":"Plot"},"ticker":{"id":"507af0d5-9885-4734-8c87-e04af980dea2","type":"BasicTicker"}},"id":"6a95e04f-cab0-44d1 ...

# %%
# リスト7.6.8：タイトルの水平位置の設定
p = figure(plot_width=200, plot_height=200, title="Title")
p.title.align = "center"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="654a5026-a52c-40b0-838c-d28ad7eb9094"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("654a5026-a52c-40b0-838c-d28ad7eb9094");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("654a5026-a52c-40b0-838c-d28ad7eb9094");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '654a5026-a52c-40b0-838c-d28ad7eb9094' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7f87f619-b404-453f-8e3b-7a68fc7d3308":{"roots":{"references":[{"attributes":{},"id":"767337e2-87f0-421c-9c2a-cdc315d58068","type":"ToolEvents"},{"attributes":{"callback":null},"id":"a13da9c4-64e3-48c9-aa6f-ff023a7a4e9c","type":"DataRange1d"},{"attributes":{"align":"center","plot":null,"text":"Title"},"id":"0e12518f-157d-4051-8445-34ed510b56ef","type":"Title"},{"attributes":{"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"}},"id":"608caa70-8fce-4034-a658-e7ebed63f192","type":"PanTool"},{"attributes":{"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"}},"id":"f54f3416-a33a-454f-8906-13c1350dae49","type":"ResetTool"},{"attributes":{"formatter":{"id":"f7589abe-96e6-48a5-8a2b-f027786722aa","type":"BasicTickFormatter"},"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"22759982-df82-4a73-ab3f-07cd87d44a36","type":"BasicTicker"}},"id":"cfdb425e-45d0-4170-84b2-a198fe61249a","type":"LinearAxis"},{"attributes":{"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b319e5ec-a423-4de2-83eb-961780d42713","type":"BasicTicker"}},"id":"494a18a2-dc04-49c2-a4bb-652398e4318f","type":"Grid"},{"attributes":{},"id":"f7589abe-96e6-48a5-8a2b-f027786722aa","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"608caa70-8fce-4034-a658-e7ebed63f192","type":"PanTool"},{"id":"5121e2fc-c11c-4c7e-ba72-28f3f3762f63","type":"WheelZoomTool"},{"id":"c2d710af-f751-45fb-b030-042329a90039","type":"BoxZoomTool"},{"id":"312cdb12-16a2-42e9-802b-dd34adcf61cf","type":"SaveTool"},{"id":"f54f3416-a33a-454f-8906-13c1350dae49","type":"ResetTool"},{"id":"db4e90bc-071e-47bd-8b64-e133f2bea4de","type":"HelpTool"}]},"id":"95db7107-ff18-4e7c-b880-990e6a912f59","type":"Toolbar"},{"attributes":{},"id":"370da10b-5e82-4a7a-86cd-03e8e6f6cc24","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"}},"id":"db4e90bc-071e-47bd-8b64-e133f2bea4de","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"80d26005-5902-4c90-9899-7b692576503c","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"22759982-df82-4a73-ab3f-07cd87d44a36","type":"BasicTicker"}},"id":"3f03196f-490f-4960-8bd3-07c9b45d0f03","type":"Grid"},{"attributes":{},"id":"22759982-df82-4a73-ab3f-07cd87d44a36","type":"BasicTicker"},{"attributes":{"formatter":{"id":"370da10b-5e82-4a7a-86cd-03e8e6f6cc24","type":"BasicTickFormatter"},"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b319e5ec-a423-4de2-83eb-961780d42713","type":"BasicTicker"}},"id":"20539297-601d-4868-b8ad-456e76b2360a","type":"LinearAxis"},{"attributes":{"plot":{"id":"d9b821f1-50e3-4188-aad4-f6652c964a4c","subtype":"Figure","type":"Plot"}},"id":"5121e2fc-c11c-4c7e-ba72-28f3f3762f63","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"20539297-601d-4868-b8ad-456e76b2360a","type":"LinearAxis"}],"left":[{"id":"cfdb425e-45d0-4170-84b2-a198fe61249a","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"20539297-601d-4868-b8ad-456e76b2360a","type":"LinearAxis"},{"id":"494a18a2-dc04-49c2-a4bb-652398e4318f","type":"Grid"},{"id":"cfdb425e-45d0-4170-84b2-a198fe61249a","type":"LinearAxis"},{"id":"3f03196f-490f-4960-8bd3-07c9b45d0f03","type":"Grid"},{"id":"80d26005-5902-4c90-9899-7b692576503c","type":"BoxAnnotation"}],"title":{"id":"0e12518f-157d-4051-8445-34ed510b56ef","type":"Title" ...

# %%
# リスト7.6.9：タイトルの書式
p = figure(plot_width=200, plot_height=200, title="Title")
p.title.text_font = "times"
p.title.text_font_size = "20pt"
p.title.text_font_style = "bold"
p.title.text_color = "red"
p.title.text_alpha = 0.5
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f6a6a0e6-31c1-42b5-96f8-e69647e5f5fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f6a6a0e6-31c1-42b5-96f8-e69647e5f5fb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6a6a0e6-31c1-42b5-96f8-e69647e5f5fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6a6a0e6-31c1-42b5-96f8-e69647e5f5fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e6ecc725-ead1-4e71-b7a6-3c688fb65849":{"roots":{"references":[{"attributes":{},"id":"e5430b28-cff7-4b81-8362-1652fb065e25","type":"BasicTicker"},{"attributes":{},"id":"2c2d6735-ba95-4738-8d70-e16f6c5a21a0","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"2fdb0a89-9e23-44be-941c-4783cae0a16c","type":"DataRange1d"},{"attributes":{"formatter":{"id":"2c2d6735-ba95-4738-8d70-e16f6c5a21a0","type":"BasicTickFormatter"},"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5430b28-cff7-4b81-8362-1652fb065e25","type":"BasicTicker"}},"id":"b4e1a11a-2c1b-43a4-a0d4-0ff6a437dafe","type":"LinearAxis"},{"attributes":{},"id":"ced622ef-b6ad-46fc-924a-3eadce503ef2","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9b00b397-63b7-4c28-a6d8-735332225965","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5430b28-cff7-4b81-8362-1652fb065e25","type":"BasicTicker"}},"id":"90a1e442-4fc8-4fcf-9438-b68b82ad1cee","type":"Grid"},{"attributes":{"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"54b4b225-3470-4176-ba21-e0c936e85529","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"66783374-caf6-4ab5-8946-96deca7e463f","type":"BasicTickFormatter"},"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"46d46c53-ba4a-4909-905f-8b47690d73ab","type":"BasicTicker"}},"id":"9a87fde5-09e9-4aaf-81e3-35dd86d56345","type":"LinearAxis"},{"attributes":{},"id":"66783374-caf6-4ab5-8946-96deca7e463f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"1d8ebac6-847c-4fba-bbde-0890b37c5dd6","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1d8ebac6-847c-4fba-bbde-0890b37c5dd6","type":"PanTool"},{"id":"54b4b225-3470-4176-ba21-e0c936e85529","type":"WheelZoomTool"},{"id":"8d284fe3-3632-4c3b-9533-e413700b64bf","type":"BoxZoomTool"},{"id":"619be65d-f9c6-4e96-a1c5-42aaad011b59","type":"SaveTool"},{"id":"0ce2baf6-9e2b-43fb-8d85-1138b71b9c6e","type":"ResetTool"},{"id":"d60e06da-f27f-4a04-9d51-ab9309e27e15","type":"HelpTool"}]},"id":"d4eec944-41e1-4bc8-8a66-626aca8e3d0f","type":"Toolbar"},{"attributes":{"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"d60e06da-f27f-4a04-9d51-ab9309e27e15","type":"HelpTool"},{"attributes":{"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"619be65d-f9c6-4e96-a1c5-42aaad011b59","type":"SaveTool"},{"attributes":{"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"0ce2baf6-9e2b-43fb-8d85-1138b71b9c6e","type":"ResetTool"},{"attributes":{},"id":"46d46c53-ba4a-4909-905f-8b47690d73ab","type":"BasicTicker"},{"attributes":{"overlay":{"id":"332ad4c6-779b-4015-87be-f0aad3cd928c","type":"BoxAnnotation"},"plot":{"id":"5aa737b1-deeb-4e0c-82d6-c123ccffa1d5","subtype":"Figure","type":"Plot"}},"id":"8d284fe3-3632-4c3b-9533-e413700b64bf","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"Title","text_alpha":{"value":0.5},"text_color":{"value":"red"},"text_font":"times","text_font_size":{"value":"20pt"}},"id":"87264374-2eba-446a-ba2c-20a97e6f7abc","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"332ad4c6-779b-4015-87be-f0aad3cd928c","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"9a87fde5-09e9-4aaf-81e3-35dd86d56345","type":"LinearAxis"}],"left":[{"id":"b4e1a11a-2c1b-43a4-a0d4-0ff6a437dafe","type":"Li ...
