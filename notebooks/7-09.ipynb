# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-9: 軸書式の調整

# %%
# リスト7.9.1：軸の書式の設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.axis_label = "x"
p.yaxis.axis_label = "y"
p.xaxis.axis_label_text_color = "red"
p.axis.axis_line_width = 3  # X軸、Y軸両方に適用される
p.xaxis.axis_line_dash = "dashed"
p.xaxis.axis_label_standoff = 30
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="894362e1-73ac-4bfd-ba5e-7095d997b484">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1ab11ba0-817d-4de9-9865-70a6eebf5d2b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1ab11ba0-817d-4de9-9865-70a6eebf5d2b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1ab11ba0-817d-4de9-9865-70a6eebf5d2b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1ab11ba0-817d-4de9-9865-70a6eebf5d2b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"57f30614-91df-4e47-b6d5-074042f936ad":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a9be87f4-5512-4901-a120-ca826208196a","type":"PanTool"},{"id":"5f51bbc4-227a-42f3-b712-d5e5cd5e791f","type":"WheelZoomTool"},{"id":"8448028d-7a48-45f3-b029-2f923adeba72","type":"BoxZoomTool"},{"id":"0b56f670-6e5b-4b5e-85b4-a2352c197d1a","type":"SaveTool"},{"id":"f6e69a76-dd56-4e0f-be62-647f812c74cc","type":"ResetTool"},{"id":"edf3024e-9d75-4760-ad71-d0140ab12940","type":"HelpTool"}]},"id":"303ad826-f198-4244-9c3a-fce2099d2a56","type":"Toolbar"},{"attributes":{},"id":"96e1a1fe-5c0c-438a-9e08-26a98cedf8d3","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"12854fd1-eea8-4db2-8a9a-dedc64c3d048","type":"Circle"},{"attributes":{},"id":"58813a91-75e7-4a93-ad43-3586c1e3833b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"a9be87f4-5512-4901-a120-ca826208196a","type":"PanTool"},{"attributes":{"below":[{"id":"7b709801-93c9-4553-9c13-3261bea94753","type":"LinearAxis"}],"left":[{"id":"6751b255-de7c-403e-b899-517bab0cf196","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"7b709801-93c9-4553-9c13-3261bea94753","type":"LinearAxis"},{"id":"2c0f06ee-c615-4314-baca-2910d1c34c48","type":"Grid"},{"id":"6751b255-de7c-403e-b899-517bab0cf196","type":"LinearAxis"},{"id":"6366d25a-b9d1-495a-ae61-49d360d987a5","type":"Grid"},{"id":"3a11604b-a760-4502-b9bc-9ca53a554598","type":"BoxAnnotation"},{"id":"c9cf678d-d381-490d-bb47-146d9f28910a","type":"GlyphRenderer"}],"title":{"id":"4bbebe9c-f155-4dc3-81d7-9140d58c9bbf","type":"Title"},"tool_events":{"id":"b688aad9-f6ce-4832-9b5c-91bf81e9cbe4","type":"ToolEvents"},"toolbar":{"id":"303ad826-f198-4244-9c3a-fce2099d2a56","type":"Toolbar"},"x_range":{"id":"04f152bf-05c8-4c74-b6ec-a73b89fc1728","type":"DataRange1d"},"y_range":{"id":"aa97de87-8814-4a8a-af42-4f3650b35687","type":"DataRange1d"}},"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"4bbebe9c-f155-4dc3-81d7-9140d58c9bbf","type":"Title"},{"attributes":{"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"5f51bbc4-227a-42f3-b712-d5e5cd5e791f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"3a11604b-a760-4502-b9bc-9ca53a554598","type":"BoxAnnotation"},"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"8448028d-7a48-45f3-b029-2f923adeba72","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"04f152bf-05c8-4c74-b6ec-a73b89fc1728","type":"DataRange1d"},{"attributes":{"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"0b56f670-6e5b-4b5e-85b4-a2352c197d1a","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"01157b8b-4b5e-4323-9db8-1c496543327f","type":"ColumnDataSource"},{"attributes":{},"id":"b688aad9-f6ce-4832-9b5c-91bf81e9cbe4","type":"ToolEvents"},{"attributes":{"data_source":{"id":"01157b8b-4b5e-4323-9db8-1c496543327f","type":"ColumnDataSource"},"glyph":{"id":"12854fd1-eea8-4db2-8a9a-dedc64c3d048","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7f6cc8e6-8a10-4bcd-9471-9c35e7f9ca0e","type":"Circle"},"selection_glyph":null},"id":"c9cf678d-d381-490d-bb47-146d9f28910a","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"f6e69a76-dd56-4e0f-be62-647f812c74cc","type":"ResetTool"},{"attributes":{"callback":null},"id":"aa97de87-8814-4a8a-af42-4f3650b35687","type":"DataRange1d"},{"attributes":{"plot":{"id":"3e0950cc-dc19-40d9-bb88-0acd9336326b","subtype":"Figure","type":"Plot"}},"id":"edf3024e-9d7 ...

# %%
# リスト7.9.2：軸の幅の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.yaxis.bounds = (-0.5, 0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="249e1355-1f97-439b-b4f2-809ca986e665"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("249e1355-1f97-439b-b4f2-809ca986e665");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("249e1355-1f97-439b-b4f2-809ca986e665");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '249e1355-1f97-439b-b4f2-809ca986e665' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bf636570-a116-4c85-b1da-3627270d02c0":{"roots":{"references":[{"attributes":{"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"}},"id":"0f990933-01b6-4f83-8c9d-1dae994fe5f5","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"5dc9c22b-1a72-49bf-ae47-bdc4f596648a","type":"DataRange1d"},{"attributes":{"data_source":{"id":"68a22f2c-4c42-4cfe-bcc9-ecbf7cdb0d1c","type":"ColumnDataSource"},"glyph":{"id":"fcc8974b-df44-487f-b556-00d045673c44","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6654ef2c-9e22-4960-983e-7393bc1659de","type":"Circle"},"selection_glyph":null},"id":"cecd5b90-345d-4ced-ac58-6c8ddaee2696","type":"GlyphRenderer"},{"attributes":{},"id":"b2d84860-fad6-4bb7-a0df-50a739083105","type":"BasicTicker"},{"attributes":{"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"},"ticker":{"id":"257a98e5-3fe4-4c3c-afd7-b5e00dcef881","type":"BasicTicker"}},"id":"6172a7d6-5551-4594-91a0-66a93f565d51","type":"Grid"},{"attributes":{},"id":"327e937f-4698-4cd1-b6b3-6e922d86752f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"}},"id":"e30d3a4e-6671-45bc-b485-1768e4325a66","type":"HelpTool"},{"attributes":{"bounds":[-0.5,0.5],"formatter":{"id":"327e937f-4698-4cd1-b6b3-6e922d86752f","type":"BasicTickFormatter"},"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"},"ticker":{"id":"b2d84860-fad6-4bb7-a0df-50a739083105","type":"BasicTicker"}},"id":"b7e7db35-4d9b-4622-9e9c-5a8d8ed9a4d9","type":"LinearAxis"},{"attributes":{"formatter":{"id":"a4bcb1b9-2318-446d-8ab1-927921abfd3a","type":"BasicTickFormatter"},"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"},"ticker":{"id":"257a98e5-3fe4-4c3c-afd7-b5e00dcef881","type":"BasicTicker"}},"id":"5a624e22-fe1e-4997-8d25-b4b9d390b672","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"},"ticker":{"id":"b2d84860-fad6-4bb7-a0df-50a739083105","type":"BasicTicker"}},"id":"419d0912-5474-4a6f-9add-ae3446148665","type":"Grid"},{"attributes":{},"id":"e46d17c6-ddec-4f53-9018-7bede8f9f2be","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1bb13e46-b91d-4fcd-b868-45ebc40d2cef","type":"PanTool"},{"id":"0f990933-01b6-4f83-8c9d-1dae994fe5f5","type":"WheelZoomTool"},{"id":"fa0fc3c1-9129-421c-9a22-fc6667d733fb","type":"BoxZoomTool"},{"id":"8dcbb627-e163-439e-843a-cd605d778c40","type":"SaveTool"},{"id":"38dd5210-2ca2-43fc-871b-0ad96e236ce3","type":"ResetTool"},{"id":"e30d3a4e-6671-45bc-b485-1768e4325a66","type":"HelpTool"}]},"id":"75d872be-2dc4-487a-9e19-a1cc9b255d4e","type":"Toolbar"},{"attributes":{"below":[{"id":"5a624e22-fe1e-4997-8d25-b4b9d390b672","type":"LinearAxis"}],"left":[{"id":"b7e7db35-4d9b-4622-9e9c-5a8d8ed9a4d9","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"5a624e22-fe1e-4997-8d25-b4b9d390b672","type":"LinearAxis"},{"id":"6172a7d6-5551-4594-91a0-66a93f565d51","type":"Grid"},{"id":"b7e7db35-4d9b-4622-9e9c-5a8d8ed9a4d9","type":"LinearAxis"},{"id":"419d0912-5474-4a6f-9add-ae3446148665","type":"Grid"},{"id":"cb882259-233d-4b12-99ba-b95fab1c8758","type":"BoxAnnotation"},{"id":"cecd5b90-345d-4ced-ac58-6c8ddaee2696","type":"GlyphRenderer"}],"title":{"id":"46771b19-8c16-4072-8fec-8e23ae666f97","type":"Title"},"tool_events":{"id":"e46d17c6-ddec-4f53-9018-7bede8f9f2be","type":"ToolEvents"},"toolbar":{"id":"75d872be-2dc4-487a-9e19-a1cc9b255d4e","type":"Toolbar"},"x_range":{"id":"e76a2a67-535a-42ca-b047-f571af45b26c","type":"DataRange1d"},"y_range":{"id":"5dc9c22b-1a72-49bf-ae47-bdc4f596648a","type":"DataRange1d"}},"id":"53283a67-1e8d-473c-8405-92c715148aad","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x ...

# %%
# リスト7.9.3：目盛りの書式の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_tick_line_width = 3
p.yaxis.major_tick_line_color = "red"
p.yaxis.minor_tick_line_color = "blue"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="945c0714-d467-4832-9223-7132d9fb7894"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("945c0714-d467-4832-9223-7132d9fb7894");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("945c0714-d467-4832-9223-7132d9fb7894");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '945c0714-d467-4832-9223-7132d9fb7894' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c65a3217-fe60-4f2f-a168-ff140c7a714b":{"roots":{"references":[{"attributes":{},"id":"1ef73761-0800-4ca3-8d37-9966c135686a","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"201efa3f-8e57-4ded-b6bf-4db08ac9d44e","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"f6690db9-9fa8-40a0-a19f-790d6eb38797","type":"Title"},{"attributes":{"formatter":{"id":"c69c1045-b571-4cff-ad3d-3197a2ad3526","type":"BasicTickFormatter"},"major_tick_line_color":{"value":"red"},"minor_tick_line_color":{"value":"blue"},"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"},"ticker":{"id":"242a9463-4e25-4cb1-90ea-887ae0886645","type":"BasicTicker"}},"id":"6de0fa59-6cc8-464e-b65b-f9b959815967","type":"LinearAxis"},{"attributes":{"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"},"ticker":{"id":"9730f987-c5df-48e2-bd44-48cb2c468255","type":"BasicTicker"}},"id":"4a38d56f-e4fc-4f35-bf8a-6cba25877d62","type":"Grid"},{"attributes":{"data_source":{"id":"201efa3f-8e57-4ded-b6bf-4db08ac9d44e","type":"ColumnDataSource"},"glyph":{"id":"5612c0bc-e4cf-48b7-b6c9-6ae8d01c019a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b0f7d957-ce60-4a65-920b-1487734665fb","type":"Circle"},"selection_glyph":null},"id":"4cc5addb-527e-40c0-ab7b-1b96565efe22","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c55ee4de-72e2-402e-ba2e-fabe8d09b65d","type":"BoxAnnotation"},{"attributes":{},"id":"c69c1045-b571-4cff-ad3d-3197a2ad3526","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"}},"id":"9482f14e-3bd7-4b99-b324-4328f498f676","type":"ResetTool"},{"attributes":{"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"}},"id":"020c3847-3fce-455b-b5b3-13e5241b71d0","type":"PanTool"},{"attributes":{"below":[{"id":"72b35c3b-c0dd-4cf2-bc9d-03824737c59d","type":"LinearAxis"}],"left":[{"id":"6de0fa59-6cc8-464e-b65b-f9b959815967","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"72b35c3b-c0dd-4cf2-bc9d-03824737c59d","type":"LinearAxis"},{"id":"4a38d56f-e4fc-4f35-bf8a-6cba25877d62","type":"Grid"},{"id":"6de0fa59-6cc8-464e-b65b-f9b959815967","type":"LinearAxis"},{"id":"c9fdf4a1-9edf-469a-a3c0-c9f968b5d02d","type":"Grid"},{"id":"c55ee4de-72e2-402e-ba2e-fabe8d09b65d","type":"BoxAnnotation"},{"id":"4cc5addb-527e-40c0-ab7b-1b96565efe22","type":"GlyphRenderer"}],"title":{"id":"f6690db9-9fa8-40a0-a19f-790d6eb38797","type":"Title"},"tool_events":{"id":"1201cc48-101a-4d68-9bcf-881a46efedbb","type":"ToolEvents"},"toolbar":{"id":"05c17eb0-ea37-47f5-ad52-109516f28fef","type":"Toolbar"},"x_range":{"id":"0e0dee7b-4337-47ea-969f-243e9932cedc","type":"DataRange1d"},"y_range":{"id":"6d07ea3e-ed25-4a96-9d8c-6727762a573c","type":"DataRange1d"}},"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"}},"id":"21ceff65-2daa-4d07-a046-e3d844e315b9","type":"WheelZoomTool"},{"attributes":{},"id":"9730f987-c5df-48e2-bd44-48cb2c468255","type":"BasicTicker"},{"attributes":{"formatter":{"id":"1ef73761-0800-4ca3-8d37-9966c135686a","type":"BasicTickFormatter"},"major_tick_line_width":{"value":3},"plot":{"id":"55c389e5-7403-4c72-a83c-ed083dd0b6f7","subtype":"Figure","type":"Plot"},"ticker":{"id":"9730f987-c5df-48e2-bd44-48cb2c468255","type":"BasicTicker"}},"id":"72b35c3b-c0dd-4cf2-bc9d-03824737c59d","type":"LinearAxis"},{"attributes":{"plot":{"id":"55c389e5-7403-4c72-a83 ...

# %%
# リスト7.9.4：目盛りラベルの書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_label_text_color = "red"
p.yaxis.major_label_text_font_size = "10pt"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8383b100-7bd7-43f9-8e46-a953ddf025f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8383b100-7bd7-43f9-8e46-a953ddf025f5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8383b100-7bd7-43f9-8e46-a953ddf025f5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8383b100-7bd7-43f9-8e46-a953ddf025f5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a14bb2f4-74cd-44d9-af22-01de40f99269":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"917e3628-4c54-4e7b-8386-ac7e033e165b","type":"Circle"},{"attributes":{"formatter":{"id":"792739fd-0f20-4ebc-ab3d-5dfcd5b23e91","type":"BasicTickFormatter"},"major_label_text_color":{"value":"red"},"plot":{"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"},"ticker":{"id":"827c1cd1-c662-45ae-916c-4712b92891a9","type":"BasicTicker"}},"id":"dcb08b53-a3ed-47cb-8d60-7104bde34599","type":"LinearAxis"},{"attributes":{"below":[{"id":"dcb08b53-a3ed-47cb-8d60-7104bde34599","type":"LinearAxis"}],"left":[{"id":"5831f069-bfc8-4292-a025-74f57e20405e","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"dcb08b53-a3ed-47cb-8d60-7104bde34599","type":"LinearAxis"},{"id":"b3003c6c-b9c6-4e4b-9eed-875ec4be9942","type":"Grid"},{"id":"5831f069-bfc8-4292-a025-74f57e20405e","type":"LinearAxis"},{"id":"c5e1bb7d-6061-49ed-9d29-4d56e4f537be","type":"Grid"},{"id":"1604fcae-e2d4-4813-86aa-18fc4e5d6452","type":"BoxAnnotation"},{"id":"48150f7d-a17a-415c-8b5b-6162501902fc","type":"GlyphRenderer"}],"title":{"id":"0ee0ea8c-cf93-4eca-b70c-e45bebd40b5f","type":"Title"},"tool_events":{"id":"9d1256c7-8b7c-456f-9ecd-a4394301651c","type":"ToolEvents"},"toolbar":{"id":"f18df7a7-89c8-4239-9e14-16e6e211fffa","type":"Toolbar"},"x_range":{"id":"89a65a62-4cea-4b7e-ab75-989bb9a6d023","type":"DataRange1d"},"y_range":{"id":"ecaa04ce-6992-4399-8106-61d902315ce8","type":"DataRange1d"}},"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1604fcae-e2d4-4813-86aa-18fc4e5d6452","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"89a65a62-4cea-4b7e-ab75-989bb9a6d023","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"336b2e07-f706-4888-b9bb-646813878d43","type":"Circle"},{"attributes":{},"id":"91c33961-eb42-423b-b055-dd2005b2c55d","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"},"ticker":{"id":"91c33961-eb42-423b-b055-dd2005b2c55d","type":"BasicTicker"}},"id":"c5e1bb7d-6061-49ed-9d29-4d56e4f537be","type":"Grid"},{"attributes":{"plot":{"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"}},"id":"47a28722-8310-465d-9dbe-bb07a7ea1dab","type":"HelpTool"},{"attributes":{"overlay":{"id":"1604fcae-e2d4-4813-86aa-18fc4e5d6452","type":"BoxAnnotation"},"plot":{"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"}},"id":"c6fae427-78b4-42b1-bd3b-1e0004c25a50","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"cd4295f7-9001-4b0b-9d27-d7af162ea744","type":"ColumnDataSource"},"glyph":{"id":"917e3628-4c54-4e7b-8386-ac7e033e165b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"336b2e07-f706-4888-b9bb-646813878d43","type":"Circle"},"selection_glyph":null},"id":"48150f7d-a17a-415c-8b5b-6162501902fc","type":"GlyphRenderer"},{"attributes":{},"id":"2be87a96-fb3c-4615-b39e-ca4ea2d639f9","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"56224e91-ac5c-4cb2-93b9-7149c9533022","subtype":"Figure","type":"Plot"}},"id":"669c5f34-cc76-49df-8abd-25cc27398cc7","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"cd4295f7-9001-4b0b-9d27-d7af162ea744","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"56224e91-ac5c-4 ...

# %%
# リスト7.9.5：目盛りの長さ設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_tick_in = 15
p.xaxis.minor_tick_out = 5
p.yaxis.major_tick_in = 15  # inとoutは両方設定可能
p.yaxis.major_tick_out = 15  # inとoutは両方設定可能
p.yaxis.minor_tick_in = -10  # 負の整数も指定可能
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="26b8f43d-e853-4cf7-8431-414965e5f141"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("26b8f43d-e853-4cf7-8431-414965e5f141");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("26b8f43d-e853-4cf7-8431-414965e5f141");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '26b8f43d-e853-4cf7-8431-414965e5f141' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"93c70590-5154-4d2a-bde3-516cba94144e":{"roots":{"references":[{"attributes":{"callback":null},"id":"e70058f4-849a-4eda-a43b-da2655cb9197","type":"DataRange1d"},{"attributes":{"plot":{"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"}},"id":"28d066f4-2280-418b-8109-427000232e9c","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"8c275f01-0a9b-49d4-8f17-912ce64533c4","type":"BasicTickFormatter"},"major_tick_in":15,"minor_tick_out":5,"plot":{"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"},"ticker":{"id":"babed553-bd95-4736-8d6f-740594412fcf","type":"BasicTicker"}},"id":"21a44366-936c-4249-a475-5b015a5dabd7","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f682382a-c1ca-4163-ba25-8ec1bd201ef2","type":"Circle"},{"attributes":{},"id":"eb3718c5-ee37-4d81-822c-31f2e32463fb","type":"BasicTicker"},{"attributes":{},"id":"babed553-bd95-4736-8d6f-740594412fcf","type":"BasicTicker"},{"attributes":{"plot":{"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"},"ticker":{"id":"babed553-bd95-4736-8d6f-740594412fcf","type":"BasicTicker"}},"id":"aca90b78-420f-4140-a6a0-95c4804f70f1","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb3718c5-ee37-4d81-822c-31f2e32463fb","type":"BasicTicker"}},"id":"54d5907a-15d5-480a-9528-3222c31834df","type":"Grid"},{"attributes":{"callback":null},"id":"b02eef6b-0dce-4836-8703-199a189b9774","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"28b6a059-6148-42be-9877-7a2e8b6a4b41","type":"Circle"},{"attributes":{},"id":"8c275f01-0a9b-49d4-8f17-912ce64533c4","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"21a44366-936c-4249-a475-5b015a5dabd7","type":"LinearAxis"}],"left":[{"id":"d49cfc74-d8b3-4d4c-90ce-d1a299a63461","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"21a44366-936c-4249-a475-5b015a5dabd7","type":"LinearAxis"},{"id":"aca90b78-420f-4140-a6a0-95c4804f70f1","type":"Grid"},{"id":"d49cfc74-d8b3-4d4c-90ce-d1a299a63461","type":"LinearAxis"},{"id":"54d5907a-15d5-480a-9528-3222c31834df","type":"Grid"},{"id":"ba5c08f0-41ad-43dd-ad2e-759aa536edf9","type":"BoxAnnotation"},{"id":"4b442794-e745-44b6-9339-98762efa53f7","type":"GlyphRenderer"}],"title":{"id":"5ecb0e4b-e2c0-4938-a3aa-c7b80ca01fa4","type":"Title"},"tool_events":{"id":"96af26a4-2856-434c-8e9a-c22052fc5fdb","type":"ToolEvents"},"toolbar":{"id":"cde1ebff-48ee-4c3c-9c46-682686b1d154","type":"Toolbar"},"x_range":{"id":"b02eef6b-0dce-4836-8703-199a189b9774","type":"DataRange1d"},"y_range":{"id":"e70058f4-849a-4eda-a43b-da2655cb9197","type":"DataRange1d"}},"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ba5c08f0-41ad-43dd-ad2e-759aa536edf9","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"c31ecd06-18c4-4fbc-90a1-c3ab9d6b9abc","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"0d269c1b-7229-473d-9f1b-a33632810275","subtype":"Figure","type":"Plot"}},"id":"4dd525ff-056b-4b08-bfe6-aa229a9b83ac","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"5ecb0e4b-e2c0-4938-a3aa-c7b80ca01fa4","type":"Title"},{"attributes":{},"id":"96af26a4-2856-434c-8e9a-c22052fc5fdb","type":"ToolEvents"},{"attributes":{"overlay":{"id":"ba5c08f0-41ad-43dd-ad2e-759aa536edf9","type ...

# %%
# リスト7.9.6：FixedTickerの設定
from bokeh.models import FixedTicker

p = figure(plot_width=200, plot_height=200)
p.circle([1, 1.5, 2.2, 3], [1, 2, 3, 4])
p.xaxis.ticker = FixedTicker(ticks=[1.5, 2.2])
p.yaxis.ticker = FixedTicker(ticks=[2, 3])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8e41318f-aa4b-4162-8ce3-9a8880834d35"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8e41318f-aa4b-4162-8ce3-9a8880834d35");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8e41318f-aa4b-4162-8ce3-9a8880834d35");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8e41318f-aa4b-4162-8ce3-9a8880834d35' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b94ff8fc-bd6f-42f4-89b6-4f92efd20dab":{"roots":{"references":[{"attributes":{},"id":"7771705a-c4dc-4e82-b935-0ac4f0c72cca","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1348ad0c-ddf9-4447-87c2-c7bf065d0678","type":"Circle"},{"attributes":{"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"}},"id":"cde0fcc1-6903-4eb5-89d9-34aacc401310","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"},"ticker":{"id":"ea972060-6336-482a-b9ae-ac46cd01fbe4","type":"BasicTicker"}},"id":"caa4bc30-c2cf-4cc7-aa5a-3842af5e9b2c","type":"Grid"},{"attributes":{"ticks":[1.5,2.2]},"id":"2fd7e9cb-77de-4db9-a73d-1ebc6b8cd439","type":"FixedTicker"},{"attributes":{"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"}},"id":"546b2fc9-078b-493a-97b7-14b30fcfcfff","type":"HelpTool"},{"attributes":{"data_source":{"id":"b36bcdb9-79d7-4291-8911-e2594e3b7f60","type":"ColumnDataSource"},"glyph":{"id":"1348ad0c-ddf9-4447-87c2-c7bf065d0678","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d107de72-6bac-4a24-978f-b29cb77bbd95","type":"Circle"},"selection_glyph":null},"id":"db4e14ec-660c-4dca-bf2d-4529ceeb8025","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"}},"id":"ab2761c1-268e-41c5-9e2f-69cb96901761","type":"ResetTool"},{"attributes":{"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"}},"id":"c56d44b5-dd47-4232-ac16-5ec18f54522a","type":"SaveTool"},{"attributes":{"callback":null},"id":"18f0ca79-344b-4008-9fc9-43c5839b4308","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"42e752d7-9100-46d6-a882-60ceb559aae4","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,1.5,2.2,3],"y":[1,2,3,4]}},"id":"b36bcdb9-79d7-4291-8911-e2594e3b7f60","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"4b9c6e22-298e-4f67-b173-067afe64e59b","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b6bded41-fe87-443f-99bf-ef5668fa1ddc","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"8e668809-d8be-49e2-b1c6-6bd6fb70ebe1","type":"LinearAxis"}],"left":[{"id":"c9c68284-ad8c-499e-8dff-c4df3992cac6","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"8e668809-d8be-49e2-b1c6-6bd6fb70ebe1","type":"LinearAxis"},{"id":"911b6d9e-51eb-41f2-9059-31ced20c778e","type":"Grid"},{"id":"c9c68284-ad8c-499e-8dff-c4df3992cac6","type":"LinearAxis"},{"id":"caa4bc30-c2cf-4cc7-aa5a-3842af5e9b2c","type":"Grid"},{"id":"b6bded41-fe87-443f-99bf-ef5668fa1ddc","type":"BoxAnnotation"},{"id":"db4e14ec-660c-4dca-bf2d-4529ceeb8025","type":"GlyphRenderer"}],"title":{"id":"42e752d7-9100-46d6-a882-60ceb559aae4","type":"Title"},"tool_events":{"id":"7771705a-c4dc-4e82-b935-0ac4f0c72cca","type":"ToolEvents"},"toolbar":{"id":"069dc0e2-839f-4417-9ef6-f2b82537a650","type":"Toolbar"},"x_range":{"id":"18f0ca79-344b-4008-9fc9-43c5839b4308","type":"DataRange1d"},"y_range":{"id":"4b9c6e22-298e-4f67-b173-067afe64e59b","type":"DataRange1d"}},"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"24aa0d61-d654-4dee-8aa0-86e6aa1a9db1","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"f46d757b-3752-47b2-bd1f-0a3b545c14a5","subtype":"Figure","type":"Plot"}},"id":"d9535d92-d207-4a80-8ebc-3306add0f3a4","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b6bded41-fe87-443f-99bf-ef5668fa1ddc","type":"BoxA ...

# %%
# リスト7.9.7：NumeralTickFormatterの設定
from bokeh.models import NumeralTickFormatter

p = figure(plot_width=200, plot_height=200)
p.circle([0.123], [0.45])
p.xaxis.formatter = NumeralTickFormatter(format="0.00")  # 小数点2桁までを表示
p.yaxis.formatter = NumeralTickFormatter(format="0.0%")  # パーセント表示
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f9bb7c8d-f8fe-4bde-a267-43c78967618b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f9bb7c8d-f8fe-4bde-a267-43c78967618b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f9bb7c8d-f8fe-4bde-a267-43c78967618b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f9bb7c8d-f8fe-4bde-a267-43c78967618b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"14ced057-7ea2-48bc-9e5c-d33cd8ab66df":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"94fe9de7-8282-463d-aec2-87a7d3e8e3c8","type":"Title"},{"attributes":{"plot":{"id":"710b2324-0baa-46fd-8f3f-229bdcddafd3","subtype":"Figure","type":"Plot"}},"id":"9a08759d-db9a-42cd-b4ee-af5dd433b10d","type":"WheelZoomTool"},{"attributes":{},"id":"9f804b6a-f664-43f4-951e-31723c2fc09a","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f30d5da3-9df2-49d5-b5f0-d4e879e246d6","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"710b2324-0baa-46fd-8f3f-229bdcddafd3","subtype":"Figure","type":"Plot"}},"id":"e893a34c-2019-432a-a567-ecba8a8d76c1","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"710b2324-0baa-46fd-8f3f-229bdcddafd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"e30e932c-0d29-4998-a042-9633ba7f61d0","type":"BasicTicker"}},"id":"3ed84d15-9a49-4f65-b6b9-cbbd700feeaf","type":"Grid"},{"attributes":{"format":"0.0%"},"id":"0ef3bf61-c9ed-48ef-890a-81631472789b","type":"NumeralTickFormatter"},{"attributes":{"data_source":{"id":"422ce09f-1093-4b32-a6cc-ae2f94a54417","type":"ColumnDataSource"},"glyph":{"id":"f58df804-ecd9-4711-9197-bc10886ddb60","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ffb3a692-52ed-407f-bb8a-06a776fbc46c","type":"Circle"},"selection_glyph":null},"id":"3a198b94-597e-4bbc-9055-5d9dc903bb93","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f58df804-ecd9-4711-9197-bc10886ddb60","type":"Circle"},{"attributes":{"callback":null},"id":"dff58fd1-71bf-46f9-ad91-678b6c85a475","type":"DataRange1d"},{"attributes":{},"id":"e30e932c-0d29-4998-a042-9633ba7f61d0","type":"BasicTicker"},{"attributes":{"below":[{"id":"b0a7af69-0136-4078-83f4-9da8ce20ed0a","type":"LinearAxis"}],"left":[{"id":"20102f46-3d30-4991-b747-7debc89c43fd","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"b0a7af69-0136-4078-83f4-9da8ce20ed0a","type":"LinearAxis"},{"id":"4b5feb45-33ba-44b2-b8b1-dacf0772e781","type":"Grid"},{"id":"20102f46-3d30-4991-b747-7debc89c43fd","type":"LinearAxis"},{"id":"3ed84d15-9a49-4f65-b6b9-cbbd700feeaf","type":"Grid"},{"id":"f30d5da3-9df2-49d5-b5f0-d4e879e246d6","type":"BoxAnnotation"},{"id":"3a198b94-597e-4bbc-9055-5d9dc903bb93","type":"GlyphRenderer"}],"title":{"id":"94fe9de7-8282-463d-aec2-87a7d3e8e3c8","type":"Title"},"tool_events":{"id":"9f804b6a-f664-43f4-951e-31723c2fc09a","type":"ToolEvents"},"toolbar":{"id":"24ac2d1d-4c5b-4d2c-a5e2-8807da0f84e5","type":"Toolbar"},"x_range":{"id":"dff58fd1-71bf-46f9-ad91-678b6c85a475","type":"DataRange1d"},"y_range":{"id":"2f61be3c-445e-4c8f-83d2-b549ee44e00e","type":"DataRange1d"}},"id":"710b2324-0baa-46fd-8f3f-229bdcddafd3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.123],"y":[0.45]}},"id":"422ce09f-1093-4b32-a6cc-ae2f94a54417","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"710b2324-0baa-46fd-8f3f-229bdcddafd3","subtype":"Figure","type":"Plot"},"ticker":{"id":"1fbbc584-f563-4114-a79a-acff7d6309f5","type":"BasicTicker"}},"id":"4b5feb45-33ba-44b2-b8b1-dacf0772e781","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e893a34c-2019-432a-a567-ecba8a8d76c1","type":"PanTool"},{"id":"9a08759d-db9a-42cd-b4ee-af5dd433b10d","type":"WheelZoomTool"},{"id":"0b40fd6a-470c-4b89-9343-0cdc1efa3859","type":"BoxZoomTool"},{"id":"25ec216c-98e8-4e5c-91bc-b686d6475582","type":"SaveTool"},{"id":"8a38e447-cb68-4925-a885-431d7adafd5b","type":"ResetTool"},{"id":"ad7eb867-b6bc-403f-bac6-1 ...

# %%
# リスト7.9.8：PrintTickFormatterの設定
from bokeh.models import PrintfTickFormatter

p = figure(plot_width=200, plot_height=200)
p.circle([0.123], [0.45])
p.xaxis.formatter = PrintfTickFormatter(format="%.2f")  # 小数点2桁までを表示
p.yaxis.formatter = PrintfTickFormatter(format="%e")  # 科学的記数法
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="290e7620-b7d1-4713-873d-c8982abe29ff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("290e7620-b7d1-4713-873d-c8982abe29ff");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("290e7620-b7d1-4713-873d-c8982abe29ff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '290e7620-b7d1-4713-873d-c8982abe29ff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7830ae13-361d-4c02-8c3c-b4b63ac8d493":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"896456d0-b6fe-48f8-b9ad-215b97540c8a","type":"Circle"},{"attributes":{"callback":null},"id":"48f9ccc4-7791-498b-8617-3832ce92602c","type":"DataRange1d"},{"attributes":{"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"}},"id":"a5cfbb93-56dc-4bbb-9345-13aa90d0b54b","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"},"ticker":{"id":"a548dd0c-4623-4d1b-86d0-51a0b2aad962","type":"BasicTicker"}},"id":"e88d020b-7e43-43d3-9b88-2c69a4ba4615","type":"Grid"},{"attributes":{"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"}},"id":"08ef86b8-578e-47a4-b867-4af943e3114b","type":"ResetTool"},{"attributes":{"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"},"ticker":{"id":"cc9198f0-5ac4-4256-9aaf-09f5fc6b63ab","type":"BasicTicker"}},"id":"e362884f-9873-42dd-bf26-037a88c678a0","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a5cfbb93-56dc-4bbb-9345-13aa90d0b54b","type":"PanTool"},{"id":"21a7d709-ef1f-4545-9e50-414dc78569e8","type":"WheelZoomTool"},{"id":"3cf92180-fbc5-421a-97d2-3afbce3572fc","type":"BoxZoomTool"},{"id":"9adb6b2b-b285-4054-81c1-e3542adaa1e4","type":"SaveTool"},{"id":"08ef86b8-578e-47a4-b867-4af943e3114b","type":"ResetTool"},{"id":"929b22f1-80fe-4400-bb61-c6a18dfb47e9","type":"HelpTool"}]},"id":"d52d2c40-76d2-48b9-871c-8b0889818442","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.123],"y":[0.45]}},"id":"df6e0c73-6ce2-4c95-b7f5-1266fd991f37","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"}},"id":"929b22f1-80fe-4400-bb61-c6a18dfb47e9","type":"HelpTool"},{"attributes":{},"id":"cc9198f0-5ac4-4256-9aaf-09f5fc6b63ab","type":"BasicTicker"},{"attributes":{"format":"%.2f"},"id":"e3574ac7-a4e9-49a7-a56d-8f152ab3b077","type":"PrintfTickFormatter"},{"attributes":{"format":"%e"},"id":"9eaf23c8-dfe8-482d-ba41-e7f0820f90f4","type":"PrintfTickFormatter"},{"attributes":{"below":[{"id":"6ca1d412-eec6-4674-9e4e-9a03c5b9d133","type":"LinearAxis"}],"left":[{"id":"7c81f2b3-863f-4dfe-ac4a-8f490421859c","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6ca1d412-eec6-4674-9e4e-9a03c5b9d133","type":"LinearAxis"},{"id":"e362884f-9873-42dd-bf26-037a88c678a0","type":"Grid"},{"id":"7c81f2b3-863f-4dfe-ac4a-8f490421859c","type":"LinearAxis"},{"id":"e88d020b-7e43-43d3-9b88-2c69a4ba4615","type":"Grid"},{"id":"2173c2ae-59f4-4b1f-b87a-d3ec30c1fe48","type":"BoxAnnotation"},{"id":"56ca7ca6-d2a4-47cc-a0c1-af9057d316b5","type":"GlyphRenderer"}],"title":{"id":"b3b411b9-6bd8-4b23-9db4-58082ef3e457","type":"Title"},"tool_events":{"id":"64c3efc2-43eb-4626-abbf-96cd88eee929","type":"ToolEvents"},"toolbar":{"id":"d52d2c40-76d2-48b9-871c-8b0889818442","type":"Toolbar"},"x_range":{"id":"48f9ccc4-7791-498b-8617-3832ce92602c","type":"DataRange1d"},"y_range":{"id":"edcd3cfd-45fb-4f90-afa8-6c12278a0a12","type":"DataRange1d"}},"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2173c2ae-59f4-4b1f-b87a-d3ec30c1fe48","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"2173c2ae-59f4-4b1f-b87a-d3ec30c1fe48","type":"BoxAnnotation"},"plot":{"id":"229c7a14-ee8d-41f2-8819-d082c5b4b385","sub ...

# %%
# リスト7.9.9：major_label_orientationの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_label_orientation = 0.6
p.yaxis.major_label_orientation = "vertical"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b4a95748-f8a4-4774-9bdb-168d25ba6fdb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b4a95748-f8a4-4774-9bdb-168d25ba6fdb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4a95748-f8a4-4774-9bdb-168d25ba6fdb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4a95748-f8a4-4774-9bdb-168d25ba6fdb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0e778fcc-85ee-4b40-ac00-e2b42a990377":{"roots":{"references":[{"attributes":{"plot":{"id":"2dacce4d-f81f-4ca0-a873-5dbb4e029f2f","subtype":"Figure","type":"Plot"}},"id":"243a46f1-0b8a-4945-a10d-adbd3de4dcbe","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"8cf8c01f-82fe-4917-a519-b87bc5d81d6f","type":"ColumnDataSource"},"glyph":{"id":"aa1ea26d-4016-4cc5-ad58-42ef76c104b8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c702da9d-4050-4dda-879d-05715fe3e4db","type":"Circle"},"selection_glyph":null},"id":"b7810a59-d2a1-4f54-915f-7c6a0e4bfeb9","type":"GlyphRenderer"},{"attributes":{},"id":"e3dd7e26-7cec-4459-99fa-9dc55480bdc1","type":"ToolEvents"},{"attributes":{},"id":"59363f5e-6313-4d77-b408-c383d44f0e7f","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"2034369c-4e3c-4a3c-a066-01fea27dc1e2","type":"Title"},{"attributes":{"overlay":{"id":"10c16e6d-36f0-4561-9d34-7596bd5dd78e","type":"BoxAnnotation"},"plot":{"id":"2dacce4d-f81f-4ca0-a873-5dbb4e029f2f","subtype":"Figure","type":"Plot"}},"id":"68406a59-84cf-4c44-b66b-dad9c025a780","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2dacce4d-f81f-4ca0-a873-5dbb4e029f2f","subtype":"Figure","type":"Plot"},"ticker":{"id":"59363f5e-6313-4d77-b408-c383d44f0e7f","type":"BasicTicker"}},"id":"6003a2f9-3f3f-447c-b006-9d986ce9eae1","type":"Grid"},{"attributes":{"formatter":{"id":"18f624f7-d9b5-49f6-86a6-2afe68348af2","type":"BasicTickFormatter"},"major_label_orientation":"vertical","plot":{"id":"2dacce4d-f81f-4ca0-a873-5dbb4e029f2f","subtype":"Figure","type":"Plot"},"ticker":{"id":"bdc5afb3-ac50-430c-8fbe-6e2ba2bbe036","type":"BasicTicker"}},"id":"cc508e40-c079-4d6c-aab1-24b47db9b77f","type":"LinearAxis"},{"attributes":{"below":[{"id":"91fc1f0b-667c-4e7b-96e9-a9ef4355275e","type":"LinearAxis"}],"left":[{"id":"cc508e40-c079-4d6c-aab1-24b47db9b77f","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"91fc1f0b-667c-4e7b-96e9-a9ef4355275e","type":"LinearAxis"},{"id":"6003a2f9-3f3f-447c-b006-9d986ce9eae1","type":"Grid"},{"id":"cc508e40-c079-4d6c-aab1-24b47db9b77f","type":"LinearAxis"},{"id":"4fe7908f-6144-4fcd-95fe-d277659d759d","type":"Grid"},{"id":"10c16e6d-36f0-4561-9d34-7596bd5dd78e","type":"BoxAnnotation"},{"id":"b7810a59-d2a1-4f54-915f-7c6a0e4bfeb9","type":"GlyphRenderer"}],"title":{"id":"2034369c-4e3c-4a3c-a066-01fea27dc1e2","type":"Title"},"tool_events":{"id":"e3dd7e26-7cec-4459-99fa-9dc55480bdc1","type":"ToolEvents"},"toolbar":{"id":"50c55bdd-dc52-48a4-b8a5-151ef34673c1","type":"Toolbar"},"x_range":{"id":"bf267985-973d-4850-9675-042ef06a0be4","type":"DataRange1d"},"y_range":{"id":"c27af581-1eff-4712-897c-16e3dc3c9fb2","type":"DataRange1d"}},"id":"2dacce4d-f81f-4ca0-a873-5dbb4e029f2f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f4b63027-9a25-4345-9c3c-8c497414e36b","type":"BasicTickFormatter"},{"attributes":{},"id":"18f624f7-d9b5-49f6-86a6-2afe68348af2","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"10c16e6d-36f0-4561-9d34-7596bd5dd78e","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"34eecfe0-1cf5-4ff6-9187-78a7af0e5e9b","type":"PanTool"},{"id":"243a46f1-0b8a-4945-a10d-adbd3de4dcbe","type":"WheelZoomTool"},{"id":"68406a59-84cf-4c44-b66b-dad9c025a780","type":"BoxZoomTool"},{"id":"167c2d7d-ede8-4630-9957-9db642de93fa","type":"SaveTool"},{"id":"fcca7f4a-026c-44b4-b4cd-ff656c5605c2","type":"ResetTool"},{"id":"95cf659d-5bf0-4aec-a2b3-6ac128d63f09","type":"HelpTool"}]},"id":"50c55bdd-dc52-48a4-b8a5-151ef34673c1","type":"Toolbar"},{"attributes":{},"id":"bdc5afb3-ac50-430c-8fbe-6e2ba2bbe036","type":"B ...
