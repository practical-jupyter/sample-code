# %%
# リスト7.9.1：軸の書式の設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.axis_label = 'x'
p.yaxis.axis_label = 'y'
p.xaxis.axis_label_text_color = 'red'
p.axis.axis_line_width = 3  # X軸、Y軸両方に適用される
p.xaxis.axis_line_dash = 'dashed'
p.xaxis.axis_label_standoff = 30
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a611e863-e6ad-4d52-9e5d-108fd51dc05f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a9915a50-5f8e-4cdb-961a-d3d87551553c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a9915a50-5f8e-4cdb-961a-d3d87551553c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a9915a50-5f8e-4cdb-961a-d3d87551553c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a9915a50-5f8e-4cdb-961a-d3d87551553c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"97d4c87f-63de-4bfb-b275-3fb65e6508aa":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"},"ticker":{"id":"1b61c6bf-7e7d-4f6c-9784-aeb1009a9101","type":"BasicTicker"}},"id":"16f4eea8-0ec8-42c4-90c5-5090905c6b88","type":"Grid"},{"attributes":{},"id":"568dfe9c-09ba-4237-9786-0c02379e6380","type":"BasicTickFormatter"},{"attributes":{},"id":"eb297c04-9a72-4712-be4b-dc62d2c1201e","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a97752d0-cfe9-4717-bbc3-abb64a0b1d16","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"57c3c826-b535-46f1-81a4-499260b9ef50","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"3a477d30-dcb2-4080-9b14-0a3d994dd644","type":"Title"},{"attributes":{"callback":null},"id":"5ec74f51-ff97-43e6-ae42-d723579d1f4f","type":"DataRange1d"},{"attributes":{"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"}},"id":"1133410c-d5bf-4f8c-b1cb-2a41e7bbec7c","type":"PanTool"},{"attributes":{"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"}},"id":"cf2232ec-9552-49c3-8f3d-3de83c4d867d","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"a97752d0-cfe9-4717-bbc3-abb64a0b1d16","type":"BoxAnnotation"},"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"}},"id":"d2aa2843-de32-49fe-8214-83be1b58fe2a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"3fd59d50-89bb-4eda-9028-2481ac581940","type":"LinearAxis"}],"left":[{"id":"0a640869-53c2-42fb-a591-b82e2fd4b8f5","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"3fd59d50-89bb-4eda-9028-2481ac581940","type":"LinearAxis"},{"id":"3a87c078-43e0-4ebb-846b-3da24dc84d97","type":"Grid"},{"id":"0a640869-53c2-42fb-a591-b82e2fd4b8f5","type":"LinearAxis"},{"id":"16f4eea8-0ec8-42c4-90c5-5090905c6b88","type":"Grid"},{"id":"a97752d0-cfe9-4717-bbc3-abb64a0b1d16","type":"BoxAnnotation"},{"id":"a4741890-9877-4a08-82f2-9214c972292b","type":"GlyphRenderer"}],"title":{"id":"3a477d30-dcb2-4080-9b14-0a3d994dd644","type":"Title"},"tool_events":{"id":"74d42d6e-4deb-4043-8f46-a4fb4d4c3e01","type":"ToolEvents"},"toolbar":{"id":"6e6e81b8-5d9f-4585-b48f-22464fb57b25","type":"Toolbar"},"x_range":{"id":"5ec74f51-ff97-43e6-ae42-d723579d1f4f","type":"DataRange1d"},"y_range":{"id":"1005b16e-0cb8-4a46-bae0-afacfc88f673","type":"DataRange1d"}},"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"}},"id":"5983ed59-57a4-4dd3-98ee-a10083542e27","type":"SaveTool"},{"attributes":{"data_source":{"id":"6b422bfb-eee6-4fe2-8a1e-51faad295f01","type":"ColumnDataSource"},"glyph":{"id":"57c3c826-b535-46f1-81a4-499260b9ef50","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b138005a-e1d4-48ea-b69e-6bcdf7778798","type":"Circle"},"selection_glyph":null},"id":"a4741890-9877-4a08-82f2-9214c972292b","type":"GlyphRenderer"},{"attributes":{},"id":"74d42d6e-4deb-4043-8f46-a4fb4d4c3e01","type":"ToolEvents"},{"attributes":{"plot":{"id":"8121aad9-1cbd-4d0b-b4d2-a6a33ef4f28c","subtype":"Figure","type":"Plot"}},"id":"9617fe5f-940b-47da-9a90-a3ef985cbd0b","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b138005a-e1d4-48ea-b69e-6bcdf7778798","type":"Circle"},{"attributes":{"plot":{"id":"8121aad9-1cbd-4 ...

# %%
# リスト7.9.2：軸の幅の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.yaxis.bounds = (-0.5, 0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0b45fa1e-6e36-4cdb-b539-1040b8c69b01"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0b45fa1e-6e36-4cdb-b539-1040b8c69b01");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0b45fa1e-6e36-4cdb-b539-1040b8c69b01");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0b45fa1e-6e36-4cdb-b539-1040b8c69b01' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d55d91bf-5953-48b6-a516-ed8268617e4f":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"426f0c80-166d-4259-ab62-bb6b2c15c6a4","type":"Title"},{"attributes":{},"id":"2d7c0e0a-69e3-44c9-9a94-1f16aadea225","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"}},"id":"0b77d2b6-2191-40a0-ba28-088b1cf8d83a","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"6ddd5462-f9a5-4be9-9e62-a38479d17a37","type":"LinearAxis"}],"left":[{"id":"62839b31-998e-4bfa-93aa-0be65ed4f184","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"6ddd5462-f9a5-4be9-9e62-a38479d17a37","type":"LinearAxis"},{"id":"3f4475e5-76c6-41ee-bbd4-79a33f539fd8","type":"Grid"},{"id":"62839b31-998e-4bfa-93aa-0be65ed4f184","type":"LinearAxis"},{"id":"c7df21ad-1e8f-41ed-b316-fbd41ef7321a","type":"Grid"},{"id":"c6193d04-f469-4492-8db6-da1da858d6ce","type":"BoxAnnotation"},{"id":"cc2a0c97-129e-4cf5-b20a-f44e7e58c39c","type":"GlyphRenderer"}],"title":{"id":"426f0c80-166d-4259-ab62-bb6b2c15c6a4","type":"Title"},"tool_events":{"id":"23699182-4f4d-48b6-9fec-949127a40fe4","type":"ToolEvents"},"toolbar":{"id":"f8f823aa-69d0-41dd-9134-f10de9b683e7","type":"Toolbar"},"x_range":{"id":"827b7be6-6759-492b-9a1e-08263df65432","type":"DataRange1d"},"y_range":{"id":"7c416eb5-735d-41bb-8140-36b0ecc8517b","type":"DataRange1d"}},"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c6193d04-f469-4492-8db6-da1da858d6ce","type":"BoxAnnotation"},{"attributes":{},"id":"23699182-4f4d-48b6-9fec-949127a40fe4","type":"ToolEvents"},{"attributes":{"overlay":{"id":"c6193d04-f469-4492-8db6-da1da858d6ce","type":"BoxAnnotation"},"plot":{"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"}},"id":"d0e7e5ba-a650-4868-96ee-f165c46843a3","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"827b7be6-6759-492b-9a1e-08263df65432","type":"DataRange1d"},{"attributes":{"plot":{"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"}},"id":"45495c4c-8125-414b-b4d8-73b7931975fc","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0ea2e94f-6a76-481a-b11a-ae0d03d1ccb3","type":"PanTool"},{"id":"0b77d2b6-2191-40a0-ba28-088b1cf8d83a","type":"WheelZoomTool"},{"id":"d0e7e5ba-a650-4868-96ee-f165c46843a3","type":"BoxZoomTool"},{"id":"45495c4c-8125-414b-b4d8-73b7931975fc","type":"SaveTool"},{"id":"cd5acd54-d9f5-4860-9b63-57e38e77c752","type":"ResetTool"},{"id":"d080f830-e88b-4999-b319-7b9020aee5fb","type":"HelpTool"}]},"id":"f8f823aa-69d0-41dd-9134-f10de9b683e7","type":"Toolbar"},{"attributes":{"plot":{"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"}},"id":"d080f830-e88b-4999-b319-7b9020aee5fb","type":"HelpTool"},{"attributes":{"data_source":{"id":"8367fcb2-145a-48e2-9c3e-1ca9204c104c","type":"ColumnDataSource"},"glyph":{"id":"86d05e9d-9451-4237-93dc-bb481002eb45","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"63e363a4-bf39-42dc-81cd-3f88afcb00c5","type":"Circle"},"selection_glyph":null},"id":"cc2a0c97-129e-4cf5-b20a-f44e7e58c39c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a04f2f59-dbc9-4a2a-adea-3482dc8d06ed","subtype":"Figure","type":"Plot"}},"id":"cd5acd54-d9f5-4860-9b63-57e38e77c752","type":"ResetTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"86d05e9d-9451-4237-93dc-bb481002eb45","type":"Circle"},{"attributes":{"formatter":{"id":"2d7c0e0a-69e3-44c9-9a94-1f16aadea225"," ...

# %%
# リスト7.9.3：目盛りの書式の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_tick_line_width = 3
p.yaxis.major_tick_line_color = 'red'
p.yaxis.minor_tick_line_color = 'blue'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="eb7a517a-acd5-4322-ab6e-80595a170b65"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("eb7a517a-acd5-4322-ab6e-80595a170b65");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("eb7a517a-acd5-4322-ab6e-80595a170b65");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'eb7a517a-acd5-4322-ab6e-80595a170b65' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b519363f-4859-4a56-a8e2-716bcefb5bcc":{"roots":{"references":[{"attributes":{},"id":"009b7c99-7143-4709-a5a1-6be22f7918d4","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"2c6d6e5f-c46b-430b-b5a5-4dd98981d6a6","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66039d77-2ab4-4176-80f5-3536b20a782c","type":"Circle"},{"attributes":{"callback":null},"id":"fd45cead-f680-4ba3-be08-5a8345fb11b0","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4f711f7f-e7ae-4ad6-9148-41e7de40987e","type":"PanTool"},{"id":"6f8d7714-9bab-42ce-8330-d304613a0222","type":"WheelZoomTool"},{"id":"f3646196-1741-43a4-8549-44ab6284b50b","type":"BoxZoomTool"},{"id":"79ab2006-cc90-45a8-85be-facb6e7c49d3","type":"SaveTool"},{"id":"5e6a9040-1665-414e-ab5c-aeae0617d137","type":"ResetTool"},{"id":"8cdbbc5d-86ca-43a9-aab4-4a9f98c537f3","type":"HelpTool"}]},"id":"ea2f2882-97ca-4681-8bea-a38f5b22c4f6","type":"Toolbar"},{"attributes":{},"id":"3f335b6a-2885-4d97-a0b9-a2c262eee222","type":"BasicTicker"},{"attributes":{"plot":{"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3f335b6a-2885-4d97-a0b9-a2c262eee222","type":"BasicTicker"}},"id":"909df75d-97e6-4303-a813-2878fa6c64d6","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"42b40370-f641-4a9e-9759-420727b9537f","type":"Circle"},{"attributes":{},"id":"b9156e42-ab25-40ee-9ae8-5d9a4433cbfa","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"b9156e42-ab25-40ee-9ae8-5d9a4433cbfa","type":"BasicTicker"}},"id":"d22ca3e5-92b3-476d-bfc9-4b4101bd8a68","type":"Grid"},{"attributes":{"plot":{"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"}},"id":"79ab2006-cc90-45a8-85be-facb6e7c49d3","type":"SaveTool"},{"attributes":{"data_source":{"id":"df1c780d-828f-423c-94ee-e8330f8e9082","type":"ColumnDataSource"},"glyph":{"id":"42b40370-f641-4a9e-9759-420727b9537f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"66039d77-2ab4-4176-80f5-3536b20a782c","type":"Circle"},"selection_glyph":null},"id":"836a36e3-22bf-47a7-a646-de2720025ef4","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"41c048e7-fefd-4ed3-9b13-147ceac89e49","type":"LinearAxis"}],"left":[{"id":"a50c41ed-4115-4fce-ae13-9ffc0d2771a9","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"41c048e7-fefd-4ed3-9b13-147ceac89e49","type":"LinearAxis"},{"id":"909df75d-97e6-4303-a813-2878fa6c64d6","type":"Grid"},{"id":"a50c41ed-4115-4fce-ae13-9ffc0d2771a9","type":"LinearAxis"},{"id":"d22ca3e5-92b3-476d-bfc9-4b4101bd8a68","type":"Grid"},{"id":"a341536b-e35f-4910-aba2-38a19f872595","type":"BoxAnnotation"},{"id":"836a36e3-22bf-47a7-a646-de2720025ef4","type":"GlyphRenderer"}],"title":{"id":"1b04f479-f8e0-4708-90d4-f329c6ac8542","type":"Title"},"tool_events":{"id":"32c78623-117e-46c2-9882-d5625300238e","type":"ToolEvents"},"toolbar":{"id":"ea2f2882-97ca-4681-8bea-a38f5b22c4f6","type":"Toolbar"},"x_range":{"id":"2c6d6e5f-c46b-430b-b5a5-4dd98981d6a6","type":"DataRange1d"},"y_range":{"id":"fd45cead-f680-4ba3-be08-5a8345fb11b0","type":"DataRange1d"}},"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"}},"id":"5e6a9040-1665-414e-ab5c-aeae0617d137","type":"ResetTool"},{"attributes":{"formatter":{"id":"009b7c99-7143-4709-a5a1-6be22f7918d4","type":"BasicTickFormatter"},"major_tick_line_width":{"value":3},"plot":{"id":"be7bdafa-699f-49ce-9f06-7c0453279c1d","subtype":"Figure","type":"Plot"},"ticker":{"id" ...

# %%
# リスト7.9.4：目盛りラベルの書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_label_text_color = 'red'
p.yaxis.major_label_text_font_size = '10pt'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="92bb426b-ef20-4ce5-a617-185f985abeb9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("92bb426b-ef20-4ce5-a617-185f985abeb9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("92bb426b-ef20-4ce5-a617-185f985abeb9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '92bb426b-ef20-4ce5-a617-185f985abeb9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"20774952-3602-453e-81b1-9e874e231dfe":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cca6813f-97e5-4bf1-9971-523ed89f8b78","type":"Circle"},{"attributes":{"below":[{"id":"41d06270-3ad5-455c-9b60-da116bddecfd","type":"LinearAxis"}],"left":[{"id":"f50d66a7-53f2-4e9a-8bc7-e3f30a740974","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"41d06270-3ad5-455c-9b60-da116bddecfd","type":"LinearAxis"},{"id":"94fd9d03-8061-49ae-9745-338742312101","type":"Grid"},{"id":"f50d66a7-53f2-4e9a-8bc7-e3f30a740974","type":"LinearAxis"},{"id":"0dd09ec6-338f-4e1a-8a00-b24f62665c45","type":"Grid"},{"id":"f46aa338-7230-4c41-a158-4ae5a3e494f8","type":"BoxAnnotation"},{"id":"8f731f27-2e89-4592-9a5c-a3a09d776e16","type":"GlyphRenderer"}],"title":{"id":"d970da9e-283a-4592-919c-d26583a0dbbc","type":"Title"},"tool_events":{"id":"6ca5e7a8-ab72-4040-9bb8-ee4aa24c0f84","type":"ToolEvents"},"toolbar":{"id":"44d3d2a2-4b1a-473c-a029-af76abcccc8e","type":"Toolbar"},"x_range":{"id":"cdd1e86f-0690-4325-989b-56e57c1a1fb6","type":"DataRange1d"},"y_range":{"id":"d6c6a2fe-5f9b-4a68-9d9b-c2c4df2f9083","type":"DataRange1d"}},"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"60eeb949-1f3d-4801-ab74-b1fc85c0c33a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"},"ticker":{"id":"31e3ed79-39ba-4421-9042-5de81546617f","type":"BasicTicker"}},"id":"94fd9d03-8061-49ae-9745-338742312101","type":"Grid"},{"attributes":{"formatter":{"id":"631a1609-8ec6-4f63-958e-b34fe2a8706e","type":"BasicTickFormatter"},"major_label_text_color":{"value":"red"},"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"},"ticker":{"id":"31e3ed79-39ba-4421-9042-5de81546617f","type":"BasicTicker"}},"id":"41d06270-3ad5-455c-9b60-da116bddecfd","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"d970da9e-283a-4592-919c-d26583a0dbbc","type":"Title"},{"attributes":{"formatter":{"id":"56ecabbe-2e91-48d6-a76d-928a06fb7068","type":"BasicTickFormatter"},"major_label_text_font_size":{"value":"10pt"},"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"},"ticker":{"id":"80f65b9a-264e-4a8b-b402-f6149afde832","type":"BasicTicker"}},"id":"f50d66a7-53f2-4e9a-8bc7-e3f30a740974","type":"LinearAxis"},{"attributes":{"overlay":{"id":"f46aa338-7230-4c41-a158-4ae5a3e494f8","type":"BoxAnnotation"},"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"}},"id":"db6a74d3-40bf-47f8-a363-898d2ebbb336","type":"BoxZoomTool"},{"attributes":{},"id":"80f65b9a-264e-4a8b-b402-f6149afde832","type":"BasicTicker"},{"attributes":{},"id":"631a1609-8ec6-4f63-958e-b34fe2a8706e","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"},"ticker":{"id":"80f65b9a-264e-4a8b-b402-f6149afde832","type":"BasicTicker"}},"id":"0dd09ec6-338f-4e1a-8a00-b24f62665c45","type":"Grid"},{"attributes":{"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"}},"id":"a6abe5ab-2ab0-443d-93d1-6835b29a3713","type":"ResetTool"},{"attributes":{},"id":"31e3ed79-39ba-4421-9042-5de81546617f","type":"BasicTicker"},{"attributes":{"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"}},"id":"1f860ab3-903d-40bb-a179-5dea801142c1","type":"SaveTool"},{"attributes":{"plot":{"id":"62ade918-1f65-45b5-85a0-a9fc6946e93e","subtype":"Figure","type":"Plot"}},"id":"cb1813c4-6a19-42d5-b1c3-53db55812647","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color": ...

# %%
# リスト7.9.5：目盛りの長さ設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_tick_in = 15
p.xaxis.minor_tick_out = 5
p.yaxis.major_tick_in = 15   # inとoutは両方設定可能
p.yaxis.major_tick_out = 15  # inとoutは両方設定可能
p.yaxis.minor_tick_in = -10  # 負の整数も指定可能
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0818bca2-ed7e-438f-86c0-0ce213c8d336"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0818bca2-ed7e-438f-86c0-0ce213c8d336");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0818bca2-ed7e-438f-86c0-0ce213c8d336");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0818bca2-ed7e-438f-86c0-0ce213c8d336' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4aac1b34-a9c8-4076-aae6-8eeeb47aef6e":{"roots":{"references":[{"attributes":{},"id":"c5e41f75-2afe-4bc0-865c-ca82673bccb3","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"c5e41f75-2afe-4bc0-865c-ca82673bccb3","type":"BasicTickFormatter"},"major_tick_in":15,"major_tick_out":15,"minor_tick_in":-10,"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"},"ticker":{"id":"a1182805-72bf-4493-b0b0-e5da9538eb74","type":"BasicTicker"}},"id":"803f602a-2a43-42b8-b883-1986b39c82f2","type":"LinearAxis"},{"attributes":{"overlay":{"id":"871484fd-7ae7-489d-a62f-947abbd6629c","type":"BoxAnnotation"},"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"}},"id":"b016f8c2-630a-400e-bfda-385c0f004d9c","type":"BoxZoomTool"},{"attributes":{},"id":"50cce8b4-5a15-497d-a006-54226e6c3c08","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"e34bbb2a-e29c-4d54-b015-76a507cdfe34","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"}},"id":"e6cb4f7a-1313-4f50-b2ae-c68a379d39a7","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"},"ticker":{"id":"50cce8b4-5a15-497d-a006-54226e6c3c08","type":"BasicTicker"}},"id":"60caa662-4f92-4e0c-84fe-943d5ad66af7","type":"Grid"},{"attributes":{"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"}},"id":"e0091db1-b3cf-4632-bc8a-348bd0b9e88d","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"d5dc9cfb-465a-4868-8396-b0aeb6d22139","type":"Title"},{"attributes":{"callback":null},"id":"dce36630-b7bf-4846-ac38-2bdf97327da8","type":"DataRange1d"},{"attributes":{},"id":"09e4906b-abbe-49ee-92f8-e95e64355380","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"}},"id":"c292423e-5974-42ac-af65-796288db4270","type":"SaveTool"},{"attributes":{"below":[{"id":"381dfa79-b7fb-4e9a-86bc-5ad27c1f1de6","type":"LinearAxis"}],"left":[{"id":"803f602a-2a43-42b8-b883-1986b39c82f2","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"381dfa79-b7fb-4e9a-86bc-5ad27c1f1de6","type":"LinearAxis"},{"id":"60caa662-4f92-4e0c-84fe-943d5ad66af7","type":"Grid"},{"id":"803f602a-2a43-42b8-b883-1986b39c82f2","type":"LinearAxis"},{"id":"da00072e-5cef-4641-81ff-f0c12930b83a","type":"Grid"},{"id":"871484fd-7ae7-489d-a62f-947abbd6629c","type":"BoxAnnotation"},{"id":"c86bb4e6-53b6-457c-8fbf-bab654ea6061","type":"GlyphRenderer"}],"title":{"id":"d5dc9cfb-465a-4868-8396-b0aeb6d22139","type":"Title"},"tool_events":{"id":"d3dacf04-c9c5-4a86-8c33-7ef3bade9397","type":"ToolEvents"},"toolbar":{"id":"e7fc303e-86e7-4cf7-9699-d5bb95a4a041","type":"Toolbar"},"x_range":{"id":"dce36630-b7bf-4846-ac38-2bdf97327da8","type":"DataRange1d"},"y_range":{"id":"2f997698-ee78-40ec-917d-845874738041","type":"DataRange1d"}},"id":"622e2f90-e25c-45cd-9ef6-270eb6508517","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e17ca658-d125-43c8-acfe-31c25671a4af","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"871484fd-7ae7-489d-a62f-947abbd6629c","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"e34bbb2a-e29c-4d54-b015-76a507cdfe34","type":"ColumnDataSource"},"glyph":{"id":"ba2a091f-46ec-4cea-ae46-3b678ba20adb","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e17ca6 ...

# %%
# リスト7.9.6：FixedTickerの設定
from bokeh.models import FixedTicker
p = figure(plot_width=200, plot_height=200)
p.circle([1, 1.5, 2.2, 3], [1, 2, 3, 4])
p.xaxis.ticker = FixedTicker(ticks=[1.5, 2.2])
p.yaxis.ticker = FixedTicker(ticks=[2, 3])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08904ce8-b4e7-4a2a-aa00-7122132d500e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08904ce8-b4e7-4a2a-aa00-7122132d500e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08904ce8-b4e7-4a2a-aa00-7122132d500e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08904ce8-b4e7-4a2a-aa00-7122132d500e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"674398d7-d3c9-41f0-86c5-1c20770399f5":{"roots":{"references":[{"attributes":{"callback":null},"id":"dbe0dd3d-eca3-460d-bdfd-c7e0148a2d2e","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a3f17f1-3cfb-4b27-b4a7-3aae44068f3b","type":"Circle"},{"attributes":{"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"}},"id":"c28218fe-6743-42a8-b4c0-c6b8d2e09123","type":"HelpTool"},{"attributes":{"formatter":{"id":"a4132cda-a933-4951-a30c-36fdf644f73d","type":"BasicTickFormatter"},"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"6408b583-c8c5-4635-adb7-3eaecd8340ad","type":"FixedTicker"}},"id":"b383a28e-71f7-4142-a7b5-7712e76ba016","type":"LinearAxis"},{"attributes":{},"id":"4e7d31f4-e18f-4931-9d41-cc9cc082e6d7","type":"BasicTicker"},{"attributes":{},"id":"002527e7-536b-424e-ac7a-735c4561f23e","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"0028798d-5444-499f-9fcf-4c8277e7b289","type":"Title"},{"attributes":{},"id":"e108fbd2-e0ef-4c49-a028-2fade116ab66","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"}},"id":"3c2264b6-a739-4cfc-ab74-edd1d61627d6","type":"SaveTool"},{"attributes":{"data_source":{"id":"95d66e95-1cc1-4ca3-9a13-6a90d5329e21","type":"ColumnDataSource"},"glyph":{"id":"4a3f17f1-3cfb-4b27-b4a7-3aae44068f3b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a3a2d2ed-3b4f-4982-853f-1d60aee580de","type":"Circle"},"selection_glyph":null},"id":"6da46b62-1416-41ce-8854-96ee4b99e882","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a3a2d2ed-3b4f-4982-853f-1d60aee580de","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"},"ticker":{"id":"002527e7-536b-424e-ac7a-735c4561f23e","type":"BasicTicker"}},"id":"7122ff23-5100-4e5e-9260-e96c472af710","type":"Grid"},{"attributes":{"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"}},"id":"c88054ef-2198-44ea-9676-456fff714847","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,1.5,2.2,3],"y":[1,2,3,4]}},"id":"95d66e95-1cc1-4ca3-9a13-6a90d5329e21","type":"ColumnDataSource"},{"attributes":{"ticks":[2,3]},"id":"6408b583-c8c5-4635-adb7-3eaecd8340ad","type":"FixedTicker"},{"attributes":{"below":[{"id":"a496a624-48ab-4d25-a474-100152eb49f8","type":"LinearAxis"}],"left":[{"id":"b383a28e-71f7-4142-a7b5-7712e76ba016","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"a496a624-48ab-4d25-a474-100152eb49f8","type":"LinearAxis"},{"id":"83e32c24-dbad-4ce7-8a7e-a7fe405bc1b9","type":"Grid"},{"id":"b383a28e-71f7-4142-a7b5-7712e76ba016","type":"LinearAxis"},{"id":"7122ff23-5100-4e5e-9260-e96c472af710","type":"Grid"},{"id":"d73571c2-7eb8-49e8-a3fe-1569ad3e1f2a","type":"BoxAnnotation"},{"id":"6da46b62-1416-41ce-8854-96ee4b99e882","type":"GlyphRenderer"}],"title":{"id":"0028798d-5444-499f-9fcf-4c8277e7b289","type":"Title"},"tool_events":{"id":"e0e0f122-c6ba-400e-b2c0-724c6682403c","type":"ToolEvents"},"toolbar":{"id":"ae2bf2d3-e39b-4cef-a816-139353ff258e","type":"Toolbar"},"x_range":{"id":"2087666c-83f1-4787-802a-6a1cead78046","type":"DataRange1d"},"y_range":{"id":"dbe0dd3d-eca3-460d-bdfd-c7e0148a2d2e","type":"DataRange1d"}},"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"},{"attributes":{"overlay":{"id":"d73571c2-7eb8-49e8-a3fe-1569ad3e1f2a","type":"BoxAnnotation"},"plot":{"id":"db95edf4-71d9-420f-bec4-92e7dea7d2e4","subtype":"Figure","type":"Plot"}},"id":"65576c0a-d25e-4b87-822d-e93c53bcee2c","type":"BoxZoomTool"},{"attributes ...

# %%
# リスト7.9.7：NumeralTickFormatterの設定
from bokeh.models import NumeralTickFormatter
p = figure(plot_width=200, plot_height=200)
p.circle([0.123], [0.45])
p.xaxis.formatter = NumeralTickFormatter(format="0.00")  # 小数点2桁までを表示
p.yaxis.formatter = NumeralTickFormatter(format="0.0%")  # パーセント表示
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68186487-d833-4ca8-ba61-a2697d3475bd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("68186487-d833-4ca8-ba61-a2697d3475bd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68186487-d833-4ca8-ba61-a2697d3475bd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68186487-d833-4ca8-ba61-a2697d3475bd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2b9a956-dff0-44c8-87b0-00267e937bb2":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"72ee58f3-3909-44c7-835b-5b4d8fb05abe","type":"Title"},{"attributes":{"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"}},"id":"41dd9a97-30c9-4dcb-bd48-138100b851e9","type":"ResetTool"},{"attributes":{"overlay":{"id":"9f8dda69-f3e4-4d8f-aded-0d7acee774c7","type":"BoxAnnotation"},"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"}},"id":"6c5219e5-ca46-4be8-b09d-af610ecf3eaa","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3553fefe-ca0e-4572-ac10-3e6e721dee4e","type":"PanTool"},{"id":"51243cf8-89b2-4443-89fb-680895a7add9","type":"WheelZoomTool"},{"id":"6c5219e5-ca46-4be8-b09d-af610ecf3eaa","type":"BoxZoomTool"},{"id":"d3df539a-830c-4c76-8510-ad127d0d1b71","type":"SaveTool"},{"id":"41dd9a97-30c9-4dcb-bd48-138100b851e9","type":"ResetTool"},{"id":"4bf8fe37-9fe3-4b8e-a428-d9da2136b861","type":"HelpTool"}]},"id":"9322dd76-b0d5-4a39-b71c-d1d5125e0da9","type":"Toolbar"},{"attributes":{"formatter":{"id":"ed518da4-fdae-4920-aef9-fd50af64fa2d","type":"NumeralTickFormatter"},"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e6f4f1-52e5-49e6-b63f-7a3c695239b4","type":"BasicTicker"}},"id":"00cc89ce-fb4c-4742-93e8-92d60363a7e3","type":"LinearAxis"},{"attributes":{},"id":"d7fa174d-d6dd-45e5-8dc7-93487fecf04a","type":"ToolEvents"},{"attributes":{"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"}},"id":"51243cf8-89b2-4443-89fb-680895a7add9","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"}},"id":"4bf8fe37-9fe3-4b8e-a428-d9da2136b861","type":"HelpTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bba1daae-5565-4df3-bb03-33198ac7c0be","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"42f9890e-2455-4da1-9208-4be477af23f6","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9f8dda69-f3e4-4d8f-aded-0d7acee774c7","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"588e523d-80d4-493b-a396-ecdc5b4abd46","type":"DataRange1d"},{"attributes":{"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"}},"id":"d3df539a-830c-4c76-8510-ad127d0d1b71","type":"SaveTool"},{"attributes":{"callback":null},"id":"ee0cdc02-1343-47f3-9a65-1d2f93918761","type":"DataRange1d"},{"attributes":{"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"02e6f4f1-52e5-49e6-b63f-7a3c695239b4","type":"BasicTicker"}},"id":"7712391a-0b7b-425c-b924-5139f8868e21","type":"Grid"},{"attributes":{"formatter":{"id":"859d78ba-5c60-44a6-ba1a-f47bcff4fe70","type":"NumeralTickFormatter"},"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"0a8621e3-cc92-4cfb-b7c3-c2b18be8d522","type":"BasicTicker"}},"id":"fe8558bf-7ff9-4c3e-b608-aa444f69235e","type":"LinearAxis"},{"attributes":{},"id":"0a8621e3-cc92-4cfb-b7c3-c2b18be8d522","type":"BasicTicker"},{"attributes":{"format":"0.0%"},"id":"859d78ba-5c60-44a6-ba1a-f47bcff4fe70","type":"NumeralTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"e3dc5f7b-067b-4179-9833-127e1fcab5d4","subtype":"Figure","type":"Plot"},"ticker":{"id":"0a8621e3-cc92-4cfb-b7c3-c2b18be8d522","type":"BasicTicke ...

# %%
# リスト7.9.8：PrintTickFormatterの設定
from bokeh.models import PrintfTickFormatter
p = figure(plot_width=200, plot_height=200)
p.circle([0.123], [0.45])
p.xaxis.formatter = PrintfTickFormatter(format="%.2f")  # 小数点2桁までを表示
p.yaxis.formatter = PrintfTickFormatter(format="%e")  # 科学的記数法
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76a61fc9-a69e-4cf8-8075-975cefe29183"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("76a61fc9-a69e-4cf8-8075-975cefe29183");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76a61fc9-a69e-4cf8-8075-975cefe29183");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '76a61fc9-a69e-4cf8-8075-975cefe29183' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4391d712-784b-464f-bb52-dc2d2393c43d":{"roots":{"references":[{"attributes":{"overlay":{"id":"219a2be9-0999-49f8-a329-2edc2aa19f95","type":"BoxAnnotation"},"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"}},"id":"d7912bdb-6ba5-4ca3-bf94-ac51cf381f7c","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"25d307f6-fa72-408b-bf9a-3c5e7a72e63b","type":"PanTool"},{"id":"471dd1cc-0edf-4a41-99aa-763df96c2aa8","type":"WheelZoomTool"},{"id":"d7912bdb-6ba5-4ca3-bf94-ac51cf381f7c","type":"BoxZoomTool"},{"id":"e435312c-8b72-43cc-9a76-ba26995ad611","type":"SaveTool"},{"id":"084c23cb-9082-4140-834b-34843d385b4a","type":"ResetTool"},{"id":"71c64a6c-0125-48e1-b7bb-b49ea6137ea5","type":"HelpTool"}]},"id":"7c0055e2-6e02-4d7e-848f-c6e042eb34c8","type":"Toolbar"},{"attributes":{},"id":"db91ef61-4a83-4e0d-9bcb-014ea8f96545","type":"ToolEvents"},{"attributes":{"formatter":{"id":"eaa10467-1a96-43c5-809b-cb7d1c2d180f","type":"PrintfTickFormatter"},"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed72d8b0-dcd3-419d-bdca-7acdd1b8d9af","type":"BasicTicker"}},"id":"1c3afc15-a038-44f7-b91c-dc84fba47da8","type":"LinearAxis"},{"attributes":{"format":"%e"},"id":"fff978dd-22fe-4f37-af56-891073a39073","type":"PrintfTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"33810136-f627-44b7-9d6f-9181a1da5357","type":"Title"},{"attributes":{"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"}},"id":"71c64a6c-0125-48e1-b7bb-b49ea6137ea5","type":"HelpTool"},{"attributes":{"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"}},"id":"25d307f6-fa72-408b-bf9a-3c5e7a72e63b","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"},"ticker":{"id":"d21a30f6-d617-478a-8572-a14572410c1f","type":"BasicTicker"}},"id":"e1267f23-6570-4b5f-b42c-e415f856031b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"219a2be9-0999-49f8-a329-2edc2aa19f95","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"741a1f99-af01-40cb-8f83-1533c4456a8d","type":"DataRange1d"},{"attributes":{"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"}},"id":"084c23cb-9082-4140-834b-34843d385b4a","type":"ResetTool"},{"attributes":{"formatter":{"id":"fff978dd-22fe-4f37-af56-891073a39073","type":"PrintfTickFormatter"},"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"},"ticker":{"id":"d21a30f6-d617-478a-8572-a14572410c1f","type":"BasicTicker"}},"id":"44a6cb05-8bd0-4427-85c5-3b3ab4a7ecd9","type":"LinearAxis"},{"attributes":{"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"},"ticker":{"id":"ed72d8b0-dcd3-419d-bdca-7acdd1b8d9af","type":"BasicTicker"}},"id":"ac716b32-8eec-4eb0-bb51-a571fdf6f0a9","type":"Grid"},{"attributes":{"data_source":{"id":"622775dd-5007-487c-824d-28b7f71eea74","type":"ColumnDataSource"},"glyph":{"id":"ad49bc54-e59a-4618-b175-853bff71c474","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"78e5002e-f91f-48e8-82f0-91ec618eea32","type":"Circle"},"selection_glyph":null},"id":"71ee5cc6-e1bd-410c-a386-f1db63569596","type":"GlyphRenderer"},{"attributes":{"format":"%.2f"},"id":"eaa10467-1a96-43c5-809b-cb7d1c2d180f","type":"PrintfTickFormatter"},{"attributes":{"plot":{"id":"45209bd3-54a7-40a1-88c2-54a2d5d05542","subtype":"Figure","type":"Plot"}},"id":"e435312c-8b72-43cc-9a76-ba26995ad611","type":"SaveTool"},{"attributes":{"below":[{"id":"1c3afc15-a038-44f7- ...

# %%
# リスト7.9.9：major_label_orientationの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0])
p.xaxis.major_label_orientation = 0.6
p.yaxis.major_label_orientation = 'vertical'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9ed0df3c-cd40-492d-85b7-65fd033e1ec6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9ed0df3c-cd40-492d-85b7-65fd033e1ec6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ed0df3c-cd40-492d-85b7-65fd033e1ec6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ed0df3c-cd40-492d-85b7-65fd033e1ec6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"900017c4-a97c-4728-9d6b-0693e61160c2":{"roots":{"references":[{"attributes":{"data_source":{"id":"34a579e9-6d1d-4b82-9161-985c19621d49","type":"ColumnDataSource"},"glyph":{"id":"cd3b55c1-f875-4418-857b-80b045f16301","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"eacf0b2b-dce5-4d0a-97ff-0c90e9c65b00","type":"Circle"},"selection_glyph":null},"id":"f4c391e3-091a-4ff0-bcc3-81bc5e2912f6","type":"GlyphRenderer"},{"attributes":{},"id":"e8726c75-2e19-4874-9ffa-39a75038f413","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"1772412f-3fea-4cf1-96f1-40ee23a36902","type":"BasicTickFormatter"},"major_label_orientation":0.6,"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"},"ticker":{"id":"d66b219e-750d-4ff0-ab63-0baf53638c0e","type":"BasicTicker"}},"id":"4582b1b8-7cba-4922-bf93-59f648deb46e","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"},"ticker":{"id":"a9c64308-06e5-4bd3-8af4-af2f23f32488","type":"BasicTicker"}},"id":"f920bb5d-34af-44a6-9495-28b54e5a012b","type":"Grid"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"360e8533-18fd-4079-8d23-34b19f8e6f39","type":"PanTool"},{"attributes":{"callback":null},"id":"40edd1b8-7873-4679-afcc-acef89a6473d","type":"DataRange1d"},{"attributes":{},"id":"6593e837-021e-40eb-afb4-ebaf97a76ea2","type":"ToolEvents"},{"attributes":{"plot":null,"text":""},"id":"171698c9-4a5d-4e26-aba8-0f34e5d5d387","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eacf0b2b-dce5-4d0a-97ff-0c90e9c65b00","type":"Circle"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"e3ee4d1c-3467-41c1-83e1-85638ca6bd4f","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"0c10e0b8-341f-41a3-871c-0893236f7ff7","type":"BoxAnnotation"},"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"8cf39b1f-59fe-46de-83ab-fc598bc1d11b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"fe4b8bbb-4e42-4204-9aa0-8d0f2e4273a4","type":"SaveTool"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"c5734707-e4b2-48d7-ab46-d301546e46d2","type":"ResetTool"},{"attributes":{"callback":null},"id":"70a848bf-4931-44fa-bde9-fada7deb6992","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd3b55c1-f875-4418-857b-80b045f16301","type":"Circle"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"}},"id":"e6105110-a48f-40d8-8c48-bcf4ca465f95","type":"HelpTool"},{"attributes":{"plot":{"id":"d04ae0bb-dfb9-4179-af56-e5b78f732fec","subtype":"Figure","type":"Plot"},"ticker":{"id":"d66b219e-750d-4ff0-ab63-0baf53638c0e","type":"BasicTicker"}},"id":"7fa30f80-9973-46f7-a23e-32490f8fc4f4","type":"Grid"},{"attributes":{"below":[{"id":"4582b1b8-7cba-4922-bf93-59f648deb46e","type":"LinearAxis"}],"left":[{"id":"84d76446-c537-4b84-9e3e-8b033bf61dab","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"4582b1b8-7cba-4922-bf93-59f648deb46e","type":"LinearAxis"},{"id":"7fa30f80-9973-46f7-a23e-32490f8fc4f4","type":"Grid"},{"id":"84d76446-c537-4b84-9e3e-8b033bf61dab","type":"LinearAxis"},{"id":"f920bb5d-34af-44a6-9495-28b54e5a012b","type":"Grid"},{"id":"0c10e0b8-341f-41a3-871c-0893236f7ff7","type":"BoxAnnotation"},{"id":"f4c391e3-091a-4ff0-bcc3-81bc5e2912f6","type":"GlyphRenderer"}],"title":{"id":"171698c9-4a5d-4e26-aba8-0f34e5d5d387","type":"Title"},"tool_events":{"id":"6593e837-021e-40eb-afb4-eba ...
