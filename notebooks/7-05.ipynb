# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-5: テキストの調整

# %%
# リスト7.5.1：フォントの設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200, x_range=(0, 2), y_range=(0.5, 2.5))
p.text(0, 1, text=["times"], text_font="times", text_font_size="25pt")
p.text(0, 2, text=["helvetica"], text_font="helvetica", text_font_size="25pt")
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="084fda8a-3145-4586-801b-9fa8952863dd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3de9130a-eb76-4e3c-85cc-b39a39260be6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3de9130a-eb76-4e3c-85cc-b39a39260be6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3de9130a-eb76-4e3c-85cc-b39a39260be6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3de9130a-eb76-4e3c-85cc-b39a39260be6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"35943de8-7b7d-47b5-b7f6-1383b3403958":{"roots":{"references":[{"attributes":{"callback":null,"end":2},"id":"0fb58d80-0b65-4b05-8076-7af96cf7dba9","type":"Range1d"},{"attributes":{"text_color":{"value":"black"},"text_font":"times","text_font_size":{"value":"25pt"},"x":{"value":0},"y":{"value":1}},"id":"dd77ab9d-4316-4882-853a-81c99e6661ea","type":"Text"},{"attributes":{},"id":"1ca02516-649b-40ab-a914-c3d22a02942f","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"415be466-b61f-4b2f-9efb-fdb0e0516499","type":"BoxAnnotation"},{"attributes":{},"id":"0cbd4fc1-7308-4240-af0c-dfbf61e12b61","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"9124aca5-5b54-44c8-96b7-952d8a75e51d","type":"LinearAxis"}],"left":[{"id":"e078544e-698b-45e1-8d6a-2c96eb6d28d6","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"9124aca5-5b54-44c8-96b7-952d8a75e51d","type":"LinearAxis"},{"id":"246d3bee-fb6f-4147-a768-6ec88b9d8446","type":"Grid"},{"id":"e078544e-698b-45e1-8d6a-2c96eb6d28d6","type":"LinearAxis"},{"id":"8ae7fffa-c2b8-44bb-b16d-e3f37979b9fd","type":"Grid"},{"id":"415be466-b61f-4b2f-9efb-fdb0e0516499","type":"BoxAnnotation"},{"id":"e5bc7dd2-929a-4892-aa75-e529d8b23ce2","type":"GlyphRenderer"},{"id":"73048add-7243-4ccd-9021-5209c18ad653","type":"GlyphRenderer"}],"title":{"id":"338f2227-0b95-4ad6-a585-751572143781","type":"Title"},"tool_events":{"id":"c534ccf0-ca82-4d76-beda-f332539ae417","type":"ToolEvents"},"toolbar":{"id":"1bc64e81-6c58-43e0-8e44-a85de1061173","type":"Toolbar"},"x_range":{"id":"0fb58d80-0b65-4b05-8076-7af96cf7dba9","type":"Range1d"},"y_range":{"id":"58e8c8f2-1fe1-4332-95a7-bae0deff7633","type":"Range1d"}},"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"}},"id":"43f36b43-34a2-4de0-84e6-9074b9f3ccab","type":"PanTool"},{"attributes":{"plot":{"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"}},"id":"e66c8919-02c0-4751-9d28-c3905a117a94","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"415be466-b61f-4b2f-9efb-fdb0e0516499","type":"BoxAnnotation"},"plot":{"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"}},"id":"270528f5-0f4a-43fc-818d-4e290323a3b7","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"1ca02516-649b-40ab-a914-c3d22a02942f","type":"BasicTickFormatter"},"plot":{"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"},"ticker":{"id":"6418be47-959a-4609-bd65-f13cb5a07921","type":"BasicTicker"}},"id":"e078544e-698b-45e1-8d6a-2c96eb6d28d6","type":"LinearAxis"},{"attributes":{"plot":{"id":"097220fd-1728-45c8-b28b-b74c6223bf58","subtype":"Figure","type":"Plot"}},"id":"53b5b8cd-dabd-4380-8470-92de62d1a184","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"338f2227-0b95-4ad6-a585-751572143781","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"43f36b43-34a2-4de0-84e6-9074b9f3ccab","type":"PanTool"},{"id":"e66c8919-02c0-4751-9d28-c3905a117a94","type":"WheelZoomTool"},{"id":"270528f5-0f4a-43fc-818d-4e290323a3b7","type":"BoxZoomTool"},{"id":"53b5b8cd-dabd-4380-8470-92de62d1a184","type":"SaveTool"},{"id":"d8a04cce-21c5-4cf4-b714-ef9642315259","type":"ResetTool"},{"id":"55d558df-48dc-4fd4-ac78-94a186629caf","type":"HelpTool"}]},"id":"1bc64e81-6c58-43e0-8e44-a85de1061173","type":"Toolbar"},{"attributes":{"data_source":{"id":"6841e7d1-a011-4634-b3b2-1466ff8b027a","type":"ColumnDataSource"},"glyph":{"id":"dd77ab9d-4316-4882-853a-81c99e6661ea","type":"Text"},"hover_glyph":null,"muted_glyph":null,"n ...

# %%
# リスト7.5.2：フォントサイズの設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 2.5))
p.text(0, 1, text=["12pt"], text_font_size="12pt")
p.text(0, 2, text=["1.5em"], text_font_size="1.5em")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ebe8a7d9-c39b-4dd1-9a85-a53f26394d96"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ebe8a7d9-c39b-4dd1-9a85-a53f26394d96");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ebe8a7d9-c39b-4dd1-9a85-a53f26394d96");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ebe8a7d9-c39b-4dd1-9a85-a53f26394d96' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c0939588-0f0f-4c1f-a0a6-f34e65d77416":{"roots":{"references":[{"attributes":{"text_color":{"value":"black"},"text_font_size":{"value":"1.5em"},"x":{"value":0},"y":{"value":2}},"id":"50f44e30-c2e8-4129-a91b-dc2876f3b0c0","type":"Text"},{"attributes":{"formatter":{"id":"4a209768-acf7-48f7-a6c5-cb5f701df9e3","type":"BasicTickFormatter"},"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"057acef8-f865-44d6-8930-87f30777c39e","type":"BasicTicker"}},"id":"d2904b55-fefb-4f43-b2b1-7adf35cee985","type":"LinearAxis"},{"attributes":{},"id":"967db1cd-8134-4f74-8557-f0553d6386f0","type":"ToolEvents"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"7d76b684-e8c0-4eca-b915-b0003899d539","type":"Text"},{"attributes":{"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"}},"id":"371cc0f3-5e3f-4c5c-9b81-f0bec1b22e9e","type":"SaveTool"},{"attributes":{"callback":null},"id":"2e18085f-e622-4ea1-843a-00332374c92b","type":"DataRange1d"},{"attributes":{"below":[{"id":"c69bc3b9-9bc4-430e-ad26-16b5a84ac64c","type":"LinearAxis"}],"left":[{"id":"d2904b55-fefb-4f43-b2b1-7adf35cee985","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"c69bc3b9-9bc4-430e-ad26-16b5a84ac64c","type":"LinearAxis"},{"id":"d0116a9a-d0eb-4da3-9650-c69580f489c5","type":"Grid"},{"id":"d2904b55-fefb-4f43-b2b1-7adf35cee985","type":"LinearAxis"},{"id":"90bf264f-5129-4419-b7a2-12ef44063860","type":"Grid"},{"id":"6055ad0b-e55e-46e5-bf16-0707159048af","type":"BoxAnnotation"},{"id":"e08c3517-7bc9-4eca-9c2d-30c7e8d64579","type":"GlyphRenderer"},{"id":"4cdd9880-f24e-4a10-933a-99f90d4df556","type":"GlyphRenderer"}],"title":{"id":"1caec5ff-6138-47df-a8b0-aa8f2587c49c","type":"Title"},"tool_events":{"id":"967db1cd-8134-4f74-8557-f0553d6386f0","type":"ToolEvents"},"toolbar":{"id":"52daa4f3-cc35-4fbc-a5ae-91cb3ab7bd0c","type":"Toolbar"},"x_range":{"id":"2e18085f-e622-4ea1-843a-00332374c92b","type":"DataRange1d"},"y_range":{"id":"597ff7db-ac6f-42bc-9f60-b547133b975a","type":"Range1d"}},"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6055ad0b-e55e-46e5-bf16-0707159048af","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"}},"id":"75aa18d7-907c-4c26-ab13-014c0dc9743f","type":"HelpTool"},{"attributes":{"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"}},"id":"f43ed845-6a97-4fa0-b966-b07390857e82","type":"PanTool"},{"attributes":{"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"efcd84bb-fc57-4a41-a482-726e94eeb978","type":"Text"},{"attributes":{"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"}},"id":"ac26ca1a-7e8a-474b-9990-361244108e20","type":"ResetTool"},{"attributes":{"data_source":{"id":"a8a13530-6508-453f-b9b4-f4560b0aaa5d","type":"ColumnDataSource"},"glyph":{"id":"efcd84bb-fc57-4a41-a482-726e94eeb978","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7d76b684-e8c0-4eca-b915-b0003899d539","type":"Text"},"selection_glyph":null},"id":"e08c3517-7bc9-4eca-9c2d-30c7e8d64579","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["12pt"]}},"id":"a8a13530-6508-453f-b9b4-f4560b0aaa5d","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"6055ad0b-e55e-46e5-bf16-0707159048af","type":"BoxAnnotation"},"plot":{"id":"5eb0484c-544b-4e2b-b837-1023d48544f5","subtype":"Figure","type":"Plot"}},"id":"6ddeab71-ec49-4614-9c20-00ff2d46 ...

# %%
# リスト7.5.3：フォントスタイルの設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 2.5))
p.text(0, 1, text=["italic"], text_font_style="italic")
p.text(0, 2, text=["bold"], text_font_style="bold")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="951f1217-13dc-46c1-bfab-3e67ef7f905b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("951f1217-13dc-46c1-bfab-3e67ef7f905b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("951f1217-13dc-46c1-bfab-3e67ef7f905b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '951f1217-13dc-46c1-bfab-3e67ef7f905b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fef1e43c-381a-4408-b749-c8160e0f3f4c":{"roots":{"references":[{"attributes":{},"id":"4aec1319-f8ac-4378-9981-437c0c904812","type":"BasicTicker"},{"attributes":{},"id":"74c695a9-50e7-4a66-bc2c-48eef59290ce","type":"BasicTicker"},{"attributes":{"formatter":{"id":"2d905b99-c548-42ce-8ff9-4c68966e6dab","type":"BasicTickFormatter"},"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4aec1319-f8ac-4378-9981-437c0c904812","type":"BasicTicker"}},"id":"86eaaaf9-f8a5-4765-a0e0-71f664dfdab7","type":"LinearAxis"},{"attributes":{"text_color":{"value":"black"},"text_font_style":"bold","x":{"value":0},"y":{"value":2}},"id":"4aa84808-700a-4fb8-b15b-d503898e1a63","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["bold"]}},"id":"c2a9b8e6-4298-4a0e-816a-53f6f762120e","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"b49ccd55-0320-498e-ab23-945157e44783","type":"BasicTickFormatter"},"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"},"ticker":{"id":"74c695a9-50e7-4a66-bc2c-48eef59290ce","type":"BasicTicker"}},"id":"0c595e52-facc-4ad3-b8ab-48827692e157","type":"LinearAxis"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_style":"bold","x":{"value":0},"y":{"value":2}},"id":"41e2e02d-2fce-4a7e-995d-b5f18e84fdec","type":"Text"},{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"3692cb0c-e71b-4b2d-a0fb-a865907f4828","type":"Range1d"},{"attributes":{"text_color":{"value":"black"},"text_font_style":"italic","x":{"value":0},"y":{"value":1}},"id":"778a2409-b2cf-443b-bef9-b244379fe1c2","type":"Text"},{"attributes":{"data_source":{"id":"b9eecc64-3d52-44f4-a93e-7f608470cdb9","type":"ColumnDataSource"},"glyph":{"id":"778a2409-b2cf-443b-bef9-b244379fe1c2","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"584df8ec-c73d-4108-8fc4-0a3acf93909b","type":"Text"},"selection_glyph":null},"id":"7e625ffc-cded-4eb2-b142-b53056790b53","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"96181391-621d-4017-b814-341cef5ffa8d","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"},"ticker":{"id":"4aec1319-f8ac-4378-9981-437c0c904812","type":"BasicTicker"}},"id":"7874dc15-25f0-434b-b8ef-653e6533ccf0","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"},"ticker":{"id":"74c695a9-50e7-4a66-bc2c-48eef59290ce","type":"BasicTicker"}},"id":"30f171db-affb-4de3-982c-c19b1cee85fc","type":"Grid"},{"attributes":{"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"}},"id":"dca8818b-51e2-4098-a870-1620a9ed25a8","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"32a82720-fb8e-4646-a9a8-927300a7c26e","subtype":"Figure","type":"Plot"}},"id":"6c60eeb9-fd53-4378-8ce1-ad6ff8027c1a","type":"PanTool"},{"attributes":{},"id":"2d905b99-c548-42ce-8ff9-4c68966e6dab","type":"BasicTickFormatter"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_style":"italic","x":{"value":0},"y":{"value":1}},"id":"584df8ec-c73d-4108-8fc4-0a3acf93909b","type":"Text"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6c60eeb9-fd53-4378-8ce1-ad6ff8027c1a","type":"PanTool"},{"id":"dca8818b-51e2-4098-a870-1620a9ed25a8","type":"WheelZoomTool"},{"id":"a750b8ca-c30b-4119-87c5-4db734e9f936","type":"BoxZoomTool"},{"id":"563a9a87-ea92-4a0e-930e-8153051ee2bb","type":"SaveTool"},{"id":"6cc204cd-6b30-4d24-9e36-f5c2eb78294e","type":"ResetTool"},{"id":"98cb ...

# %%
# リスト7.5.4：テキストの色の設定
p = figure(plot_width=200, plot_height=200, x_range=(-1, 2.7), y_range=(0.5, 2.5))
p.text(0, 2, text=["red"], text_color="red")
p.text(0, 1, text=["(0, 255, 0, 0.5)"], text_color=(0, 255, 0, 0.5))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5f6e677b-bfc2-4a89-bf5d-1e8441d27945"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5f6e677b-bfc2-4a89-bf5d-1e8441d27945");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5f6e677b-bfc2-4a89-bf5d-1e8441d27945");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5f6e677b-bfc2-4a89-bf5d-1e8441d27945' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80f7d913-2103-4332-8b71-a6fce6c11c3b":{"roots":{"references":[{"attributes":{},"id":"f68267f6-ab8a-4d0a-988a-2511cacfce60","type":"BasicTicker"},{"attributes":{"formatter":{"id":"dc3a38c3-5f41-44da-9708-a21ad1de709e","type":"BasicTickFormatter"},"plot":{"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"10b231dd-88a3-4d9d-8480-ad7d9b8aab0a","type":"BasicTicker"}},"id":"15011938-6cf4-4469-ac52-b3205d0e22c0","type":"LinearAxis"},{"attributes":{},"id":"9ab073df-4c01-45d3-8b8c-00d279f119cd","type":"BasicTickFormatter"},{"attributes":{},"id":"dc3a38c3-5f41-44da-9708-a21ad1de709e","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"9bd58d12-9f1a-4a95-96a5-560c44b77196","type":"BoxAnnotation"},"plot":{"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type":"Plot"}},"id":"3a692684-34e0-41ea-8776-37e62475cbed","type":"BoxZoomTool"},{"attributes":{},"id":"10b231dd-88a3-4d9d-8480-ad7d9b8aab0a","type":"BasicTicker"},{"attributes":{"text_color":{"value":"red"},"x":{"value":0},"y":{"value":2}},"id":"163456f7-17e9-4cfc-93ab-c6215011763c","type":"Text"},{"attributes":{"below":[{"id":"15011938-6cf4-4469-ac52-b3205d0e22c0","type":"LinearAxis"}],"left":[{"id":"350f2e8d-9399-49eb-b8da-bec054b474f0","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"15011938-6cf4-4469-ac52-b3205d0e22c0","type":"LinearAxis"},{"id":"bb6c46ba-76b5-41d1-b07d-af93b2dfbcbd","type":"Grid"},{"id":"350f2e8d-9399-49eb-b8da-bec054b474f0","type":"LinearAxis"},{"id":"5f82bbba-ed9e-4414-92b4-dd2ce66aefad","type":"Grid"},{"id":"9bd58d12-9f1a-4a95-96a5-560c44b77196","type":"BoxAnnotation"},{"id":"6bfcc63d-dbdd-4c00-8451-1cb3ae55c725","type":"GlyphRenderer"},{"id":"e097b945-01cb-450a-a95e-5bb2b7f4144d","type":"GlyphRenderer"}],"title":{"id":"75f3ae58-5ef5-4973-8a1f-fc1050331b16","type":"Title"},"tool_events":{"id":"1933dd00-ade6-49a9-be9e-bea84273c2e3","type":"ToolEvents"},"toolbar":{"id":"2a06871c-07f7-406c-9b1b-f6bf30b7eaa1","type":"Toolbar"},"x_range":{"id":"6a94bd85-b8aa-4876-84f7-2e909d437a8b","type":"Range1d"},"y_range":{"id":"d250e3c8-f70e-49bd-b96d-ce245568f4ce","type":"Range1d"}},"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":2.7,"start":-1},"id":"6a94bd85-b8aa-4876-84f7-2e909d437a8b","type":"Range1d"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["red"]}},"id":"581b0986-26b5-4ec3-ab76-075a9baef275","type":"ColumnDataSource"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"a476ddd6-1315-4f1a-8955-4328696b20ca","type":"Text"},{"attributes":{"plot":{"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type":"Plot"}},"id":"9971cb63-1086-4cc8-91e1-b75160eb16fc","type":"SaveTool"},{"attributes":{},"id":"1933dd00-ade6-49a9-be9e-bea84273c2e3","type":"ToolEvents"},{"attributes":{"text_color":{"value":"rgba(0, 255, 0, 0.5)"},"x":{"value":0},"y":{"value":1}},"id":"9b30316d-9bc6-4d99-8282-77a16a9463c8","type":"Text"},{"attributes":{"formatter":{"id":"9ab073df-4c01-45d3-8b8c-00d279f119cd","type":"BasicTickFormatter"},"plot":{"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"f68267f6-ab8a-4d0a-988a-2511cacfce60","type":"BasicTicker"}},"id":"350f2e8d-9399-49eb-b8da-bec054b474f0","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"75f3ae58-5ef5-4973-8a1f-fc1050331b16","type":"Title"},{"attributes":{"data_source":{"id":"581b0986-26b5-4ec3-ab76-075a9baef275","type":"ColumnDataSource"},"glyph":{"id":"163456f7-17e9-4cfc-93ab-c6215011763c","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e0bb8e6c-94e1-4678-b829-06ead44eadde","type":"Text"},"selection_glyph":null},"id":"6bfcc63d-dbdd-4c00-8451-1cb3ae55c725","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"83bdcdc3-63f6-439c-bafa-00fe8cd505cb","subtype":"Figure","type ...

# %%
# リスト7.5.5：テキストの位置の設定例
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 3.5))
p.text(1, 3, text=["left"], text_align="left")
p.text(1, 2, text=["center"], text_align="center")
p.text(1, 1, text=["right"], text_align="right")
p.line([1, 1], [0.5, 3.5])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ab22ec70-ec2b-42ca-9283-54f7fee28a8b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ab22ec70-ec2b-42ca-9283-54f7fee28a8b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ab22ec70-ec2b-42ca-9283-54f7fee28a8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ab22ec70-ec2b-42ca-9283-54f7fee28a8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"392e8861-6e60-4582-a341-d54851898bc2":{"roots":{"references":[{"attributes":{"callback":null},"id":"625148ed-92eb-4665-888c-04140db06823","type":"DataRange1d"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"},"ticker":{"id":"82ca6569-ad2b-43db-8d7a-40ac7db28fbf","type":"BasicTicker"}},"id":"5a886075-1133-447c-938e-f1b0e43bb0b3","type":"Grid"},{"attributes":{"overlay":{"id":"44305aa5-c2ad-4ad7-929c-4387cdb99fc3","type":"BoxAnnotation"},"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"fd95fa8f-6c27-464c-8974-49bfd05a4f7c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"b3245e8c-4d88-4bd6-b198-1916858cd9fa","type":"WheelZoomTool"},{"attributes":{"text_align":"right","text_color":{"value":"black"},"x":{"value":1},"y":{"value":1}},"id":"af9d745f-9add-4f7f-95be-d041438ee959","type":"Text"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"b7e76970-472f-4103-afd1-a9edd52e459b","type":"SaveTool"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"d070612d-b45f-45ac-b4f4-96cd7339b9ea","type":"HelpTool"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"5107eeab-91be-4fe3-96e8-582c5f4ccd61","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8801de7b-fb9d-4588-9d73-a5a40c87a7e4","type":"Line"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["right"]}},"id":"38585ba3-8ed5-41cd-b3f0-dd48e61f4dc6","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"f0bb7717-8901-4550-9f6f-e609ac1bf489","type":"BasicTickFormatter"},"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"},"ticker":{"id":"d2eeea29-f602-4566-9e80-55019a78894f","type":"BasicTicker"}},"id":"a313172f-2830-410c-8454-b0861be5c998","type":"LinearAxis"},{"attributes":{},"id":"f0bb7717-8901-4550-9f6f-e609ac1bf489","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"44305aa5-c2ad-4ad7-929c-4387cdb99fc3","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"38585ba3-8ed5-41cd-b3f0-dd48e61f4dc6","type":"ColumnDataSource"},"glyph":{"id":"af9d745f-9add-4f7f-95be-d041438ee959","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9d6c2fd6-66f6-408e-89a5-09ff01116d57","type":"Text"},"selection_glyph":null},"id":"f56bb64a-1363-42d8-85ed-2cb9ae4e3918","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"27f9d580-5f38-4cb1-a9de-278280e2d445","subtype":"Figure","type":"Plot"}},"id":"95ee06c9-c34d-45fc-8697-1e20fcc9c037","type":"PanTool"},{"attributes":{"data_source":{"id":"a835a3eb-2dcb-4fdd-ae7f-4f38e228ff4b","type":"ColumnDataSource"},"glyph":{"id":"14f3313a-8a19-4a66-b655-523ea46de1c2","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"621ab731-452e-41a4-b323-9ab824b034a6","type":"Text"},"selection_glyph":null},"id":"745ba3da-6209-47c4-a03e-7d1364830e1d","type":"GlyphRenderer"},{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"14f3313a-8a19-4a66-b655-523ea46de1c2","type":"Text"},{"attributes":{"text_color":{"value":"black"},"x":{"value":1},"y":{"value":3}},"id":"bfa01b91-be6d-4b20-a787-3a4d3356a80e","type":"Text"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"621ab731-452e-41a4-b323-9ab824b034a6","typ ...

# %%
# リスト7.5.6：垂直揃えの設定
p = figure(plot_width=600, plot_height=200, x_range=(-0.5, 5))
baselines = ["top", "middle", "bottom", "alphabetic", "hanging"]
for y, baseline in enumerate(baselines):
    p.text(y, 1, text=[baseline], text_baseline=baseline)
    p.line([-0.5, 10.5], [1, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="97cb2369-fb57-4ac1-a2e8-1c7c26271165"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("97cb2369-fb57-4ac1-a2e8-1c7c26271165");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("97cb2369-fb57-4ac1-a2e8-1c7c26271165");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '97cb2369-fb57-4ac1-a2e8-1c7c26271165' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e9e0e570-5237-49e4-b4b4-8271df39c9b4":{"roots":{"references":[{"attributes":{},"id":"f7f1a651-cf0a-40fa-9c8f-84224c2db616","type":"BasicTicker"},{"attributes":{"plot":{"id":"432a6835-1f92-4e21-8528-1d67d62c22b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7f1a651-cf0a-40fa-9c8f-84224c2db616","type":"BasicTicker"}},"id":"fd791922-6b15-47a8-b2d7-3e2ecd801820","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6afdd884-9aa6-4e71-9b18-95391bbf688e","type":"Line"},{"attributes":{"formatter":{"id":"ad0cbfed-3b6c-4d69-b090-16cb2b1f093d","type":"BasicTickFormatter"},"plot":{"id":"432a6835-1f92-4e21-8528-1d67d62c22b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7f1a651-cf0a-40fa-9c8f-84224c2db616","type":"BasicTicker"}},"id":"05bc6c9a-5718-46c3-8453-ead74e651fa5","type":"LinearAxis"},{"attributes":{"data_source":{"id":"aa4ff353-610f-4e7f-9cb1-9451e10e27ca","type":"ColumnDataSource"},"glyph":{"id":"395d081d-8fa7-441f-8586-d6b2bfd52f2c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6afdd884-9aa6-4e71-9b18-95391bbf688e","type":"Line"},"selection_glyph":null},"id":"8fa70fbd-0029-4829-91ae-736d914268eb","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["top"]}},"id":"6451ad9e-4ce4-409b-b434-d8be2c36d958","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c5b1cd0d-8b77-40ab-94e0-f859026159c9","type":"Line"},{"attributes":{},"id":"b5e13d39-b3ce-448f-a8bd-fdd947ef8da3","type":"BasicTicker"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"hanging","text_color":{"value":"black"},"x":{"value":4},"y":{"value":1}},"id":"8ab9c178-618f-49b1-947b-4badf1d0cf3c","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["hanging"]}},"id":"78c525b9-6e71-4eef-a8c9-f27ebbe4ab4d","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"cd3bd129-ce6f-48d5-875f-a74625c993e4","type":"BasicTickFormatter"},"plot":{"id":"432a6835-1f92-4e21-8528-1d67d62c22b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"b5e13d39-b3ce-448f-a8bd-fdd947ef8da3","type":"BasicTicker"}},"id":"5e588adc-0f20-44d2-9b19-62805f34ef67","type":"LinearAxis"},{"attributes":{"data_source":{"id":"d3aaa0a6-b459-4b2f-8ba2-2a3cc0433084","type":"ColumnDataSource"},"glyph":{"id":"72f2b9c7-077d-4bc0-83db-214926bd45f2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"90996459-2e80-4986-a1b9-c061594ff6f4","type":"Line"},"selection_glyph":null},"id":"9d2de118-7d8f-4c0b-b004-8a7b91a7e9cb","type":"GlyphRenderer"},{"attributes":{"text_baseline":"hanging","text_color":{"value":"black"},"x":{"value":4},"y":{"value":1}},"id":"ba1a5864-013c-468a-86a2-5ef2ba9e6427","type":"Text"},{"attributes":{"text_baseline":"top","text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"d2a96dfc-abda-46e8-bcfa-1b7cf3c061a4","type":"Text"},{"attributes":{"data_source":{"id":"78c525b9-6e71-4eef-a8c9-f27ebbe4ab4d","type":"ColumnDataSource"},"glyph":{"id":"ba1a5864-013c-468a-86a2-5ef2ba9e6427","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8ab9c178-618f-49b1-947b-4badf1d0cf3c","type":"Text"},"selection_glyph":null},"id":"7fcad5a6-5ee7-4169-a1f4-2847563afa10","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"74c90a19-cd4a-4d08-b377-a074754d8f26","type":"ColumnDataSource"},"glyph":{"id":"f824763a-6e25-459b-8bad-0d42c2c5bfe5","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7e47a392-dc34-4af6-8a75-72200b41e13e","type":"Text"},"selection_glyph":null},"id":"61599f03-519d-4160-8ca7-797aea978fa7","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"90996459-2e80-4986-a1b9-c061594ff6f4","type":"Line"},{"attributes":{"line ...
