# %%
# リスト7.5.1：フォントの設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200, x_range=(0, 2), y_range=(0.5, 2.5))
p.text(0, 1, text=['times'], text_font='times', text_font_size='25pt')
p.text(0, 2, text=['helvetica'], text_font='helvetica', text_font_size='25pt')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e1fadda6-956f-45f9-a808-39c3045c543a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="066f40bf-cb7d-4aba-8fb2-9c7acf5eee6a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("066f40bf-cb7d-4aba-8fb2-9c7acf5eee6a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("066f40bf-cb7d-4aba-8fb2-9c7acf5eee6a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '066f40bf-cb7d-4aba-8fb2-9c7acf5eee6a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f3eda0fb-c6cb-482d-a872-c943d5caf4f3":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fea8ba6f-3559-4357-973c-61af744e0d8e","type":"PanTool"},{"id":"69118aa4-79ed-46bc-993f-47d1a62ada49","type":"WheelZoomTool"},{"id":"d5cdeb7e-4c01-4373-ba0c-f47d4f329129","type":"BoxZoomTool"},{"id":"da46b7de-7383-4368-8454-36cd45f76fce","type":"SaveTool"},{"id":"48acb8e1-c6ca-46be-8b74-6d10eed76fa0","type":"ResetTool"},{"id":"bd89ff6c-ebe7-4304-9b83-0e091f253a06","type":"HelpTool"}]},"id":"4473e941-fdb9-499a-a178-11360a017896","type":"Toolbar"},{"attributes":{},"id":"9679324d-4680-4b5f-9459-3a9a8c640b9d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"fea8ba6f-3559-4357-973c-61af744e0d8e","type":"PanTool"},{"attributes":{"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"69118aa4-79ed-46bc-993f-47d1a62ada49","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"629edd7c-f28d-4f44-9a8f-939816582179","type":"Title"},{"attributes":{},"id":"2dbc23ab-87a0-4062-9fe0-3bcfca41f4dd","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"815fa40d-d0cb-46eb-b586-1ebfccf2a7da","type":"BoxAnnotation"},"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"d5cdeb7e-4c01-4373-ba0c-f47d4f329129","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"90083c15-4af2-4f17-92f8-e1c0116bbcce","type":"LinearAxis"}],"left":[{"id":"43bdb5ed-88f8-4189-8a7c-2b701922a113","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"90083c15-4af2-4f17-92f8-e1c0116bbcce","type":"LinearAxis"},{"id":"bbc558a3-a67d-4ba4-9b73-56a7e9f173b0","type":"Grid"},{"id":"43bdb5ed-88f8-4189-8a7c-2b701922a113","type":"LinearAxis"},{"id":"a04aaad0-b1b8-4c43-829f-34a35d628fb4","type":"Grid"},{"id":"815fa40d-d0cb-46eb-b586-1ebfccf2a7da","type":"BoxAnnotation"},{"id":"09d493f0-b5d2-4b34-87bc-6616bf00c7cd","type":"GlyphRenderer"},{"id":"628cf565-ea13-4c93-bbe5-7a45dc3f7c75","type":"GlyphRenderer"}],"title":{"id":"629edd7c-f28d-4f44-9a8f-939816582179","type":"Title"},"tool_events":{"id":"b8c85dc9-7933-4737-af32-00307fd18b06","type":"ToolEvents"},"toolbar":{"id":"4473e941-fdb9-499a-a178-11360a017896","type":"Toolbar"},"x_range":{"id":"093691a9-7592-48d3-b05d-651bc8af20b6","type":"Range1d"},"y_range":{"id":"fef0b591-cb31-4b9b-b4a5-35a906cc8caf","type":"Range1d"}},"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"da46b7de-7383-4368-8454-36cd45f76fce","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["times"]}},"id":"52e4e436-9b18-43f9-9d02-8d8c8de98cd1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"48acb8e1-c6ca-46be-8b74-6d10eed76fa0","type":"ResetTool"},{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"fef0b591-cb31-4b9b-b4a5-35a906cc8caf","type":"Range1d"},{"attributes":{"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"}},"id":"bd89ff6c-ebe7-4304-9b83-0e091f253a06","type":"HelpTool"},{"attributes":{"text_color":{"value":"black"},"text_font":"times","text_font_size":{"value":"25pt"},"x":{"value":0},"y":{"value":1}},"id":"88947c10-21da-45cd-889b-e28aa2b863c8","type":"Text"},{"attributes":{"formatter":{"id":"2dbc23ab-87a0-4062-9fe0-3bcfca41f4dd","type":"BasicTickFormatter"},"plot":{"id":"3938a95e-0e29-4672-a421-ecccf3709c9c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9cc8304d-947c-44e9-9874-2e3bb319253b","type":"BasicTicker"}},"id":"90083c15-4af2-4f17-92f8-e1c0116bbcce","type":"LinearAxis"},{"attributes":{"data_source":{"id":"52e4e436-9b18-43f9-9d02-8d8c8de98cd1","type":"ColumnDataSource ...

# %%
# リスト7.5.2：フォントサイズの設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 2.5))
p.text(0, 1, text=['12pt'], text_font_size='12pt')
p.text(0, 2, text=['1.5em'], text_font_size='1.5em')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b75cb6e3-c80b-418c-b658-f63af3202d40"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b75cb6e3-c80b-418c-b658-f63af3202d40");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b75cb6e3-c80b-418c-b658-f63af3202d40");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b75cb6e3-c80b-418c-b658-f63af3202d40' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9b4fa1e0-1a5c-4c04-8e73-87d382bbaa6a":{"roots":{"references":[{"attributes":{},"id":"cf8fdc38-3dab-465b-aff2-3b9141e63f96","type":"BasicTickFormatter"},{"attributes":{"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"4e6d7942-ff8c-46a6-b9e4-9a002f61a8cc","type":"Text"},{"attributes":{"formatter":{"id":"526e175f-9d91-469a-ae65-397fdbbec788","type":"BasicTickFormatter"},"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"dc9e58bc-e201-4c13-9440-e2cc1a38d40e","type":"BasicTicker"}},"id":"6d920890-d608-46f4-b50b-fb01046ef3c4","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"95e4abb3-b626-4f87-974a-7c9328080a66","type":"PanTool"},{"id":"dbf3df4f-9b0b-4f99-bc5e-7c7e10b9d64e","type":"WheelZoomTool"},{"id":"b1a067c2-9c8d-4e0f-b01f-f7e82c60b0da","type":"BoxZoomTool"},{"id":"058ed882-b9c7-40c8-95d4-7a7f9ef62a3c","type":"SaveTool"},{"id":"b3f8fda2-4933-4718-a62c-4bed8cfa1f22","type":"ResetTool"},{"id":"29b94c41-44f5-4ac0-9476-f7882b50291a","type":"HelpTool"}]},"id":"83450ce6-3788-4d92-9771-af9cb3bbe931","type":"Toolbar"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"094ff74e-ec6a-4efe-8b4a-abaad3fff46c","type":"Text"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"79a5f63e-ecfd-4f40-863c-49f6722329c1","type":"BasicTicker"}},"id":"93a5219f-ddc0-43d5-a66a-8de13f2118f2","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"6cc784d6-9895-42c8-8a29-c8b0650f5e39","type":"Title"},{"attributes":{"formatter":{"id":"cf8fdc38-3dab-465b-aff2-3b9141e63f96","type":"BasicTickFormatter"},"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"},"ticker":{"id":"79a5f63e-ecfd-4f40-863c-49f6722329c1","type":"BasicTicker"}},"id":"37d4f3f4-b342-431d-8d1b-4102154c7008","type":"LinearAxis"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"b3f8fda2-4933-4718-a62c-4bed8cfa1f22","type":"ResetTool"},{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"1ddde903-ccdb-44f9-b7dc-0e015e37bec0","type":"Range1d"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"058ed882-b9c7-40c8-95d4-7a7f9ef62a3c","type":"SaveTool"},{"attributes":{},"id":"79a5f63e-ecfd-4f40-863c-49f6722329c1","type":"BasicTicker"},{"attributes":{"overlay":{"id":"b677e43e-c7a3-4536-a57d-734f6cc66cd5","type":"BoxAnnotation"},"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"b1a067c2-9c8d-4e0f-b01f-f7e82c60b0da","type":"BoxZoomTool"},{"attributes":{"text_color":{"value":"black"},"text_font_size":{"value":"1.5em"},"x":{"value":0},"y":{"value":2}},"id":"5da8dc0c-ff86-41a4-84d3-2596f0149422","type":"Text"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"dbf3df4f-9b0b-4f99-bc5e-7c7e10b9d64e","type":"WheelZoomTool"},{"attributes":{},"id":"cdbbaad7-840d-4d76-a0fd-bc0be1b59800","type":"ToolEvents"},{"attributes":{},"id":"526e175f-9d91-469a-ae65-397fdbbec788","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["1.5em"]}},"id":"80b23950-9d4c-4b50-a0a5-fde913476b84","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"95e4abb3-b626-4f87-974a-7c9328080a66","type":"PanTool"},{"attributes":{"callback":null},"id":"9c13f52e-300c-456a-be94-2a2592fdfb0e","type":"DataRange1d"},{"attributes":{"plot":{"id":"428d04a6-8257-4769-be0e-cebb58905c7d","subtype":"Figure","type":"Plot"}},"id":"29b94c41-44f5-4ac0-9476-f7882b50291a","type":"HelpTool"},{"attributes":{},"id":"dc9e58bc-e201-4c13-9440-e2cc1a38d40e","type":"BasicTicker"},{"attributes":{"below": ...

# %%
# リスト7.5.3：フォントスタイルの設定
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 2.5))
p.text(0, 1, text=['italic'], text_font_style='italic')
p.text(0, 2, text=['bold'], text_font_style='bold')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="60e92a1f-0e48-4854-bc71-a0036bac54cd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("60e92a1f-0e48-4854-bc71-a0036bac54cd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("60e92a1f-0e48-4854-bc71-a0036bac54cd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '60e92a1f-0e48-4854-bc71-a0036bac54cd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4d77d661-619e-4c2d-919f-82bf875d5ff5":{"roots":{"references":[{"attributes":{"data_source":{"id":"09f0cb27-8410-4017-afb2-de9953a7c6d0","type":"ColumnDataSource"},"glyph":{"id":"1a4bf148-56e4-4f86-8b6a-25c44c022e96","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ae69996d-a3a6-45f0-bb5e-16147bbabd7a","type":"Text"},"selection_glyph":null},"id":"0f3c717a-1821-413b-b73e-890c353036c1","type":"GlyphRenderer"},{"attributes":{},"id":"423e64cb-d302-440a-a620-2c39fd750ba6","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"86f405f7-d74f-4420-8ca5-08a1295a6457","type":"PanTool"},{"id":"9c1055a9-7e43-4330-901c-8bc7eefb1c76","type":"WheelZoomTool"},{"id":"9e32b120-6f87-4b70-ba74-43ea945e45ea","type":"BoxZoomTool"},{"id":"7a46d97c-bc10-42b2-ab24-14416b501114","type":"SaveTool"},{"id":"ad039135-8222-462e-9b82-a65def804e11","type":"ResetTool"},{"id":"415a92a6-7940-4e39-bf58-2db123a0ae92","type":"HelpTool"}]},"id":"78cf4bfa-ae47-48c5-bb9b-20023c999eca","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"4996e884-8acc-4b5a-8a20-6ffd0d4f0408","subtype":"Figure","type":"Plot"},"ticker":{"id":"423e64cb-d302-440a-a620-2c39fd750ba6","type":"BasicTicker"}},"id":"a2f083d6-b7f6-46f3-adcd-d9e46dc76bf8","type":"Grid"},{"attributes":{"callback":null},"id":"54cd315c-d14d-4a9f-9b1e-1ba931b934d4","type":"DataRange1d"},{"attributes":{"text_color":{"value":"black"},"text_font_style":"italic","x":{"value":0},"y":{"value":1}},"id":"1a4bf148-56e4-4f86-8b6a-25c44c022e96","type":"Text"},{"attributes":{"plot":{"id":"4996e884-8acc-4b5a-8a20-6ffd0d4f0408","subtype":"Figure","type":"Plot"}},"id":"86f405f7-d74f-4420-8ca5-08a1295a6457","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"f5a34db0-7e30-44d3-90de-d444eea157ad","type":"Title"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["bold"]}},"id":"19d397ec-14b1-49aa-936b-6a69199eca8b","type":"ColumnDataSource"},{"attributes":{},"id":"4e690306-c22f-441c-a1b0-a7ad68baa0b7","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4996e884-8acc-4b5a-8a20-6ffd0d4f0408","subtype":"Figure","type":"Plot"}},"id":"7a46d97c-bc10-42b2-ab24-14416b501114","type":"SaveTool"},{"attributes":{},"id":"930f66bf-7f88-4914-b17b-b14c4bd024f2","type":"ToolEvents"},{"attributes":{"plot":{"id":"4996e884-8acc-4b5a-8a20-6ffd0d4f0408","subtype":"Figure","type":"Plot"}},"id":"9c1055a9-7e43-4330-901c-8bc7eefb1c76","type":"WheelZoomTool"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_style":"italic","x":{"value":0},"y":{"value":1}},"id":"ae69996d-a3a6-45f0-bb5e-16147bbabd7a","type":"Text"},{"attributes":{"overlay":{"id":"bcec41ad-ffa3-4bd1-88ab-a7c899907e88","type":"BoxAnnotation"},"plot":{"id":"4996e884-8acc-4b5a-8a20-6ffd0d4f0408","subtype":"Figure","type":"Plot"}},"id":"9e32b120-6f87-4b70-ba74-43ea945e45ea","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":2.5,"start":0.5},"id":"28643564-d60c-4155-9cea-acba8b788cf4","type":"Range1d"},{"attributes":{"below":[{"id":"7e234810-161e-4a9e-b0cd-7cb2a6e5ab68","type":"LinearAxis"}],"left":[{"id":"d79fb7cb-b257-4d95-8f50-37b378bb0ffa","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"7e234810-161e-4a9e-b0cd-7cb2a6e5ab68","type":"LinearAxis"},{"id":"c7072b17-a346-4146-b075-e2b8f6137a76","type":"Grid"},{"id":"d79fb7cb-b257-4d95-8f50-37b378bb0ffa","type":"LinearAxis"},{"id":"a2f083d6-b7f6-46f3-adcd-d9e46dc76bf8","type":"Grid"},{"id":"bcec41ad-ffa3-4bd1-88ab-a7c899907e88","type":"BoxAnnotation"},{"id":"0f3c717a-1821-413b-b73e-890c353036c1","type":"GlyphRenderer"},{"id":"d8eb8135-0a98-45ba-b623-3594eea3d230","type":"GlyphRenderer"}],"title":{"id":"f5a34db0-7e30-44d3-90de-d444eea157ad","type":"Title"},"tool_events":{"id":"930f66bf-7f88-4914-b17b-b14c4bd024f2","type":"ToolEvents"},"toolbar":{"id":"78cf4bfa-ae47-48c5-bb9b-20023c999eca","type":"Toolbar"},"x_range":{"id" ...

# %%
# リスト7.5.4：テキストの色の設定
p = figure(plot_width=200, plot_height=200, x_range=(-1, 2.7), y_range=(0.5, 2.5))
p.text(0, 2, text=['red'], text_color='red')
p.text(0, 1, text=['(0, 255, 0, 0.5)'], text_color=(0, 255, 0, 0.5))
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6d52ca99-94d0-4510-b24a-b656c9938441"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6d52ca99-94d0-4510-b24a-b656c9938441");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6d52ca99-94d0-4510-b24a-b656c9938441");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6d52ca99-94d0-4510-b24a-b656c9938441' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9aaec32d-9fd1-43a3-af91-6711aff04968":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"129d973b-2420-4cdc-beb8-da14c463f5ac","type":"Title"},{"attributes":{"plot":{"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Figure","type":"Plot"}},"id":"3869f4ec-41bf-4d1d-b4d0-e6c3f187ba47","type":"SaveTool"},{"attributes":{"below":[{"id":"08a25b72-b592-49c1-bf12-0c8cc56ae040","type":"LinearAxis"}],"left":[{"id":"5b660faa-83b5-42a3-b903-6c7f17b50262","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"08a25b72-b592-49c1-bf12-0c8cc56ae040","type":"LinearAxis"},{"id":"28b72c51-beb6-40b5-94c2-58596392e8f4","type":"Grid"},{"id":"5b660faa-83b5-42a3-b903-6c7f17b50262","type":"LinearAxis"},{"id":"54512bb8-b37a-40d5-84c1-148c403b2bab","type":"Grid"},{"id":"d032cd2a-6e5a-4d8e-9a4d-b193b8bd7533","type":"BoxAnnotation"},{"id":"6989cf6d-8806-488f-b289-19b207491ebf","type":"GlyphRenderer"},{"id":"5878c94f-757a-45b7-abe4-eac9a0adff85","type":"GlyphRenderer"}],"title":{"id":"129d973b-2420-4cdc-beb8-da14c463f5ac","type":"Title"},"tool_events":{"id":"0333faf2-34c3-47df-8f6a-f3ab8f579e0c","type":"ToolEvents"},"toolbar":{"id":"e81b11c7-7c11-43b3-99bb-d07e2fb0ee5a","type":"Toolbar"},"x_range":{"id":"9158c38e-21b0-46bb-9767-c5e5851be68d","type":"Range1d"},"y_range":{"id":"7f885292-34cc-44c8-9029-d1873741bf08","type":"Range1d"}},"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["red"]}},"id":"b0cdef8d-0e2d-4fee-928e-148df3b56a64","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c4564dfe-319f-42cc-825f-cce88fd7e4ca","type":"PanTool"},{"id":"c8de0112-5e46-4a04-b1b8-e735caee88e1","type":"WheelZoomTool"},{"id":"a9c607f8-d7c2-4623-bfc5-62c633ad01e9","type":"BoxZoomTool"},{"id":"3869f4ec-41bf-4d1d-b4d0-e6c3f187ba47","type":"SaveTool"},{"id":"abb47d52-0aeb-4c92-80ea-854e43ec3181","type":"ResetTool"},{"id":"ca491c30-f293-43f2-9297-8f354f8e0cc4","type":"HelpTool"}]},"id":"e81b11c7-7c11-43b3-99bb-d07e2fb0ee5a","type":"Toolbar"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":0},"y":{"value":2}},"id":"c0148a3e-0b78-453b-9835-1240282cd17f","type":"Text"},{"attributes":{},"id":"0333faf2-34c3-47df-8f6a-f3ab8f579e0c","type":"ToolEvents"},{"attributes":{"data_source":{"id":"b0cdef8d-0e2d-4fee-928e-148df3b56a64","type":"ColumnDataSource"},"glyph":{"id":"23705dcf-222e-4aa8-a67b-afec6ae7b95c","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c0148a3e-0b78-453b-9835-1240282cd17f","type":"Text"},"selection_glyph":null},"id":"6989cf6d-8806-488f-b289-19b207491ebf","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Figure","type":"Plot"}},"id":"ca491c30-f293-43f2-9297-8f354f8e0cc4","type":"HelpTool"},{"attributes":{},"id":"b42c3687-d082-4d70-84c0-e24297803ac0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Figure","type":"Plot"}},"id":"abb47d52-0aeb-4c92-80ea-854e43ec3181","type":"ResetTool"},{"attributes":{"plot":{"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Figure","type":"Plot"},"ticker":{"id":"5dcf7569-1a36-4d0d-9da5-53566530d265","type":"BasicTicker"}},"id":"28b72c51-beb6-40b5-94c2-58596392e8f4","type":"Grid"},{"attributes":{},"id":"5dcf7569-1a36-4d0d-9da5-53566530d265","type":"BasicTicker"},{"attributes":{"data_source":{"id":"25d6cb06-6378-4a29-accb-f63a00d67b13","type":"ColumnDataSource"},"glyph":{"id":"0f282483-f861-46eb-a79c-aeeb1261801b","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5da0e6a4-185d-4a37-92d5-835870af9671","type":"Text"},"selection_glyph":null},"id":"5878c94f-757a-45b7-abe4-eac9a0adff85","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9291dbdc-5b30-4806-b019-fa52ce4867ab","subtype":"Fig ...

# %%
# リスト7.5.5：テキストの位置の設定例
p = figure(plot_width=200, plot_height=200, y_range=(0.5, 3.5))
p.text(1, 3, text=['left'], text_align='left')
p.text(1, 2, text=['center'], text_align='center')
p.text(1, 1, text=['right'], text_align='right')
p.line([1, 1], [0.5, 3.5])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="104ca457-d938-4eee-a2f0-358a2f1059dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("104ca457-d938-4eee-a2f0-358a2f1059dc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("104ca457-d938-4eee-a2f0-358a2f1059dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '104ca457-d938-4eee-a2f0-358a2f1059dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0277c4ad-56b4-4f26-9078-5d92e42df020":{"roots":{"references":[{"attributes":{"text_align":"center","text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"a7238299-1a94-45dc-b59f-4b842aa72b3c","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["left"]}},"id":"78d03288-bb0d-4a32-a081-344cdaf84794","type":"ColumnDataSource"},{"attributes":{"text_align":"center","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1},"y":{"value":2}},"id":"42b4995a-b101-4510-ab0b-0ef12097bd49","type":"Text"},{"attributes":{"below":[{"id":"3a7c4a12-5378-4476-a743-cd8b49f95d6b","type":"LinearAxis"}],"left":[{"id":"3da1a585-c343-4591-93ac-b5522c33db2a","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"3a7c4a12-5378-4476-a743-cd8b49f95d6b","type":"LinearAxis"},{"id":"05779db6-af13-452e-a03a-1df87d926e79","type":"Grid"},{"id":"3da1a585-c343-4591-93ac-b5522c33db2a","type":"LinearAxis"},{"id":"781b57d8-0081-4973-a100-d0678315c63e","type":"Grid"},{"id":"5a7c43ad-60a0-42eb-a373-10bcc29ace40","type":"BoxAnnotation"},{"id":"d1a895c3-21fb-47c5-b967-1d752ff49b09","type":"GlyphRenderer"},{"id":"49d9dbc9-fc66-4383-9785-4cf855872446","type":"GlyphRenderer"},{"id":"8347abf4-e2b1-48c1-8732-6c34f17a3eeb","type":"GlyphRenderer"},{"id":"a0ea3bf5-958b-4cbc-b852-76a569c09641","type":"GlyphRenderer"}],"title":{"id":"6a5d88ff-dcc0-44a9-bf66-ec9a3069d1b4","type":"Title"},"tool_events":{"id":"b1eb0a22-7d0f-4936-ae96-4c5a8c03176f","type":"ToolEvents"},"toolbar":{"id":"b10ab4ef-2d71-45f3-a592-492d14a3bc44","type":"Toolbar"},"x_range":{"id":"4a138eae-7b50-454a-9ecf-215797f845b9","type":"DataRange1d"},"y_range":{"id":"ac4d6701-8c1b-445e-9ea1-cf341a072227","type":"Range1d"}},"id":"a2171910-6234-4e6d-abe8-debbc7c0f787","subtype":"Figure","type":"Plot"},{"attributes":{"text_align":"right","text_color":{"value":"black"},"x":{"value":1},"y":{"value":1}},"id":"fcdf7bd0-658c-4398-b049-1fabe12dcfa8","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["right"]}},"id":"2a8cdd01-7416-450b-91eb-1c7d7bdc1f0e","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c3c3c14c-2e72-4ff5-b9b2-b1d95bdb1de0","type":"ColumnDataSource"},"glyph":{"id":"917867e2-4b6b-42c7-b4ba-a232a664892b","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"59745bb1-0a1d-405a-9e75-fc6504163a41","type":"Line"},"selection_glyph":null},"id":"a0ea3bf5-958b-4cbc-b852-76a569c09641","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1dc4542c-a0fa-4e20-928b-4aa9727fb27d","type":"ColumnDataSource"},"glyph":{"id":"a7238299-1a94-45dc-b59f-4b842aa72b3c","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"42b4995a-b101-4510-ab0b-0ef12097bd49","type":"Text"},"selection_glyph":null},"id":"49d9dbc9-fc66-4383-9785-4cf855872446","type":"GlyphRenderer"},{"attributes":{"text_align":"right","text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1},"y":{"value":1}},"id":"723854ea-b09a-4bad-a226-ef6529597be3","type":"Text"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3d897f8f-122b-40a2-a668-16dce761f47a","type":"PanTool"},{"id":"19c89b11-1e02-4ec8-a92b-42857cc61de0","type":"WheelZoomTool"},{"id":"f8a779e8-442d-4b6d-b2aa-c3f3f28e19de","type":"BoxZoomTool"},{"id":"bf61f6cf-65bb-47b7-aae4-f3fb8f71d0dc","type":"SaveTool"},{"id":"986f83da-1b10-48ce-9950-15a014005787","type":"ResetTool"},{"id":"589697ab-4660-46de-af0d-cbb0522b0a16","type":"HelpTool"}]},"id":"b10ab4ef-2d71-45f3-a592-492d14a3bc44","type":"Toolbar"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"917867e2-4b6b-42c7-b4ba-a232a664892b","type":"Line"},{"attributes":{"callback":null},"id":"4a138eae-7b50-454a-9ecf-215797f845b9","type":"DataRange1d"},{"attributes":{"plot":{"id":"a2171910-6234-4e6d-abe8-debbc7c0f787","subtype":"Figure","type":"Plot"}}, ...

# %%
# リスト7.5.6：垂直揃えの設定
p = figure(plot_width=600, plot_height=200, x_range=(-0.5, 5))
baselines = ['top', 'middle', 'bottom', 'alphabetic', 'hanging']
for y, baseline in enumerate(baselines):
    p.text(y, 1, text=[baseline], text_baseline=baseline)
    p.line([-0.5, 10.5], [1, 1])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="92225c19-4480-41e0-acb2-2d72ce4d04b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("92225c19-4480-41e0-acb2-2d72ce4d04b0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("92225c19-4480-41e0-acb2-2d72ce4d04b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '92225c19-4480-41e0-acb2-2d72ce4d04b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"896f3ce6-cf7b-4fd6-ab10-63bd70a24930":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-0.5,10.5],"y":[1,1]}},"id":"80ebc52b-3b51-4354-8d5a-6739591f0a86","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[-0.5,10.5],"y":[1,1]}},"id":"79c8608d-35dd-4ff9-8383-eaf87d47c5d5","type":"ColumnDataSource"},{"attributes":{},"id":"0652ff91-4ca4-4c9d-a67a-fd218b983642","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"470aaea3-23fe-4846-a255-02913c905fc4","type":"ColumnDataSource"},"glyph":{"id":"25d76ae3-1244-4621-a1e0-31fa648799b7","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1decb9d9-f043-4920-b1c1-fb61cb082641","type":"Text"},"selection_glyph":null},"id":"3d0074ad-468b-463b-9426-49ceda80de23","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"e9d054b2-6066-45cc-975f-22bc2996085d","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6b58ca9-8732-4173-a1eb-5d212311d663","type":"BasicTicker"}},"id":"d0917fd5-354d-4162-8918-96bd6511b59a","type":"Grid"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":2},"y":{"value":1}},"id":"9d8f10e5-fad2-4602-8173-3671c6d20c4d","type":"Text"},{"attributes":{"data_source":{"id":"401c95af-5969-4f27-90cc-31f350f569c6","type":"ColumnDataSource"},"glyph":{"id":"366bed52-9e10-4d56-8906-55a832fc9257","type":"Text"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9d8f10e5-fad2-4602-8173-3671c6d20c4d","type":"Text"},"selection_glyph":null},"id":"cf14b5ce-4eae-4eb9-bf96-996e71a0d5fa","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_baseline":"alphabetic","text_color":{"value":"black"},"x":{"value":3},"y":{"value":1}},"id":"1decb9d9-f043-4920-b1c1-fb61cb082641","type":"Text"},{"attributes":{"callback":null,"column_names":["text"],"data":{"text":["middle"]}},"id":"dd95180b-4e2b-4488-9f44-12bf20c50cba","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c4c9ffe5-2313-4bd9-a7dd-3e4b5ba18a37","type":"BoxAnnotation"},{"attributes":{},"id":"f6b58ca9-8732-4173-a1eb-5d212311d663","type":"BasicTicker"},{"attributes":{"text_baseline":"alphabetic","text_color":{"value":"black"},"x":{"value":3},"y":{"value":1}},"id":"25d76ae3-1244-4621-a1e0-31fa648799b7","type":"Text"},{"attributes":{"plot":{"id":"e9d054b2-6066-45cc-975f-22bc2996085d","subtype":"Figure","type":"Plot"}},"id":"58578959-f84f-4fcd-bf43-a428d61d7ebd","type":"PanTool"},{"attributes":{"data_source":{"id":"a9c45aa1-bcce-47ea-99f4-5a721d2f3666","type":"ColumnDataSource"},"glyph":{"id":"72699780-9d93-4acb-b57a-54a3868178ee","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c115d63a-d089-4474-aab2-9171583f878c","type":"Line"},"selection_glyph":null},"id":"40948521-72fb-4078-9b5d-21132d36a227","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e9d054b2-6066-45cc-975f-22bc2996085d","subtype":"Figure","type":"Plot"}},"id":"66c27a78-a891-4f1b-9d73-58de16ebb7f3","type":"SaveTool"},{"attributes":{"text_baseline":"top","text_color":{"value":"black"},"x":{"value":0},"y":{"value":1}},"id":"7ef096e6-d09f-473c-98ff-21e9c7b95e5b","type":"Text"},{"attributes":{"plot":{"id":"e9d054b2-6066-45cc-975f-22bc2996085d","subtype":"Figure","type":"Plot"}},"id":"462edf93-7c75-47ef-9b20-dcbc111a2ddd","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d048e72b-24e0-43c3-acee-2d5f4afa0cdd","type":"Line"},{"attributes":{"plot":{"id":"e9d054b2-6066-45cc-975f-22bc2996085d","subtype":"Figure","type":"Plot"}},"id":"a5d36fd3-eee9 ...
