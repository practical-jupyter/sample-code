# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-7: 図形の調整

# %%
# リスト7.7.1：circleメソッドの例
from bokeh.plotting import figure

p = figure(plot_width=200, plot_height=200)
r = p.circle([0], [0])
print(r)
# Out:
# GlyphRenderer(id='1dc99c83-8ee5-4772-b2e1-abe2d4c0d013', ...)

# %%
# リスト7.7.3：図形の設定
from bokeh.io import output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
r = p.circle([0], [0])
r.glyph.size = 50
r.glyph.fill_color = "red"  # サイズ
r.glyph.fill_alpha = 0.5  # 塗りつぶしの不透明度
r.glyph.line_color = "black"  # 枠線の色
r.glyph.line_alpha = 0.5  # 枠線の不透明度
r.glyph.line_width = 3  # 枠線の太さ
r.glyph.line_dash = "dashed"  # 枠線の種類
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="75c5b757-4390-4455-8767-0e8efe1a5316">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="13496f99-a684-4a6f-850f-5beed9185fa8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("13496f99-a684-4a6f-850f-5beed9185fa8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13496f99-a684-4a6f-850f-5beed9185fa8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13496f99-a684-4a6f-850f-5beed9185fa8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4b91cd19-61ac-4082-b3ae-9861cca7e7bb":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ab3318ed-0ac6-4ad8-a59f-5fcca9d14ee7","type":"PanTool"},{"id":"09961f66-90a4-49db-9224-cba33c8a6d46","type":"WheelZoomTool"},{"id":"763271ba-1885-4d57-99c4-334f1139053a","type":"BoxZoomTool"},{"id":"fa029591-b457-4bc6-8050-26a71907f1d0","type":"SaveTool"},{"id":"a5caee9b-f80f-421c-8402-6e3587e1ecb3","type":"ResetTool"},{"id":"093b8dca-61c8-4d14-9fc2-03b1eb6068ba","type":"HelpTool"}]},"id":"8285be50-9433-44c0-84e8-59fcf81cda69","type":"Toolbar"},{"attributes":{"formatter":{"id":"6f639bb2-e592-4fda-915a-54cca90e14d0","type":"BasicTickFormatter"},"plot":{"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"592f4d00-8821-4ec2-ab5d-7e8c72eeda5c","type":"BasicTicker"}},"id":"4522c427-76fb-468e-bcc7-bc93950c2490","type":"LinearAxis"},{"attributes":{"plot":{"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"592f4d00-8821-4ec2-ab5d-7e8c72eeda5c","type":"BasicTicker"}},"id":"b08bb6e5-0761-42e7-9392-981b00065501","type":"Grid"},{"attributes":{"formatter":{"id":"491fa100-4df9-4809-8b02-9b319dbf1041","type":"BasicTickFormatter"},"plot":{"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"a94e49f8-4651-4b0c-8a71-913013413d9e","type":"BasicTicker"}},"id":"44f8c7b0-928f-41a5-b08f-a4cf953a83e9","type":"LinearAxis"},{"attributes":{},"id":"a94e49f8-4651-4b0c-8a71-913013413d9e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"},"ticker":{"id":"a94e49f8-4651-4b0c-8a71-913013413d9e","type":"BasicTicker"}},"id":"f59bcafc-a81f-4f0a-85ed-8109851a8072","type":"Grid"},{"attributes":{"data_source":{"id":"c05d7e43-cb52-490b-826f-61308439641c","type":"ColumnDataSource"},"glyph":{"id":"61245e28-061b-4e47-a5c0-41a5e399304d","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d751ac9a-7138-4154-8660-01d915aa3d45","type":"Circle"},"selection_glyph":null},"id":"3d60e996-98f7-4612-a671-ff19429e57cf","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cc31b725-2cf4-47eb-9223-639b5a516177","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":""},"id":"469695aa-f0fc-47a5-a194-a2b5a5d02f30","type":"Title"},{"attributes":{"plot":{"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"}},"id":"ab3318ed-0ac6-4ad8-a59f-5fcca9d14ee7","type":"PanTool"},{"attributes":{"below":[{"id":"4522c427-76fb-468e-bcc7-bc93950c2490","type":"LinearAxis"}],"left":[{"id":"44f8c7b0-928f-41a5-b08f-a4cf953a83e9","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"4522c427-76fb-468e-bcc7-bc93950c2490","type":"LinearAxis"},{"id":"b08bb6e5-0761-42e7-9392-981b00065501","type":"Grid"},{"id":"44f8c7b0-928f-41a5-b08f-a4cf953a83e9","type":"LinearAxis"},{"id":"f59bcafc-a81f-4f0a-85ed-8109851a8072","type":"Grid"},{"id":"cc31b725-2cf4-47eb-9223-639b5a516177","type":"BoxAnnotation"},{"id":"3d60e996-98f7-4612-a671-ff19429e57cf","type":"GlyphRenderer"}],"title":{"id":"469695aa-f0fc-47a5-a194-a2b5a5d02f30","type":"Title"},"tool_events":{"id":"522ed6ab-d7db-4a38-aca5-1fd0317fe973","type":"ToolEvents"},"toolbar":{"id":"8285be50-9433-44c0-84e8-59fcf81cda69","type":"Toolbar"},"x_range":{"id":"2cf91055-a393-487a-b35f-a75845780209","type":"DataRange1d"},"y_range":{"id":"5017b279-13d6-4725-aeb2-76c4082c3aa2","type":"DataRange1d"}},"id":"0587566c-6318-4e06-8235-1c96f62d79fb","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"491fa100-4df9-4809- ...

# %%
# リスト7.7.4：図形の選択
from bokeh.models import Circle, Square

p = figure(
    plot_width=200,
    plot_height=200,
    x_range=(-0.5, 2.5),
    y_range=(-0.5, 2.5),
    tools=["tap", "save"],
)
r1 = p.circle([0, 1, 2], [0, 1, 2], size=30)  # ①
r2 = p.square([0, 2], [2, 0], size=30)  # ②
r1.selection_glyph = Circle(fill_color="red")
r1.nonselection_glyph = Circle(fill_color="green")
r2.selection_glyph = Square(fill_color="orange")
r2.nonselection_glyph = Square(fill_color="pink")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68b3746b-9ec5-4da2-81e1-10befa0276db"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("68b3746b-9ec5-4da2-81e1-10befa0276db");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68b3746b-9ec5-4da2-81e1-10befa0276db");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68b3746b-9ec5-4da2-81e1-10befa0276db' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9755b159-b15b-4bc8-8029-c268a7e67d0d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,2],"y":[2,0]}},"id":"9a128341-49f7-44dd-bc35-3368c935c18a","type":"ColumnDataSource"},{"attributes":{"callback":null,"plot":{"id":"ee667f6b-c318-4aef-9b8f-0ece7432b04b","subtype":"Figure","type":"Plot"}},"id":"ad7ac0e1-e3ea-4de8-bb25-c02f5a35d1dc","type":"TapTool"},{"attributes":{"plot":null,"text":""},"id":"a73acc14-e5f5-4bdb-9e6d-56b16b9e2b9a","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2],"y":[0,1,2]}},"id":"90232d5e-e9b2-4f2a-bc99-2279a62a5dcc","type":"ColumnDataSource"},{"attributes":{},"id":"9836c16e-ec39-45b9-af6a-64da8af9d723","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"9a128341-49f7-44dd-bc35-3368c935c18a","type":"ColumnDataSource"},"glyph":{"id":"c31e488a-f87c-4a2a-ac80-a9f352171679","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"78a53e1f-0cf5-487f-bc1c-94baa86234d6","type":"Square"},"selection_glyph":{"id":"71baf1b2-68ff-41c3-a21d-b4bbe237ccaf","type":"Square"}},"id":"5b1859e4-fe69-4fda-8d4f-5747836ef255","type":"GlyphRenderer"},{"attributes":{},"id":"959a61ef-c711-4c45-9ff9-f2772642ae1e","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"c9849783-3fb2-45b1-ad43-a48590361352","type":"LinearAxis"}],"left":[{"id":"6c912288-5c17-4a38-924e-8ff387239fa6","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"c9849783-3fb2-45b1-ad43-a48590361352","type":"LinearAxis"},{"id":"05b65b01-4730-46f1-a615-9af81bdb766f","type":"Grid"},{"id":"6c912288-5c17-4a38-924e-8ff387239fa6","type":"LinearAxis"},{"id":"63acbe2f-bcfb-400b-9c6f-d70c731ccffc","type":"Grid"},{"id":"896abb6d-da01-4ee6-abcb-d7cfd6db9d14","type":"GlyphRenderer"},{"id":"5b1859e4-fe69-4fda-8d4f-5747836ef255","type":"GlyphRenderer"}],"title":{"id":"a73acc14-e5f5-4bdb-9e6d-56b16b9e2b9a","type":"Title"},"tool_events":{"id":"fc61af6c-4c22-4b73-b266-13c6692e56e1","type":"ToolEvents"},"toolbar":{"id":"050e25b0-be4d-457a-9348-04cfede6d10d","type":"Toolbar"},"x_range":{"id":"4160fc04-8412-4a72-bd71-b89c05d12ebe","type":"Range1d"},"y_range":{"id":"bf2e5882-cbbc-443a-abd7-7e27fb87cdb4","type":"Range1d"}},"id":"ee667f6b-c318-4aef-9b8f-0ece7432b04b","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"green"}},"id":"ecb6f690-8837-4eb0-be7a-3f72aac6cf97","type":"Circle"},{"attributes":{"fill_color":{"value":"red"}},"id":"484fad8f-eef9-4ec3-a550-00e634221c09","type":"Circle"},{"attributes":{},"id":"fc61af6c-4c22-4b73-b266-13c6692e56e1","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"pink"}},"id":"78a53e1f-0cf5-487f-bc1c-94baa86234d6","type":"Square"},{"attributes":{"data_source":{"id":"90232d5e-e9b2-4f2a-bc99-2279a62a5dcc","type":"ColumnDataSource"},"glyph":{"id":"6ebc448b-b400-4609-97b5-99a4c8b3a8b2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ecb6f690-8837-4eb0-be7a-3f72aac6cf97","type":"Circle"},"selection_glyph":{"id":"484fad8f-eef9-4ec3-a550-00e634221c09","type":"Circle"}},"id":"896abb6d-da01-4ee6-abcb-d7cfd6db9d14","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"c31e488a-f87c-4a2a-ac80-a9f352171679","type":"Square"},{"attributes":{},"id":"960aeb7d-8409-48e8-8bf3-ddff2fceb786","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"orange"}},"id":"71baf1b2-68ff-41c3-a21d-b4bbe237ccaf","type":"Square"},{"attributes":{"formatter":{"id":"959a61ef-c711-4c45-9ff9-f2772642ae1e","type":"BasicTickFormatter"},"plot":{"id":"ee667f6b-c318-4aef-9b8f-0ece7432b04b","subtype":"Figure","type":"Plot"},"ticker":{"id":"960aeb7d-8409-48e8-8bf3-ddff2fceb786","type":"BasicTicker"}},"id":"c9849783-3fb2-45b1-ad43-a48590361352","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto" ...
