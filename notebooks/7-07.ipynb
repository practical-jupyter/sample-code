# %%
# リスト7.7.1：circleメソッドの例
from bokeh.plotting import figure
p = figure(plot_width=200, plot_height=200)
r = p.circle([0], [0])
print(r)
# Out:
# GlyphRenderer(id='6d0c85be-cae6-4230-8c36-676d2a15a03d', ...)

# %%
# リスト7.7.3：図形の設定
from bokeh.io import output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
r = p.circle([0], [0])
r.glyph.size = 50
r.glyph.fill_color = 'red'   # サイズ
r.glyph.fill_alpha = 0.5   # 塗りつぶしの不透明度
r.glyph.line_color = 'black' # 枠線の色
r.glyph.line_alpha = 0.5 # 枠線の不透明度
r.glyph.line_width = 3   # 枠線の太さ
r.glyph.line_dash = 'dashed'   # 枠線の種類
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8669af34-dcba-4d59-acd2-4218ab99f4f2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0ac85dda-4e03-4639-ac61-3490f3f5cdfb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0ac85dda-4e03-4639-ac61-3490f3f5cdfb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0ac85dda-4e03-4639-ac61-3490f3f5cdfb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0ac85dda-4e03-4639-ac61-3490f3f5cdfb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cd1edd06-241d-4ae9-997c-437cc89d4784":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"dc42dc40-459a-4940-9fd5-663dbc8eba84","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"dc42dc40-459a-4940-9fd5-663dbc8eba84","type":"ColumnDataSource"},"glyph":{"id":"fcd61f8e-549a-456c-9771-511e57d3ef8a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"98e39b8c-6979-4937-bec0-bd7454ba889c","type":"Circle"},"selection_glyph":null},"id":"a074a938-b0a8-4ab3-9b08-34ff03389672","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"98e39b8c-6979-4937-bec0-bd7454ba889c","type":"Circle"},{"attributes":{},"id":"c6d11359-6fdf-4126-8e91-88c6738ef784","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"97eda872-c155-4c36-ae5a-13a47744ba52","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"be1a3592-3adf-44d7-8543-1cd723782fee","subtype":"Figure","type":"Plot"}},"id":"60f892f7-5556-4d91-9406-41659b445586","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"red"},"line_alpha":{"value":0.5},"line_color":{"value":"black"},"line_dash":[6],"line_width":{"value":3},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"fcd61f8e-549a-456c-9771-511e57d3ef8a","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"a01eb621-6035-4da9-9621-f76e8e5815a4","type":"Title"},{"attributes":{"callback":null},"id":"efb05b18-21fd-4ac6-af05-1d515f033f5e","type":"DataRange1d"},{"attributes":{"plot":{"id":"be1a3592-3adf-44d7-8543-1cd723782fee","subtype":"Figure","type":"Plot"}},"id":"ed8b69f6-e505-4685-9a4f-c2e0b7387821","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"97eda872-c155-4c36-ae5a-13a47744ba52","type":"BoxAnnotation"},"plot":{"id":"be1a3592-3adf-44d7-8543-1cd723782fee","subtype":"Figure","type":"Plot"}},"id":"ed59cdeb-b081-4055-9fa2-fbdff44a7b40","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"be1a3592-3adf-44d7-8543-1cd723782fee","subtype":"Figure","type":"Plot"}},"id":"fbf5783e-68b2-42b7-8d68-573fef755823","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"60f892f7-5556-4d91-9406-41659b445586","type":"PanTool"},{"id":"ed8b69f6-e505-4685-9a4f-c2e0b7387821","type":"WheelZoomTool"},{"id":"ed59cdeb-b081-4055-9fa2-fbdff44a7b40","type":"BoxZoomTool"},{"id":"fbf5783e-68b2-42b7-8d68-573fef755823","type":"SaveTool"},{"id":"1cd36caf-0454-437f-a784-b935ad06662a","type":"ResetTool"},{"id":"4aa082eb-a327-4814-85ab-3485f4ff023f","type":"HelpTool"}]},"id":"e3c9aac3-3f70-4b3d-9dd0-24eda5e1d5f1","type":"Toolbar"},{"attributes":{"plot":{"id":"be1a3592-3adf-44d7-8543-1cd723782fee","subtype":"Figure","type":"Plot"}},"id":"1cd36caf-0454-437f-a784-b935ad06662a","type":"ResetTool"},{"attributes":{"below":[{"id":"33eb11b3-77eb-4cf6-b350-8771618851ec","type":"LinearAxis"}],"left":[{"id":"3771f3e6-07f8-4f96-92dc-2357fc09f0a3","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"33eb11b3-77eb-4cf6-b350-8771618851ec","type":"LinearAxis"},{"id":"5d4627dc-6edf-4c79-b30d-4f97ca3aa708","type":"Grid"},{"id":"3771f3e6-07f8-4f96-92dc-2357fc09f0a3","type":"LinearAxis"},{"id":"5a3fb96a-b4eb-4fb0-a4f3-d0e9bca83dc7","type":"Grid"},{"id":"97eda872-c155-4c36-ae5a-13a47744ba52","type":"BoxAnnotation"},{"id":"a074a938-b0a8-4ab3-9b08-34ff03389672","type":"GlyphRenderer"}],"title":{"id":"a01eb621-6035-4da9-9621-f76e8e5815a4","type":"Title"},"tool_events":{"id":"e14f9eba- ...

# %%
# リスト7.7.4：図形の選択
from bokeh.models import Circle, Square
p = figure(plot_width=200, plot_height=200,
           x_range=(-0.5, 2.5), y_range=(-0.5, 2.5),
           tools=['tap', 'save'])
r1 = p.circle([0, 1, 2], [0, 1, 2], size=30)  # ①
r2 = p.square([0, 2], [2, 0], size=30)  # ②
r1.selection_glyph = Circle(fill_color='red')
r1.nonselection_glyph = Circle(fill_color='green')
r2.selection_glyph = Square(fill_color='orange')
r2.nonselection_glyph = Square(fill_color='pink')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a26c68cc-6fd7-48bc-9aef-0b905b691c2b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a26c68cc-6fd7-48bc-9aef-0b905b691c2b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a26c68cc-6fd7-48bc-9aef-0b905b691c2b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a26c68cc-6fd7-48bc-9aef-0b905b691c2b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"36d55843-434e-4da9-b73b-62d0c319c817":{"roots":{"references":[{"attributes":{},"id":"1078e6cc-0f96-47f5-a440-6e510d087c09","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"1078e6cc-0f96-47f5-a440-6e510d087c09","type":"BasicTickFormatter"},"plot":{"id":"c9e8af4c-2939-4d16-bff6-49a39d68cdfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b6568c1-eacd-4d2d-9855-a44800c4487c","type":"BasicTicker"}},"id":"cf76f65b-bf03-46a8-b683-8a3abdb5fc54","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"pink"}},"id":"db4a4426-2ac2-4b7f-af7e-e304c920cb90","type":"Square"},{"attributes":{"plot":{"id":"c9e8af4c-2939-4d16-bff6-49a39d68cdfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"15bd800b-9f59-414b-8451-88d7b25f57c6","type":"BasicTicker"}},"id":"229c6621-bab3-4cf4-9195-10b4136da60a","type":"Grid"},{"attributes":{},"id":"08da3154-c31e-4b49-8e1b-a9137192538a","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"green"}},"id":"aa4d8d2f-e536-4e54-a71c-5e461ac8c864","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1,2],"y":[0,1,2]}},"id":"9b178dd1-111a-4f24-9547-72daa7ea7d6d","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":""},"id":"a95b7f50-2dd8-4c22-99c4-14e4dab6254e","type":"Title"},{"attributes":{"plot":{"id":"c9e8af4c-2939-4d16-bff6-49a39d68cdfc","subtype":"Figure","type":"Plot"}},"id":"784f819c-ccbf-433b-9dce-a5bf34fb1070","type":"SaveTool"},{"attributes":{"below":[{"id":"759a8c89-d401-4989-b1a1-c69f2e84a283","type":"LinearAxis"}],"left":[{"id":"cf76f65b-bf03-46a8-b683-8a3abdb5fc54","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"759a8c89-d401-4989-b1a1-c69f2e84a283","type":"LinearAxis"},{"id":"229c6621-bab3-4cf4-9195-10b4136da60a","type":"Grid"},{"id":"cf76f65b-bf03-46a8-b683-8a3abdb5fc54","type":"LinearAxis"},{"id":"59a79699-bc0d-45d4-b28a-d50e2c2de198","type":"Grid"},{"id":"d641a66d-3ed3-4053-8c33-0ad57c85676f","type":"GlyphRenderer"},{"id":"3fe9ba9e-c7ff-4b0a-9e6d-9866bf73eaca","type":"GlyphRenderer"}],"title":{"id":"a95b7f50-2dd8-4c22-99c4-14e4dab6254e","type":"Title"},"tool_events":{"id":"0db88d3f-4884-49be-868a-68ec7f252027","type":"ToolEvents"},"toolbar":{"id":"01de8544-fdce-41ad-bdfa-e7cf7f3bb36f","type":"Toolbar"},"x_range":{"id":"2ab4af84-c5f6-45fb-b612-ebfb3a59a1c8","type":"Range1d"},"y_range":{"id":"7f3c624e-c2ae-4742-8598-471ee10e54ac","type":"Range1d"}},"id":"c9e8af4c-2939-4d16-bff6-49a39d68cdfc","subtype":"Figure","type":"Plot"},{"attributes":{"fill_color":{"value":"orange"}},"id":"76ccf108-6eb6-4511-9aa9-d62f858b9a11","type":"Square"},{"attributes":{"data_source":{"id":"df81bc17-b417-4962-bd60-d21ecaa90f77","type":"ColumnDataSource"},"glyph":{"id":"d0577a5f-80a2-4a4b-8d62-5f8b85a98c9e","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"db4a4426-2ac2-4b7f-af7e-e304c920cb90","type":"Square"},"selection_glyph":{"id":"76ccf108-6eb6-4511-9aa9-d62f858b9a11","type":"Square"}},"id":"3fe9ba9e-c7ff-4b0a-9e6d-9866bf73eaca","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"c9e8af4c-2939-4d16-bff6-49a39d68cdfc","subtype":"Figure","type":"Plot"}},"id":"b9dbe470-1b7e-421e-9d31-2889af58c2fc","type":"TapTool"},{"attributes":{},"id":"0db88d3f-4884-49be-868a-68ec7f252027","type":"ToolEvents"},{"attributes":{"data_source":{"id":"9b178dd1-111a-4f24-9547-72daa7ea7d6d","type":"ColumnDataSource"},"glyph":{"id":"299f2566-60ca-40b9-ad86-18551f023de8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"aa4d8d2f-e536-4e54-a71c-5e461ac8c864","type":"Circle"},"selection_glyph":{"id":"7f70dd40-a7d0-42af-ac72-585435aebdac","type":"Circle"}},"id":"d641a66d-3ed3-4053-8c33-0ad57c85676f","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":30},"x":{"field":"x"},"y":{"field":"y"}},"id":"299f2566-60ca-40b9-ad86-18551f023de8","type":"Circle"},{" ...
