# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-11: 凡例の調整

# %%
# リスト7.11.1：凡例の設定
from bokeh.plotting import figure, output_notebook, show

output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend="circle")
p.square([0, 1], [2, 2], legend="square")
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d96ef70b-640a-49e3-b128-5fbb60afb94e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="729541ce-e1d4-4b20-a601-69a6c90c4bbd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("729541ce-e1d4-4b20-a601-69a6c90c4bbd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("729541ce-e1d4-4b20-a601-69a6c90c4bbd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '729541ce-e1d4-4b20-a601-69a6c90c4bbd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e54a20b7-55b1-47f7-8f3e-ac392d9a6aaa":{"roots":{"references":[{"attributes":{},"id":"67a0705f-7d42-45e9-8796-a087343a917d","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"951d5c60-5ebe-4551-8ee0-09a4d5cd1628","type":"Square"},{"attributes":{"label":{"value":"square"},"renderers":[{"id":"1d992bd9-1ae0-4644-bedd-5e63281ba9c5","type":"GlyphRenderer"}]},"id":"efa3f127-0fca-46a3-8384-b9a245fb93ef","type":"LegendItem"},{"attributes":{"data_source":{"id":"06ba7810-fae4-451d-89ff-5dcc1573b52f","type":"ColumnDataSource"},"glyph":{"id":"951d5c60-5ebe-4551-8ee0-09a4d5cd1628","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"530f9019-8bce-455c-9560-7f79eb270642","type":"Square"},"selection_glyph":null},"id":"1d992bd9-1ae0-4644-bedd-5e63281ba9c5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"530f9019-8bce-455c-9560-7f79eb270642","type":"Square"},{"attributes":{"callback":null},"id":"f82f8a97-aeb7-49e3-8c4b-57b89b8780ad","type":"DataRange1d"},{"attributes":{},"id":"5c7930e3-3553-4c9b-af42-b79013304b65","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"f7ff53a0-8f4f-47cf-80a3-6a0584ba0b45","type":"DataRange1d"},{"attributes":{"formatter":{"id":"5c7930e3-3553-4c9b-af42-b79013304b65","type":"BasicTickFormatter"},"plot":{"id":"0c4aeae0-1bfe-46e5-a791-3f90a4a93834","subtype":"Figure","type":"Plot"},"ticker":{"id":"ccd28776-b9fe-4b93-9e81-bf518fc834c0","type":"BasicTicker"}},"id":"8795b647-e5fa-43e2-8dcd-df1d96d850a8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"3d81901b-aa81-4306-b400-d39985129550","type":"ColumnDataSource"},"glyph":{"id":"bf40ed77-0f0b-4edd-98cc-63c0ff74fb5b","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"18986d8c-5657-4169-8e95-31e5328e1e38","type":"Circle"},"selection_glyph":null},"id":"c4f0ab68-6712-4724-aefb-2a59a174de39","type":"GlyphRenderer"},{"attributes":{},"id":"ccd28776-b9fe-4b93-9e81-bf518fc834c0","type":"BasicTicker"},{"attributes":{"plot":{"id":"0c4aeae0-1bfe-46e5-a791-3f90a4a93834","subtype":"Figure","type":"Plot"},"ticker":{"id":"ccd28776-b9fe-4b93-9e81-bf518fc834c0","type":"BasicTicker"}},"id":"e3c47430-84a5-4e62-997d-5aa9c21ad9eb","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bf40ed77-0f0b-4edd-98cc-63c0ff74fb5b","type":"Circle"},{"attributes":{"formatter":{"id":"cbecc992-7a98-4e5f-9076-5b9c826b2901","type":"BasicTickFormatter"},"plot":{"id":"0c4aeae0-1bfe-46e5-a791-3f90a4a93834","subtype":"Figure","type":"Plot"},"ticker":{"id":"81c9b0dc-fc6a-4ede-9d49-e19cf5ca66a7","type":"BasicTicker"}},"id":"360b2dea-338b-4ff6-b1d1-f67c87129cb2","type":"LinearAxis"},{"attributes":{},"id":"cbecc992-7a98-4e5f-9076-5b9c826b2901","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"3d81901b-aa81-4306-b400-d39985129550","type":"ColumnDataSource"},{"attributes":{},"id":"81c9b0dc-fc6a-4ede-9d49-e19cf5ca66a7","type":"BasicTicker"},{"attributes":{"items":[{"id":"828184d2-f4bb-498c-962b-4bbec2dd0a43","type":"LegendItem"},{"id":"efa3f127-0fca-46a3-8384-b9a245fb93ef","type":"LegendItem"}],"plot":{"id":"0c4aeae0-1bfe-46e5-a791-3f90a4a93834","subtype":"Figure","type":"Plot"}},"id":"661380d2-8727-4a5d-8380-e9b12361a6e8","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"0c4aeae0-1bfe-46e5-a791-3f90a4a93834","subtype":"Figure","type":"Plot"},"ticker":{"id":"81c9b0dc-fc6a-4ede-9d49-e19cf5ca66a7","type":"BasicTicker"}},"id":"bb870db4-f113-4436-b206-2dc1e01d5fb8","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","le ...

# %%
# リスト7.11.2：凡例のテキストの書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend="circle")
p.legend.label_text_font = "times"
p.legend.label_text_font_size = "15pt"
p.legend.label_text_color = "red"
p.legend.label_text_font_style = "bold"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dd4770f3-72b3-4327-a6d7-e67b04efe295"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("dd4770f3-72b3-4327-a6d7-e67b04efe295");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dd4770f3-72b3-4327-a6d7-e67b04efe295");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dd4770f3-72b3-4327-a6d7-e67b04efe295' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f254b17d-94f6-48eb-80db-1ed7cd9ba703":{"roots":{"references":[{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"7e70034c-2488-4847-a1ce-9b23ff21f7f9","type":"GlyphRenderer"}]},"id":"7b972097-ec63-4a1e-9cbf-1d255f6a6d7e","type":"LegendItem"},{"attributes":{"plot":{"id":"638921ad-8555-4ecf-aa0b-8c0b206755f6","subtype":"Figure","type":"Plot"}},"id":"b20b2371-450f-41bf-a35e-78ff534a10f6","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b20b2371-450f-41bf-a35e-78ff534a10f6","type":"PanTool"},{"id":"e46f424d-4cbf-4d57-aa1b-3341f6ac236e","type":"WheelZoomTool"},{"id":"18037c7c-00da-4c06-bcf0-b68018b6eb6f","type":"BoxZoomTool"},{"id":"fc8944a7-f8c8-46fc-9f99-20a4410abb5f","type":"SaveTool"},{"id":"b5ea6c8b-dff8-4b09-bf14-5a7058f9021c","type":"ResetTool"},{"id":"c96663ab-776d-40ba-9368-3c3465103f49","type":"HelpTool"}]},"id":"6dc30c8e-dfb9-4564-ab5d-b07b423ea66e","type":"Toolbar"},{"attributes":{"data_source":{"id":"be75261a-4ed0-4399-b126-ebf816b3da33","type":"ColumnDataSource"},"glyph":{"id":"36dbfad1-9bcb-4075-b268-51c3898f24c2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"37930731-37b7-4fe8-8541-4ab7eb72de21","type":"Circle"},"selection_glyph":null},"id":"7e70034c-2488-4847-a1ce-9b23ff21f7f9","type":"GlyphRenderer"},{"attributes":{},"id":"1199c36c-d2bc-4c86-82db-106463964bac","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"be75261a-4ed0-4399-b126-ebf816b3da33","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"36dbfad1-9bcb-4075-b268-51c3898f24c2","type":"Circle"},{"attributes":{"formatter":{"id":"7d1d7480-b3e7-43cc-862f-b5a2a01ba0ba","type":"BasicTickFormatter"},"plot":{"id":"638921ad-8555-4ecf-aa0b-8c0b206755f6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac3247db-db71-4caa-8072-4695d05eecdd","type":"BasicTicker"}},"id":"69aaaa9e-9f90-4d07-a85d-974ee727ce94","type":"LinearAxis"},{"attributes":{"below":[{"id":"69aaaa9e-9f90-4d07-a85d-974ee727ce94","type":"LinearAxis"}],"left":[{"id":"57dae522-fe36-46d6-ae16-c22fa323bdfd","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"69aaaa9e-9f90-4d07-a85d-974ee727ce94","type":"LinearAxis"},{"id":"eaa10c3c-7e60-4a06-8912-998fbc2a1354","type":"Grid"},{"id":"57dae522-fe36-46d6-ae16-c22fa323bdfd","type":"LinearAxis"},{"id":"9f852152-05bf-4e4c-aa52-9974065a3d43","type":"Grid"},{"id":"7cc1646c-a92c-4004-b1e2-0124c363b876","type":"BoxAnnotation"},{"id":"2cfbee3d-4722-41a7-b7a4-f9027e80ec39","type":"Legend"},{"id":"7e70034c-2488-4847-a1ce-9b23ff21f7f9","type":"GlyphRenderer"}],"title":{"id":"c80e0e32-1b14-450f-9974-8f18e67f00bd","type":"Title"},"tool_events":{"id":"dd2e8c6c-66d0-4914-a259-b50abd67428f","type":"ToolEvents"},"toolbar":{"id":"6dc30c8e-dfb9-4564-ab5d-b07b423ea66e","type":"Toolbar"},"x_range":{"id":"ff4e10e4-4f0b-4d43-a4a5-4961224c733b","type":"DataRange1d"},"y_range":{"id":"c4c8dc33-c843-4233-99c1-994b404d7058","type":"DataRange1d"}},"id":"638921ad-8555-4ecf-aa0b-8c0b206755f6","subtype":"Figure","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7cc1646c-a92c-4004-b1e2-0124c363b876","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"638921ad-8555-4ecf-aa0b-8c0b206755f6","subtype":"Figure","type":"Plot"}},"id":"e46f424d-4cbf-4d57-aa1b-3341f6ac236e","type":"WheelZoomTool"},{"attributes":{"formatter":{"id":"1199c36c-d2bc-4c86-82db-106463964bac","type":"BasicTickFormatter"},"plot":{"id":"638921ad-8555-4ecf-aa0b-8c0b206755f6","subtype":"Figure","type":"Plot"},"ticker" ...

# %%
# リスト7.11.3：凡例の枠線の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend="circle")
p.legend.border_line_width = 3
p.legend.border_line_color = "red"
p.legend.border_line_alpha = 0.5
p.legend.border_line_dash = "dashed"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e3a025f6-ae8b-4cc3-930a-57628aa77e00"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e3a025f6-ae8b-4cc3-930a-57628aa77e00");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e3a025f6-ae8b-4cc3-930a-57628aa77e00");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e3a025f6-ae8b-4cc3-930a-57628aa77e00' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8062ba69-fefc-4a83-857f-ec100569152e":{"roots":{"references":[{"attributes":{"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"2cb67ef2-7c9a-4d91-890b-c0f80fd16aca","type":"ResetTool"},{"attributes":{"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"d31c16df-daed-4bed-9711-224abd1dc48d","type":"PanTool"},{"attributes":{"below":[{"id":"466c641e-df79-4c49-94a9-2ad1b985188b","type":"LinearAxis"}],"left":[{"id":"24ed9ff8-c4da-4a75-b29d-943fe6e1ab48","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"466c641e-df79-4c49-94a9-2ad1b985188b","type":"LinearAxis"},{"id":"99b098a5-2df1-4fd1-9b85-c8e6ea137c8e","type":"Grid"},{"id":"24ed9ff8-c4da-4a75-b29d-943fe6e1ab48","type":"LinearAxis"},{"id":"24d81559-5f1a-4091-8c58-81faf7578582","type":"Grid"},{"id":"56f81f98-be99-4720-a32f-dcbfdabfc52d","type":"BoxAnnotation"},{"id":"dc45d5b6-6299-4c82-b86c-a99cece8abae","type":"Legend"},{"id":"a17ce8b0-3ef1-41bc-bbc0-fe0e9eb0e56b","type":"GlyphRenderer"}],"title":{"id":"d0a169bc-7665-4019-9bb5-ce39a182421c","type":"Title"},"tool_events":{"id":"c0831601-dab8-4fed-872e-abae6ebaba79","type":"ToolEvents"},"toolbar":{"id":"8e10b166-07dc-4eb0-ba34-98746915185f","type":"Toolbar"},"x_range":{"id":"bec8e5d0-8290-4454-ab29-c0de165cefcb","type":"DataRange1d"},"y_range":{"id":"7a142d0b-6d87-480e-96fe-bb4593cc5fd8","type":"DataRange1d"}},"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"d958fa3a-8409-4cb9-ab0b-d7affe10f248","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"d0a169bc-7665-4019-9bb5-ce39a182421c","type":"Title"},{"attributes":{"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"9dbe786d-31c4-4fd5-83ec-5154ea475703","type":"HelpTool"},{"attributes":{"callback":null},"id":"bec8e5d0-8290-4454-ab29-c0de165cefcb","type":"DataRange1d"},{"attributes":{"border_line_color":{"value":"red"},"border_line_dash":[6],"border_line_width":{"value":3},"items":[{"id":"a27572ae-7f0b-4a78-ac01-e0ab0656a56c","type":"LegendItem"}],"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"dc45d5b6-6299-4c82-b86c-a99cece8abae","type":"Legend"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"280bd58a-f1c1-457c-8135-dbb25905f26b","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d31c16df-daed-4bed-9711-224abd1dc48d","type":"PanTool"},{"id":"579c414f-d8fa-4172-8681-f71a1e5b9240","type":"WheelZoomTool"},{"id":"01dad1aa-87ab-419a-bced-fec97ddea5cc","type":"BoxZoomTool"},{"id":"d958fa3a-8409-4cb9-ab0b-d7affe10f248","type":"SaveTool"},{"id":"2cb67ef2-7c9a-4d91-890b-c0f80fd16aca","type":"ResetTool"},{"id":"9dbe786d-31c4-4fd5-83ec-5154ea475703","type":"HelpTool"}]},"id":"8e10b166-07dc-4eb0-ba34-98746915185f","type":"Toolbar"},{"attributes":{"overlay":{"id":"56f81f98-be99-4720-a32f-dcbfdabfc52d","type":"BoxAnnotation"},"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"}},"id":"01dad1aa-87ab-419a-bced-fec97ddea5cc","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"7a142d0b-6d87-480e-96fe-bb4593cc5fd8","type":"DataRange1d"},{"attributes":{},"id":"0a8c06db-d974-4510-bb87-71ebb8a3a2e3","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"0d38327b-849e-4abd-b348-1c1fe2e55717","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"5831a04f-b89b-4f60-90f6-1fee9f876cf9","subtype":"Figure","type":"Plot"},"ticker":{"id":"e0e870da-28d0-4c21-aba7-157a1c5ff335","type":"BasicTicker"}},"id":"24d81559-5f1a-4091-8c58-81faf7578582","type":"Grid"},{"attributes":{"fill_alpha":{"value":0 ...

# %%
# リスト7.11.4：凡例の背景色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend="circle")
p.legend.background_fill_color = "red"
p.legend.background_fill_alpha = 0.5
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bfd2d099-a326-4de2-a5fb-bb185ddc8ab7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bfd2d099-a326-4de2-a5fb-bb185ddc8ab7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bfd2d099-a326-4de2-a5fb-bb185ddc8ab7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bfd2d099-a326-4de2-a5fb-bb185ddc8ab7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1f689e0a-0b78-4695-a67f-76d94bd38051":{"roots":{"references":[{"attributes":{"plot":{"id":"fa1d4ecd-cc97-4f08-aa0f-07517fbe0b95","subtype":"Figure","type":"Plot"}},"id":"90200825-b15b-4c04-8426-7f962dcc19c6","type":"HelpTool"},{"attributes":{},"id":"0c8611f0-5257-4a02-922f-27dd2c1600c7","type":"BasicTicker"},{"attributes":{"callback":null},"id":"b0b127a7-b76f-4b6e-a082-7d8d4e5b6918","type":"DataRange1d"},{"attributes":{"data_source":{"id":"01e9f22e-057f-4034-bd33-22148e9a1365","type":"ColumnDataSource"},"glyph":{"id":"3b124576-1c13-4f3f-9c8c-2d02f13b0bf8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d335fe67-87db-41d1-8def-1479d6acbe79","type":"Circle"},"selection_glyph":null},"id":"f95f03e9-d1ce-4a1e-8888-4fac43dd0bab","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"dade38fd-1727-4404-aba5-417c22854498","type":"DataRange1d"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"f95f03e9-d1ce-4a1e-8888-4fac43dd0bab","type":"GlyphRenderer"}]},"id":"48ad3f3f-f69d-48ca-a5d0-f2c20af515cc","type":"LegendItem"},{"attributes":{},"id":"5137ede1-b92c-4ff5-a93c-ff54cfc0eefd","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"1ca9524a-d5b2-4cca-be36-9ebfa41f65c9","type":"LinearAxis"}],"left":[{"id":"ac3df672-3fcc-4e26-b028-006a70d0c2e2","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"1ca9524a-d5b2-4cca-be36-9ebfa41f65c9","type":"LinearAxis"},{"id":"63699dd2-94a4-4311-9ad5-4859eb5eaf06","type":"Grid"},{"id":"ac3df672-3fcc-4e26-b028-006a70d0c2e2","type":"LinearAxis"},{"id":"0750a1d2-4aaa-4fb4-b125-ee61f8739080","type":"Grid"},{"id":"a09f68e4-653d-44cc-a5e5-65629e113696","type":"BoxAnnotation"},{"id":"f8d48680-2d2f-4dbc-bd68-0d0c9c720e47","type":"Legend"},{"id":"f95f03e9-d1ce-4a1e-8888-4fac43dd0bab","type":"GlyphRenderer"}],"title":{"id":"d1fba7f3-f947-49fa-bb1b-e8f694f2cd5b","type":"Title"},"tool_events":{"id":"5dc481c6-5fbf-4c6e-aaa0-4edb040c9a03","type":"ToolEvents"},"toolbar":{"id":"c1fc6239-abe8-4d9a-8a81-96d9d004edc5","type":"Toolbar"},"x_range":{"id":"b0b127a7-b76f-4b6e-a082-7d8d4e5b6918","type":"DataRange1d"},"y_range":{"id":"dade38fd-1727-4404-aba5-417c22854498","type":"DataRange1d"}},"id":"fa1d4ecd-cc97-4f08-aa0f-07517fbe0b95","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"a478fb85-beae-446a-8194-eed23a019772","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"a478fb85-beae-446a-8194-eed23a019772","type":"BasicTickFormatter"},"plot":{"id":"fa1d4ecd-cc97-4f08-aa0f-07517fbe0b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c8611f0-5257-4a02-922f-27dd2c1600c7","type":"BasicTicker"}},"id":"ac3df672-3fcc-4e26-b028-006a70d0c2e2","type":"LinearAxis"},{"attributes":{},"id":"d02ad6a2-feb9-437f-9680-4bbdf7639ee9","type":"BasicTicker"},{"attributes":{"plot":{"id":"fa1d4ecd-cc97-4f08-aa0f-07517fbe0b95","subtype":"Figure","type":"Plot"}},"id":"ebffc680-1441-4a74-b797-4a2ca9a09e34","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ebffc680-1441-4a74-b797-4a2ca9a09e34","type":"PanTool"},{"id":"ee0081f7-2f4d-4cd8-a482-a99eedadabe2","type":"WheelZoomTool"},{"id":"eb4b9361-130d-47eb-a93f-ecc82bf9dd0d","type":"BoxZoomTool"},{"id":"be7186b0-d867-4785-ade3-95b87eb8c6cd","type":"SaveTool"},{"id":"bb045426-e6e0-441b-add2-a9b47a2699ce","type":"ResetTool"},{"id":"90200825-b15b-4c04-8426-7f962dcc19c6","type":"HelpTool"}]},"id":"c1fc6239-abe8-4d9a-8a81-96d9d004edc5","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"01e9f22e-057f-4034-bd33-22148e9a1365","type":"ColumnDataSource"},{"attributes":{},"id":"5dc481c6-5fbf-4c6e-aaa0-4edb040c9a03","type":"ToolEvents"},{"attributes":{"formatter":{"id":"5137ede1-b92c-4ff5-a93c-ff54cfc0eefd","type":"BasicTickFormatter"},"plot":{"id":"fa1d4ecd-cc97-4f08-aa0f-07517fbe0b95","subtype":"Figure","type":"Plot"},"ticker":{"id":"d02ad6a2-feb9-437f-9680-4bbdf ...

# %%
# リスト7.11.5：凡例の位置の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend="circle")
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f734fdf5-d6ab-42d8-8428-5c1c0482af59"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f734fdf5-d6ab-42d8-8428-5c1c0482af59");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f734fdf5-d6ab-42d8-8428-5c1c0482af59");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f734fdf5-d6ab-42d8-8428-5c1c0482af59' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7f490b42-dc5d-43dc-8649-33ea324b68d4":{"roots":{"references":[{"attributes":{"data_source":{"id":"6309fe76-f5e6-4e15-aa19-0c3b00e3c1d7","type":"ColumnDataSource"},"glyph":{"id":"4a2e8eac-9b80-4d8d-8f58-87a3711d54bf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"583923b1-5a26-4736-b967-043081ad6dcb","type":"Circle"},"selection_glyph":null},"id":"41798b1f-19ad-4758-af1a-99e21572b8e4","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"ac8a9a2f-9fb7-449d-b6a8-72d31485ad58","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"583923b1-5a26-4736-b967-043081ad6dcb","type":"Circle"},{"attributes":{},"id":"ce119520-65fd-4935-80b9-4515c687bd5b","type":"BasicTicker"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"41798b1f-19ad-4758-af1a-99e21572b8e4","type":"GlyphRenderer"}]},"id":"0f07910a-9bef-4c08-a086-9ad8fd10bbbc","type":"LegendItem"},{"attributes":{},"id":"26b0a70b-5c76-43d9-abcd-110b16ef4b14","type":"ToolEvents"},{"attributes":{"items":[{"id":"0f07910a-9bef-4c08-a086-9ad8fd10bbbc","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"551ae2cd-d618-4580-8f42-4faa73a8a1d6","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce119520-65fd-4935-80b9-4515c687bd5b","type":"BasicTicker"}},"id":"ac6811da-f067-4a6a-95c3-fc1d6901f16f","type":"Grid"},{"attributes":{"overlay":{"id":"dc3bf90a-6767-41bf-97f0-b52955c9da14","type":"BoxAnnotation"},"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"941d923c-e9f3-44cf-aa35-d8d3853a8ad5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cc03043-288b-48d4-815d-1509ccb2fae9","type":"BasicTicker"}},"id":"e48be151-5535-481c-aa7d-f3ea3aa61b72","type":"Grid"},{"attributes":{"callback":null},"id":"5cb11db8-16cd-442e-8d15-8a32018e8913","type":"DataRange1d"},{"attributes":{},"id":"058a28c4-203a-46b2-96e2-b486789d8ea4","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"98463c8c-e718-4ffc-a16a-be5c0a8bea86","type":"WheelZoomTool"},{"attributes":{},"id":"3cc03043-288b-48d4-815d-1509ccb2fae9","type":"BasicTicker"},{"attributes":{"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"806081b3-6e18-40cf-bd7b-ee005ba7cbd4","type":"HelpTool"},{"attributes":{"formatter":{"id":"29083dd9-f9ca-46dc-b2a8-a9c2308c9aa8","type":"BasicTickFormatter"},"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"},"ticker":{"id":"ce119520-65fd-4935-80b9-4515c687bd5b","type":"BasicTicker"}},"id":"431483a5-7667-488a-8970-7270e5fa71c7","type":"LinearAxis"},{"attributes":{"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"9a43ff9c-3622-4661-9ccf-7f21a6d84567","type":"ResetTool"},{"attributes":{"plot":{"id":"cbe977e3-da1f-4d62-9df7-c971c71a0078","subtype":"Figure","type":"Plot"}},"id":"fe7d1c28-1c94-4aff-9715-8527ae508364","type":"SaveTool"},{"attributes":{},"id":"29083dd9-f9ca-46dc-b2a8-a9c2308c9aa8","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f2871ab2-6c70-45c6-aa87-7bde23a3fb55","type":"PanTool"},{"id":"98463c8c-e718-4ffc-a16a-be5c0a8bea86","type":"WheelZoomTool"},{"id":"941d923c-e9f3-44cf-aa35-d8d3853a8ad5","type":"BoxZoomTool"},{"id":"fe7d1c28-1c94-4aff-9715-8527ae508364","type":"SaveTool"},{"id":"9a43ff9c-3622-4661-9ccf-7f21a6d84567","type":"ResetTool"},{"id":"806081b3-6e18-40cf-bd7b-ee005ba7cbd4","type":"HelpTool"}]}, ...

# %%
# リスト7.11.6：レイアウトの設定
from bokeh.models import Legend

p = figure(plot_width=300, plot_height=200)
r = p.circle([0], [0])
legend = Legend(items=[("circle", [r])], location="bottom_left")
p.add_layout(legend, "left")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9b1fb176-1bcd-4d46-a96d-8adc12d3d495"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9b1fb176-1bcd-4d46-a96d-8adc12d3d495");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9b1fb176-1bcd-4d46-a96d-8adc12d3d495");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9b1fb176-1bcd-4d46-a96d-8adc12d3d495' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c7772177-8cf7-42db-a6aa-0a1eeaf654ff":{"roots":{"references":[{"attributes":{"below":[{"id":"78ec0f57-ffec-429f-9a26-3811b8902fba","type":"LinearAxis"}],"left":[{"id":"86689df0-a741-4aab-b557-1035ff259c5f","type":"LinearAxis"},{"id":"8fc2532b-25f9-4f23-994e-f4234a568f1e","type":"Legend"}],"plot_height":200,"plot_width":300,"renderers":[{"id":"78ec0f57-ffec-429f-9a26-3811b8902fba","type":"LinearAxis"},{"id":"79eb6d95-12c7-4987-80fb-8a6af17575c4","type":"Grid"},{"id":"86689df0-a741-4aab-b557-1035ff259c5f","type":"LinearAxis"},{"id":"2c241485-b4a6-414a-aa39-7cee248be5fc","type":"Grid"},{"id":"13d4c2dd-f15a-4723-ae66-62bb18d3ea0b","type":"BoxAnnotation"},{"id":"3e75b704-8206-49ff-8414-3202348de331","type":"GlyphRenderer"},{"id":"8fc2532b-25f9-4f23-994e-f4234a568f1e","type":"Legend"}],"title":{"id":"39b58008-68c8-42a1-a375-92e633740a8d","type":"Title"},"tool_events":{"id":"0808f3b4-21f7-4b4b-8ed3-c2e185e8c426","type":"ToolEvents"},"toolbar":{"id":"14d8e8a4-0ead-487b-8503-0426c3ebc044","type":"Toolbar"},"x_range":{"id":"ca009feb-c480-4a3e-9102-00255febfdc2","type":"DataRange1d"},"y_range":{"id":"16e2bf8c-a4f4-4de2-b4ee-954064072b17","type":"DataRange1d"}},"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"515e099d-0329-4b92-ae1b-ce6ff6a40c39","type":"ColumnDataSource"},"glyph":{"id":"68544e76-321e-4273-b655-dd94073055bf","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e5924c3e-1990-4f1e-b0d7-8acc288ff51e","type":"Circle"},"selection_glyph":null},"id":"3e75b704-8206-49ff-8414-3202348de331","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"13d4c2dd-f15a-4723-ae66-62bb18d3ea0b","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"},"ticker":{"id":"80524393-4aaa-4242-90b7-80acba936a34","type":"BasicTicker"}},"id":"2c241485-b4a6-414a-aa39-7cee248be5fc","type":"Grid"},{"attributes":{},"id":"0f8a7d56-5d30-4ca3-aaa8-888f2d03afe7","type":"BasicTicker"},{"attributes":{"callback":null},"id":"ca009feb-c480-4a3e-9102-00255febfdc2","type":"DataRange1d"},{"attributes":{"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"}},"id":"90d91d37-0395-45dc-9a83-c44dfdc0d817","type":"HelpTool"},{"attributes":{},"id":"553d0949-12fa-4ea2-bb60-06ac76897007","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"}},"id":"51d38680-84d4-48a6-9095-4a78554ce799","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"68544e76-321e-4273-b655-dd94073055bf","type":"Circle"},{"attributes":{"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"}},"id":"ce68ce49-8f21-4708-8e8a-ea88b9f67b8b","type":"ResetTool"},{"attributes":{"formatter":{"id":"0d927f25-2922-4bf5-a885-4b90515bc990","type":"BasicTickFormatter"},"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f8a7d56-5d30-4ca3-aaa8-888f2d03afe7","type":"BasicTicker"}},"id":"78ec0f57-ffec-429f-9a26-3811b8902fba","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e5924c3e-1990-4f1e-b0d7-8acc288ff51e","type":"Circle"},{"attributes":{"plot":{"id":"464f0a12-ef83-479b-9609-501996077660","subtype":"Figure","type":"Plot"}},"id":"0ce33aaa-f31d-4bbc-8894-f80e1da3fc93","type":"SaveTool"},{"attributes":{"label":{"value ...

# %%
# リスト7.11.7：orientationの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend="circle")
p.square([0, 1], [2, 2], legend="square")
p.legend.orientation = "horizontal"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c15b720a-55f4-4447-990e-380a708ea055"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c15b720a-55f4-4447-990e-380a708ea055");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c15b720a-55f4-4447-990e-380a708ea055");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c15b720a-55f4-4447-990e-380a708ea055' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f239bbcf-9f27-4ee2-b248-15032d154341":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7ceb81b-6be0-4d4b-aa40-96b2c87d1541","type":"BasicTicker"}},"id":"18d68c6d-0546-43a7-bcc0-8e459b114899","type":"Grid"},{"attributes":{"data_source":{"id":"41cd20eb-fe63-4d4c-b006-71ace85b6e56","type":"ColumnDataSource"},"glyph":{"id":"515dc407-119a-47b6-959c-7da72ae418a9","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ee61fd47-0398-4e20-94c8-f76621216ebe","type":"Square"},"selection_glyph":null},"id":"3591e71e-c019-476c-a8c9-eddf8d28303b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ee61fd47-0398-4e20-94c8-f76621216ebe","type":"Square"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"43727ad6-d6de-4ab9-a413-24c9ed5dea57","type":"GlyphRenderer"}]},"id":"823fe8d5-23c2-43fd-8920-096f55647a99","type":"LegendItem"},{"attributes":{},"id":"f1bb2994-651d-463f-8ae5-9d57bed161dd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"}},"id":"9e8945ce-7840-4cb3-bd42-ed3aeb45e0d4","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"1f6c54de-74b6-418d-85ba-88a1909321a6","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"}},"id":"df4febc3-e603-431d-9c5d-62d22963052e","type":"ResetTool"},{"attributes":{"below":[{"id":"1c539327-2ac9-40e2-b1da-cb3fadfa75dd","type":"LinearAxis"}],"left":[{"id":"901f30c1-a067-48bd-87cc-ee04b9bcb069","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"1c539327-2ac9-40e2-b1da-cb3fadfa75dd","type":"LinearAxis"},{"id":"2f67b532-22bd-4fca-a652-e9750130c3f7","type":"Grid"},{"id":"901f30c1-a067-48bd-87cc-ee04b9bcb069","type":"LinearAxis"},{"id":"18d68c6d-0546-43a7-bcc0-8e459b114899","type":"Grid"},{"id":"1af83355-8c43-4f3d-a2d6-e384244cf0d3","type":"BoxAnnotation"},{"id":"835acf4f-40e7-4a3d-ab8f-be310163170c","type":"Legend"},{"id":"43727ad6-d6de-4ab9-a413-24c9ed5dea57","type":"GlyphRenderer"},{"id":"3591e71e-c019-476c-a8c9-eddf8d28303b","type":"GlyphRenderer"}],"title":{"id":"6506d555-cf9f-4121-9820-610a0b204381","type":"Title"},"tool_events":{"id":"cd43da36-6789-43c7-b65d-9aa0e1127212","type":"ToolEvents"},"toolbar":{"id":"12ff89dc-aa25-4334-9092-b250b0ab725d","type":"Toolbar"},"x_range":{"id":"c6e23466-78d0-4fed-9ea8-5d38ef1e8998","type":"DataRange1d"},"y_range":{"id":"1ac91cc6-92f2-4100-bdd1-8d9b073c9c03","type":"DataRange1d"}},"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"}},"id":"c73eca11-b00b-4c73-ad3e-e05f6bdb31d7","type":"PanTool"},{"attributes":{"formatter":{"id":"f1bb2994-651d-463f-8ae5-9d57bed161dd","type":"BasicTickFormatter"},"plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"},"ticker":{"id":"ad8f398b-826b-4e93-992c-471c4baab6a2","type":"BasicTicker"}},"id":"1c539327-2ac9-40e2-b1da-cb3fadfa75dd","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f8391eb7-f3e6-43e1-9028-8083cb09048a","type":"Circle"},{"attributes":{"items":[{"id":"823fe8d5-23c2-43fd-8920-096f55647a99","type":"LegendItem"},{"id":"80e4c305-155e-40e6-9aa9-1e7d73bc5e24","type":"LegendItem"}],"orientation":"horizontal","plot":{"id":"9788bbab-7b51-450f-935e-886ba70de19e","subtype":"Figure","type":"Plot"}},"id":"835acf4f-40e7-4a3d-ab8f-be310163170c","type":"Legend"},{"attributes":{"data_source":{"id":"1f6c54de-74b6-418d-85ba-88a1909321a6","t ...

# %%
# リスト7.11.8：凡例の調整
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend="circle")
p.square([0, 1], [2, 2], legend="square")
p.legend.border_line_color = "black"
p.legend.location = "center"
p.legend.spacing = 15
p.legend.padding = 20
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7e1d47c3-69db-484a-947c-3f034be39687"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7e1d47c3-69db-484a-947c-3f034be39687");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7e1d47c3-69db-484a-947c-3f034be39687");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7e1d47c3-69db-484a-947c-3f034be39687' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d57ba299-15f1-403e-9117-f577a3c189af":{"roots":{"references":[{"attributes":{},"id":"a60c6013-acca-457f-bf5e-f946d3ce9178","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"9e3e7a40-7eb0-4f00-b529-5f5a2c4f021f","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"fd44541c-16f9-40a6-a1d1-dff5f7a318d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"a60c6013-acca-457f-bf5e-f946d3ce9178","type":"BasicTicker"}},"id":"1345365b-93b3-40d6-8dd7-d8e1adb124c4","type":"Grid"},{"attributes":{"formatter":{"id":"0ea48faa-7446-4d77-b77a-ec438f6ace79","type":"BasicTickFormatter"},"plot":{"id":"fd44541c-16f9-40a6-a1d1-dff5f7a318d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"a60c6013-acca-457f-bf5e-f946d3ce9178","type":"BasicTicker"}},"id":"e5bd8329-4a4a-45f4-97d3-51a90513a4c3","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"98afc641-3eb9-4f9c-be93-bc54128dcabd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"98afc641-3eb9-4f9c-be93-bc54128dcabd","type":"ColumnDataSource"},"glyph":{"id":"ced04b27-84b1-42cf-9057-cdb9205f362f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8c530aa3-2799-41b7-8185-e6b18f430f69","type":"Circle"},"selection_glyph":null},"id":"954bb6a0-1118-42e6-aa31-6562ad914307","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"2b314c55-8327-41a7-9d7c-5f5c852d5668","type":"BasicTickFormatter"},"plot":{"id":"fd44541c-16f9-40a6-a1d1-dff5f7a318d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"6e52bc71-e010-4abd-ad8c-dfa079d3a5ec","type":"BasicTicker"}},"id":"e2ad63d0-1bdb-475a-b679-9a591f120701","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3f669293-ab9c-443b-8688-7e68dea83bce","type":"PanTool"},{"id":"3c17137c-a462-4205-a8eb-4c1187dd07a4","type":"WheelZoomTool"},{"id":"2f538873-9108-4c97-a02c-9fd7e0fa946c","type":"BoxZoomTool"},{"id":"10088d95-6c89-43c0-a309-6a7ee0903a84","type":"SaveTool"},{"id":"84274177-9b1f-4490-8f25-3b415457bf11","type":"ResetTool"},{"id":"c4d82203-4908-4443-a4e3-6691b4a61a09","type":"HelpTool"}]},"id":"e3c79d49-123e-4c29-863e-93cf6afcd53c","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4120ef89-f5bf-4ae6-a6ac-a99740b412ae","type":"Square"},{"attributes":{},"id":"fb58fe31-1a2a-4bea-8446-d13ed83a3133","type":"ToolEvents"},{"attributes":{"label":{"value":"square"},"renderers":[{"id":"f2e20221-df77-4b21-93db-75595bb7c761","type":"GlyphRenderer"}]},"id":"e6a98d9c-1adf-44db-8f98-8f9ca6b8024b","type":"LegendItem"},{"attributes":{"callback":null},"id":"049dc849-a039-4648-9df5-b5ecb8a69399","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"053029f6-c4fd-48e9-8839-a60ea4b567cd","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"c6b8da60-4352-4405-9ab2-f51f83d98fa4","type":"ColumnDataSource"},"glyph":{"id":"e207b0ae-6889-4350-94c2-ec94d61eec66","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4120ef89-f5bf-4ae6-a6ac-a99740b412ae","type":"Square"},"selection_glyph":null},"id":"f2e20221-df77-4b21-93db-75595bb7c761","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"e2ad63d0-1bdb-475a-b679-9a591f120701","type":"LinearAxis"}],"left":[{"id":"e5bd8329-4a4a-45f4-97d3-51a90513a4c3","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"e2ad63d0-1bdb-475a-b679-9a591f120701","type":"LinearAxis"},{"id":"052085a1-0681-4c69-ac5d-29196ed5d64e","type":"Grid"},{"id":"e5bd8329-4a ...
