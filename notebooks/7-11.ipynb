# %%
# リスト7.11.1：凡例の設定
from bokeh.plotting import figure, output_notebook, show
output_notebook()
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend='circle')
p.square([0, 1], [2, 2], legend='square')
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d3e698d1-7437-41dd-83a4-4c0117865069">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3dc7e2d-6d4b-4cb1-a741-96f9906bb134"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a3dc7e2d-6d4b-4cb1-a741-96f9906bb134");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3dc7e2d-6d4b-4cb1-a741-96f9906bb134");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3dc7e2d-6d4b-4cb1-a741-96f9906bb134' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d28f58b-dc48-4f32-be0c-5b888f26a825":{"roots":{"references":[{"attributes":{},"id":"07d68932-fd12-4df7-b471-f0217039e2fd","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"05936073-8f1a-4307-8ed1-2e3a4ba32bd9","type":"GlyphRenderer"}]},"id":"56191eb3-5e96-4235-90f3-1c9a921494ef","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"bf73548b-33dc-4320-a46b-3d8002644722","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"ec0825a9-d821-42f7-ac7d-9e1f08121391","type":"LinearAxis"}],"left":[{"id":"27090795-ed63-4e60-b2c6-e95d9f0913ab","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"ec0825a9-d821-42f7-ac7d-9e1f08121391","type":"LinearAxis"},{"id":"ed2ef98c-c276-48cc-b9b7-722dfdd2f891","type":"Grid"},{"id":"27090795-ed63-4e60-b2c6-e95d9f0913ab","type":"LinearAxis"},{"id":"3b99f226-892e-49bf-bf43-330535f0d5f9","type":"Grid"},{"id":"75e832d4-f166-445d-827c-21f04d59a59f","type":"BoxAnnotation"},{"id":"f9689544-e1d4-4916-9e71-fb2029b22d31","type":"Legend"},{"id":"05936073-8f1a-4307-8ed1-2e3a4ba32bd9","type":"GlyphRenderer"},{"id":"7c0838fa-4105-44df-9ed4-6fd6189de1c2","type":"GlyphRenderer"}],"title":{"id":"66e2c08c-9cf7-4421-b134-428230a1797e","type":"Title"},"tool_events":{"id":"dce9b762-6797-4b11-bdbd-3ebedb54e878","type":"ToolEvents"},"toolbar":{"id":"b81e1f1b-6c42-4b45-8b93-569dd133bbf9","type":"Toolbar"},"x_range":{"id":"d209a658-9997-46b2-be1b-d83991760beb","type":"DataRange1d"},"y_range":{"id":"2636173c-908e-44f5-a584-d42e5fb2d82d","type":"DataRange1d"}},"id":"43136405-f9aa-47d4-8024-76e455309508","subtype":"Figure","type":"Plot"},{"attributes":{"label":{"value":"square"},"renderers":[{"id":"7c0838fa-4105-44df-9ed4-6fd6189de1c2","type":"GlyphRenderer"}]},"id":"0f9cb585-eb0e-4c04-9b7c-abcfae36f06b","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6454579b-5e4e-49a1-883a-dc842cbd8d2d","type":"Square"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5b145352-0b71-45f0-9c2b-8e9ee3d91f97","type":"Square"},{"attributes":{"data_source":{"id":"61a570a8-478f-47aa-bc93-dff9fb063cf6","type":"ColumnDataSource"},"glyph":{"id":"5b145352-0b71-45f0-9c2b-8e9ee3d91f97","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"6454579b-5e4e-49a1-883a-dc842cbd8d2d","type":"Square"},"selection_glyph":null},"id":"7c0838fa-4105-44df-9ed4-6fd6189de1c2","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"d209a658-9997-46b2-be1b-d83991760beb","type":"DataRange1d"},{"attributes":{"items":[{"id":"56191eb3-5e96-4235-90f3-1c9a921494ef","type":"LegendItem"},{"id":"0f9cb585-eb0e-4c04-9b7c-abcfae36f06b","type":"LegendItem"}],"plot":{"id":"43136405-f9aa-47d4-8024-76e455309508","subtype":"Figure","type":"Plot"}},"id":"f9689544-e1d4-4916-9e71-fb2029b22d31","type":"Legend"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4b63220b-f0de-44e3-9e15-7a09d42208d4","type":"Circle"},{"attributes":{"callback":null},"id":"2636173c-908e-44f5-a584-d42e5fb2d82d","type":"DataRange1d"},{"attributes":{"formatter":{"id":"07d68932-fd12-4df7-b471-f0217039e2fd","type":"BasicTickFormatter"},"plot":{"id":"43136405-f9aa-47d4-8024-76e455309508","subtype":"Figure","type":"Plot"},"ticker":{"id":"4def040a-91d5-45ef-be78-23125b9bd0e8","type":"BasicTicker"}},"id":"ec0825a9-d821-42f7-ac7d-9e1f08121391","type":"LinearAxis"},{"attributes":{},"id":"4def040a-91d5-45ef-be78-23125b9bd0e8","type":"BasicTicker"},{"attributes":{"plot":{"id":"43136405-f9aa-47d4-8024-76e455309508","subtype":"Figure","type":"Plot"},"ticker":{"id":"4def040a-91d5-45ef-be78-23125b9bd0e8","type":"BasicTicker"}},"id":"ed2ef98c-c276-48 ...

# %%
# リスト7.11.2：凡例のテキストの書式設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend='circle')
p.legend.label_text_font = 'times'
p.legend.label_text_font_size = '15pt'
p.legend.label_text_color = 'red'
p.legend.label_text_font_style = 'bold'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="927bd15d-8d03-4500-be4e-a830de8e6b3f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("927bd15d-8d03-4500-be4e-a830de8e6b3f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("927bd15d-8d03-4500-be4e-a830de8e6b3f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '927bd15d-8d03-4500-be4e-a830de8e6b3f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b98658ff-9d47-4ab9-9194-64895417f754":{"roots":{"references":[{"attributes":{},"id":"b7ba07f1-c28a-45e7-9f80-913a21b4c7b2","type":"BasicTicker"},{"attributes":{"plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7ba07f1-c28a-45e7-9f80-913a21b4c7b2","type":"BasicTicker"}},"id":"d01762ea-e0f9-4961-b914-0921c0a7ec73","type":"Grid"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"b0da91bf-41f5-497c-8409-833f5482b6de","type":"GlyphRenderer"}]},"id":"fc5d4838-2b28-4c7c-b57c-5b8d473ec984","type":"LegendItem"},{"attributes":{"below":[{"id":"2f8970c8-e4dd-49e9-a01a-91ab1b8aaf32","type":"LinearAxis"}],"left":[{"id":"dee12426-7b51-4f87-ad2a-15b63cd56a4d","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"2f8970c8-e4dd-49e9-a01a-91ab1b8aaf32","type":"LinearAxis"},{"id":"d01762ea-e0f9-4961-b914-0921c0a7ec73","type":"Grid"},{"id":"dee12426-7b51-4f87-ad2a-15b63cd56a4d","type":"LinearAxis"},{"id":"01945429-e975-4824-a0a4-20988aa85dab","type":"Grid"},{"id":"6232993f-dbf2-4ddc-ad78-bd6749e764a0","type":"BoxAnnotation"},{"id":"b7bcc654-11b6-44c6-a2b9-2c058b796b40","type":"Legend"},{"id":"b0da91bf-41f5-497c-8409-833f5482b6de","type":"GlyphRenderer"}],"title":{"id":"9cb67c1c-d875-44f6-9fd9-376c15aab3cc","type":"Title"},"tool_events":{"id":"8ebb1c85-a672-4d09-b199-53b3aee79857","type":"ToolEvents"},"toolbar":{"id":"17f76e58-c412-416a-b349-94b373fbeb55","type":"Toolbar"},"x_range":{"id":"98bb69d8-c152-495c-b5b8-0f6d5b5f7c0f","type":"DataRange1d"},"y_range":{"id":"fdce1a99-68c8-4d27-9e62-307d51b5e5a9","type":"DataRange1d"}},"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"},{"attributes":{"items":[{"id":"fc5d4838-2b28-4c7c-b57c-5b8d473ec984","type":"LegendItem"}],"label_text_color":{"value":"red"},"label_text_font":"times","label_text_font_size":{"value":"15pt"},"label_text_font_style":"bold","plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"}},"id":"b7bcc654-11b6-44c6-a2b9-2c058b796b40","type":"Legend"},{"attributes":{"callback":null},"id":"fdce1a99-68c8-4d27-9e62-307d51b5e5a9","type":"DataRange1d"},{"attributes":{"plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"}},"id":"ed1c80ab-9415-4adb-8ff0-095a4b07fe9b","type":"HelpTool"},{"attributes":{"data_source":{"id":"158459c7-7565-4f96-851e-67b3559488b9","type":"ColumnDataSource"},"glyph":{"id":"81347321-8d6c-45ed-be34-798c27afbbe8","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"11494efd-4847-44b2-aace-8595b630c4ae","type":"Circle"},"selection_glyph":null},"id":"b0da91bf-41f5-497c-8409-833f5482b6de","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"}},"id":"8d5f94a0-24bf-4148-ba2b-e3db56e386ae","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d7f15047-dfd4-4940-84c1-25dc7edfbb91","type":"PanTool"},{"id":"6f56f9c5-21ea-464b-b655-38fabe12fb88","type":"WheelZoomTool"},{"id":"78e7248f-578f-47ed-b385-b6a9792947ce","type":"BoxZoomTool"},{"id":"8d5f94a0-24bf-4148-ba2b-e3db56e386ae","type":"SaveTool"},{"id":"0f08b5b4-73a1-4e7e-b610-8e591fe31cc8","type":"ResetTool"},{"id":"ed1c80ab-9415-4adb-8ff0-095a4b07fe9b","type":"HelpTool"}]},"id":"17f76e58-c412-416a-b349-94b373fbeb55","type":"Toolbar"},{"attributes":{"callback":null},"id":"98bb69d8-c152-495c-b5b8-0f6d5b5f7c0f","type":"DataRange1d"},{"attributes":{"plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"}},"id":"0f08b5b4-73a1-4e7e-b610-8e591fe31cc8","type":"ResetTool"},{"attributes":{},"id":"8ebb1c85-a672-4d09-b199-53b3aee79857","type":"ToolEvents"},{"attributes":{"overlay":{"id":"6232993f-dbf2-4ddc-ad78-bd6749e764a0","type":"BoxAnnotation"},"plot":{"id":"5c5df62d-862a-4075-bed8-5a40aafd08c1","subtype":"Figure","type":"Plot"}},"id":"78e7248f-578f-4 ...

# %%
# リスト7.11.3：凡例の枠線の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend='circle')
p.legend.border_line_width = 3
p.legend.border_line_color = 'red'
p.legend.border_line_alpha = 0.5
p.legend.border_line_dash = 'dashed'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b20a309a-a0eb-4258-b2d5-5320015b7857"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b20a309a-a0eb-4258-b2d5-5320015b7857");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b20a309a-a0eb-4258-b2d5-5320015b7857");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b20a309a-a0eb-4258-b2d5-5320015b7857' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"04da2178-f373-458f-b6b6-7c652c517fad":{"roots":{"references":[{"attributes":{"below":[{"id":"eac0edb2-ff1f-4de0-95fe-f210fcca8ef8","type":"LinearAxis"}],"left":[{"id":"ae22ec29-a77d-4cbf-9b2e-149886e03b24","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"eac0edb2-ff1f-4de0-95fe-f210fcca8ef8","type":"LinearAxis"},{"id":"933a73e0-0458-4c80-9088-0c703c4a17d8","type":"Grid"},{"id":"ae22ec29-a77d-4cbf-9b2e-149886e03b24","type":"LinearAxis"},{"id":"a02fd489-9eca-41dc-81fe-e025b7e2a3c8","type":"Grid"},{"id":"b55e8dae-dfb8-4a34-8946-d46d372367da","type":"BoxAnnotation"},{"id":"2e16899e-6aaa-4b9b-8a3d-324b81e755d0","type":"Legend"},{"id":"1f1b0fb9-7896-4cb7-96c3-bcc2bc1e8779","type":"GlyphRenderer"}],"title":{"id":"923e3009-b984-44f6-89dd-5fcbe273759a","type":"Title"},"tool_events":{"id":"238bc6a9-e025-4525-83cc-c306be7ecf81","type":"ToolEvents"},"toolbar":{"id":"dca11c75-96bb-4eb0-a8bc-3b62439b9dfc","type":"Toolbar"},"x_range":{"id":"5d43e063-9aba-43ba-a44d-d3f030d5935a","type":"DataRange1d"},"y_range":{"id":"68c0202c-4dd8-4346-b9c6-4ce49839019b","type":"DataRange1d"}},"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"}},"id":"c25b3aa2-efd4-4813-b27b-ec3881bc8b79","type":"ResetTool"},{"attributes":{},"id":"64ecdb2a-da1f-4b23-ae0c-47acffe503e3","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"}},"id":"9b65efc8-e256-470e-8aae-a3d82f7cc8de","type":"SaveTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f2104b5-6e96-4c14-b03f-6cfd57d89861","type":"Circle"},{"attributes":{"overlay":{"id":"b55e8dae-dfb8-4a34-8946-d46d372367da","type":"BoxAnnotation"},"plot":{"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"}},"id":"99a6c2d2-bc99-45f5-8c20-fc6bda1af385","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b55e8dae-dfb8-4a34-8946-d46d372367da","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"79caee16-2cfa-4b8f-8472-b473702feb3c","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"}},"id":"4f793a2e-91dc-48b2-8094-24fca7e264a9","type":"PanTool"},{"attributes":{"data_source":{"id":"79caee16-2cfa-4b8f-8472-b473702feb3c","type":"ColumnDataSource"},"glyph":{"id":"6f2104b5-6e96-4c14-b03f-6cfd57d89861","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b4bee6ce-e62f-4be5-9b17-fa320c8fb57f","type":"Circle"},"selection_glyph":null},"id":"1f1b0fb9-7896-4cb7-96c3-bcc2bc1e8779","type":"GlyphRenderer"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"1f1b0fb9-7896-4cb7-96c3-bcc2bc1e8779","type":"GlyphRenderer"}]},"id":"9dd4311d-4d20-4044-8ff2-ea53c99b265e","type":"LegendItem"},{"attributes":{"formatter":{"id":"5fec11e2-b960-441c-ba5b-9cd14c2b8ac6","type":"BasicTickFormatter"},"plot":{"id":"5f73cdf3-424c-4120-8450-efc402cad7cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"6ed0cf16-97fa-4783-8c5e-aa43bc825675","type":"BasicTicker"}},"id":"ae22ec29-a77d-4cbf-9b2e-149886e03b24","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4f793a2e-91dc-48b2-8094-24fca7e264a9","type":"PanTool"},{"id":"7f3fedc6-100f-47b5-bc45-5c4227960ecc","type":"WheelZoomTool"},{"id":"99a6c2d2-bc99-45f5-8c20-fc6bda1af385","type":"BoxZoomTool"},{"id":"9b65efc8-e256-470e-8aae-a3d82f7cc8de" ...

# %%
# リスト7.11.4：凡例の背景色の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend='circle')
p.legend.background_fill_color = 'red'
p.legend.background_fill_alpha = 0.5
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d5fcd17-8cd0-42d6-886f-8a2d0b596de6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9d5fcd17-8cd0-42d6-886f-8a2d0b596de6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d5fcd17-8cd0-42d6-886f-8a2d0b596de6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d5fcd17-8cd0-42d6-886f-8a2d0b596de6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6040054f-dea2-4469-8b19-bd3284c10852":{"roots":{"references":[{"attributes":{"formatter":{"id":"058ec798-4d3f-44cc-82f0-34c63dfeae61","type":"BasicTickFormatter"},"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"},"ticker":{"id":"6aac0cd0-78f1-4f0b-ac46-969e36dc18b7","type":"BasicTicker"}},"id":"82574da8-fa1f-46e1-9576-3a8b5d60602e","type":"LinearAxis"},{"attributes":{},"id":"6aac0cd0-78f1-4f0b-ac46-969e36dc18b7","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"},"ticker":{"id":"6aac0cd0-78f1-4f0b-ac46-969e36dc18b7","type":"BasicTicker"}},"id":"5e7019e3-aad8-4959-8a83-1d8d9ac8c957","type":"Grid"},{"attributes":{"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"}},"id":"32b852f3-a8ae-4620-9919-4fc01b251e4f","type":"HelpTool"},{"attributes":{},"id":"b79efae9-fdf2-40b0-ae31-b2bc42b7159e","type":"BasicTicker"},{"attributes":{"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"},"ticker":{"id":"b79efae9-fdf2-40b0-ae31-b2bc42b7159e","type":"BasicTicker"}},"id":"31ec2c44-e9e9-4308-8e80-0c59536e769b","type":"Grid"},{"attributes":{"overlay":{"id":"8a7d088a-0fdc-4043-95de-5d8ec454920b","type":"BoxAnnotation"},"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"}},"id":"cb8083b1-b583-4649-a780-377d3d4397dd","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"88efc680-f663-4cad-97aa-639eb0f86903","type":"DataRange1d"},{"attributes":{"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"}},"id":"b71d6d48-034e-42e1-9277-5af9c5be2154","type":"SaveTool"},{"attributes":{"below":[{"id":"c03a9536-558b-4269-8708-842ee838140c","type":"LinearAxis"}],"left":[{"id":"82574da8-fa1f-46e1-9576-3a8b5d60602e","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"c03a9536-558b-4269-8708-842ee838140c","type":"LinearAxis"},{"id":"31ec2c44-e9e9-4308-8e80-0c59536e769b","type":"Grid"},{"id":"82574da8-fa1f-46e1-9576-3a8b5d60602e","type":"LinearAxis"},{"id":"5e7019e3-aad8-4959-8a83-1d8d9ac8c957","type":"Grid"},{"id":"8a7d088a-0fdc-4043-95de-5d8ec454920b","type":"BoxAnnotation"},{"id":"da3c8585-ccb7-4822-821b-f5486f9e38e2","type":"Legend"},{"id":"e774d524-09ba-4e9e-b6a7-1eb367187190","type":"GlyphRenderer"}],"title":{"id":"b0b3b904-8f5c-4614-a8ed-2fdfc6a4a13d","type":"Title"},"tool_events":{"id":"5734f76b-9b34-4992-8b47-e63119d35798","type":"ToolEvents"},"toolbar":{"id":"6f65e220-560b-45a2-a101-94252dc7556a","type":"Toolbar"},"x_range":{"id":"88efc680-f663-4cad-97aa-639eb0f86903","type":"DataRange1d"},"y_range":{"id":"7573c95f-94cf-473e-9ebb-b743823b7131","type":"DataRange1d"}},"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"}},"id":"4d504505-f7ac-4402-ad7e-0c3b7496db36","type":"PanTool"},{"attributes":{"background_fill_alpha":{"value":0.5},"background_fill_color":{"value":"red"},"items":[{"id":"707608a5-5fc9-4af1-90c7-8ffb5321a59d","type":"LegendItem"}],"plot":{"id":"17315389-31ab-4728-9444-ffbadb460d3e","subtype":"Figure","type":"Plot"}},"id":"da3c8585-ccb7-4822-821b-f5486f9e38e2","type":"Legend"},{"attributes":{"callback":null},"id":"7573c95f-94cf-473e-9ebb-b743823b7131","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"5b2a389e-e34e-438e-a10c-161d5b624e83","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4450d292-edc5-461f-9eb3-d5930964f271","type":"Circle"},{"attributes":{},"id":"058ec798-4d3f-44cc-82f0-34c63dfeae61","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"d1a330dc-9869-46bc-bcea-07d2664fd91c"," ...

# %%
# リスト7.11.5：凡例の位置の設定
p = figure(plot_width=200, plot_height=200)
p.circle([0], [0], legend='circle')
p.legend.location = 'bottom_left'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="66ccf963-793f-4e90-8dab-b5b082e78da8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("66ccf963-793f-4e90-8dab-b5b082e78da8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("66ccf963-793f-4e90-8dab-b5b082e78da8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '66ccf963-793f-4e90-8dab-b5b082e78da8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"66d2af93-13a9-407a-b51a-e4a77fd415aa":{"roots":{"references":[{"attributes":{},"id":"e8cabee9-9339-4eab-a523-d757429047f6","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7191fc86-9294-4e3b-9dfa-532ed5f6fff2","type":"Circle"},{"attributes":{"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"}},"id":"7ad1e19a-32ae-4d52-8e99-130d7019914c","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"bb6083bb-4350-47b8-9816-ab7f396b562a","type":"ColumnDataSource"},"glyph":{"id":"7191fc86-9294-4e3b-9dfa-532ed5f6fff2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"35576ddf-043c-417d-b111-385381e588b1","type":"Circle"},"selection_glyph":null},"id":"062cfc78-a360-41f3-b6de-6b8855cb8245","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c35e582a-5ff7-4976-bbc3-d218ab4f47cf","type":"PanTool"},{"id":"7ad1e19a-32ae-4d52-8e99-130d7019914c","type":"WheelZoomTool"},{"id":"022f07d8-0f27-44b4-b19e-83f4f6df6c42","type":"BoxZoomTool"},{"id":"fc347e76-32b2-4319-9484-f2c7baf9d9f6","type":"SaveTool"},{"id":"32d375cb-0b52-4c87-8f29-60114b982562","type":"ResetTool"},{"id":"0988e9c8-5aa1-492e-8f60-2f05eb5699e2","type":"HelpTool"}]},"id":"a40daf11-78ae-4bbb-be2f-6a0a88d4f96e","type":"Toolbar"},{"attributes":{},"id":"73bfa45e-f57f-4fd0-911e-689b123402dd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"}},"id":"32d375cb-0b52-4c87-8f29-60114b982562","type":"ResetTool"},{"attributes":{"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"}},"id":"0988e9c8-5aa1-492e-8f60-2f05eb5699e2","type":"HelpTool"},{"attributes":{"callback":null},"id":"a1b46d85-5c5f-463d-87ee-cccce399284e","type":"DataRange1d"},{"attributes":{},"id":"dcb814d0-c66a-4050-a3e9-7e221a1b3505","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"73bfa45e-f57f-4fd0-911e-689b123402dd","type":"BasicTickFormatter"},"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e8cabee9-9339-4eab-a523-d757429047f6","type":"BasicTicker"}},"id":"ade1665c-f063-4573-a7d6-c163fa431089","type":"LinearAxis"},{"attributes":{"items":[{"id":"c8052bbd-7a2e-4613-b53c-1a80ed0ae63f","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"}},"id":"6edc39a6-a4db-4ef9-9885-4d20133dd7dc","type":"Legend"},{"attributes":{},"id":"e10faf7a-c55e-4891-80bf-6a3970d20583","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"35576ddf-043c-417d-b111-385381e588b1","type":"Circle"},{"attributes":{"callback":null},"id":"896b819b-59e6-4105-8d5b-1c3b98995522","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"bb6083bb-4350-47b8-9816-ab7f396b562a","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e10faf7a-c55e-4891-80bf-6a3970d20583","type":"BasicTicker"}},"id":"d52ad2ab-7c89-4428-9b5e-35966684e6f0","type":"Grid"},{"attributes":{"overlay":{"id":"9e8170d9-0b5a-4ef0-a452-5feafbbbaeef","type":"BoxAnnotation"},"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"}},"id":"022f07d8-0f27-44b4-b19e-83f4f6df6c42","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"dcb814d0-c66a-4050-a3e9-7e221a1b3505","type":"BasicTickFormatter"},"plot":{"id":"b2fe78c2-44ba-4978-8497-5355d62b4e3d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e10faf7a-c55e-4891-80bf-6a3970d20583","type":"BasicTicker"}},"id":"43d57c3c-790b-423e-98fd-b ...

# %%
# リスト7.11.6：レイアウトの設定
from bokeh.models import Legend
p = figure(plot_width=300, plot_height=200)
r = p.circle([0], [0])
legend = Legend(items=[('circle', [r])], location='bottom_left')
p.add_layout(legend, 'left')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a813eda7-e01e-4981-8207-b038b10d018d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a813eda7-e01e-4981-8207-b038b10d018d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a813eda7-e01e-4981-8207-b038b10d018d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a813eda7-e01e-4981-8207-b038b10d018d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"03541cc0-88cc-4fe1-a672-0069b9fa6a4f":{"roots":{"references":[{"attributes":{},"id":"2fd57d09-0f6d-4ffc-b57d-68fcb909c1ad","type":"BasicTickFormatter"},{"attributes":{},"id":"ae0e87b7-d6e1-4ff7-8575-3c06b91d5d65","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4fc81a4-608d-4776-9e3a-714ed75e7bee","type":"Circle"},{"attributes":{},"id":"30c6c2e0-19bc-4c80-9b47-bcecc007bfd2","type":"BasicTicker"},{"attributes":{"label":{"value":"circle"},"renderers":[{"id":"73f114c0-b411-4da0-acae-390bf240f63d","type":"GlyphRenderer"}]},"id":"cbcbe8af-0cee-4a25-941d-7ab28d4029fd","type":"LegendItem"},{"attributes":{"callback":null},"id":"6ed9c0a6-3c5e-4396-9622-2d07c91e1a88","type":"DataRange1d"},{"attributes":{"callback":null},"id":"5deb9353-dddd-4d4d-b2d6-0700865d9387","type":"DataRange1d"},{"attributes":{"formatter":{"id":"ae0e87b7-d6e1-4ff7-8575-3c06b91d5d65","type":"BasicTickFormatter"},"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ffdeccb-2daa-4aa6-9edd-2ebe2d1896ad","type":"BasicTicker"}},"id":"1969fc9d-3480-4130-b611-839e2e56cde7","type":"LinearAxis"},{"attributes":{},"id":"17bcc2f6-4316-411d-99fd-cdd69abf6f81","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"},"ticker":{"id":"30c6c2e0-19bc-4c80-9b47-bcecc007bfd2","type":"BasicTicker"}},"id":"afdde556-2feb-47a7-bb70-cbe9f17b7c98","type":"Grid"},{"attributes":{"overlay":{"id":"077390bd-7813-4d46-be47-f14619b2fb5d","type":"BoxAnnotation"},"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"}},"id":"161b54b1-b7fa-43d7-bd56-1043a30b9608","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ffdeccb-2daa-4aa6-9edd-2ebe2d1896ad","type":"BasicTicker"}},"id":"964edec5-b151-4d56-89e4-1552eef14691","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a3369197-cc5d-41a1-ab91-8885b16d54f3","type":"PanTool"},{"id":"3acac680-40b0-4ac3-baf4-c5ec702c6c23","type":"WheelZoomTool"},{"id":"161b54b1-b7fa-43d7-bd56-1043a30b9608","type":"BoxZoomTool"},{"id":"677fec97-1be0-4530-ac3d-b1780b01886f","type":"SaveTool"},{"id":"815b8304-6450-4689-a4cc-9007b7634a5d","type":"ResetTool"},{"id":"bfa73864-1b5a-4491-afd1-a7011c3c2d2e","type":"HelpTool"}]},"id":"6e16c4aa-ac73-4023-8dd9-33b7d5c8c3bf","type":"Toolbar"},{"attributes":{"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"}},"id":"677fec97-1be0-4530-ac3d-b1780b01886f","type":"SaveTool"},{"attributes":{"plot":{"id":"01e1da76-8a2d-4cef-9e15-4006f7593777","subtype":"Figure","type":"Plot"}},"id":"a3369197-cc5d-41a1-ab91-8885b16d54f3","type":"PanTool"},{"attributes":{"below":[{"id":"1969fc9d-3480-4130-b611-839e2e56cde7","type":"LinearAxis"}],"left":[{"id":"829da363-f56c-418e-bb71-48be07e02d29","type":"LinearAxis"},{"id":"1fffc86b-a793-4f22-a038-c8c5b1354530","type":"Legend"}],"plot_height":200,"plot_width":300,"renderers":[{"id":"1969fc9d-3480-4130-b611-839e2e56cde7","type":"LinearAxis"},{"id":"964edec5-b151-4d56-89e4-1552eef14691","type":"Grid"},{"id":"829da363-f56c-418e-bb71-48be07e02d29","type":"LinearAxis"},{"id":"afdde556-2feb-47a7-bb70-cbe9f17b7c98","type":"Grid"},{"id":"077390bd-7813-4d46-be47-f14619b2fb5d","type":"BoxAnnotation"},{"id":"73f114c0-b411-4da0-acae-390bf240f63d","type":"GlyphRenderer"},{"id":"1fffc86b-a793-4f22-a038-c8c5b1354530","type":"Legend"}],"title":{"id":"59591b7b-0331-4538-9569-2468303da22e","type":"Title"},"tool_events":{"id":"17bcc2f6-4316-411d-99fd-cdd69abf6f81","type":"ToolEvents"},"toolbar":{"id":"6e16c4aa-ac73-4023-8dd9-33b7d5c8c3bf","type":"Toolbar"},"x_range":{"id":"6ed9c0a6-3c5e-4396-9622-2d07c91e1a88","type":"DataRange1d"},"y_range":{"id":"5deb9353-dddd-4 ...

# %%
# リスト7.11.7：orientationの設定
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend='circle')
p.square([0, 1], [2, 2], legend='square')
p.legend.orientation = 'horizontal'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bbcd80ac-5918-4766-8dee-32f84ba30e6d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bbcd80ac-5918-4766-8dee-32f84ba30e6d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bbcd80ac-5918-4766-8dee-32f84ba30e6d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bbcd80ac-5918-4766-8dee-32f84ba30e6d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e7fb79eb-634b-4a4e-8855-0fa0d771553a":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"38e75df7-53a7-4286-8590-bb4319b71e4a","type":"Square"},{"attributes":{"data_source":{"id":"c78f3c43-47c7-41de-b270-ce99c243e32f","type":"ColumnDataSource"},"glyph":{"id":"38e75df7-53a7-4286-8590-bb4319b71e4a","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b6850617-d99c-4dba-a817-8c590f061d7a","type":"Square"},"selection_glyph":null},"id":"b7497d77-8bf3-4f82-aad0-4429f0b16764","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6850617-d99c-4dba-a817-8c590f061d7a","type":"Square"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ffdc51be-d2a5-49c3-a222-8ec3913e9d76","type":"Circle"},{"attributes":{"label":{"value":"square"},"renderers":[{"id":"b7497d77-8bf3-4f82-aad0-4429f0b16764","type":"GlyphRenderer"}]},"id":"64f383dd-2e4c-4d67-b72a-dfaa2462b0f6","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"},"ticker":{"id":"72d39460-7a94-45f3-8e74-b3d78d59ae87","type":"BasicTicker"}},"id":"5abbe65b-4ce9-459b-9834-be10d2f4a538","type":"Grid"},{"attributes":{"overlay":{"id":"996c0833-0202-42d6-86fd-1fd99204df52","type":"BoxAnnotation"},"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"}},"id":"85d4a75a-ae84-4701-b98e-8a75b5e5392f","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":""},"id":"2ccf53b3-c693-4905-92fd-f08ec4bdeef9","type":"Title"},{"attributes":{"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"}},"id":"2f6df08b-dd39-4486-843c-18b6b74009db","type":"PanTool"},{"attributes":{"data_source":{"id":"6809dd71-b50a-46be-ade4-d7d8f3a3bf8c","type":"ColumnDataSource"},"glyph":{"id":"ffdc51be-d2a5-49c3-a222-8ec3913e9d76","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1f105a56-991e-4cfb-b338-a5370bd79a10","type":"Circle"},"selection_glyph":null},"id":"c45841ae-1adc-4af1-a785-29bd2aad18fe","type":"GlyphRenderer"},{"attributes":{},"id":"6bc107fc-8569-4ca8-8606-e616ad70030c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"}},"id":"f8218544-1b40-47c1-8e1a-fe7fce9ac876","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"}},"id":"5fd117ad-0e4d-4f0b-8e1a-d5ff0664f3aa","type":"SaveTool"},{"attributes":{},"id":"73e364c0-6d30-4340-9f14-332658a10a4c","type":"BasicTickFormatter"},{"attributes":{},"id":"d52f2079-4395-4261-8e48-6a577b4ce6d4","type":"BasicTicker"},{"attributes":{"plot":{"id":"4de89d3e-1bfc-46af-9dd7-1364a7ce2fe2","subtype":"Figure","type":"Plot"}},"id":"fe44026d-034b-4005-a951-b47438a8fd2c","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"6809dd71-b50a-46be-ade4-d7d8f3a3bf8c","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"829d1bd9-71a9-4a61-8508-5bc7a806a702","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"996c0833-0202-42d6-86fd-1fd99204df52","type":"BoxAnnotation"},{"attributes":{},"id":"72d39460-7a94-45f3-8e74-b3d78d59ae87","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_c ...

# %%
# リスト7.11.8：凡例の調整
p = figure(plot_width=200, plot_height=200)
p.circle([0, 1], [1, 1], legend='circle')
p.square([0, 1], [2, 2], legend='square')
p.legend.border_line_color = 'black'
p.legend.location = 'center'
p.legend.spacing = 15
p.legend.padding = 20
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f5512a08-b175-4218-916e-6484b3f14c86"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f5512a08-b175-4218-916e-6484b3f14c86");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f5512a08-b175-4218-916e-6484b3f14c86");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f5512a08-b175-4218-916e-6484b3f14c86' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"98fa7822-a6ce-4efe-b47a-3ec5b564e4e3":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e693e984-81cf-4af9-b71b-ac752a752ded","type":"Square"},{"attributes":{"data_source":{"id":"b0a7dc51-c33f-4476-9fdc-5ddd8a732152","type":"ColumnDataSource"},"glyph":{"id":"e693e984-81cf-4af9-b71b-ac752a752ded","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"66b4c4f2-1701-462f-abc2-0a05b47f9082","type":"Square"},"selection_glyph":null},"id":"917d88c1-abb7-4280-bc49-7e33a1a4eb0d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0,1],"y":[1,1]}},"id":"1ad85d89-3719-41f6-b1e0-9a2c01f6afe2","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"403aff8b-3fea-42c4-bb0f-41922e86143a","type":"BasicTickFormatter"},"plot":{"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"787fae45-d4fb-4180-b817-4c95bcf144e5","type":"BasicTicker"}},"id":"7cf83bcf-9dc2-4bf6-ac05-475e9e15a136","type":"LinearAxis"},{"attributes":{"label":{"value":"square"},"renderers":[{"id":"917d88c1-abb7-4280-bc49-7e33a1a4eb0d","type":"GlyphRenderer"}]},"id":"c873f785-adff-4578-abc3-5502caa5e0d2","type":"LegendItem"},{"attributes":{"plot":null,"text":""},"id":"22e21e60-2c76-471b-bdd7-62ff587ac551","type":"Title"},{"attributes":{"plot":{"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"},"ticker":{"id":"22589627-402d-41bc-b668-08ddfe1a45a5","type":"BasicTicker"}},"id":"b64c3c1c-b78b-42d0-a44c-fe1a9c93fc32","type":"Grid"},{"attributes":{},"id":"845f68e9-35fe-427a-92f5-732c7c7573bb","type":"ToolEvents"},{"attributes":{"below":[{"id":"e45023f6-6c87-4a39-b275-095a499f3b09","type":"LinearAxis"}],"left":[{"id":"7cf83bcf-9dc2-4bf6-ac05-475e9e15a136","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"e45023f6-6c87-4a39-b275-095a499f3b09","type":"LinearAxis"},{"id":"b64c3c1c-b78b-42d0-a44c-fe1a9c93fc32","type":"Grid"},{"id":"7cf83bcf-9dc2-4bf6-ac05-475e9e15a136","type":"LinearAxis"},{"id":"7974f5b5-3592-4557-8f51-2d7ffb1d68d0","type":"Grid"},{"id":"40616707-c207-480f-834f-61923ac63100","type":"BoxAnnotation"},{"id":"f41c2e6f-2e76-41d9-8809-b30d1289fb26","type":"Legend"},{"id":"fad918c6-c609-4df4-9fe9-28ac8c83b865","type":"GlyphRenderer"},{"id":"917d88c1-abb7-4280-bc49-7e33a1a4eb0d","type":"GlyphRenderer"}],"title":{"id":"22e21e60-2c76-471b-bdd7-62ff587ac551","type":"Title"},"tool_events":{"id":"845f68e9-35fe-427a-92f5-732c7c7573bb","type":"ToolEvents"},"toolbar":{"id":"93d2ea9e-2660-453b-922e-7e337f353eb3","type":"Toolbar"},"x_range":{"id":"8a761722-4139-492c-b917-b8ccdfd55099","type":"DataRange1d"},"y_range":{"id":"fb2b2b86-1f75-46fc-8143-9e0ff18f379c","type":"DataRange1d"}},"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66b4c4f2-1701-462f-abc2-0a05b47f9082","type":"Square"},{"attributes":{"plot":{"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"}},"id":"be77f597-11f1-4733-8995-008d57adca95","type":"ResetTool"},{"attributes":{"plot":{"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"}},"id":"20121572-718c-4fe2-a639-1030189de0e8","type":"HelpTool"},{"attributes":{},"id":"403aff8b-3fea-42c4-bb0f-41922e86143a","type":"BasicTickFormatter"},{"attributes":{"border_line_color":{"value":"black"},"items":[{"id":"791531af-e827-4f29-ba91-7f9e91f92ab4","type":"LegendItem"},{"id":"c873f785-adff-4578-abc3-5502caa5e0d2","type":"LegendItem"}],"location":"center","padding":20,"plot":{"id":"4e7446a8-630c-4569-98e3-929440e725d3","subtype":"Figure","type":"Plot"},"spacing":15},"id":"f41c2e6f-2e76-41d9-8809-b30d1289fb26","type":"Legend"},{"attributes":{"p ...
