# %% [markdown]
# ## 第7章 Bokehを使いこなそう
#
# ### 7-12: 複数の図のレイアウト調整

# %%
# リスト7.12.1：column()関数で縦に並べる
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column

output_notebook()
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
show(column(p1, p2))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="51889487-0bcc-4b20-b742-e033c52d77f3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3101cb9a-c733-464c-844f-5b4f82cdd983"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3101cb9a-c733-464c-844f-5b4f82cdd983");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3101cb9a-c733-464c-844f-5b4f82cdd983");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3101cb9a-c733-464c-844f-5b4f82cdd983' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a6c7b238-7cd4-4890-ac77-7afdd3361873":{"roots":{"references":[{"attributes":{"formatter":{"id":"1c34844e-bb72-4335-9816-bf3efc460152","type":"BasicTickFormatter"},"plot":{"id":"7889e0d9-dff6-4235-ac3a-b411949359ea","subtype":"Figure","type":"Plot"},"ticker":{"id":"57eb6185-f107-4eb1-82e4-c05a6fa8b867","type":"BasicTicker"}},"id":"0a6b0fef-01d1-4b32-bf66-5f6750acf750","type":"LinearAxis"},{"attributes":{"plot":{"id":"7889e0d9-dff6-4235-ac3a-b411949359ea","subtype":"Figure","type":"Plot"}},"id":"e66a8d80-924d-48b6-bdbe-e8ec8a87539b","type":"SaveTool"},{"attributes":{},"id":"1c34844e-bb72-4335-9816-bf3efc460152","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"29b20f5b-569e-4243-a86b-bd70ec50b756","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"b1373c63-8a13-4848-adae-90c341998e36","type":"DataRange1d"},{"attributes":{"below":[{"id":"0a6b0fef-01d1-4b32-bf66-5f6750acf750","type":"LinearAxis"}],"left":[{"id":"e129cda8-ad23-4b58-b769-0712f079720b","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"0a6b0fef-01d1-4b32-bf66-5f6750acf750","type":"LinearAxis"},{"id":"1ef8d16c-513d-4f71-b027-83b31e3c749a","type":"Grid"},{"id":"e129cda8-ad23-4b58-b769-0712f079720b","type":"LinearAxis"},{"id":"ecb1cdb2-7811-4604-9841-182e2b73339d","type":"Grid"},{"id":"29b20f5b-569e-4243-a86b-bd70ec50b756","type":"BoxAnnotation"}],"title":{"id":"d30ffe4d-b3d1-4ac9-bcaf-6a7a80a7ba17","type":"Title"},"tool_events":{"id":"fb1e10ac-8b76-48b9-8fee-198b3b16bce7","type":"ToolEvents"},"toolbar":{"id":"90ac193d-f191-452d-9c1d-1a35bcb04089","type":"Toolbar"},"x_range":{"id":"b8db3d19-5616-4438-8a08-2c7601a3ae8f","type":"DataRange1d"},"y_range":{"id":"f02555cb-10c6-45c8-9318-fd36cbef4b57","type":"DataRange1d"}},"id":"7889e0d9-dff6-4235-ac3a-b411949359ea","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"7889e0d9-dff6-4235-ac3a-b411949359ea","subtype":"Figure","type":"Plot"}},"id":"b783789c-64ac-4a06-ae57-ac9f46b2be2d","type":"ResetTool"},{"attributes":{},"id":"05a3a874-30d2-4600-8651-495948631a88","type":"ToolEvents"},{"attributes":{"formatter":{"id":"d85ab643-888c-461f-9926-afb5cfffe564","type":"BasicTickFormatter"},"plot":{"id":"c20f0e57-e719-49b7-a8a0-4f84b7b249d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"59badcd5-37a4-4fc9-ac53-80f4d303dbf4","type":"BasicTicker"}},"id":"e2d8f5f9-85fa-4e3f-987a-c163691da00b","type":"LinearAxis"},{"attributes":{"below":[{"id":"e2d8f5f9-85fa-4e3f-987a-c163691da00b","type":"LinearAxis"}],"left":[{"id":"0a4ec831-dfeb-44f3-bff6-4359cb9a9c43","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"e2d8f5f9-85fa-4e3f-987a-c163691da00b","type":"LinearAxis"},{"id":"a8762697-355e-49e0-874d-1620a1651d15","type":"Grid"},{"id":"0a4ec831-dfeb-44f3-bff6-4359cb9a9c43","type":"LinearAxis"},{"id":"6756abce-08db-48e3-ba1f-7661a3036fec","type":"Grid"},{"id":"c0c64ced-e8e3-4fe5-bd4d-1db5848b1325","type":"BoxAnnotation"}],"title":{"id":"fef099fe-004c-42f7-a7f1-adfe4ddc09dd","type":"Title"},"tool_events":{"id":"05a3a874-30d2-4600-8651-495948631a88","type":"ToolEvents"},"toolbar":{"id":"98b71f0d-7a71-4edf-8b6e-fc9d2f554f07","type":"Toolbar"},"x_range":{"id":"2bd172a2-9f03-4627-9b47-a89a380044f0","type":"DataRange1d"},"y_range":{"id":"b1373c63-8a13-4848-adae-90c341998e36","type":"DataRange1d"}},"id":"c20f0e57-e719-49b7-a8a0-4f84b7b249d0","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"59badcd5-37a4-4fc9-ac53-80f4d303dbf4","type":"BasicTicker"},{"attributes":{"plot":{"id":"7889e0d9-dff6-4235-ac3a-b411949359ea","subtype":"Figure","type":"Plot"}},"id":"ad5cf971-8d17-487a-a7ef-37222f1fb806","type":"HelpTool"},{"attributes":{},"id":"fb1e10ac- ...

# %%
# リスト7.12.2：row()関数で横に並べる
from bokeh.layouts import row

p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
show(row(p1, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc3d5be8-db45-4c93-9a92-2dcabf378179"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fc3d5be8-db45-4c93-9a92-2dcabf378179");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc3d5be8-db45-4c93-9a92-2dcabf378179");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc3d5be8-db45-4c93-9a92-2dcabf378179' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"28515f4b-c154-49f5-ad0d-434564aa5b04":{"roots":{"references":[{"attributes":{"below":[{"id":"a3aef46c-6690-4462-b771-de9db9abd038","type":"LinearAxis"}],"left":[{"id":"dd1f083b-4f5c-4a02-b838-b1af40fc42d4","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"a3aef46c-6690-4462-b771-de9db9abd038","type":"LinearAxis"},{"id":"b9f7a75f-e22c-486a-8424-7a95cb4400ae","type":"Grid"},{"id":"dd1f083b-4f5c-4a02-b838-b1af40fc42d4","type":"LinearAxis"},{"id":"8fe29a92-9dc7-4694-89f6-9000e2b4a5ed","type":"Grid"},{"id":"6472da78-ec61-492f-a2da-9062d5da2277","type":"BoxAnnotation"}],"title":{"id":"9cf56236-a83f-411b-8a60-a69177868dfa","type":"Title"},"tool_events":{"id":"7e46f80b-9c02-42f4-b36f-61788b292faf","type":"ToolEvents"},"toolbar":{"id":"a7ee62e8-eb4f-4ae6-b2b7-a6e756b082d0","type":"Toolbar"},"x_range":{"id":"15b98569-8c2f-467d-ab18-a4a79bdb3a25","type":"DataRange1d"},"y_range":{"id":"8a1847c3-06d1-4b20-9aa9-f02cb17c3ba6","type":"DataRange1d"}},"id":"dcef557e-4ce3-4cf6-ab7f-fc26caa8daf6","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"5e7bf25c-eefe-43b0-9a7c-ddfc7729168f","type":"Title"},{"attributes":{"below":[{"id":"8a4b9ed4-7259-46f0-a8f5-b3e00d27eca9","type":"LinearAxis"}],"left":[{"id":"89f8f6b8-07ef-41ee-9f31-a694075c3ce5","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"8a4b9ed4-7259-46f0-a8f5-b3e00d27eca9","type":"LinearAxis"},{"id":"f04e1939-10b0-45a0-a7a9-a66859b93608","type":"Grid"},{"id":"89f8f6b8-07ef-41ee-9f31-a694075c3ce5","type":"LinearAxis"},{"id":"d553bd4a-b9eb-4f8c-aba0-ff92e4c7e9f9","type":"Grid"},{"id":"43c5afb1-746b-4839-b032-2202e1b01efe","type":"BoxAnnotation"}],"title":{"id":"5e7bf25c-eefe-43b0-9a7c-ddfc7729168f","type":"Title"},"tool_events":{"id":"6889655d-955c-410c-8728-8dba505fad24","type":"ToolEvents"},"toolbar":{"id":"a38e6db8-9149-4bed-86aa-a58a8300f835","type":"Toolbar"},"x_range":{"id":"6466a723-884b-4d96-aede-2c7350bf1efa","type":"DataRange1d"},"y_range":{"id":"d68f2809-83d3-4567-8da7-980def716039","type":"DataRange1d"}},"id":"bdc6a7fb-9822-418f-9480-86066883cd3f","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"a400e7e8-c817-4876-8d0e-4719b91a5e96","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"70d2dfe5-483b-4ce0-b16f-60c9ac8ad793","type":"PanTool"},{"id":"bd52a609-371f-4169-a656-75b6aafae121","type":"WheelZoomTool"},{"id":"a377a7b3-f352-49f2-8b63-b7fdadffdca2","type":"BoxZoomTool"},{"id":"ee3c64fe-8835-4998-89d4-dcc1984d2417","type":"SaveTool"},{"id":"1dda6646-e5cc-493a-91b6-c85781f389e5","type":"ResetTool"},{"id":"db753e34-87ca-48b4-9829-8b4e2594aa79","type":"HelpTool"}]},"id":"a7ee62e8-eb4f-4ae6-b2b7-a6e756b082d0","type":"Toolbar"},{"attributes":{"callback":null},"id":"15b98569-8c2f-467d-ab18-a4a79bdb3a25","type":"DataRange1d"},{"attributes":{"plot":{"id":"dcef557e-4ce3-4cf6-ab7f-fc26caa8daf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"543fd6f0-de08-485b-973c-f26cc50b4cd0","type":"BasicTicker"}},"id":"b9f7a75f-e22c-486a-8424-7a95cb4400ae","type":"Grid"},{"attributes":{},"id":"7e46f80b-9c02-42f4-b36f-61788b292faf","type":"ToolEvents"},{"attributes":{},"id":"543fd6f0-de08-485b-973c-f26cc50b4cd0","type":"BasicTicker"},{"attributes":{},"id":"ecb23d88-48ad-465c-99f1-3ae39f69ac77","type":"BasicTickFormatter"},{"attributes":{},"id":"6889655d-955c-410c-8728-8dba505fad24","type":"ToolEvents"},{"attributes":{"formatter":{"id":"ecb23d88-48ad-465c-99f1-3ae39f69ac77","type":"BasicTickFormatter"},"plot":{"id":"dcef557e-4ce3-4cf6-ab7f-fc26caa8daf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"543fd6f0-de08-485b-973c-f26cc50b4cd0","type":"BasicTicker"}},"id":"a3aef46c-6690-4462-b771-de9db9abd038","type":"LinearAxis"},{"attributes":{"plot":{"id":"bdc6a7fb-9822-418f-9480-86066883cd3f","subtype":"Figure","type":"Plot"}},"id":"29f77cd0-7477-4b58-ba9c-b015c9fb53bb","type":"PanTool"},{"attributes":{"callback":nul ...

# %%
# リスト7.12.3：gridplot()関数で並べる
from bokeh.layouts import gridplot

p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=200, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(gridplot([[p1, p2], [None, p3]]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d9c2a57c-737a-4a37-9462-5cb29e4511aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d9c2a57c-737a-4a37-9462-5cb29e4511aa");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9c2a57c-737a-4a37-9462-5cb29e4511aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9c2a57c-737a-4a37-9462-5cb29e4511aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"55079c64-7ecd-4a41-b808-5fc393bb56af":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"33d21401-6c04-4c88-a42b-1b16497fde63","type":"Circle"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"20d6cfc9-046b-4d9c-89a1-c8496a01edb6","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"63e6e0d9-936e-4dbf-9f8e-aeaad8c8f4f9","subtype":"Figure","type":"Plot"},{"id":"c4dfe88c-d4da-45a5-9acc-c152d299f390","subtype":"Figure","type":"Plot"}]},"id":"300f1d1e-a39b-402e-996e-74b3484b56a8","type":"Row"},{"attributes":{"callback":null},"id":"8dce57f9-ef17-4118-83c3-0e1c55be415f","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f0bde19-7d3e-4b92-8aab-07afa99044ad","type":"Square"},{"attributes":{},"id":"1acb6f60-1f43-4d72-9dd9-70eac5608b38","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"426c3476-52e3-4bc0-8e8c-67cdb4c1ac48","type":"Square"},{"attributes":{"data_source":{"id":"3d6ada8a-1719-4227-bff4-b8f06379bf78","type":"ColumnDataSource"},"glyph":{"id":"6f0bde19-7d3e-4b92-8aab-07afa99044ad","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"426c3476-52e3-4bc0-8e8c-67cdb4c1ac48","type":"Square"},"selection_glyph":null},"id":"dda54baf-af61-49f7-b9e9-4a4d01c772c6","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"20588d02-2d1e-428a-a2bb-5ebd0727f553","type":"Title"},{"attributes":{},"id":"43ceebc0-f9ea-496c-b9b4-366a2e9fe74f","type":"BasicTickFormatter"},{"attributes":{},"id":"2c3c5c9f-0cf9-42ad-a9e6-721502a59483","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"300f1d1e-a39b-402e-996e-74b3484b56a8","type":"Row"},{"id":"80d5bdd0-9eff-4289-ab51-a98e865825a0","type":"Row"}]},"id":"d06779fc-75f4-4bc7-a049-bcebaa99141f","type":"Column"},{"attributes":{"children":[{"id":"a5befd83-58aa-44bd-99aa-8591e98cc2ab","type":"Spacer"},{"id":"22a0f9dc-c611-417c-aee5-7d7c3dcf5469","subtype":"Figure","type":"Plot"}]},"id":"80d5bdd0-9eff-4289-ab51-a98e865825a0","type":"Row"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"8b61ab73-372f-48a9-8677-d130aa06cdfb","type":"Triangle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"34e2e9ea-2198-4cd1-bc51-a46b5c542812","type":"PanTool"},{"id":"8428454c-a586-4607-bf48-0be15bf02d82","type":"WheelZoomTool"},{"id":"a24686e0-d964-4111-819e-75a499843ddd","type":"BoxZoomTool"},{"id":"d93ad4a9-2c27-4fa1-89d0-d9fdc91d122a","type":"SaveTool"},{"id":"3b171a49-804c-4af9-a097-71c3830ea134","type":"ResetTool"},{"id":"6e9c06ec-b9b1-41b4-b1f8-f3a02404e7ad","type":"HelpTool"}]},"id":"70926ff8-7b17-470b-b4fc-05bf8d1cf70a","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"7cee9b4d-b714-4579-97fa-599cce8dea8e","type":"Triangle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5701a991-a973-4bb8-a6ff-1ba6640a1205","type":"PanTool"},{"id":"de0512e6-047b-4c40-a57f-522facc7b1dc","type":"WheelZoomTool"},{"id":"e001f5ab-bc9c-46cd-b0cf-b6ce4b3fc543","type":"BoxZoomTool"},{"id":"dc1e1320-9622-49ca-b984-aebce3905d2e","type":"SaveTool"},{"id":"0bf6a5c0-24c4-450d-b233-0880980ca6c6","type":"ResetTool"},{"id":"4b114093-53a2-4470-9f44-c362bc415c41","type":"HelpTool"}]},"id":"2021c4a ...

# %%
# リスト7.12.4：ncolsを指定したgridplot()関数で並べる
from bokeh.layouts import gridplot

p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=200, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(gridplot([p1, p2, None, p3], ncols=2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="03abf913-6227-48c5-b56e-cef235c9d089"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("03abf913-6227-48c5-b56e-cef235c9d089");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("03abf913-6227-48c5-b56e-cef235c9d089");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '03abf913-6227-48c5-b56e-cef235c9d089' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c222b8d2-1c59-4752-83fe-18b57c1c234e":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"66fe6221-88bd-4d54-982c-8ed48619ec28","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"32cfd54a-f8f5-438b-940f-557cf9943077","type":"BoxAnnotation"},{"attributes":{"children":[{"id":"f79adb5d-fd1b-419e-ac7c-c6a433a9175b","type":"ToolbarBox"},{"id":"5922060e-0ea1-4772-a147-c2c3cdf5d93c","type":"Column"}]},"id":"1a77b5a7-2b57-4ed4-a372-74be8ace1732","type":"Column"},{"attributes":{},"id":"1ba7872c-17e7-4660-a64d-d329bcbe0b34","type":"BasicTicker"},{"attributes":{},"id":"03b4ea22-d383-4145-9db2-0198e8898a11","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"404f50a0-9093-4f02-9718-de24b1676408","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"6ef0dcf0-c333-4c2c-b69e-b096e0e7f3cb","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ba7872c-17e7-4660-a64d-d329bcbe0b34","type":"BasicTicker"}},"id":"b58baa48-f743-45e9-9f3a-f00ebfbd6f2f","type":"Grid"},{"attributes":{"formatter":{"id":"b3d87861-666b-49d0-8b6f-f0a33dabd53f","type":"BasicTickFormatter"},"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ba7872c-17e7-4660-a64d-d329bcbe0b34","type":"BasicTicker"}},"id":"f00611e2-f1f8-4c4b-bc79-bf118b766053","type":"LinearAxis"},{"attributes":{"data_source":{"id":"24b58161-7e08-44de-a729-c0d2b0306cc9","type":"ColumnDataSource"},"glyph":{"id":"fda90140-c36b-4bdd-b7aa-70fcad46319c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"66fe6221-88bd-4d54-982c-8ed48619ec28","type":"Circle"},"selection_glyph":null},"id":"8832263a-78a8-453c-b21a-f13a936d12cd","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"32cfd54a-f8f5-438b-940f-557cf9943077","type":"BoxAnnotation"},"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"34e9ba2f-2be5-4194-8ae9-09bee1204ad7","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"af4baee2-13ea-4cc9-becb-4485dcb34ae3","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"af179f6b-24f8-492f-8957-ddf8784ff5ec","type":"WheelZoomTool"},{"attributes":{},"id":"1b0862a0-33db-4d80-8431-e01ee06f6cc5","type":"BasicTicker"},{"attributes":{},"id":"e5ebd8d9-119a-4253-9a2c-25d8cfc1d440","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"6bea245b-cbce-4390-897f-3b322b188109","type":"ResetTool"},{"attributes":{"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"92545005-c0b6-4f0b-ba01-c85e05dc9dc4","type":"SaveTool"},{"attributes":{"callback":null},"id":"33e23845-105f-45ac-9e05-9f74bedaa6c9","type":"DataRange1d"},{"attributes":{},"id":"cadd3b1d-a4a8-44b7-bb8c-e15474908a29","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"d4070d12-efe9-43e5-b636-5347ba9eabcc","subtype":"Figure","type":"Plot"}},"id":"0c020703-1cf6-4542-b22f-48955a89bc21","type":"HelpTool"},{"attributes":{"callback":null},"id":"47b297a5-3b04-4892-8c87-a884051f64b4","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f7e62270-fb3a- ...

# %%
# リスト7.12.5：layout()関数で並べる
from bokeh.layouts import layout

p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=400, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(layout([p1, p2], [p3]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="021761de-c3db-4ea7-aa2e-b8348c7336b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("021761de-c3db-4ea7-aa2e-b8348c7336b4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("021761de-c3db-4ea7-aa2e-b8348c7336b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '021761de-c3db-4ea7-aa2e-b8348c7336b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aed80ccb-8eb9-454f-a93e-8404231133c4":{"roots":{"references":[{"attributes":{"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"ca211a7e-7699-4234-8247-7f20412529d3","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3fa0fc8b-1768-4464-ac3d-0a44603b2a76","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"abe1a3ad-298a-4dfc-b6f7-72e5c9f41dcf","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"3fa0fc8b-1768-4464-ac3d-0a44603b2a76","type":"BoxAnnotation"},"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"6833d741-c450-4cd4-bbe4-e639e24cdf0e","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"3081bc1c-c944-4d07-84e8-e4e3f2b62043","type":"SaveTool"},{"attributes":{"formatter":{"id":"f2cb259a-cb7d-45e8-9990-45e72283f09c","type":"BasicTickFormatter"},"plot":{"id":"053aa58b-b393-49a4-8035-2be535f8174e","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3b2fcb6-4072-47cb-8b5d-b288e62e285c","type":"BasicTicker"}},"id":"f48abe64-28b4-47cc-a147-09b63cafba0f","type":"LinearAxis"},{"attributes":{"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"b75fbada-a58a-4130-8e16-16d0ab3e9c41","type":"ResetTool"},{"attributes":{"plot":{"id":"ab19af3e-3e99-4b6c-b583-8eb71da5fc4e","subtype":"Figure","type":"Plot"}},"id":"44fe71d1-77a1-4ae5-9034-b8ff68fa4351","type":"HelpTool"},{"attributes":{"formatter":{"id":"299a61d3-75c2-4e56-bab1-6f4d62d60498","type":"BasicTickFormatter"},"plot":{"id":"22f38386-3d4c-4d8a-9b0e-a88631086fba","subtype":"Figure","type":"Plot"},"ticker":{"id":"793ab8b0-c593-4e95-b994-ccd550ee5c53","type":"BasicTicker"}},"id":"1016099e-46c1-4c8f-9cf6-9f07863384c5","type":"LinearAxis"},{"attributes":{"data_source":{"id":"cbe3fd89-0f61-48f7-a2d7-1fcf41ef98cf","type":"ColumnDataSource"},"glyph":{"id":"44ab91e3-662e-4b2a-bf3a-738d125d4831","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"308d580b-47e0-454a-907c-ab86b2794998","type":"Circle"},"selection_glyph":null},"id":"ec117a5f-0af0-4dbf-88c7-a56ad72853f2","type":"GlyphRenderer"},{"attributes":{},"id":"c020ebf1-8f82-4789-a7f0-d5ee11dae57e","type":"ToolEvents"},{"attributes":{},"id":"793ab8b0-c593-4e95-b994-ccd550ee5c53","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"22f38386-3d4c-4d8a-9b0e-a88631086fba","subtype":"Figure","type":"Plot"},"ticker":{"id":"793ab8b0-c593-4e95-b994-ccd550ee5c53","type":"BasicTicker"}},"id":"bfe3d149-85c1-4c71-9888-731be24104eb","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"8312ea54-b72a-46fe-bd91-46e2fe5a40d3","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"308d580b-47e0-454a-907c-ab86b2794998","type":"Circle"},{"attributes":{"children":[{"id":"22f38386-3d4c-4d8a-9b0e-a88631086fba","subtype":"Figure","type":"Plot"}]},"id":"510ee863-2f77-4933-87dd-017b75daad99","type":"Row"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7e0e2119-fff7-4707-8d0a-cea29fe8d354","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"22f38386-3d4c-4d8a-9b0e-a88631086fba ...
