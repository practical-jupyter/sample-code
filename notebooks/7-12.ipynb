# %%
# リスト7.12.1：column()関数で縦に並べる
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column
output_notebook()
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
show(column(p1, p2))
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3e8426ef-3708-475a-8135-2c08d9f872e0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="198cb924-71c3-4ed5-adb3-b8b4e0fa21a6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("198cb924-71c3-4ed5-adb3-b8b4e0fa21a6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("198cb924-71c3-4ed5-adb3-b8b4e0fa21a6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '198cb924-71c3-4ed5-adb3-b8b4e0fa21a6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6efb58d4-04c1-458d-b636-8fd3fbb6ae21":{"roots":{"references":[{"attributes":{"plot":{"id":"9d2d24d8-8459-4e62-a7c6-1adf2bbe3836","subtype":"Figure","type":"Plot"}},"id":"b97095b3-8a07-49e0-b292-a5950a35ce7c","type":"ResetTool"},{"attributes":{"plot":{"id":"9d2d24d8-8459-4e62-a7c6-1adf2bbe3836","subtype":"Figure","type":"Plot"}},"id":"e33bec21-43c4-4b22-8749-ac6e45b6dbd0","type":"HelpTool"},{"attributes":{"formatter":{"id":"4980afd1-d310-4745-aacb-148cc388b3b0","type":"BasicTickFormatter"},"plot":{"id":"9d2d24d8-8459-4e62-a7c6-1adf2bbe3836","subtype":"Figure","type":"Plot"},"ticker":{"id":"2a778c82-ebef-4031-83fa-37de63daca4b","type":"BasicTicker"}},"id":"0a74aacf-39ff-4ccb-ab18-a61a69cbf15d","type":"LinearAxis"},{"attributes":{},"id":"69194996-1eda-4650-87fe-72bd7f263017","type":"BasicTicker"},{"attributes":{},"id":"6658848d-9565-4daf-8e9c-df36132e3fc0","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"8f003d06-78eb-4a2b-83b0-b107215a86d5","type":"DataRange1d"},{"attributes":{"plot":{"id":"24dbff07-fd6f-46d0-a7eb-a5c08a700f65","subtype":"Figure","type":"Plot"},"ticker":{"id":"69194996-1eda-4650-87fe-72bd7f263017","type":"BasicTicker"}},"id":"d2a47c06-92d5-4fde-9087-c44c2f462007","type":"Grid"},{"attributes":{"formatter":{"id":"f93ac6d6-e052-4bce-ab6b-8b3313918776","type":"BasicTickFormatter"},"plot":{"id":"24dbff07-fd6f-46d0-a7eb-a5c08a700f65","subtype":"Figure","type":"Plot"},"ticker":{"id":"76dbb2eb-818f-4b22-b0e4-9ffbd2daf2b8","type":"BasicTicker"}},"id":"580a209f-9d6e-4dd7-82f5-36661fbba793","type":"LinearAxis"},{"attributes":{},"id":"76dbb2eb-818f-4b22-b0e4-9ffbd2daf2b8","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"24dbff07-fd6f-46d0-a7eb-a5c08a700f65","subtype":"Figure","type":"Plot"},"ticker":{"id":"76dbb2eb-818f-4b22-b0e4-9ffbd2daf2b8","type":"BasicTicker"}},"id":"2fe54a68-0b2d-42fe-952e-6efeceee535f","type":"Grid"},{"attributes":{"children":[{"id":"24dbff07-fd6f-46d0-a7eb-a5c08a700f65","subtype":"Figure","type":"Plot"},{"id":"9d2d24d8-8459-4e62-a7c6-1adf2bbe3836","subtype":"Figure","type":"Plot"}]},"id":"a89b46d2-5ead-404e-be38-569c09f0d18c","type":"Column"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7076d35e-1afe-47df-adaa-fa7360039951","type":"BoxAnnotation"},{"attributes":{},"id":"bd176f16-c5fd-45e8-b67b-3dd6d365f096","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"07a68f83-c231-41a1-a0e3-a04157629167","type":"PanTool"},{"id":"dfb12b9b-0919-4e87-b194-40dd106dad89","type":"WheelZoomTool"},{"id":"e5263693-5c08-4d98-a055-65d3cdfeb62e","type":"BoxZoomTool"},{"id":"82704c80-898c-445f-b948-662b084ce2fa","type":"SaveTool"},{"id":"1850cc62-7b23-488b-822f-f56987d04d0d","type":"ResetTool"},{"id":"ec8148e4-742d-4dbc-a48a-db8e54f98d76","type":"HelpTool"}]},"id":"be548b5c-772b-4e7f-be70-d6da1efc17aa","type":"Toolbar"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ba470ba4-e3ff-48e3-b95f-092f30454111","type":"PanTool"},{"id":"1297a795-f33d-40b5-9631-ea3808640f79","type":"WheelZoomTool"},{"id":"f648c867-6514-4b14-ad96-c7ec78b2648d","type":"BoxZoomTool"},{"id":"45663ad5-e56e-4159-8291-7314bb421db2","type":"SaveTool"},{"id":"b97095b3-8a07-49e0-b292-a5950a35ce7c","type":"ResetTool"},{"id":"e33bec21-43c4-4b22-8749-ac6e45b6dbd0","type":"HelpTool"}]},"id":"217269fb-c26c-44cd-882d-185e04005630","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"3eb2b49b-a222-4277-a98d-6df5784d1aae","type":"Title"},{"attributes":{"plot":{"id":"24dbff07-fd6f-46d0-a7eb-a5c08a700f65","subtype":"Figure","type":"Plot"}},"id":"07a68f83-c231-41a1-a0e3-a04157629167","type":"PanTool"},{"attribut ...

# %%
# リスト7.12.2：row()関数で横に並べる
from bokeh.layouts import row
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
show(row(p1, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2583425b-0148-4c05-baba-39c06d597fd8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2583425b-0148-4c05-baba-39c06d597fd8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2583425b-0148-4c05-baba-39c06d597fd8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2583425b-0148-4c05-baba-39c06d597fd8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0fa5951c-daaf-45df-98f7-debef685c88e":{"roots":{"references":[{"attributes":{"plot":{"id":"bc508b47-1cea-4795-8361-343ac096edf5","subtype":"Figure","type":"Plot"}},"id":"83cff726-5571-4be1-963b-eb42caa1f344","type":"HelpTool"},{"attributes":{},"id":"040387b7-c031-41e8-bade-284c32c34e96","type":"BasicTicker"},{"attributes":{},"id":"b9b1ebb9-7414-450e-994c-5d467e67f583","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"2de604af-9633-4b2d-9822-2a12bbee0b9b","type":"DataRange1d"},{"attributes":{},"id":"0e6d7480-0578-484c-b675-462954499dcb","type":"ToolEvents"},{"attributes":{},"id":"05f304a1-4ae2-4722-ab7c-93c336692456","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"}},"id":"0d8574c7-6996-4670-8d0e-aebf5d14029e","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"6b17ba35-58b6-4abd-900e-e856b3d7d098","type":"Title"},{"attributes":{"callback":null},"id":"9e063c03-b4fd-4972-8443-d98346a0eb90","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a0b69a87-c2e8-490b-aa92-18c37d8e6763","type":"PanTool"},{"id":"5e4c0913-aee8-4f62-ac42-f5aed6b071e9","type":"WheelZoomTool"},{"id":"8cc17099-beb3-4b3e-9fb0-2f5c18b48a68","type":"BoxZoomTool"},{"id":"16fee945-ab28-48f0-ac99-6260e15ebfa2","type":"SaveTool"},{"id":"a0ec5b6d-bae8-42f8-899f-014d091c5b44","type":"ResetTool"},{"id":"83cff726-5571-4be1-963b-eb42caa1f344","type":"HelpTool"}]},"id":"591a7dd5-9cd4-4367-96d1-a272e3560773","type":"Toolbar"},{"attributes":{"formatter":{"id":"49c130fc-3494-4e74-b56e-c4e90158cf41","type":"BasicTickFormatter"},"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"},"ticker":{"id":"05b48a3a-de79-4159-a6ad-99820be4347d","type":"BasicTicker"}},"id":"df4031b9-f2b0-44a7-9845-7726f6d7ddf4","type":"LinearAxis"},{"attributes":{"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"},"ticker":{"id":"05b48a3a-de79-4159-a6ad-99820be4347d","type":"BasicTicker"}},"id":"ba30d58b-b164-4236-8658-ba12e91102f6","type":"Grid"},{"attributes":{"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"}},"id":"2501d953-5583-4c40-843a-37a982e87fe5","type":"SaveTool"},{"attributes":{"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"}},"id":"b3471e23-363e-4224-b5e5-8f471bef930e","type":"PanTool"},{"attributes":{"formatter":{"id":"001033bc-54e1-45cb-9ec9-d8fe1a77e51f","type":"BasicTickFormatter"},"plot":{"id":"db17eaa2-a812-4c93-8949-04d692e8e26a","subtype":"Figure","type":"Plot"},"ticker":{"id":"040387b7-c031-41e8-bade-284c32c34e96","type":"BasicTicker"}},"id":"28100c9f-3ad8-4d31-866c-8189c971c2a3","type":"LinearAxis"},{"attributes":{"below":[{"id":"4a15b4d7-c345-4921-80b5-df4e561733a4","type":"LinearAxis"}],"left":[{"id":"7f427c31-cace-4c31-b6ab-a458e0b02d9e","type":"LinearAxis"}],"plot_height":200,"plot_width":200,"renderers":[{"id":"4a15b4d7-c345-4921-80b5-df4e561733a4","type":"LinearAxis"},{"id":"3448eee5-9033-429c-9ca7-e7f06d0cd6e5","type":"Grid"},{"id":"7f427c31-cace-4c31-b6ab-a458e0b02d9e","type":"LinearAxis"},{"id":"22ab4286-f593-416d-8b5c-8ce26086774c","type":"Grid"},{"id":"9393aa57-41db-452d-a89f-9eabf812cfa8","type":"BoxAnnotation"}],"title":{"id":"6b17ba35-58b6-4abd-900e-e856b3d7d098","type":"Title"},"tool_events":{"id":"0e6d7480-0578-484c-b675-462954499dcb","type":"ToolEvents"},"toolbar":{"id":"591a7dd5-9cd4-4367-96d1-a272e3560773","type":"Toolbar"},"x_range":{"id":"2de604af-9633-4b2d-9822-2a12bbee0b9b","type":"DataRange1d"},"y_range":{"id":"cb75b0b3-d3ad-497c-a011-d3269605bb72","type":"DataRange1d"}},"id":"bc508b47-1cea-4795-8361-343ac096edf5","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b3471e23-363e-4224-b5e5-8f471bef930e","type":"PanTool"},{"id":"76655294-36e6-4277-ae ...

# %%
# リスト7.12.3：gridplot()関数で並べる
from bokeh.layouts import gridplot
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=200, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(gridplot([[p1, p2], [None, p3]]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3f7c4fa0-f8e1-4a2c-955c-933f8f28479c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3f7c4fa0-f8e1-4a2c-955c-933f8f28479c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f7c4fa0-f8e1-4a2c-955c-933f8f28479c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f7c4fa0-f8e1-4a2c-955c-933f8f28479c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"85998d5b-96e5-4571-88be-ed8a1e29e040":{"roots":{"references":[{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"},"ticker":{"id":"979921c0-892d-4d7d-a617-edbd5c1a6919","type":"BasicTicker"}},"id":"27276a5c-46d0-4aef-ab34-612c050f08bc","type":"Grid"},{"attributes":{},"id":"979921c0-892d-4d7d-a617-edbd5c1a6919","type":"BasicTicker"},{"attributes":{"formatter":{"id":"fbc9b067-05cc-4582-8a10-b6bb60f2a841","type":"BasicTickFormatter"},"plot":{"id":"707ac85b-9574-41da-9c1a-465abc425906","subtype":"Figure","type":"Plot"},"ticker":{"id":"3bfe96c2-5a91-434f-9485-74e70104a10a","type":"BasicTicker"}},"id":"2184b42b-5232-431c-bec9-3259450c11e5","type":"LinearAxis"},{"attributes":{},"id":"ccf1ca33-fe72-482f-93e1-e5622cd5e256","type":"ToolEvents"},{"attributes":{"callback":null},"id":"dbe5c2ad-f17f-4c51-9fe5-c02a2c61780e","type":"DataRange1d"},{"attributes":{},"id":"aaa59ea7-85b3-4563-8ec6-823ffb85251c","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca22e481-f7bc-4c3c-8955-24fe8f10b4c2","type":"BasicTicker"}},"id":"3a0a8e0a-15c5-4098-ac49-202429a66738","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"44d25fc9-ea4e-4b5e-8c1c-f8157de0f163","type":"Circle"},{"attributes":{},"id":"ca22e481-f7bc-4c3c-8955-24fe8f10b4c2","type":"BasicTicker"},{"attributes":{"formatter":{"id":"e8b69b2c-45a1-4864-9efb-2bbbceafb2e8","type":"BasicTickFormatter"},"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca22e481-f7bc-4c3c-8955-24fe8f10b4c2","type":"BasicTicker"}},"id":"c0469006-e6b5-43ba-94f2-24dacb7703ec","type":"LinearAxis"},{"attributes":{"plot":{"id":"707ac85b-9574-41da-9c1a-465abc425906","subtype":"Figure","type":"Plot"},"ticker":{"id":"3bfe96c2-5a91-434f-9485-74e70104a10a","type":"BasicTicker"}},"id":"a190853c-cf4a-497e-bce4-c8e40cfa07f2","type":"Grid"},{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"005b4940-5f6a-4477-9b10-2551b056f0ba","type":"PanTool"},{"attributes":{"overlay":{"id":"faaff5b7-ea49-41de-914b-f72724524180","type":"BoxAnnotation"},"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"2d7bf4a8-23f0-4251-868b-c8e3c7240c98","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"84b36e45-bafc-45a9-a94d-5fd4f13fed86","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"ab35f81c-efc0-4321-9e6a-19e5e3fed34a","type":"HelpTool"},{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"d6c0a6ef-737f-43dc-9cc2-cb5ed5ed0b79","type":"ResetTool"},{"attributes":{"plot":{"id":"17fb130d-0f7c-4d9d-abe5-53380e873d86","subtype":"Figure","type":"Plot"}},"id":"f97c32a2-e7b1-4cd1-ad1a-03419d42ecc0","type":"SaveTool"},{"attributes":{},"id":"909238e4-c6ec-4260-bece-fe847a4cf305","type":"ToolEvents"},{"attributes":{},"id":"3bfe96c2-5a91-434f-9485-74e70104a10a","type":"BasicTicker"},{"attributes":{},"id":"d530746a-ebc1-4c31-8caf-78e552895c72","type":"BasicTicker"},{"attributes":{"formatter":{"id":"f5c67d20-4a67-490c-af85-c3f3ab30f6c9","type":"BasicTickFormatter"},"plot":{"id":"707ac85b-9574-41da-9c1a-465abc425906","subtype":"Figure","type":"Plot"},"ticker":{"id":"d530746a-ebc1-4c31-8caf-78e552895c72","type":"BasicTicker"}},"id":"d61c8693-9e04-4d8f-b06e-772894992456","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"707ac85b-9574-41da-9c1a-465abc425906","subtype":"Figure","type":"Plot"},"ticker":{"id":"d530746a-ebc1-4c31-8caf-78e552895c ...

# %%
# リスト7.12.4：ncolsを指定したgridplot()関数で並べる
from bokeh.layouts import gridplot
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=200, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(gridplot([p1, p2, None, p3], ncols=2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d90c740f-7018-4fce-bbe2-9dc1aa4a8754"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d90c740f-7018-4fce-bbe2-9dc1aa4a8754");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d90c740f-7018-4fce-bbe2-9dc1aa4a8754");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd90c740f-7018-4fce-bbe2-9dc1aa4a8754' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"085262a8-0b95-459f-b5d1-d0ff48de2662":{"roots":{"references":[{"attributes":{"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"}},"id":"327170e2-b8d8-4b72-8607-171b1bfec264","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"},"ticker":{"id":"7951974f-ecd1-4ffc-9a65-63c30e1ef81c","type":"BasicTicker"}},"id":"acd5c137-80e0-4d64-be36-797f3e07b53f","type":"Grid"},{"attributes":{"overlay":{"id":"071f7d56-1811-4e99-8fb1-1a9f30671d26","type":"BoxAnnotation"},"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"}},"id":"c88ebf0b-c928-4e43-adfa-52a751dfcb93","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"}},"id":"1e9f4d9e-104a-404c-953d-30efe6f9c577","type":"ResetTool"},{"attributes":{"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"}},"id":"2c0add73-4853-45d0-9a2c-788dbad05678","type":"SaveTool"},{"attributes":{},"id":"7951974f-ecd1-4ffc-9a65-63c30e1ef81c","type":"BasicTicker"},{"attributes":{},"id":"28562d8b-8798-49b1-98cd-f2bc96e88031","type":"BasicTicker"},{"attributes":{"callback":null},"id":"9719d0b2-cd06-4384-a5fd-baa81a03adf2","type":"DataRange1d"},{"attributes":{},"id":"90e8aac4-4606-45d0-9c40-9e394b4605ea","type":"BasicTicker"},{"attributes":{"formatter":{"id":"2da4b6f3-259f-4cbf-9cb4-55004c2c9da1","type":"BasicTickFormatter"},"plot":{"id":"42ddaf7b-dc00-43bf-b121-12fa4ac77ae5","subtype":"Figure","type":"Plot"},"ticker":{"id":"28562d8b-8798-49b1-98cd-f2bc96e88031","type":"BasicTicker"}},"id":"088b7c6f-9825-4468-a51a-8064e39176e3","type":"LinearAxis"},{"attributes":{"plot":{"id":"8b915d37-2bdb-49df-a000-b12d25cc7975","subtype":"Figure","type":"Plot"}},"id":"98ced815-65c9-4c4e-afbd-0252d29ef7ed","type":"HelpTool"},{"attributes":{"formatter":{"id":"4bab84e4-fe4b-4c2d-ae1e-8c333eb8c3b3","type":"BasicTickFormatter"},"plot":{"id":"42ddaf7b-dc00-43bf-b121-12fa4ac77ae5","subtype":"Figure","type":"Plot"},"ticker":{"id":"a22b4fb2-b5e8-4a39-8df7-b186421d4e00","type":"BasicTicker"}},"id":"c4a15b62-b50b-478e-8ed7-94c85e130978","type":"LinearAxis"},{"attributes":{"plot":{"id":"42ddaf7b-dc00-43bf-b121-12fa4ac77ae5","subtype":"Figure","type":"Plot"},"ticker":{"id":"28562d8b-8798-49b1-98cd-f2bc96e88031","type":"BasicTicker"}},"id":"2cd76785-9ffa-4ee7-a29a-9a2e04036d2b","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"42ddaf7b-dc00-43bf-b121-12fa4ac77ae5","subtype":"Figure","type":"Plot"},"ticker":{"id":"a22b4fb2-b5e8-4a39-8df7-b186421d4e00","type":"BasicTicker"}},"id":"3e5b398f-ead4-4cf4-af32-4987ed9fd33a","type":"Grid"},{"attributes":{},"id":"a22b4fb2-b5e8-4a39-8df7-b186421d4e00","type":"BasicTicker"},{"attributes":{"children":[{"id":"f2800ea8-dea4-4336-8145-7309ca2c1b27","type":"ToolbarBox"},{"id":"2ee6f2c4-cb72-4824-814b-89fbc6471faa","type":"Column"}]},"id":"c52428df-9ca5-4f65-adc9-7ecb7db5cea1","type":"Column"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"90117fd7-2377-4ba1-9735-bd4235e8ea1b","type":"PanTool"},{"id":"0beca8bb-a788-45ce-b580-6b61604b4984","type":"WheelZoomTool"},{"id":"f4f0a2b6-3248-45f3-b180-afe598e709e3","type":"BoxZoomTool"},{"id":"3803f008-cbcc-47f4-92dd-fd1ba75538aa","type":"SaveTool"},{"id":"a7130975-6912-46c5-969a-84543861952d","type":"ResetTool"},{"id":"c68cdb41-eed8-4af4-9d19-3a66eb407066","type":"HelpTool"}]},"id":"8efd1559-963e-4749-8cce-8531cd928035","type":"Toolbar"},{"attributes":{"data_source":{"id":"ed07424f-de74-429f-a101-5ec52f415343","type":"ColumnDataSource"},"glyph":{"id":"20a1f876-e9bd-47ed-8c4a-98b6d77629d6","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"288a6a74-c865-41e7-a2c9-f7802b6f5ce7","type":"Circle"},"selection_glyph":null},"id":"1cd1f72f-15d8-482f-8799-425dc5eb8373","type":"GlyphRenderer"},{"attributes":{"callba ...

# %%
# リスト7.12.5：layout()関数で並べる
from bokeh.layouts import layout
p1 = figure(plot_width=200, plot_height=200)
p2 = figure(plot_width=200, plot_height=200)
p3 = figure(plot_width=400, plot_height=200)
p1.circle([0], [0], size=50)
p2.square([0], [0], size=50)
p3.triangle([0], [0], size=50)
show(layout([p1, p2], [p3]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0bae336d-23f1-41fc-bef7-b782aae1372b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0bae336d-23f1-41fc-bef7-b782aae1372b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bae336d-23f1-41fc-bef7-b782aae1372b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bae336d-23f1-41fc-bef7-b782aae1372b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"de634e20-326a-4459-8b26-da24696892f4":{"roots":{"references":[{"attributes":{"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"7c25d28a-b4bb-4889-999c-5e186a053807","type":"PanTool"},{"attributes":{"children":[{"id":"89654b92-ba73-4c8f-a4d9-d50c45542b65","subtype":"Figure","type":"Plot"},{"id":"6543cfa2-4f7a-453a-93ef-5ccd50aee293","subtype":"Figure","type":"Plot"}]},"id":"baa8cb15-90af-4db1-8d53-c98b8608d17d","type":"Row"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0],"y":[0]}},"id":"0a14600e-ca9f-4fb3-bbe9-6b138f5cecaf","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"ff24b673-3d01-4a06-a60f-a451da555071","type":"HelpTool"},{"attributes":{"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"0bb24cdd-25ff-4902-9c0c-4892cdac7d8b","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"c4efa7b4-89ba-4dd7-afba-f261e92e11b6","type":"BoxAnnotation"},"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"186b4fa8-0c13-40cd-8c99-1b774bc454d0","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"71fcd645-24d3-49b0-8588-7ba9c9947073","type":"BasicTickFormatter"},"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"},"ticker":{"id":"535f1014-15f8-40e5-9468-51a5df682008","type":"BasicTicker"}},"id":"79ed2fc0-3699-49c4-8a4c-11766bba8031","type":"LinearAxis"},{"attributes":{"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"54be436a-b4bb-46cc-9dbf-0b515ef6c36f","type":"SaveTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":50},"x":{"field":"x"},"y":{"field":"y"}},"id":"4f68a5a7-ec46-4757-b2b8-81e43096223f","type":"Circle"},{"attributes":{"plot":null,"text":""},"id":"b2783dfd-16d1-4ea9-8a8a-b6494a71b4ff","type":"Title"},{"attributes":{"data_source":{"id":"80d0a270-5563-432b-8167-a524fcd7952f","type":"ColumnDataSource"},"glyph":{"id":"4f68a5a7-ec46-4757-b2b8-81e43096223f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e562a22d-bc2a-484c-8a8f-c5579ce76afe","type":"Circle"},"selection_glyph":null},"id":"e7b1f2db-a23a-4212-b2d7-8fc7da9eb32c","type":"GlyphRenderer"},{"attributes":{},"id":"535f1014-15f8-40e5-9468-51a5df682008","type":"BasicTicker"},{"attributes":{},"id":"ae1c80b5-bef1-4c61-91c8-a62030b8b455","type":"BasicTickFormatter"},{"attributes":{},"id":"fd3f2410-61a2-4989-bf03-062125c9c856","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"},"ticker":{"id":"535f1014-15f8-40e5-9468-51a5df682008","type":"BasicTicker"}},"id":"1842df37-13af-4311-a729-d1502ee5b0d7","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8ed025f9-6895-4ac0-9105-b8250624eebc","type":"BoxAnnotation"},{"attributes":{},"id":"71fcd645-24d3-49b0-8588-7ba9c9947073","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"068fdda2-bbd0-4af0-ba8d-29ae8d417634","subtype":"Figure","type":"Plot"}},"id":"6bfc3847-582a-48f0-a7d1-8f29b7ab7ff6","type":"ResetTool"},{"attributes":{"plot":{"id":"6543cfa2-4f7a-453a-93ef-5ccd50aee293","subtype":"Figure","type":"Plot"}},"id":"39ad5a26-fafc-486c-bb66-f96524fe10d0","type":"PanTool"},{"attributes":{"callback":null},"id":"7a9e6649-cac8-4513-a616-21be73abc832","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7c25d28a-b4bb-4889-999c-5e186a053807","type":"PanTool"},{"id":"0b ...
