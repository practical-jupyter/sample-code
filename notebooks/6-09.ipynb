# %% [markdown]
# ## 第6章 Bokehでグラフを描画しよう
#
# ### 6-9: 円グラフ

# %%
# リスト6.9.1：リスト-ライク・オブジェクトから円グラフを作成
from bokeh.charts import Donut, output_notebook, show

output_notebook()
p = Donut([1, 2, 3])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3eb9ca71-fc23-4fa8-8986-7b6ffc6d2207">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="85f567ca-1b99-46fd-8ab6-29b215bbf02e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("85f567ca-1b99-46fd-8ab6-29b215bbf02e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("85f567ca-1b99-46fd-8ab6-29b215bbf02e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '85f567ca-1b99-46fd-8ab6-29b215bbf02e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"86310406-c652-4539-8f31-76d739e2f989":{"roots":{"references":[{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"0a1bca70-e706-4be4-95d9-b45e5a623c78","type":"Range1d"},{"attributes":{"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"c4581634-eae4-439e-82e0-1b313d518bdb","type":"PanTool"},{"attributes":{"location":"top_left","plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"6a05ce37-90a0-4487-bfe1-9fcc9572ef84","type":"Legend"},{"attributes":{"callback":null,"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"},"tooltips":[["Value","@values"]]},"id":"b7a9d8a8-0ddd-4aa7-9788-ac8f697da79e","type":"HoverTool"},{"attributes":{},"id":"0541286e-f760-45a7-b5f9-a98031bf3d51","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6371f77d-c732-4f9e-9e13-940311a52373","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","index"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/","dtype":"float64","shape":[3]},"color":["#f22c40","#5ab738","#407ee7"],"end":{"__ndarray__":"ZXMtOFLB8D8YLURU+yEJQBgtRFT7IRlA","dtype":"float64","shape":[3]},"index":[0,1,2],"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[3]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[3]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/","dtype":"float64","shape":[3]},"start":{"__ndarray__":"AAAAAAAAAABlcy04UsHwPxgtRFT7IQlA","dtype":"float64","shape":[3]},"values":[1,2,3]}},"id":"4f309aa4-762c-4803-9b15-3a1331661b64","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"8ee2ab3e-4297-4609-949d-a37335acec76","type":"WheelZoomTool"},{"attributes":{},"id":"99bb010e-8bdd-47de-a8e8-a7628a1f74cb","type":"BasicTicker"},{"attributes":{"overlay":{"id":"6371f77d-c732-4f9e-9e13-940311a52373","type":"BoxAnnotation"},"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"82618b8a-86f3-4725-86fc-49bc49ad0db2","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"a3353e86-9c8a-47c8-a68b-7b71dd54b26a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"530152d1-fe47-42f0-b7f7-4b5dadecb481","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"6371f77d-c732-4f9e-9e13-940311a52373","type":"BoxAnnotation"},{"id":"35b253a2-5619-41f0-9db2-fa7685d76a80","type":"GlyphRenderer"},{"id":"2f31a354-a0dc-4775-a1a9-8ac6c3467762","type":"GlyphRenderer"},{"id":"6a05ce37-90a0-4487-bfe1-9fcc9572ef84","type":"Legend"},{"id":"a3353e86-9c8a-47c8-a68b-7b71dd54b26a","type":"LinearAxis"},{"id":"530152d1-fe47-42f0-b7f7-4b5dadecb481","type":"LinearAxis"}],"title":{"id":"fc260b11-3fb7-4af2-a2cd-0458d842a324","type":"Title"},"tool_events":{"id":"0541286e-f760-45a7-b5f9-a98031bf3d51","type":"ToolEvents"},"toolbar":{"id":"b405f581-a1f6-44bd-9af1-6a92062f9b7e","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0a1bca70-e706-4be4-95d9-b45e5a623c78","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"39846d6f-4ae3-451d-9c50-2d8afa8f307a","type":"Range1d"}},"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"a37b8bd1-b482-42ac-92e6-624381b04c8a","type":"SaveTool"},{"attributes":{"plot":{"id":"75c7f706-7672-42fb-8e0b-283ad5a1962a","subtype":"Chart","type":"Plot"}},"id":"2005ce6a-dafc-4266-95b ...

# %%
# リスト6.9.2：辞書型のデータから円グラフを作成
data = {"values": [1, 2, 3], "pie_label": ["a", "b", "c"]}
p = Donut(data, values="values", label="pie_label")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="68bb072f-b535-42e5-9183-5ae1e3012e42"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("68bb072f-b535-42e5-9183-5ae1e3012e42");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("68bb072f-b535-42e5-9183-5ae1e3012e42");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '68bb072f-b535-42e5-9183-5ae1e3012e42' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3d8b45af-c934-45b0-94ed-58b9d6458b5e":{"roots":{"references":[{"attributes":{"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"}},"id":"e908f4c1-39bd-4783-8ca2-9a40b0fd0926","type":"ResetTool"},{"attributes":{},"id":"e1000e55-3bda-48e9-83a2-65f4ed824d6e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"}},"id":"f103aeea-7b8f-40a0-b9b5-6c55c0e0d997","type":"WheelZoomTool"},{"attributes":{},"id":"50af19d9-38a2-4bcc-ba5c-1b856ab9b7a9","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"ab13b063-1cbb-49f3-a47f-78b7507cf368","type":"ColumnDataSource"},"glyph":{"id":"a06547e5-9527-4c35-ad8f-45dfb43c7c44","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"e4212161-b4b8-49e6-acd1-e50bdaa26d33","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"5d50ef2e-8e03-45f5-8053-b732707f04ec","type":"BoxAnnotation"},"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"}},"id":"1f165eef-8e20-432b-b2a2-4272931396fe","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"}},"id":"34ee1b43-8df7-490a-bd98-8d191d18059e","type":"SaveTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"0b38f3e6-2555-409b-9c54-f5a61cf29da8","type":"AnnularWedge"},{"attributes":{"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"}},"id":"c2438f48-7865-4798-984d-1453a6214033","type":"HelpTool"},{"attributes":{"axis_label":null,"formatter":{"id":"e1000e55-3bda-48e9-83a2-65f4ed824d6e","type":"BasicTickFormatter"},"plot":{"id":"3d2ac013-db96-46ad-9f1f-268987ab3738","subtype":"Chart","type":"Plot"},"ticker":{"id":"a67f65a0-f234-4ae4-88be-218e4eb0f1db","type":"BasicTicker"},"visible":false},"id":"31d16854-5afb-4149-b40c-c3e27098e3b0","type":"LinearAxis"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"12967e69-c0fe-48f1-85bf-7c046f342349","type":"Range1d"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a06547e5-9527-4c35-ad8f-45dfb43c7c44","type":"Text"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5d50ef2e-8e03-45f5-8053-b732707f04ec","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"79433d01-824d-4baa-87cd-a3b70f21acfa","type":"PanTool"},{"id":"f103aeea-7b8f-40a0-b9b5-6c55c0e0d997","type":"WheelZoomTool"},{"id":"1f165eef-8e20-432b-b2a2-4272931396fe","type":"BoxZoomTool"},{"id":"34ee1b43-8df7-490a-bd98-8d191d18059e","type":"SaveTool"},{"id":"e908f4c1-39bd-4783-8ca2-9a40b0fd0926","type":"ResetTool"},{"id":"c2438f48-7865-4798-984d-1453a6214033","type":"HelpTool"},{"id":"558f57f1-1068-4f71-bf84-9af713a59ab7","type":"HoverTool"}]},"id":"fffa3591-ff7a-4ff0-8fad-33cd8c77b4f5","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["a","b","c"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[3]},"x":[0.9742785792574935,-0.5624999999999998,-2.0665914735611583e-16],"y":[0.5624999999999999,0.9742785792574935,-1.125]}},"id":"ab13b063-1cbb-49f3-a47f-78b7507cf368","type":"ColumnDataSource"},{"attributes":{"plot ...

# %%
# リスト6.9.3：DataFrameから円グラフを作成
import os
import pandas as pd

base_url = (
    "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
)
anime_master_csv = os.path.join(base_url, "anime_master.csv")
df = pd.read_csv(anime_master_csv)
plot_df = df.groupby("type").mean()
p = Donut(plot_df, values="members", plot_width=400, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a79db97b-1f03-4781-bead-12c135f9a73f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a79db97b-1f03-4781-bead-12c135f9a73f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a79db97b-1f03-4781-bead-12c135f9a73f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a79db97b-1f03-4781-bead-12c135f9a73f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c320c9f7-9277-4709-8c02-da93b542c795":{"roots":{"references":[{"attributes":{"data_source":{"id":"ce9281d4-2327-455d-b528-e8b84c491215","type":"ColumnDataSource"},"glyph":{"id":"f6f0afe1-6b5f-4ce0-9238-b50d0668fc2e","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"f3cde4be-1967-4789-85de-e7271cab95c4","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"}},"id":"887f7387-2440-4c85-b031-c5017e09efae","type":"PanTool"},{"attributes":{"callback":null,"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"},"tooltips":[["Value","@values"]]},"id":"78113bd8-004c-4d47-830c-2d882373230e","type":"HoverTool"},{"attributes":{"axis_label":null,"formatter":{"id":"3bcf76df-e9d8-483d-9333-70406c119709","type":"BasicTickFormatter"},"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"},"ticker":{"id":"955e29b8-c84e-4241-90f4-c74ef30811df","type":"BasicTicker"},"visible":false},"id":"0a012bc6-d6e9-4982-a12a-5ae4da80155b","type":"LinearAxis"},{"attributes":{},"id":"955e29b8-c84e-4241-90f4-c74ef30811df","type":"BasicTicker"},{"attributes":{},"id":"e05f8f7e-02df-4e17-aea4-0e3b15310505","type":"BasicTickFormatter"},{"attributes":{},"id":"3bcf76df-e9d8-483d-9333-70406c119709","type":"BasicTickFormatter"},{"attributes":{},"id":"c076a11e-5966-4ff1-80b6-bb3e6c6cbc9d","type":"BasicTicker"},{"attributes":{"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"}},"id":"a2c77120-579d-407a-a50e-15d66ff8a79e","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"97cc6deb-ee9b-40a2-9302-3dabb1d8f58a","type":"BoxAnnotation"},"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"}},"id":"e4a04f7a-524d-4f14-b94b-75e70486655a","type":"BoxZoomTool"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"60e61753-bf3a-4743-a89e-25b7d8a755ea","type":"Range1d"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"d0b3d8ca-7840-444e-91b2-c12300555b81","type":"Range1d"},{"attributes":{"plot":{"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"}},"id":"8134f273-f1b2-4288-af6d-377a563e96c0","type":"SaveTool"},{"attributes":{"below":[{"id":"ed246665-a636-4f1a-bc04-d53bb1a3bec8","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"0a012bc6-d6e9-4982-a12a-5ae4da80155b","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"97cc6deb-ee9b-40a2-9302-3dabb1d8f58a","type":"BoxAnnotation"},{"id":"c0c42885-7f6c-4519-9b50-21542ef7db6b","type":"GlyphRenderer"},{"id":"f3cde4be-1967-4789-85de-e7271cab95c4","type":"GlyphRenderer"},{"id":"1491797b-e0bf-4ecd-815d-5a396c330bd2","type":"Legend"},{"id":"ed246665-a636-4f1a-bc04-d53bb1a3bec8","type":"LinearAxis"},{"id":"0a012bc6-d6e9-4982-a12a-5ae4da80155b","type":"LinearAxis"}],"title":{"id":"355b9f71-954e-43d1-bc2f-dfed60732fb7","type":"Title"},"tool_events":{"id":"77de5464-7575-4899-a460-dff35d56893e","type":"ToolEvents"},"toolbar":{"id":"26db4ef0-ddd1-4496-b356-c1d45a0e74d1","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"60e61753-bf3a-4743-a89e-25b7d8a755ea","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"d0b3d8ca-7840-444e-91b2-c12300555b81","type":"Range1d"}},"id":"28229d4a-1869-4580-8a65-464284b4be58","subtype":"Chart","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"887f7387-2440-4c85-b031-c5017e09efae","type":"PanTool"},{"id":"a2c77120-579d-407a-a50e-15d66ff8a79e","type":"WheelZoomTool"},{"id":"e4a04f7a-524d-4f14-b94b-75e70486655a","type":"BoxZoomTool"},{"id":"8134f273-f1b2-4288-af6d-377a563e96c0","type":"SaveTool"},{"id":"f3f9c825-d789-49d8-8e00-86cce989ec17","type":"ResetTool"},{"id":"0d8b5211-370e-4212-9c76-460c7331d55b","type":"HelpTool"},{"id":"78113bd8-004c-4d47-830c-2d882373230e","type":"HoverTool"}]}, ...

# %%
# リスト6.9.4：グループ化したグラフ
anime_genre_top10_csv = os.path.join(base_url, "anime_genre_top10.csv")
df = pd.read_csv(anime_genre_top10_csv)
p = Donut(
    df,
    label=["type", "genre"],
    values="members",
    agg="mean",
    plot_width=600,
    plot_height=600,
)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d01231e3-dc15-466b-9e0d-6b0fad74c1d5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d01231e3-dc15-466b-9e0d-6b0fad74c1d5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d01231e3-dc15-466b-9e0d-6b0fad74c1d5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd01231e3-dc15-466b-9e0d-6b0fad74c1d5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8f897976-4d46-4cc4-af0b-7ea9c7f58fdb":{"roots":{"references":[{"attributes":{"plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"}},"id":"d5a0eed0-c1c7-42d2-8b53-532bf49c5f11","type":"PanTool"},{"attributes":{},"id":"150e4a7d-bc2c-46ad-b029-450e075bae73","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"},"tooltips":[["Mean Of Members","@values"]]},"id":"a89db5a0-137b-4dea-9178-9ecd38737c57","type":"HoverTool"},{"attributes":{"axis_label":null,"formatter":{"id":"150e4a7d-bc2c-46ad-b029-450e075bae73","type":"BasicTickFormatter"},"plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"},"ticker":{"id":"87ae0fb7-d81f-435e-9d39-cf6426cbe349","type":"BasicTicker"},"visible":false},"id":"8398666c-2688-44a3-9ef1-36d01b6df4d7","type":"LinearAxis"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"ae86313b-03f8-4567-a5c3-14a24920e4e7","type":"Range1d"},{"attributes":{},"id":"64ba8efa-a0d9-4f9f-baea-5dec0bbafe2a","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"}},"id":"f7e7e4ea-2e6e-448d-85a0-23838aac2d3e","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"30b10acd-2c3f-492c-982f-2c3a12d07734","type":"BoxAnnotation"},{"attributes":{"axis_label":null,"formatter":{"id":"2f574c17-118f-484b-adbd-04c0bfc9145a","type":"BasicTickFormatter"},"plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"},"ticker":{"id":"e282114d-932d-49f2-89b9-b1f91b3e0a3e","type":"BasicTicker"},"visible":false},"id":"f15abfca-9f01-48d9-8105-1c79150ad36e","type":"LinearAxis"},{"attributes":{"data_source":{"id":"bf3d31a4-1660-4172-a239-8fe0afa97763","type":"ColumnDataSource"},"glyph":{"id":"acdede25-722c-4585-a570-19829ae02c2f","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"fc7e438e-be18-47ad-86fb-25aea1460960","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8583d535-c1a2-4775-87f6-1aa0de32d78d","subtype":"Chart","type":"Plot"}},"id":"c1ec017e-eea5-48c1-b5ea-ddc442d35219","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["Movie","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural","Music","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Supernatural","ONA","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural","OVA","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural","Special","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural","TV","Action","Adventure","Comedy","Drama","Fantasy","Romance","School","Sci-Fi","Shounen","Supernatural"],"text_angle":{"__ndarray__":"...","dtype":"float64","shape":[65]},"x":[0.962238135542212,2.2470197867689015,2.2267722307926814,2.1981326456626418,2.150715036353877,2.081540586649839,1.9563354169616958,1.7821504819369751,1.6363788647533355,1.4868231900256503,1.2325238768338083,0.4307777042028002,1.0096522096049325,0.9423247946035623,0.8988974615119439,0.8616430255741596,0.8245574863106087,0.7994128501601262,0.7778404188056424,0.729766326408322,0.6801280968485272,0.14759281914713918,0.6414220642864392,0.5962036609887371,0.5490098226592423,0.484032132228903,0.4393369417207331,0.34952062817748025,0.1985672246141179,0.08333733489508703,0.009420102623541959,-0.05880945692624547,-0.36460649580906523,-0.15867919120226737,-0.2656 ...
