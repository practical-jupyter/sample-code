# %%
# ●リスト6.9.1：リスト-ライク・オブジェクトから円グラフを作成
from bokeh.charts import Donut, output_notebook, show
output_notebook()
p = Donut([1, 2, 3])
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b747f856-1387-42ec-a0c7-7f7d6aa458f4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="36433460-768b-4702-828d-8a539ec86663"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("36433460-768b-4702-828d-8a539ec86663");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36433460-768b-4702-828d-8a539ec86663");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36433460-768b-4702-828d-8a539ec86663' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"136bb7e6-d8ff-4d4b-abfd-7afb14ec432f":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a8ef7aff-138a-48d1-9896-ad1aca1433b4","type":"PanTool"},{"id":"9928d86b-f2b1-43fc-95a6-e277600e8e0f","type":"WheelZoomTool"},{"id":"bc41e719-d6c8-4d88-b800-f1a2791893b5","type":"BoxZoomTool"},{"id":"87e83c1b-6703-49f5-ae5b-db5c04f9c4e1","type":"SaveTool"},{"id":"62465820-bc76-4e62-a26e-94722408e60a","type":"ResetTool"},{"id":"48b3189b-1b50-4f08-a6f8-3a33216d2816","type":"HelpTool"},{"id":"5a014538-4301-4e04-9b3b-4f57a673f4ce","type":"HoverTool"}]},"id":"d1e27308-4ed5-4fc5-b73e-42fdcc13298b","type":"Toolbar"},{"attributes":{"data_source":{"id":"dbe094a3-3811-43ce-a929-67a12c3d23fd","type":"ColumnDataSource"},"glyph":{"id":"226ef94f-bea7-4430-bb56-17e4276a859a","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"bb438377-7351-4cac-a02d-fe789c01bcda","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0352e615-9a67-4b41-9e62-b5c4ab8768bf","type":"BoxAnnotation"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"de4eed4e-bb96-4fac-9dfc-85d1e57c2a3f","type":"AnnularWedge"},{"attributes":{"plot":null,"text":null},"id":"4105e17c-df1d-4da4-b9d6-0fb0522a85f1","type":"Title"},{"attributes":{"axis_label":null,"formatter":{"id":"73b92827-688e-43e9-9833-9d11f615913f","type":"BasicTickFormatter"},"plot":{"id":"c46b22bc-059c-4689-9e1b-6bc64eaacbcf","subtype":"Chart","type":"Plot"},"ticker":{"id":"d07f8a75-6d15-4e83-a39c-f2955c34e30e","type":"BasicTicker"},"visible":false},"id":"e5b11ee1-f325-49d0-ae48-cc84d88bad4d","type":"LinearAxis"},{"attributes":{},"id":"73b92827-688e-43e9-9833-9d11f615913f","type":"BasicTickFormatter"},{"attributes":{},"id":"07f3ed14-9bd4-4d08-a1da-5068e2f4f6d3","type":"BasicTickFormatter"},{"attributes":{},"id":"d07f8a75-6d15-4e83-a39c-f2955c34e30e","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"c46b22bc-059c-4689-9e1b-6bc64eaacbcf","subtype":"Chart","type":"Plot"},"tooltips":[["Value","@values"]]},"id":"5a014538-4301-4e04-9b3b-4f57a673f4ce","type":"HoverTool"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"17a28968-076c-479a-a2a5-73e92725e115","type":"Range1d"},{"attributes":{"axis_label":null,"formatter":{"id":"07f3ed14-9bd4-4d08-a1da-5068e2f4f6d3","type":"BasicTickFormatter"},"plot":{"id":"c46b22bc-059c-4689-9e1b-6bc64eaacbcf","subtype":"Chart","type":"Plot"},"ticker":{"id":"8c7c7a52-97c6-4c7a-8ef2-4c9ba5e17a05","type":"BasicTicker"},"visible":false},"id":"cd679330-6d20-4c1b-a1db-8ee35698e2cd","type":"LinearAxis"},{"attributes":{"below":[{"id":"cd679330-6d20-4c1b-a1db-8ee35698e2cd","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"e5b11ee1-f325-49d0-ae48-cc84d88bad4d","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"0352e615-9a67-4b41-9e62-b5c4ab8768bf","type":"BoxAnnotation"},{"id":"877b65b2-251b-440c-9d1f-ec55006377f2","type":"GlyphRenderer"},{"id":"bb438377-7351-4cac-a02d-fe789c01bcda","type":"GlyphRenderer"},{"id":"fff512ca-ed0c-4744-8bb9-a077da00e875","type":"Legend"},{"id":"cd679330-6d20-4c1b-a1db-8ee35698e2cd","type":"LinearAxis"},{"id":"e5b11ee1-f325-49d0-ae48-cc84d88bad4d","type":"LinearAxis"}],"title":{"id":"4105e17c-df1d-4da4-b9d6-0fb0522a85f1","type":"Title"},"tool_events":{"id":"a8e870fb-6fa6-4546-9c11-5a7cfd9d1c53","type":"ToolEvents"},"toolbar":{"id ...

# %%
# ●リスト6.9.2：辞書型のデータから円グラフを作成
data = {'values': [1, 2, 3], 'pie_label': ['a', 'b', 'c']}
p = Donut(data, values='values', label='pie_label')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7ca7af29-ae33-4dae-ad7f-8bbc7832ad37"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7ca7af29-ae33-4dae-ad7f-8bbc7832ad37");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7ca7af29-ae33-4dae-ad7f-8bbc7832ad37");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7ca7af29-ae33-4dae-ad7f-8bbc7832ad37' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"032338df-6608-4b26-8989-cd93e0c17de0":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["text","x","y","text_angle"],"data":{"text":["a","b","c"],"text_angle":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[3]},"x":[0.9742785792574935,-0.5624999999999998,-2.0665914735611583e-16],"y":[0.5624999999999999,0.9742785792574935,-1.125]}},"id":"f0f417fa-fe2c-4b59-a8e2-31d6ec05556c","type":"ColumnDataSource"},{"attributes":{"axis_label":null,"formatter":{"id":"cca9de9b-97fc-4398-bef4-9fbe28354c17","type":"BasicTickFormatter"},"plot":{"id":"15b4d9ff-7330-4747-aada-114b7c3b4818","subtype":"Chart","type":"Plot"},"ticker":{"id":"5da19dd4-c6f7-49a8-9ace-9c5895622348","type":"BasicTicker"},"visible":false},"id":"cdad6188-772e-426b-b2aa-aef3c5f34ec7","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"57fd6732-45ff-422f-89e3-0a134ef99faf","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"32860015-e18d-460c-bfbd-20a1752f2a7f","type":"Range1d"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"ce405b17-ca07-4af1-84f7-d4d9f1a5c7fb","type":"Range1d"},{"attributes":{"plot":{"id":"15b4d9ff-7330-4747-aada-114b7c3b4818","subtype":"Chart","type":"Plot"}},"id":"bcc57219-6280-4e47-b310-fb01004ce6cd","type":"ResetTool"},{"attributes":{"below":[{"id":"e68b909b-4467-4b58-bee3-3722b35cac33","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"cdad6188-772e-426b-b2aa-aef3c5f34ec7","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"57fd6732-45ff-422f-89e3-0a134ef99faf","type":"BoxAnnotation"},{"id":"8dc5e0ba-5051-428b-bbac-104545d4bea6","type":"GlyphRenderer"},{"id":"786ac151-a9da-4c7d-946f-5e005fee4a9d","type":"GlyphRenderer"},{"id":"eca3e30a-1176-473d-8d25-3bfeef65cbcd","type":"Legend"},{"id":"e68b909b-4467-4b58-bee3-3722b35cac33","type":"LinearAxis"},{"id":"cdad6188-772e-426b-b2aa-aef3c5f34ec7","type":"LinearAxis"}],"title":{"id":"67b38e9f-0419-49f4-80fd-50a8a447ac0e","type":"Title"},"tool_events":{"id":"d9cec7eb-6070-4fe2-9194-6b4701ba14bc","type":"ToolEvents"},"toolbar":{"id":"8dbac8a3-4e64-4d11-ae3f-93b1671a5e49","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"32860015-e18d-460c-bfbd-20a1752f2a7f","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"ce405b17-ca07-4af1-84f7-d4d9f1a5c7fb","type":"Range1d"}},"id":"15b4d9ff-7330-4747-aada-114b7c3b4818","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"d9cec7eb-6070-4fe2-9194-6b4701ba14bc","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"67b38e9f-0419-49f4-80fd-50a8a447ac0e","type":"Title"},{"attributes":{"plot":{"id":"15b4d9ff-7330-4747-aada-114b7c3b4818","subtype":"Chart","type":"Plot"}},"id":"0ccc3144-b7cd-4352-b112-1e6fbecb07af","type":"PanTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0ccc3144-b7cd-4352-b112-1e6fbecb07af","type":"PanTool"},{"id":"5570ac06-7b99-4be2-aec4-246403a5d44d","type":"WheelZoomTool"},{"id":"da7908be-fa6a-4085-bcd5-9a59613c4efa","type":"BoxZoomTool"},{"id":"851159b2-b786-4bff-8dfc-66031e301ac8","type":"SaveTool"},{"id":"bcc57219-6280-4e47-b310-fb01004ce6cd","type":"ResetTool"},{"id":"3e21a28f-68db-486c-b062-da492fcfa23e","type":"HelpTool"},{"id":"a73e4b56-56b4-43bf-90ba-22b340d79be4","type":"HoverTool"}]},"id":"8dbac8a3-4e64-4d11-ae3f-93b1671a5e49","type":"Toolbar"},{"attributes":{},"id":"cca9de9b-97fc-4398-bef4-9fbe28354c17","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"f0f417fa-fe2c-4b59-a8e2-31d6ec05556c","type":"ColumnDataSource"},"glyph":{"id":"d8a24abf-c32e-4bfe-96 ...

# %%
# ●リスト6.9.3：DataFrameから円グラフを作成
import os
import pandas as pd
base_url = 'https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/'
anime_master_csv = os.path.join(base_url, 'anime_master.csv')
df = pd.read_csv(anime_master_csv)
plot_df = df.groupby('type').mean()
p = Donut(
    plot_df, values='members',
    plot_width=400, plot_height=400)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d487f54-66e1-4241-9fb7-e97eb68f7880"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9d487f54-66e1-4241-9fb7-e97eb68f7880");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d487f54-66e1-4241-9fb7-e97eb68f7880");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d487f54-66e1-4241-9fb7-e97eb68f7880' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"008f02a6-04fc-4983-bad0-612ba3b38541":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["end","level","start","values","inners","outers","centers","color","index"],"data":{"centers":{"__ndarray__":"AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/AAAAAAAA8j8AAAAAAADyPwAAAAAAAPI/","dtype":"float64","shape":[6]},"color":["#f22c40","#5ab738","#407ee7","#df5320","#00ad9c","#c33ff3"],"end":{"__ndarray__":"UV2JIKWS7T8X5Yqen43wP5NRzNeRqfY/yfWzLpYVAEBQeujTjTwFQBgtRFT7IRlA","dtype":"float64","shape":[6]},"index":["Movie","Music","ONA","OVA","Special","TV"],"inners":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[6]},"level":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"float64","shape":[6]},"outers":{"__ndarray__":"AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/AAAAAAAA+D8AAAAAAAD4PwAAAAAAAPg/","dtype":"float64","shape":[6]},"start":{"__ndarray__":"AAAAAAAAAABRXYkgpZLtPxflip6fjfA/k1HM15Gp9j/J9bMulhUAQFB66NONPAVA","dtype":"float64","shape":[6]},"values":{"__ndarray__":"2vVB0wLPxECkFQuPHeSTQF5YjITSMbFA49H8wYbBukDkYs79oAC9QGrRrg8KbeRA","dtype":"float64","shape":[6]}}},"id":"b397cbe1-b9e7-4e78-9646-61dbbf0e4ec2","type":"ColumnDataSource"},{"attributes":{},"id":"6727fce3-8c7d-4f66-9912-4ae4937651d0","type":"BasicTickFormatter"},{"attributes":{"axis_label":null,"formatter":{"id":"6727fce3-8c7d-4f66-9912-4ae4937651d0","type":"BasicTickFormatter"},"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"},"ticker":{"id":"bc737f76-2efb-47a2-bb69-533a6b52c0f6","type":"BasicTicker"},"visible":false},"id":"eecc1caf-5b79-4f41-918b-1d9f83b99a8a","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"00568dc2-399a-434b-b39e-b0e15f8686f5","type":"BoxAnnotation"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e5894635-80c4-44ad-8cf0-a10683ab6995","type":"Text"},{"attributes":{"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"}},"id":"ffd29504-a230-4e48-b921-14d89275256b","type":"PanTool"},{"attributes":{"callback":null,"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"},"tooltips":[["Value","@values"]]},"id":"1cacbd83-0992-4df2-b723-0b114552ee63","type":"HoverTool"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"496cff7f-fb63-4d3c-81df-703dd092cb6a","type":"Range1d"},{"attributes":{"callback":null,"end":1.6500000000000001,"start":-1.6500000000000001},"id":"c31b2888-6569-4c50-b4ac-e8dea66ac084","type":"Range1d"},{"attributes":{"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"}},"id":"17b24407-80e3-4382-9306-20787f77a6af","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"00568dc2-399a-434b-b39e-b0e15f8686f5","type":"BoxAnnotation"},"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"}},"id":"b220fff9-87cd-4378-9a86-d0e135b0b442","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"2033084d-fddc-4355-a7e8-ae56ef922417","type":"ColumnDataSource"},"glyph":{"id":"e5894635-80c4-44ad-8cf0-a10683ab6995","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"9797e0b2-b6d7-4545-aabd-6ab7543584fc","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9761ee05-4255-4550-94fd-49df310b1cfc","subtype":"Chart","type":"Plot"}},"id":"2ac771f0-7ab4-4661-94e2-123e4627acdf","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ffd29504-a230-4e48-b921-14d8927525 ...

# %%
# ●リスト6.9.4：グループ化したグラフ
anime_genre_top10_csv = os.path.join(base_url, 'anime_genre_top10.csv')
df = pd.read_csv(anime_genre_top10_csv)
p = Donut(
    df, label=['type', 'genre'],
    values='members', agg='mean',
    plot_width=600, plot_height=600)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4bbfc2ed-0e37-4102-969b-338d276666ad"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4bbfc2ed-0e37-4102-969b-338d276666ad");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4bbfc2ed-0e37-4102-969b-338d276666ad");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4bbfc2ed-0e37-4102-969b-338d276666ad' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ddac6d7c-7e4d-4cae-a75c-a1a867426a88":{"roots":{"references":[{"attributes":{},"id":"b8d608a8-8e21-4795-8337-3db49877778e","type":"ToolEvents"},{"attributes":{},"id":"650aa819-501f-410d-8aba-4ab388b8b2f6","type":"BasicTickFormatter"},{"attributes":{"location":"top_left","plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"}},"id":"beb250fe-b316-4e12-8318-2cbd926f66fe","type":"Legend"},{"attributes":{"plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"}},"id":"e490c81e-2a0d-413a-8bd9-b607c57ff3e1","type":"PanTool"},{"attributes":{"overlay":{"id":"cb1a20bb-7bef-4ce5-a386-05527d57e184","type":"BoxAnnotation"},"plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"}},"id":"6417d394-4398-45a0-b24b-f01b0e7b6a91","type":"BoxZoomTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"01b30d52-030d-4c43-83a9-47e4bf842d77","type":"AnnularWedge"},{"attributes":{"plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"}},"id":"b0d4ff47-d4a5-4f27-be37-f7f8c200cf99","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e490c81e-2a0d-413a-8bd9-b607c57ff3e1","type":"PanTool"},{"id":"45dcd78b-fdf5-4ee8-bd24-a5ec10f0f0d6","type":"WheelZoomTool"},{"id":"6417d394-4398-45a0-b24b-f01b0e7b6a91","type":"BoxZoomTool"},{"id":"b0d4ff47-d4a5-4f27-be37-f7f8c200cf99","type":"SaveTool"},{"id":"e8a253a0-fea4-4f1f-aa05-c46ef1143082","type":"ResetTool"},{"id":"a621544f-b399-4ce3-ab16-3ec6381eaa7d","type":"HelpTool"},{"id":"2d6a38bb-57f5-45d0-b0a9-ed10b49a4771","type":"HoverTool"}]},"id":"1bba165b-3331-4f1b-83dd-5a0f95c3114b","type":"Toolbar"},{"attributes":{},"id":"f80fee5b-759a-4d8f-a71d-ca0e1e21e6ca","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"},"tooltips":[["Mean Of Members","@values"]]},"id":"2d6a38bb-57f5-45d0-b0a9-ed10b49a4771","type":"HoverTool"},{"attributes":{"data_source":{"id":"85cfb864-5c71-43a9-81a5-1ba0b90be06c","type":"ColumnDataSource"},"glyph":{"id":"54ec7fe8-7842-4cfc-b6ba-ed38333a9dae","type":"Text"},"hover_glyph":null,"muted_glyph":null},"id":"3b42c19e-5120-4a93-975e-04af5c29563b","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"6e8ae5ee-3f9c-45ec-b7e9-ea90bf633abf","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"14d2f36c-1560-41f0-bc72-d4470700f73d","type":"LinearAxis"}],"renderers":[{"id":"cb1a20bb-7bef-4ce5-a386-05527d57e184","type":"BoxAnnotation"},{"id":"d045751c-ea3b-4c6c-81cf-5b8328ecd7e8","type":"GlyphRenderer"},{"id":"3b42c19e-5120-4a93-975e-04af5c29563b","type":"GlyphRenderer"},{"id":"beb250fe-b316-4e12-8318-2cbd926f66fe","type":"Legend"},{"id":"6e8ae5ee-3f9c-45ec-b7e9-ea90bf633abf","type":"LinearAxis"},{"id":"14d2f36c-1560-41f0-bc72-d4470700f73d","type":"LinearAxis"}],"title":{"id":"aa287f38-943a-400c-b0a4-a389e112c318","type":"Title"},"tool_events":{"id":"b8d608a8-8e21-4795-8337-3db49877778e","type":"ToolEvents"},"toolbar":{"id":"1bba165b-3331-4f1b-83dd-5a0f95c3114b","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"1524aabc-4478-4bdf-8cac-a5815fa0f0d9","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"d5c589ea-1776-47d2-a250-adb7f359bded","type":"Range1d"}},"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"1524aabc-4478-4bdf-8cac-a5815fa0f0d9","type":"Range1d"},{"attributes":{"plot":{"id":"06ffa09f-b25a-4a44-8ecc-5d6f9b27516d","subtype":"Chart","type":"Plot"}},"id":"e8a253a0-fea4-4f1f-aa05-c46ef1143082","type" ...
